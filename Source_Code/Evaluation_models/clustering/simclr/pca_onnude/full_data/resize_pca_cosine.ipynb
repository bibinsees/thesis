# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import tifffile as tiff
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
from copy import deepcopy   
import random
from sklearn.preprocessing import normalize

from collections import Counter
from scipy.stats import mode

# %% [markdown]
# Resize inference trasnsition not good for tsne 1d

# %%
# Set seed for reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set seed
set_seed(42)

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class SimCLR(nn.Module):
    def __init__(self, hidden_dim, lr, temperature, weight_decay):
        super().__init__()
        self.temperature = temperature
        
        # Load the pretrained ResNet-18 model
        self.convnet = torchvision.models.resnet18(weights='ResNet18_Weights.DEFAULT')
        
        # Modify the fully connected layer
        self.convnet.fc = nn.Sequential(
            nn.Linear(self.convnet.fc.in_features, 4 * hidden_dim),  # Linear layer with 4*hidden_dim output
            nn.ReLU(inplace=True),
            nn.Linear(4 * hidden_dim, 20)  # Output layer with hidden_dim output
        )

        self.optimizer = optim.AdamW(self.parameters(), lr=lr, weight_decay=weight_decay)
        self.lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(self.optimizer, T_max=50, eta_min=lr / 50)

    def forward(self, x):
        return self.convnet(x)

    def info_nce_loss(self, imgs1, imgs2, device):

        imgs = torch.cat((imgs1, imgs2), dim=0)  # Concatenate along the batch dimension
        imgs = imgs.to(device)  # Move images to the device

        # Encode all images
        feats = self.forward(imgs)
    
        # Calculate cosine similarity
        cos_sim = nn.functional.cosine_similarity(feats[:, None, :], feats[None, :, :], dim=-1)
    
        # Mask out cosine similarity to itself
        self_mask = torch.eye(cos_sim.shape[0], dtype=torch.bool, device=cos_sim.device)
        cos_sim.masked_fill_(self_mask, -9e15)
    
        # Find positive example -> batch_size//2 away from the original example
        pos_mask = self_mask.roll(shifts=cos_sim.shape[0] // 2, dims=0)
    
        # Normalize similarity scores by temperature
        cos_sim = cos_sim / self.temperature

        # InfoNCE loss
        nll = -cos_sim[pos_mask] + torch.logsumexp(cos_sim, dim=-1)
        nll = nll.mean()

        # Accuracy calculations
        # Create a combination of positive and negative similarities for ranking
        comb_sim = torch.cat([cos_sim[pos_mask][:, None],  # Positive example in first position
                          cos_sim.masked_fill(pos_mask, -9e15)], dim=-1)
    
        # Sort and get the ranking position of the positive example
        sim_argsort = comb_sim.argsort(dim=-1, descending=True).argmin(dim=-1)
    
        # Compute accuracy metrics
        top1_acc = (sim_argsort == 0).float().mean()  # Top-1 accuracy
        top5_acc = (sim_argsort < 5).float().mean()   # Top-5 accuracy
        mean_pos = 1 + sim_argsort.float().mean()     # Mean position of the positive example

        return nll, top1_acc, top5_acc, mean_pos

    def train_epoch(self, train_loader, device):
        self.train()
        total_loss = 0.0
        total_top1_acc = 0.0
        total_top5_acc = 0.0
        total_mean_pos = 0.0

        for batch in tqdm(train_loader, desc="Training", leave=False):
            imgs1, imgs2, _ = batch
            imgs1, imgs2 = imgs1.to(device), imgs2.to(device)  # Move data to device
        
            self.optimizer.zero_grad()

            # Calculate loss and accuracy metrics
            loss, top1_acc, top5_acc, mean_pos = self.info_nce_loss(imgs1, imgs2, device)

            loss.backward()
            self.optimizer.step()
            self.lr_scheduler.step()

            # Accumulate metrics
            total_loss += loss.item()
            total_top1_acc += top1_acc.item()
            total_top5_acc += top5_acc.item()
            total_mean_pos += mean_pos.item()

        avg_loss = total_loss / len(train_loader)
        avg_top1_acc = total_top1_acc / len(train_loader)
        avg_top5_acc = total_top5_acc / len(train_loader)
        avg_mean_pos = total_mean_pos / len(train_loader)

        return avg_loss, avg_top1_acc, avg_top5_acc, avg_mean_pos

    def validate_epoch(self, val_loader, device):
        self.eval()
        total_loss = 0.0
        total_top1_acc = 0.0
        total_top5_acc = 0.0
        total_mean_pos = 0.0

        with torch.no_grad():
            for batch in tqdm(val_loader, desc="Validating", leave=False):
                imgs1, imgs2, _ = batch
                imgs1, imgs2 = imgs1.to(device), imgs2.to(device)  # Move data to device

                # Calculate loss and accuracy metrics
                loss, top1_acc, top5_acc, mean_pos = self.info_nce_loss(imgs1, imgs2, device)

                # Accumulate metrics
                total_loss += loss.item()
                total_top1_acc += top1_acc.item()
                total_top5_acc += top5_acc.item()
                total_mean_pos += mean_pos.item()

        avg_loss = total_loss / len(val_loader)
        avg_top1_acc = total_top1_acc / len(val_loader)
        avg_top5_acc = total_top5_acc / len(val_loader)
        avg_mean_pos = total_mean_pos / len(val_loader)

        return avg_loss, avg_top1_acc, avg_top5_acc, avg_mean_pos

# %%
full_model_path =  r'C:\Users\k54739\Bibi_new_thesis\saved_model\resize_simclr_modelepoch250.pth' 
simclr_model = torch.load(full_model_path)
simclr_model.to(device)
simclr_model.eval()
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_15324\3495648145.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   simclr_model = torch.load(full_model_path)
# SimCLR(
#   (convnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=512, out_features=20, bias=True)
#     )
#   )
# )

# %% [markdown]
# # Clustering

# %%
class LabeledImageDataset(Dataset):
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        #self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Ensure the image has 3 layers (channels)
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} does not have exactly 3 layers.")

        # Normalize the 16-bit image to [0, 1]
        image = image.astype(np.float32) / 65535.0

        # Convert to a torch tensor and add channel dimension
        image = torch.tensor(image, dtype=torch.float32)
        
        # Apply resize transform
        image = self.resize_transform(image)

        label = self.labels[idx]

        #return image, label
        return image, label, img_path

def load_data(root_dir):
    #classes = ['cond7_all', 'sd','ex'] #full dataset
    #classes = ['cond7_curated', 'sd','ex'] # curated full dataset


    #classes = ['cure_cond7_40', 'sdonly_40','ex'] # 40 subset
    classes = ['cond7_all', 'sd','ex']


   
    
    #classes = ['curated_cond7_40', 'sd_40','ex'] # curated 40 subset


    image_files = []
    labels = []

    for idx, class_name in enumerate(classes):
        class_dir = os.path.join(root_dir, class_name)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir) if file.endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        labels.extend([idx] * len(files))
    
    # Check if the labels correctly reflect the classes
    print("Label distribution:", {classes[i]: labels.count(i) for i in range(len(classes))})

    return image_files, labels


# Directories for labeled data
#image_dir =  r"C:\Users\k54739\Bibi_new_thesis\thesis\classification"

image_dir =  r"G:\classification\cond_all"


# Load data
image_files, labels = load_data(image_dir)

# Create the labeled datasets
labeled_dataset = LabeledImageDataset(image_files, labels)

# Define DataLoaders
batch_size = 16
loader_labeled = DataLoader(labeled_dataset, batch_size=batch_size, shuffle=True, drop_last=False, pin_memory=True, num_workers=0)
# Out:
# Label distribution: {'cond7_all': 472, 'sd': 103, 'ex': 40}

# %%
# Print label mapping
classes = ['cond7_all', 'sd','ex']
for idx, class_name in enumerate(classes):
    print(f"Label {idx} corresponds to class: {class_name}")
# Out:
# Label 0 corresponds to class: cond7_all
# Label 1 corresponds to class: sd
# Label 2 corresponds to class: ex

# %%
label_mapping = {idx: class_name for idx, class_name in enumerate(classes)}
print("Label mapping:", label_mapping)
# Out:
# Label mapping: {0: 'cond7_all', 1: 'sd', 2: 'ex'}

# %%
for anchor,label,path in loader_labeled:
    print(anchor.shape, label.shape, anchor.dtype)
    print(label)
    print(path)
    break
# Out:
# torch.Size([16, 3, 96, 96]) torch.Size([16]) torch.float32
# tensor([1, 0, 0, 0, 0, 0, 1, 2, 1, 1, 0, 0, 0, 0, 0, 0])
# ['G:\\classification\\cond_all\\sd\\RBT10_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_D09-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g8_B11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_D07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D10-T01.tiff']

# %%
@torch.no_grad()
def prepare_data_features(model, dataloader):
    # Prepare model
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()  # Removing projection head g(.)
    network.eval()
    network.to(device)

    # Encode all images
    feats, labels, paths = [], [], []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        print(f"Batch features shape: {batch_feats.shape}")
        print(f"Batch labels shape: {batch_labels.shape}")
        print(f"Batch labels shape: {batch_paths}")
        
        feats.append(batch_feats.detach().cpu())
        labels.append(batch_labels)
        paths.extend(batch_paths) 

    feats = torch.cat(feats, dim=0)
    labels = torch.cat(labels, dim=0)
    
    
    print(f"Features shape after concatenation: {feats.shape}")
    print(f"Labels shape after concatenation: {labels.shape}")
    print(f"Number of paths after concatenation: {len(paths)}")

    return feats, labels, paths

# %% [markdown]
# @torch.no_grad()
# def prepare_data_features(model, dataloader):
#     # Prepare model
#     network = deepcopy(model.convnet)
#     network.fc = nn.Identity()  # Removing projection head g(.)
#     network.eval()
#     network.to(device)
#
#     # Encode all images
#     feats, labels = [], []
#     for batch_imgs, batch_labels in tqdm(dataloader):
#         batch_imgs = batch_imgs.to(device)
#         batch_feats = network(batch_imgs)
#         print(f"Batch features shape: {batch_feats.shape}")
#         print(f"Batch labels shape: {batch_labels.shape}")
#
#         feats.append(batch_feats.detach().cpu())
#         labels.append(batch_labels)
#
#     feats = torch.cat(feats, dim=0)
#     labels = torch.cat(labels, dim=0)
#
#     print(f"Features shape after concatenation: {feats.shape}")
#     print(f"Labels shape after concatenation: {labels.shape}")
#
#     return torch.utils.data.TensorDataset(feats, labels)

# %%
# Extract features for train and test datasets
feats, labels, paths = prepare_data_features(simclr_model, loader_labeled)
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]
#   3%|▎         | 1/39 [00:05<03:28,  5.49s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_62_G08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B04-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B04-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_E11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F04-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g9_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B07-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g8_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F05-T01.tiff']
#   5%|▌         | 2/39 [00:10<03:12,  5.21s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_52_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F04-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_C10-T01.tiff']
#   8%|▊         | 3/39 [00:15<03:01,  5.04s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT09_B11-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g9_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D08-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g9_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_C08-T01.tiff']
#  10%|█         | 4/39 [00:19<02:46,  4.77s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_52_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_G10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E11-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g9_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C09-T01.tiff']
#  13%|█▎        | 5/39 [00:25<02:51,  5.03s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_62_B10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g9_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D03-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G02-T01.tiff']
#  15%|█▌        | 6/39 [00:30<02:43,  4.97s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT09_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E04-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_F08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G10-T01.tiff']
#  18%|█▊        | 7/39 [00:34<02:32,  4.75s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT14_C07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_D09-T01.tiff']
#  21%|██        | 8/39 [00:38<02:22,  4.58s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_41_F04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B03-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g9_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G11-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds41_g9_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F04-T01.tiff']
#  23%|██▎       | 9/39 [00:43<02:22,  4.74s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\sd_04_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C06-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_G10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E11-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g3_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B09-T01.tiff']
#  26%|██▌       | 10/39 [00:48<02:18,  4.77s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT14_B10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g8_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C03-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C07-T01.tiff']
#  28%|██▊       | 11/39 [00:53<02:19,  5.00s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT14_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_G08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B03-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_C07-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g6_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g3_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D07-T01.tiff']
#  31%|███       | 12/39 [00:59<02:20,  5.20s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_52_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G03-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B08-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g6_F03-T01.tiff']
#  33%|███▎      | 13/39 [01:05<02:21,  5.44s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT09_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_G09-T01.tiff']
#  36%|███▌      | 14/39 [01:11<02:16,  5.47s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_42_E11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_E08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C03-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G11-T01.tiff']
#  38%|███▊      | 15/39 [01:15<02:05,  5.23s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_51_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D06-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_D07-T01.tiff']
#  41%|████      | 16/39 [01:21<02:05,  5.44s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT10_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G06-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g9_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G06-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_E11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F07-T01.tiff']
#  44%|████▎     | 17/39 [01:27<02:01,  5.53s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_1B_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_E11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E02-T01.tiff']
#  46%|████▌     | 18/39 [01:33<01:58,  5.64s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\ex\\ds62_g8_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g3_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G06-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D08-T01.tiff']
#  49%|████▊     | 19/39 [01:38<01:52,  5.62s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_1B_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C06-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_C09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G04-T01.tiff']
#  51%|█████▏    | 20/39 [01:43<01:42,  5.39s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_51_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B03-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g8_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F04-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F03-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G09-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds41_g3_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D03-T01.tiff']
#  54%|█████▍    | 21/39 [01:49<01:39,  5.52s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_42_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D04-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g3_C03-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g6_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E02-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g9_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D06-T01.tiff']
#  56%|█████▋    | 22/39 [01:55<01:33,  5.51s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_42_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C04-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_C09-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds1B_g9_C7.tif', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g3_C04-T01.tiff']
#  59%|█████▉    | 23/39 [02:00<01:28,  5.55s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_42_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B02-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds41_g3_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_C08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C09-T01.tiff']
#  62%|██████▏   | 24/39 [02:06<01:23,  5.55s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_62_F11-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g9_C09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_F10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_G08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F06-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g8_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E04-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds1B_g9_C8.tif', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g6_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F06-T01.tiff']
#  64%|██████▍   | 25/39 [02:12<01:20,  5.72s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_61_D03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F06-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g8_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B04-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E06-T01.tiff']
#  67%|██████▋   | 26/39 [02:17<01:12,  5.61s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_52_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D10-T01.tiff']
#  69%|██████▉   | 27/39 [02:24<01:10,  5.90s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT10_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B03-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds1B_g9_c10.tif', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D03-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G06-T01.tiff']
#  72%|███████▏  | 28/39 [02:30<01:07,  6.09s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_42_E02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_D10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E04-T01.tiff']
#  74%|███████▍  | 29/39 [02:37<01:01,  6.14s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_41_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_G09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_G10-T01.tiff']
#  77%|███████▋  | 30/39 [02:43<00:56,  6.23s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_52_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F08-T01.tiff']
#  79%|███████▉  | 31/39 [02:49<00:48,  6.08s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_51_D04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E09-T01.tiff']
#  82%|████████▏ | 32/39 [02:55<00:43,  6.22s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_1B_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C09-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds41_g3_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C06-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_F07-T01.tiff']
#  85%|████████▍ | 33/39 [03:02<00:37,  6.33s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_62_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B07-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g6_F04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C03-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_G08-T01.tiff']
#  87%|████████▋ | 34/39 [03:08<00:31,  6.33s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\ex\\ds1B_g9_C9.tif', 'G:\\classification\\cond_all\\sd\\RBT09_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_B11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_E08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_C10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds1B_g9_C11.tif', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F03-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_B10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C04-T01.tiff']
#  90%|████████▉ | 35/39 [03:15<00:25,  6.40s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_62_F09-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g9_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D04-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C07-T01.tiff']
#  92%|█████████▏| 36/39 [03:21<00:19,  6.45s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_51_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_G09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E04-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D11-T01.tiff']
#  95%|█████████▍| 37/39 [03:28<00:12,  6.44s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\ex\\ds61_g8_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D09-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds41_g3_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B08-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds41_g3_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G03-T01.tiff']
#  97%|█████████▋| 38/39 [03:34<00:06,  6.27s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_62_B11-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g8_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_E10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_C10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g8_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E08-T01.tiff']
# 100%|██████████| 39/39 [03:37<00:00,  5.57s/it]
# Batch features shape: torch.Size([7, 512])
# Batch labels shape: torch.Size([7])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT14_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F03-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G11-T01.tiff']
# Features shape after concatenation: torch.Size([615, 512])
# Labels shape after concatenation: torch.Size([615])
# Number of paths after concatenation: 615

# %%
import umap
import matplotlib.pyplot as plt
import numpy as np

# Assuming feats is a tensor of shape (N, feature_size), where N is the number of samples and feature_size is the dimensionality of the features
# You can reduce the dimensionality of feats with UMAP

# Convert feats to numpy array
feats_np = feats.detach().cpu().numpy()

# 2D UMAP projection
umap_2d = umap.UMAP(n_components=2, random_state=42)
feats_2d = umap_2d.fit_transform(feats_np)

# 1D UMAP projection
umap_1d = umap.UMAP(n_components=1, random_state=42)
feats_1d = umap_1d.fit_transform(feats_np)

# Plot 2D UMAP
plt.figure(figsize=(10, 6))
plt.scatter(feats_2d[:, 0], feats_2d[:, 1], c=labels, cmap='viridis', edgecolors='k', s=50)
plt.colorbar(label='Class Label')
plt.title('2D UMAP projection of features')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()

# Plot 1D UMAP
plt.figure(figsize=(10, 6))
plt.scatter(feats_1d, np.zeros_like(feats_1d), c=labels, cmap='viridis', edgecolors='k', s=50)
plt.colorbar(label='Class Label')
plt.title('1D UMAP projection of features')
plt.xlabel('UMAP 1D')
plt.yticks([])  # Hide the y-axis ticks since it's all zeros
plt.show()
# Out:
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
s

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE
import seaborn as sns

# Perform t-SNE
perplexity = 30  # You can tune this parameter
n_iter = 1000  # Number of iterations for optimization

# Convert features to NumPy array if they are in tensor form
feats_np = feats.numpy() if isinstance(feats, torch.Tensor) else feats
labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else labels

# Apply t-SNE
print("Running t-SNE...")
tsne = TSNE(n_components=2, perplexity=perplexity, n_iter=n_iter, random_state=42)
feats_2d = tsne.fit_transform(feats_np)

# Create a scatter plot
plt.figure(figsize=(10, 8))
sns.scatterplot(x=feats_2d[:, 0], y=feats_2d[:, 1], hue=labels_np, palette="deep", alpha=0.7, edgecolors='k')
plt.title("2D t-SNE Visualization of Features")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.legend(title="Class", loc='best')
plt.grid(True)
plt.show()
# Out:
# Running t-SNE...
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE
import seaborn as sns

# Perform t-SNE
perplexity = 30  # You can tune this parameter
n_iter = 1000  # Number of iterations for optimization

# Convert features to NumPy array if they are in tensor form
feats_np = feats.numpy() if isinstance(feats, torch.Tensor) else feats
labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else labels

# Apply t-SNE
print("Running t-SNE...")
tsne = TSNE(n_components=2, perplexity=perplexity, n_iter=n_iter, random_state=42)
feats_2d = tsne.fit_transform(feats_np)

# Define colors for the different classes
num_classes = len(np.unique(labels_np))
colors = plt.cm.rainbow(np.linspace(0, 1, num_classes))

# Create a scatter plot
plt.figure(figsize=(10, 8))
for i, color in zip(np.unique(labels_np), colors):
    plt.scatter(feats_2d[labels_np == i, 0], feats_2d[labels_np == i, 1], label=f'Class {i}', color=color, alpha=0.7, edgecolors='k')

plt.title("2D t-SNE Visualization of Features")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.legend(title="Class", loc='best')
plt.grid(True)
plt.show()
# Out:
# Running t-SNE...
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE

# Perform t-SNE
perplexity = 30  # Tune as needed
n_iter = 1000  # Number of optimization iterations

# Convert features to NumPy array if they are in tensor form
feats_np = feats.numpy() if isinstance(feats, torch.Tensor) else feats
labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else labels

# Apply 1D t-SNE
print("Running 1D t-SNE...")
tsne = TSNE(n_components=1, perplexity=perplexity, n_iter=n_iter, random_state=42)
feats_1d = tsne.fit_transform(feats_np).flatten()  # Flatten to make it a 1D array

# Define colors for the different classes
num_classes = len(np.unique(labels_np))
colors = plt.cm.rainbow(np.linspace(0, 1, num_classes))

# Create a scatter plot in 1D
plt.figure(figsize=(12, 4))
for i, color in zip(np.unique(labels_np), colors):
    plt.scatter(feats_1d[labels_np == i], np.zeros_like(feats_1d[labels_np == i]), 
                label=f'Class {i}', color=color, alpha=0.7, edgecolors='k')

plt.title("1D t-SNE Visualization of Features")
plt.xlabel("t-SNE Component 1")
plt.yticks([])  # Remove y-axis ticks for clarity
plt.legend(title="Class", loc='best')
plt.grid(axis='x')
plt.show()
# Out:
# Running 1D t-SNE...
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE
import torch

# Perform t-SNE
perplexity = 30  # Tune as needed
n_iter = 1000  # Number of optimization iterations

# Convert features to NumPy array if they are in tensor form
feats_np = feats.numpy() if isinstance(feats, torch.Tensor) else feats
labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else labels

# Apply 1D t-SNE
print("Running 1D t-SNE...")
tsne = TSNE(n_components=1, perplexity=perplexity, n_iter=n_iter, random_state=42)
feats_1d = tsne.fit_transform(feats_np).flatten()  # Flatten to make it a 1D array

# Get unique class labels and assign y-values accordingly
unique_labels = np.unique(labels_np)
class_y_positions = {label: i for i, label in enumerate(unique_labels)}

# Map labels to their respective y positions
y_positions = np.array([class_y_positions[label] for label in labels_np])

# Define colors for the different classes
num_classes = len(unique_labels)
colors = plt.cm.rainbow(np.linspace(0, 1, num_classes))

# Create a scatter plot in 1D with separate y-axis levels for each class
plt.figure(figsize=(12, 6))
for i, color in zip(unique_labels, colors):
    plt.scatter(feats_1d[labels_np == i], y_positions[labels_np == i], 
                label=f'Class {i}', color=color, alpha=0.7, edgecolors='k')

plt.title("1D t-SNE Visualization of Features")
plt.xlabel("t-SNE Component 1")
plt.ylabel("Class")
plt.yticks(range(len(unique_labels)), [f'Class {label}' for label in unique_labels])  # Set y-axis labels
plt.legend(title="Class", loc='best')
plt.grid(axis='x')
plt.show()
# Out:
# Running 1D t-SNE...
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %% [markdown]
# import matplotlib.pyplot as plt
# import numpy as np
# from sklearn.manifold import TSNE
#
# # Perform t-SNE
# perplexity = 30  # Tune as needed
# n_iter = 1000  # Number of optimization iterations
#
# # Convert features to NumPy array if they are in tensor form
# feats_np = feats.numpy() if isinstance(feats, torch.Tensor) else feats
# labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else labels
#
# # Apply 1D t-SNE
# print("Running 1D t-SNE...")
# tsne = TSNE(n_components=1, perplexity=perplexity, n_iter=n_iter, random_state=42)
# feats_1d = tsne.fit_transform(feats_np).flatten()  # Flatten to make it a 1D array
#
# # Print paths along with t-SNE scores
# print("\nPaths and t-SNE Scores:")
# for path, score in zip(paths, feats_1d):
#     print(f"{path}: {score:.4f}")
#
# # Define colors for the different classes
# num_classes = len(np.unique(labels_np))
# colors = plt.cm.rainbow(np.linspace(0, 1, num_classes))
#
# # Create a scatter plot in 1D
# plt.figure(figsize=(12, 4))
# for i, color in zip(np.unique(labels_np), colors):
#     plt.scatter(feats_1d[labels_np == i], np.zeros_like(feats_1d[labels_np == i]),
#                 label=f'Class {i}', color=color, alpha=0.7, edgecolors='k')
#
# plt.title("1D t-SNE Visualization of Features")
# plt.xlabel("t-SNE Component 1")
# plt.yticks([])  # Remove y-axis ticks for clarity
# plt.legend(title="Class", loc='best')
# plt.grid(axis='x')
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE

# Perform t-SNE
perplexity = 30  # Tune as needed
n_iter = 1000  # Number of optimization iterations

# Convert features to NumPy array if they are in tensor form
feats_np = feats.numpy() if isinstance(feats, torch.Tensor) else feats
labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else labels

# Apply 1D t-SNE
print("Running 1D t-SNE...")
tsne = TSNE(n_components=1, perplexity=perplexity, n_iter=n_iter, random_state=42)
feats_1d = tsne.fit_transform(feats_np).flatten()  # Flatten to 1D array

# Sort paths and scores in ascending order of t-SNE scores
sorted_indices = np.argsort(feats_1d)  # Get indices that would sort the scores
sorted_paths = np.array(paths)[sorted_indices]
sorted_scores = feats_1d[sorted_indices]

# Print sorted paths with corresponding t-SNE scores
print("\nPaths and t-SNE Scores (Ascending Order):")
for path, score in zip(sorted_paths, sorted_scores):
    print(f"{path}: {score:.4f}")

# Define colors for the different classes
num_classes = len(np.unique(labels_np))
colors = plt.cm.rainbow(np.linspace(0, 1, num_classes))

# Create a scatter plot in 1D
plt.figure(figsize=(12, 4))
for i, color in zip(np.unique(labels_np), colors):
    plt.scatter(sorted_scores[labels_np[sorted_indices] == i], 
                np.zeros_like(sorted_scores[labels_np[sorted_indices] == i]), 
                label=f'Class {i}', color=color, alpha=0.7, edgecolors='k')

plt.title("1D t-SNE Visualization of Features (Sorted)")
plt.xlabel("t-SNE Component 1")
plt.yticks([])  # Remove y-axis ticks for clarity
plt.legend(title="Class", loc='best')
plt.grid(axis='x')
plt.show()
# Out:
# Running 1D t-SNE...
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Paths and t-SNE Scores (Ascending Order):
# G:\classification\cond_all\sd\RBT14_C08-T01.tiff: -41.3881
# G:\classification\cond_all\sd\RBT10_G11-T01.tiff: -41.3314
# G:\classification\cond_all\sd\RBT10_G07-T01.tiff: -41.2104
# G:\classification\cond_all\sd\RBT04_F08-T01.tiff: -41.0074
# G:\classification\cond_all\sd\RBT09_G10-T01.tiff: -40.9657
# G:\classification\cond_all\sd\RBT09_G08-T01.tiff: -40.9214
# G:\classification\cond_all\sd\RBT10_G10-T01.tiff: -40.8921
# G:\classification\cond_all\sd\RBT09_B10-T01.tiff: -40.7260
# G:\classification\cond_all\sd\RBT04_G07-T01.tiff: -40.4051
# G:\classification\cond_all\sd\RBT04_F11-T01.tiff: -40.3354
# G:\classification\cond_all\sd\RBT04_G10-T01.tiff: -40.3292
# G:\classification\cond_all\sd\RBT04_G11-T01.tiff: -40.1174
# G:\classification\cond_all\sd\RBT09_G11-T01.tiff: -40.1010
# G:\classification\cond_all\sd\RBT04_G09-T01.tiff: -39.9728
# G:\classification\cond_all\sd\RBT10_G09-T01.tiff: -39.8419
# G:\classification\cond_all\sd\RBT10_G08-T01.tiff: -39.6968
# G:\classification\cond_all\sd\RBT10_F11-T01.tiff: -39.5666
# G:\classification\cond_all\sd\RBT09_G09-T01.tiff: -39.5482
# G:\classification\cond_all\sd\RBT09_G07-T01.tiff: -39.4296
# G:\classification\cond_all\sd\RBT09_F10-T01.tiff: -39.2556
# G:\classification\cond_all\sd\RBT09_B11-T01.tiff: -39.1498
# G:\classification\cond_all\sd\RBT04_G08-T01.tiff: -38.8958
# G:\classification\cond_all\sd\RBT09_F09-T01.tiff: -38.8627
# G:\classification\cond_all\sd\RBT09_F11-T01.tiff: -38.5723
# G:\classification\cond_all\sd\RBT14_C09-T01.tiff: -38.5551
# G:\classification\cond_all\sd\RBT04_D10-T01.tiff: -38.5301
# G:\classification\cond_all\sd\RBT09_B09-T01.tiff: -38.4730
# G:\classification\cond_all\sd\RBT09_D11-T01.tiff: -38.1962
# G:\classification\cond_all\sd\RBT09_E11-T01.tiff: -38.1270
# G:\classification\cond_all\sd\RBT09_F08-T01.tiff: -38.1244
# G:\classification\cond_all\sd\RBT09_B07-T01.tiff: -38.0300
# G:\classification\cond_all\sd\RBT09_B08-T01.tiff: -37.9415
# G:\classification\cond_all\sd\RBT09_C10-T01.tiff: -37.9068
# G:\classification\cond_all\sd\RBT09_F07-T01.tiff: -37.8281
# G:\classification\cond_all\sd\RBT09_C11-T01.tiff: -37.5148
# G:\classification\cond_all\sd\RBT09_D09-T01.tiff: -37.4940
# G:\classification\cond_all\sd\RBT10_F09-T01.tiff: -37.3140
# G:\classification\cond_all\sd\RBT09_C09-T01.tiff: -37.2807
# G:\classification\cond_all\sd\RBT04_F09-T01.tiff: -37.2623
# G:\classification\cond_all\sd\RBT09_E10-T01.tiff: -37.1906
# G:\classification\cond_all\sd\RBT04_F07-T01.tiff: -37.1881
# G:\classification\cond_all\sd\RBT09_E07-T01.tiff: -36.9953
# G:\classification\cond_all\sd\RBT09_C07-T01.tiff: -36.9870
# G:\classification\cond_all\sd\RBT09_C08-T01.tiff: -36.9301
# G:\classification\cond_all\sd\RBT09_D08-T01.tiff: -36.8402
# G:\classification\cond_all\sd\RBT09_E08-T01.tiff: -36.8322
# G:\classification\cond_all\sd\RBT04_F10-T01.tiff: -36.7880
# G:\classification\cond_all\sd\RBT09_E09-T01.tiff: -36.7718
# G:\classification\cond_all\sd\RBT09_D07-T01.tiff: -36.6905
# G:\classification\cond_all\sd\RBT09_D10-T01.tiff: -36.6065
# G:\classification\cond_all\sd\RBT10_F07-T01.tiff: -36.5536
# G:\classification\cond_all\sd\RBT10_D10-T01.tiff: -36.1370
# G:\classification\cond_all\sd\RBT10_F08-T01.tiff: -35.8945
# G:\classification\cond_all\sd\RBT10_F10-T01.tiff: -35.8442
# G:\classification\cond_all\sd\RBT10_E11-T01.tiff: -35.7582
# G:\classification\cond_all\sd\RBT04_E11-T01.tiff: -35.6546
# G:\classification\cond_all\sd\RBT10_E10-T01.tiff: -35.5193
# G:\classification\cond_all\sd\RBT10_C11-T01.tiff: -35.4182
# G:\classification\cond_all\sd\RBT04_D11-T01.tiff: -35.2889
# G:\classification\cond_all\sd\RBT04_E10-T01.tiff: -35.2506
# G:\classification\cond_all\sd\RBT10_D09-T01.tiff: -35.1247
# G:\classification\cond_all\sd\RBT10_C08-T01.tiff: -34.7924
# G:\classification\cond_all\sd\RBT10_D07-T01.tiff: -34.7787
# G:\classification\cond_all\sd\RBT10_C10-T01.tiff: -34.7083
# G:\classification\cond_all\sd\RBT10_C09-T01.tiff: -34.5895
# G:\classification\cond_all\sd\RBT10_B08-T01.tiff: -34.5105
# G:\classification\cond_all\sd\RBT10_B07-T01.tiff: -34.4816
# G:\classification\cond_all\sd\RBT10_E09-T01.tiff: -34.4608
# G:\classification\cond_all\sd\RBT10_C07-T01.tiff: -34.4177
# G:\classification\cond_all\sd\RBT10_B10-T01.tiff: -34.3894
# G:\classification\cond_all\sd\RBT10_D11-T01.tiff: -34.2500
# G:\classification\cond_all\sd\RBT10_B11-T01.tiff: -34.2164
# G:\classification\cond_all\sd\RBT10_D08-T01.tiff: -34.0871
# G:\classification\cond_all\sd\RBT10_B09-T01.tiff: -34.0832
# G:\classification\cond_all\sd\RBT04_D08-T01.tiff: -34.0407
# G:\classification\cond_all\sd\RBT04_B09-T01.tiff: -34.0256
# G:\classification\cond_all\sd\RBT04_B10-T01.tiff: -33.8833
# G:\classification\cond_all\sd\RBT04_B08-T01.tiff: -33.7379
# G:\classification\cond_all\sd\RBT04_E09-T01.tiff: -33.7315
# G:\classification\cond_all\sd\RBT04_B07-T01.tiff: -33.6652
# G:\classification\cond_all\sd\RBT04_D09-T01.tiff: -33.5181
# G:\classification\cond_all\sd\RBT04_C07-T01.tiff: -33.4952
# G:\classification\cond_all\sd\RBT04_C08-T01.tiff: -33.4705
# G:\classification\cond_all\sd\RBT04_E08-T01.tiff: -33.4355
# G:\classification\cond_all\sd\RBT14_D08-T01.tiff: -32.9240
# G:\classification\cond_all\sd\RBT04_C09-T01.tiff: -32.8164
# G:\classification\cond_all\sd\RBT04_D07-T01.tiff: -32.6583
# G:\classification\cond_all\sd\RBT14_C07-T01.tiff: -32.5674
# G:\classification\cond_all\sd\RBT04_E07-T01.tiff: -32.3544
# G:\classification\cond_all\sd\RBT10_E07-T01.tiff: -32.3531
# G:\classification\cond_all\sd\RBT04_C10-T01.tiff: -32.2718
# G:\classification\cond_all\sd\RBT14_D09-T01.tiff: -32.1371
# G:\classification\cond_all\sd\RBT14_D07-T01.tiff: -31.6953
# G:\classification\cond_all\sd\RBT14_B08-T01.tiff: -31.4904
# G:\classification\cond_all\sd\RBT14_B07-T01.tiff: -31.4639
# G:\classification\cond_all\sd\RBT14_C10-T01.tiff: -31.4224
# G:\classification\cond_all\sd\RBT14_D10-T01.tiff: -31.3467
# G:\classification\cond_all\sd\RBT14_B09-T01.tiff: -31.0784
# G:\classification\cond_all\sd\RBT14_C11-T01.tiff: -30.9795
# G:\classification\cond_all\sd\RBT14_B11-T01.tiff: -30.9131
# G:\classification\cond_all\sd\RBT04_B11-T01.tiff: -30.9031
# G:\classification\cond_all\sd\RBT14_B10-T01.tiff: -30.7901
# G:\classification\cond_all\sd\RBT14_D11-T01.tiff: -29.5202
# G:\classification\cond_all\ex\ds41_g3_C06-T01.tiff: -28.5859
# G:\classification\cond_all\ex\ds41_g3_C03-T01.tiff: -28.4113
# G:\classification\cond_all\ex\ds41_g3_C05-T01.tiff: -28.3262
# G:\classification\cond_all\ex\ds41_g3_C02-T01.tiff: -28.2712
# G:\classification\cond_all\ex\ds41_g3_C04-T01.tiff: -27.6143
# G:\classification\cond_all\ex\ds62_g9_C09-T01.tiff: -27.2002
# G:\classification\cond_all\ex\ds41_g9_C10-T01.tiff: -27.1085
# G:\classification\cond_all\ex\ds62_g8_B07-T01.tiff: -27.0766
# G:\classification\cond_all\ex\ds62_g9_C10-T01.tiff: -27.0606
# G:\classification\cond_all\ex\ds62_g8_B11-T01.tiff: -26.9781
# G:\classification\cond_all\ex\ds62_g8_B10-T01.tiff: -26.9589
# G:\classification\cond_all\ex\ds62_g9_C08-T01.tiff: -26.9280
# G:\classification\cond_all\ex\ds62_g9_C07-T01.tiff: -26.5964
# G:\classification\cond_all\ex\ds62_g9_C11-T01.tiff: -26.5661
# G:\classification\cond_all\ex\ds62_g8_B09-T01.tiff: -26.3080
# G:\classification\cond_all\ex\ds61_g9_C11-T01.tiff: -25.6063
# G:\classification\cond_all\ex\ds61_g9_C10-T01.tiff: -25.5019
# G:\classification\cond_all\ex\ds61_g8_B10-T01.tiff: -25.4991
# G:\classification\cond_all\ex\ds61_g9_C09-T01.tiff: -25.4775
# G:\classification\cond_all\ex\ds61_g8_B09-T01.tiff: -25.3958
# G:\classification\cond_all\ex\ds61_g8_B11-T01.tiff: -25.3760
# G:\classification\cond_all\ex\ds61_g9_C08-T01.tiff: -25.3211
# G:\classification\cond_all\ex\ds61_g8_B07-T01.tiff: -25.0746
# G:\classification\cond_all\ex\ds61_g6_F05-T01.tiff: -24.8591
# G:\classification\cond_all\ex\ds61_g3_C05-T01.tiff: -24.6241
# G:\classification\cond_all\ex\ds61_g3_C06-T01.tiff: -24.5340
# G:\classification\cond_all\ex\ds61_g3_C03-T01.tiff: -24.4547
# G:\classification\cond_all\ex\ds61_g6_F02-T01.tiff: -24.3670
# G:\classification\cond_all\ex\ds61_g3_C04-T01.tiff: -24.3443
# G:\classification\cond_all\ex\ds61_g3_C02-T01.tiff: -24.3073
# G:\classification\cond_all\ex\ds61_g6_F03-T01.tiff: -24.0769
# G:\classification\cond_all\ex\ds61_g6_F04-T01.tiff: -23.9621
# G:\classification\cond_all\ex\ds61_g9_C07-T01.tiff: -23.9262
# G:\classification\cond_all\ex\ds61_g8_B08-T01.tiff: -22.9237
# G:\classification\cond_all\ex\ds1B_g9_C9.tif: -22.7622
# G:\classification\cond_all\ex\ds61_g6_F06-T01.tiff: -22.7474
# G:\classification\cond_all\ex\ds1B_g9_c10.tif: -22.5684
# G:\classification\cond_all\ex\ds1B_g9_C11.tif: -22.5660
# G:\classification\cond_all\ex\ds1B_g9_C7.tif: -22.5495
# G:\classification\cond_all\ex\ds1B_g9_C8.tif: -22.4475
# G:\classification\cond_all\cond7_all\ds_52_G06-T01.tiff: -21.6850
# G:\classification\cond_all\cond7_all\ds_62_B11-T01.tiff: -19.3204
# G:\classification\cond_all\cond7_all\ds_61_E02-T01.tiff: -18.9878
# G:\classification\cond_all\cond7_all\ds_62_B10-T01.tiff: -18.8301
# G:\classification\cond_all\cond7_all\ds_62_B04-T01.tiff: -18.5792
# G:\classification\cond_all\cond7_all\ds_62_B05-T01.tiff: -18.5194
# G:\classification\cond_all\cond7_all\ds_62_G05-T01.tiff: -18.4836
# G:\classification\cond_all\cond7_all\ds_62_G03-T01.tiff: -18.2554
# G:\classification\cond_all\cond7_all\ds_62_C10-T01.tiff: -18.1820
# G:\classification\cond_all\cond7_all\ds_61_B03-T01.tiff: -17.9160
# G:\classification\cond_all\cond7_all\ds_62_B08-T01.tiff: -17.8399
# G:\classification\cond_all\cond7_all\ds_61_C11-T01.tiff: -17.7958
# G:\classification\cond_all\cond7_all\ds_61_G06-T01.tiff: -17.7883
# G:\classification\cond_all\cond7_all\ds_62_D04-T01.tiff: -17.7866
# G:\classification\cond_all\cond7_all\ds_61_G09-T01.tiff: -17.7253
# G:\classification\cond_all\cond7_all\ds_62_G09-T01.tiff: -17.6267
# G:\classification\cond_all\cond7_all\ds_62_G07-T01.tiff: -17.6150
# G:\classification\cond_all\cond7_all\ds_61_G08-T01.tiff: -17.5585
# G:\classification\cond_all\cond7_all\ds_62_E08-T01.tiff: -17.4179
# G:\classification\cond_all\cond7_all\ds_61_E05-T01.tiff: -17.3492
# G:\classification\cond_all\cond7_all\ds_62_F10-T01.tiff: -17.3169
# G:\classification\cond_all\cond7_all\ds_62_G10-T01.tiff: -16.9319
# G:\classification\cond_all\cond7_all\ds_61_C02-T01.tiff: -16.9311
# G:\classification\cond_all\cond7_all\ds_61_C04-T01.tiff: -16.9048
# G:\classification\cond_all\cond7_all\ds_61_D02-T01.tiff: -16.8922
# G:\classification\cond_all\cond7_all\ds_61_F10-T01.tiff: -16.8083
# G:\classification\cond_all\cond7_all\ds_61_E06-T01.tiff: -16.7722
# G:\classification\cond_all\cond7_all\ds_62_F11-T01.tiff: -16.7414
# G:\classification\cond_all\cond7_all\ds_61_B10-T01.tiff: -16.5154
# G:\classification\cond_all\cond7_all\ds_62_C11-T01.tiff: -16.4502
# G:\classification\cond_all\cond7_all\ds_62_F08-T01.tiff: -16.3724
# G:\classification\cond_all\cond7_all\ds_62_E09-T01.tiff: -16.3137
# G:\classification\cond_all\cond7_all\ds_61_E03-T01.tiff: -16.2657
# G:\classification\cond_all\cond7_all\ds_61_G10-T01.tiff: -16.2116
# G:\classification\cond_all\cond7_all\ds_61_D06-T01.tiff: -16.1722
# G:\classification\cond_all\cond7_all\ds_61_C05-T01.tiff: -15.8707
# G:\classification\cond_all\cond7_all\ds_62_C05-T01.tiff: -15.8424
# G:\classification\cond_all\cond7_all\ds_62_F09-T01.tiff: -15.7881
# G:\classification\cond_all\cond7_all\ds_62_F07-T01.tiff: -15.7184
# G:\classification\cond_all\cond7_all\ds_62_E07-T01.tiff: -15.4904
# G:\classification\cond_all\cond7_all\ds_62_B06-T01.tiff: -15.2284
# G:\classification\cond_all\cond7_all\ds_62_E03-T01.tiff: -15.1847
# G:\classification\cond_all\cond7_all\ds_62_C03-T01.tiff: -14.8741
# G:\classification\cond_all\cond7_all\ds_62_E04-T01.tiff: -14.8183
# G:\classification\cond_all\cond7_all\ds_62_F06-T01.tiff: -14.7958
# G:\classification\cond_all\cond7_all\ds_62_B03-T01.tiff: -14.7918
# G:\classification\cond_all\cond7_all\ds_62_D02-T01.tiff: -14.7908
# G:\classification\cond_all\cond7_all\ds_62_E05-T01.tiff: -14.7616
# G:\classification\cond_all\cond7_all\ds_62_F04-T01.tiff: -14.4594
# G:\classification\cond_all\cond7_all\ds_61_G03-T01.tiff: -14.4238
# G:\classification\cond_all\cond7_all\ds_62_C07-T01.tiff: -13.8664
# G:\classification\cond_all\cond7_all\ds_61_C03-T01.tiff: -13.8172
# G:\classification\cond_all\cond7_all\ds_62_F02-T01.tiff: -13.5397
# G:\classification\cond_all\cond7_all\ds_62_G04-T01.tiff: -12.6551
# G:\classification\cond_all\cond7_all\ds_62_G02-T01.tiff: -12.5489
# G:\classification\cond_all\cond7_all\ds_62_E02-T01.tiff: -11.9414
# G:\classification\cond_all\cond7_all\ds_62_G11-T01.tiff: -11.8343
# G:\classification\cond_all\cond7_all\ds_62_G06-T01.tiff: -11.4256
# G:\classification\cond_all\cond7_all\ds_61_G05-T01.tiff: -11.1811
# G:\classification\cond_all\cond7_all\ds_62_G08-T01.tiff: -11.0941
# G:\classification\cond_all\cond7_all\ds_52_E08-T01.tiff: -10.7887
# G:\classification\cond_all\cond7_all\ds_52_C09-T01.tiff: -10.6739
# G:\classification\cond_all\cond7_all\ds_62_B09-T01.tiff: -9.9951
# G:\classification\cond_all\cond7_all\ds_62_C09-T01.tiff: -9.9606
# G:\classification\cond_all\cond7_all\ds_62_E11-T01.tiff: -9.8013
# G:\classification\cond_all\cond7_all\ds_61_F06-T01.tiff: -9.6968
# G:\classification\cond_all\cond7_all\ds_61_B05-T01.tiff: -9.6931
# G:\classification\cond_all\cond7_all\ds_61_E04-T01.tiff: -9.6355
# G:\classification\cond_all\cond7_all\ds_61_E11-T01.tiff: -9.2439
# G:\classification\cond_all\cond7_all\ds_62_D11-T01.tiff: -9.2174
# G:\classification\cond_all\cond7_all\ds_61_E10-T01.tiff: -9.1040
# G:\classification\cond_all\cond7_all\ds_61_D05-T01.tiff: -8.8968
# G:\classification\cond_all\cond7_all\ds_61_F05-T01.tiff: -8.8587
# G:\classification\cond_all\cond7_all\ds_61_C07-T01.tiff: -8.7237
# G:\classification\cond_all\cond7_all\ds_61_F11-T01.tiff: -8.5544
# G:\classification\cond_all\cond7_all\ds_61_F09-T01.tiff: -8.4562
# G:\classification\cond_all\cond7_all\ds_62_D10-T01.tiff: -8.4293
# G:\classification\cond_all\cond7_all\ds_52_C06-T01.tiff: -8.3474
# G:\classification\cond_all\cond7_all\ds_61_E07-T01.tiff: -8.1849
# G:\classification\cond_all\cond7_all\ds_61_C08-T01.tiff: -7.9768
# G:\classification\cond_all\cond7_all\ds_52_F05-T01.tiff: -7.6450
# G:\classification\cond_all\cond7_all\ds_52_G09-T01.tiff: -7.5835
# G:\classification\cond_all\cond7_all\ds_52_G07-T01.tiff: -7.4156
# G:\classification\cond_all\cond7_all\ds_41_F09-T01.tiff: -7.2625
# G:\classification\cond_all\cond7_all\ds_41_C07-T01.tiff: -7.1656
# G:\classification\cond_all\cond7_all\ds_52_B07-T01.tiff: -7.1600
# G:\classification\cond_all\cond7_all\ds_51_G03-T01.tiff: -7.0587
# G:\classification\cond_all\cond7_all\ds_41_E06-T01.tiff: -6.9888
# G:\classification\cond_all\cond7_all\ds_52_C07-T01.tiff: -6.9426
# G:\classification\cond_all\cond7_all\ds_41_C09-T01.tiff: -6.8973
# G:\classification\cond_all\cond7_all\ds_41_E09-T01.tiff: -6.6987
# G:\classification\cond_all\cond7_all\ds_41_B08-T01.tiff: -6.5909
# G:\classification\cond_all\cond7_all\ds_41_E04-T01.tiff: -6.5412
# G:\classification\cond_all\cond7_all\ds_41_F06-T01.tiff: -6.5225
# G:\classification\cond_all\cond7_all\ds_52_F06-T01.tiff: -6.4883
# G:\classification\cond_all\cond7_all\ds_41_D06-T01.tiff: -6.2375
# G:\classification\cond_all\cond7_all\ds_52_C04-T01.tiff: -6.0616
# G:\classification\cond_all\cond7_all\ds_52_C03-T01.tiff: -6.0599
# G:\classification\cond_all\cond7_all\ds_41_F08-T01.tiff: -5.8475
# G:\classification\cond_all\cond7_all\ds_52_F04-T01.tiff: -5.7982
# G:\classification\cond_all\cond7_all\ds_41_G06-T01.tiff: -5.7091
# G:\classification\cond_all\cond7_all\ds_52_G08-T01.tiff: -5.5841
# G:\classification\cond_all\cond7_all\ds_41_F03-T01.tiff: -5.5687
# G:\classification\cond_all\cond7_all\ds_52_B02-T01.tiff: -5.5655
# G:\classification\cond_all\cond7_all\ds_52_G05-T01.tiff: -5.4971
# G:\classification\cond_all\cond7_all\ds_41_G08-T01.tiff: -5.3971
# G:\classification\cond_all\cond7_all\ds_42_E06-T01.tiff: -5.2188
# G:\classification\cond_all\cond7_all\ds_41_G05-T01.tiff: -5.2057
# G:\classification\cond_all\cond7_all\ds_42_G06-T01.tiff: -5.0645
# G:\classification\cond_all\cond7_all\ds_41_E05-T01.tiff: -5.0379
# G:\classification\cond_all\cond7_all\ds_41_G04-T01.tiff: -4.9990
# G:\classification\cond_all\cond7_all\ds_41_B09-T01.tiff: -4.9892
# G:\classification\cond_all\cond7_all\ds_52_E02-T01.tiff: -4.3814
# G:\classification\cond_all\cond7_all\ds_52_G11-T01.tiff: -4.3420
# G:\classification\cond_all\cond7_all\ds_52_B11-T01.tiff: -4.3239
# G:\classification\cond_all\cond7_all\ds_52_F02-T01.tiff: -4.2085
# G:\classification\cond_all\cond7_all\ds_62_D08-T01.tiff: -4.1372
# G:\classification\cond_all\cond7_all\ds_62_B07-T01.tiff: -4.0791
# G:\classification\cond_all\cond7_all\ds_62_C02-T01.tiff: -3.9629
# G:\classification\cond_all\cond7_all\ds_62_F05-T01.tiff: -3.6522
# G:\classification\cond_all\cond7_all\ds_52_B09-T01.tiff: -3.5681
# G:\classification\cond_all\cond7_all\ds_62_D06-T01.tiff: -3.5057
# G:\classification\cond_all\cond7_all\ds_52_B03-T01.tiff: -3.4663
# G:\classification\cond_all\cond7_all\ds_61_F07-T01.tiff: -3.0625
# G:\classification\cond_all\cond7_all\ds_52_E03-T01.tiff: -2.8728
# G:\classification\cond_all\cond7_all\ds_62_D07-T01.tiff: -2.8613
# G:\classification\cond_all\cond7_all\ds_41_G09-T01.tiff: -2.8170
# G:\classification\cond_all\cond7_all\ds_62_C06-T01.tiff: -2.8022
# G:\classification\cond_all\cond7_all\ds_52_B06-T01.tiff: -2.7989
# G:\classification\cond_all\cond7_all\ds_52_E05-T01.tiff: -2.7909
# G:\classification\cond_all\cond7_all\ds_52_G04-T01.tiff: -2.7505
# G:\classification\cond_all\cond7_all\ds_62_D09-T01.tiff: -2.6194
# G:\classification\cond_all\cond7_all\ds_52_C02-T01.tiff: -2.5422
# G:\classification\cond_all\cond7_all\ds_52_C05-T01.tiff: -2.2675
# G:\classification\cond_all\cond7_all\ds_61_F08-T01.tiff: -2.1545
# G:\classification\cond_all\cond7_all\ds_52_B08-T01.tiff: -2.0377
# G:\classification\cond_all\cond7_all\ds_62_D05-T01.tiff: -1.9172
# G:\classification\cond_all\cond7_all\ds_52_F03-T01.tiff: -1.8870
# G:\classification\cond_all\cond7_all\ds_41_F04-T01.tiff: -1.8118
# G:\classification\cond_all\cond7_all\ds_41_F02-T01.tiff: -1.6895
# G:\classification\cond_all\cond7_all\ds_41_F05-T01.tiff: -1.5972
# G:\classification\cond_all\cond7_all\ds_52_D06-T01.tiff: -1.3144
# G:\classification\cond_all\cond7_all\ds_52_E04-T01.tiff: -1.2555
# G:\classification\cond_all\cond7_all\ds_41_B06-T01.tiff: -1.1731
# G:\classification\cond_all\cond7_all\ds_41_D07-T01.tiff: -1.1133
# G:\classification\cond_all\cond7_all\ds_41_D05-T01.tiff: -0.9571
# G:\classification\cond_all\cond7_all\ds_41_G07-T01.tiff: -0.9509
# G:\classification\cond_all\cond7_all\ds_41_B05-T01.tiff: -0.9046
# G:\classification\cond_all\cond7_all\ds_41_E02-T01.tiff: -0.7783
# G:\classification\cond_all\cond7_all\ds_61_B06-T01.tiff: -0.7644
# G:\classification\cond_all\cond7_all\ds_41_C06-T01.tiff: -0.7306
# G:\classification\cond_all\cond7_all\ds_41_E03-T01.tiff: -0.6358
# G:\classification\cond_all\cond7_all\ds_61_B07-T01.tiff: -0.6290
# G:\classification\cond_all\cond7_all\ds_52_D05-T01.tiff: -0.5665
# G:\classification\cond_all\cond7_all\ds_41_C04-T01.tiff: -0.5109
# G:\classification\cond_all\cond7_all\ds_62_E10-T01.tiff: -0.2361
# G:\classification\cond_all\cond7_all\ds_52_E06-T01.tiff: -0.1387
# G:\classification\cond_all\cond7_all\ds_41_C08-T01.tiff: -0.0989
# G:\classification\cond_all\cond7_all\ds_52_D03-T01.tiff: -0.0119
# G:\classification\cond_all\cond7_all\ds_41_D04-T01.tiff: 0.0041
# G:\classification\cond_all\cond7_all\ds_41_C03-T01.tiff: 0.0766
# G:\classification\cond_all\cond7_all\ds_41_D03-T01.tiff: 0.2436
# G:\classification\cond_all\cond7_all\ds_52_C10-T01.tiff: 0.4773
# G:\classification\cond_all\cond7_all\ds_61_C09-T01.tiff: 0.5812
# G:\classification\cond_all\cond7_all\ds_61_E08-T01.tiff: 0.6841
# G:\classification\cond_all\cond7_all\ds_52_D02-T01.tiff: 0.7259
# G:\classification\cond_all\cond7_all\ds_41_C05-T01.tiff: 0.7400
# G:\classification\cond_all\cond7_all\ds_52_D04-T01.tiff: 0.8701
# G:\classification\cond_all\cond7_all\ds_52_B10-T01.tiff: 1.3175
# G:\classification\cond_all\cond7_all\ds_41_E10-T01.tiff: 1.3696
# G:\classification\cond_all\cond7_all\ds_41_F10-T01.tiff: 1.4745
# G:\classification\cond_all\cond7_all\ds_52_F07-T01.tiff: 1.4961
# G:\classification\cond_all\cond7_all\ds_52_C08-T01.tiff: 1.8081
# G:\classification\cond_all\cond7_all\ds_41_D08-T01.tiff: 1.9665
# G:\classification\cond_all\cond7_all\ds_61_D09-T01.tiff: 2.0211
# G:\classification\cond_all\cond7_all\ds_52_F08-T01.tiff: 2.0596
# G:\classification\cond_all\cond7_all\ds_52_F11-T01.tiff: 2.1309
# G:\classification\cond_all\cond7_all\ds_52_F10-T01.tiff: 2.1659
# G:\classification\cond_all\cond7_all\ds_52_D09-T01.tiff: 2.3768
# G:\classification\cond_all\cond7_all\ds_52_E07-T01.tiff: 2.4260
# G:\classification\cond_all\cond7_all\ds_41_E08-T01.tiff: 2.4420
# G:\classification\cond_all\cond7_all\ds_52_E09-T01.tiff: 2.7206
# G:\classification\cond_all\cond7_all\ds_52_F09-T01.tiff: 3.0554
# G:\classification\cond_all\cond7_all\ds_52_D07-T01.tiff: 3.1040
# G:\classification\cond_all\cond7_all\ds_51_G04-T01.tiff: 3.1542
# G:\classification\cond_all\cond7_all\ds_52_G10-T01.tiff: 3.1545
# G:\classification\cond_all\cond7_all\ds_51_G06-T01.tiff: 3.2138
# G:\classification\cond_all\cond7_all\ds_41_C10-T01.tiff: 3.6990
# G:\classification\cond_all\cond7_all\ds_41_D10-T01.tiff: 3.8127
# G:\classification\cond_all\cond7_all\sd_04_G02-T01.tiff: 4.0935
# G:\classification\cond_all\cond7_all\sd_04_G03-T01.tiff: 4.1989
# G:\classification\cond_all\cond7_all\ds_42_G07-T01.tiff: 4.2107
# G:\classification\cond_all\cond7_all\ds_41_G10-T01.tiff: 4.2866
# G:\classification\cond_all\cond7_all\ds_42_G08-T01.tiff: 4.6376
# G:\classification\cond_all\cond7_all\ds_61_D03-T01.tiff: 4.7146
# G:\classification\cond_all\cond7_all\ds_41_G11-T01.tiff: 4.8019
# G:\classification\cond_all\cond7_all\ds_41_C11-T01.tiff: 4.9293
# G:\classification\cond_all\cond7_all\ds_61_D07-T01.tiff: 5.0332
# G:\classification\cond_all\cond7_all\ds_61_D10-T01.tiff: 5.4723
# G:\classification\cond_all\cond7_all\ds_61_G07-T01.tiff: 5.6594
# G:\classification\cond_all\cond7_all\ds_61_C10-T01.tiff: 5.7139
# G:\classification\cond_all\cond7_all\ds_42_G10-T01.tiff: 5.8614
# G:\classification\cond_all\cond7_all\ds_42_G11-T01.tiff: 5.9565
# G:\classification\cond_all\cond7_all\ds_61_G04-T01.tiff: 5.9693
# G:\classification\cond_all\cond7_all\ds_61_G11-T01.tiff: 6.3814
# G:\classification\cond_all\cond7_all\ds_61_B09-T01.tiff: 6.6068
# G:\classification\cond_all\cond7_all\ds_52_B05-T01.tiff: 6.7442
# G:\classification\cond_all\cond7_all\ds_61_D04-T01.tiff: 6.7858
# G:\classification\cond_all\cond7_all\ds_61_B02-T01.tiff: 6.9280
# G:\classification\cond_all\cond7_all\ds_61_B11-T01.tiff: 7.0828
# G:\classification\cond_all\cond7_all\ds_62_C08-T01.tiff: 7.0995
# G:\classification\cond_all\cond7_all\ds_62_C04-T01.tiff: 7.1091
# G:\classification\cond_all\cond7_all\ds_62_D03-T01.tiff: 7.2593
# G:\classification\cond_all\cond7_all\ds_61_G02-T01.tiff: 7.4469
# G:\classification\cond_all\cond7_all\ds_61_F04-T01.tiff: 7.6561
# G:\classification\cond_all\cond7_all\ds_62_E06-T01.tiff: 7.6627
# G:\classification\cond_all\cond7_all\ds_62_B02-T01.tiff: 7.8471
# G:\classification\cond_all\cond7_all\ds_52_B04-T01.tiff: 8.0313
# G:\classification\cond_all\cond7_all\ds_61_C06-T01.tiff: 8.1292
# G:\classification\cond_all\cond7_all\ds_52_G03-T01.tiff: 8.2620
# G:\classification\cond_all\cond7_all\ds_61_F02-T01.tiff: 8.4491
# G:\classification\cond_all\cond7_all\ds_42_G09-T01.tiff: 8.7100
# G:\classification\cond_all\cond7_all\ds_52_E11-T01.tiff: 8.7283
# G:\classification\cond_all\cond7_all\ds_52_G02-T01.tiff: 8.7524
# G:\classification\cond_all\cond7_all\ds_41_B07-T01.tiff: 8.9795
# G:\classification\cond_all\cond7_all\ds_41_B11-T01.tiff: 9.0386
# G:\classification\cond_all\cond7_all\ds_42_F10-T01.tiff: 9.0602
# G:\classification\cond_all\cond7_all\ds_41_B04-T01.tiff: 9.1575
# G:\classification\cond_all\cond7_all\ds_41_D02-T01.tiff: 9.2956
# G:\classification\cond_all\cond7_all\ds_41_C02-T01.tiff: 9.3597
# G:\classification\cond_all\cond7_all\ds_41_B03-T01.tiff: 9.4177
# G:\classification\cond_all\cond7_all\sd_04_B03-T01.tiff: 9.5200
# G:\classification\cond_all\cond7_all\ds_42_B10-T01.tiff: 9.9156
# G:\classification\cond_all\cond7_all\ds_42_C06-T01.tiff: 10.1279
# G:\classification\cond_all\cond7_all\ds_42_C04-T01.tiff: 10.1361
# G:\classification\cond_all\cond7_all\ds_42_D06-T01.tiff: 10.2123
# G:\classification\cond_all\cond7_all\ds_42_B06-T01.tiff: 10.2516
# G:\classification\cond_all\cond7_all\ds_42_D05-T01.tiff: 10.3194
# G:\classification\cond_all\cond7_all\ds_42_F03-T01.tiff: 10.3421
# G:\classification\cond_all\cond7_all\ds_41_G02-T01.tiff: 10.4254
# G:\classification\cond_all\cond7_all\ds_42_B03-T01.tiff: 10.6245
# G:\classification\cond_all\cond7_all\ds_42_D04-T01.tiff: 10.7032
# G:\classification\cond_all\cond7_all\ds_42_E04-T01.tiff: 10.7616
# G:\classification\cond_all\cond7_all\ds_42_F06-T01.tiff: 10.9539
# G:\classification\cond_all\cond7_all\ds_42_B09-T01.tiff: 10.9587
# G:\classification\cond_all\cond7_all\ds_42_F02-T01.tiff: 10.9804
# G:\classification\cond_all\cond7_all\ds_42_D02-T01.tiff: 11.0739
# G:\classification\cond_all\cond7_all\ds_42_C03-T01.tiff: 11.0972
# G:\classification\cond_all\cond7_all\ds_42_F04-T01.tiff: 11.2969
# G:\classification\cond_all\cond7_all\ds_42_C05-T01.tiff: 11.3597
# G:\classification\cond_all\cond7_all\ds_42_E03-T01.tiff: 11.4189
# G:\classification\cond_all\cond7_all\ds_42_G04-T01.tiff: 11.5237
# G:\classification\cond_all\cond7_all\ds_42_G05-T01.tiff: 11.6003
# G:\classification\cond_all\cond7_all\ds_42_E05-T01.tiff: 11.7185
# G:\classification\cond_all\cond7_all\ds_42_C11-T01.tiff: 11.8791
# G:\classification\cond_all\cond7_all\ds_42_B11-T01.tiff: 12.0159
# G:\classification\cond_all\cond7_all\ds_1B_B02-T01.tiff: 12.1259
# G:\classification\cond_all\cond7_all\ds_61_F03-T01.tiff: 12.3583
# G:\classification\cond_all\cond7_all\ds_42_C10-T01.tiff: 12.4888
# G:\classification\cond_all\cond7_all\ds_42_C09-T01.tiff: 12.5880
# G:\classification\cond_all\cond7_all\ds_42_D03-T01.tiff: 12.6518
# G:\classification\cond_all\cond7_all\ds_42_C08-T01.tiff: 12.6949
# G:\classification\cond_all\cond7_all\ds_1B_B07-T01.tiff: 12.7121
# G:\classification\cond_all\cond7_all\ds_42_B05-T01.tiff: 12.8991
# G:\classification\cond_all\cond7_all\ds_1B_B03-T01.tiff: 12.9071
# G:\classification\cond_all\cond7_all\ds_42_E02-T01.tiff: 12.9874
# G:\classification\cond_all\cond7_all\ds_42_B08-T01.tiff: 12.9896
# G:\classification\cond_all\cond7_all\ds_41_B10-T01.tiff: 13.1077
# G:\classification\cond_all\cond7_all\ds_42_B07-T01.tiff: 13.1942
# G:\classification\cond_all\cond7_all\ds_42_C07-T01.tiff: 13.3069
# G:\classification\cond_all\cond7_all\ds_42_C02-T01.tiff: 13.6411
# G:\classification\cond_all\cond7_all\ds_42_F05-T01.tiff: 13.7275
# G:\classification\cond_all\cond7_all\ds_42_B04-T01.tiff: 13.8343
# G:\classification\cond_all\cond7_all\ds_42_G02-T01.tiff: 13.8963
# G:\classification\cond_all\cond7_all\ds_42_B02-T01.tiff: 14.0781
# G:\classification\cond_all\cond7_all\ds_1B_B04-T01.tiff: 14.3840
# G:\classification\cond_all\cond7_all\ds_42_E11-T01.tiff: 15.6637
# G:\classification\cond_all\cond7_all\ds_61_E09-T01.tiff: 15.7196
# G:\classification\cond_all\cond7_all\ds_41_E07-T01.tiff: 16.0181
# G:\classification\cond_all\cond7_all\ds_42_F07-T01.tiff: 16.2233
# G:\classification\cond_all\cond7_all\ds_42_E07-T01.tiff: 16.2619
# G:\classification\cond_all\cond7_all\ds_41_D09-T01.tiff: 16.6479
# G:\classification\cond_all\cond7_all\sd_04_G04-T01.tiff: 16.8820
# G:\classification\cond_all\cond7_all\ds_41_F07-T01.tiff: 16.8955
# G:\classification\cond_all\cond7_all\sd_04_F11-T01.tiff: 17.0614
# G:\classification\cond_all\cond7_all\sd_04_G06-T01.tiff: 17.1251
# G:\classification\cond_all\cond7_all\sd_04_G11-T01.tiff: 17.1786
# G:\classification\cond_all\cond7_all\sd_04_G05-T01.tiff: 17.4839
# G:\classification\cond_all\cond7_all\sd_04_G08-T01.tiff: 18.1756
# G:\classification\cond_all\cond7_all\sd_04_G07-T01.tiff: 18.2090
# G:\classification\cond_all\cond7_all\sd_04_G09-T01.tiff: 18.2116
# G:\classification\cond_all\cond7_all\ds_52_C11-T01.tiff: 18.9823
# G:\classification\cond_all\cond7_all\ds_51_E05-T01.tiff: 19.5792
# G:\classification\cond_all\cond7_all\ds_51_B05-T01.tiff: 19.6269
# G:\classification\cond_all\cond7_all\ds_51_B08-T01.tiff: 19.7273
# G:\classification\cond_all\cond7_all\ds_52_D11-T01.tiff: 19.7788
# G:\classification\cond_all\cond7_all\ds_51_G02-T01.tiff: 19.9681
# G:\classification\cond_all\cond7_all\ds_51_F08-T01.tiff: 20.1647
# G:\classification\cond_all\cond7_all\ds_51_E02-T01.tiff: 20.2173
# G:\classification\cond_all\cond7_all\ds_52_E10-T01.tiff: 20.2321
# G:\classification\cond_all\cond7_all\ds_51_C02-T01.tiff: 20.6489
# G:\classification\cond_all\cond7_all\ds_51_B03-T01.tiff: 20.6843
# G:\classification\cond_all\cond7_all\ds_51_B02-T01.tiff: 20.7363
# G:\classification\cond_all\cond7_all\ds_51_C05-T01.tiff: 21.0240
# G:\classification\cond_all\cond7_all\ds_51_D03-T01.tiff: 21.0430
# G:\classification\cond_all\cond7_all\ds_51_G11-T01.tiff: 21.1170
# G:\classification\cond_all\cond7_all\ds_51_B07-T01.tiff: 21.1351
# G:\classification\cond_all\cond7_all\ds_51_B11-T01.tiff: 21.1690
# G:\classification\cond_all\cond7_all\ds_51_B06-T01.tiff: 21.2528
# G:\classification\cond_all\cond7_all\ds_51_F02-T01.tiff: 21.3081
# G:\classification\cond_all\cond7_all\ds_51_C07-T01.tiff: 21.3289
# G:\classification\cond_all\cond7_all\ds_51_B10-T01.tiff: 21.3951
# G:\classification\cond_all\cond7_all\ds_51_F10-T01.tiff: 21.6774
# G:\classification\cond_all\cond7_all\ds_51_F04-T01.tiff: 21.8093
# G:\classification\cond_all\cond7_all\ds_51_G07-T01.tiff: 21.8296
# G:\classification\cond_all\cond7_all\ds_51_F03-T01.tiff: 21.9977
# G:\classification\cond_all\cond7_all\ds_52_D10-T01.tiff: 22.1151
# G:\classification\cond_all\cond7_all\ds_51_F07-T01.tiff: 22.4879
# G:\classification\cond_all\cond7_all\ds_51_E03-T01.tiff: 22.5249
# G:\classification\cond_all\cond7_all\ds_51_D02-T01.tiff: 22.5910
# G:\classification\cond_all\cond7_all\ds_51_F05-T01.tiff: 22.6578
# G:\classification\cond_all\cond7_all\ds_51_B09-T01.tiff: 22.7459
# G:\classification\cond_all\cond7_all\ds_51_G05-T01.tiff: 22.7684
# G:\classification\cond_all\cond7_all\ds_51_D04-T01.tiff: 22.8535
# G:\classification\cond_all\cond7_all\ds_51_G08-T01.tiff: 22.9682
# G:\classification\cond_all\cond7_all\ds_51_E04-T01.tiff: 22.9755
# G:\classification\cond_all\cond7_all\ds_51_C03-T01.tiff: 23.0323
# G:\classification\cond_all\cond7_all\ds_51_C04-T01.tiff: 23.0642
# G:\classification\cond_all\cond7_all\ds_51_G10-T01.tiff: 23.2183
# G:\classification\cond_all\cond7_all\ds_51_F11-T01.tiff: 23.5035
# G:\classification\cond_all\cond7_all\ds_51_C06-T01.tiff: 23.5158
# G:\classification\cond_all\cond7_all\ds_51_E06-T01.tiff: 23.5739
# G:\classification\cond_all\cond7_all\ds_51_F06-T01.tiff: 23.6363
# G:\classification\cond_all\cond7_all\ds_51_E08-T01.tiff: 23.6753
# G:\classification\cond_all\cond7_all\ds_52_D08-T01.tiff: 23.7267
# G:\classification\cond_all\cond7_all\ds_51_D06-T01.tiff: 23.7314
# G:\classification\cond_all\cond7_all\ds_51_D05-T01.tiff: 23.7674
# G:\classification\cond_all\cond7_all\ds_51_C10-T01.tiff: 23.7940
# G:\classification\cond_all\cond7_all\ds_51_G09-T01.tiff: 23.8337
# G:\classification\cond_all\cond7_all\ds_51_E10-T01.tiff: 23.8804
# G:\classification\cond_all\cond7_all\ds_51_C09-T01.tiff: 24.1564
# G:\classification\cond_all\cond7_all\ds_51_D10-T01.tiff: 24.2161
# G:\classification\cond_all\cond7_all\ds_51_C08-T01.tiff: 24.2275
# G:\classification\cond_all\cond7_all\ds_51_D09-T01.tiff: 24.3688
# G:\classification\cond_all\cond7_all\ds_51_C11-T01.tiff: 24.3698
# G:\classification\cond_all\cond7_all\ds_51_E11-T01.tiff: 24.3874
# G:\classification\cond_all\cond7_all\ds_51_F09-T01.tiff: 24.3925
# G:\classification\cond_all\cond7_all\ds_51_D07-T01.tiff: 24.4140
# G:\classification\cond_all\cond7_all\ds_51_E07-T01.tiff: 24.6591
# G:\classification\cond_all\cond7_all\ds_51_D08-T01.tiff: 24.7742
# G:\classification\cond_all\cond7_all\ds_51_D11-T01.tiff: 24.7746
# G:\classification\cond_all\cond7_all\ds_51_E09-T01.tiff: 25.1579
# G:\classification\cond_all\cond7_all\ds_1B_G03-T01.tiff: 25.9454
# G:\classification\cond_all\cond7_all\sd_04_C08-T01.tiff: 26.4139
# G:\classification\cond_all\cond7_all\sd_04_E09-T01.tiff: 27.0375
# G:\classification\cond_all\cond7_all\sd_04_D06-T01.tiff: 27.1775
# G:\classification\cond_all\cond7_all\sd_04_E08-T01.tiff: 27.1802
# G:\classification\cond_all\cond7_all\sd_04_B09-T01.tiff: 27.2524
# G:\classification\cond_all\cond7_all\sd_04_E07-T01.tiff: 27.3376
# G:\classification\cond_all\cond7_all\sd_04_C07-T01.tiff: 27.3418
# G:\classification\cond_all\cond7_all\sd_04_F07-T01.tiff: 27.3479
# G:\classification\cond_all\cond7_all\sd_04_F06-T01.tiff: 27.3701
# G:\classification\cond_all\cond7_all\sd_04_D08-T01.tiff: 27.6641
# G:\classification\cond_all\cond7_all\sd_04_D07-T01.tiff: 27.7520
# G:\classification\cond_all\cond7_all\sd_04_D09-T01.tiff: 27.8226
# G:\classification\cond_all\cond7_all\sd_04_F09-T01.tiff: 27.8415
# G:\classification\cond_all\cond7_all\sd_04_D05-T01.tiff: 27.8522
# G:\classification\cond_all\cond7_all\sd_04_F08-T01.tiff: 28.0986
# G:\classification\cond_all\cond7_all\sd_04_E11-T01.tiff: 28.1952
# G:\classification\cond_all\cond7_all\sd_04_F04-T01.tiff: 28.1983
# G:\classification\cond_all\cond7_all\sd_04_E10-T01.tiff: 28.2594
# G:\classification\cond_all\cond7_all\sd_04_D11-T01.tiff: 28.3349
# G:\classification\cond_all\cond7_all\sd_04_F05-T01.tiff: 28.5288
# G:\classification\cond_all\cond7_all\sd_04_E05-T01.tiff: 28.5361
# G:\classification\cond_all\cond7_all\sd_04_E06-T01.tiff: 28.6076
# G:\classification\cond_all\cond7_all\sd_04_B07-T01.tiff: 29.1397
# G:\classification\cond_all\cond7_all\sd_04_C06-T01.tiff: 29.1765
# G:\classification\cond_all\cond7_all\sd_04_C04-T01.tiff: 29.3331
# G:\classification\cond_all\cond7_all\sd_04_C11-T01.tiff: 29.5068
# G:\classification\cond_all\cond7_all\sd_04_F10-T01.tiff: 29.5712
# G:\classification\cond_all\cond7_all\sd_04_C05-T01.tiff: 30.0502
# G:\classification\cond_all\cond7_all\ds_61_D08-T01.tiff: 30.7068
# G:\classification\cond_all\cond7_all\ds_41_D11-T01.tiff: 30.8317
# G:\classification\cond_all\cond7_all\sd_04_D04-T01.tiff: 31.3987
# G:\classification\cond_all\cond7_all\sd_04_B06-T01.tiff: 31.5176
# G:\classification\cond_all\cond7_all\sd_04_C09-T01.tiff: 31.5314
# G:\classification\cond_all\cond7_all\sd_04_B05-T01.tiff: 31.6212
# G:\classification\cond_all\cond7_all\sd_04_E03-T01.tiff: 31.6532
# G:\classification\cond_all\cond7_all\sd_04_B10-T01.tiff: 31.7628
# G:\classification\cond_all\cond7_all\sd_04_B08-T01.tiff: 31.9097
# G:\classification\cond_all\cond7_all\sd_04_E04-T01.tiff: 31.9752
# G:\classification\cond_all\cond7_all\sd_04_D10-T01.tiff: 32.0783
# G:\classification\cond_all\cond7_all\sd_04_D03-T01.tiff: 32.2416
# G:\classification\cond_all\cond7_all\sd_04_B04-T01.tiff: 32.3049
# G:\classification\cond_all\cond7_all\sd_04_E02-T01.tiff: 32.5138
# G:\classification\cond_all\cond7_all\sd_04_F03-T01.tiff: 32.6860
# G:\classification\cond_all\cond7_all\sd_04_C03-T01.tiff: 32.7064
# G:\classification\cond_all\cond7_all\sd_04_B11-T01.tiff: 32.9552
# G:\classification\cond_all\cond7_all\ds_1B_D11-T01.tiff: 32.9700
# G:\classification\cond_all\cond7_all\sd_04_C10-T01.tiff: 33.2328
# G:\classification\cond_all\cond7_all\sd_04_C02-T01.tiff: 33.3550
# G:\classification\cond_all\cond7_all\sd_04_B02-T01.tiff: 33.6857
# G:\classification\cond_all\cond7_all\ds_42_E08-T01.tiff: 33.8540
# G:\classification\cond_all\cond7_all\ds_42_D09-T01.tiff: 34.6583
# G:\classification\cond_all\cond7_all\ds_42_D11-T01.tiff: 34.6597
# G:\classification\cond_all\cond7_all\ds_61_D11-T01.tiff: 34.7612
# G:\classification\cond_all\cond7_all\ds_42_F08-T01.tiff: 34.7708
# G:\classification\cond_all\cond7_all\ds_42_D10-T01.tiff: 34.8195
# G:\classification\cond_all\cond7_all\ds_1B_E09-T01.tiff: 35.5092
# G:\classification\cond_all\cond7_all\ds_42_D07-T01.tiff: 35.7500
# G:\classification\cond_all\cond7_all\ds_41_E11-T01.tiff: 35.8367
# G:\classification\cond_all\cond7_all\ds_42_F09-T01.tiff: 35.8409
# G:\classification\cond_all\cond7_all\sd_04_F02-T01.tiff: 35.8443
# G:\classification\cond_all\cond7_all\ds_41_F11-T01.tiff: 35.8955
# G:\classification\cond_all\cond7_all\ds_42_F11-T01.tiff: 36.6234
# G:\classification\cond_all\cond7_all\ds_1B_G02-T01.tiff: 36.8774
# G:\classification\cond_all\cond7_all\ds_1B_B06-T01.tiff: 37.0873
# G:\classification\cond_all\cond7_all\ds_1B_G05-T01.tiff: 37.1042
# G:\classification\cond_all\cond7_all\ds_1B_G08-T01.tiff: 37.1498
# G:\classification\cond_all\cond7_all\ds_1B_G06-T01.tiff: 37.2669
# G:\classification\cond_all\cond7_all\ds_1B_G04-T01.tiff: 37.2783
# G:\classification\cond_all\cond7_all\ds_1B_B05-T01.tiff: 37.4619
# G:\classification\cond_all\cond7_all\ds_1B_G09-T01.tiff: 37.5060
# G:\classification\cond_all\cond7_all\ds_1B_G11-T01.tiff: 37.6246
# G:\classification\cond_all\cond7_all\ds_1B_G07-T01.tiff: 37.8441
# G:\classification\cond_all\cond7_all\ds_1B_F05-T01.tiff: 37.8945
# G:\classification\cond_all\cond7_all\ds_1B_F03-T01.tiff: 37.9050
# G:\classification\cond_all\cond7_all\ds_1B_F02-T01.tiff: 37.9744
# G:\classification\cond_all\cond7_all\ds_1B_D02-T01.tiff: 38.2794
# G:\classification\cond_all\cond7_all\ds_1B_E02-T01.tiff: 38.2933
# G:\classification\cond_all\cond7_all\ds_1B_B11-T01.tiff: 38.3201
# G:\classification\cond_all\cond7_all\ds_1B_G10-T01.tiff: 38.3633
# G:\classification\cond_all\cond7_all\ds_1B_F08-T01.tiff: 38.4678
# G:\classification\cond_all\cond7_all\ds_1B_F07-T01.tiff: 38.8764
# G:\classification\cond_all\cond7_all\ds_1B_E05-T01.tiff: 38.8943
# G:\classification\cond_all\cond7_all\ds_1B_B10-T01.tiff: 38.9591
# G:\classification\cond_all\cond7_all\ds_1B_C02-T01.tiff: 39.1591
# G:\classification\cond_all\cond7_all\ds_1B_D04-T01.tiff: 39.1942
# G:\classification\cond_all\cond7_all\ds_1B_E03-T01.tiff: 39.2132
# G:\classification\cond_all\cond7_all\ds_1B_C04-T01.tiff: 39.2734
# G:\classification\cond_all\cond7_all\ds_1B_C10-T01.tiff: 39.3401
# G:\classification\cond_all\cond7_all\ds_1B_F06-T01.tiff: 39.4520
# G:\classification\cond_all\cond7_all\ds_1B_F10-T01.tiff: 39.5035
# G:\classification\cond_all\cond7_all\ds_1B_C05-T01.tiff: 39.7631
# G:\classification\cond_all\cond7_all\ds_42_E09-T01.tiff: 39.8221
# G:\classification\cond_all\cond7_all\ds_1B_F09-T01.tiff: 39.8877
# G:\classification\cond_all\cond7_all\ds_1B_D10-T01.tiff: 39.8937
# G:\classification\cond_all\cond7_all\ds_1B_E04-T01.tiff: 39.9074
# G:\classification\cond_all\cond7_all\ds_1B_D05-T01.tiff: 39.9629
# G:\classification\cond_all\cond7_all\ds_1B_F11-T01.tiff: 40.1265
# G:\classification\cond_all\cond7_all\ds_1B_C07-T01.tiff: 40.1556
# G:\classification\cond_all\cond7_all\sd_04_D02-T01.tiff: 40.2284
# G:\classification\cond_all\cond7_all\ds_1B_C09-T01.tiff: 40.2977
# G:\classification\cond_all\cond7_all\ds_1B_D09-T01.tiff: 40.3694
# G:\classification\cond_all\cond7_all\ds_1B_C11-T01.tiff: 40.4352
# G:\classification\cond_all\cond7_all\ds_1B_B08-T01.tiff: 40.5340
# G:\classification\cond_all\cond7_all\ds_42_E10-T01.tiff: 40.6191
# G:\classification\cond_all\cond7_all\ds_1B_C08-T01.tiff: 40.7942
# G:\classification\cond_all\cond7_all\ds_1B_E11-T01.tiff: 41.1025
# G:\classification\cond_all\cond7_all\ds_1B_E10-T01.tiff: 41.2539
# G:\classification\cond_all\cond7_all\ds_1B_B09-T01.tiff: 41.4010
# G:\classification\cond_all\cond7_all\ds_1B_C06-T01.tiff: 41.4197
# G:\classification\cond_all\cond7_all\ds_1B_D06-T01.tiff: 41.4356
# G:\classification\cond_all\cond7_all\ds_1B_D07-T01.tiff: 41.6702
# G:\classification\cond_all\cond7_all\ds_1B_D03-T01.tiff: 41.7331
# G:\classification\cond_all\cond7_all\ds_1B_C03-T01.tiff: 41.8109
# G:\classification\cond_all\cond7_all\ds_1B_E07-T01.tiff: 41.8345
# G:\classification\cond_all\cond7_all\ds_1B_E08-T01.tiff: 41.8448
# G:\classification\cond_all\cond7_all\ds_1B_D08-T01.tiff: 41.8754
# G:\classification\cond_all\cond7_all\ds_1B_E06-T01.tiff: 41.9055
# G:\classification\cond_all\cond7_all\ds_1B_F04-T01.tiff: 42.3772
# G:\classification\cond_all\cond7_all\ds_42_D08-T01.tiff: 42.4355

# %%
import os
import shutil

# Specify the folder where the images will be saved
output_folder = r'G:\classification\resize'

# Ensure the output folder exists
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Save images with ascending order in the filename
for idx, (path, score) in enumerate(zip(sorted_paths, sorted_scores), start=1):
    # Extract the image name and add the ascending index in front
    image_name = os.path.basename(path)  # Get the image name
    new_image_name = f"{idx:03d}_{image_name}"  # Add ascending index in front (e.g., 001, 002, 003)
    
    # Construct the full path to the output file
    output_path = os.path.join(output_folder, new_image_name)
    
    # Copy the image to the output folder with the new name
    shutil.copy(path, output_path)

    print(f"Saved {path} as {output_path}")
# Out:
# Saved G:\classification\cond_all\sd\RBT14_C08-T01.tiff as G:\classification\resize\001_RBT14_C08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_G11-T01.tiff as G:\classification\resize\002_RBT10_G11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_G07-T01.tiff as G:\classification\resize\003_RBT10_G07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_F08-T01.tiff as G:\classification\resize\004_RBT04_F08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_G10-T01.tiff as G:\classification\resize\005_RBT09_G10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_G08-T01.tiff as G:\classification\resize\006_RBT09_G08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_G10-T01.tiff as G:\classification\resize\007_RBT10_G10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_B10-T01.tiff as G:\classification\resize\008_RBT09_B10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_G07-T01.tiff as G:\classification\resize\009_RBT04_G07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_F11-T01.tiff as G:\classification\resize\010_RBT04_F11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_G10-T01.tiff as G:\classification\resize\011_RBT04_G10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_G11-T01.tiff as G:\classification\resize\012_RBT04_G11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_G11-T01.tiff as G:\classification\resize\013_RBT09_G11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_G09-T01.tiff as G:\classification\resize\014_RBT04_G09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_G09-T01.tiff as G:\classification\resize\015_RBT10_G09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_G08-T01.tiff as G:\classification\resize\016_RBT10_G08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_F11-T01.tiff as G:\classification\resize\017_RBT10_F11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_G09-T01.tiff as G:\classification\resize\018_RBT09_G09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_G07-T01.tiff as G:\classification\resize\019_RBT09_G07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_F10-T01.tiff as G:\classification\resize\020_RBT09_F10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_B11-T01.tiff as G:\classification\resize\021_RBT09_B11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_G08-T01.tiff as G:\classification\resize\022_RBT04_G08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_F09-T01.tiff as G:\classification\resize\023_RBT09_F09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_F11-T01.tiff as G:\classification\resize\024_RBT09_F11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_C09-T01.tiff as G:\classification\resize\025_RBT14_C09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_D10-T01.tiff as G:\classification\resize\026_RBT04_D10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_B09-T01.tiff as G:\classification\resize\027_RBT09_B09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_D11-T01.tiff as G:\classification\resize\028_RBT09_D11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_E11-T01.tiff as G:\classification\resize\029_RBT09_E11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_F08-T01.tiff as G:\classification\resize\030_RBT09_F08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_B07-T01.tiff as G:\classification\resize\031_RBT09_B07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_B08-T01.tiff as G:\classification\resize\032_RBT09_B08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_C10-T01.tiff as G:\classification\resize\033_RBT09_C10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_F07-T01.tiff as G:\classification\resize\034_RBT09_F07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_C11-T01.tiff as G:\classification\resize\035_RBT09_C11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_D09-T01.tiff as G:\classification\resize\036_RBT09_D09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_F09-T01.tiff as G:\classification\resize\037_RBT10_F09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_C09-T01.tiff as G:\classification\resize\038_RBT09_C09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_F09-T01.tiff as G:\classification\resize\039_RBT04_F09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_E10-T01.tiff as G:\classification\resize\040_RBT09_E10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_F07-T01.tiff as G:\classification\resize\041_RBT04_F07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_E07-T01.tiff as G:\classification\resize\042_RBT09_E07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_C07-T01.tiff as G:\classification\resize\043_RBT09_C07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_C08-T01.tiff as G:\classification\resize\044_RBT09_C08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_D08-T01.tiff as G:\classification\resize\045_RBT09_D08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_E08-T01.tiff as G:\classification\resize\046_RBT09_E08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_F10-T01.tiff as G:\classification\resize\047_RBT04_F10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_E09-T01.tiff as G:\classification\resize\048_RBT09_E09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_D07-T01.tiff as G:\classification\resize\049_RBT09_D07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_D10-T01.tiff as G:\classification\resize\050_RBT09_D10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_F07-T01.tiff as G:\classification\resize\051_RBT10_F07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_D10-T01.tiff as G:\classification\resize\052_RBT10_D10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_F08-T01.tiff as G:\classification\resize\053_RBT10_F08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_F10-T01.tiff as G:\classification\resize\054_RBT10_F10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_E11-T01.tiff as G:\classification\resize\055_RBT10_E11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_E11-T01.tiff as G:\classification\resize\056_RBT04_E11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_E10-T01.tiff as G:\classification\resize\057_RBT10_E10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_C11-T01.tiff as G:\classification\resize\058_RBT10_C11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_D11-T01.tiff as G:\classification\resize\059_RBT04_D11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_E10-T01.tiff as G:\classification\resize\060_RBT04_E10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_D09-T01.tiff as G:\classification\resize\061_RBT10_D09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_C08-T01.tiff as G:\classification\resize\062_RBT10_C08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_D07-T01.tiff as G:\classification\resize\063_RBT10_D07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_C10-T01.tiff as G:\classification\resize\064_RBT10_C10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_C09-T01.tiff as G:\classification\resize\065_RBT10_C09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_B08-T01.tiff as G:\classification\resize\066_RBT10_B08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_B07-T01.tiff as G:\classification\resize\067_RBT10_B07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_E09-T01.tiff as G:\classification\resize\068_RBT10_E09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_C07-T01.tiff as G:\classification\resize\069_RBT10_C07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_B10-T01.tiff as G:\classification\resize\070_RBT10_B10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_D11-T01.tiff as G:\classification\resize\071_RBT10_D11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_B11-T01.tiff as G:\classification\resize\072_RBT10_B11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_D08-T01.tiff as G:\classification\resize\073_RBT10_D08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_B09-T01.tiff as G:\classification\resize\074_RBT10_B09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_D08-T01.tiff as G:\classification\resize\075_RBT04_D08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_B09-T01.tiff as G:\classification\resize\076_RBT04_B09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_B10-T01.tiff as G:\classification\resize\077_RBT04_B10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_B08-T01.tiff as G:\classification\resize\078_RBT04_B08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_E09-T01.tiff as G:\classification\resize\079_RBT04_E09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_B07-T01.tiff as G:\classification\resize\080_RBT04_B07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_D09-T01.tiff as G:\classification\resize\081_RBT04_D09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_C07-T01.tiff as G:\classification\resize\082_RBT04_C07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_C08-T01.tiff as G:\classification\resize\083_RBT04_C08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_E08-T01.tiff as G:\classification\resize\084_RBT04_E08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_D08-T01.tiff as G:\classification\resize\085_RBT14_D08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_C09-T01.tiff as G:\classification\resize\086_RBT04_C09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_D07-T01.tiff as G:\classification\resize\087_RBT04_D07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_C07-T01.tiff as G:\classification\resize\088_RBT14_C07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_E07-T01.tiff as G:\classification\resize\089_RBT04_E07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_E07-T01.tiff as G:\classification\resize\090_RBT10_E07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_C10-T01.tiff as G:\classification\resize\091_RBT04_C10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_D09-T01.tiff as G:\classification\resize\092_RBT14_D09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_D07-T01.tiff as G:\classification\resize\093_RBT14_D07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_B08-T01.tiff as G:\classification\resize\094_RBT14_B08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_B07-T01.tiff as G:\classification\resize\095_RBT14_B07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_C10-T01.tiff as G:\classification\resize\096_RBT14_C10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_D10-T01.tiff as G:\classification\resize\097_RBT14_D10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_B09-T01.tiff as G:\classification\resize\098_RBT14_B09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_C11-T01.tiff as G:\classification\resize\099_RBT14_C11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_B11-T01.tiff as G:\classification\resize\100_RBT14_B11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_B11-T01.tiff as G:\classification\resize\101_RBT04_B11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_B10-T01.tiff as G:\classification\resize\102_RBT14_B10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_D11-T01.tiff as G:\classification\resize\103_RBT14_D11-T01.tiff
# Saved G:\classification\cond_all\ex\ds41_g3_C06-T01.tiff as G:\classification\resize\104_ds41_g3_C06-T01.tiff
# Saved G:\classification\cond_all\ex\ds41_g3_C03-T01.tiff as G:\classification\resize\105_ds41_g3_C03-T01.tiff
# Saved G:\classification\cond_all\ex\ds41_g3_C05-T01.tiff as G:\classification\resize\106_ds41_g3_C05-T01.tiff
# Saved G:\classification\cond_all\ex\ds41_g3_C02-T01.tiff as G:\classification\resize\107_ds41_g3_C02-T01.tiff
# Saved G:\classification\cond_all\ex\ds41_g3_C04-T01.tiff as G:\classification\resize\108_ds41_g3_C04-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g9_C09-T01.tiff as G:\classification\resize\109_ds62_g9_C09-T01.tiff
# Saved G:\classification\cond_all\ex\ds41_g9_C10-T01.tiff as G:\classification\resize\110_ds41_g9_C10-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g8_B07-T01.tiff as G:\classification\resize\111_ds62_g8_B07-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g9_C10-T01.tiff as G:\classification\resize\112_ds62_g9_C10-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g8_B11-T01.tiff as G:\classification\resize\113_ds62_g8_B11-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g8_B10-T01.tiff as G:\classification\resize\114_ds62_g8_B10-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g9_C08-T01.tiff as G:\classification\resize\115_ds62_g9_C08-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g9_C07-T01.tiff as G:\classification\resize\116_ds62_g9_C07-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g9_C11-T01.tiff as G:\classification\resize\117_ds62_g9_C11-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g8_B09-T01.tiff as G:\classification\resize\118_ds62_g8_B09-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g9_C11-T01.tiff as G:\classification\resize\119_ds61_g9_C11-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g9_C10-T01.tiff as G:\classification\resize\120_ds61_g9_C10-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g8_B10-T01.tiff as G:\classification\resize\121_ds61_g8_B10-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g9_C09-T01.tiff as G:\classification\resize\122_ds61_g9_C09-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g8_B09-T01.tiff as G:\classification\resize\123_ds61_g8_B09-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g8_B11-T01.tiff as G:\classification\resize\124_ds61_g8_B11-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g9_C08-T01.tiff as G:\classification\resize\125_ds61_g9_C08-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g8_B07-T01.tiff as G:\classification\resize\126_ds61_g8_B07-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g6_F05-T01.tiff as G:\classification\resize\127_ds61_g6_F05-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g3_C05-T01.tiff as G:\classification\resize\128_ds61_g3_C05-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g3_C06-T01.tiff as G:\classification\resize\129_ds61_g3_C06-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g3_C03-T01.tiff as G:\classification\resize\130_ds61_g3_C03-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g6_F02-T01.tiff as G:\classification\resize\131_ds61_g6_F02-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g3_C04-T01.tiff as G:\classification\resize\132_ds61_g3_C04-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g3_C02-T01.tiff as G:\classification\resize\133_ds61_g3_C02-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g6_F03-T01.tiff as G:\classification\resize\134_ds61_g6_F03-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g6_F04-T01.tiff as G:\classification\resize\135_ds61_g6_F04-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g9_C07-T01.tiff as G:\classification\resize\136_ds61_g9_C07-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g8_B08-T01.tiff as G:\classification\resize\137_ds61_g8_B08-T01.tiff
# Saved G:\classification\cond_all\ex\ds1B_g9_C9.tif as G:\classification\resize\138_ds1B_g9_C9.tif
# Saved G:\classification\cond_all\ex\ds61_g6_F06-T01.tiff as G:\classification\resize\139_ds61_g6_F06-T01.tiff
# Saved G:\classification\cond_all\ex\ds1B_g9_c10.tif as G:\classification\resize\140_ds1B_g9_c10.tif
# Saved G:\classification\cond_all\ex\ds1B_g9_C11.tif as G:\classification\resize\141_ds1B_g9_C11.tif
# Saved G:\classification\cond_all\ex\ds1B_g9_C7.tif as G:\classification\resize\142_ds1B_g9_C7.tif
# Saved G:\classification\cond_all\ex\ds1B_g9_C8.tif as G:\classification\resize\143_ds1B_g9_C8.tif
# Saved G:\classification\cond_all\cond7_all\ds_52_G06-T01.tiff as G:\classification\resize\144_ds_52_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B11-T01.tiff as G:\classification\resize\145_ds_62_B11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E02-T01.tiff as G:\classification\resize\146_ds_61_E02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B10-T01.tiff as G:\classification\resize\147_ds_62_B10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B04-T01.tiff as G:\classification\resize\148_ds_62_B04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B05-T01.tiff as G:\classification\resize\149_ds_62_B05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G05-T01.tiff as G:\classification\resize\150_ds_62_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G03-T01.tiff as G:\classification\resize\151_ds_62_G03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C10-T01.tiff as G:\classification\resize\152_ds_62_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B03-T01.tiff as G:\classification\resize\153_ds_61_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B08-T01.tiff as G:\classification\resize\154_ds_62_B08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C11-T01.tiff as G:\classification\resize\155_ds_61_C11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G06-T01.tiff as G:\classification\resize\156_ds_61_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D04-T01.tiff as G:\classification\resize\157_ds_62_D04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G09-T01.tiff as G:\classification\resize\158_ds_61_G09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G09-T01.tiff as G:\classification\resize\159_ds_62_G09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G07-T01.tiff as G:\classification\resize\160_ds_62_G07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G08-T01.tiff as G:\classification\resize\161_ds_61_G08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E08-T01.tiff as G:\classification\resize\162_ds_62_E08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E05-T01.tiff as G:\classification\resize\163_ds_61_E05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F10-T01.tiff as G:\classification\resize\164_ds_62_F10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G10-T01.tiff as G:\classification\resize\165_ds_62_G10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C02-T01.tiff as G:\classification\resize\166_ds_61_C02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C04-T01.tiff as G:\classification\resize\167_ds_61_C04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D02-T01.tiff as G:\classification\resize\168_ds_61_D02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F10-T01.tiff as G:\classification\resize\169_ds_61_F10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E06-T01.tiff as G:\classification\resize\170_ds_61_E06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F11-T01.tiff as G:\classification\resize\171_ds_62_F11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B10-T01.tiff as G:\classification\resize\172_ds_61_B10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C11-T01.tiff as G:\classification\resize\173_ds_62_C11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F08-T01.tiff as G:\classification\resize\174_ds_62_F08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E09-T01.tiff as G:\classification\resize\175_ds_62_E09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E03-T01.tiff as G:\classification\resize\176_ds_61_E03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G10-T01.tiff as G:\classification\resize\177_ds_61_G10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D06-T01.tiff as G:\classification\resize\178_ds_61_D06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C05-T01.tiff as G:\classification\resize\179_ds_61_C05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C05-T01.tiff as G:\classification\resize\180_ds_62_C05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F09-T01.tiff as G:\classification\resize\181_ds_62_F09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F07-T01.tiff as G:\classification\resize\182_ds_62_F07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E07-T01.tiff as G:\classification\resize\183_ds_62_E07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B06-T01.tiff as G:\classification\resize\184_ds_62_B06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E03-T01.tiff as G:\classification\resize\185_ds_62_E03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C03-T01.tiff as G:\classification\resize\186_ds_62_C03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E04-T01.tiff as G:\classification\resize\187_ds_62_E04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F06-T01.tiff as G:\classification\resize\188_ds_62_F06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B03-T01.tiff as G:\classification\resize\189_ds_62_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D02-T01.tiff as G:\classification\resize\190_ds_62_D02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E05-T01.tiff as G:\classification\resize\191_ds_62_E05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F04-T01.tiff as G:\classification\resize\192_ds_62_F04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G03-T01.tiff as G:\classification\resize\193_ds_61_G03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C07-T01.tiff as G:\classification\resize\194_ds_62_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C03-T01.tiff as G:\classification\resize\195_ds_61_C03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F02-T01.tiff as G:\classification\resize\196_ds_62_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G04-T01.tiff as G:\classification\resize\197_ds_62_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G02-T01.tiff as G:\classification\resize\198_ds_62_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E02-T01.tiff as G:\classification\resize\199_ds_62_E02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G11-T01.tiff as G:\classification\resize\200_ds_62_G11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G06-T01.tiff as G:\classification\resize\201_ds_62_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G05-T01.tiff as G:\classification\resize\202_ds_61_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G08-T01.tiff as G:\classification\resize\203_ds_62_G08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E08-T01.tiff as G:\classification\resize\204_ds_52_E08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C09-T01.tiff as G:\classification\resize\205_ds_52_C09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B09-T01.tiff as G:\classification\resize\206_ds_62_B09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C09-T01.tiff as G:\classification\resize\207_ds_62_C09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E11-T01.tiff as G:\classification\resize\208_ds_62_E11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F06-T01.tiff as G:\classification\resize\209_ds_61_F06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B05-T01.tiff as G:\classification\resize\210_ds_61_B05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E04-T01.tiff as G:\classification\resize\211_ds_61_E04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E11-T01.tiff as G:\classification\resize\212_ds_61_E11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D11-T01.tiff as G:\classification\resize\213_ds_62_D11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E10-T01.tiff as G:\classification\resize\214_ds_61_E10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D05-T01.tiff as G:\classification\resize\215_ds_61_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F05-T01.tiff as G:\classification\resize\216_ds_61_F05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C07-T01.tiff as G:\classification\resize\217_ds_61_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F11-T01.tiff as G:\classification\resize\218_ds_61_F11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F09-T01.tiff as G:\classification\resize\219_ds_61_F09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D10-T01.tiff as G:\classification\resize\220_ds_62_D10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C06-T01.tiff as G:\classification\resize\221_ds_52_C06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E07-T01.tiff as G:\classification\resize\222_ds_61_E07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C08-T01.tiff as G:\classification\resize\223_ds_61_C08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F05-T01.tiff as G:\classification\resize\224_ds_52_F05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G09-T01.tiff as G:\classification\resize\225_ds_52_G09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G07-T01.tiff as G:\classification\resize\226_ds_52_G07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F09-T01.tiff as G:\classification\resize\227_ds_41_F09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C07-T01.tiff as G:\classification\resize\228_ds_41_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B07-T01.tiff as G:\classification\resize\229_ds_52_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G03-T01.tiff as G:\classification\resize\230_ds_51_G03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_E06-T01.tiff as G:\classification\resize\231_ds_41_E06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C07-T01.tiff as G:\classification\resize\232_ds_52_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C09-T01.tiff as G:\classification\resize\233_ds_41_C09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_E09-T01.tiff as G:\classification\resize\234_ds_41_E09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B08-T01.tiff as G:\classification\resize\235_ds_41_B08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_E04-T01.tiff as G:\classification\resize\236_ds_41_E04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F06-T01.tiff as G:\classification\resize\237_ds_41_F06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F06-T01.tiff as G:\classification\resize\238_ds_52_F06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D06-T01.tiff as G:\classification\resize\239_ds_41_D06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C04-T01.tiff as G:\classification\resize\240_ds_52_C04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C03-T01.tiff as G:\classification\resize\241_ds_52_C03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F08-T01.tiff as G:\classification\resize\242_ds_41_F08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F04-T01.tiff as G:\classification\resize\243_ds_52_F04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G06-T01.tiff as G:\classification\resize\244_ds_41_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G08-T01.tiff as G:\classification\resize\245_ds_52_G08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F03-T01.tiff as G:\classification\resize\246_ds_41_F03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B02-T01.tiff as G:\classification\resize\247_ds_52_B02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G05-T01.tiff as G:\classification\resize\248_ds_52_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G08-T01.tiff as G:\classification\resize\249_ds_41_G08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_E06-T01.tiff as G:\classification\resize\250_ds_42_E06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G05-T01.tiff as G:\classification\resize\251_ds_41_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G06-T01.tiff as G:\classification\resize\252_ds_42_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_E05-T01.tiff as G:\classification\resize\253_ds_41_E05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G04-T01.tiff as G:\classification\resize\254_ds_41_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B09-T01.tiff as G:\classification\resize\255_ds_41_B09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E02-T01.tiff as G:\classification\resize\256_ds_52_E02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G11-T01.tiff as G:\classification\resize\257_ds_52_G11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B11-T01.tiff as G:\classification\resize\258_ds_52_B11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F02-T01.tiff as G:\classification\resize\259_ds_52_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D08-T01.tiff as G:\classification\resize\260_ds_62_D08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B07-T01.tiff as G:\classification\resize\261_ds_62_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C02-T01.tiff as G:\classification\resize\262_ds_62_C02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F05-T01.tiff as G:\classification\resize\263_ds_62_F05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B09-T01.tiff as G:\classification\resize\264_ds_52_B09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D06-T01.tiff as G:\classification\resize\265_ds_62_D06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B03-T01.tiff as G:\classification\resize\266_ds_52_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F07-T01.tiff as G:\classification\resize\267_ds_61_F07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E03-T01.tiff as G:\classification\resize\268_ds_52_E03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D07-T01.tiff as G:\classification\resize\269_ds_62_D07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G09-T01.tiff as G:\classification\resize\270_ds_41_G09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C06-T01.tiff as G:\classification\resize\271_ds_62_C06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B06-T01.tiff as G:\classification\resize\272_ds_52_B06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E05-T01.tiff as G:\classification\resize\273_ds_52_E05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G04-T01.tiff as G:\classification\resize\274_ds_52_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D09-T01.tiff as G:\classification\resize\275_ds_62_D09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C02-T01.tiff as G:\classification\resize\276_ds_52_C02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C05-T01.tiff as G:\classification\resize\277_ds_52_C05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F08-T01.tiff as G:\classification\resize\278_ds_61_F08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B08-T01.tiff as G:\classification\resize\279_ds_52_B08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D05-T01.tiff as G:\classification\resize\280_ds_62_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F03-T01.tiff as G:\classification\resize\281_ds_52_F03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F04-T01.tiff as G:\classification\resize\282_ds_41_F04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F02-T01.tiff as G:\classification\resize\283_ds_41_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F05-T01.tiff as G:\classification\resize\284_ds_41_F05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D06-T01.tiff as G:\classification\resize\285_ds_52_D06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E04-T01.tiff as G:\classification\resize\286_ds_52_E04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B06-T01.tiff as G:\classification\resize\287_ds_41_B06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D07-T01.tiff as G:\classification\resize\288_ds_41_D07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D05-T01.tiff as G:\classification\resize\289_ds_41_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G07-T01.tiff as G:\classification\resize\290_ds_41_G07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B05-T01.tiff as G:\classification\resize\291_ds_41_B05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_E02-T01.tiff as G:\classification\resize\292_ds_41_E02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B06-T01.tiff as G:\classification\resize\293_ds_61_B06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C06-T01.tiff as G:\classification\resize\294_ds_41_C06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_E03-T01.tiff as G:\classification\resize\295_ds_41_E03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B07-T01.tiff as G:\classification\resize\296_ds_61_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D05-T01.tiff as G:\classification\resize\297_ds_52_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C04-T01.tiff as G:\classification\resize\298_ds_41_C04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E10-T01.tiff as G:\classification\resize\299_ds_62_E10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E06-T01.tiff as G:\classification\resize\300_ds_52_E06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C08-T01.tiff as G:\classification\resize\301_ds_41_C08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D03-T01.tiff as G:\classification\resize\302_ds_52_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D04-T01.tiff as G:\classification\resize\303_ds_41_D04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C03-T01.tiff as G:\classification\resize\304_ds_41_C03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D03-T01.tiff as G:\classification\resize\305_ds_41_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C10-T01.tiff as G:\classification\resize\306_ds_52_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C09-T01.tiff as G:\classification\resize\307_ds_61_C09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E08-T01.tiff as G:\classification\resize\308_ds_61_E08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D02-T01.tiff as G:\classification\resize\309_ds_52_D02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C05-T01.tiff as G:\classification\resize\310_ds_41_C05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D04-T01.tiff as G:\classification\resize\311_ds_52_D04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B10-T01.tiff as G:\classification\resize\312_ds_52_B10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_E10-T01.tiff as G:\classification\resize\313_ds_41_E10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F10-T01.tiff as G:\classification\resize\314_ds_41_F10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F07-T01.tiff as G:\classification\resize\315_ds_52_F07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C08-T01.tiff as G:\classification\resize\316_ds_52_C08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D08-T01.tiff as G:\classification\resize\317_ds_41_D08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D09-T01.tiff as G:\classification\resize\318_ds_61_D09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F08-T01.tiff as G:\classification\resize\319_ds_52_F08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F11-T01.tiff as G:\classification\resize\320_ds_52_F11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F10-T01.tiff as G:\classification\resize\321_ds_52_F10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D09-T01.tiff as G:\classification\resize\322_ds_52_D09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E07-T01.tiff as G:\classification\resize\323_ds_52_E07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_E08-T01.tiff as G:\classification\resize\324_ds_41_E08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E09-T01.tiff as G:\classification\resize\325_ds_52_E09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F09-T01.tiff as G:\classification\resize\326_ds_52_F09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D07-T01.tiff as G:\classification\resize\327_ds_52_D07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G04-T01.tiff as G:\classification\resize\328_ds_51_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G10-T01.tiff as G:\classification\resize\329_ds_52_G10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G06-T01.tiff as G:\classification\resize\330_ds_51_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C10-T01.tiff as G:\classification\resize\331_ds_41_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D10-T01.tiff as G:\classification\resize\332_ds_41_D10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_G02-T01.tiff as G:\classification\resize\333_sd_04_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_G03-T01.tiff as G:\classification\resize\334_sd_04_G03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G07-T01.tiff as G:\classification\resize\335_ds_42_G07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G10-T01.tiff as G:\classification\resize\336_ds_41_G10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G08-T01.tiff as G:\classification\resize\337_ds_42_G08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D03-T01.tiff as G:\classification\resize\338_ds_61_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G11-T01.tiff as G:\classification\resize\339_ds_41_G11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C11-T01.tiff as G:\classification\resize\340_ds_41_C11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D07-T01.tiff as G:\classification\resize\341_ds_61_D07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D10-T01.tiff as G:\classification\resize\342_ds_61_D10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G07-T01.tiff as G:\classification\resize\343_ds_61_G07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C10-T01.tiff as G:\classification\resize\344_ds_61_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G10-T01.tiff as G:\classification\resize\345_ds_42_G10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G11-T01.tiff as G:\classification\resize\346_ds_42_G11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G04-T01.tiff as G:\classification\resize\347_ds_61_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G11-T01.tiff as G:\classification\resize\348_ds_61_G11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B09-T01.tiff as G:\classification\resize\349_ds_61_B09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B05-T01.tiff as G:\classification\resize\350_ds_52_B05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D04-T01.tiff as G:\classification\resize\351_ds_61_D04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B02-T01.tiff as G:\classification\resize\352_ds_61_B02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B11-T01.tiff as G:\classification\resize\353_ds_61_B11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C08-T01.tiff as G:\classification\resize\354_ds_62_C08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C04-T01.tiff as G:\classification\resize\355_ds_62_C04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D03-T01.tiff as G:\classification\resize\356_ds_62_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G02-T01.tiff as G:\classification\resize\357_ds_61_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F04-T01.tiff as G:\classification\resize\358_ds_61_F04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E06-T01.tiff as G:\classification\resize\359_ds_62_E06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B02-T01.tiff as G:\classification\resize\360_ds_62_B02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B04-T01.tiff as G:\classification\resize\361_ds_52_B04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C06-T01.tiff as G:\classification\resize\362_ds_61_C06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G03-T01.tiff as G:\classification\resize\363_ds_52_G03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F02-T01.tiff as G:\classification\resize\364_ds_61_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G09-T01.tiff as G:\classification\resize\365_ds_42_G09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E11-T01.tiff as G:\classification\resize\366_ds_52_E11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G02-T01.tiff as G:\classification\resize\367_ds_52_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B07-T01.tiff as G:\classification\resize\368_ds_41_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B11-T01.tiff as G:\classification\resize\369_ds_41_B11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_F10-T01.tiff as G:\classification\resize\370_ds_42_F10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B04-T01.tiff as G:\classification\resize\371_ds_41_B04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D02-T01.tiff as G:\classification\resize\372_ds_41_D02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C02-T01.tiff as G:\classification\resize\373_ds_41_C02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B03-T01.tiff as G:\classification\resize\374_ds_41_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_B03-T01.tiff as G:\classification\resize\375_sd_04_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B10-T01.tiff as G:\classification\resize\376_ds_42_B10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C06-T01.tiff as G:\classification\resize\377_ds_42_C06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C04-T01.tiff as G:\classification\resize\378_ds_42_C04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_D06-T01.tiff as G:\classification\resize\379_ds_42_D06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B06-T01.tiff as G:\classification\resize\380_ds_42_B06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_D05-T01.tiff as G:\classification\resize\381_ds_42_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_F03-T01.tiff as G:\classification\resize\382_ds_42_F03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G02-T01.tiff as G:\classification\resize\383_ds_41_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B03-T01.tiff as G:\classification\resize\384_ds_42_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_D04-T01.tiff as G:\classification\resize\385_ds_42_D04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_E04-T01.tiff as G:\classification\resize\386_ds_42_E04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_F06-T01.tiff as G:\classification\resize\387_ds_42_F06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B09-T01.tiff as G:\classification\resize\388_ds_42_B09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_F02-T01.tiff as G:\classification\resize\389_ds_42_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_D02-T01.tiff as G:\classification\resize\390_ds_42_D02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C03-T01.tiff as G:\classification\resize\391_ds_42_C03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_F04-T01.tiff as G:\classification\resize\392_ds_42_F04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C05-T01.tiff as G:\classification\resize\393_ds_42_C05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_E03-T01.tiff as G:\classification\resize\394_ds_42_E03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G04-T01.tiff as G:\classification\resize\395_ds_42_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G05-T01.tiff as G:\classification\resize\396_ds_42_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_E05-T01.tiff as G:\classification\resize\397_ds_42_E05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C11-T01.tiff as G:\classification\resize\398_ds_42_C11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B11-T01.tiff as G:\classification\resize\399_ds_42_B11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B02-T01.tiff as G:\classification\resize\400_ds_1B_B02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F03-T01.tiff as G:\classification\resize\401_ds_61_F03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C10-T01.tiff as G:\classification\resize\402_ds_42_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C09-T01.tiff as G:\classification\resize\403_ds_42_C09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_D03-T01.tiff as G:\classification\resize\404_ds_42_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C08-T01.tiff as G:\classification\resize\405_ds_42_C08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B07-T01.tiff as G:\classification\resize\406_ds_1B_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B05-T01.tiff as G:\classification\resize\407_ds_42_B05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B03-T01.tiff as G:\classification\resize\408_ds_1B_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_E02-T01.tiff as G:\classification\resize\409_ds_42_E02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B08-T01.tiff as G:\classification\resize\410_ds_42_B08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B10-T01.tiff as G:\classification\resize\411_ds_41_B10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B07-T01.tiff as G:\classification\resize\412_ds_42_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C07-T01.tiff as G:\classification\resize\413_ds_42_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C02-T01.tiff as G:\classification\resize\414_ds_42_C02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_F05-T01.tiff as G:\classification\resize\415_ds_42_F05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B04-T01.tiff as G:\classification\resize\416_ds_42_B04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G02-T01.tiff as G:\classification\resize\417_ds_42_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B02-T01.tiff as G:\classification\resize\418_ds_42_B02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B04-T01.tiff as G:\classification\resize\419_ds_1B_B04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_E11-T01.tiff as G:\classification\resize\420_ds_42_E11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E09-T01.tiff as G:\classification\resize\421_ds_61_E09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_E07-T01.tiff as G:\classification\resize\422_ds_41_E07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_F07-T01.tiff as G:\classification\resize\423_ds_42_F07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_E07-T01.tiff as G:\classification\resize\424_ds_42_E07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D09-T01.tiff as G:\classification\resize\425_ds_41_D09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_G04-T01.tiff as G:\classification\resize\426_sd_04_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F07-T01.tiff as G:\classification\resize\427_ds_41_F07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_F11-T01.tiff as G:\classification\resize\428_sd_04_F11-T01.tiff
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 21
#      18 output_path = os.path.join(output_folder, new_image_name)
#      20 # Copy the image to the output folder with the new name
# ---> 21 shutil.copy(path, output_path)
#      23 print(f"Saved {path} as {output_path}")
#
# File c:\Users\k54739\.conda\envs\master\Lib\shutil.py:435, in copy(src, dst, follow_symlinks)
#     433 if os.path.isdir(dst):
#     434     dst = os.path.join(dst, os.path.basename(src))
# --> 435 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436 copymode(src, dst, follow_symlinks=follow_symlinks)
#     437 return dst
#
# File c:\Users\k54739\.conda\envs\master\Lib\shutil.py:280, in copyfile(src, dst, follow_symlinks)
#     277 # Windows, see:
#     278 # https://github.com/python/cpython/pull/7160#discussion_r195405230
#     279 elif _WINDOWS and file_size > 0:
# --> 280     _copyfileobj_readinto(fsrc, fdst, min(file_size, COPY_BUFSIZE))
#     281     return dst
#     283 copyfileobj(fsrc, fdst)
#
# File c:\Users\k54739\.conda\envs\master\Lib\shutil.py:194, in _copyfileobj_readinto(fsrc, fdst, length)
#     192     break
#     193 else:
# --> 194     fdst_write(mv)
#
# KeyboardInterrupt:

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %% [markdown]
# import torch
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import StandardScaler
#
# # Convert PyTorch tensors to NumPy arrays
# feats_np = feats.numpy()
# labels_np = labels.numpy()
#
# # Standardize features before PCA
# scaler = StandardScaler()
# feats_scaled = scaler.fit_transform(feats_np)
#
# # Apply PCA
# pca = PCA(n_components=2)
# feats_pca = pca.fit_transform(feats_scaled)
#
# # Plot PCA results
# plt.figure(figsize=(8, 6))
# scatter = plt.scatter(feats_pca[:, 0], feats_pca[:, 1], c=labels_np, cmap='viridis', alpha=0.7)
# plt.colorbar(scatter, label='Class Labels')
# plt.xlabel('PCA Component 1')
# plt.ylabel('PCA Component 2')
# plt.title('PCA Visualization of SimCLR Features')
# plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Convert PyTorch tensors to NumPy arrays
feats_np = feats.numpy()
labels_np = labels.numpy()

# Standardize features before PCA
scaler = StandardScaler()
feats_scaled = scaler.fit_transform(feats_np)

# Apply PCA
pca = PCA(n_components=2)
feats_pca = pca.fit_transform(feats_scaled)

# Plot PCA results
plt.figure(figsize=(8, 6))
scatter = plt.scatter(feats_pca[:, 0], feats_pca[:, 1], c=labels_np, cmap='viridis', alpha=0.7)
plt.colorbar(scatter, label='Class Labels')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA Visualization of SimCLR Features')

# Create legend
unique_labels = np.unique(labels_np)
colors = [scatter.cmap(scatter.norm(label)) for label in unique_labels]
legend_labels = [f'Class {label}' for label in unique_labels]
plt.legend(handles=[plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) for color in colors], labels=legend_labels, title='Classes')

plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Convert PyTorch tensors to NumPy arrays and prepare data
feats_np = feats.numpy()
scaler = StandardScaler()
feats_scaled = scaler.fit_transform(feats_np)

# Apply PCA
pca = PCA()
pca.fit(feats_scaled)

# Get first 10 components of explained variance ratio
explained_var_ratio = pca.explained_variance_ratio_[:10]

# Create the bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(range(1, 11), explained_var_ratio, alpha=0.8, color='blue')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot (First 10 Principal Components)')
plt.grid(True, alpha=0.3)

# Add percentage labels on top of each bar
for i, v in enumerate(explained_var_ratio):
    plt.text(i + 1, v, f'{v*100:.1f}%', ha='center', va='bottom')

# Print cumulative explained variance
cumulative_var = np.cumsum(explained_var_ratio)
print("\nCumulative Explained Variance:")
for i, cum_var in enumerate(cumulative_var, 1):
    print(f"PC1 to PC{i}: {cum_var*100:.1f}%")

plt.tight_layout()
plt.show()
# Out:
# Cumulative Explained Variance:
# PC1 to PC1: 24.2%
# PC1 to PC2: 39.2%
# PC1 to PC3: 47.2%
# PC1 to PC4: 53.7%
# PC1 to PC5: 58.6%
# PC1 to PC6: 62.3%
# PC1 to PC7: 65.8%
# PC1 to PC8: 68.0%
# PC1 to PC9: 69.9%
# PC1 to PC10: 71.4%

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Convert PyTorch tensors to NumPy arrays
feats_np = feats.numpy()
labels_np = labels.numpy()

# Standardize features before PCA
scaler = StandardScaler()
feats_scaled = scaler.fit_transform(feats_np)

# Apply PCA with 1 component
pca = PCA(n_components=1)
feats_pca = pca.fit_transform(feats_scaled)

# Plot PCA results
plt.figure(figsize=(8, 6))
# Since we have 1D data, we'll use the PCA component for x-axis and create artificial y-coordinates
scatter = plt.scatter(feats_pca, np.zeros_like(feats_pca), c=labels_np, cmap='viridis', alpha=0.7)
plt.colorbar(scatter, label='Class Labels')
plt.xlabel('PCA Component 1')
plt.ylabel('')  # No y-axis label needed
plt.title('1D PCA Visualization of SimCLR Features')

# Create legend
unique_labels = np.unique(labels_np)
colors = [scatter.cmap(scatter.norm(label)) for label in unique_labels]
legend_labels = [f'Class {label}' for label in unique_labels]
plt.legend(handles=[plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) for color in colors], labels=legend_labels, title='Classes')

# Remove y-axis ticks since they're not meaningful
plt.yticks([])

plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Convert PyTorch tensors to NumPy arrays
feats_np = feats.numpy()
labels_np = labels.numpy()

# Standardize features before PCA
scaler = StandardScaler()
feats_scaled = scaler.fit_transform(feats_np)

# Apply PCA with 1 component
pca = PCA(n_components=1)
feats_pca = pca.fit_transform(feats_scaled)

# Get unique class labels and assign y-values accordingly
unique_labels = np.unique(labels_np)
class_y_positions = {label: i for i, label in enumerate(unique_labels)}

# Map labels to their respective y positions
y_positions = np.array([class_y_positions[label] for label in labels_np])

# Plot PCA results
plt.figure(figsize=(10, 6))
scatter = plt.scatter(feats_pca, y_positions, c=labels_np, cmap='viridis', alpha=0.7)

# Add colorbar and labels
plt.colorbar(scatter, label='Class Labels')
plt.xlabel('PCA Component 1')
plt.ylabel('Class')
plt.title('1D PCA Visualization of SimCLR Features')

# Set y-ticks to represent class labels
plt.yticks(range(len(unique_labels)), [f'Class {label}' for label in unique_labels])

plt.show()

# %% [markdown]
# import torch
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import StandardScaler, normalize
#
# # Convert PyTorch tensors to NumPy arrays
# feats_np = feats.numpy()
# labels_np = labels.numpy()
#
# # Normalize features
# feats_np_norm = normalize(feats_np, axis=1)
#
# # Standardize features before PCA
# scaler = StandardScaler()
# feats_scaled = scaler.fit_transform(feats_np_norm)
#
# # Apply PCA
# pca = PCA(n_components=2)
# feats_pca = pca.fit_transform(feats_scaled)
#
# # Plot PCA results
# plt.figure(figsize=(8, 6))
# scatter = plt.scatter(feats_pca[:, 0], feats_pca[:, 1], c=labels_np, cmap='viridis', alpha=0.7)
# plt.colorbar(scatter, label='Class Labels')
# plt.xlabel('PCA Component 1')
# plt.ylabel('PCA Component 2')
# plt.title('PCA Visualization of SimCLR Features')
#
# # Create legend
# unique_labels = np.unique(labels_np)
# colors = [scatter.cmap(scatter.norm(label)) for label in unique_labels]
# legend_labels = [f'Class {label}' for label in unique_labels]
# plt.legend(handles=[plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) for color in colors], labels=legend_labels, title='Classes')
#
# plt.show()

# %%
type(feats)
# Out:
# torch.Tensor

# %% [markdown]
# # Extract features for train and test datasets
# feats_simclr = prepare_data_features(simclr_model, loader_labeled)

# %%
"""# Convert features and labels to NumPy arrays
feats_np = feats_simclr.tensors[0].numpy()  # Features in shape (60, 512)

labels_np = feats_simclr.tensors[1].numpy()  # Corresponding labels"""

feats_np = feats.numpy()
labels_np = labels.numpy()

# Check the shapes
print("Shape of features (for K-Means):", feats_np.shape)
print("Shape of labels:", labels_np.shape)
# Out:
# Shape of features (for K-Means): (120, 512)
# Shape of labels: (120,)

# %%
from sklearn.preprocessing import normalize

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Function to reduce to 2D using PCA
def reduce_to_2D_pca(X, centroids):
    pca = PCA(n_components=2)
    X_2D = pca.fit_transform(X)  # Reducing original data points
    centroids_2D = pca.transform(centroids)  # Reducing centroids

    return X_2D, centroids_2D

# Function to plot 2D clusters with centroids and true labels
def plot_2D_clusters_with_labels(X_2D, centroids_2D, idx, labels, K):
    plt.figure(figsize=(8, 6))
    
    # Define color map for clusters
    colors = plt.cm.rainbow(np.linspace(0, 1, K))
    
    # Plot data points colored by their cluster assignment
    for k in range(K):
        cluster_points = X_2D[idx == k]
        cluster_labels = labels[idx == k]  # Get true labels for the current cluster
        
        # Scatter plot for each cluster
        plt.scatter(cluster_points[:, 0], cluster_points[:, 1], 
                    c=[colors[k]], label=f"Cluster {k+1}", alpha=0.6, s=20)
        
        # Annotate each point with its true label
        for i in range(len(cluster_points)):
            plt.annotate(str(cluster_labels[i]), 
                         (cluster_points[i, 0], cluster_points[i, 1]), 
                         fontsize=8, alpha=0.75)

    # Plot centroids as larger markers
    for k in range(K):
        plt.scatter(centroids_2D[k, 0], centroids_2D[k, 1], 
                    c='k', marker='x', s=200, label=f'Centroid {k+1}' if k == 0 else "")

    plt.title("2D Visualization of Clusters using PCA with True Labels")
    plt.xlabel("Principal Component 1")
    plt.ylabel("Principal Component 2")
    plt.legend()
    plt.grid()
    plt.show()

# Apply PCA after K-Means clustering for 2D visualization
X_2D_pca, centroids_2D_pca = reduce_to_2D_pca(feats_np_norm, best_centroids)

# Plot the 2D clusters with centroids and true labels
plot_2D_clusters_with_labels(X_2D_pca, centroids_2D_pca, best_idx, labels_np, K)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Function to reduce to 2D using PCA and return explained variance
def reduce_to_2D_pca(X, centroids):
    pca = PCA(n_components=2)
    X_2D = pca.fit_transform(X)  # Reducing original data points
    centroids_2D = pca.transform(centroids)  # Reducing centroids
    explained_variance = pca.explained_variance_ratio_  # Explained variance for the first two PCs

    return X_2D, centroids_2D, explained_variance

# Function to plot PCA scree plot
def plot_pca_scree(explained_variance):
    plt.figure(figsize=(6, 4))
    plt.bar(["PC1", "PC2"], explained_variance * 100, color=['blue', 'orange'])
    plt.ylabel("Explained Variance (%)")
    plt.title("PCA Scree Plot: Variance Explained by Principal Components")
    plt.ylim(0, 100)  # Limit to 100% for better visualization
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# Apply PCA after K-Means clustering for 2D visualization
X_2D_pca, centroids_2D_pca, explained_variance_pca = reduce_to_2D_pca(feats_np_norm, best_centroids)

# Plot the 2D clusters with centroids and true labels
plot_2D_clusters_with_labels(X_2D_pca, centroids_2D_pca, best_idx, labels_np, K)

# Plot PCA Scree Plot
plot_pca_scree(explained_variance_pca)

# %%
print(f"Explained Variance Ratio - PC1: {explained_variance_pca[0]:.4f}, PC2: {explained_variance_pca[1]:.4f}")
# Out:
# Explained Variance Ratio - PC1: 0.2860, PC2: 0.2309

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Function to reduce the dimensionality of data points and centroids to 1D using PCA
def reduce_to_1D_pca(X, centroids):
    # Initialize PCA with 1 component
    pca = PCA(n_components=1)
    
    # Apply PCA to the data points (X) and centroids
    X_1D = pca.fit_transform(X)  # Reducing original data points
    centroids_1D = pca.transform(centroids)  # Reducing centroids

    return X_1D, centroids_1D

# Function to plot 1D visualization of clustered data points and centroids with true labels
def plot_1D_clusters_with_labels(X_1D, centroids_1D, idx, labels, K):
    plt.figure(figsize=(10, 5))
    
    # Define color map for clusters
    colors = plt.cm.rainbow(np.linspace(0, 1, K))
    
    # Plot data points colored by their cluster assignment
    for k in range(K):
        cluster_points = X_1D[idx == k]
        cluster_labels = labels[idx == k]  # Get true labels for the current cluster
        
        # Scatter plot for each cluster
        plt.scatter(cluster_points, [k] * len(cluster_points), 
                    c=[colors[k]], label=f"Cluster {k+1}", alpha=0.6, s=20)
        
        # Annotate each point with its true label
        for i in range(len(cluster_points)):
            plt.annotate(str(cluster_labels[i]), 
                         (cluster_points[i], k), 
                         fontsize=8, alpha=0.75)

    # Plot centroids as larger markers
    for k in range(K):
        plt.scatter(centroids_1D[k], k, 
                    c='k', marker='x', s=200, label=f'Centroid {k+1}' if k == 0 else "")

    plt.title("1D Visualization of Clusters using PCA with True Labels")
    plt.xlabel("Principal Component 1")
    plt.ylabel("Cluster Index")
    plt.legend()
    plt.grid()
    plt.show()

# Apply PCA after K-Means clustering for 1D visualization
X_1D_pca, centroids_1D_pca = reduce_to_1D_pca(feats_np_norm, best_centroids)

# Plot the 1D clusters with centroids and true labels
plot_1D_clusters_with_labels(X_1D_pca, centroids_1D_pca, best_idx, labels_np, K)

# Print the 1D values (PCA scores) in ascending order
sorted_X_1D = np.sort(X_1D_pca.flatten())  # Flatten and sort the PCA scores
print("\n1D PCA values in ascending order:", sorted_X_1D)

# Sort the 1D centroid values and map to labels
sorted_centroids_idx = np.argsort(centroids_1D_pca.flatten())
true_labels_mapping = ['control', 'sd', 'ex']
sorted_labels = [true_labels_mapping[i] for i in sorted_centroids_idx]

# Print sorted centroids with their corresponding true labels
print("\nCentroids in ascending order:")
for i, idx in enumerate(sorted_centroids_idx):
    print(f"Centroid {i+1}: {sorted_labels[i]}, Value: {centroids_1D_pca[idx][0]:.4f}")
# Out:
# 1D PCA values in ascending order: [-0.67422354 -0.6618506  -0.63328415 -0.63090384 -0.6232822  -0.6050955
#  -0.59161615 -0.58710814 -0.5817171  -0.5816232  -0.5671112  -0.5644147
#  -0.5570517  -0.5475627  -0.54161656 -0.5309715  -0.5261008  -0.49478018
#  -0.49377307 -0.45689332 -0.44976163 -0.43842104 -0.433227   -0.41051653
#  -0.406223   -0.3989715  -0.39519322 -0.38608617 -0.3834336  -0.38045263
#  -0.37674323 -0.37528268 -0.37380263 -0.36921185 -0.35411978 -0.3440262
#  -0.31818148 -0.315335   -0.26533034 -0.25883582 -0.19865803 -0.1891391
#  -0.17756371 -0.11318383 -0.11306266 -0.11083626 -0.10778275 -0.10614646
#  -0.08753853 -0.07616495 -0.05343712 -0.04390974 -0.04132077 -0.03795398
#  -0.03555905 -0.03353995 -0.02524958 -0.01587157 -0.00607888  0.01255174
#   0.02466077  0.04244286  0.06228642  0.06839561  0.07360953  0.08137137
#   0.08619266  0.08853185  0.10009573  0.10011639  0.10764465  0.1292649
#   0.13330436  0.1491074   0.18082166  0.19298589  0.19844873  0.20968878
#   0.2124299   0.22756605  0.26159805  0.28725052  0.30486193  0.31340274
#   0.32924342  0.34637773  0.3510512   0.35546425  0.39093047  0.4015555
#   0.40760997  0.415778    0.4233651   0.4306164   0.43109116  0.44060823
#   0.44916993  0.46333253  0.46586958  0.47638175  0.4797498   0.48082462
#   0.48413494  0.48719645  0.4876347   0.49014202  0.49676606  0.49818125
#   0.5018287   0.5101825   0.5112456   0.5127305   0.51713383  0.5226659
#   0.52353084  0.523736    0.5252759   0.53226274  0.56992024  0.5749168 ]
#
# Centroids in ascending order:
# Centroid 1: control, Value: -0.5573
# Centroid 2: sd, Value: 0.0304
# Centroid 3: ex, Value: 0.5275

# %%
import numpy as np
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from scipy.stats import mode

def reduce_to_1D_pca(X, centroids):
    pca = PCA(n_components=1)
    X_1D = pca.fit_transform(X)
    centroids_1D = pca.transform(centroids)
    return X_1D, centroids_1D

def plot_1D_clusters_with_labels(X_1D, centroids_1D, idx, labels, K):
    plt.figure(figsize=(10, 5))
    colors = plt.cm.rainbow(np.linspace(0, 1, K))
    
    for k in range(K):
        cluster_points = X_1D[idx == k]
        cluster_labels = labels[idx == k]
        
        plt.scatter(cluster_points, [k] * len(cluster_points), 
                    c=[colors[k]], label=f"Cluster {k+1}", alpha=0.6, s=20)
        
        for i in range(len(cluster_points)):
            plt.annotate(str(cluster_labels[i]), 
                         (cluster_points[i], k), 
                         fontsize=8, alpha=0.75)

    for k in range(K):
        plt.scatter(centroids_1D[k], k, 
                    c='k', marker='x', s=200, label=f'Centroid {k+1}' if k == 0 else "")

    plt.title("1D Visualization of Clusters using PCA with True Labels")
    plt.xlabel("Principal Component 1")
    plt.ylabel("Cluster Index")
    plt.legend()
    plt.grid()
    plt.show()

# Normalize features
feats_np_norm = normalize(feats_np, axis=1)

# Run clustering (using your existing cosine distance K-means code)
K = 3
best_centroids, best_idx, best_accuracy, accuracies = perform_clustering(feats_np_norm, K)

# Apply PCA and get sorted indices with paths
X_1D_pca, centroids_1D_pca = reduce_to_1D_pca(feats_np_norm, best_centroids)

# Create a list of tuples containing (PCA value, path, true_label)
pca_path_pairs = list(zip(X_1D_pca.flatten(), paths, labels_np))

# Sort based on PCA values while keeping track of paths and labels
sorted_pca_path_pairs = sorted(pca_path_pairs, key=lambda x: x[0])

# Separate sorted values, paths, and labels
sorted_X_1D = np.array([x[0] for x in sorted_pca_path_pairs])
sorted_paths = [x[1] for x in sorted_pca_path_pairs]
sorted_true_labels = [x[2] for x in sorted_pca_path_pairs]

# Print values with corresponding paths and true labels
print("\nSorted PCA values with corresponding paths and true labels:")
true_labels_mapping = ['control', 'sd', 'ex']
for pca_val, path, label in zip(sorted_X_1D, sorted_paths, sorted_true_labels):
    print(f"PCA value: {pca_val:.4f}, Label: {true_labels_mapping[label]}, Path: {path}")

# Print centroid information
sorted_centroids_idx = np.argsort(centroids_1D_pca.flatten())
sorted_labels = [true_labels_mapping[i] for i in sorted_centroids_idx]

print("\nCentroids in ascending order:")
for i, idx in enumerate(sorted_centroids_idx):
    print(f"Centroid {i+1}: {sorted_labels[i]}, Value: {centroids_1D_pca[idx][0]:.4f}")

# Plot the visualization
plot_1D_clusters_with_labels(X_1D_pca, centroids_1D_pca, best_idx, labels_np, K)
# Out:
# Sorted PCA values with corresponding paths and true labels:
# PCA value: -0.6742, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B11-T01.tiff
# PCA value: -0.6619, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F02-T01.tiff
# PCA value: -0.6333, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C11-T01.tiff
# PCA value: -0.6309, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F03-T01.tiff
# PCA value: -0.6233, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B10-T01.tiff
# PCA value: -0.6051, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B07-T01.tiff
# PCA value: -0.5916, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C10-T01.tiff
# PCA value: -0.5871, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C08-T01.tiff
# PCA value: -0.5817, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B09-T01.tiff
# PCA value: -0.5816, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F06-T01.tiff
# PCA value: -0.5671, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B10-T01.tiff
# PCA value: -0.5644, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F05-T01.tiff
# PCA value: -0.5571, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B08-T01.tiff
# PCA value: -0.5476, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C09-T01.tiff
# PCA value: -0.5416, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C07-T01.tiff
# PCA value: -0.5310, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F04-T01.tiff
# PCA value: -0.5261, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C11-T01.tiff
# PCA value: -0.4948, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C06-T01.tiff
# PCA value: -0.4938, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B09-T01.tiff
# PCA value: -0.4569, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B07-T01.tiff
# PCA value: -0.4498, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C04-T01.tiff
# PCA value: -0.4384, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C05-T01.tiff
# PCA value: -0.4332, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C7.tif
# PCA value: -0.4105, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B11-T01.tiff
# PCA value: -0.4062, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C03-T01.tiff
# PCA value: -0.3990, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C09-T01.tiff
# PCA value: -0.3952, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C05-T01.tiff
# PCA value: -0.3861, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C03-T01.tiff
# PCA value: -0.3834, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C07-T01.tiff
# PCA value: -0.3805, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C02-T01.tiff
# PCA value: -0.3767, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C8.tif
# PCA value: -0.3753, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C10-T01.tiff
# PCA value: -0.3738, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C02-T01.tiff
# PCA value: -0.3692, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C04-T01.tiff
# PCA value: -0.3541, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C9.tif
# PCA value: -0.3440, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C06-T01.tiff
# PCA value: -0.3182, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_c10.tif
# PCA value: -0.3153, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C08-T01.tiff
# PCA value: -0.2653, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C11.tif
# PCA value: -0.2588, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g9_C10-T01.tiff
# PCA value: -0.1987, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E06-T01.tiff
# PCA value: -0.1891, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C11-T01.tiff
# PCA value: -0.1776, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D02-T01.tiff
# PCA value: -0.1132, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B03-T01.tiff
# PCA value: -0.1131, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E10-T01.tiff
# PCA value: -0.1108, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D05-T01.tiff
# PCA value: -0.1078, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C09-T01.tiff
# PCA value: -0.1061, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E08-T01.tiff
# PCA value: -0.0875, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E11-T01.tiff
# PCA value: -0.0762, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D03-T01.tiff
# PCA value: -0.0534, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_F02-T01.tiff
# PCA value: -0.0439, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C10-T01.tiff
# PCA value: -0.0413, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B02-T01.tiff
# PCA value: -0.0380, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C08-T01.tiff
# PCA value: -0.0356, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D04-T01.tiff
# PCA value: -0.0335, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D06-T01.tiff
# PCA value: -0.0252, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F02-T01.tiff
# PCA value: -0.0159, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B05-T01.tiff
# PCA value: -0.0061, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B07-T01.tiff
# PCA value: 0.0126, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E07-T01.tiff
# PCA value: 0.0247, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D09-T01.tiff
# PCA value: 0.0424, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D08-T01.tiff
# PCA value: 0.0623, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F08-T01.tiff
# PCA value: 0.0684, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D07-T01.tiff
# PCA value: 0.0736, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F09-T01.tiff
# PCA value: 0.0814, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D10-T01.tiff
# PCA value: 0.0862, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D04-T01.tiff
# PCA value: 0.0885, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B04-T01.tiff
# PCA value: 0.1001, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E09-T01.tiff
# PCA value: 0.1001, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F07-T01.tiff
# PCA value: 0.1076, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_F03-T01.tiff
# PCA value: 0.1293, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_G09-T01.tiff
# PCA value: 0.1333, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D05-T01.tiff
# PCA value: 0.1491, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B06-T01.tiff
# PCA value: 0.1808, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F04-T01.tiff
# PCA value: 0.1930, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F03-T01.tiff
# PCA value: 0.1984, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F06-T01.tiff
# PCA value: 0.2097, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F05-T01.tiff
# PCA value: 0.2124, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D11-T01.tiff
# PCA value: 0.2276, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_G11-T01.tiff
# PCA value: 0.2616, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C11-T01.tiff
# PCA value: 0.2873, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D09-T01.tiff
# PCA value: 0.3049, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C10-T01.tiff
# PCA value: 0.3134, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D10-T01.tiff
# PCA value: 0.3292, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C08-T01.tiff
# PCA value: 0.3464, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F08-T01.tiff
# PCA value: 0.3511, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C09-T01.tiff
# PCA value: 0.3555, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_G11-T01.tiff
# PCA value: 0.3909, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C07-T01.tiff
# PCA value: 0.4016, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D08-T01.tiff
# PCA value: 0.4076, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F07-T01.tiff
# PCA value: 0.4158, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_D09-T01.tiff
# PCA value: 0.4234, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_D08-T01.tiff
# PCA value: 0.4306, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C07-T01.tiff
# PCA value: 0.4311, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_G08-T01.tiff
# PCA value: 0.4406, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_G10-T01.tiff
# PCA value: 0.4492, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_D11-T01.tiff
# PCA value: 0.4633, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C10-T01.tiff
# PCA value: 0.4659, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C08-T01.tiff
# PCA value: 0.4764, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D07-T01.tiff
# PCA value: 0.4797, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B11-T01.tiff
# PCA value: 0.4808, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_G07-T01.tiff
# PCA value: 0.4841, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E10-T01.tiff
# PCA value: 0.4872, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_D10-T01.tiff
# PCA value: 0.4876, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_C07-T01.tiff
# PCA value: 0.4901, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C09-T01.tiff
# PCA value: 0.4968, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B07-T01.tiff
# PCA value: 0.4982, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B10-T01.tiff
# PCA value: 0.5018, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_D09-T01.tiff
# PCA value: 0.5102, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F11-T01.tiff
# PCA value: 0.5112, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_D07-T01.tiff
# PCA value: 0.5127, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E11-T01.tiff
# PCA value: 0.5171, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F09-T01.tiff
# PCA value: 0.5227, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E07-T01.tiff
# PCA value: 0.5235, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_G09-T01.tiff
# PCA value: 0.5237, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B08-T01.tiff
# PCA value: 0.5253, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_F07-T01.tiff
# PCA value: 0.5323, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E09-T01.tiff
# PCA value: 0.5699, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F10-T01.tiff
# PCA value: 0.5749, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B09-T01.tiff
#
# Centroids in ascending order:
# Centroid 1: ex, Value: -0.5573
# Centroid 2: control, Value: 0.0304
# Centroid 3: sd, Value: 0.5275

# %% [markdown]
# weighted pca

# %%
import numpy as np
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Function to reduce to 2D PCA and compute weighted 1D metric
def reduce_to_weighted_1D_pca(X, centroids):
    pca = PCA(n_components=2)
    X_2D = pca.fit_transform(X)
    centroids_2D = pca.transform(centroids)
    
    # Get explained variance ratios as weights
    explained_variance = pca.explained_variance_ratio_
    w1, w2 = explained_variance[0], explained_variance[1]
    
    # Compute the weighted 1D metric
    X_weighted_1D = w1 * X_2D[:, 0] + w2 * X_2D[:, 1]
    centroids_weighted_1D = w1 * centroids_2D[:, 0] + w2 * centroids_2D[:, 1]
    
    return X_weighted_1D, centroids_weighted_1D

# Apply PCA and compute weighted 1D metric
X_weighted_1D, centroids_weighted_1D = reduce_to_weighted_1D_pca(feats_np_norm, best_centroids)

# Create a list of tuples containing (Weighted PCA value, path, true_label)
pca_path_pairs = list(zip(X_weighted_1D, paths, labels_np))

# Sort based on the weighted PCA values
sorted_pca_path_pairs = sorted(pca_path_pairs, key=lambda x: x[0])

# Separate sorted values, paths, and labels
sorted_weighted_X_1D = np.array([x[0] for x in sorted_pca_path_pairs])
sorted_paths = [x[1] for x in sorted_pca_path_pairs]
sorted_true_labels = [x[2] for x in sorted_pca_path_pairs]

# Print sorted weighted PCA values with corresponding paths and true labels
true_labels_mapping = ['control', 'sd', 'ex']
print("\nSorted Weighted PCA values with corresponding paths and true labels:")
for pca_val, path, label in zip(sorted_weighted_X_1D, sorted_paths, sorted_true_labels):
    print(f"Weighted PCA value: {pca_val:.4f}, Label: {true_labels_mapping[label]}, Path: {path}")

# Print centroid information
sorted_centroids_idx = np.argsort(centroids_weighted_1D)
sorted_labels = [true_labels_mapping[i] for i in sorted_centroids_idx]

print("\nCentroids in ascending order:")
for i, idx in enumerate(sorted_centroids_idx):
    print(f"Centroid {i+1}: {sorted_labels[i]}, Value: {centroids_weighted_1D[idx]:.4f}")
# Out:
# Sorted Weighted PCA values with corresponding paths and true labels:
# Weighted PCA value: -0.2551, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F02-T01.tiff
# Weighted PCA value: -0.2486, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B11-T01.tiff
# Weighted PCA value: -0.2482, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B10-T01.tiff
# Weighted PCA value: -0.2459, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C11-T01.tiff
# Weighted PCA value: -0.2410, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F05-T01.tiff
# Weighted PCA value: -0.2368, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C11-T01.tiff
# Weighted PCA value: -0.2360, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B07-T01.tiff
# Weighted PCA value: -0.2337, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C10-T01.tiff
# Weighted PCA value: -0.2324, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B10-T01.tiff
# Weighted PCA value: -0.2288, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F03-T01.tiff
# Weighted PCA value: -0.2281, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B09-T01.tiff
# Weighted PCA value: -0.2248, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B09-T01.tiff
# Weighted PCA value: -0.2227, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B07-T01.tiff
# Weighted PCA value: -0.2199, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C08-T01.tiff
# Weighted PCA value: -0.2197, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C09-T01.tiff
# Weighted PCA value: -0.2196, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F04-T01.tiff
# Weighted PCA value: -0.2194, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F06-T01.tiff
# Weighted PCA value: -0.2086, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C06-T01.tiff
# Weighted PCA value: -0.2068, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C07-T01.tiff
# Weighted PCA value: -0.2060, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B11-T01.tiff
# Weighted PCA value: -0.2043, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C09-T01.tiff
# Weighted PCA value: -0.2017, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C07-T01.tiff
# Weighted PCA value: -0.1994, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C04-T01.tiff
# Weighted PCA value: -0.1970, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C03-T01.tiff
# Weighted PCA value: -0.1939, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C08-T01.tiff
# Weighted PCA value: -0.1914, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B08-T01.tiff
# Weighted PCA value: -0.1904, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C05-T01.tiff
# Weighted PCA value: -0.1837, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C10-T01.tiff
# Weighted PCA value: -0.1652, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C02-T01.tiff
# Weighted PCA value: -0.1312, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C05-T01.tiff
# Weighted PCA value: -0.1211, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C7.tif
# Weighted PCA value: -0.1160, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C03-T01.tiff
# Weighted PCA value: -0.1138, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g9_C10-T01.tiff
# Weighted PCA value: -0.1106, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C02-T01.tiff
# Weighted PCA value: -0.1000, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C04-T01.tiff
# Weighted PCA value: -0.0910, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C06-T01.tiff
# Weighted PCA value: -0.0892, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C8.tif
# Weighted PCA value: -0.0860, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C9.tif
# Weighted PCA value: -0.0799, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_c10.tif
# Weighted PCA value: -0.0466, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C11.tif
# Weighted PCA value: 0.0089, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F08-T01.tiff
# Weighted PCA value: 0.0131, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D09-T01.tiff
# Weighted PCA value: 0.0158, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C08-T01.tiff
# Weighted PCA value: 0.0282, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F07-T01.tiff
# Weighted PCA value: 0.0282, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_G08-T01.tiff
# Weighted PCA value: 0.0477, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C11-T01.tiff
# Weighted PCA value: 0.0486, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D08-T01.tiff
# Weighted PCA value: 0.0493, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D02-T01.tiff
# Weighted PCA value: 0.0507, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E06-T01.tiff
# Weighted PCA value: 0.0512, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D10-T01.tiff
# Weighted PCA value: 0.0522, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_G11-T01.tiff
# Weighted PCA value: 0.0532, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C07-T01.tiff
# Weighted PCA value: 0.0543, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_D08-T01.tiff
# Weighted PCA value: 0.0551, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B07-T01.tiff
# Weighted PCA value: 0.0553, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E10-T01.tiff
# Weighted PCA value: 0.0556, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_G07-T01.tiff
# Weighted PCA value: 0.0568, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D06-T01.tiff
# Weighted PCA value: 0.0581, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B08-T01.tiff
# Weighted PCA value: 0.0595, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C09-T01.tiff
# Weighted PCA value: 0.0622, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C07-T01.tiff
# Weighted PCA value: 0.0629, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C11-T01.tiff
# Weighted PCA value: 0.0683, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_D09-T01.tiff
# Weighted PCA value: 0.0699, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B03-T01.tiff
# Weighted PCA value: 0.0708, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_C07-T01.tiff
# Weighted PCA value: 0.0720, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C09-T01.tiff
# Weighted PCA value: 0.0729, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F11-T01.tiff
# Weighted PCA value: 0.0763, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E10-T01.tiff
# Weighted PCA value: 0.0767, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_D11-T01.tiff
# Weighted PCA value: 0.0798, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_D10-T01.tiff
# Weighted PCA value: 0.0821, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C10-T01.tiff
# Weighted PCA value: 0.0827, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C08-T01.tiff
# Weighted PCA value: 0.0828, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F09-T01.tiff
# Weighted PCA value: 0.0832, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_G09-T01.tiff
# Weighted PCA value: 0.0858, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B11-T01.tiff
# Weighted PCA value: 0.0864, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E11-T01.tiff
# Weighted PCA value: 0.0895, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E07-T01.tiff
# Weighted PCA value: 0.0897, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_D09-T01.tiff
# Weighted PCA value: 0.0907, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E09-T01.tiff
# Weighted PCA value: 0.0926, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D09-T01.tiff
# Weighted PCA value: 0.0945, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B09-T01.tiff
# Weighted PCA value: 0.0962, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_F07-T01.tiff
# Weighted PCA value: 0.0974, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F08-T01.tiff
# Weighted PCA value: 0.0988, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D05-T01.tiff
# Weighted PCA value: 0.0988, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D08-T01.tiff
# Weighted PCA value: 0.0996, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C09-T01.tiff
# Weighted PCA value: 0.0999, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B10-T01.tiff
# Weighted PCA value: 0.1000, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F09-T01.tiff
# Weighted PCA value: 0.1009, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E08-T01.tiff
# Weighted PCA value: 0.1015, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E11-T01.tiff
# Weighted PCA value: 0.1032, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F07-T01.tiff
# Weighted PCA value: 0.1052, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C10-T01.tiff
# Weighted PCA value: 0.1071, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_D07-T01.tiff
# Weighted PCA value: 0.1071, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D03-T01.tiff
# Weighted PCA value: 0.1077, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F02-T01.tiff
# Weighted PCA value: 0.1132, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D10-T01.tiff
# Weighted PCA value: 0.1146, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D04-T01.tiff
# Weighted PCA value: 0.1150, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F10-T01.tiff
# Weighted PCA value: 0.1175, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D07-T01.tiff
# Weighted PCA value: 0.1186, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_F02-T01.tiff
# Weighted PCA value: 0.1187, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B05-T01.tiff
# Weighted PCA value: 0.1205, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D07-T01.tiff
# Weighted PCA value: 0.1216, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B02-T01.tiff
# Weighted PCA value: 0.1223, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_G10-T01.tiff
# Weighted PCA value: 0.1226, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D05-T01.tiff
# Weighted PCA value: 0.1228, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C08-T01.tiff
# Weighted PCA value: 0.1247, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F06-T01.tiff
# Weighted PCA value: 0.1262, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D04-T01.tiff
# Weighted PCA value: 0.1268, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C10-T01.tiff
# Weighted PCA value: 0.1321, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F05-T01.tiff
# Weighted PCA value: 0.1331, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B04-T01.tiff
# Weighted PCA value: 0.1331, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F04-T01.tiff
# Weighted PCA value: 0.1351, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E09-T01.tiff
# Weighted PCA value: 0.1367, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_G09-T01.tiff
# Weighted PCA value: 0.1391, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E07-T01.tiff
# Weighted PCA value: 0.1405, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B07-T01.tiff
# Weighted PCA value: 0.1581, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_F03-T01.tiff
# Weighted PCA value: 0.1628, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F03-T01.tiff
# Weighted PCA value: 0.1636, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D11-T01.tiff
# Weighted PCA value: 0.1691, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B06-T01.tiff
# Weighted PCA value: 0.1692, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_G11-T01.tiff
#
# Centroids in ascending order:
# Centroid 1: ex, Value: -0.2174
# Centroid 2: sd, Value: 0.0847
# Centroid 3: control, Value: 0.1366

# %%
import numpy as np

def calculate_middle_cluster_accuracy(X_1D, idx, centroids_1D):
    # Convert idx to array if it's not already
    if not isinstance(idx, np.ndarray):
        idx = np.array(idx)
    
    # Ensure idx is the same length as X_1D
    if idx.shape != (len(X_1D),):
        print("Warning: Reshaping idx to match data points")
        idx = np.full(len(X_1D), idx)
    
    print("Debugging Information:")
    print(f"Shape of X_1D: {X_1D.shape}")
    print(f"Shape of idx (after fix): {idx.shape}")
    print(f"Shape of centroids_1D: {centroids_1D.shape}")
    print(f"Unique cluster indices: {np.unique(idx)}")
    
    # Sort centroids and get their indices
    centroid_values = centroids_1D.flatten()
    sorted_indices = np.argsort(centroid_values)
    print(f"Centroid values: {centroid_values}")
    print(f"Sorted centroid indices: {sorted_indices}")
    
    # Map old cluster indices to new ordered indices (0, 1, 2)
    index_mapping = {old_idx: new_idx for new_idx, old_idx in enumerate(sorted_indices)}
    
    # Reindex the clusters to be 0, 1, 2 in order of centroid values
    new_idx = np.zeros_like(idx)
    for old_idx, new_idx_val in index_mapping.items():
        new_idx[idx == old_idx] = new_idx_val
    
    # Now we work with the reindexed clusters
    # Get points belonging to each cluster
    first_cluster_points = X_1D[new_idx == 0]
    middle_cluster_points = X_1D[new_idx == 1]
    third_cluster_points = X_1D[new_idx == 2]
    
    print(f"\nCluster sizes after reindexing:")
    print(f"First cluster points: {len(first_cluster_points)}")
    print(f"Middle cluster points: {len(middle_cluster_points)}")
    print(f"Third cluster points: {len(third_cluster_points)}")
    
    # Check if any clusters are empty
    if len(first_cluster_points) == 0 or len(middle_cluster_points) == 0 or len(third_cluster_points) == 0:
        raise ValueError("One or more clusters are empty after reindexing. Please check cluster assignments.")
    
    # Calculate boundary values
    first_cluster_max = np.max(first_cluster_points)
    third_cluster_min = np.min(third_cluster_points)
    
    # Count errors
    errors_below = np.sum(middle_cluster_points < first_cluster_max)
    errors_above = np.sum(middle_cluster_points > third_cluster_min)
    total_errors = errors_below + errors_above
    total_points = 40+40+40
    # Calculate accuracy
    total_middle_points = len(middle_cluster_points)
    accuracy = (total_points - total_errors) / total_points
    
    # Print boundary information
    print(f"\nBoundary Information:")
    print(f"First cluster range: [{np.min(first_cluster_points):.4f}, {first_cluster_max:.4f}]")
    print(f"Middle cluster range: [{np.min(middle_cluster_points):.4f}, {np.max(middle_cluster_points):.4f}]")
    print(f"Third cluster range: [{third_cluster_min:.4f}, {np.max(third_cluster_points):.4f}]")
    
    return {
        'accuracy': accuracy,
        'total_points': total_middle_points,
        'errors_below': errors_below,
        'errors_above': errors_above,
        'total_errors': total_errors,
        'first_cluster_max': first_cluster_max,
        'third_cluster_min': third_cluster_min
    }

# Try to calculate the accuracy metrics with error handling
try:
    # Use best_idx from our successful K-means clustering
    results = calculate_middle_cluster_accuracy(X_1D_pca, best_idx, centroids_1D_pca)
    
    print(f"\nResults:")
    print(f"Total points in middle cluster: {results['total_points']}")
    print(f"Errors below first cluster max: {results['errors_below']}")
    print(f"Errors above third cluster min: {results['errors_above']}")
    print(f"Total errors: {results['total_errors']}")
    print(f"Accuracy: {results['accuracy']:.4f} ({results['accuracy']*100:.2f}%)")
    
except ValueError as e:
    print(f"Error: {e}")
    print("Additional debugging needed. Please check:")
    print("1. The original cluster assignments")
    print("2. The K-means clustering results")
    print("3. The PCA transformation process")
# Out:
# Debugging Information:
# Shape of X_1D: (120, 1)
# Shape of idx (after fix): (120,)
# Shape of centroids_1D: (3, 1)
# Unique cluster indices: [0 1 2]
# Centroid values: [ 0.03042284  0.52752201 -0.55725242]
# Sorted centroid indices: [2 0 1]
#
# Cluster sizes after reindexing:
# First cluster points: 40
# Middle cluster points: 40
# Third cluster points: 40
#
# Boundary Information:
# First cluster range: [-0.6742, -0.2588]
# Middle cluster range: [-0.1987, 0.2276]
# Third cluster range: [0.2616, 0.5749]
#
# Results:
# Total points in middle cluster: 40
# Errors below first cluster max: 0
# Errors above third cluster min: 0
# Total errors: 0
# Accuracy: 1.0000 (100.00%)

# %%
import numpy as np

def calculate_cluster_accuracy_both_metrics(X_1D, idx, centroids_1D):
    # Convert idx to array if it's not already
    if not isinstance(idx, np.ndarray):
        idx = np.array(idx)
    
    # Ensure idx is the same length as X_1D
    if idx.shape != (len(X_1D),):
        print("Warning: Reshaping idx to match data points")
        idx = np.full(len(X_1D), idx)
    
    print("Debugging Information:")
    print(f"Shape of X_1D: {X_1D.shape}")
    print(f"Shape of idx (after fix): {idx.shape}")
    print(f"Shape of centroids_1D: {centroids_1D.shape}")
    print(f"Unique cluster indices: {np.unique(idx)}")
    
    # Sort centroids and get their indices
    centroid_values = centroids_1D.flatten()
    sorted_indices = np.argsort(centroid_values)
    print(f"Centroid values: {centroid_values}")
    print(f"Sorted centroid indices: {sorted_indices}")
    
    # Map old cluster indices to new ordered indices (0, 1, 2)
    index_mapping = {old_idx: new_idx for new_idx, old_idx in enumerate(sorted_indices)}
    
    # Reindex the clusters to be 0, 1, 2 in order of centroid values
    new_idx = np.zeros_like(idx)
    for old_idx, new_idx_val in index_mapping.items():
        new_idx[idx == old_idx] = new_idx_val
    
    # Now we work with the reindexed clusters
    # Get points belonging to each cluster
    first_cluster_points = X_1D[new_idx == 0]
    middle_cluster_points = X_1D[new_idx == 1]
    third_cluster_points = X_1D[new_idx == 2]
    
    print(f"\nCluster sizes after reindexing:")
    print(f"First cluster points: {len(first_cluster_points)}")
    print(f"Middle cluster points: {len(middle_cluster_points)}")
    print(f"Third cluster points: {len(third_cluster_points)}")
    
    # Check if any clusters are empty
    if len(first_cluster_points) == 0 or len(middle_cluster_points) == 0 or len(third_cluster_points) == 0:
        raise ValueError("One or more clusters are empty after reindexing. Please check cluster assignments.")
    
    # Calculate boundary values for original metric
    first_cluster_max = np.max(first_cluster_points)
    third_cluster_min = np.min(third_cluster_points)
    
    # Calculate boundary values for new metric
    middle_cluster_min = np.min(middle_cluster_points)
    middle_cluster_max = np.max(middle_cluster_points)
    
    # Count errors for original metric (middle cluster errors)
    middle_errors_below = np.sum(middle_cluster_points < first_cluster_max)
    middle_errors_above = np.sum(middle_cluster_points > third_cluster_min)
    total_middle_errors = middle_errors_below + middle_errors_above
    
    # Count errors for new metric (outer clusters errors)
    first_cluster_errors = np.sum(first_cluster_points > middle_cluster_min)
    third_cluster_errors = np.sum(third_cluster_points < middle_cluster_max)
    total_outer_errors = first_cluster_errors + third_cluster_errors
    
    total_points = len(first_cluster_points) + len(middle_cluster_points) + len(third_cluster_points)
    
    # Calculate accuracies
    middle_accuracy = (total_points - total_middle_errors) / total_points
    outer_accuracy = (total_points - total_outer_errors) / total_points
    
    # Print boundary information
    print(f"\nBoundary Information:")
    print(f"First cluster range: [{np.min(first_cluster_points):.4f}, {first_cluster_max:.4f}]")
    print(f"Middle cluster range: [{middle_cluster_min:.4f}, {middle_cluster_max:.4f}]")
    print(f"Third cluster range: [{third_cluster_min:.4f}, {np.max(third_cluster_points):.4f}]")
    
    # Print detailed error counts for debugging
    print("\nDetailed Error Analysis:")
    print("Original Metric (Middle cluster errors):")
    print(f"Middle points below first max: {middle_errors_below}")
    print(f"Middle points above third min: {middle_errors_above}")
    print("\nNew Metric (Outer clusters errors):")
    print(f"First cluster points above middle min: {first_cluster_errors}")
    print(f"Third cluster points below middle max: {third_cluster_errors}")
    
    return {
        # Original metric results
        'middle_accuracy': middle_accuracy,
        'middle_errors_below': middle_errors_below,
        'middle_errors_above': middle_errors_above,
        'total_middle_errors': total_middle_errors,
        
        # New metric results
        'outer_accuracy': outer_accuracy,
        'first_cluster_errors': first_cluster_errors,
        'third_cluster_errors': third_cluster_errors,
        'total_outer_errors': total_outer_errors,
        
        # Boundary values
        'first_cluster_max': first_cluster_max,
        'middle_cluster_min': middle_cluster_min,
        'middle_cluster_max': middle_cluster_max,
        'third_cluster_min': third_cluster_min,
        
        'total_points': total_points
    }

# Try to calculate both accuracy metrics with error handling
try:
    # Use best_idx from the K-means clustering
    results = calculate_cluster_accuracy_both_metrics(X_1D_pca, best_idx, centroids_1D_pca)
    
    print(f"\nFinal Results:")
    print("\nOriginal Metric (Middle cluster errors):")
    print(f"Total errors: {results['total_middle_errors']}")
    print(f"Accuracy: {results['middle_accuracy']:.4f} ({results['middle_accuracy']*100:.2f}%)")
    
    print("\nNew Metric (Outer clusters errors):")
    print(f"Total errors: {results['total_outer_errors']}")
    print(f"Accuracy: {results['outer_accuracy']:.4f} ({results['outer_accuracy']*100:.2f}%)")
    
except ValueError as e:
    print(f"Error: {e}")
    print("Additional debugging needed. Please check:")
    print("1. The original cluster assignments")
    print("2. The K-means clustering results")
    print("3. The PCA transformation process")
# Out:
# Debugging Information:
# Shape of X_1D: (120, 1)
# Shape of idx (after fix): (120,)
# Shape of centroids_1D: (3, 1)
# Unique cluster indices: [0 1 2]
# Centroid values: [ 0.03042284  0.52752201 -0.55725242]
# Sorted centroid indices: [2 0 1]
#
# Cluster sizes after reindexing:
# First cluster points: 40
# Middle cluster points: 40
# Third cluster points: 40
#
# Boundary Information:
# First cluster range: [-0.6742, -0.2588]
# Middle cluster range: [-0.1987, 0.2276]
# Third cluster range: [0.2616, 0.5749]
#
# Detailed Error Analysis:
# Original Metric (Middle cluster errors):
# Middle points below first max: 0
# Middle points above third min: 0
#
# New Metric (Outer clusters errors):
# First cluster points above middle min: 0
# Third cluster points below middle max: 0
#
# Final Results:
#
# Original Metric (Middle cluster errors):
# Total errors: 0
# Accuracy: 1.0000 (100.00%)
#
# New Metric (Outer clusters errors):
# Total errors: 0
# Accuracy: 1.0000 (100.00%)

# %% [markdown]
# # Function to reduce the dimensionality of data points and centroids to 2D using PCA
# def reduce_to_2D_pca(X, centroids):
#     # Initialize PCA with 2 components
#     pca = PCA(n_components=2)
#
#     # Apply PCA to the data points (X) and centroids
#     X_2D = pca.fit_transform(X)  # Reducing original data points
#     centroids_2D = pca.transform(centroids)  # Reducing centroids
#
#     return X_2D, centroids_2D
#
# # Function to plot 2D visualization of clustered data points and centroids with true labels
# def plot_2D_clusters_with_labels(X_2D, centroids_2D, idx, labels, K):
#     plt.figure(figsize=(10, 7))
#
#     # Define color map for clusters
#     colors = plt.cm.rainbow(np.linspace(0, 1, K))
#
#     # Plot data points colored by their cluster assignment
#     for k in range(K):
#         cluster_points = X_2D[idx == k]
#         cluster_labels = labels[idx == k]  # Get true labels for the current cluster
#
#         # Scatter plot for each cluster
#         plt.scatter(cluster_points[:, 0], cluster_points[:, 1],
#                     c=[colors[k]], label=f"Cluster {k+1}", alpha=0.6)
#
#         # Annotate each point with its true label
#         for i in range(cluster_points.shape[0]):
#             plt.annotate(str(cluster_labels[i]),
#                          (cluster_points[i, 0], cluster_points[i, 1]),
#                          fontsize=8, alpha=0.75)
#
#     # Plot centroids as larger markers
#     plt.scatter(centroids_2D[:, 0], centroids_2D[:, 1],
#                 c='k', marker='x', s=200, label='Centroids')
#
#     plt.title("2D Visualization of Clusters using PCA with True Labels")
#     plt.xlabel("Component 1")
#     plt.ylabel("Component 2")
#     plt.legend()
#     plt.grid()
#     plt.show()

# %% [markdown]
# # Apply PCA after K-Means clustering for 2D visualization
# X_2D_pca, centroids_2D_pca = reduce_to_2D_pca(feats_np_norm, centroids)
#
# # Plot the 2D clusters with centroids and true labels
# plot_2D_clusters_with_labels(X_2D_pca, centroids_2D_pca, idx, labels_np, K)
