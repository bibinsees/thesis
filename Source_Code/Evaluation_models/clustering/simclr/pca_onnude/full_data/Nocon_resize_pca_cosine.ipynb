# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import tifffile as tiff
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
from copy import deepcopy   
import random
from sklearn.preprocessing import normalize

from collections import Counter
from scipy.stats import mode

# %%
# Set seed for reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set seed
set_seed(42)

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class SimCLR(nn.Module):
    def __init__(self, hidden_dim, lr, temperature, weight_decay):
        super().__init__()
        self.temperature = temperature
        
        # Load the pretrained ResNet-18 model
        self.convnet = torchvision.models.resnet18(weights='ResNet18_Weights.DEFAULT')
        
        # Modify the fully connected layer
        self.convnet.fc = nn.Sequential(
            nn.Linear(self.convnet.fc.in_features, 4 * hidden_dim),  # Linear layer with 4*hidden_dim output
            nn.ReLU(inplace=True),
            nn.Linear(4 * hidden_dim, 20)  # Output layer with hidden_dim output
        )

        self.optimizer = optim.AdamW(self.parameters(), lr=lr, weight_decay=weight_decay)
        self.lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(self.optimizer, T_max=50, eta_min=lr / 50)

    def forward(self, x):
        return self.convnet(x)

    def info_nce_loss(self, imgs1, imgs2, device):

        imgs = torch.cat((imgs1, imgs2), dim=0)  # Concatenate along the batch dimension
        imgs = imgs.to(device)  # Move images to the device

        # Encode all images
        feats = self.forward(imgs)
    
        # Calculate cosine similarity
        cos_sim = nn.functional.cosine_similarity(feats[:, None, :], feats[None, :, :], dim=-1)
    
        # Mask out cosine similarity to itself
        self_mask = torch.eye(cos_sim.shape[0], dtype=torch.bool, device=cos_sim.device)
        cos_sim.masked_fill_(self_mask, -9e15)
    
        # Find positive example -> batch_size//2 away from the original example
        pos_mask = self_mask.roll(shifts=cos_sim.shape[0] // 2, dims=0)
    
        # Normalize similarity scores by temperature
        cos_sim = cos_sim / self.temperature

        # InfoNCE loss
        nll = -cos_sim[pos_mask] + torch.logsumexp(cos_sim, dim=-1)
        nll = nll.mean()

        # Accuracy calculations
        # Create a combination of positive and negative similarities for ranking
        comb_sim = torch.cat([cos_sim[pos_mask][:, None],  # Positive example in first position
                          cos_sim.masked_fill(pos_mask, -9e15)], dim=-1)
    
        # Sort and get the ranking position of the positive example
        sim_argsort = comb_sim.argsort(dim=-1, descending=True).argmin(dim=-1)
    
        # Compute accuracy metrics
        top1_acc = (sim_argsort == 0).float().mean()  # Top-1 accuracy
        top5_acc = (sim_argsort < 5).float().mean()   # Top-5 accuracy
        mean_pos = 1 + sim_argsort.float().mean()     # Mean position of the positive example

        return nll, top1_acc, top5_acc, mean_pos

    def train_epoch(self, train_loader, device):
        self.train()
        total_loss = 0.0
        total_top1_acc = 0.0
        total_top5_acc = 0.0
        total_mean_pos = 0.0

        for batch in tqdm(train_loader, desc="Training", leave=False):
            imgs1, imgs2, _ = batch
            imgs1, imgs2 = imgs1.to(device), imgs2.to(device)  # Move data to device
        
            self.optimizer.zero_grad()

            # Calculate loss and accuracy metrics
            loss, top1_acc, top5_acc, mean_pos = self.info_nce_loss(imgs1, imgs2, device)

            loss.backward()
            self.optimizer.step()
            self.lr_scheduler.step()

            # Accumulate metrics
            total_loss += loss.item()
            total_top1_acc += top1_acc.item()
            total_top5_acc += top5_acc.item()
            total_mean_pos += mean_pos.item()

        avg_loss = total_loss / len(train_loader)
        avg_top1_acc = total_top1_acc / len(train_loader)
        avg_top5_acc = total_top5_acc / len(train_loader)
        avg_mean_pos = total_mean_pos / len(train_loader)

        return avg_loss, avg_top1_acc, avg_top5_acc, avg_mean_pos

    def validate_epoch(self, val_loader, device):
        self.eval()
        total_loss = 0.0
        total_top1_acc = 0.0
        total_top5_acc = 0.0
        total_mean_pos = 0.0

        with torch.no_grad():
            for batch in tqdm(val_loader, desc="Validating", leave=False):
                imgs1, imgs2, _ = batch
                imgs1, imgs2 = imgs1.to(device), imgs2.to(device)  # Move data to device

                # Calculate loss and accuracy metrics
                loss, top1_acc, top5_acc, mean_pos = self.info_nce_loss(imgs1, imgs2, device)

                # Accumulate metrics
                total_loss += loss.item()
                total_top1_acc += top1_acc.item()
                total_top5_acc += top5_acc.item()
                total_mean_pos += mean_pos.item()

        avg_loss = total_loss / len(val_loader)
        avg_top1_acc = total_top1_acc / len(val_loader)
        avg_top5_acc = total_top5_acc / len(val_loader)
        avg_mean_pos = total_mean_pos / len(val_loader)

        return avg_loss, avg_top1_acc, avg_top5_acc, avg_mean_pos

# %%
# Define file paths
model_path = r'C:\Users\k54739\Bibi_new_thesis\thesis\Source_Code\SimCLR_base_models\ohnecontrast_balancedResize_simclr_modelepoch245.pth'
simclr_model = SimCLR(hidden_dim=128, lr=5e-4, temperature=0.07, weight_decay=1e-4)
simclr_model.load_state_dict(torch.load(model_path))
simclr_model.to(device)
simclr_model.eval()
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_4728\572655663.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   simclr_model.load_state_dict(torch.load(model_path))
# SimCLR(
#   (convnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=512, out_features=20, bias=True)
#     )
#   )
# )

# %% [markdown]
# # Clustering

# %%
class LabeledImageDataset(Dataset):
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        #self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Ensure the image has 3 layers (channels)
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} does not have exactly 3 layers.")

        # Normalize the 16-bit image to [0, 1]
        image = image.astype(np.float32) / 65535.0

        # Convert to a torch tensor and add channel dimension
        image = torch.tensor(image, dtype=torch.float32)
        
        # Apply resize transform
        image = self.resize_transform(image)

        label = self.labels[idx]

        #return image, label
        return image, label, img_path

def load_data(root_dir):
    #classes = ['cond7_all', 'sd','ex'] #full dataset
    #classes = ['cond7_curated', 'sd','ex'] # curated full dataset


    #classes = ['cure_cond7_40', 'sdonly_40','ex'] # 40 subset
    classes = ['cond7_all', 'sd','ex']


   
    
    #classes = ['curated_cond7_40', 'sd_40','ex'] # curated 40 subset


    image_files = []
    labels = []

    for idx, class_name in enumerate(classes):
        class_dir = os.path.join(root_dir, class_name)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir) if file.endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        labels.extend([idx] * len(files))
    
    # Check if the labels correctly reflect the classes
    print("Label distribution:", {classes[i]: labels.count(i) for i in range(len(classes))})

    return image_files, labels


# Directories for labeled data
#image_dir =  r"C:\Users\k54739\Bibi_new_thesis\thesis\classification"

image_dir =  r"G:\classification\cond_all"


# Load data
image_files, labels = load_data(image_dir)

# Create the labeled datasets
labeled_dataset = LabeledImageDataset(image_files, labels)

# Define DataLoaders
batch_size = 16
loader_labeled = DataLoader(labeled_dataset, batch_size=batch_size, shuffle=True, drop_last=False, pin_memory=True, num_workers=0)
# Out:
# Label distribution: {'cond7_all': 472, 'sd': 103, 'ex': 40}

# %%
# Print label mapping
classes = ['cond7_all', 'sd','ex']
for idx, class_name in enumerate(classes):
    print(f"Label {idx} corresponds to class: {class_name}")
# Out:
# Label 0 corresponds to class: cond7_all
# Label 1 corresponds to class: sd
# Label 2 corresponds to class: ex

# %%
label_mapping = {idx: class_name for idx, class_name in enumerate(classes)}
print("Label mapping:", label_mapping)
# Out:
# Label mapping: {0: 'cond7_all', 1: 'sd', 2: 'ex'}

# %%
for anchor,label,path in loader_labeled:
    print(anchor.shape, label.shape, anchor.dtype)
    print(label)
    print(path)
    break
# Out:
# torch.Size([16, 3, 96, 96]) torch.Size([16]) torch.float32
# tensor([0, 0, 2, 0, 0, 0, 0, 0, 0, 0, 0, 2, 0, 2, 0, 2])
# ['G:\\classification\\cond_all\\cond7_all\\ds_1B_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C02-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g9_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G09-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g8_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E07-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g9_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D09-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g9_C08-T01.tiff']

# %%
@torch.no_grad()
def prepare_data_features(model, dataloader):
    # Prepare model
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()  # Removing projection head g(.)
    network.eval()
    network.to(device)

    # Encode all images
    feats, labels, paths = [], [], []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        print(f"Batch features shape: {batch_feats.shape}")
        print(f"Batch labels shape: {batch_labels.shape}")
        print(f"Batch labels shape: {batch_paths}")
        
        feats.append(batch_feats.detach().cpu())
        labels.append(batch_labels)
        paths.extend(batch_paths) 

    feats = torch.cat(feats, dim=0)
    labels = torch.cat(labels, dim=0)
    
    
    print(f"Features shape after concatenation: {feats.shape}")
    print(f"Labels shape after concatenation: {labels.shape}")
    print(f"Number of paths after concatenation: {len(paths)}")

    return feats, labels, paths

# %% [markdown]
# @torch.no_grad()
# def prepare_data_features(model, dataloader):
#     # Prepare model
#     network = deepcopy(model.convnet)
#     network.fc = nn.Identity()  # Removing projection head g(.)
#     network.eval()
#     network.to(device)
#
#     # Encode all images
#     feats, labels = [], []
#     for batch_imgs, batch_labels in tqdm(dataloader):
#         batch_imgs = batch_imgs.to(device)
#         batch_feats = network(batch_imgs)
#         print(f"Batch features shape: {batch_feats.shape}")
#         print(f"Batch labels shape: {batch_labels.shape}")
#
#         feats.append(batch_feats.detach().cpu())
#         labels.append(batch_labels)
#
#     feats = torch.cat(feats, dim=0)
#     labels = torch.cat(labels, dim=0)
#
#     print(f"Features shape after concatenation: {feats.shape}")
#     print(f"Labels shape after concatenation: {labels.shape}")
#
#     return torch.utils.data.TensorDataset(feats, labels)

# %%
# Extract features for train and test datasets
feats, labels, paths = prepare_data_features(simclr_model, loader_labeled)
# Out:
#   3%|▎         | 1/39 [00:04<02:33,  4.05s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT09_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g9_C09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_G08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F06-T01.tiff']
#   5%|▌         | 2/39 [00:07<02:20,  3.79s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_41_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_F10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E02-T01.tiff']
#   8%|▊         | 3/39 [00:10<02:00,  3.35s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\sd_04_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E06-T01.tiff']
#  10%|█         | 4/39 [00:13<01:56,  3.33s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_52_G08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G02-T01.tiff']
#  13%|█▎        | 5/39 [00:16<01:48,  3.20s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_52_B04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_E11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G06-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_C09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C04-T01.tiff']
#  15%|█▌        | 6/39 [00:20<01:53,  3.45s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\sd_04_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D11-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g3_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E11-T01.tiff']
#  18%|█▊        | 7/39 [00:25<02:01,  3.79s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT04_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D04-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds1B_g9_C8.tif', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_G08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_D09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_B11-T01.tiff']
#  21%|██        | 8/39 [00:28<01:48,  3.49s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_51_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E03-T01.tiff']
#  23%|██▎       | 9/39 [00:30<01:39,  3.32s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\ex\\ds61_g6_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G03-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g8_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G05-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g9_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_C09-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g8_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B11-T01.tiff']
#  26%|██▌       | 10/39 [00:33<01:32,  3.19s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT10_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F04-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_F11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B09-T01.tiff']
#  28%|██▊       | 11/39 [00:37<01:36,  3.46s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_1B_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C06-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D04-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B07-T01.tiff']
#  31%|███       | 12/39 [00:42<01:41,  3.76s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT09_E11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds41_g9_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_F08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_D10-T01.tiff']
#  33%|███▎      | 13/39 [00:45<01:34,  3.62s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_51_C06-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g6_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B03-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_G09-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g9_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G02-T01.tiff']
#  36%|███▌      | 14/39 [00:50<01:36,  3.86s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_52_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g8_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D06-T01.tiff']
#  38%|███▊      | 15/39 [00:53<01:28,  3.70s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\ex\\ds1B_g9_c10.tif', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E06-T01.tiff']
#  41%|████      | 16/39 [00:58<01:32,  4.04s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\sd_04_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D03-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds41_g3_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G11-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g8_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E04-T01.tiff']
#  44%|████▎     | 17/39 [01:01<01:23,  3.81s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT04_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E10-T01.tiff']
#  46%|████▌     | 18/39 [01:05<01:23,  3.98s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_51_B05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D08-T01.tiff']
#  49%|████▊     | 19/39 [01:09<01:17,  3.90s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_62_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_B11-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds41_g3_C02-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds1B_g9_C11.tif', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B07-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g8_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C08-T01.tiff']
#  51%|█████▏    | 20/39 [01:14<01:19,  4.21s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT09_C07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F11-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g6_F05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_B08-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g9_C11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_C08-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g9_C11-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g3_C04-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g8_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D03-T01.tiff']
#  54%|█████▍    | 21/39 [01:18<01:12,  4.03s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_51_G09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_C10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds41_g3_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G11-T01.tiff']
#  56%|█████▋    | 22/39 [01:22<01:10,  4.15s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_42_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G08-T01.tiff']
#  59%|█████▉    | 23/39 [01:26<01:05,  4.11s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_52_B03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_B07-T01.tiff']
#  62%|██████▏   | 24/39 [01:31<01:04,  4.30s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_42_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G03-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds41_g3_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_B03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B05-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds41_g3_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G02-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds1B_g9_C9.tif', 'G:\\classification\\cond_all\\ex\\ds61_g3_C03-T01.tiff']
#  64%|██████▍   | 25/39 [01:35<00:58,  4.21s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT04_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G07-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds1B_g9_C7.tif', 'G:\\classification\\cond_all\\cond7_all\\sd_04_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D05-T01.tiff']
#  67%|██████▋   | 26/39 [01:39<00:53,  4.15s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_42_D03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F08-T01.tiff']
#  69%|██████▉   | 27/39 [01:43<00:49,  4.09s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_51_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C05-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g9_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_G10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C03-T01.tiff']
#  72%|███████▏  | 28/39 [01:46<00:41,  3.75s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_42_D04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B02-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g3_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_G10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D11-T01.tiff']
#  74%|███████▍  | 29/39 [01:50<00:39,  3.94s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_51_G03-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g9_C09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F06-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F03-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g6_F04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_C08-T01.tiff']
#  77%|███████▋  | 30/39 [01:55<00:37,  4.21s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_61_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C11-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g9_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_F11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D08-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g8_B10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_E08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_C10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G09-T01.tiff']
#  79%|███████▉  | 31/39 [01:59<00:33,  4.17s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_42_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_G09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_G07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_B09-T01.tiff']
#  82%|████████▏ | 32/39 [02:03<00:29,  4.23s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\ex\\ds61_g8_B09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_C10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_E11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C02-T01.tiff']
#  85%|████████▍ | 33/39 [02:08<00:26,  4.38s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\sd_04_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_F04-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_E08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_G09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_G10-T01.tiff']
#  87%|████████▋ | 34/39 [02:13<00:23,  4.66s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_61_G06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_C07-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g9_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_B06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_B10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_E05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D07-T01.tiff']
#  90%|████████▉ | 35/39 [02:19<00:19,  4.83s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_41_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_B08-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds62_g9_C07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_G02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_E11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_C07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_E04-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_G09-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g8_B08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_C10-T01.tiff']
#  92%|█████████▏| 36/39 [02:23<00:14,  4.71s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_61_F10-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g6_F03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_C02-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_G08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_D03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_E03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_D10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_C03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_G06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_C08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_G10-T01.tiff']
#  95%|█████████▍| 37/39 [02:29<00:10,  5.16s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT10_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_E09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_B05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_D07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_1B_C04-T01.tiff', 'G:\\classification\\cond_all\\ex\\ds61_g3_C06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_F07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_C11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G06-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_C07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F08-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_G10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_61_G05-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_B10-T01.tiff']
#  97%|█████████▋| 38/39 [02:34<00:05,  5.04s/it]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['G:\\classification\\cond_all\\cond7_all\\ds_52_G02-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_D09-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_E07-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_B10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT10_G11-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_G10-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT04_E10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_42_E07-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_G10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_62_D05-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_D09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_F09-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D03-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_F10-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_51_F09-T01.tiff']
# 100%|██████████| 39/39 [02:37<00:00,  4.03s/it]
# Batch features shape: torch.Size([7, 512])
# Batch labels shape: torch.Size([7])
# Batch labels shape: ['G:\\classification\\cond_all\\sd\\RBT10_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\sd_04_B08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_D06-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_41_B11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT14_C11-T01.tiff', 'G:\\classification\\cond_all\\sd\\RBT09_D08-T01.tiff', 'G:\\classification\\cond_all\\cond7_all\\ds_52_E03-T01.tiff']
# Features shape after concatenation: torch.Size([615, 512])
# Labels shape after concatenation: torch.Size([615])
# Number of paths after concatenation: 615

# %%
import umap
import matplotlib.pyplot as plt
import numpy as np

# Assuming feats is a tensor of shape (N, feature_size), where N is the number of samples and feature_size is the dimensionality of the features
# You can reduce the dimensionality of feats with UMAP

# Convert feats to numpy array
feats_np = feats.detach().cpu().numpy()

# 2D UMAP projection
umap_2d = umap.UMAP(n_components=2, random_state=42)
feats_2d = umap_2d.fit_transform(feats_np)

# 1D UMAP projection
umap_1d = umap.UMAP(n_components=1, random_state=42)
feats_1d = umap_1d.fit_transform(feats_np)

# Plot 2D UMAP
plt.figure(figsize=(10, 6))
plt.scatter(feats_2d[:, 0], feats_2d[:, 1], c=labels, cmap='viridis', edgecolors='k', s=50)
plt.colorbar(label='Class Label')
plt.title('2D UMAP projection of features')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()

# Plot 1D UMAP
plt.figure(figsize=(10, 6))
plt.scatter(feats_1d, np.zeros_like(feats_1d), c=labels, cmap='viridis', edgecolors='k', s=50)
plt.colorbar(label='Class Label')
plt.title('1D UMAP projection of features')
plt.xlabel('UMAP 1D')
plt.yticks([])  # Hide the y-axis ticks since it's all zeros
plt.show()
# Out:
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE
import seaborn as sns

# Perform t-SNE
perplexity = 30  # You can tune this parameter
n_iter = 1000  # Number of iterations for optimization

# Convert features to NumPy array if they are in tensor form
feats_np = feats.numpy() if isinstance(feats, torch.Tensor) else feats
labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else labels

# Apply t-SNE
print("Running t-SNE...")
tsne = TSNE(n_components=2, perplexity=perplexity, n_iter=n_iter, random_state=42)
feats_2d = tsne.fit_transform(feats_np)

# Create a scatter plot
plt.figure(figsize=(10, 8))
sns.scatterplot(x=feats_2d[:, 0], y=feats_2d[:, 1], hue=labels_np, palette="deep", alpha=0.7, edgecolors='k')
plt.title("2D t-SNE Visualization of Features")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.legend(title="Class", loc='best')
plt.grid(True)
plt.show()
# Out:
# Running t-SNE...
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE
import seaborn as sns

# Perform t-SNE
perplexity = 30  # You can tune this parameter
n_iter = 1000  # Number of iterations for optimization

# Convert features to NumPy array if they are in tensor form
feats_np = feats.numpy() if isinstance(feats, torch.Tensor) else feats
labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else labels

# Apply t-SNE
print("Running t-SNE...")
tsne = TSNE(n_components=2, perplexity=perplexity, n_iter=n_iter, random_state=42)
feats_2d = tsne.fit_transform(feats_np)

# Define colors for the different classes
num_classes = len(np.unique(labels_np))
colors = plt.cm.rainbow(np.linspace(0, 1, num_classes))

# Create a scatter plot
plt.figure(figsize=(10, 8))
for i, color in zip(np.unique(labels_np), colors):
    plt.scatter(feats_2d[labels_np == i, 0], feats_2d[labels_np == i, 1], label=f'Class {i}', color=color, alpha=0.7, edgecolors='k')

plt.title("2D t-SNE Visualization of Features")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.legend(title="Class", loc='best')
plt.grid(True)
plt.show()
# Out:
# Running t-SNE...
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE

# Perform t-SNE
perplexity = 30  # Tune as needed
n_iter = 1000  # Number of optimization iterations

# Convert features to NumPy array if they are in tensor form
feats_np = feats.numpy() if isinstance(feats, torch.Tensor) else feats
labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else labels

# Apply 1D t-SNE
print("Running 1D t-SNE...")
tsne = TSNE(n_components=1, perplexity=perplexity, n_iter=n_iter, random_state=42)
feats_1d = tsne.fit_transform(feats_np).flatten()  # Flatten to make it a 1D array

# Define colors for the different classes
num_classes = len(np.unique(labels_np))
colors = plt.cm.rainbow(np.linspace(0, 1, num_classes))

# Create a scatter plot in 1D
plt.figure(figsize=(12, 4))
for i, color in zip(np.unique(labels_np), colors):
    plt.scatter(feats_1d[labels_np == i], np.zeros_like(feats_1d[labels_np == i]), 
                label=f'Class {i}', color=color, alpha=0.7, edgecolors='k')

plt.title("1D t-SNE Visualization of Features")
plt.xlabel("t-SNE Component 1")
plt.yticks([])  # Remove y-axis ticks for clarity
plt.legend(title="Class", loc='best')
plt.grid(axis='x')
plt.show()
# Out:
# Running 1D t-SNE...
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE

# Perform t-SNE
perplexity = 30  # Tune as needed
n_iter = 1000  # Number of optimization iterations

# Convert features to NumPy array if they are in tensor form
feats_np = feats.numpy() if isinstance(feats, torch.Tensor) else feats
labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else labels

# Apply 1D t-SNE
print("Running 1D t-SNE...")
tsne = TSNE(n_components=1, perplexity=perplexity, n_iter=n_iter, random_state=42)
feats_1d = tsne.fit_transform(feats_np).flatten()  # Flatten to 1D array

# Sort paths and scores in ascending order of t-SNE scores
sorted_indices = np.argsort(feats_1d)  # Get indices that would sort the scores
sorted_paths = np.array(paths)[sorted_indices]
sorted_scores = feats_1d[sorted_indices]

# Print sorted paths with corresponding t-SNE scores
print("\nPaths and t-SNE Scores (Ascending Order):")
for path, score in zip(sorted_paths, sorted_scores):
    print(f"{path}: {score:.4f}")

# Define colors for the different classes
num_classes = len(np.unique(labels_np))
colors = plt.cm.rainbow(np.linspace(0, 1, num_classes))

# Create a scatter plot in 1D
plt.figure(figsize=(12, 4))
for i, color in zip(np.unique(labels_np), colors):
    plt.scatter(sorted_scores[labels_np[sorted_indices] == i], 
                np.zeros_like(sorted_scores[labels_np[sorted_indices] == i]), 
                label=f'Class {i}', color=color, alpha=0.7, edgecolors='k')

plt.title("1D t-SNE Visualization of Features (Sorted)")
plt.xlabel("t-SNE Component 1")
plt.yticks([])  # Remove y-axis ticks for clarity
plt.legend(title="Class", loc='best')
plt.grid(axis='x')
plt.show()
# Out:
# Running 1D t-SNE...
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Paths and t-SNE Scores (Ascending Order):
# G:\classification\cond_all\sd\RBT14_C09-T01.tiff: -26.6371
# G:\classification\cond_all\sd\RBT09_B09-T01.tiff: -26.6249
# G:\classification\cond_all\sd\RBT09_D11-T01.tiff: -26.6056
# G:\classification\cond_all\sd\ds41_g5_E05-T01.tiff: -26.5780
# G:\classification\cond_all\sd\RBT09_E07-T01.tiff: -26.5095
# G:\classification\cond_all\sd\RBT09_D09-T01.tiff: -26.4762
# G:\classification\cond_all\sd\RBT09_C07-T01.tiff: -26.4194
# G:\classification\cond_all\sd\ds42_g5_E03-T01.tiff: -26.3608
# G:\classification\cond_all\sd\RBT09_B10-T01.tiff: -26.2723
# G:\classification\cond_all\sd\RBT09_E09-T01.tiff: -25.8097
# G:\classification\cond_all\sd\ds41_g5_E04-T01.tiff: -25.6992
# G:\classification\cond_all\sd\RBT04_F07-T01.tiff: -25.6432
# G:\classification\cond_all\sd\ds42_g5_E05-T01.tiff: -25.6055
# G:\classification\cond_all\sd\RBT14_C10-T01.tiff: -25.4507
# G:\classification\cond_all\sd\RBT10_F07-T01.tiff: -25.3716
# G:\classification\cond_all\sd\RBT14_B08-T01.tiff: -25.3099
# G:\classification\cond_all\sd\RBT14_D07-T01.tiff: -25.2407
# G:\classification\cond_all\sd\RBT14_D09-T01.tiff: -25.2198
# G:\classification\cond_all\sd\RBT14_D10-T01.tiff: -25.0966
# G:\classification\cond_all\sd\RBT14_B10-T01.tiff: -25.0662
# G:\classification\cond_all\sd\RBT04_E07-T01.tiff: -24.8677
# G:\classification\cond_all\sd\RBT04_C10-T01.tiff: -24.6906
# G:\classification\cond_all\sd\RBT04_C09-T01.tiff: -24.5484
# G:\classification\cond_all\sd\RBT04_B08-T01.tiff: -24.5429
# G:\classification\cond_all\sd\ds41_g2_B04-T01.tiff: -24.5175
# G:\classification\cond_all\sd\RBT04_B11-T01.tiff: -24.4944
# G:\classification\cond_all\sd\RBT04_G09-T01.tiff: -24.4865
# G:\classification\cond_all\sd\RBT04_D10-T01.tiff: -24.4837
# G:\classification\cond_all\sd\RBT14_C11-T01.tiff: -24.4570
# G:\classification\cond_all\sd\RBT14_D11-T01.tiff: -24.3909
# G:\classification\cond_all\sd\RBT04_G11-T01.tiff: -24.3327
# G:\classification\cond_all\sd\RBT04_E08-T01.tiff: -24.0586
# G:\classification\cond_all\sd\RBT09_G09-T01.tiff: -23.9658
# G:\classification\cond_all\sd\ds42_g5_E02-T01.tiff: -23.8301
# G:\classification\cond_all\sd\ds42_g5_E04-T01.tiff: -23.7991
# G:\classification\cond_all\sd\RBT04_B10-T01.tiff: -23.7899
# G:\classification\cond_all\sd\RBT09_G11-T01.tiff: -23.7098
# G:\classification\cond_all\sd\ds41_g2_B03-T01.tiff: -23.6709
# G:\classification\cond_all\sd\RBT04_E09-T01.tiff: -23.6067
# G:\classification\cond_all\sd\RBT10_D10-T01.tiff: -23.4771
# G:\classification\cond_all\sd\RBT04_B09-T01.tiff: -23.3519
# G:\classification\cond_all\sd\RBT04_C08-T01.tiff: -23.1855
# G:\classification\cond_all\sd\RBT10_C08-T01.tiff: -23.0307
# G:\classification\cond_all\sd\RBT10_B11-T01.tiff: -23.0072
# G:\classification\cond_all\sd\RBT10_C09-T01.tiff: -22.9669
# G:\classification\cond_all\sd\RBT10_E09-T01.tiff: -22.9005
# G:\classification\cond_all\sd\RBT10_D07-T01.tiff: -22.8080
# G:\classification\cond_all\sd\RBT10_B09-T01.tiff: -22.6305
# G:\classification\cond_all\sd\RBT10_B08-T01.tiff: -22.5183
# G:\classification\cond_all\sd\RBT04_G07-T01.tiff: -22.4816
# G:\classification\cond_all\sd\RBT09_D07-T01.tiff: -22.4211
# G:\classification\cond_all\sd\ds41_g2_B06-T01.tiff: -22.3987
# G:\classification\cond_all\sd\RBT14_C07-T01.tiff: -22.2832
# G:\classification\cond_all\sd\RBT04_G10-T01.tiff: -22.2279
# G:\classification\cond_all\sd\RBT09_E10-T01.tiff: -22.1890
# G:\classification\cond_all\sd\RBT14_B07-T01.tiff: -22.1602
# G:\classification\cond_all\sd\RBT10_B07-T01.tiff: -22.0051
# G:\classification\cond_all\sd\ds42_g2_B04-T01.tiff: -22.0034
# G:\classification\cond_all\sd\RBT10_G09-T01.tiff: -21.8388
# G:\classification\cond_all\sd\RBT04_D07-T01.tiff: -21.7821
# G:\classification\cond_all\sd\RBT04_F10-T01.tiff: -21.5956
# G:\classification\cond_all\sd\ds42_g2_B03-T01.tiff: -21.5667
# G:\classification\cond_all\sd\ds42_g2_B05-T01.tiff: -21.5660
# G:\classification\cond_all\sd\RBT09_C09-T01.tiff: -21.5465
# G:\classification\cond_all\sd\RBT04_D08-T01.tiff: -21.5331
# G:\classification\cond_all\sd\RBT04_C07-T01.tiff: -21.4462
# G:\classification\cond_all\sd\ds42_g2_B06-T01.tiff: -21.3637
# G:\classification\cond_all\sd\RBT04_F08-T01.tiff: -21.3616
# G:\classification\cond_all\sd\RBT04_F09-T01.tiff: -21.3461
# G:\classification\cond_all\sd\RBT04_B07-T01.tiff: -21.2594
# G:\classification\cond_all\sd\ds1b_g5_E2.tif: -21.1829
# G:\classification\cond_all\sd\RBT04_F11-T01.tiff: -21.1514
# G:\classification\cond_all\sd\RBT10_F08-T01.tiff: -21.1178
# G:\classification\cond_all\sd\RBT04_D11-T01.tiff: -21.1133
# G:\classification\cond_all\sd\RBT10_C07-T01.tiff: -20.9748
# G:\classification\cond_all\sd\RBT04_E10-T01.tiff: -20.8861
# G:\classification\cond_all\sd\RBT04_D09-T01.tiff: -20.8178
# G:\classification\cond_all\sd\ds42_g5_E06-T01.tiff: -20.7729
# G:\classification\cond_all\sd\RBT10_D11-T01.tiff: -20.5989
# G:\classification\cond_all\sd\RBT10_G11-T01.tiff: -20.5744
# G:\classification\cond_all\sd\RBT10_G08-T01.tiff: -20.5668
# G:\classification\cond_all\sd\RBT10_D08-T01.tiff: -20.5306
# G:\classification\cond_all\sd\RBT14_D08-T01.tiff: -20.3072
# G:\classification\cond_all\sd\RBT14_B09-T01.tiff: -20.2797
# G:\classification\cond_all\sd\RBT04_E11-T01.tiff: -20.1213
# G:\classification\cond_all\sd\RBT10_G07-T01.tiff: -20.1126
# G:\classification\cond_all\sd\RBT10_D09-T01.tiff: -20.1115
# G:\classification\cond_all\sd\RBT10_E11-T01.tiff: -20.0817
# G:\classification\cond_all\sd\RBT14_C08-T01.tiff: -20.0312
# G:\classification\cond_all\sd\RBT10_B10-T01.tiff: -20.0243
# G:\classification\cond_all\sd\RBT10_F10-T01.tiff: -19.7456
# G:\classification\cond_all\sd\RBT14_B11-T01.tiff: -19.6514
# G:\classification\cond_all\sd\RBT09_C11-T01.tiff: -19.6028
# G:\classification\cond_all\sd\ds1b_g5_E5.tif: -19.5902
# G:\classification\cond_all\sd\RBT10_F11-T01.tiff: -19.5414
# G:\classification\cond_all\sd\RBT09_E08-T01.tiff: -19.5000
# G:\classification\cond_all\sd\RBT10_G10-T01.tiff: -19.3552
# G:\classification\cond_all\sd\RBT09_F10-T01.tiff: -19.3138
# G:\classification\cond_all\sd\RBT09_E11-T01.tiff: -19.2438
# G:\classification\cond_all\sd\RBT09_C08-T01.tiff: -19.1204
# G:\classification\cond_all\sd\RBT09_D10-T01.tiff: -19.0928
# G:\classification\cond_all\sd\RBT09_B11-T01.tiff: -19.0571
# G:\classification\cond_all\sd\ds41_g5_E06-T01.tiff: -18.8993
# G:\classification\cond_all\sd\RBT09_F08-T01.tiff: -18.6860
# G:\classification\cond_all\sd\RBT10_C11-T01.tiff: -18.6793
# G:\classification\cond_all\sd\RBT10_E10-T01.tiff: -18.5534
# G:\classification\cond_all\sd\RBT09_G10-T01.tiff: -18.4338
# G:\classification\cond_all\sd\RBT09_G07-T01.tiff: -18.4114
# G:\classification\cond_all\sd\RBT09_F11-T01.tiff: -18.3523
# G:\classification\cond_all\sd\RBT10_C10-T01.tiff: -18.3405
# G:\classification\cond_all\sd\RBT09_D08-T01.tiff: -18.3307
# G:\classification\cond_all\sd\ds1b_g5_E4.tif: -18.2695
# G:\classification\cond_all\sd\RBT09_B07-T01.tiff: -18.2514
# G:\classification\cond_all\sd\RBT09_F09-T01.tiff: -18.1952
# G:\classification\cond_all\sd\RBT09_G08-T01.tiff: -18.1244
# G:\classification\cond_all\sd\RBT09_F07-T01.tiff: -18.0977
# G:\classification\cond_all\sd\RBT10_F09-T01.tiff: -18.0624
# G:\classification\cond_all\sd\RBT09_B08-T01.tiff: -17.7902
# G:\classification\cond_all\sd\RBT10_E07-T01.tiff: -17.6124
# G:\classification\cond_all\sd\RBT04_G08-T01.tiff: -17.5513
# G:\classification\cond_all\sd\RBT09_C10-T01.tiff: -17.3887
# G:\classification\cond_all\sd\ds62_g2_B03-T01.tiff: -17.1350
# G:\classification\cond_all\sd\ds62_g2_B02-T01.tiff: -17.1240
# G:\classification\cond_all\sd\ds62_g2_B04-T01.tiff: -17.0997
# G:\classification\cond_all\sd\ds1b_g5_E3.tif: -16.7691
# G:\classification\cond_all\ex\ds1B_g9_C11.tif: -15.2242
# G:\classification\cond_all\ex\ds1B_g9_C8.tif: -15.1985
# G:\classification\cond_all\ex\ds1B_g9_C7.tif: -15.1360
# G:\classification\cond_all\ex\ds1B_g9_c10.tif: -15.0726
# G:\classification\cond_all\ex\ds1B_g9_C9.tif: -15.0054
# G:\classification\cond_all\ex\ds41_g3_C04-T01.tiff: -14.8974
# G:\classification\cond_all\ex\ds41_g3_C02-T01.tiff: -14.7541
# G:\classification\cond_all\ex\ds41_g3_C03-T01.tiff: -14.5622
# G:\classification\cond_all\ex\ds41_g3_C05-T01.tiff: -14.5054
# G:\classification\cond_all\ex\ds41_g3_C06-T01.tiff: -14.4200
# G:\classification\cond_all\ex\ds61_g8_B07-T01.tiff: -14.3250
# G:\classification\cond_all\ex\ds61_g8_B11-T01.tiff: -14.3041
# G:\classification\cond_all\ex\ds61_g6_F04-T01.tiff: -14.0791
# G:\classification\cond_all\ex\ds61_g9_C11-T01.tiff: -14.0306
# G:\classification\cond_all\ex\ds61_g3_C05-T01.tiff: -13.9309
# G:\classification\cond_all\ex\ds61_g3_C04-T01.tiff: -13.9224
# G:\classification\cond_all\ex\ds61_g3_C06-T01.tiff: -13.9173
# G:\classification\cond_all\ex\ds61_g9_C08-T01.tiff: -13.9037
# G:\classification\cond_all\ex\ds61_g8_B08-T01.tiff: -13.8123
# G:\classification\cond_all\ex\ds61_g6_F06-T01.tiff: -13.7836
# G:\classification\cond_all\ex\ds61_g9_C07-T01.tiff: -13.7760
# G:\classification\cond_all\ex\ds61_g9_C09-T01.tiff: -13.7005
# G:\classification\cond_all\ex\ds61_g6_F03-T01.tiff: -13.6311
# G:\classification\cond_all\ex\ds61_g3_C02-T01.tiff: -13.6289
# G:\classification\cond_all\ex\ds61_g6_F02-T01.tiff: -13.6079
# G:\classification\cond_all\ex\ds61_g6_F05-T01.tiff: -13.4389
# G:\classification\cond_all\ex\ds61_g8_B10-T01.tiff: -13.4053
# G:\classification\cond_all\ex\ds61_g3_C03-T01.tiff: -13.3726
# G:\classification\cond_all\ex\ds62_g8_B10-T01.tiff: -13.3720
# G:\classification\cond_all\ex\ds61_g9_C10-T01.tiff: -12.9591
# G:\classification\cond_all\ex\ds62_g8_B11-T01.tiff: -12.9205
# G:\classification\cond_all\ex\ds61_g8_B09-T01.tiff: -12.7417
# G:\classification\cond_all\ex\ds62_g8_B09-T01.tiff: -12.5433
# G:\classification\cond_all\ex\ds62_g9_C08-T01.tiff: -12.4337
# G:\classification\cond_all\ex\ds62_g9_C11-T01.tiff: -12.2627
# G:\classification\cond_all\ex\ds62_g9_C07-T01.tiff: -12.0524
# G:\classification\cond_all\ex\ds62_g9_C10-T01.tiff: -12.0405
# G:\classification\cond_all\ex\ds62_g8_B07-T01.tiff: -11.9514
# G:\classification\cond_all\ex\ds62_g9_C09-T01.tiff: -11.9464
# G:\classification\cond_all\ex\ds41_g9_C10-T01.tiff: -11.8364
# G:\classification\cond_all\cond7_all\ds_62_B10-T01.tiff: -10.8663
# G:\classification\cond_all\cond7_all\ds_62_B08-T01.tiff: -10.5825
# G:\classification\cond_all\cond7_all\ds_61_E02-T01.tiff: -10.3865
# G:\classification\cond_all\cond7_all\ds_62_G03-T01.tiff: -10.3746
# G:\classification\cond_all\cond7_all\ds_61_B10-T01.tiff: -10.2962
# G:\classification\cond_all\cond7_all\ds_61_F02-T01.tiff: -10.2111
# G:\classification\cond_all\cond7_all\ds_62_C07-T01.tiff: -10.1877
# G:\classification\cond_all\cond7_all\ds_62_B11-T01.tiff: -10.1460
# G:\classification\cond_all\cond7_all\ds_61_C03-T01.tiff: -10.0928
# G:\classification\cond_all\cond7_all\ds_62_G09-T01.tiff: -10.0209
# G:\classification\cond_all\cond7_all\ds_61_G04-T01.tiff: -9.6950
# G:\classification\cond_all\cond7_all\ds_61_G10-T01.tiff: -9.4554
# G:\classification\cond_all\cond7_all\ds_61_D02-T01.tiff: -9.4050
# G:\classification\cond_all\cond7_all\ds_61_B03-T01.tiff: -9.3656
# G:\classification\cond_all\cond7_all\ds_62_C10-T01.tiff: -9.2761
# G:\classification\cond_all\cond7_all\ds_61_G03-T01.tiff: -9.1478
# G:\classification\cond_all\cond7_all\ds_62_C11-T01.tiff: -9.1272
# G:\classification\cond_all\cond7_all\ds_61_C02-T01.tiff: -8.9901
# G:\classification\cond_all\cond7_all\ds_62_G07-T01.tiff: -8.9676
# G:\classification\cond_all\cond7_all\ds_62_E09-T01.tiff: -8.9209
# G:\classification\cond_all\cond7_all\ds_61_F10-T01.tiff: -8.8574
# G:\classification\cond_all\cond7_all\ds_61_E06-T01.tiff: -8.8054
# G:\classification\cond_all\cond7_all\ds_61_B05-T01.tiff: -8.7820
# G:\classification\cond_all\cond7_all\ds_61_E03-T01.tiff: -8.6064
# G:\classification\cond_all\cond7_all\ds_62_D10-T01.tiff: -8.5583
# G:\classification\cond_all\cond7_all\ds_62_C09-T01.tiff: -8.3889
# G:\classification\cond_all\cond7_all\ds_62_D09-T01.tiff: -8.3694
# G:\classification\cond_all\cond7_all\ds_61_D06-T01.tiff: -8.2814
# G:\classification\cond_all\cond7_all\ds_61_F07-T01.tiff: -8.2245
# G:\classification\cond_all\cond7_all\ds_62_F10-T01.tiff: -8.1411
# G:\classification\cond_all\cond7_all\ds_61_B06-T01.tiff: -8.0608
# G:\classification\cond_all\cond7_all\ds_61_C10-T01.tiff: -8.0188
# G:\classification\cond_all\cond7_all\ds_62_E11-T01.tiff: -8.0057
# G:\classification\cond_all\cond7_all\ds_61_G09-T01.tiff: -7.9609
# G:\classification\cond_all\cond7_all\ds_61_G06-T01.tiff: -7.9070
# G:\classification\cond_all\cond7_all\ds_52_E07-T01.tiff: -7.7172
# G:\classification\cond_all\cond7_all\ds_61_C07-T01.tiff: -7.6081
# G:\classification\cond_all\cond7_all\ds_61_F11-T01.tiff: -7.4984
# G:\classification\cond_all\cond7_all\ds_52_E05-T01.tiff: -7.4953
# G:\classification\cond_all\cond7_all\ds_61_D05-T01.tiff: -7.4936
# G:\classification\cond_all\cond7_all\ds_61_F06-T01.tiff: -7.4877
# G:\classification\cond_all\cond7_all\ds_62_G10-T01.tiff: -7.4821
# G:\classification\cond_all\cond7_all\ds_61_E10-T01.tiff: -7.4057
# G:\classification\cond_all\cond7_all\ds_61_C09-T01.tiff: -7.3973
# G:\classification\cond_all\cond7_all\ds_61_E11-T01.tiff: -6.9606
# G:\classification\cond_all\cond7_all\ds_62_E07-T01.tiff: -6.8768
# G:\classification\cond_all\cond7_all\ds_62_F08-T01.tiff: -6.8592
# G:\classification\cond_all\cond7_all\ds_62_E08-T01.tiff: -6.8004
# G:\classification\cond_all\cond7_all\ds_61_D11-T01.tiff: -6.6634
# G:\classification\cond_all\cond7_all\ds_41_C07-T01.tiff: -6.6278
# G:\classification\cond_all\cond7_all\ds_41_C09-T01.tiff: -6.5878
# G:\classification\cond_all\cond7_all\ds_61_B02-T01.tiff: -6.5804
# G:\classification\cond_all\cond7_all\ds_41_B07-T01.tiff: -6.5483
# G:\classification\cond_all\cond7_all\ds_61_C05-T01.tiff: -6.3524
# G:\classification\cond_all\cond7_all\ds_62_F09-T01.tiff: -6.3397
# G:\classification\cond_all\cond7_all\ds_61_C11-T01.tiff: -6.1331
# G:\classification\cond_all\cond7_all\ds_61_E07-T01.tiff: -6.0885
# G:\classification\cond_all\cond7_all\ds_61_C04-T01.tiff: -6.0689
# G:\classification\cond_all\cond7_all\ds_61_D10-T01.tiff: -6.0346
# G:\classification\cond_all\cond7_all\ds_61_G08-T01.tiff: -5.9046
# G:\classification\cond_all\cond7_all\ds_62_F07-T01.tiff: -5.7936
# G:\classification\cond_all\cond7_all\ds_61_F05-T01.tiff: -5.7500
# G:\classification\cond_all\cond7_all\ds_62_G08-T01.tiff: -5.7250
# G:\classification\cond_all\cond7_all\ds_61_E04-T01.tiff: -5.6803
# G:\classification\cond_all\cond7_all\ds_62_G06-T01.tiff: -5.6695
# G:\classification\cond_all\cond7_all\ds_61_E05-T01.tiff: -5.6472
# G:\classification\cond_all\cond7_all\ds_61_F09-T01.tiff: -5.6031
# G:\classification\cond_all\cond7_all\ds_52_G07-T01.tiff: -5.5467
# G:\classification\cond_all\cond7_all\ds_61_D09-T01.tiff: -5.4262
# G:\classification\cond_all\cond7_all\ds_61_G05-T01.tiff: -5.4038
# G:\classification\cond_all\cond7_all\ds_62_F11-T01.tiff: -5.2323
# G:\classification\cond_all\cond7_all\ds_62_G11-T01.tiff: -4.9858
# G:\classification\cond_all\cond7_all\ds_61_B11-T01.tiff: -4.9678
# G:\classification\cond_all\cond7_all\ds_61_G07-T01.tiff: -4.7878
# G:\classification\cond_all\cond7_all\ds_52_C04-T01.tiff: -4.7630
# G:\classification\cond_all\cond7_all\ds_52_F07-T01.tiff: -4.7493
# G:\classification\cond_all\cond7_all\ds_52_G02-T01.tiff: -4.6747
# G:\classification\cond_all\cond7_all\ds_52_B02-T01.tiff: -4.5948
# G:\classification\cond_all\cond7_all\ds_52_G08-T01.tiff: -4.5698
# G:\classification\cond_all\cond7_all\ds_41_F03-T01.tiff: -4.4126
# G:\classification\cond_all\cond7_all\ds_61_D03-T01.tiff: -4.3454
# G:\classification\cond_all\cond7_all\ds_61_F04-T01.tiff: -4.2055
# G:\classification\cond_all\cond7_all\ds_52_F06-T01.tiff: -4.1493
# G:\classification\cond_all\cond7_all\ds_51_G07-T01.tiff: -3.9997
# G:\classification\cond_all\cond7_all\ds_52_F03-T01.tiff: -3.9788
# G:\classification\cond_all\cond7_all\ds_62_F04-T01.tiff: -3.9060
# G:\classification\cond_all\cond7_all\ds_52_B09-T01.tiff: -3.6548
# G:\classification\cond_all\cond7_all\ds_52_C07-T01.tiff: -3.4850
# G:\classification\cond_all\cond7_all\ds_52_E08-T01.tiff: -3.4719
# G:\classification\cond_all\cond7_all\ds_62_D08-T01.tiff: -3.3393
# G:\classification\cond_all\cond7_all\ds_52_B07-T01.tiff: -3.2587
# G:\classification\cond_all\cond7_all\ds_52_G10-T01.tiff: -3.2130
# G:\classification\cond_all\cond7_all\ds_62_D05-T01.tiff: -3.1491
# G:\classification\cond_all\cond7_all\ds_51_G08-T01.tiff: -3.0863
# G:\classification\cond_all\cond7_all\ds_52_G11-T01.tiff: -3.0832
# G:\classification\cond_all\cond7_all\ds_51_G05-T01.tiff: -2.9971
# G:\classification\cond_all\cond7_all\ds_51_F09-T01.tiff: -2.9388
# G:\classification\cond_all\cond7_all\ds_62_D03-T01.tiff: -2.9286
# G:\classification\cond_all\cond7_all\ds_52_B11-T01.tiff: -2.8676
# G:\classification\cond_all\cond7_all\ds_51_C09-T01.tiff: -2.6990
# G:\classification\cond_all\cond7_all\ds_51_F07-T01.tiff: -2.6186
# G:\classification\cond_all\cond7_all\ds_52_B03-T01.tiff: -2.6142
# G:\classification\cond_all\cond7_all\ds_51_G03-T01.tiff: -2.4561
# G:\classification\cond_all\cond7_all\ds_51_B03-T01.tiff: -2.4456
# G:\classification\cond_all\cond7_all\ds_51_C07-T01.tiff: -2.2853
# G:\classification\cond_all\cond7_all\ds_51_D11-T01.tiff: -2.2760
# G:\classification\cond_all\cond7_all\ds_62_B06-T01.tiff: -2.1546
# G:\classification\cond_all\cond7_all\ds_62_D02-T01.tiff: -2.1407
# G:\classification\cond_all\cond7_all\ds_62_E03-T01.tiff: -2.1012
# G:\classification\cond_all\cond7_all\ds_51_G04-T01.tiff: -1.7008
# G:\classification\cond_all\cond7_all\ds_62_C05-T01.tiff: -1.6985
# G:\classification\cond_all\cond7_all\ds_62_B05-T01.tiff: -1.6851
# G:\classification\cond_all\cond7_all\ds_62_B07-T01.tiff: -1.6803
# G:\classification\cond_all\cond7_all\ds_62_D04-T01.tiff: -1.6562
# G:\classification\cond_all\cond7_all\ds_51_G02-T01.tiff: -1.5990
# G:\classification\cond_all\cond7_all\ds_62_E02-T01.tiff: -1.3654
# G:\classification\cond_all\cond7_all\ds_62_C03-T01.tiff: -1.2962
# G:\classification\cond_all\cond7_all\ds_51_F04-T01.tiff: -1.2819
# G:\classification\cond_all\cond7_all\ds_52_C11-T01.tiff: -1.1362
# G:\classification\cond_all\cond7_all\ds_62_E06-T01.tiff: -0.9698
# G:\classification\cond_all\cond7_all\ds_62_E04-T01.tiff: -0.8071
# G:\classification\cond_all\cond7_all\ds_62_D06-T01.tiff: -0.7900
# G:\classification\cond_all\cond7_all\ds_62_F06-T01.tiff: -0.7819
# G:\classification\cond_all\cond7_all\ds_62_G05-T01.tiff: -0.6932
# G:\classification\cond_all\cond7_all\ds_52_C09-T01.tiff: -0.6802
# G:\classification\cond_all\cond7_all\ds_62_C04-T01.tiff: -0.6783
# G:\classification\cond_all\cond7_all\ds_52_D08-T01.tiff: -0.5911
# G:\classification\cond_all\cond7_all\ds_51_C05-T01.tiff: -0.5764
# G:\classification\cond_all\cond7_all\ds_62_B04-T01.tiff: -0.5085
# G:\classification\cond_all\cond7_all\ds_62_E05-T01.tiff: -0.4689
# G:\classification\cond_all\cond7_all\ds_52_F09-T01.tiff: -0.2227
# G:\classification\cond_all\cond7_all\ds_62_F05-T01.tiff: -0.1541
# G:\classification\cond_all\cond7_all\ds_51_D06-T01.tiff: -0.0720
# G:\classification\cond_all\cond7_all\ds_52_D10-T01.tiff: 0.0502
# G:\classification\cond_all\cond7_all\ds_51_F05-T01.tiff: 0.0621
# G:\classification\cond_all\cond7_all\ds_52_F10-T01.tiff: 0.0773
# G:\classification\cond_all\cond7_all\ds_62_G02-T01.tiff: 0.1082
# G:\classification\cond_all\cond7_all\ds_62_G04-T01.tiff: 0.1183
# G:\classification\cond_all\cond7_all\ds_51_F06-T01.tiff: 0.2257
# G:\classification\cond_all\cond7_all\ds_62_F02-T01.tiff: 0.3007
# G:\classification\cond_all\cond7_all\ds_51_E06-T01.tiff: 0.3129
# G:\classification\cond_all\cond7_all\ds_62_C02-T01.tiff: 0.4194
# G:\classification\cond_all\cond7_all\ds_51_G06-T01.tiff: 0.4976
# G:\classification\cond_all\cond7_all\ds_51_E08-T01.tiff: 0.7573
# G:\classification\cond_all\cond7_all\ds_51_E03-T01.tiff: 0.8040
# G:\classification\cond_all\cond7_all\ds_51_F03-T01.tiff: 0.8159
# G:\classification\cond_all\cond7_all\ds_51_F02-T01.tiff: 0.8422
# G:\classification\cond_all\cond7_all\ds_51_E02-T01.tiff: 0.8660
# G:\classification\cond_all\cond7_all\ds_51_E10-T01.tiff: 0.8926
# G:\classification\cond_all\cond7_all\ds_51_G10-T01.tiff: 0.9045
# G:\classification\cond_all\cond7_all\ds_51_D10-T01.tiff: 0.9938
# G:\classification\cond_all\cond7_all\ds_51_D07-T01.tiff: 1.0948
# G:\classification\cond_all\cond7_all\ds_51_C08-T01.tiff: 1.1794
# G:\classification\cond_all\cond7_all\ds_51_F08-T01.tiff: 1.2751
# G:\classification\cond_all\cond7_all\ds_51_C06-T01.tiff: 1.2777
# G:\classification\cond_all\cond7_all\ds_62_B09-T01.tiff: 1.2995
# G:\classification\cond_all\cond7_all\ds_51_B06-T01.tiff: 1.3674
# G:\classification\cond_all\cond7_all\ds_51_B05-T01.tiff: 1.4762
# G:\classification\cond_all\cond7_all\ds_62_B02-T01.tiff: 1.6535
# G:\classification\cond_all\cond7_all\ds_51_B11-T01.tiff: 1.6668
# G:\classification\cond_all\cond7_all\ds_51_B09-T01.tiff: 1.6874
# G:\classification\cond_all\cond7_all\ds_51_D02-T01.tiff: 1.8695
# G:\classification\cond_all\cond7_all\ds_51_C10-T01.tiff: 1.9108
# G:\classification\cond_all\cond7_all\ds_51_B10-T01.tiff: 1.9653
# G:\classification\cond_all\cond7_all\ds_51_D04-T01.tiff: 2.0482
# G:\classification\cond_all\cond7_all\ds_51_B08-T01.tiff: 2.0901
# G:\classification\cond_all\cond7_all\ds_51_E11-T01.tiff: 2.2735
# G:\classification\cond_all\cond7_all\ds_51_D03-T01.tiff: 2.3116
# G:\classification\cond_all\cond7_all\ds_51_G09-T01.tiff: 2.3818
# G:\classification\cond_all\cond7_all\ds_51_F10-T01.tiff: 2.4252
# G:\classification\cond_all\cond7_all\ds_51_B02-T01.tiff: 2.4661
# G:\classification\cond_all\cond7_all\ds_51_C03-T01.tiff: 2.5149
# G:\classification\cond_all\cond7_all\ds_51_C02-T01.tiff: 2.5338
# G:\classification\cond_all\cond7_all\ds_51_B07-T01.tiff: 2.6161
# G:\classification\cond_all\cond7_all\ds_51_D05-T01.tiff: 2.6743
# G:\classification\cond_all\cond7_all\ds_51_C04-T01.tiff: 2.7126
# G:\classification\cond_all\cond7_all\ds_51_D09-T01.tiff: 2.7973
# G:\classification\cond_all\cond7_all\ds_51_E04-T01.tiff: 2.8027
# G:\classification\cond_all\cond7_all\ds_62_B03-T01.tiff: 2.8614
# G:\classification\cond_all\cond7_all\ds_52_G06-T01.tiff: 2.9397
# G:\classification\cond_all\cond7_all\ds_52_D11-T01.tiff: 3.0238
# G:\classification\cond_all\cond7_all\ds_51_F11-T01.tiff: 3.0544
# G:\classification\cond_all\cond7_all\ds_52_G09-T01.tiff: 3.2108
# G:\classification\cond_all\cond7_all\ds_52_B06-T01.tiff: 3.3030
# G:\classification\cond_all\cond7_all\ds_52_D04-T01.tiff: 3.3585
# G:\classification\cond_all\cond7_all\ds_42_B06-T01.tiff: 3.4211
# G:\classification\cond_all\cond7_all\ds_51_E05-T01.tiff: 3.4545
# G:\classification\cond_all\cond7_all\ds_52_D06-T01.tiff: 3.5216
# G:\classification\cond_all\cond7_all\ds_42_D02-T01.tiff: 3.5991
# G:\classification\cond_all\cond7_all\ds_52_E09-T01.tiff: 3.6084
# G:\classification\cond_all\cond7_all\ds_62_C06-T01.tiff: 3.7975
# G:\classification\cond_all\cond7_all\ds_62_D07-T01.tiff: 3.9023
# G:\classification\cond_all\cond7_all\ds_52_C08-T01.tiff: 3.9770
# G:\classification\cond_all\cond7_all\ds_52_D07-T01.tiff: 3.9776
# G:\classification\cond_all\cond7_all\ds_52_E10-T01.tiff: 4.0033
# G:\classification\cond_all\cond7_all\ds_52_F11-T01.tiff: 4.1602
# G:\classification\cond_all\cond7_all\ds_52_F08-T01.tiff: 4.2210
# G:\classification\cond_all\cond7_all\ds_42_G10-T01.tiff: 4.2756
# G:\classification\cond_all\cond7_all\ds_52_F02-T01.tiff: 4.2840
# G:\classification\cond_all\cond7_all\ds_52_D09-T01.tiff: 4.4071
# G:\classification\cond_all\cond7_all\ds_52_B10-T01.tiff: 4.6031
# G:\classification\cond_all\cond7_all\ds_52_C02-T01.tiff: 4.8351
# G:\classification\cond_all\cond7_all\ds_51_C11-T01.tiff: 5.2107
# G:\classification\cond_all\cond7_all\ds_51_G11-T01.tiff: 5.2384
# G:\classification\cond_all\cond7_all\ds_61_C08-T01.tiff: 5.2795
# G:\classification\cond_all\cond7_all\ds_61_E09-T01.tiff: 5.3404
# G:\classification\cond_all\cond7_all\ds_52_B05-T01.tiff: 5.3963
# G:\classification\cond_all\cond7_all\ds_61_D07-T01.tiff: 5.4257
# G:\classification\cond_all\cond7_all\ds_42_F09-T01.tiff: 5.5880
# G:\classification\cond_all\cond7_all\ds_61_B07-T01.tiff: 5.6131
# G:\classification\cond_all\cond7_all\ds_41_D07-T01.tiff: 5.7171
# G:\classification\cond_all\cond7_all\ds_42_D04-T01.tiff: 5.8164
# G:\classification\cond_all\cond7_all\ds_42_F02-T01.tiff: 5.9196
# G:\classification\cond_all\cond7_all\ds_41_G02-T01.tiff: 5.9544
# G:\classification\cond_all\cond7_all\ds_41_E11-T01.tiff: 6.0514
# G:\classification\cond_all\cond7_all\ds_41_C02-T01.tiff: 6.0895
# G:\classification\cond_all\cond7_all\ds_41_B05-T01.tiff: 6.2365
# G:\classification\cond_all\cond7_all\ds_52_G04-T01.tiff: 6.3911
# G:\classification\cond_all\cond7_all\ds_41_D04-T01.tiff: 6.4733
# G:\classification\cond_all\cond7_all\ds_52_E11-T01.tiff: 6.5498
# G:\classification\cond_all\cond7_all\ds_52_E04-T01.tiff: 6.6787
# G:\classification\cond_all\cond7_all\ds_52_E03-T01.tiff: 6.6974
# G:\classification\cond_all\cond7_all\ds_41_D06-T01.tiff: 6.7017
# G:\classification\cond_all\cond7_all\ds_41_C10-T01.tiff: 6.7421
# G:\classification\cond_all\cond7_all\ds_41_C06-T01.tiff: 6.7839
# G:\classification\cond_all\cond7_all\ds_42_G05-T01.tiff: 7.0577
# G:\classification\cond_all\cond7_all\ds_52_C10-T01.tiff: 7.1513
# G:\classification\cond_all\cond7_all\ds_41_B09-T01.tiff: 7.2157
# G:\classification\cond_all\cond7_all\ds_41_D10-T01.tiff: 7.2297
# G:\classification\cond_all\cond7_all\ds_41_B08-T01.tiff: 7.3062
# G:\classification\cond_all\cond7_all\ds_52_E06-T01.tiff: 7.4181
# G:\classification\cond_all\cond7_all\ds_41_E02-T01.tiff: 7.4919
# G:\classification\cond_all\cond7_all\ds_52_D05-T01.tiff: 7.5854
# G:\classification\cond_all\cond7_all\sd_04_D11-T01.tiff: 7.7559
# G:\classification\cond_all\cond7_all\ds_41_G05-T01.tiff: 7.7773
# G:\classification\cond_all\cond7_all\ds_42_G06-T01.tiff: 7.8541
# G:\classification\cond_all\cond7_all\ds_41_G09-T01.tiff: 7.8906
# G:\classification\cond_all\cond7_all\ds_42_E06-T01.tiff: 7.9738
# G:\classification\cond_all\cond7_all\ds_41_F06-T01.tiff: 8.0256
# G:\classification\cond_all\cond7_all\ds_52_D02-T01.tiff: 8.0685
# G:\classification\cond_all\cond7_all\ds_52_C05-T01.tiff: 8.1031
# G:\classification\cond_all\cond7_all\ds_41_G10-T01.tiff: 8.1265
# G:\classification\cond_all\cond7_all\ds_52_B08-T01.tiff: 8.2440
# G:\classification\cond_all\cond7_all\ds_52_D03-T01.tiff: 8.3409
# G:\classification\cond_all\cond7_all\ds_41_C11-T01.tiff: 8.3591
# G:\classification\cond_all\cond7_all\ds_41_G06-T01.tiff: 8.3969
# G:\classification\cond_all\cond7_all\ds_41_E08-T01.tiff: 8.4007
# G:\classification\cond_all\cond7_all\ds_41_G08-T01.tiff: 8.4260
# G:\classification\cond_all\cond7_all\ds_52_C06-T01.tiff: 8.4925
# G:\classification\cond_all\cond7_all\ds_42_G09-T01.tiff: 8.5301
# G:\classification\cond_all\cond7_all\ds_41_F08-T01.tiff: 8.7444
# G:\classification\cond_all\cond7_all\ds_61_F08-T01.tiff: 8.8366
# G:\classification\cond_all\cond7_all\ds_61_E08-T01.tiff: 8.8507
# G:\classification\cond_all\cond7_all\ds_42_E04-T01.tiff: 8.8718
# G:\classification\cond_all\cond7_all\ds_42_F04-T01.tiff: 9.1737
# G:\classification\cond_all\cond7_all\ds_42_G08-T01.tiff: 9.2129
# G:\classification\cond_all\cond7_all\ds_41_F11-T01.tiff: 9.2143
# G:\classification\cond_all\cond7_all\ds_42_F10-T01.tiff: 9.3190
# G:\classification\cond_all\cond7_all\ds_41_G11-T01.tiff: 9.3541
# G:\classification\cond_all\cond7_all\ds_42_F06-T01.tiff: 9.3774
# G:\classification\cond_all\cond7_all\ds_42_F07-T01.tiff: 9.4176
# G:\classification\cond_all\cond7_all\ds_42_G11-T01.tiff: 9.5300
# G:\classification\cond_all\cond7_all\ds_41_B06-T01.tiff: 9.5527
# G:\classification\cond_all\cond7_all\ds_52_G03-T01.tiff: 9.7926
# G:\classification\cond_all\cond7_all\ds_42_F11-T01.tiff: 9.8378
# G:\classification\cond_all\cond7_all\ds_42_E11-T01.tiff: 9.9499
# G:\classification\cond_all\cond7_all\ds_41_C03-T01.tiff: 10.0691
# G:\classification\cond_all\cond7_all\ds_42_G07-T01.tiff: 10.0969
# G:\classification\cond_all\cond7_all\ds_42_F08-T01.tiff: 10.2495
# G:\classification\cond_all\cond7_all\ds_41_C04-T01.tiff: 10.2741
# G:\classification\cond_all\cond7_all\ds_42_E07-T01.tiff: 10.2814
# G:\classification\cond_all\cond7_all\ds_41_C05-T01.tiff: 10.2946
# G:\classification\cond_all\cond7_all\ds_42_E08-T01.tiff: 10.3245
# G:\classification\cond_all\cond7_all\ds_42_C04-T01.tiff: 10.3714
# G:\classification\cond_all\cond7_all\ds_42_D10-T01.tiff: 10.4569
# G:\classification\cond_all\cond7_all\ds_42_D11-T01.tiff: 10.7064
# G:\classification\cond_all\cond7_all\ds_42_E09-T01.tiff: 10.7328
# G:\classification\cond_all\cond7_all\ds_42_C03-T01.tiff: 10.8001
# G:\classification\cond_all\cond7_all\ds_42_C10-T01.tiff: 10.8551
# G:\classification\cond_all\cond7_all\ds_41_D08-T01.tiff: 10.8726
# G:\classification\cond_all\cond7_all\ds_42_C02-T01.tiff: 10.8771
# G:\classification\cond_all\cond7_all\ds_42_D09-T01.tiff: 10.9186
# G:\classification\cond_all\cond7_all\ds_51_E07-T01.tiff: 10.9753
# G:\classification\cond_all\cond7_all\ds_42_D07-T01.tiff: 11.0005
# G:\classification\cond_all\cond7_all\ds_42_B03-T01.tiff: 11.0982
# G:\classification\cond_all\cond7_all\ds_42_B10-T01.tiff: 11.1346
# G:\classification\cond_all\cond7_all\ds_61_D08-T01.tiff: 11.2524
# G:\classification\cond_all\cond7_all\ds_62_D11-T01.tiff: 11.3462
# G:\classification\cond_all\cond7_all\ds_42_B05-T01.tiff: 11.4619
# G:\classification\cond_all\cond7_all\ds_42_C09-T01.tiff: 11.5093
# G:\classification\cond_all\cond7_all\ds_41_G07-T01.tiff: 11.8190
# G:\classification\cond_all\cond7_all\ds_41_F09-T01.tiff: 11.8770
# G:\classification\cond_all\cond7_all\ds_42_E02-T01.tiff: 11.9339
# G:\classification\cond_all\cond7_all\ds_42_E05-T01.tiff: 11.9768
# G:\classification\cond_all\cond7_all\ds_41_F05-T01.tiff: 12.0823
# G:\classification\cond_all\cond7_all\ds_42_C08-T01.tiff: 12.0952
# G:\classification\cond_all\cond7_all\ds_61_C06-T01.tiff: 12.1437
# G:\classification\cond_all\cond7_all\ds_41_B11-T01.tiff: 12.1713
# G:\classification\cond_all\cond7_all\ds_41_D02-T01.tiff: 12.2363
# G:\classification\cond_all\cond7_all\ds_62_C08-T01.tiff: 12.2541
# G:\classification\cond_all\cond7_all\ds_61_D04-T01.tiff: 12.2694
# G:\classification\cond_all\cond7_all\ds_61_F03-T01.tiff: 12.3238
# G:\classification\cond_all\cond7_all\ds_61_B09-T01.tiff: 12.6844
# G:\classification\cond_all\cond7_all\ds_41_E07-T01.tiff: 12.8217
# G:\classification\cond_all\cond7_all\ds_61_G02-T01.tiff: 12.8529
# G:\classification\cond_all\cond7_all\ds_61_G11-T01.tiff: 13.0084
# G:\classification\cond_all\cond7_all\ds_52_C03-T01.tiff: 13.1163
# G:\classification\cond_all\cond7_all\ds_41_E04-T01.tiff: 13.1180
# G:\classification\cond_all\cond7_all\ds_41_C08-T01.tiff: 13.1904
# G:\classification\cond_all\cond7_all\ds_41_D09-T01.tiff: 13.3021
# G:\classification\cond_all\cond7_all\ds_42_B08-T01.tiff: 13.4869
# G:\classification\cond_all\cond7_all\ds_52_E02-T01.tiff: 13.5158
# G:\classification\cond_all\cond7_all\ds_41_F10-T01.tiff: 13.5490
# G:\classification\cond_all\cond7_all\ds_62_E10-T01.tiff: 13.9229
# G:\classification\cond_all\cond7_all\ds_41_E06-T01.tiff: 13.9885
# G:\classification\cond_all\cond7_all\sd_04_D09-T01.tiff: 14.0134
# G:\classification\cond_all\cond7_all\sd_04_E11-T01.tiff: 14.0400
# G:\classification\cond_all\cond7_all\sd_04_B09-T01.tiff: 14.0427
# G:\classification\cond_all\cond7_all\sd_04_B10-T01.tiff: 14.0589
# G:\classification\cond_all\cond7_all\sd_04_D06-T01.tiff: 14.0631
# G:\classification\cond_all\cond7_all\sd_04_C04-T01.tiff: 14.0850
# G:\classification\cond_all\cond7_all\sd_04_E10-T01.tiff: 14.1161
# G:\classification\cond_all\cond7_all\ds_41_D11-T01.tiff: 14.1753
# G:\classification\cond_all\cond7_all\ds_41_E05-T01.tiff: 14.3925
# G:\classification\cond_all\cond7_all\sd_04_C11-T01.tiff: 14.5320
# G:\classification\cond_all\cond7_all\ds_52_B04-T01.tiff: 14.6493
# G:\classification\cond_all\cond7_all\ds_41_G04-T01.tiff: 14.7177
# G:\classification\cond_all\cond7_all\sd_04_B04-T01.tiff: 14.8012
# G:\classification\cond_all\cond7_all\ds_52_F04-T01.tiff: 14.8485
# G:\classification\cond_all\cond7_all\ds_52_F05-T01.tiff: 14.8499
# G:\classification\cond_all\cond7_all\ds_41_B03-T01.tiff: 15.0270
# G:\classification\cond_all\cond7_all\sd_04_B06-T01.tiff: 15.2348
# G:\classification\cond_all\cond7_all\ds_41_E03-T01.tiff: 15.2408
# G:\classification\cond_all\cond7_all\ds_41_F07-T01.tiff: 15.4102
# G:\classification\cond_all\cond7_all\ds_41_E10-T01.tiff: 15.4307
# G:\classification\cond_all\cond7_all\sd_04_F09-T01.tiff: 15.6186
# G:\classification\cond_all\cond7_all\ds_42_G04-T01.tiff: 15.6538
# G:\classification\cond_all\cond7_all\sd_04_F11-T01.tiff: 15.7709
# G:\classification\cond_all\cond7_all\sd_04_F10-T01.tiff: 15.7719
# G:\classification\cond_all\cond7_all\ds_41_F04-T01.tiff: 15.8139
# G:\classification\cond_all\cond7_all\sd_04_G09-T01.tiff: 15.8724
# G:\classification\cond_all\cond7_all\ds_42_D06-T01.tiff: 15.8910
# G:\classification\cond_all\cond7_all\sd_04_B07-T01.tiff: 15.9925
# G:\classification\cond_all\cond7_all\sd_04_C06-T01.tiff: 16.1073
# G:\classification\cond_all\cond7_all\ds_1B_D10-T01.tiff: 16.2544
# G:\classification\cond_all\cond7_all\ds_1B_E11-T01.tiff: 16.2814
# G:\classification\cond_all\cond7_all\ds_1B_F09-T01.tiff: 16.3475
# G:\classification\cond_all\cond7_all\ds_41_F02-T01.tiff: 16.4580
# G:\classification\cond_all\cond7_all\ds_41_D03-T01.tiff: 16.4687
# G:\classification\cond_all\cond7_all\sd_04_G04-T01.tiff: 16.4885
# G:\classification\cond_all\cond7_all\ds_1B_G05-T01.tiff: 16.5336
# G:\classification\cond_all\cond7_all\ds_42_F03-T01.tiff: 16.6341
# G:\classification\cond_all\cond7_all\sd_04_G03-T01.tiff: 16.7517
# G:\classification\cond_all\cond7_all\ds_42_E03-T01.tiff: 16.8454
# G:\classification\cond_all\cond7_all\sd_04_G02-T01.tiff: 16.8837
# G:\classification\cond_all\cond7_all\sd_04_G08-T01.tiff: 16.9839
# G:\classification\cond_all\cond7_all\ds_42_G02-T01.tiff: 17.1790
# G:\classification\cond_all\cond7_all\ds_42_C05-T01.tiff: 17.2389
# G:\classification\cond_all\cond7_all\ds_42_C06-T01.tiff: 17.3201
# G:\classification\cond_all\cond7_all\sd_04_E09-T01.tiff: 17.3508
# G:\classification\cond_all\cond7_all\ds_42_C11-T01.tiff: 17.5582
# G:\classification\cond_all\cond7_all\ds_42_B09-T01.tiff: 17.5883
# G:\classification\cond_all\cond7_all\ds_42_B11-T01.tiff: 17.7618
# G:\classification\cond_all\cond7_all\ds_1B_B02-T01.tiff: 17.8337
# G:\classification\cond_all\cond7_all\ds_41_B04-T01.tiff: 17.9311
# G:\classification\cond_all\cond7_all\ds_42_B07-T01.tiff: 17.9515
# G:\classification\cond_all\cond7_all\ds_42_E10-T01.tiff: 17.9658
# G:\classification\cond_all\cond7_all\sd_04_C02-T01.tiff: 18.1997
# G:\classification\cond_all\cond7_all\ds_42_D03-T01.tiff: 18.3039
# G:\classification\cond_all\cond7_all\ds_42_B02-T01.tiff: 18.3401
# G:\classification\cond_all\cond7_all\ds_1B_B10-T01.tiff: 18.3965
# G:\classification\cond_all\cond7_all\sd_04_B11-T01.tiff: 18.4522
# G:\classification\cond_all\cond7_all\ds_42_B04-T01.tiff: 18.5692
# G:\classification\cond_all\cond7_all\sd_04_B03-T01.tiff: 18.5938
# G:\classification\cond_all\cond7_all\ds_1B_F04-T01.tiff: 18.6199
# G:\classification\cond_all\cond7_all\sd_04_C05-T01.tiff: 18.7623
# G:\classification\cond_all\cond7_all\sd_04_E06-T01.tiff: 18.8183
# G:\classification\cond_all\cond7_all\sd_04_F04-T01.tiff: 18.8939
# G:\classification\cond_all\cond7_all\sd_04_D02-T01.tiff: 18.9019
# G:\classification\cond_all\cond7_all\sd_04_E04-T01.tiff: 18.9533
# G:\classification\cond_all\cond7_all\ds_1B_G09-T01.tiff: 18.9922
# G:\classification\cond_all\cond7_all\ds_1B_E04-T01.tiff: 19.0602
# G:\classification\cond_all\cond7_all\ds_1B_F03-T01.tiff: 19.0740
# G:\classification\cond_all\cond7_all\ds_1B_C03-T01.tiff: 19.1166
# G:\classification\cond_all\cond7_all\sd_04_G05-T01.tiff: 19.1387
# G:\classification\cond_all\cond7_all\ds_1B_E07-T01.tiff: 19.2090
# G:\classification\cond_all\cond7_all\sd_04_D05-T01.tiff: 19.2230
# G:\classification\cond_all\cond7_all\ds_1B_C08-T01.tiff: 19.3964
# G:\classification\cond_all\cond7_all\ds_1B_F02-T01.tiff: 19.4137
# G:\classification\cond_all\cond7_all\ds_1B_G06-T01.tiff: 19.4523
# G:\classification\cond_all\cond7_all\ds_1B_G04-T01.tiff: 19.4652
# G:\classification\cond_all\cond7_all\sd_04_C03-T01.tiff: 19.5447
# G:\classification\cond_all\cond7_all\sd_04_B08-T01.tiff: 19.7796
# G:\classification\cond_all\cond7_all\sd_04_F03-T01.tiff: 19.8169
# G:\classification\cond_all\cond7_all\ds_51_D08-T01.tiff: 19.9916
# G:\classification\cond_all\cond7_all\ds_1B_F05-T01.tiff: 20.0884
# G:\classification\cond_all\cond7_all\ds_51_E09-T01.tiff: 20.1378
# G:\classification\cond_all\cond7_all\sd_04_C08-T01.tiff: 20.1914
# G:\classification\cond_all\cond7_all\sd_04_F06-T01.tiff: 20.3074
# G:\classification\cond_all\cond7_all\ds_1B_E06-T01.tiff: 20.3285
# G:\classification\cond_all\cond7_all\ds_1B_E02-T01.tiff: 20.3521
# G:\classification\cond_all\cond7_all\ds_41_B10-T01.tiff: 20.4293
# G:\classification\cond_all\cond7_all\ds_1B_B05-T01.tiff: 20.6933
# G:\classification\cond_all\cond7_all\ds_41_E09-T01.tiff: 20.7041
# G:\classification\cond_all\cond7_all\ds_1B_D08-T01.tiff: 20.7493
# G:\classification\cond_all\cond7_all\ds_42_D08-T01.tiff: 20.7685
# G:\classification\cond_all\cond7_all\sd_04_G11-T01.tiff: 20.7925
# G:\classification\cond_all\cond7_all\ds_42_C07-T01.tiff: 20.8769
# G:\classification\cond_all\cond7_all\ds_1B_E09-T01.tiff: 20.9016
# G:\classification\cond_all\cond7_all\ds_1B_D07-T01.tiff: 20.9567
# G:\classification\cond_all\cond7_all\sd_04_C10-T01.tiff: 21.0476
# G:\classification\cond_all\cond7_all\sd_04_D10-T01.tiff: 21.0492
# G:\classification\cond_all\cond7_all\sd_04_C09-T01.tiff: 21.0877
# G:\classification\cond_all\cond7_all\sd_04_G06-T01.tiff: 21.2636
# G:\classification\cond_all\cond7_all\ds_1B_B07-T01.tiff: 21.3031
# G:\classification\cond_all\cond7_all\ds_52_G05-T01.tiff: 21.3104
# G:\classification\cond_all\cond7_all\sd_04_D08-T01.tiff: 21.4713
# G:\classification\cond_all\cond7_all\ds_41_D05-T01.tiff: 21.5006
# G:\classification\cond_all\cond7_all\ds_1B_F11-T01.tiff: 21.5989
# G:\classification\cond_all\cond7_all\sd_04_B05-T01.tiff: 21.6942
# G:\classification\cond_all\cond7_all\ds_1B_B06-T01.tiff: 21.7114
# G:\classification\cond_all\cond7_all\sd_04_D07-T01.tiff: 21.8072
# G:\classification\cond_all\cond7_all\ds_42_F05-T01.tiff: 21.8387
# G:\classification\cond_all\cond7_all\ds_1B_C06-T01.tiff: 21.9038
# G:\classification\cond_all\cond7_all\ds_1B_E05-T01.tiff: 21.9655
# G:\classification\cond_all\cond7_all\ds_1B_F06-T01.tiff: 21.9757
# G:\classification\cond_all\cond7_all\ds_1B_D11-T01.tiff: 22.1235
# G:\classification\cond_all\cond7_all\ds_1B_D05-T01.tiff: 22.2316
# G:\classification\cond_all\cond7_all\ds_1B_B08-T01.tiff: 22.2438
# G:\classification\cond_all\cond7_all\sd_04_D03-T01.tiff: 22.4159
# G:\classification\cond_all\cond7_all\ds_1B_E03-T01.tiff: 22.4711
# G:\classification\cond_all\cond7_all\ds_1B_B11-T01.tiff: 22.4973
# G:\classification\cond_all\cond7_all\ds_1B_C09-T01.tiff: 22.5133
# G:\classification\cond_all\cond7_all\ds_1B_G03-T01.tiff: 22.5495
# G:\classification\cond_all\cond7_all\sd_04_F08-T01.tiff: 22.7452
# G:\classification\cond_all\cond7_all\ds_1B_C10-T01.tiff: 22.8050
# G:\classification\cond_all\cond7_all\ds_1B_G07-T01.tiff: 22.8289
# G:\classification\cond_all\cond7_all\ds_1B_C02-T01.tiff: 22.8459
# G:\classification\cond_all\cond7_all\ds_1B_F10-T01.tiff: 22.8576
# G:\classification\cond_all\cond7_all\sd_04_E02-T01.tiff: 22.8954
# G:\classification\cond_all\cond7_all\ds_1B_E10-T01.tiff: 22.9481
# G:\classification\cond_all\cond7_all\ds_42_D05-T01.tiff: 23.0252
# G:\classification\cond_all\cond7_all\sd_04_C07-T01.tiff: 23.0936
# G:\classification\cond_all\cond7_all\sd_04_F05-T01.tiff: 23.1883
# G:\classification\cond_all\cond7_all\sd_04_E08-T01.tiff: 23.4837
# G:\classification\cond_all\cond7_all\ds_1B_F07-T01.tiff: 23.5101
# G:\classification\cond_all\cond7_all\ds_1B_D09-T01.tiff: 23.6074
# G:\classification\cond_all\cond7_all\ds_1B_C05-T01.tiff: 23.7323
# G:\classification\cond_all\cond7_all\ds_1B_D04-T01.tiff: 23.8411
# G:\classification\cond_all\cond7_all\ds_1B_G08-T01.tiff: 23.8649
# G:\classification\cond_all\cond7_all\ds_1B_D03-T01.tiff: 23.9433
# G:\classification\cond_all\cond7_all\sd_04_F02-T01.tiff: 23.9552
# G:\classification\cond_all\cond7_all\ds_1B_C07-T01.tiff: 23.9837
# G:\classification\cond_all\cond7_all\ds_1B_C11-T01.tiff: 23.9854
# G:\classification\cond_all\cond7_all\ds_1B_E08-T01.tiff: 24.1880
# G:\classification\cond_all\cond7_all\sd_04_E07-T01.tiff: 24.2362
# G:\classification\cond_all\cond7_all\sd_04_G07-T01.tiff: 24.3593
# G:\classification\cond_all\cond7_all\sd_04_E03-T01.tiff: 24.3872
# G:\classification\cond_all\cond7_all\ds_1B_G10-T01.tiff: 24.4372
# G:\classification\cond_all\cond7_all\ds_1B_D06-T01.tiff: 24.5985
# G:\classification\cond_all\cond7_all\sd_04_F07-T01.tiff: 24.7395
# G:\classification\cond_all\cond7_all\ds_1B_B04-T01.tiff: 24.7705
# G:\classification\cond_all\cond7_all\ds_1B_B03-T01.tiff: 25.0084
# G:\classification\cond_all\cond7_all\ds_1B_F08-T01.tiff: 25.1738
# G:\classification\cond_all\cond7_all\sd_04_D04-T01.tiff: 25.4166
# G:\classification\cond_all\cond7_all\sd_04_E05-T01.tiff: 25.4610
# G:\classification\cond_all\cond7_all\ds_1B_G02-T01.tiff: 25.6767
# G:\classification\cond_all\cond7_all\ds_1B_B09-T01.tiff: 25.8153
# G:\classification\cond_all\cond7_all\ds_1B_D02-T01.tiff: 25.9425
# G:\classification\cond_all\cond7_all\ds_1B_C04-T01.tiff: 25.9669
# G:\classification\cond_all\cond7_all\sd_04_B02-T01.tiff: 25.9758
# G:\classification\cond_all\cond7_all\ds_1B_G11-T01.tiff: 26.0650

# %%
import os
import shutil

# Specify the folder where the images will be saved
output_folder = r'G:\classification\nocon_resize'

# Ensure the output folder exists
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Save images with ascending order in the filename
for idx, (path, score) in enumerate(zip(sorted_paths, sorted_scores), start=1):
    # Extract the image name and add the ascending index in front
    image_name = os.path.basename(path)  # Get the image name
    new_image_name = f"{idx:03d}_{image_name}"  # Add ascending index in front (e.g., 001, 002, 003)
    
    # Construct the full path to the output file
    output_path = os.path.join(output_folder, new_image_name)
    
    # Copy the image to the output folder with the new name
    shutil.copy(path, output_path)

    print(f"Saved {path} as {output_path}")
# Out:
# Saved G:\classification\cond_all\sd\RBT14_C09-T01.tiff as G:\classification\nocon_resize\001_RBT14_C09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_B09-T01.tiff as G:\classification\nocon_resize\002_RBT09_B09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_D11-T01.tiff as G:\classification\nocon_resize\003_RBT09_D11-T01.tiff
# Saved G:\classification\cond_all\sd\ds41_g5_E05-T01.tiff as G:\classification\nocon_resize\004_ds41_g5_E05-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_E07-T01.tiff as G:\classification\nocon_resize\005_RBT09_E07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_D09-T01.tiff as G:\classification\nocon_resize\006_RBT09_D09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_C07-T01.tiff as G:\classification\nocon_resize\007_RBT09_C07-T01.tiff
# Saved G:\classification\cond_all\sd\ds42_g5_E03-T01.tiff as G:\classification\nocon_resize\008_ds42_g5_E03-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_B10-T01.tiff as G:\classification\nocon_resize\009_RBT09_B10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_E09-T01.tiff as G:\classification\nocon_resize\010_RBT09_E09-T01.tiff
# Saved G:\classification\cond_all\sd\ds41_g5_E04-T01.tiff as G:\classification\nocon_resize\011_ds41_g5_E04-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_F07-T01.tiff as G:\classification\nocon_resize\012_RBT04_F07-T01.tiff
# Saved G:\classification\cond_all\sd\ds42_g5_E05-T01.tiff as G:\classification\nocon_resize\013_ds42_g5_E05-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_C10-T01.tiff as G:\classification\nocon_resize\014_RBT14_C10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_F07-T01.tiff as G:\classification\nocon_resize\015_RBT10_F07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_B08-T01.tiff as G:\classification\nocon_resize\016_RBT14_B08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_D07-T01.tiff as G:\classification\nocon_resize\017_RBT14_D07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_D09-T01.tiff as G:\classification\nocon_resize\018_RBT14_D09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_D10-T01.tiff as G:\classification\nocon_resize\019_RBT14_D10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_B10-T01.tiff as G:\classification\nocon_resize\020_RBT14_B10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_E07-T01.tiff as G:\classification\nocon_resize\021_RBT04_E07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_C10-T01.tiff as G:\classification\nocon_resize\022_RBT04_C10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_C09-T01.tiff as G:\classification\nocon_resize\023_RBT04_C09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_B08-T01.tiff as G:\classification\nocon_resize\024_RBT04_B08-T01.tiff
# Saved G:\classification\cond_all\sd\ds41_g2_B04-T01.tiff as G:\classification\nocon_resize\025_ds41_g2_B04-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_B11-T01.tiff as G:\classification\nocon_resize\026_RBT04_B11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_G09-T01.tiff as G:\classification\nocon_resize\027_RBT04_G09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_D10-T01.tiff as G:\classification\nocon_resize\028_RBT04_D10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_C11-T01.tiff as G:\classification\nocon_resize\029_RBT14_C11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_D11-T01.tiff as G:\classification\nocon_resize\030_RBT14_D11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_G11-T01.tiff as G:\classification\nocon_resize\031_RBT04_G11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_E08-T01.tiff as G:\classification\nocon_resize\032_RBT04_E08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_G09-T01.tiff as G:\classification\nocon_resize\033_RBT09_G09-T01.tiff
# Saved G:\classification\cond_all\sd\ds42_g5_E02-T01.tiff as G:\classification\nocon_resize\034_ds42_g5_E02-T01.tiff
# Saved G:\classification\cond_all\sd\ds42_g5_E04-T01.tiff as G:\classification\nocon_resize\035_ds42_g5_E04-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_B10-T01.tiff as G:\classification\nocon_resize\036_RBT04_B10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_G11-T01.tiff as G:\classification\nocon_resize\037_RBT09_G11-T01.tiff
# Saved G:\classification\cond_all\sd\ds41_g2_B03-T01.tiff as G:\classification\nocon_resize\038_ds41_g2_B03-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_E09-T01.tiff as G:\classification\nocon_resize\039_RBT04_E09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_D10-T01.tiff as G:\classification\nocon_resize\040_RBT10_D10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_B09-T01.tiff as G:\classification\nocon_resize\041_RBT04_B09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_C08-T01.tiff as G:\classification\nocon_resize\042_RBT04_C08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_C08-T01.tiff as G:\classification\nocon_resize\043_RBT10_C08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_B11-T01.tiff as G:\classification\nocon_resize\044_RBT10_B11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_C09-T01.tiff as G:\classification\nocon_resize\045_RBT10_C09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_E09-T01.tiff as G:\classification\nocon_resize\046_RBT10_E09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_D07-T01.tiff as G:\classification\nocon_resize\047_RBT10_D07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_B09-T01.tiff as G:\classification\nocon_resize\048_RBT10_B09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_B08-T01.tiff as G:\classification\nocon_resize\049_RBT10_B08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_G07-T01.tiff as G:\classification\nocon_resize\050_RBT04_G07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_D07-T01.tiff as G:\classification\nocon_resize\051_RBT09_D07-T01.tiff
# Saved G:\classification\cond_all\sd\ds41_g2_B06-T01.tiff as G:\classification\nocon_resize\052_ds41_g2_B06-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_C07-T01.tiff as G:\classification\nocon_resize\053_RBT14_C07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_G10-T01.tiff as G:\classification\nocon_resize\054_RBT04_G10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_E10-T01.tiff as G:\classification\nocon_resize\055_RBT09_E10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_B07-T01.tiff as G:\classification\nocon_resize\056_RBT14_B07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_B07-T01.tiff as G:\classification\nocon_resize\057_RBT10_B07-T01.tiff
# Saved G:\classification\cond_all\sd\ds42_g2_B04-T01.tiff as G:\classification\nocon_resize\058_ds42_g2_B04-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_G09-T01.tiff as G:\classification\nocon_resize\059_RBT10_G09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_D07-T01.tiff as G:\classification\nocon_resize\060_RBT04_D07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_F10-T01.tiff as G:\classification\nocon_resize\061_RBT04_F10-T01.tiff
# Saved G:\classification\cond_all\sd\ds42_g2_B03-T01.tiff as G:\classification\nocon_resize\062_ds42_g2_B03-T01.tiff
# Saved G:\classification\cond_all\sd\ds42_g2_B05-T01.tiff as G:\classification\nocon_resize\063_ds42_g2_B05-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_C09-T01.tiff as G:\classification\nocon_resize\064_RBT09_C09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_D08-T01.tiff as G:\classification\nocon_resize\065_RBT04_D08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_C07-T01.tiff as G:\classification\nocon_resize\066_RBT04_C07-T01.tiff
# Saved G:\classification\cond_all\sd\ds42_g2_B06-T01.tiff as G:\classification\nocon_resize\067_ds42_g2_B06-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_F08-T01.tiff as G:\classification\nocon_resize\068_RBT04_F08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_F09-T01.tiff as G:\classification\nocon_resize\069_RBT04_F09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_B07-T01.tiff as G:\classification\nocon_resize\070_RBT04_B07-T01.tiff
# Saved G:\classification\cond_all\sd\ds1b_g5_E2.tif as G:\classification\nocon_resize\071_ds1b_g5_E2.tif
# Saved G:\classification\cond_all\sd\RBT04_F11-T01.tiff as G:\classification\nocon_resize\072_RBT04_F11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_F08-T01.tiff as G:\classification\nocon_resize\073_RBT10_F08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_D11-T01.tiff as G:\classification\nocon_resize\074_RBT04_D11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_C07-T01.tiff as G:\classification\nocon_resize\075_RBT10_C07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_E10-T01.tiff as G:\classification\nocon_resize\076_RBT04_E10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_D09-T01.tiff as G:\classification\nocon_resize\077_RBT04_D09-T01.tiff
# Saved G:\classification\cond_all\sd\ds42_g5_E06-T01.tiff as G:\classification\nocon_resize\078_ds42_g5_E06-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_D11-T01.tiff as G:\classification\nocon_resize\079_RBT10_D11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_G11-T01.tiff as G:\classification\nocon_resize\080_RBT10_G11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_G08-T01.tiff as G:\classification\nocon_resize\081_RBT10_G08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_D08-T01.tiff as G:\classification\nocon_resize\082_RBT10_D08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_D08-T01.tiff as G:\classification\nocon_resize\083_RBT14_D08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_B09-T01.tiff as G:\classification\nocon_resize\084_RBT14_B09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_E11-T01.tiff as G:\classification\nocon_resize\085_RBT04_E11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_G07-T01.tiff as G:\classification\nocon_resize\086_RBT10_G07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_D09-T01.tiff as G:\classification\nocon_resize\087_RBT10_D09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_E11-T01.tiff as G:\classification\nocon_resize\088_RBT10_E11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_C08-T01.tiff as G:\classification\nocon_resize\089_RBT14_C08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_B10-T01.tiff as G:\classification\nocon_resize\090_RBT10_B10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_F10-T01.tiff as G:\classification\nocon_resize\091_RBT10_F10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT14_B11-T01.tiff as G:\classification\nocon_resize\092_RBT14_B11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_C11-T01.tiff as G:\classification\nocon_resize\093_RBT09_C11-T01.tiff
# Saved G:\classification\cond_all\sd\ds1b_g5_E5.tif as G:\classification\nocon_resize\094_ds1b_g5_E5.tif
# Saved G:\classification\cond_all\sd\RBT10_F11-T01.tiff as G:\classification\nocon_resize\095_RBT10_F11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_E08-T01.tiff as G:\classification\nocon_resize\096_RBT09_E08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_G10-T01.tiff as G:\classification\nocon_resize\097_RBT10_G10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_F10-T01.tiff as G:\classification\nocon_resize\098_RBT09_F10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_E11-T01.tiff as G:\classification\nocon_resize\099_RBT09_E11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_C08-T01.tiff as G:\classification\nocon_resize\100_RBT09_C08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_D10-T01.tiff as G:\classification\nocon_resize\101_RBT09_D10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_B11-T01.tiff as G:\classification\nocon_resize\102_RBT09_B11-T01.tiff
# Saved G:\classification\cond_all\sd\ds41_g5_E06-T01.tiff as G:\classification\nocon_resize\103_ds41_g5_E06-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_F08-T01.tiff as G:\classification\nocon_resize\104_RBT09_F08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_C11-T01.tiff as G:\classification\nocon_resize\105_RBT10_C11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_E10-T01.tiff as G:\classification\nocon_resize\106_RBT10_E10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_G10-T01.tiff as G:\classification\nocon_resize\107_RBT09_G10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_G07-T01.tiff as G:\classification\nocon_resize\108_RBT09_G07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_F11-T01.tiff as G:\classification\nocon_resize\109_RBT09_F11-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_C10-T01.tiff as G:\classification\nocon_resize\110_RBT10_C10-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_D08-T01.tiff as G:\classification\nocon_resize\111_RBT09_D08-T01.tiff
# Saved G:\classification\cond_all\sd\ds1b_g5_E4.tif as G:\classification\nocon_resize\112_ds1b_g5_E4.tif
# Saved G:\classification\cond_all\sd\RBT09_B07-T01.tiff as G:\classification\nocon_resize\113_RBT09_B07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_F09-T01.tiff as G:\classification\nocon_resize\114_RBT09_F09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_G08-T01.tiff as G:\classification\nocon_resize\115_RBT09_G08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_F07-T01.tiff as G:\classification\nocon_resize\116_RBT09_F07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_F09-T01.tiff as G:\classification\nocon_resize\117_RBT10_F09-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_B08-T01.tiff as G:\classification\nocon_resize\118_RBT09_B08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT10_E07-T01.tiff as G:\classification\nocon_resize\119_RBT10_E07-T01.tiff
# Saved G:\classification\cond_all\sd\RBT04_G08-T01.tiff as G:\classification\nocon_resize\120_RBT04_G08-T01.tiff
# Saved G:\classification\cond_all\sd\RBT09_C10-T01.tiff as G:\classification\nocon_resize\121_RBT09_C10-T01.tiff
# Saved G:\classification\cond_all\sd\ds62_g2_B03-T01.tiff as G:\classification\nocon_resize\122_ds62_g2_B03-T01.tiff
# Saved G:\classification\cond_all\sd\ds62_g2_B02-T01.tiff as G:\classification\nocon_resize\123_ds62_g2_B02-T01.tiff
# Saved G:\classification\cond_all\sd\ds62_g2_B04-T01.tiff as G:\classification\nocon_resize\124_ds62_g2_B04-T01.tiff
# Saved G:\classification\cond_all\sd\ds1b_g5_E3.tif as G:\classification\nocon_resize\125_ds1b_g5_E3.tif
# Saved G:\classification\cond_all\ex\ds1B_g9_C11.tif as G:\classification\nocon_resize\126_ds1B_g9_C11.tif
# Saved G:\classification\cond_all\ex\ds1B_g9_C8.tif as G:\classification\nocon_resize\127_ds1B_g9_C8.tif
# Saved G:\classification\cond_all\ex\ds1B_g9_C7.tif as G:\classification\nocon_resize\128_ds1B_g9_C7.tif
# Saved G:\classification\cond_all\ex\ds1B_g9_c10.tif as G:\classification\nocon_resize\129_ds1B_g9_c10.tif
# Saved G:\classification\cond_all\ex\ds1B_g9_C9.tif as G:\classification\nocon_resize\130_ds1B_g9_C9.tif
# Saved G:\classification\cond_all\ex\ds41_g3_C04-T01.tiff as G:\classification\nocon_resize\131_ds41_g3_C04-T01.tiff
# Saved G:\classification\cond_all\ex\ds41_g3_C02-T01.tiff as G:\classification\nocon_resize\132_ds41_g3_C02-T01.tiff
# Saved G:\classification\cond_all\ex\ds41_g3_C03-T01.tiff as G:\classification\nocon_resize\133_ds41_g3_C03-T01.tiff
# Saved G:\classification\cond_all\ex\ds41_g3_C05-T01.tiff as G:\classification\nocon_resize\134_ds41_g3_C05-T01.tiff
# Saved G:\classification\cond_all\ex\ds41_g3_C06-T01.tiff as G:\classification\nocon_resize\135_ds41_g3_C06-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g8_B07-T01.tiff as G:\classification\nocon_resize\136_ds61_g8_B07-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g8_B11-T01.tiff as G:\classification\nocon_resize\137_ds61_g8_B11-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g6_F04-T01.tiff as G:\classification\nocon_resize\138_ds61_g6_F04-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g9_C11-T01.tiff as G:\classification\nocon_resize\139_ds61_g9_C11-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g3_C05-T01.tiff as G:\classification\nocon_resize\140_ds61_g3_C05-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g3_C04-T01.tiff as G:\classification\nocon_resize\141_ds61_g3_C04-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g3_C06-T01.tiff as G:\classification\nocon_resize\142_ds61_g3_C06-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g9_C08-T01.tiff as G:\classification\nocon_resize\143_ds61_g9_C08-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g8_B08-T01.tiff as G:\classification\nocon_resize\144_ds61_g8_B08-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g6_F06-T01.tiff as G:\classification\nocon_resize\145_ds61_g6_F06-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g9_C07-T01.tiff as G:\classification\nocon_resize\146_ds61_g9_C07-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g9_C09-T01.tiff as G:\classification\nocon_resize\147_ds61_g9_C09-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g6_F03-T01.tiff as G:\classification\nocon_resize\148_ds61_g6_F03-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g3_C02-T01.tiff as G:\classification\nocon_resize\149_ds61_g3_C02-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g6_F02-T01.tiff as G:\classification\nocon_resize\150_ds61_g6_F02-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g6_F05-T01.tiff as G:\classification\nocon_resize\151_ds61_g6_F05-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g8_B10-T01.tiff as G:\classification\nocon_resize\152_ds61_g8_B10-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g3_C03-T01.tiff as G:\classification\nocon_resize\153_ds61_g3_C03-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g8_B10-T01.tiff as G:\classification\nocon_resize\154_ds62_g8_B10-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g9_C10-T01.tiff as G:\classification\nocon_resize\155_ds61_g9_C10-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g8_B11-T01.tiff as G:\classification\nocon_resize\156_ds62_g8_B11-T01.tiff
# Saved G:\classification\cond_all\ex\ds61_g8_B09-T01.tiff as G:\classification\nocon_resize\157_ds61_g8_B09-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g8_B09-T01.tiff as G:\classification\nocon_resize\158_ds62_g8_B09-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g9_C08-T01.tiff as G:\classification\nocon_resize\159_ds62_g9_C08-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g9_C11-T01.tiff as G:\classification\nocon_resize\160_ds62_g9_C11-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g9_C07-T01.tiff as G:\classification\nocon_resize\161_ds62_g9_C07-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g9_C10-T01.tiff as G:\classification\nocon_resize\162_ds62_g9_C10-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g8_B07-T01.tiff as G:\classification\nocon_resize\163_ds62_g8_B07-T01.tiff
# Saved G:\classification\cond_all\ex\ds62_g9_C09-T01.tiff as G:\classification\nocon_resize\164_ds62_g9_C09-T01.tiff
# Saved G:\classification\cond_all\ex\ds41_g9_C10-T01.tiff as G:\classification\nocon_resize\165_ds41_g9_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B10-T01.tiff as G:\classification\nocon_resize\166_ds_62_B10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B08-T01.tiff as G:\classification\nocon_resize\167_ds_62_B08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E02-T01.tiff as G:\classification\nocon_resize\168_ds_61_E02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G03-T01.tiff as G:\classification\nocon_resize\169_ds_62_G03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B10-T01.tiff as G:\classification\nocon_resize\170_ds_61_B10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F02-T01.tiff as G:\classification\nocon_resize\171_ds_61_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C07-T01.tiff as G:\classification\nocon_resize\172_ds_62_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B11-T01.tiff as G:\classification\nocon_resize\173_ds_62_B11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C03-T01.tiff as G:\classification\nocon_resize\174_ds_61_C03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G09-T01.tiff as G:\classification\nocon_resize\175_ds_62_G09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G04-T01.tiff as G:\classification\nocon_resize\176_ds_61_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G10-T01.tiff as G:\classification\nocon_resize\177_ds_61_G10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D02-T01.tiff as G:\classification\nocon_resize\178_ds_61_D02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B03-T01.tiff as G:\classification\nocon_resize\179_ds_61_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C10-T01.tiff as G:\classification\nocon_resize\180_ds_62_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G03-T01.tiff as G:\classification\nocon_resize\181_ds_61_G03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C11-T01.tiff as G:\classification\nocon_resize\182_ds_62_C11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C02-T01.tiff as G:\classification\nocon_resize\183_ds_61_C02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G07-T01.tiff as G:\classification\nocon_resize\184_ds_62_G07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E09-T01.tiff as G:\classification\nocon_resize\185_ds_62_E09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F10-T01.tiff as G:\classification\nocon_resize\186_ds_61_F10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E06-T01.tiff as G:\classification\nocon_resize\187_ds_61_E06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B05-T01.tiff as G:\classification\nocon_resize\188_ds_61_B05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E03-T01.tiff as G:\classification\nocon_resize\189_ds_61_E03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D10-T01.tiff as G:\classification\nocon_resize\190_ds_62_D10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C09-T01.tiff as G:\classification\nocon_resize\191_ds_62_C09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D09-T01.tiff as G:\classification\nocon_resize\192_ds_62_D09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D06-T01.tiff as G:\classification\nocon_resize\193_ds_61_D06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F07-T01.tiff as G:\classification\nocon_resize\194_ds_61_F07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F10-T01.tiff as G:\classification\nocon_resize\195_ds_62_F10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B06-T01.tiff as G:\classification\nocon_resize\196_ds_61_B06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C10-T01.tiff as G:\classification\nocon_resize\197_ds_61_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E11-T01.tiff as G:\classification\nocon_resize\198_ds_62_E11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G09-T01.tiff as G:\classification\nocon_resize\199_ds_61_G09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G06-T01.tiff as G:\classification\nocon_resize\200_ds_61_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E07-T01.tiff as G:\classification\nocon_resize\201_ds_52_E07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C07-T01.tiff as G:\classification\nocon_resize\202_ds_61_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F11-T01.tiff as G:\classification\nocon_resize\203_ds_61_F11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E05-T01.tiff as G:\classification\nocon_resize\204_ds_52_E05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D05-T01.tiff as G:\classification\nocon_resize\205_ds_61_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F06-T01.tiff as G:\classification\nocon_resize\206_ds_61_F06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G10-T01.tiff as G:\classification\nocon_resize\207_ds_62_G10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E10-T01.tiff as G:\classification\nocon_resize\208_ds_61_E10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C09-T01.tiff as G:\classification\nocon_resize\209_ds_61_C09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E11-T01.tiff as G:\classification\nocon_resize\210_ds_61_E11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E07-T01.tiff as G:\classification\nocon_resize\211_ds_62_E07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F08-T01.tiff as G:\classification\nocon_resize\212_ds_62_F08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E08-T01.tiff as G:\classification\nocon_resize\213_ds_62_E08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D11-T01.tiff as G:\classification\nocon_resize\214_ds_61_D11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C07-T01.tiff as G:\classification\nocon_resize\215_ds_41_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C09-T01.tiff as G:\classification\nocon_resize\216_ds_41_C09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B02-T01.tiff as G:\classification\nocon_resize\217_ds_61_B02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B07-T01.tiff as G:\classification\nocon_resize\218_ds_41_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C05-T01.tiff as G:\classification\nocon_resize\219_ds_61_C05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F09-T01.tiff as G:\classification\nocon_resize\220_ds_62_F09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C11-T01.tiff as G:\classification\nocon_resize\221_ds_61_C11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E07-T01.tiff as G:\classification\nocon_resize\222_ds_61_E07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C04-T01.tiff as G:\classification\nocon_resize\223_ds_61_C04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D10-T01.tiff as G:\classification\nocon_resize\224_ds_61_D10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G08-T01.tiff as G:\classification\nocon_resize\225_ds_61_G08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F07-T01.tiff as G:\classification\nocon_resize\226_ds_62_F07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F05-T01.tiff as G:\classification\nocon_resize\227_ds_61_F05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G08-T01.tiff as G:\classification\nocon_resize\228_ds_62_G08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E04-T01.tiff as G:\classification\nocon_resize\229_ds_61_E04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G06-T01.tiff as G:\classification\nocon_resize\230_ds_62_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E05-T01.tiff as G:\classification\nocon_resize\231_ds_61_E05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F09-T01.tiff as G:\classification\nocon_resize\232_ds_61_F09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G07-T01.tiff as G:\classification\nocon_resize\233_ds_52_G07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D09-T01.tiff as G:\classification\nocon_resize\234_ds_61_D09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G05-T01.tiff as G:\classification\nocon_resize\235_ds_61_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F11-T01.tiff as G:\classification\nocon_resize\236_ds_62_F11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G11-T01.tiff as G:\classification\nocon_resize\237_ds_62_G11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B11-T01.tiff as G:\classification\nocon_resize\238_ds_61_B11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_G07-T01.tiff as G:\classification\nocon_resize\239_ds_61_G07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C04-T01.tiff as G:\classification\nocon_resize\240_ds_52_C04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F07-T01.tiff as G:\classification\nocon_resize\241_ds_52_F07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G02-T01.tiff as G:\classification\nocon_resize\242_ds_52_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B02-T01.tiff as G:\classification\nocon_resize\243_ds_52_B02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G08-T01.tiff as G:\classification\nocon_resize\244_ds_52_G08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F03-T01.tiff as G:\classification\nocon_resize\245_ds_41_F03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D03-T01.tiff as G:\classification\nocon_resize\246_ds_61_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_F04-T01.tiff as G:\classification\nocon_resize\247_ds_61_F04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F06-T01.tiff as G:\classification\nocon_resize\248_ds_52_F06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G07-T01.tiff as G:\classification\nocon_resize\249_ds_51_G07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F03-T01.tiff as G:\classification\nocon_resize\250_ds_52_F03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F04-T01.tiff as G:\classification\nocon_resize\251_ds_62_F04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B09-T01.tiff as G:\classification\nocon_resize\252_ds_52_B09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C07-T01.tiff as G:\classification\nocon_resize\253_ds_52_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E08-T01.tiff as G:\classification\nocon_resize\254_ds_52_E08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D08-T01.tiff as G:\classification\nocon_resize\255_ds_62_D08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B07-T01.tiff as G:\classification\nocon_resize\256_ds_52_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G10-T01.tiff as G:\classification\nocon_resize\257_ds_52_G10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D05-T01.tiff as G:\classification\nocon_resize\258_ds_62_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G08-T01.tiff as G:\classification\nocon_resize\259_ds_51_G08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G11-T01.tiff as G:\classification\nocon_resize\260_ds_52_G11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G05-T01.tiff as G:\classification\nocon_resize\261_ds_51_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_F09-T01.tiff as G:\classification\nocon_resize\262_ds_51_F09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D03-T01.tiff as G:\classification\nocon_resize\263_ds_62_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B11-T01.tiff as G:\classification\nocon_resize\264_ds_52_B11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_C09-T01.tiff as G:\classification\nocon_resize\265_ds_51_C09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_F07-T01.tiff as G:\classification\nocon_resize\266_ds_51_F07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B03-T01.tiff as G:\classification\nocon_resize\267_ds_52_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G03-T01.tiff as G:\classification\nocon_resize\268_ds_51_G03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_B03-T01.tiff as G:\classification\nocon_resize\269_ds_51_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_C07-T01.tiff as G:\classification\nocon_resize\270_ds_51_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_D11-T01.tiff as G:\classification\nocon_resize\271_ds_51_D11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B06-T01.tiff as G:\classification\nocon_resize\272_ds_62_B06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D02-T01.tiff as G:\classification\nocon_resize\273_ds_62_D02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E03-T01.tiff as G:\classification\nocon_resize\274_ds_62_E03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G04-T01.tiff as G:\classification\nocon_resize\275_ds_51_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C05-T01.tiff as G:\classification\nocon_resize\276_ds_62_C05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B05-T01.tiff as G:\classification\nocon_resize\277_ds_62_B05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B07-T01.tiff as G:\classification\nocon_resize\278_ds_62_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D04-T01.tiff as G:\classification\nocon_resize\279_ds_62_D04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G02-T01.tiff as G:\classification\nocon_resize\280_ds_51_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E02-T01.tiff as G:\classification\nocon_resize\281_ds_62_E02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C03-T01.tiff as G:\classification\nocon_resize\282_ds_62_C03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_F04-T01.tiff as G:\classification\nocon_resize\283_ds_51_F04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C11-T01.tiff as G:\classification\nocon_resize\284_ds_52_C11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E06-T01.tiff as G:\classification\nocon_resize\285_ds_62_E06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E04-T01.tiff as G:\classification\nocon_resize\286_ds_62_E04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D06-T01.tiff as G:\classification\nocon_resize\287_ds_62_D06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F06-T01.tiff as G:\classification\nocon_resize\288_ds_62_F06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G05-T01.tiff as G:\classification\nocon_resize\289_ds_62_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C09-T01.tiff as G:\classification\nocon_resize\290_ds_52_C09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C04-T01.tiff as G:\classification\nocon_resize\291_ds_62_C04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D08-T01.tiff as G:\classification\nocon_resize\292_ds_52_D08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_C05-T01.tiff as G:\classification\nocon_resize\293_ds_51_C05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B04-T01.tiff as G:\classification\nocon_resize\294_ds_62_B04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_E05-T01.tiff as G:\classification\nocon_resize\295_ds_62_E05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F09-T01.tiff as G:\classification\nocon_resize\296_ds_52_F09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F05-T01.tiff as G:\classification\nocon_resize\297_ds_62_F05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_D06-T01.tiff as G:\classification\nocon_resize\298_ds_51_D06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D10-T01.tiff as G:\classification\nocon_resize\299_ds_52_D10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_F05-T01.tiff as G:\classification\nocon_resize\300_ds_51_F05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F10-T01.tiff as G:\classification\nocon_resize\301_ds_52_F10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G02-T01.tiff as G:\classification\nocon_resize\302_ds_62_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_G04-T01.tiff as G:\classification\nocon_resize\303_ds_62_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_F06-T01.tiff as G:\classification\nocon_resize\304_ds_51_F06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_F02-T01.tiff as G:\classification\nocon_resize\305_ds_62_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_E06-T01.tiff as G:\classification\nocon_resize\306_ds_51_E06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C02-T01.tiff as G:\classification\nocon_resize\307_ds_62_C02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G06-T01.tiff as G:\classification\nocon_resize\308_ds_51_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_E08-T01.tiff as G:\classification\nocon_resize\309_ds_51_E08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_E03-T01.tiff as G:\classification\nocon_resize\310_ds_51_E03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_F03-T01.tiff as G:\classification\nocon_resize\311_ds_51_F03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_F02-T01.tiff as G:\classification\nocon_resize\312_ds_51_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_E02-T01.tiff as G:\classification\nocon_resize\313_ds_51_E02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_E10-T01.tiff as G:\classification\nocon_resize\314_ds_51_E10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G10-T01.tiff as G:\classification\nocon_resize\315_ds_51_G10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_D10-T01.tiff as G:\classification\nocon_resize\316_ds_51_D10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_D07-T01.tiff as G:\classification\nocon_resize\317_ds_51_D07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_C08-T01.tiff as G:\classification\nocon_resize\318_ds_51_C08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_F08-T01.tiff as G:\classification\nocon_resize\319_ds_51_F08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_C06-T01.tiff as G:\classification\nocon_resize\320_ds_51_C06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B09-T01.tiff as G:\classification\nocon_resize\321_ds_62_B09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_B06-T01.tiff as G:\classification\nocon_resize\322_ds_51_B06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_B05-T01.tiff as G:\classification\nocon_resize\323_ds_51_B05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B02-T01.tiff as G:\classification\nocon_resize\324_ds_62_B02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_B11-T01.tiff as G:\classification\nocon_resize\325_ds_51_B11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_B09-T01.tiff as G:\classification\nocon_resize\326_ds_51_B09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_D02-T01.tiff as G:\classification\nocon_resize\327_ds_51_D02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_C10-T01.tiff as G:\classification\nocon_resize\328_ds_51_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_B10-T01.tiff as G:\classification\nocon_resize\329_ds_51_B10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_D04-T01.tiff as G:\classification\nocon_resize\330_ds_51_D04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_B08-T01.tiff as G:\classification\nocon_resize\331_ds_51_B08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_E11-T01.tiff as G:\classification\nocon_resize\332_ds_51_E11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_D03-T01.tiff as G:\classification\nocon_resize\333_ds_51_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G09-T01.tiff as G:\classification\nocon_resize\334_ds_51_G09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_F10-T01.tiff as G:\classification\nocon_resize\335_ds_51_F10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_B02-T01.tiff as G:\classification\nocon_resize\336_ds_51_B02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_C03-T01.tiff as G:\classification\nocon_resize\337_ds_51_C03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_C02-T01.tiff as G:\classification\nocon_resize\338_ds_51_C02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_B07-T01.tiff as G:\classification\nocon_resize\339_ds_51_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_D05-T01.tiff as G:\classification\nocon_resize\340_ds_51_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_C04-T01.tiff as G:\classification\nocon_resize\341_ds_51_C04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_D09-T01.tiff as G:\classification\nocon_resize\342_ds_51_D09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_E04-T01.tiff as G:\classification\nocon_resize\343_ds_51_E04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_B03-T01.tiff as G:\classification\nocon_resize\344_ds_62_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G06-T01.tiff as G:\classification\nocon_resize\345_ds_52_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D11-T01.tiff as G:\classification\nocon_resize\346_ds_52_D11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_F11-T01.tiff as G:\classification\nocon_resize\347_ds_51_F11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G09-T01.tiff as G:\classification\nocon_resize\348_ds_52_G09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B06-T01.tiff as G:\classification\nocon_resize\349_ds_52_B06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D04-T01.tiff as G:\classification\nocon_resize\350_ds_52_D04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B06-T01.tiff as G:\classification\nocon_resize\351_ds_42_B06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_E05-T01.tiff as G:\classification\nocon_resize\352_ds_51_E05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D06-T01.tiff as G:\classification\nocon_resize\353_ds_52_D06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_D02-T01.tiff as G:\classification\nocon_resize\354_ds_42_D02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E09-T01.tiff as G:\classification\nocon_resize\355_ds_52_E09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_C06-T01.tiff as G:\classification\nocon_resize\356_ds_62_C06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_62_D07-T01.tiff as G:\classification\nocon_resize\357_ds_62_D07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C08-T01.tiff as G:\classification\nocon_resize\358_ds_52_C08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D07-T01.tiff as G:\classification\nocon_resize\359_ds_52_D07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E10-T01.tiff as G:\classification\nocon_resize\360_ds_52_E10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F11-T01.tiff as G:\classification\nocon_resize\361_ds_52_F11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F08-T01.tiff as G:\classification\nocon_resize\362_ds_52_F08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G10-T01.tiff as G:\classification\nocon_resize\363_ds_42_G10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_F02-T01.tiff as G:\classification\nocon_resize\364_ds_52_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D09-T01.tiff as G:\classification\nocon_resize\365_ds_52_D09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B10-T01.tiff as G:\classification\nocon_resize\366_ds_52_B10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C02-T01.tiff as G:\classification\nocon_resize\367_ds_52_C02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_C11-T01.tiff as G:\classification\nocon_resize\368_ds_51_C11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_G11-T01.tiff as G:\classification\nocon_resize\369_ds_51_G11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_C08-T01.tiff as G:\classification\nocon_resize\370_ds_61_C08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_E09-T01.tiff as G:\classification\nocon_resize\371_ds_61_E09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B05-T01.tiff as G:\classification\nocon_resize\372_ds_52_B05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_D07-T01.tiff as G:\classification\nocon_resize\373_ds_61_D07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_F09-T01.tiff as G:\classification\nocon_resize\374_ds_42_F09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_61_B07-T01.tiff as G:\classification\nocon_resize\375_ds_61_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D07-T01.tiff as G:\classification\nocon_resize\376_ds_41_D07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_D04-T01.tiff as G:\classification\nocon_resize\377_ds_42_D04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_F02-T01.tiff as G:\classification\nocon_resize\378_ds_42_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G02-T01.tiff as G:\classification\nocon_resize\379_ds_41_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_E11-T01.tiff as G:\classification\nocon_resize\380_ds_41_E11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C02-T01.tiff as G:\classification\nocon_resize\381_ds_41_C02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B05-T01.tiff as G:\classification\nocon_resize\382_ds_41_B05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G04-T01.tiff as G:\classification\nocon_resize\383_ds_52_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D04-T01.tiff as G:\classification\nocon_resize\384_ds_41_D04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E11-T01.tiff as G:\classification\nocon_resize\385_ds_52_E11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E04-T01.tiff as G:\classification\nocon_resize\386_ds_52_E04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E03-T01.tiff as G:\classification\nocon_resize\387_ds_52_E03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D06-T01.tiff as G:\classification\nocon_resize\388_ds_41_D06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C10-T01.tiff as G:\classification\nocon_resize\389_ds_41_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C06-T01.tiff as G:\classification\nocon_resize\390_ds_41_C06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G05-T01.tiff as G:\classification\nocon_resize\391_ds_42_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C10-T01.tiff as G:\classification\nocon_resize\392_ds_52_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B09-T01.tiff as G:\classification\nocon_resize\393_ds_41_B09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D10-T01.tiff as G:\classification\nocon_resize\394_ds_41_D10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B08-T01.tiff as G:\classification\nocon_resize\395_ds_41_B08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_E06-T01.tiff as G:\classification\nocon_resize\396_ds_52_E06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_E02-T01.tiff as G:\classification\nocon_resize\397_ds_41_E02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D05-T01.tiff as G:\classification\nocon_resize\398_ds_52_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_D11-T01.tiff as G:\classification\nocon_resize\399_sd_04_D11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G05-T01.tiff as G:\classification\nocon_resize\400_ds_41_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G06-T01.tiff as G:\classification\nocon_resize\401_ds_42_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G09-T01.tiff as G:\classification\nocon_resize\402_ds_41_G09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_E06-T01.tiff as G:\classification\nocon_resize\403_ds_42_E06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F06-T01.tiff as G:\classification\nocon_resize\404_ds_41_F06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D02-T01.tiff as G:\classification\nocon_resize\405_ds_52_D02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_C05-T01.tiff as G:\classification\nocon_resize\406_ds_52_C05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G10-T01.tiff as G:\classification\nocon_resize\407_ds_41_G10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_B08-T01.tiff as G:\classification\nocon_resize\408_ds_52_B08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_D03-T01.tiff as G:\classification\nocon_resize\409_ds_52_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_C11-T01.tiff as G:\classification\nocon_resize\410_ds_41_C11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_G06-T01.tiff as G:\classification\nocon_resize\411_ds_41_G06-T01.tiff
# ...
# Saved G:\classification\cond_all\cond7_all\sd_04_F10-T01.tiff as G:\classification\nocon_resize\504_sd_04_F10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F04-T01.tiff as G:\classification\nocon_resize\505_ds_41_F04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_G09-T01.tiff as G:\classification\nocon_resize\506_sd_04_G09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_D06-T01.tiff as G:\classification\nocon_resize\507_ds_42_D06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_B07-T01.tiff as G:\classification\nocon_resize\508_sd_04_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_C06-T01.tiff as G:\classification\nocon_resize\509_sd_04_C06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_D10-T01.tiff as G:\classification\nocon_resize\510_ds_1B_D10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_E11-T01.tiff as G:\classification\nocon_resize\511_ds_1B_E11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_F09-T01.tiff as G:\classification\nocon_resize\512_ds_1B_F09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_F02-T01.tiff as G:\classification\nocon_resize\513_ds_41_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D03-T01.tiff as G:\classification\nocon_resize\514_ds_41_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_G04-T01.tiff as G:\classification\nocon_resize\515_sd_04_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_G05-T01.tiff as G:\classification\nocon_resize\516_ds_1B_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_F03-T01.tiff as G:\classification\nocon_resize\517_ds_42_F03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_G03-T01.tiff as G:\classification\nocon_resize\518_sd_04_G03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_E03-T01.tiff as G:\classification\nocon_resize\519_ds_42_E03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_G02-T01.tiff as G:\classification\nocon_resize\520_sd_04_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_G08-T01.tiff as G:\classification\nocon_resize\521_sd_04_G08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_G02-T01.tiff as G:\classification\nocon_resize\522_ds_42_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C05-T01.tiff as G:\classification\nocon_resize\523_ds_42_C05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C06-T01.tiff as G:\classification\nocon_resize\524_ds_42_C06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_E09-T01.tiff as G:\classification\nocon_resize\525_sd_04_E09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C11-T01.tiff as G:\classification\nocon_resize\526_ds_42_C11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B09-T01.tiff as G:\classification\nocon_resize\527_ds_42_B09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B11-T01.tiff as G:\classification\nocon_resize\528_ds_42_B11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B02-T01.tiff as G:\classification\nocon_resize\529_ds_1B_B02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B04-T01.tiff as G:\classification\nocon_resize\530_ds_41_B04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B07-T01.tiff as G:\classification\nocon_resize\531_ds_42_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_E10-T01.tiff as G:\classification\nocon_resize\532_ds_42_E10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_C02-T01.tiff as G:\classification\nocon_resize\533_sd_04_C02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_D03-T01.tiff as G:\classification\nocon_resize\534_ds_42_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B02-T01.tiff as G:\classification\nocon_resize\535_ds_42_B02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B10-T01.tiff as G:\classification\nocon_resize\536_ds_1B_B10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_B11-T01.tiff as G:\classification\nocon_resize\537_sd_04_B11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_B04-T01.tiff as G:\classification\nocon_resize\538_ds_42_B04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_B03-T01.tiff as G:\classification\nocon_resize\539_sd_04_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_F04-T01.tiff as G:\classification\nocon_resize\540_ds_1B_F04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_C05-T01.tiff as G:\classification\nocon_resize\541_sd_04_C05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_E06-T01.tiff as G:\classification\nocon_resize\542_sd_04_E06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_F04-T01.tiff as G:\classification\nocon_resize\543_sd_04_F04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_D02-T01.tiff as G:\classification\nocon_resize\544_sd_04_D02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_E04-T01.tiff as G:\classification\nocon_resize\545_sd_04_E04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_G09-T01.tiff as G:\classification\nocon_resize\546_ds_1B_G09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_E04-T01.tiff as G:\classification\nocon_resize\547_ds_1B_E04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_F03-T01.tiff as G:\classification\nocon_resize\548_ds_1B_F03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_C03-T01.tiff as G:\classification\nocon_resize\549_ds_1B_C03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_G05-T01.tiff as G:\classification\nocon_resize\550_sd_04_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_E07-T01.tiff as G:\classification\nocon_resize\551_ds_1B_E07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_D05-T01.tiff as G:\classification\nocon_resize\552_sd_04_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_C08-T01.tiff as G:\classification\nocon_resize\553_ds_1B_C08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_F02-T01.tiff as G:\classification\nocon_resize\554_ds_1B_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_G06-T01.tiff as G:\classification\nocon_resize\555_ds_1B_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_G04-T01.tiff as G:\classification\nocon_resize\556_ds_1B_G04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_C03-T01.tiff as G:\classification\nocon_resize\557_sd_04_C03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_B08-T01.tiff as G:\classification\nocon_resize\558_sd_04_B08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_F03-T01.tiff as G:\classification\nocon_resize\559_sd_04_F03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_D08-T01.tiff as G:\classification\nocon_resize\560_ds_51_D08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_F05-T01.tiff as G:\classification\nocon_resize\561_ds_1B_F05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_51_E09-T01.tiff as G:\classification\nocon_resize\562_ds_51_E09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_C08-T01.tiff as G:\classification\nocon_resize\563_sd_04_C08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_F06-T01.tiff as G:\classification\nocon_resize\564_sd_04_F06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_E06-T01.tiff as G:\classification\nocon_resize\565_ds_1B_E06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_E02-T01.tiff as G:\classification\nocon_resize\566_ds_1B_E02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_B10-T01.tiff as G:\classification\nocon_resize\567_ds_41_B10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B05-T01.tiff as G:\classification\nocon_resize\568_ds_1B_B05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_E09-T01.tiff as G:\classification\nocon_resize\569_ds_41_E09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_D08-T01.tiff as G:\classification\nocon_resize\570_ds_1B_D08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_D08-T01.tiff as G:\classification\nocon_resize\571_ds_42_D08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_G11-T01.tiff as G:\classification\nocon_resize\572_sd_04_G11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_C07-T01.tiff as G:\classification\nocon_resize\573_ds_42_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_E09-T01.tiff as G:\classification\nocon_resize\574_ds_1B_E09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_D07-T01.tiff as G:\classification\nocon_resize\575_ds_1B_D07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_C10-T01.tiff as G:\classification\nocon_resize\576_sd_04_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_D10-T01.tiff as G:\classification\nocon_resize\577_sd_04_D10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_C09-T01.tiff as G:\classification\nocon_resize\578_sd_04_C09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_G06-T01.tiff as G:\classification\nocon_resize\579_sd_04_G06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B07-T01.tiff as G:\classification\nocon_resize\580_ds_1B_B07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_52_G05-T01.tiff as G:\classification\nocon_resize\581_ds_52_G05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_D08-T01.tiff as G:\classification\nocon_resize\582_sd_04_D08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_41_D05-T01.tiff as G:\classification\nocon_resize\583_ds_41_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_F11-T01.tiff as G:\classification\nocon_resize\584_ds_1B_F11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_B05-T01.tiff as G:\classification\nocon_resize\585_sd_04_B05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B06-T01.tiff as G:\classification\nocon_resize\586_ds_1B_B06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_D07-T01.tiff as G:\classification\nocon_resize\587_sd_04_D07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_F05-T01.tiff as G:\classification\nocon_resize\588_ds_42_F05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_C06-T01.tiff as G:\classification\nocon_resize\589_ds_1B_C06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_E05-T01.tiff as G:\classification\nocon_resize\590_ds_1B_E05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_F06-T01.tiff as G:\classification\nocon_resize\591_ds_1B_F06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_D11-T01.tiff as G:\classification\nocon_resize\592_ds_1B_D11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_D05-T01.tiff as G:\classification\nocon_resize\593_ds_1B_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B08-T01.tiff as G:\classification\nocon_resize\594_ds_1B_B08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_D03-T01.tiff as G:\classification\nocon_resize\595_sd_04_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_E03-T01.tiff as G:\classification\nocon_resize\596_ds_1B_E03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B11-T01.tiff as G:\classification\nocon_resize\597_ds_1B_B11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_C09-T01.tiff as G:\classification\nocon_resize\598_ds_1B_C09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_G03-T01.tiff as G:\classification\nocon_resize\599_ds_1B_G03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_F08-T01.tiff as G:\classification\nocon_resize\600_sd_04_F08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_C10-T01.tiff as G:\classification\nocon_resize\601_ds_1B_C10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_G07-T01.tiff as G:\classification\nocon_resize\602_ds_1B_G07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_C02-T01.tiff as G:\classification\nocon_resize\603_ds_1B_C02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_F10-T01.tiff as G:\classification\nocon_resize\604_ds_1B_F10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_E02-T01.tiff as G:\classification\nocon_resize\605_sd_04_E02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_E10-T01.tiff as G:\classification\nocon_resize\606_ds_1B_E10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_42_D05-T01.tiff as G:\classification\nocon_resize\607_ds_42_D05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_C07-T01.tiff as G:\classification\nocon_resize\608_sd_04_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_F05-T01.tiff as G:\classification\nocon_resize\609_sd_04_F05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_E08-T01.tiff as G:\classification\nocon_resize\610_sd_04_E08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_F07-T01.tiff as G:\classification\nocon_resize\611_ds_1B_F07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_D09-T01.tiff as G:\classification\nocon_resize\612_ds_1B_D09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_C05-T01.tiff as G:\classification\nocon_resize\613_ds_1B_C05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_D04-T01.tiff as G:\classification\nocon_resize\614_ds_1B_D04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_G08-T01.tiff as G:\classification\nocon_resize\615_ds_1B_G08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_D03-T01.tiff as G:\classification\nocon_resize\616_ds_1B_D03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_F02-T01.tiff as G:\classification\nocon_resize\617_sd_04_F02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_C07-T01.tiff as G:\classification\nocon_resize\618_ds_1B_C07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_C11-T01.tiff as G:\classification\nocon_resize\619_ds_1B_C11-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_E08-T01.tiff as G:\classification\nocon_resize\620_ds_1B_E08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_E07-T01.tiff as G:\classification\nocon_resize\621_sd_04_E07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_G07-T01.tiff as G:\classification\nocon_resize\622_sd_04_G07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_E03-T01.tiff as G:\classification\nocon_resize\623_sd_04_E03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_G10-T01.tiff as G:\classification\nocon_resize\624_ds_1B_G10-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_D06-T01.tiff as G:\classification\nocon_resize\625_ds_1B_D06-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_F07-T01.tiff as G:\classification\nocon_resize\626_sd_04_F07-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B04-T01.tiff as G:\classification\nocon_resize\627_ds_1B_B04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B03-T01.tiff as G:\classification\nocon_resize\628_ds_1B_B03-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_F08-T01.tiff as G:\classification\nocon_resize\629_ds_1B_F08-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_D04-T01.tiff as G:\classification\nocon_resize\630_sd_04_D04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_E05-T01.tiff as G:\classification\nocon_resize\631_sd_04_E05-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_G02-T01.tiff as G:\classification\nocon_resize\632_ds_1B_G02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_B09-T01.tiff as G:\classification\nocon_resize\633_ds_1B_B09-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_D02-T01.tiff as G:\classification\nocon_resize\634_ds_1B_D02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_C04-T01.tiff as G:\classification\nocon_resize\635_ds_1B_C04-T01.tiff
# Saved G:\classification\cond_all\cond7_all\sd_04_B02-T01.tiff as G:\classification\nocon_resize\636_sd_04_B02-T01.tiff
# Saved G:\classification\cond_all\cond7_all\ds_1B_G11-T01.tiff as G:\classification\nocon_resize\637_ds_1B_G11-T01.tiff

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE
import torch

# Perform t-SNE
perplexity = 30  # Tune as needed
n_iter = 1000  # Number of optimization iterations

# Convert features to NumPy array if they are in tensor form
feats_np = feats.numpy() if isinstance(feats, torch.Tensor) else feats
labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else labels

# Apply 1D t-SNE
print("Running 1D t-SNE...")
tsne = TSNE(n_components=1, perplexity=perplexity, n_iter=n_iter, random_state=42)
feats_1d = tsne.fit_transform(feats_np).flatten()  # Flatten to make it a 1D array

# Get unique class labels and assign y-values accordingly
unique_labels = np.unique(labels_np)
class_y_positions = {label: i for i, label in enumerate(unique_labels)}

# Map labels to their respective y positions
y_positions = np.array([class_y_positions[label] for label in labels_np])

# Define colors for the different classes
num_classes = len(unique_labels)
colors = plt.cm.rainbow(np.linspace(0, 1, num_classes))

# Create a scatter plot in 1D with separate y-axis levels for each class
plt.figure(figsize=(12, 6))
for i, color in zip(unique_labels, colors):
    plt.scatter(feats_1d[labels_np == i], y_positions[labels_np == i], 
                label=f'Class {i}', color=color, alpha=0.7, edgecolors='k')

plt.title("1D t-SNE Visualization of Features")
plt.xlabel("t-SNE Component 1")
plt.ylabel("Class")
plt.yticks(range(len(unique_labels)), [f'Class {label}' for label in unique_labels])  # Set y-axis labels
plt.legend(title="Class", loc='best')
plt.grid(axis='x')
plt.show()
# Out:
# Running 1D t-SNE...
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE

# Perform t-SNE
perplexity = 30  # Tune as needed
n_iter = 1000  # Number of optimization iterations

# Convert features to NumPy array if they are in tensor form
feats_np = feats.numpy() if isinstance(feats, torch.Tensor) else feats
labels_np = labels.numpy() if isinstance(labels, torch.Tensor) else labels

# Apply 1D t-SNE
print("Running 1D t-SNE...")
tsne = TSNE(n_components=1, perplexity=perplexity, n_iter=n_iter, random_state=42)
feats_1d = tsne.fit_transform(feats_np).flatten()  # Flatten to 1D array

# Sort paths and scores in ascending order of t-SNE scores
sorted_indices = np.argsort(feats_1d)  # Get indices that would sort the scores
sorted_paths = np.array(paths)[sorted_indices]
sorted_scores = feats_1d[sorted_indices]

# Print sorted paths with corresponding t-SNE scores
print("\nPaths and t-SNE Scores (Ascending Order):")
for path, score in zip(sorted_paths, sorted_scores):
    print(f"{path}: {score:.4f}")

# Define colors for the different classes
num_classes = len(np.unique(labels_np))
colors = plt.cm.rainbow(np.linspace(0, 1, num_classes))

# Create a scatter plot in 1D
plt.figure(figsize=(12, 4))
for i, color in zip(np.unique(labels_np), colors):
    plt.scatter(sorted_scores[labels_np[sorted_indices] == i], 
                np.zeros_like(sorted_scores[labels_np[sorted_indices] == i]), 
                label=f'Class {i}', color=color, alpha=0.7, edgecolors='k')

plt.title("1D t-SNE Visualization of Features (Sorted)")
plt.xlabel("t-SNE Component 1")
plt.yticks([])  # Remove y-axis ticks for clarity
plt.legend(title="Class", loc='best')
plt.grid(axis='x')
plt.show()
# Out:
# Running 1D t-SNE...
# c:\Users\k54739\.conda\envs\master\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Paths and t-SNE Scores (Ascending Order):
# G:\classification\cond_all\sd\RBT14_C09-T01.tiff: -26.6371
# G:\classification\cond_all\sd\RBT09_B09-T01.tiff: -26.6249
# G:\classification\cond_all\sd\RBT09_D11-T01.tiff: -26.6056
# G:\classification\cond_all\sd\ds41_g5_E05-T01.tiff: -26.5780
# G:\classification\cond_all\sd\RBT09_E07-T01.tiff: -26.5095
# G:\classification\cond_all\sd\RBT09_D09-T01.tiff: -26.4762
# G:\classification\cond_all\sd\RBT09_C07-T01.tiff: -26.4194
# G:\classification\cond_all\sd\ds42_g5_E03-T01.tiff: -26.3608
# G:\classification\cond_all\sd\RBT09_B10-T01.tiff: -26.2723
# G:\classification\cond_all\sd\RBT09_E09-T01.tiff: -25.8097
# G:\classification\cond_all\sd\ds41_g5_E04-T01.tiff: -25.6992
# G:\classification\cond_all\sd\RBT04_F07-T01.tiff: -25.6432
# G:\classification\cond_all\sd\ds42_g5_E05-T01.tiff: -25.6055
# G:\classification\cond_all\sd\RBT14_C10-T01.tiff: -25.4507
# G:\classification\cond_all\sd\RBT10_F07-T01.tiff: -25.3716
# G:\classification\cond_all\sd\RBT14_B08-T01.tiff: -25.3099
# G:\classification\cond_all\sd\RBT14_D07-T01.tiff: -25.2407
# G:\classification\cond_all\sd\RBT14_D09-T01.tiff: -25.2198
# G:\classification\cond_all\sd\RBT14_D10-T01.tiff: -25.0966
# G:\classification\cond_all\sd\RBT14_B10-T01.tiff: -25.0662
# G:\classification\cond_all\sd\RBT04_E07-T01.tiff: -24.8677
# G:\classification\cond_all\sd\RBT04_C10-T01.tiff: -24.6906
# G:\classification\cond_all\sd\RBT04_C09-T01.tiff: -24.5484
# G:\classification\cond_all\sd\RBT04_B08-T01.tiff: -24.5429
# G:\classification\cond_all\sd\ds41_g2_B04-T01.tiff: -24.5175
# G:\classification\cond_all\sd\RBT04_B11-T01.tiff: -24.4944
# G:\classification\cond_all\sd\RBT04_G09-T01.tiff: -24.4865
# G:\classification\cond_all\sd\RBT04_D10-T01.tiff: -24.4837
# G:\classification\cond_all\sd\RBT14_C11-T01.tiff: -24.4570
# G:\classification\cond_all\sd\RBT14_D11-T01.tiff: -24.3909
# G:\classification\cond_all\sd\RBT04_G11-T01.tiff: -24.3327
# G:\classification\cond_all\sd\RBT04_E08-T01.tiff: -24.0586
# G:\classification\cond_all\sd\RBT09_G09-T01.tiff: -23.9658
# G:\classification\cond_all\sd\ds42_g5_E02-T01.tiff: -23.8301
# G:\classification\cond_all\sd\ds42_g5_E04-T01.tiff: -23.7991
# G:\classification\cond_all\sd\RBT04_B10-T01.tiff: -23.7899
# G:\classification\cond_all\sd\RBT09_G11-T01.tiff: -23.7098
# G:\classification\cond_all\sd\ds41_g2_B03-T01.tiff: -23.6709
# G:\classification\cond_all\sd\RBT04_E09-T01.tiff: -23.6067
# G:\classification\cond_all\sd\RBT10_D10-T01.tiff: -23.4771
# G:\classification\cond_all\sd\RBT04_B09-T01.tiff: -23.3519
# G:\classification\cond_all\sd\RBT04_C08-T01.tiff: -23.1855
# G:\classification\cond_all\sd\RBT10_C08-T01.tiff: -23.0307
# G:\classification\cond_all\sd\RBT10_B11-T01.tiff: -23.0072
# G:\classification\cond_all\sd\RBT10_C09-T01.tiff: -22.9669
# G:\classification\cond_all\sd\RBT10_E09-T01.tiff: -22.9005
# G:\classification\cond_all\sd\RBT10_D07-T01.tiff: -22.8080
# G:\classification\cond_all\sd\RBT10_B09-T01.tiff: -22.6305
# G:\classification\cond_all\sd\RBT10_B08-T01.tiff: -22.5183
# G:\classification\cond_all\sd\RBT04_G07-T01.tiff: -22.4816
# G:\classification\cond_all\sd\RBT09_D07-T01.tiff: -22.4211
# G:\classification\cond_all\sd\ds41_g2_B06-T01.tiff: -22.3987
# G:\classification\cond_all\sd\RBT14_C07-T01.tiff: -22.2832
# G:\classification\cond_all\sd\RBT04_G10-T01.tiff: -22.2279
# G:\classification\cond_all\sd\RBT09_E10-T01.tiff: -22.1890
# G:\classification\cond_all\sd\RBT14_B07-T01.tiff: -22.1602
# G:\classification\cond_all\sd\RBT10_B07-T01.tiff: -22.0051
# G:\classification\cond_all\sd\ds42_g2_B04-T01.tiff: -22.0034
# G:\classification\cond_all\sd\RBT10_G09-T01.tiff: -21.8388
# G:\classification\cond_all\sd\RBT04_D07-T01.tiff: -21.7821
# G:\classification\cond_all\sd\RBT04_F10-T01.tiff: -21.5956
# G:\classification\cond_all\sd\ds42_g2_B03-T01.tiff: -21.5667
# G:\classification\cond_all\sd\ds42_g2_B05-T01.tiff: -21.5660
# G:\classification\cond_all\sd\RBT09_C09-T01.tiff: -21.5465
# G:\classification\cond_all\sd\RBT04_D08-T01.tiff: -21.5331
# G:\classification\cond_all\sd\RBT04_C07-T01.tiff: -21.4462
# G:\classification\cond_all\sd\ds42_g2_B06-T01.tiff: -21.3637
# G:\classification\cond_all\sd\RBT04_F08-T01.tiff: -21.3616
# G:\classification\cond_all\sd\RBT04_F09-T01.tiff: -21.3461
# G:\classification\cond_all\sd\RBT04_B07-T01.tiff: -21.2594
# G:\classification\cond_all\sd\ds1b_g5_E2.tif: -21.1829
# G:\classification\cond_all\sd\RBT04_F11-T01.tiff: -21.1514
# G:\classification\cond_all\sd\RBT10_F08-T01.tiff: -21.1178
# G:\classification\cond_all\sd\RBT04_D11-T01.tiff: -21.1133
# G:\classification\cond_all\sd\RBT10_C07-T01.tiff: -20.9748
# G:\classification\cond_all\sd\RBT04_E10-T01.tiff: -20.8861
# G:\classification\cond_all\sd\RBT04_D09-T01.tiff: -20.8178
# G:\classification\cond_all\sd\ds42_g5_E06-T01.tiff: -20.7729
# G:\classification\cond_all\sd\RBT10_D11-T01.tiff: -20.5989
# G:\classification\cond_all\sd\RBT10_G11-T01.tiff: -20.5744
# G:\classification\cond_all\sd\RBT10_G08-T01.tiff: -20.5668
# G:\classification\cond_all\sd\RBT10_D08-T01.tiff: -20.5306
# G:\classification\cond_all\sd\RBT14_D08-T01.tiff: -20.3072
# G:\classification\cond_all\sd\RBT14_B09-T01.tiff: -20.2797
# G:\classification\cond_all\sd\RBT04_E11-T01.tiff: -20.1213
# G:\classification\cond_all\sd\RBT10_G07-T01.tiff: -20.1126
# G:\classification\cond_all\sd\RBT10_D09-T01.tiff: -20.1115
# G:\classification\cond_all\sd\RBT10_E11-T01.tiff: -20.0817
# G:\classification\cond_all\sd\RBT14_C08-T01.tiff: -20.0312
# G:\classification\cond_all\sd\RBT10_B10-T01.tiff: -20.0243
# G:\classification\cond_all\sd\RBT10_F10-T01.tiff: -19.7456
# G:\classification\cond_all\sd\RBT14_B11-T01.tiff: -19.6514
# G:\classification\cond_all\sd\RBT09_C11-T01.tiff: -19.6028
# G:\classification\cond_all\sd\ds1b_g5_E5.tif: -19.5902
# G:\classification\cond_all\sd\RBT10_F11-T01.tiff: -19.5414
# G:\classification\cond_all\sd\RBT09_E08-T01.tiff: -19.5000
# G:\classification\cond_all\sd\RBT10_G10-T01.tiff: -19.3552
# G:\classification\cond_all\sd\RBT09_F10-T01.tiff: -19.3138
# G:\classification\cond_all\sd\RBT09_E11-T01.tiff: -19.2438
# G:\classification\cond_all\sd\RBT09_C08-T01.tiff: -19.1204
# G:\classification\cond_all\sd\RBT09_D10-T01.tiff: -19.0928
# G:\classification\cond_all\sd\RBT09_B11-T01.tiff: -19.0571
# G:\classification\cond_all\sd\ds41_g5_E06-T01.tiff: -18.8993
# G:\classification\cond_all\sd\RBT09_F08-T01.tiff: -18.6860
# G:\classification\cond_all\sd\RBT10_C11-T01.tiff: -18.6793
# G:\classification\cond_all\sd\RBT10_E10-T01.tiff: -18.5534
# G:\classification\cond_all\sd\RBT09_G10-T01.tiff: -18.4338
# G:\classification\cond_all\sd\RBT09_G07-T01.tiff: -18.4114
# G:\classification\cond_all\sd\RBT09_F11-T01.tiff: -18.3523
# G:\classification\cond_all\sd\RBT10_C10-T01.tiff: -18.3405
# G:\classification\cond_all\sd\RBT09_D08-T01.tiff: -18.3307
# G:\classification\cond_all\sd\ds1b_g5_E4.tif: -18.2695
# G:\classification\cond_all\sd\RBT09_B07-T01.tiff: -18.2514
# G:\classification\cond_all\sd\RBT09_F09-T01.tiff: -18.1952
# G:\classification\cond_all\sd\RBT09_G08-T01.tiff: -18.1244
# G:\classification\cond_all\sd\RBT09_F07-T01.tiff: -18.0977
# G:\classification\cond_all\sd\RBT10_F09-T01.tiff: -18.0624
# G:\classification\cond_all\sd\RBT09_B08-T01.tiff: -17.7902
# G:\classification\cond_all\sd\RBT10_E07-T01.tiff: -17.6124
# G:\classification\cond_all\sd\RBT04_G08-T01.tiff: -17.5513
# G:\classification\cond_all\sd\RBT09_C10-T01.tiff: -17.3887
# G:\classification\cond_all\sd\ds62_g2_B03-T01.tiff: -17.1350
# G:\classification\cond_all\sd\ds62_g2_B02-T01.tiff: -17.1240
# G:\classification\cond_all\sd\ds62_g2_B04-T01.tiff: -17.0997
# G:\classification\cond_all\sd\ds1b_g5_E3.tif: -16.7691
# G:\classification\cond_all\ex\ds1B_g9_C11.tif: -15.2242
# G:\classification\cond_all\ex\ds1B_g9_C8.tif: -15.1985
# G:\classification\cond_all\ex\ds1B_g9_C7.tif: -15.1360
# G:\classification\cond_all\ex\ds1B_g9_c10.tif: -15.0726
# G:\classification\cond_all\ex\ds1B_g9_C9.tif: -15.0054
# G:\classification\cond_all\ex\ds41_g3_C04-T01.tiff: -14.8974
# G:\classification\cond_all\ex\ds41_g3_C02-T01.tiff: -14.7541
# G:\classification\cond_all\ex\ds41_g3_C03-T01.tiff: -14.5622
# G:\classification\cond_all\ex\ds41_g3_C05-T01.tiff: -14.5054
# G:\classification\cond_all\ex\ds41_g3_C06-T01.tiff: -14.4200
# G:\classification\cond_all\ex\ds61_g8_B07-T01.tiff: -14.3250
# G:\classification\cond_all\ex\ds61_g8_B11-T01.tiff: -14.3041
# G:\classification\cond_all\ex\ds61_g6_F04-T01.tiff: -14.0791
# G:\classification\cond_all\ex\ds61_g9_C11-T01.tiff: -14.0306
# G:\classification\cond_all\ex\ds61_g3_C05-T01.tiff: -13.9309
# G:\classification\cond_all\ex\ds61_g3_C04-T01.tiff: -13.9224
# G:\classification\cond_all\ex\ds61_g3_C06-T01.tiff: -13.9173
# G:\classification\cond_all\ex\ds61_g9_C08-T01.tiff: -13.9037
# G:\classification\cond_all\ex\ds61_g8_B08-T01.tiff: -13.8123
# G:\classification\cond_all\ex\ds61_g6_F06-T01.tiff: -13.7836
# G:\classification\cond_all\ex\ds61_g9_C07-T01.tiff: -13.7760
# G:\classification\cond_all\ex\ds61_g9_C09-T01.tiff: -13.7005
# G:\classification\cond_all\ex\ds61_g6_F03-T01.tiff: -13.6311
# G:\classification\cond_all\ex\ds61_g3_C02-T01.tiff: -13.6289
# G:\classification\cond_all\ex\ds61_g6_F02-T01.tiff: -13.6079
# G:\classification\cond_all\ex\ds61_g6_F05-T01.tiff: -13.4389
# G:\classification\cond_all\ex\ds61_g8_B10-T01.tiff: -13.4053
# G:\classification\cond_all\ex\ds61_g3_C03-T01.tiff: -13.3726
# G:\classification\cond_all\ex\ds62_g8_B10-T01.tiff: -13.3720
# G:\classification\cond_all\ex\ds61_g9_C10-T01.tiff: -12.9591
# G:\classification\cond_all\ex\ds62_g8_B11-T01.tiff: -12.9205
# G:\classification\cond_all\ex\ds61_g8_B09-T01.tiff: -12.7417
# G:\classification\cond_all\ex\ds62_g8_B09-T01.tiff: -12.5433
# G:\classification\cond_all\ex\ds62_g9_C08-T01.tiff: -12.4337
# G:\classification\cond_all\ex\ds62_g9_C11-T01.tiff: -12.2627
# G:\classification\cond_all\ex\ds62_g9_C07-T01.tiff: -12.0524
# G:\classification\cond_all\ex\ds62_g9_C10-T01.tiff: -12.0405
# G:\classification\cond_all\ex\ds62_g8_B07-T01.tiff: -11.9514
# G:\classification\cond_all\ex\ds62_g9_C09-T01.tiff: -11.9464
# G:\classification\cond_all\ex\ds41_g9_C10-T01.tiff: -11.8364
# G:\classification\cond_all\cond7_all\ds_62_B10-T01.tiff: -10.8663
# G:\classification\cond_all\cond7_all\ds_62_B08-T01.tiff: -10.5825
# G:\classification\cond_all\cond7_all\ds_61_E02-T01.tiff: -10.3865
# G:\classification\cond_all\cond7_all\ds_62_G03-T01.tiff: -10.3746
# G:\classification\cond_all\cond7_all\ds_61_B10-T01.tiff: -10.2962
# G:\classification\cond_all\cond7_all\ds_61_F02-T01.tiff: -10.2111
# G:\classification\cond_all\cond7_all\ds_62_C07-T01.tiff: -10.1877
# G:\classification\cond_all\cond7_all\ds_62_B11-T01.tiff: -10.1460
# G:\classification\cond_all\cond7_all\ds_61_C03-T01.tiff: -10.0928
# G:\classification\cond_all\cond7_all\ds_62_G09-T01.tiff: -10.0209
# G:\classification\cond_all\cond7_all\ds_61_G04-T01.tiff: -9.6950
# G:\classification\cond_all\cond7_all\ds_61_G10-T01.tiff: -9.4554
# G:\classification\cond_all\cond7_all\ds_61_D02-T01.tiff: -9.4050
# G:\classification\cond_all\cond7_all\ds_61_B03-T01.tiff: -9.3656
# G:\classification\cond_all\cond7_all\ds_62_C10-T01.tiff: -9.2761
# G:\classification\cond_all\cond7_all\ds_61_G03-T01.tiff: -9.1478
# G:\classification\cond_all\cond7_all\ds_62_C11-T01.tiff: -9.1272
# G:\classification\cond_all\cond7_all\ds_61_C02-T01.tiff: -8.9901
# G:\classification\cond_all\cond7_all\ds_62_G07-T01.tiff: -8.9676
# G:\classification\cond_all\cond7_all\ds_62_E09-T01.tiff: -8.9209
# G:\classification\cond_all\cond7_all\ds_61_F10-T01.tiff: -8.8574
# G:\classification\cond_all\cond7_all\ds_61_E06-T01.tiff: -8.8054
# G:\classification\cond_all\cond7_all\ds_61_B05-T01.tiff: -8.7820
# G:\classification\cond_all\cond7_all\ds_61_E03-T01.tiff: -8.6064
# G:\classification\cond_all\cond7_all\ds_62_D10-T01.tiff: -8.5583
# G:\classification\cond_all\cond7_all\ds_62_C09-T01.tiff: -8.3889
# G:\classification\cond_all\cond7_all\ds_62_D09-T01.tiff: -8.3694
# G:\classification\cond_all\cond7_all\ds_61_D06-T01.tiff: -8.2814
# G:\classification\cond_all\cond7_all\ds_61_F07-T01.tiff: -8.2245
# G:\classification\cond_all\cond7_all\ds_62_F10-T01.tiff: -8.1411
# G:\classification\cond_all\cond7_all\ds_61_B06-T01.tiff: -8.0608
# G:\classification\cond_all\cond7_all\ds_61_C10-T01.tiff: -8.0188
# G:\classification\cond_all\cond7_all\ds_62_E11-T01.tiff: -8.0057
# G:\classification\cond_all\cond7_all\ds_61_G09-T01.tiff: -7.9609
# G:\classification\cond_all\cond7_all\ds_61_G06-T01.tiff: -7.9070
# G:\classification\cond_all\cond7_all\ds_52_E07-T01.tiff: -7.7172
# G:\classification\cond_all\cond7_all\ds_61_C07-T01.tiff: -7.6081
# G:\classification\cond_all\cond7_all\ds_61_F11-T01.tiff: -7.4984
# G:\classification\cond_all\cond7_all\ds_52_E05-T01.tiff: -7.4953
# G:\classification\cond_all\cond7_all\ds_61_D05-T01.tiff: -7.4936
# G:\classification\cond_all\cond7_all\ds_61_F06-T01.tiff: -7.4877
# G:\classification\cond_all\cond7_all\ds_62_G10-T01.tiff: -7.4821
# G:\classification\cond_all\cond7_all\ds_61_E10-T01.tiff: -7.4057
# G:\classification\cond_all\cond7_all\ds_61_C09-T01.tiff: -7.3973
# G:\classification\cond_all\cond7_all\ds_61_E11-T01.tiff: -6.9606
# G:\classification\cond_all\cond7_all\ds_62_E07-T01.tiff: -6.8768
# G:\classification\cond_all\cond7_all\ds_62_F08-T01.tiff: -6.8592
# G:\classification\cond_all\cond7_all\ds_62_E08-T01.tiff: -6.8004
# G:\classification\cond_all\cond7_all\ds_61_D11-T01.tiff: -6.6634
# G:\classification\cond_all\cond7_all\ds_41_C07-T01.tiff: -6.6278
# G:\classification\cond_all\cond7_all\ds_41_C09-T01.tiff: -6.5878
# G:\classification\cond_all\cond7_all\ds_61_B02-T01.tiff: -6.5804
# G:\classification\cond_all\cond7_all\ds_41_B07-T01.tiff: -6.5483
# G:\classification\cond_all\cond7_all\ds_61_C05-T01.tiff: -6.3524
# G:\classification\cond_all\cond7_all\ds_62_F09-T01.tiff: -6.3397
# G:\classification\cond_all\cond7_all\ds_61_C11-T01.tiff: -6.1331
# G:\classification\cond_all\cond7_all\ds_61_E07-T01.tiff: -6.0885
# G:\classification\cond_all\cond7_all\ds_61_C04-T01.tiff: -6.0689
# G:\classification\cond_all\cond7_all\ds_61_D10-T01.tiff: -6.0346
# G:\classification\cond_all\cond7_all\ds_61_G08-T01.tiff: -5.9046
# G:\classification\cond_all\cond7_all\ds_62_F07-T01.tiff: -5.7936
# G:\classification\cond_all\cond7_all\ds_61_F05-T01.tiff: -5.7500
# G:\classification\cond_all\cond7_all\ds_62_G08-T01.tiff: -5.7250
# G:\classification\cond_all\cond7_all\ds_61_E04-T01.tiff: -5.6803
# G:\classification\cond_all\cond7_all\ds_62_G06-T01.tiff: -5.6695
# G:\classification\cond_all\cond7_all\ds_61_E05-T01.tiff: -5.6472
# G:\classification\cond_all\cond7_all\ds_61_F09-T01.tiff: -5.6031
# G:\classification\cond_all\cond7_all\ds_52_G07-T01.tiff: -5.5467
# G:\classification\cond_all\cond7_all\ds_61_D09-T01.tiff: -5.4262
# G:\classification\cond_all\cond7_all\ds_61_G05-T01.tiff: -5.4038
# G:\classification\cond_all\cond7_all\ds_62_F11-T01.tiff: -5.2323
# G:\classification\cond_all\cond7_all\ds_62_G11-T01.tiff: -4.9858
# G:\classification\cond_all\cond7_all\ds_61_B11-T01.tiff: -4.9678
# G:\classification\cond_all\cond7_all\ds_61_G07-T01.tiff: -4.7878
# G:\classification\cond_all\cond7_all\ds_52_C04-T01.tiff: -4.7630
# G:\classification\cond_all\cond7_all\ds_52_F07-T01.tiff: -4.7493
# G:\classification\cond_all\cond7_all\ds_52_G02-T01.tiff: -4.6747
# G:\classification\cond_all\cond7_all\ds_52_B02-T01.tiff: -4.5948
# G:\classification\cond_all\cond7_all\ds_52_G08-T01.tiff: -4.5698
# G:\classification\cond_all\cond7_all\ds_41_F03-T01.tiff: -4.4126
# G:\classification\cond_all\cond7_all\ds_61_D03-T01.tiff: -4.3454
# G:\classification\cond_all\cond7_all\ds_61_F04-T01.tiff: -4.2055
# G:\classification\cond_all\cond7_all\ds_52_F06-T01.tiff: -4.1493
# G:\classification\cond_all\cond7_all\ds_51_G07-T01.tiff: -3.9997
# G:\classification\cond_all\cond7_all\ds_52_F03-T01.tiff: -3.9788
# G:\classification\cond_all\cond7_all\ds_62_F04-T01.tiff: -3.9060
# G:\classification\cond_all\cond7_all\ds_52_B09-T01.tiff: -3.6548
# G:\classification\cond_all\cond7_all\ds_52_C07-T01.tiff: -3.4850
# G:\classification\cond_all\cond7_all\ds_52_E08-T01.tiff: -3.4719
# G:\classification\cond_all\cond7_all\ds_62_D08-T01.tiff: -3.3393
# G:\classification\cond_all\cond7_all\ds_52_B07-T01.tiff: -3.2587
# G:\classification\cond_all\cond7_all\ds_52_G10-T01.tiff: -3.2130
# G:\classification\cond_all\cond7_all\ds_62_D05-T01.tiff: -3.1491
# G:\classification\cond_all\cond7_all\ds_51_G08-T01.tiff: -3.0863
# G:\classification\cond_all\cond7_all\ds_52_G11-T01.tiff: -3.0832
# G:\classification\cond_all\cond7_all\ds_51_G05-T01.tiff: -2.9971
# G:\classification\cond_all\cond7_all\ds_51_F09-T01.tiff: -2.9388
# G:\classification\cond_all\cond7_all\ds_62_D03-T01.tiff: -2.9286
# G:\classification\cond_all\cond7_all\ds_52_B11-T01.tiff: -2.8676
# G:\classification\cond_all\cond7_all\ds_51_C09-T01.tiff: -2.6990
# G:\classification\cond_all\cond7_all\ds_51_F07-T01.tiff: -2.6186
# G:\classification\cond_all\cond7_all\ds_52_B03-T01.tiff: -2.6142
# G:\classification\cond_all\cond7_all\ds_51_G03-T01.tiff: -2.4561
# G:\classification\cond_all\cond7_all\ds_51_B03-T01.tiff: -2.4456
# G:\classification\cond_all\cond7_all\ds_51_C07-T01.tiff: -2.2853
# G:\classification\cond_all\cond7_all\ds_51_D11-T01.tiff: -2.2760
# G:\classification\cond_all\cond7_all\ds_62_B06-T01.tiff: -2.1546
# G:\classification\cond_all\cond7_all\ds_62_D02-T01.tiff: -2.1407
# G:\classification\cond_all\cond7_all\ds_62_E03-T01.tiff: -2.1012
# G:\classification\cond_all\cond7_all\ds_51_G04-T01.tiff: -1.7008
# G:\classification\cond_all\cond7_all\ds_62_C05-T01.tiff: -1.6985
# G:\classification\cond_all\cond7_all\ds_62_B05-T01.tiff: -1.6851
# G:\classification\cond_all\cond7_all\ds_62_B07-T01.tiff: -1.6803
# G:\classification\cond_all\cond7_all\ds_62_D04-T01.tiff: -1.6562
# G:\classification\cond_all\cond7_all\ds_51_G02-T01.tiff: -1.5990
# G:\classification\cond_all\cond7_all\ds_62_E02-T01.tiff: -1.3654
# G:\classification\cond_all\cond7_all\ds_62_C03-T01.tiff: -1.2962
# G:\classification\cond_all\cond7_all\ds_51_F04-T01.tiff: -1.2819
# G:\classification\cond_all\cond7_all\ds_52_C11-T01.tiff: -1.1362
# G:\classification\cond_all\cond7_all\ds_62_E06-T01.tiff: -0.9698
# G:\classification\cond_all\cond7_all\ds_62_E04-T01.tiff: -0.8071
# G:\classification\cond_all\cond7_all\ds_62_D06-T01.tiff: -0.7900
# G:\classification\cond_all\cond7_all\ds_62_F06-T01.tiff: -0.7819
# G:\classification\cond_all\cond7_all\ds_62_G05-T01.tiff: -0.6932
# G:\classification\cond_all\cond7_all\ds_52_C09-T01.tiff: -0.6802
# G:\classification\cond_all\cond7_all\ds_62_C04-T01.tiff: -0.6783
# G:\classification\cond_all\cond7_all\ds_52_D08-T01.tiff: -0.5911
# G:\classification\cond_all\cond7_all\ds_51_C05-T01.tiff: -0.5764
# G:\classification\cond_all\cond7_all\ds_62_B04-T01.tiff: -0.5085
# G:\classification\cond_all\cond7_all\ds_62_E05-T01.tiff: -0.4689
# G:\classification\cond_all\cond7_all\ds_52_F09-T01.tiff: -0.2227
# G:\classification\cond_all\cond7_all\ds_62_F05-T01.tiff: -0.1541
# G:\classification\cond_all\cond7_all\ds_51_D06-T01.tiff: -0.0720
# G:\classification\cond_all\cond7_all\ds_52_D10-T01.tiff: 0.0502
# G:\classification\cond_all\cond7_all\ds_51_F05-T01.tiff: 0.0621
# G:\classification\cond_all\cond7_all\ds_52_F10-T01.tiff: 0.0773
# G:\classification\cond_all\cond7_all\ds_62_G02-T01.tiff: 0.1082
# G:\classification\cond_all\cond7_all\ds_62_G04-T01.tiff: 0.1183
# G:\classification\cond_all\cond7_all\ds_51_F06-T01.tiff: 0.2257
# G:\classification\cond_all\cond7_all\ds_62_F02-T01.tiff: 0.3007
# G:\classification\cond_all\cond7_all\ds_51_E06-T01.tiff: 0.3129
# G:\classification\cond_all\cond7_all\ds_62_C02-T01.tiff: 0.4194
# G:\classification\cond_all\cond7_all\ds_51_G06-T01.tiff: 0.4976
# G:\classification\cond_all\cond7_all\ds_51_E08-T01.tiff: 0.7573
# G:\classification\cond_all\cond7_all\ds_51_E03-T01.tiff: 0.8040
# G:\classification\cond_all\cond7_all\ds_51_F03-T01.tiff: 0.8159
# G:\classification\cond_all\cond7_all\ds_51_F02-T01.tiff: 0.8422
# G:\classification\cond_all\cond7_all\ds_51_E02-T01.tiff: 0.8660
# G:\classification\cond_all\cond7_all\ds_51_E10-T01.tiff: 0.8926
# G:\classification\cond_all\cond7_all\ds_51_G10-T01.tiff: 0.9045
# G:\classification\cond_all\cond7_all\ds_51_D10-T01.tiff: 0.9938
# G:\classification\cond_all\cond7_all\ds_51_D07-T01.tiff: 1.0948
# G:\classification\cond_all\cond7_all\ds_51_C08-T01.tiff: 1.1794
# G:\classification\cond_all\cond7_all\ds_51_F08-T01.tiff: 1.2751
# G:\classification\cond_all\cond7_all\ds_51_C06-T01.tiff: 1.2777
# G:\classification\cond_all\cond7_all\ds_62_B09-T01.tiff: 1.2995
# G:\classification\cond_all\cond7_all\ds_51_B06-T01.tiff: 1.3674
# G:\classification\cond_all\cond7_all\ds_51_B05-T01.tiff: 1.4762
# G:\classification\cond_all\cond7_all\ds_62_B02-T01.tiff: 1.6535
# G:\classification\cond_all\cond7_all\ds_51_B11-T01.tiff: 1.6668
# G:\classification\cond_all\cond7_all\ds_51_B09-T01.tiff: 1.6874
# G:\classification\cond_all\cond7_all\ds_51_D02-T01.tiff: 1.8695
# G:\classification\cond_all\cond7_all\ds_51_C10-T01.tiff: 1.9108
# G:\classification\cond_all\cond7_all\ds_51_B10-T01.tiff: 1.9653
# G:\classification\cond_all\cond7_all\ds_51_D04-T01.tiff: 2.0482
# G:\classification\cond_all\cond7_all\ds_51_B08-T01.tiff: 2.0901
# G:\classification\cond_all\cond7_all\ds_51_E11-T01.tiff: 2.2735
# G:\classification\cond_all\cond7_all\ds_51_D03-T01.tiff: 2.3116
# G:\classification\cond_all\cond7_all\ds_51_G09-T01.tiff: 2.3818
# G:\classification\cond_all\cond7_all\ds_51_F10-T01.tiff: 2.4252
# G:\classification\cond_all\cond7_all\ds_51_B02-T01.tiff: 2.4661
# G:\classification\cond_all\cond7_all\ds_51_C03-T01.tiff: 2.5149
# G:\classification\cond_all\cond7_all\ds_51_C02-T01.tiff: 2.5338
# G:\classification\cond_all\cond7_all\ds_51_B07-T01.tiff: 2.6161
# G:\classification\cond_all\cond7_all\ds_51_D05-T01.tiff: 2.6743
# G:\classification\cond_all\cond7_all\ds_51_C04-T01.tiff: 2.7126
# G:\classification\cond_all\cond7_all\ds_51_D09-T01.tiff: 2.7973
# G:\classification\cond_all\cond7_all\ds_51_E04-T01.tiff: 2.8027
# G:\classification\cond_all\cond7_all\ds_62_B03-T01.tiff: 2.8614
# G:\classification\cond_all\cond7_all\ds_52_G06-T01.tiff: 2.9397
# G:\classification\cond_all\cond7_all\ds_52_D11-T01.tiff: 3.0238
# G:\classification\cond_all\cond7_all\ds_51_F11-T01.tiff: 3.0544
# G:\classification\cond_all\cond7_all\ds_52_G09-T01.tiff: 3.2108
# G:\classification\cond_all\cond7_all\ds_52_B06-T01.tiff: 3.3030
# G:\classification\cond_all\cond7_all\ds_52_D04-T01.tiff: 3.3585
# G:\classification\cond_all\cond7_all\ds_42_B06-T01.tiff: 3.4211
# G:\classification\cond_all\cond7_all\ds_51_E05-T01.tiff: 3.4545
# G:\classification\cond_all\cond7_all\ds_52_D06-T01.tiff: 3.5216
# G:\classification\cond_all\cond7_all\ds_42_D02-T01.tiff: 3.5991
# G:\classification\cond_all\cond7_all\ds_52_E09-T01.tiff: 3.6084
# G:\classification\cond_all\cond7_all\ds_62_C06-T01.tiff: 3.7975
# G:\classification\cond_all\cond7_all\ds_62_D07-T01.tiff: 3.9023
# G:\classification\cond_all\cond7_all\ds_52_C08-T01.tiff: 3.9770
# G:\classification\cond_all\cond7_all\ds_52_D07-T01.tiff: 3.9776
# G:\classification\cond_all\cond7_all\ds_52_E10-T01.tiff: 4.0033
# G:\classification\cond_all\cond7_all\ds_52_F11-T01.tiff: 4.1602
# G:\classification\cond_all\cond7_all\ds_52_F08-T01.tiff: 4.2210
# G:\classification\cond_all\cond7_all\ds_42_G10-T01.tiff: 4.2756
# G:\classification\cond_all\cond7_all\ds_52_F02-T01.tiff: 4.2840
# G:\classification\cond_all\cond7_all\ds_52_D09-T01.tiff: 4.4071
# G:\classification\cond_all\cond7_all\ds_52_B10-T01.tiff: 4.6031
# G:\classification\cond_all\cond7_all\ds_52_C02-T01.tiff: 4.8351
# G:\classification\cond_all\cond7_all\ds_51_C11-T01.tiff: 5.2107
# G:\classification\cond_all\cond7_all\ds_51_G11-T01.tiff: 5.2384
# G:\classification\cond_all\cond7_all\ds_61_C08-T01.tiff: 5.2795
# G:\classification\cond_all\cond7_all\ds_61_E09-T01.tiff: 5.3404
# G:\classification\cond_all\cond7_all\ds_52_B05-T01.tiff: 5.3963
# G:\classification\cond_all\cond7_all\ds_61_D07-T01.tiff: 5.4257
# G:\classification\cond_all\cond7_all\ds_42_F09-T01.tiff: 5.5880
# G:\classification\cond_all\cond7_all\ds_61_B07-T01.tiff: 5.6131
# G:\classification\cond_all\cond7_all\ds_41_D07-T01.tiff: 5.7171
# G:\classification\cond_all\cond7_all\ds_42_D04-T01.tiff: 5.8164
# G:\classification\cond_all\cond7_all\ds_42_F02-T01.tiff: 5.9196
# G:\classification\cond_all\cond7_all\ds_41_G02-T01.tiff: 5.9544
# G:\classification\cond_all\cond7_all\ds_41_E11-T01.tiff: 6.0514
# G:\classification\cond_all\cond7_all\ds_41_C02-T01.tiff: 6.0895
# G:\classification\cond_all\cond7_all\ds_41_B05-T01.tiff: 6.2365
# G:\classification\cond_all\cond7_all\ds_52_G04-T01.tiff: 6.3911
# G:\classification\cond_all\cond7_all\ds_41_D04-T01.tiff: 6.4733
# G:\classification\cond_all\cond7_all\ds_52_E11-T01.tiff: 6.5498
# G:\classification\cond_all\cond7_all\ds_52_E04-T01.tiff: 6.6787
# G:\classification\cond_all\cond7_all\ds_52_E03-T01.tiff: 6.6974
# G:\classification\cond_all\cond7_all\ds_41_D06-T01.tiff: 6.7017
# G:\classification\cond_all\cond7_all\ds_41_C10-T01.tiff: 6.7421
# G:\classification\cond_all\cond7_all\ds_41_C06-T01.tiff: 6.7839
# G:\classification\cond_all\cond7_all\ds_42_G05-T01.tiff: 7.0577
# G:\classification\cond_all\cond7_all\ds_52_C10-T01.tiff: 7.1513
# G:\classification\cond_all\cond7_all\ds_41_B09-T01.tiff: 7.2157
# G:\classification\cond_all\cond7_all\ds_41_D10-T01.tiff: 7.2297
# G:\classification\cond_all\cond7_all\ds_41_B08-T01.tiff: 7.3062
# G:\classification\cond_all\cond7_all\ds_52_E06-T01.tiff: 7.4181
# G:\classification\cond_all\cond7_all\ds_41_E02-T01.tiff: 7.4919
# G:\classification\cond_all\cond7_all\ds_52_D05-T01.tiff: 7.5854
# G:\classification\cond_all\cond7_all\sd_04_D11-T01.tiff: 7.7559
# G:\classification\cond_all\cond7_all\ds_41_G05-T01.tiff: 7.7773
# G:\classification\cond_all\cond7_all\ds_42_G06-T01.tiff: 7.8541
# G:\classification\cond_all\cond7_all\ds_41_G09-T01.tiff: 7.8906
# G:\classification\cond_all\cond7_all\ds_42_E06-T01.tiff: 7.9738
# G:\classification\cond_all\cond7_all\ds_41_F06-T01.tiff: 8.0256
# G:\classification\cond_all\cond7_all\ds_52_D02-T01.tiff: 8.0685
# G:\classification\cond_all\cond7_all\ds_52_C05-T01.tiff: 8.1031
# G:\classification\cond_all\cond7_all\ds_41_G10-T01.tiff: 8.1265
# G:\classification\cond_all\cond7_all\ds_52_B08-T01.tiff: 8.2440
# G:\classification\cond_all\cond7_all\ds_52_D03-T01.tiff: 8.3409
# G:\classification\cond_all\cond7_all\ds_41_C11-T01.tiff: 8.3591
# G:\classification\cond_all\cond7_all\ds_41_G06-T01.tiff: 8.3969
# G:\classification\cond_all\cond7_all\ds_41_E08-T01.tiff: 8.4007
# G:\classification\cond_all\cond7_all\ds_41_G08-T01.tiff: 8.4260
# G:\classification\cond_all\cond7_all\ds_52_C06-T01.tiff: 8.4925
# G:\classification\cond_all\cond7_all\ds_42_G09-T01.tiff: 8.5301
# G:\classification\cond_all\cond7_all\ds_41_F08-T01.tiff: 8.7444
# G:\classification\cond_all\cond7_all\ds_61_F08-T01.tiff: 8.8366
# G:\classification\cond_all\cond7_all\ds_61_E08-T01.tiff: 8.8507
# G:\classification\cond_all\cond7_all\ds_42_E04-T01.tiff: 8.8718
# G:\classification\cond_all\cond7_all\ds_42_F04-T01.tiff: 9.1737
# G:\classification\cond_all\cond7_all\ds_42_G08-T01.tiff: 9.2129
# G:\classification\cond_all\cond7_all\ds_41_F11-T01.tiff: 9.2143
# G:\classification\cond_all\cond7_all\ds_42_F10-T01.tiff: 9.3190
# G:\classification\cond_all\cond7_all\ds_41_G11-T01.tiff: 9.3541
# G:\classification\cond_all\cond7_all\ds_42_F06-T01.tiff: 9.3774
# G:\classification\cond_all\cond7_all\ds_42_F07-T01.tiff: 9.4176
# G:\classification\cond_all\cond7_all\ds_42_G11-T01.tiff: 9.5300
# G:\classification\cond_all\cond7_all\ds_41_B06-T01.tiff: 9.5527
# G:\classification\cond_all\cond7_all\ds_52_G03-T01.tiff: 9.7926
# G:\classification\cond_all\cond7_all\ds_42_F11-T01.tiff: 9.8378
# G:\classification\cond_all\cond7_all\ds_42_E11-T01.tiff: 9.9499
# G:\classification\cond_all\cond7_all\ds_41_C03-T01.tiff: 10.0691
# G:\classification\cond_all\cond7_all\ds_42_G07-T01.tiff: 10.0969
# G:\classification\cond_all\cond7_all\ds_42_F08-T01.tiff: 10.2495
# G:\classification\cond_all\cond7_all\ds_41_C04-T01.tiff: 10.2741
# G:\classification\cond_all\cond7_all\ds_42_E07-T01.tiff: 10.2814
# G:\classification\cond_all\cond7_all\ds_41_C05-T01.tiff: 10.2946
# G:\classification\cond_all\cond7_all\ds_42_E08-T01.tiff: 10.3245
# G:\classification\cond_all\cond7_all\ds_42_C04-T01.tiff: 10.3714
# G:\classification\cond_all\cond7_all\ds_42_D10-T01.tiff: 10.4569
# G:\classification\cond_all\cond7_all\ds_42_D11-T01.tiff: 10.7064
# G:\classification\cond_all\cond7_all\ds_42_E09-T01.tiff: 10.7328
# G:\classification\cond_all\cond7_all\ds_42_C03-T01.tiff: 10.8001
# G:\classification\cond_all\cond7_all\ds_42_C10-T01.tiff: 10.8551
# G:\classification\cond_all\cond7_all\ds_41_D08-T01.tiff: 10.8726
# G:\classification\cond_all\cond7_all\ds_42_C02-T01.tiff: 10.8771
# G:\classification\cond_all\cond7_all\ds_42_D09-T01.tiff: 10.9186
# G:\classification\cond_all\cond7_all\ds_51_E07-T01.tiff: 10.9753
# G:\classification\cond_all\cond7_all\ds_42_D07-T01.tiff: 11.0005
# G:\classification\cond_all\cond7_all\ds_42_B03-T01.tiff: 11.0982
# G:\classification\cond_all\cond7_all\ds_42_B10-T01.tiff: 11.1346
# G:\classification\cond_all\cond7_all\ds_61_D08-T01.tiff: 11.2524
# G:\classification\cond_all\cond7_all\ds_62_D11-T01.tiff: 11.3462
# G:\classification\cond_all\cond7_all\ds_42_B05-T01.tiff: 11.4619
# G:\classification\cond_all\cond7_all\ds_42_C09-T01.tiff: 11.5093
# G:\classification\cond_all\cond7_all\ds_41_G07-T01.tiff: 11.8190
# G:\classification\cond_all\cond7_all\ds_41_F09-T01.tiff: 11.8770
# G:\classification\cond_all\cond7_all\ds_42_E02-T01.tiff: 11.9339
# G:\classification\cond_all\cond7_all\ds_42_E05-T01.tiff: 11.9768
# G:\classification\cond_all\cond7_all\ds_41_F05-T01.tiff: 12.0823
# G:\classification\cond_all\cond7_all\ds_42_C08-T01.tiff: 12.0952
# G:\classification\cond_all\cond7_all\ds_61_C06-T01.tiff: 12.1437
# G:\classification\cond_all\cond7_all\ds_41_B11-T01.tiff: 12.1713
# G:\classification\cond_all\cond7_all\ds_41_D02-T01.tiff: 12.2363
# G:\classification\cond_all\cond7_all\ds_62_C08-T01.tiff: 12.2541
# G:\classification\cond_all\cond7_all\ds_61_D04-T01.tiff: 12.2694
# G:\classification\cond_all\cond7_all\ds_61_F03-T01.tiff: 12.3238
# G:\classification\cond_all\cond7_all\ds_61_B09-T01.tiff: 12.6844
# G:\classification\cond_all\cond7_all\ds_41_E07-T01.tiff: 12.8217
# G:\classification\cond_all\cond7_all\ds_61_G02-T01.tiff: 12.8529
# G:\classification\cond_all\cond7_all\ds_61_G11-T01.tiff: 13.0084
# G:\classification\cond_all\cond7_all\ds_52_C03-T01.tiff: 13.1163
# G:\classification\cond_all\cond7_all\ds_41_E04-T01.tiff: 13.1180
# G:\classification\cond_all\cond7_all\ds_41_C08-T01.tiff: 13.1904
# G:\classification\cond_all\cond7_all\ds_41_D09-T01.tiff: 13.3021
# G:\classification\cond_all\cond7_all\ds_42_B08-T01.tiff: 13.4869
# G:\classification\cond_all\cond7_all\ds_52_E02-T01.tiff: 13.5158
# G:\classification\cond_all\cond7_all\ds_41_F10-T01.tiff: 13.5490
# G:\classification\cond_all\cond7_all\ds_62_E10-T01.tiff: 13.9229
# G:\classification\cond_all\cond7_all\ds_41_E06-T01.tiff: 13.9885
# G:\classification\cond_all\cond7_all\sd_04_D09-T01.tiff: 14.0134
# G:\classification\cond_all\cond7_all\sd_04_E11-T01.tiff: 14.0400
# G:\classification\cond_all\cond7_all\sd_04_B09-T01.tiff: 14.0427
# G:\classification\cond_all\cond7_all\sd_04_B10-T01.tiff: 14.0589
# G:\classification\cond_all\cond7_all\sd_04_D06-T01.tiff: 14.0631
# G:\classification\cond_all\cond7_all\sd_04_C04-T01.tiff: 14.0850
# G:\classification\cond_all\cond7_all\sd_04_E10-T01.tiff: 14.1161
# G:\classification\cond_all\cond7_all\ds_41_D11-T01.tiff: 14.1753
# G:\classification\cond_all\cond7_all\ds_41_E05-T01.tiff: 14.3925
# G:\classification\cond_all\cond7_all\sd_04_C11-T01.tiff: 14.5320
# G:\classification\cond_all\cond7_all\ds_52_B04-T01.tiff: 14.6493
# G:\classification\cond_all\cond7_all\ds_41_G04-T01.tiff: 14.7177
# G:\classification\cond_all\cond7_all\sd_04_B04-T01.tiff: 14.8012
# G:\classification\cond_all\cond7_all\ds_52_F04-T01.tiff: 14.8485
# G:\classification\cond_all\cond7_all\ds_52_F05-T01.tiff: 14.8499
# G:\classification\cond_all\cond7_all\ds_41_B03-T01.tiff: 15.0270
# G:\classification\cond_all\cond7_all\sd_04_B06-T01.tiff: 15.2348
# G:\classification\cond_all\cond7_all\ds_41_E03-T01.tiff: 15.2408
# G:\classification\cond_all\cond7_all\ds_41_F07-T01.tiff: 15.4102
# G:\classification\cond_all\cond7_all\ds_41_E10-T01.tiff: 15.4307
# G:\classification\cond_all\cond7_all\sd_04_F09-T01.tiff: 15.6186
# G:\classification\cond_all\cond7_all\ds_42_G04-T01.tiff: 15.6538
# G:\classification\cond_all\cond7_all\sd_04_F11-T01.tiff: 15.7709
# G:\classification\cond_all\cond7_all\sd_04_F10-T01.tiff: 15.7719
# G:\classification\cond_all\cond7_all\ds_41_F04-T01.tiff: 15.8139
# G:\classification\cond_all\cond7_all\sd_04_G09-T01.tiff: 15.8724
# G:\classification\cond_all\cond7_all\ds_42_D06-T01.tiff: 15.8910
# G:\classification\cond_all\cond7_all\sd_04_B07-T01.tiff: 15.9925
# G:\classification\cond_all\cond7_all\sd_04_C06-T01.tiff: 16.1073
# G:\classification\cond_all\cond7_all\ds_1B_D10-T01.tiff: 16.2544
# G:\classification\cond_all\cond7_all\ds_1B_E11-T01.tiff: 16.2814
# G:\classification\cond_all\cond7_all\ds_1B_F09-T01.tiff: 16.3475
# G:\classification\cond_all\cond7_all\ds_41_F02-T01.tiff: 16.4580
# G:\classification\cond_all\cond7_all\ds_41_D03-T01.tiff: 16.4687
# G:\classification\cond_all\cond7_all\sd_04_G04-T01.tiff: 16.4885
# G:\classification\cond_all\cond7_all\ds_1B_G05-T01.tiff: 16.5336
# G:\classification\cond_all\cond7_all\ds_42_F03-T01.tiff: 16.6341
# G:\classification\cond_all\cond7_all\sd_04_G03-T01.tiff: 16.7517
# G:\classification\cond_all\cond7_all\ds_42_E03-T01.tiff: 16.8454
# G:\classification\cond_all\cond7_all\sd_04_G02-T01.tiff: 16.8837
# G:\classification\cond_all\cond7_all\sd_04_G08-T01.tiff: 16.9839
# G:\classification\cond_all\cond7_all\ds_42_G02-T01.tiff: 17.1790
# G:\classification\cond_all\cond7_all\ds_42_C05-T01.tiff: 17.2389
# G:\classification\cond_all\cond7_all\ds_42_C06-T01.tiff: 17.3201
# G:\classification\cond_all\cond7_all\sd_04_E09-T01.tiff: 17.3508
# G:\classification\cond_all\cond7_all\ds_42_C11-T01.tiff: 17.5582
# G:\classification\cond_all\cond7_all\ds_42_B09-T01.tiff: 17.5883
# G:\classification\cond_all\cond7_all\ds_42_B11-T01.tiff: 17.7618
# G:\classification\cond_all\cond7_all\ds_1B_B02-T01.tiff: 17.8337
# G:\classification\cond_all\cond7_all\ds_41_B04-T01.tiff: 17.9311
# G:\classification\cond_all\cond7_all\ds_42_B07-T01.tiff: 17.9515
# G:\classification\cond_all\cond7_all\ds_42_E10-T01.tiff: 17.9658
# G:\classification\cond_all\cond7_all\sd_04_C02-T01.tiff: 18.1997
# G:\classification\cond_all\cond7_all\ds_42_D03-T01.tiff: 18.3039
# G:\classification\cond_all\cond7_all\ds_42_B02-T01.tiff: 18.3401
# G:\classification\cond_all\cond7_all\ds_1B_B10-T01.tiff: 18.3965
# G:\classification\cond_all\cond7_all\sd_04_B11-T01.tiff: 18.4522
# G:\classification\cond_all\cond7_all\ds_42_B04-T01.tiff: 18.5692
# G:\classification\cond_all\cond7_all\sd_04_B03-T01.tiff: 18.5938
# G:\classification\cond_all\cond7_all\ds_1B_F04-T01.tiff: 18.6199
# G:\classification\cond_all\cond7_all\sd_04_C05-T01.tiff: 18.7623
# G:\classification\cond_all\cond7_all\sd_04_E06-T01.tiff: 18.8183
# G:\classification\cond_all\cond7_all\sd_04_F04-T01.tiff: 18.8939
# G:\classification\cond_all\cond7_all\sd_04_D02-T01.tiff: 18.9019
# G:\classification\cond_all\cond7_all\sd_04_E04-T01.tiff: 18.9533
# G:\classification\cond_all\cond7_all\ds_1B_G09-T01.tiff: 18.9922
# G:\classification\cond_all\cond7_all\ds_1B_E04-T01.tiff: 19.0602
# G:\classification\cond_all\cond7_all\ds_1B_F03-T01.tiff: 19.0740
# G:\classification\cond_all\cond7_all\ds_1B_C03-T01.tiff: 19.1166
# G:\classification\cond_all\cond7_all\sd_04_G05-T01.tiff: 19.1387
# G:\classification\cond_all\cond7_all\ds_1B_E07-T01.tiff: 19.2090
# G:\classification\cond_all\cond7_all\sd_04_D05-T01.tiff: 19.2230
# G:\classification\cond_all\cond7_all\ds_1B_C08-T01.tiff: 19.3964
# G:\classification\cond_all\cond7_all\ds_1B_F02-T01.tiff: 19.4137
# G:\classification\cond_all\cond7_all\ds_1B_G06-T01.tiff: 19.4523
# G:\classification\cond_all\cond7_all\ds_1B_G04-T01.tiff: 19.4652
# G:\classification\cond_all\cond7_all\sd_04_C03-T01.tiff: 19.5447
# G:\classification\cond_all\cond7_all\sd_04_B08-T01.tiff: 19.7796
# G:\classification\cond_all\cond7_all\sd_04_F03-T01.tiff: 19.8169
# G:\classification\cond_all\cond7_all\ds_51_D08-T01.tiff: 19.9916
# G:\classification\cond_all\cond7_all\ds_1B_F05-T01.tiff: 20.0884
# G:\classification\cond_all\cond7_all\ds_51_E09-T01.tiff: 20.1378
# G:\classification\cond_all\cond7_all\sd_04_C08-T01.tiff: 20.1914
# G:\classification\cond_all\cond7_all\sd_04_F06-T01.tiff: 20.3074
# G:\classification\cond_all\cond7_all\ds_1B_E06-T01.tiff: 20.3285
# G:\classification\cond_all\cond7_all\ds_1B_E02-T01.tiff: 20.3521
# G:\classification\cond_all\cond7_all\ds_41_B10-T01.tiff: 20.4293
# G:\classification\cond_all\cond7_all\ds_1B_B05-T01.tiff: 20.6933
# G:\classification\cond_all\cond7_all\ds_41_E09-T01.tiff: 20.7041
# G:\classification\cond_all\cond7_all\ds_1B_D08-T01.tiff: 20.7493
# G:\classification\cond_all\cond7_all\ds_42_D08-T01.tiff: 20.7685
# G:\classification\cond_all\cond7_all\sd_04_G11-T01.tiff: 20.7925
# G:\classification\cond_all\cond7_all\ds_42_C07-T01.tiff: 20.8769
# G:\classification\cond_all\cond7_all\ds_1B_E09-T01.tiff: 20.9016
# G:\classification\cond_all\cond7_all\ds_1B_D07-T01.tiff: 20.9567
# G:\classification\cond_all\cond7_all\sd_04_C10-T01.tiff: 21.0476
# G:\classification\cond_all\cond7_all\sd_04_D10-T01.tiff: 21.0492
# G:\classification\cond_all\cond7_all\sd_04_C09-T01.tiff: 21.0877
# G:\classification\cond_all\cond7_all\sd_04_G06-T01.tiff: 21.2636
# G:\classification\cond_all\cond7_all\ds_1B_B07-T01.tiff: 21.3031
# G:\classification\cond_all\cond7_all\ds_52_G05-T01.tiff: 21.3104
# G:\classification\cond_all\cond7_all\sd_04_D08-T01.tiff: 21.4713
# G:\classification\cond_all\cond7_all\ds_41_D05-T01.tiff: 21.5006
# G:\classification\cond_all\cond7_all\ds_1B_F11-T01.tiff: 21.5989
# G:\classification\cond_all\cond7_all\sd_04_B05-T01.tiff: 21.6942
# G:\classification\cond_all\cond7_all\ds_1B_B06-T01.tiff: 21.7114
# G:\classification\cond_all\cond7_all\sd_04_D07-T01.tiff: 21.8072
# G:\classification\cond_all\cond7_all\ds_42_F05-T01.tiff: 21.8387
# G:\classification\cond_all\cond7_all\ds_1B_C06-T01.tiff: 21.9038
# G:\classification\cond_all\cond7_all\ds_1B_E05-T01.tiff: 21.9655
# G:\classification\cond_all\cond7_all\ds_1B_F06-T01.tiff: 21.9757
# G:\classification\cond_all\cond7_all\ds_1B_D11-T01.tiff: 22.1235
# G:\classification\cond_all\cond7_all\ds_1B_D05-T01.tiff: 22.2316
# G:\classification\cond_all\cond7_all\ds_1B_B08-T01.tiff: 22.2438
# G:\classification\cond_all\cond7_all\sd_04_D03-T01.tiff: 22.4159
# G:\classification\cond_all\cond7_all\ds_1B_E03-T01.tiff: 22.4711
# G:\classification\cond_all\cond7_all\ds_1B_B11-T01.tiff: 22.4973
# G:\classification\cond_all\cond7_all\ds_1B_C09-T01.tiff: 22.5133
# G:\classification\cond_all\cond7_all\ds_1B_G03-T01.tiff: 22.5495
# G:\classification\cond_all\cond7_all\sd_04_F08-T01.tiff: 22.7452
# G:\classification\cond_all\cond7_all\ds_1B_C10-T01.tiff: 22.8050
# G:\classification\cond_all\cond7_all\ds_1B_G07-T01.tiff: 22.8289
# G:\classification\cond_all\cond7_all\ds_1B_C02-T01.tiff: 22.8459
# G:\classification\cond_all\cond7_all\ds_1B_F10-T01.tiff: 22.8576
# G:\classification\cond_all\cond7_all\sd_04_E02-T01.tiff: 22.8954
# G:\classification\cond_all\cond7_all\ds_1B_E10-T01.tiff: 22.9481
# G:\classification\cond_all\cond7_all\ds_42_D05-T01.tiff: 23.0252
# G:\classification\cond_all\cond7_all\sd_04_C07-T01.tiff: 23.0936
# G:\classification\cond_all\cond7_all\sd_04_F05-T01.tiff: 23.1883
# G:\classification\cond_all\cond7_all\sd_04_E08-T01.tiff: 23.4837
# G:\classification\cond_all\cond7_all\ds_1B_F07-T01.tiff: 23.5101
# G:\classification\cond_all\cond7_all\ds_1B_D09-T01.tiff: 23.6074
# G:\classification\cond_all\cond7_all\ds_1B_C05-T01.tiff: 23.7323
# G:\classification\cond_all\cond7_all\ds_1B_D04-T01.tiff: 23.8411
# G:\classification\cond_all\cond7_all\ds_1B_G08-T01.tiff: 23.8649
# G:\classification\cond_all\cond7_all\ds_1B_D03-T01.tiff: 23.9433
# G:\classification\cond_all\cond7_all\sd_04_F02-T01.tiff: 23.9552
# G:\classification\cond_all\cond7_all\ds_1B_C07-T01.tiff: 23.9837
# G:\classification\cond_all\cond7_all\ds_1B_C11-T01.tiff: 23.9854
# G:\classification\cond_all\cond7_all\ds_1B_E08-T01.tiff: 24.1880
# G:\classification\cond_all\cond7_all\sd_04_E07-T01.tiff: 24.2362
# G:\classification\cond_all\cond7_all\sd_04_G07-T01.tiff: 24.3593
# G:\classification\cond_all\cond7_all\sd_04_E03-T01.tiff: 24.3872
# G:\classification\cond_all\cond7_all\ds_1B_G10-T01.tiff: 24.4372
# G:\classification\cond_all\cond7_all\ds_1B_D06-T01.tiff: 24.5985
# G:\classification\cond_all\cond7_all\sd_04_F07-T01.tiff: 24.7395
# G:\classification\cond_all\cond7_all\ds_1B_B04-T01.tiff: 24.7705
# G:\classification\cond_all\cond7_all\ds_1B_B03-T01.tiff: 25.0084
# G:\classification\cond_all\cond7_all\ds_1B_F08-T01.tiff: 25.1738
# G:\classification\cond_all\cond7_all\sd_04_D04-T01.tiff: 25.4166
# G:\classification\cond_all\cond7_all\sd_04_E05-T01.tiff: 25.4610
# G:\classification\cond_all\cond7_all\ds_1B_G02-T01.tiff: 25.6767
# G:\classification\cond_all\cond7_all\ds_1B_B09-T01.tiff: 25.8153
# G:\classification\cond_all\cond7_all\ds_1B_D02-T01.tiff: 25.9425
# G:\classification\cond_all\cond7_all\ds_1B_C04-T01.tiff: 25.9669
# G:\classification\cond_all\cond7_all\sd_04_B02-T01.tiff: 25.9758
# G:\classification\cond_all\cond7_all\ds_1B_G11-T01.tiff: 26.0650

# %% [markdown]
# import torch
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import StandardScaler
#
# # Convert PyTorch tensors to NumPy arrays
# feats_np = feats.numpy()
# labels_np = labels.numpy()
#
# # Standardize features before PCA
# scaler = StandardScaler()
# feats_scaled = scaler.fit_transform(feats_np)
#
# # Apply PCA
# pca = PCA(n_components=2)
# feats_pca = pca.fit_transform(feats_scaled)
#
# # Plot PCA results
# plt.figure(figsize=(8, 6))
# scatter = plt.scatter(feats_pca[:, 0], feats_pca[:, 1], c=labels_np, cmap='viridis', alpha=0.7)
# plt.colorbar(scatter, label='Class Labels')
# plt.xlabel('PCA Component 1')
# plt.ylabel('PCA Component 2')
# plt.title('PCA Visualization of SimCLR Features')
# plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Convert PyTorch tensors to NumPy arrays
feats_np = feats.numpy()
labels_np = labels.numpy()

# Standardize features before PCA
scaler = StandardScaler()
feats_scaled = scaler.fit_transform(feats_np)

# Apply PCA
pca = PCA(n_components=2)
feats_pca = pca.fit_transform(feats_scaled)

# Plot PCA results
plt.figure(figsize=(8, 6))
scatter = plt.scatter(feats_pca[:, 0], feats_pca[:, 1], c=labels_np, cmap='viridis', alpha=0.7)
plt.colorbar(scatter, label='Class Labels')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA Visualization of SimCLR Features')

# Create legend
unique_labels = np.unique(labels_np)
colors = [scatter.cmap(scatter.norm(label)) for label in unique_labels]
legend_labels = [f'Class {label}' for label in unique_labels]
plt.legend(handles=[plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) for color in colors], labels=legend_labels, title='Classes')

plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Convert PyTorch tensors to NumPy arrays and prepare data
feats_np = feats.numpy()
scaler = StandardScaler()
feats_scaled = scaler.fit_transform(feats_np)

# Apply PCA
pca = PCA()
pca.fit(feats_scaled)

# Get first 10 components of explained variance ratio
explained_var_ratio = pca.explained_variance_ratio_[:10]

# Create the bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(range(1, 11), explained_var_ratio, alpha=0.8, color='blue')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot (First 10 Principal Components)')
plt.grid(True, alpha=0.3)

# Add percentage labels on top of each bar
for i, v in enumerate(explained_var_ratio):
    plt.text(i + 1, v, f'{v*100:.1f}%', ha='center', va='bottom')

# Print cumulative explained variance
cumulative_var = np.cumsum(explained_var_ratio)
print("\nCumulative Explained Variance:")
for i, cum_var in enumerate(cumulative_var, 1):
    print(f"PC1 to PC{i}: {cum_var*100:.1f}%")

plt.tight_layout()
plt.show()
# Out:
# Cumulative Explained Variance:
# PC1 to PC1: 12.3%
# PC1 to PC2: 22.4%
# PC1 to PC3: 31.0%
# PC1 to PC4: 38.9%
# PC1 to PC5: 45.8%
# PC1 to PC6: 51.2%
# PC1 to PC7: 56.0%
# PC1 to PC8: 59.5%
# PC1 to PC9: 62.4%
# PC1 to PC10: 64.8%

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Convert PyTorch tensors to NumPy arrays
feats_np = feats.numpy()
labels_np = labels.numpy()

# Standardize features before PCA
scaler = StandardScaler()
feats_scaled = scaler.fit_transform(feats_np)

# Apply PCA with 1 component
pca = PCA(n_components=1)
feats_pca = pca.fit_transform(feats_scaled)

# Plot PCA results
plt.figure(figsize=(8, 6))
# Since we have 1D data, we'll use the PCA component for x-axis and create artificial y-coordinates
scatter = plt.scatter(feats_pca, np.zeros_like(feats_pca), c=labels_np, cmap='viridis', alpha=0.7)
plt.colorbar(scatter, label='Class Labels')
plt.xlabel('PCA Component 1')
plt.ylabel('')  # No y-axis label needed
plt.title('1D PCA Visualization of SimCLR Features')

# Create legend
unique_labels = np.unique(labels_np)
colors = [scatter.cmap(scatter.norm(label)) for label in unique_labels]
legend_labels = [f'Class {label}' for label in unique_labels]
plt.legend(handles=[plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) for color in colors], labels=legend_labels, title='Classes')

# Remove y-axis ticks since they're not meaningful
plt.yticks([])

plt.show()

# %% [markdown]
# import torch
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import StandardScaler, normalize
#
# # Convert PyTorch tensors to NumPy arrays
# feats_np = feats.numpy()
# labels_np = labels.numpy()
#
# # Normalize features
# feats_np_norm = normalize(feats_np, axis=1)
#
# # Standardize features before PCA
# scaler = StandardScaler()
# feats_scaled = scaler.fit_transform(feats_np_norm)
#
# # Apply PCA
# pca = PCA(n_components=2)
# feats_pca = pca.fit_transform(feats_scaled)
#
# # Plot PCA results
# plt.figure(figsize=(8, 6))
# scatter = plt.scatter(feats_pca[:, 0], feats_pca[:, 1], c=labels_np, cmap='viridis', alpha=0.7)
# plt.colorbar(scatter, label='Class Labels')
# plt.xlabel('PCA Component 1')
# plt.ylabel('PCA Component 2')
# plt.title('PCA Visualization of SimCLR Features')
#
# # Create legend
# unique_labels = np.unique(labels_np)
# colors = [scatter.cmap(scatter.norm(label)) for label in unique_labels]
# legend_labels = [f'Class {label}' for label in unique_labels]
# plt.legend(handles=[plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) for color in colors], labels=legend_labels, title='Classes')
#
# plt.show()

# %%
type(feats)
# Out:
# torch.Tensor

# %% [markdown]
# # Extract features for train and test datasets
# feats_simclr = prepare_data_features(simclr_model, loader_labeled)

# %%
"""# Convert features and labels to NumPy arrays
feats_np = feats_simclr.tensors[0].numpy()  # Features in shape (60, 512)

labels_np = feats_simclr.tensors[1].numpy()  # Corresponding labels"""

feats_np = feats.numpy()
labels_np = labels.numpy()

# Check the shapes
print("Shape of features (for K-Means):", feats_np.shape)
print("Shape of labels:", labels_np.shape)
# Out:
# Shape of features (for K-Means): (637, 512)
# Shape of labels: (637,)

# %%
from sklearn.preprocessing import normalize

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Function to reduce to 2D using PCA
def reduce_to_2D_pca(X, centroids):
    pca = PCA(n_components=2)
    X_2D = pca.fit_transform(X)  # Reducing original data points
    centroids_2D = pca.transform(centroids)  # Reducing centroids

    return X_2D, centroids_2D

# Function to plot 2D clusters with centroids and true labels
def plot_2D_clusters_with_labels(X_2D, centroids_2D, idx, labels, K):
    plt.figure(figsize=(8, 6))
    
    # Define color map for clusters
    colors = plt.cm.rainbow(np.linspace(0, 1, K))
    
    # Plot data points colored by their cluster assignment
    for k in range(K):
        cluster_points = X_2D[idx == k]
        cluster_labels = labels[idx == k]  # Get true labels for the current cluster
        
        # Scatter plot for each cluster
        plt.scatter(cluster_points[:, 0], cluster_points[:, 1], 
                    c=[colors[k]], label=f"Cluster {k+1}", alpha=0.6, s=20)
        
        # Annotate each point with its true label
        for i in range(len(cluster_points)):
            plt.annotate(str(cluster_labels[i]), 
                         (cluster_points[i, 0], cluster_points[i, 1]), 
                         fontsize=8, alpha=0.75)

    # Plot centroids as larger markers
    for k in range(K):
        plt.scatter(centroids_2D[k, 0], centroids_2D[k, 1], 
                    c='k', marker='x', s=200, label=f'Centroid {k+1}' if k == 0 else "")

    plt.title("2D Visualization of Clusters using PCA with True Labels")
    plt.xlabel("Principal Component 1")
    plt.ylabel("Principal Component 2")
    plt.legend()
    plt.grid()
    plt.show()

# Apply PCA after K-Means clustering for 2D visualization
X_2D_pca, centroids_2D_pca = reduce_to_2D_pca(feats_np_norm, best_centroids)

# Plot the 2D clusters with centroids and true labels
plot_2D_clusters_with_labels(X_2D_pca, centroids_2D_pca, best_idx, labels_np, K)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 48
#      45     plt.show()
#      47 # Apply PCA after K-Means clustering for 2D visualization
# ---> 48 X_2D_pca, centroids_2D_pca = reduce_to_2D_pca(feats_np_norm, best_centroids)
#      50 # Plot the 2D clusters with centroids and true labels
#      51 plot_2D_clusters_with_labels(X_2D_pca, centroids_2D_pca, best_idx, labels_np, K)
#
# NameError: name 'feats_np_norm' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Function to reduce to 2D using PCA and return explained variance
def reduce_to_2D_pca(X, centroids):
    pca = PCA(n_components=2)
    X_2D = pca.fit_transform(X)  # Reducing original data points
    centroids_2D = pca.transform(centroids)  # Reducing centroids
    explained_variance = pca.explained_variance_ratio_  # Explained variance for the first two PCs

    return X_2D, centroids_2D, explained_variance

# Function to plot PCA scree plot
def plot_pca_scree(explained_variance):
    plt.figure(figsize=(6, 4))
    plt.bar(["PC1", "PC2"], explained_variance * 100, color=['blue', 'orange'])
    plt.ylabel("Explained Variance (%)")
    plt.title("PCA Scree Plot: Variance Explained by Principal Components")
    plt.ylim(0, 100)  # Limit to 100% for better visualization
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# Apply PCA after K-Means clustering for 2D visualization
X_2D_pca, centroids_2D_pca, explained_variance_pca = reduce_to_2D_pca(feats_np_norm, best_centroids)

# Plot the 2D clusters with centroids and true labels
plot_2D_clusters_with_labels(X_2D_pca, centroids_2D_pca, best_idx, labels_np, K)

# Plot PCA Scree Plot
plot_pca_scree(explained_variance_pca)

# %%
print(f"Explained Variance Ratio - PC1: {explained_variance_pca[0]:.4f}, PC2: {explained_variance_pca[1]:.4f}")
# Out:
# Explained Variance Ratio - PC1: 0.2860, PC2: 0.2309

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Function to reduce the dimensionality of data points and centroids to 1D using PCA
def reduce_to_1D_pca(X, centroids):
    # Initialize PCA with 1 component
    pca = PCA(n_components=1)
    
    # Apply PCA to the data points (X) and centroids
    X_1D = pca.fit_transform(X)  # Reducing original data points
    centroids_1D = pca.transform(centroids)  # Reducing centroids

    return X_1D, centroids_1D

# Function to plot 1D visualization of clustered data points and centroids with true labels
def plot_1D_clusters_with_labels(X_1D, centroids_1D, idx, labels, K):
    plt.figure(figsize=(10, 5))
    
    # Define color map for clusters
    colors = plt.cm.rainbow(np.linspace(0, 1, K))
    
    # Plot data points colored by their cluster assignment
    for k in range(K):
        cluster_points = X_1D[idx == k]
        cluster_labels = labels[idx == k]  # Get true labels for the current cluster
        
        # Scatter plot for each cluster
        plt.scatter(cluster_points, [k] * len(cluster_points), 
                    c=[colors[k]], label=f"Cluster {k+1}", alpha=0.6, s=20)
        
        # Annotate each point with its true label
        for i in range(len(cluster_points)):
            plt.annotate(str(cluster_labels[i]), 
                         (cluster_points[i], k), 
                         fontsize=8, alpha=0.75)

    # Plot centroids as larger markers
    for k in range(K):
        plt.scatter(centroids_1D[k], k, 
                    c='k', marker='x', s=200, label=f'Centroid {k+1}' if k == 0 else "")

    plt.title("1D Visualization of Clusters using PCA with True Labels")
    plt.xlabel("Principal Component 1")
    plt.ylabel("Cluster Index")
    plt.legend()
    plt.grid()
    plt.show()

# Apply PCA after K-Means clustering for 1D visualization
X_1D_pca, centroids_1D_pca = reduce_to_1D_pca(feats_np_norm, best_centroids)

# Plot the 1D clusters with centroids and true labels
plot_1D_clusters_with_labels(X_1D_pca, centroids_1D_pca, best_idx, labels_np, K)

# Print the 1D values (PCA scores) in ascending order
sorted_X_1D = np.sort(X_1D_pca.flatten())  # Flatten and sort the PCA scores
print("\n1D PCA values in ascending order:", sorted_X_1D)

# Sort the 1D centroid values and map to labels
sorted_centroids_idx = np.argsort(centroids_1D_pca.flatten())
true_labels_mapping = ['control', 'sd', 'ex']
sorted_labels = [true_labels_mapping[i] for i in sorted_centroids_idx]

# Print sorted centroids with their corresponding true labels
print("\nCentroids in ascending order:")
for i, idx in enumerate(sorted_centroids_idx):
    print(f"Centroid {i+1}: {sorted_labels[i]}, Value: {centroids_1D_pca[idx][0]:.4f}")
# Out:
# 1D PCA values in ascending order: [-0.67422354 -0.6618506  -0.63328415 -0.63090384 -0.6232822  -0.6050955
#  -0.59161615 -0.58710814 -0.5817171  -0.5816232  -0.5671112  -0.5644147
#  -0.5570517  -0.5475627  -0.54161656 -0.5309715  -0.5261008  -0.49478018
#  -0.49377307 -0.45689332 -0.44976163 -0.43842104 -0.433227   -0.41051653
#  -0.406223   -0.3989715  -0.39519322 -0.38608617 -0.3834336  -0.38045263
#  -0.37674323 -0.37528268 -0.37380263 -0.36921185 -0.35411978 -0.3440262
#  -0.31818148 -0.315335   -0.26533034 -0.25883582 -0.19865803 -0.1891391
#  -0.17756371 -0.11318383 -0.11306266 -0.11083626 -0.10778275 -0.10614646
#  -0.08753853 -0.07616495 -0.05343712 -0.04390974 -0.04132077 -0.03795398
#  -0.03555905 -0.03353995 -0.02524958 -0.01587157 -0.00607888  0.01255174
#   0.02466077  0.04244286  0.06228642  0.06839561  0.07360953  0.08137137
#   0.08619266  0.08853185  0.10009573  0.10011639  0.10764465  0.1292649
#   0.13330436  0.1491074   0.18082166  0.19298589  0.19844873  0.20968878
#   0.2124299   0.22756605  0.26159805  0.28725052  0.30486193  0.31340274
#   0.32924342  0.34637773  0.3510512   0.35546425  0.39093047  0.4015555
#   0.40760997  0.415778    0.4233651   0.4306164   0.43109116  0.44060823
#   0.44916993  0.46333253  0.46586958  0.47638175  0.4797498   0.48082462
#   0.48413494  0.48719645  0.4876347   0.49014202  0.49676606  0.49818125
#   0.5018287   0.5101825   0.5112456   0.5127305   0.51713383  0.5226659
#   0.52353084  0.523736    0.5252759   0.53226274  0.56992024  0.5749168 ]
#
# Centroids in ascending order:
# Centroid 1: control, Value: -0.5573
# Centroid 2: sd, Value: 0.0304
# Centroid 3: ex, Value: 0.5275

# %%
import numpy as np
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from scipy.stats import mode

def reduce_to_1D_pca(X, centroids):
    pca = PCA(n_components=1)
    X_1D = pca.fit_transform(X)
    centroids_1D = pca.transform(centroids)
    return X_1D, centroids_1D

def plot_1D_clusters_with_labels(X_1D, centroids_1D, idx, labels, K):
    plt.figure(figsize=(10, 5))
    colors = plt.cm.rainbow(np.linspace(0, 1, K))
    
    for k in range(K):
        cluster_points = X_1D[idx == k]
        cluster_labels = labels[idx == k]
        
        plt.scatter(cluster_points, [k] * len(cluster_points), 
                    c=[colors[k]], label=f"Cluster {k+1}", alpha=0.6, s=20)
        
        for i in range(len(cluster_points)):
            plt.annotate(str(cluster_labels[i]), 
                         (cluster_points[i], k), 
                         fontsize=8, alpha=0.75)

    for k in range(K):
        plt.scatter(centroids_1D[k], k, 
                    c='k', marker='x', s=200, label=f'Centroid {k+1}' if k == 0 else "")

    plt.title("1D Visualization of Clusters using PCA with True Labels")
    plt.xlabel("Principal Component 1")
    plt.ylabel("Cluster Index")
    plt.legend()
    plt.grid()
    plt.show()

# Normalize features
feats_np_norm = normalize(feats_np, axis=1)

# Run clustering (using your existing cosine distance K-means code)
K = 3
best_centroids, best_idx, best_accuracy, accuracies = perform_clustering(feats_np_norm, K)

# Apply PCA and get sorted indices with paths
X_1D_pca, centroids_1D_pca = reduce_to_1D_pca(feats_np_norm, best_centroids)

# Create a list of tuples containing (PCA value, path, true_label)
pca_path_pairs = list(zip(X_1D_pca.flatten(), paths, labels_np))

# Sort based on PCA values while keeping track of paths and labels
sorted_pca_path_pairs = sorted(pca_path_pairs, key=lambda x: x[0])

# Separate sorted values, paths, and labels
sorted_X_1D = np.array([x[0] for x in sorted_pca_path_pairs])
sorted_paths = [x[1] for x in sorted_pca_path_pairs]
sorted_true_labels = [x[2] for x in sorted_pca_path_pairs]

# Print values with corresponding paths and true labels
print("\nSorted PCA values with corresponding paths and true labels:")
true_labels_mapping = ['control', 'sd', 'ex']
for pca_val, path, label in zip(sorted_X_1D, sorted_paths, sorted_true_labels):
    print(f"PCA value: {pca_val:.4f}, Label: {true_labels_mapping[label]}, Path: {path}")

# Print centroid information
sorted_centroids_idx = np.argsort(centroids_1D_pca.flatten())
sorted_labels = [true_labels_mapping[i] for i in sorted_centroids_idx]

print("\nCentroids in ascending order:")
for i, idx in enumerate(sorted_centroids_idx):
    print(f"Centroid {i+1}: {sorted_labels[i]}, Value: {centroids_1D_pca[idx][0]:.4f}")

# Plot the visualization
plot_1D_clusters_with_labels(X_1D_pca, centroids_1D_pca, best_idx, labels_np, K)
# Out:
# Sorted PCA values with corresponding paths and true labels:
# PCA value: -0.6742, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B11-T01.tiff
# PCA value: -0.6619, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F02-T01.tiff
# PCA value: -0.6333, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C11-T01.tiff
# PCA value: -0.6309, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F03-T01.tiff
# PCA value: -0.6233, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B10-T01.tiff
# PCA value: -0.6051, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B07-T01.tiff
# PCA value: -0.5916, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C10-T01.tiff
# PCA value: -0.5871, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C08-T01.tiff
# PCA value: -0.5817, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B09-T01.tiff
# PCA value: -0.5816, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F06-T01.tiff
# PCA value: -0.5671, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B10-T01.tiff
# PCA value: -0.5644, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F05-T01.tiff
# PCA value: -0.5571, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B08-T01.tiff
# PCA value: -0.5476, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C09-T01.tiff
# PCA value: -0.5416, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C07-T01.tiff
# PCA value: -0.5310, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F04-T01.tiff
# PCA value: -0.5261, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C11-T01.tiff
# PCA value: -0.4948, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C06-T01.tiff
# PCA value: -0.4938, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B09-T01.tiff
# PCA value: -0.4569, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B07-T01.tiff
# PCA value: -0.4498, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C04-T01.tiff
# PCA value: -0.4384, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C05-T01.tiff
# PCA value: -0.4332, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C7.tif
# PCA value: -0.4105, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B11-T01.tiff
# PCA value: -0.4062, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C03-T01.tiff
# PCA value: -0.3990, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C09-T01.tiff
# PCA value: -0.3952, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C05-T01.tiff
# PCA value: -0.3861, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C03-T01.tiff
# PCA value: -0.3834, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C07-T01.tiff
# PCA value: -0.3805, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C02-T01.tiff
# PCA value: -0.3767, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C8.tif
# PCA value: -0.3753, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C10-T01.tiff
# PCA value: -0.3738, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C02-T01.tiff
# PCA value: -0.3692, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C04-T01.tiff
# PCA value: -0.3541, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C9.tif
# PCA value: -0.3440, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C06-T01.tiff
# PCA value: -0.3182, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_c10.tif
# PCA value: -0.3153, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C08-T01.tiff
# PCA value: -0.2653, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C11.tif
# PCA value: -0.2588, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g9_C10-T01.tiff
# PCA value: -0.1987, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E06-T01.tiff
# PCA value: -0.1891, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C11-T01.tiff
# PCA value: -0.1776, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D02-T01.tiff
# PCA value: -0.1132, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B03-T01.tiff
# PCA value: -0.1131, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E10-T01.tiff
# PCA value: -0.1108, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D05-T01.tiff
# PCA value: -0.1078, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C09-T01.tiff
# PCA value: -0.1061, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E08-T01.tiff
# PCA value: -0.0875, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E11-T01.tiff
# PCA value: -0.0762, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D03-T01.tiff
# PCA value: -0.0534, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_F02-T01.tiff
# PCA value: -0.0439, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C10-T01.tiff
# PCA value: -0.0413, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B02-T01.tiff
# PCA value: -0.0380, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C08-T01.tiff
# PCA value: -0.0356, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D04-T01.tiff
# PCA value: -0.0335, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D06-T01.tiff
# PCA value: -0.0252, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F02-T01.tiff
# PCA value: -0.0159, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B05-T01.tiff
# PCA value: -0.0061, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B07-T01.tiff
# PCA value: 0.0126, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E07-T01.tiff
# PCA value: 0.0247, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D09-T01.tiff
# PCA value: 0.0424, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D08-T01.tiff
# PCA value: 0.0623, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F08-T01.tiff
# PCA value: 0.0684, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D07-T01.tiff
# PCA value: 0.0736, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F09-T01.tiff
# PCA value: 0.0814, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D10-T01.tiff
# PCA value: 0.0862, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D04-T01.tiff
# PCA value: 0.0885, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B04-T01.tiff
# PCA value: 0.1001, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E09-T01.tiff
# PCA value: 0.1001, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F07-T01.tiff
# PCA value: 0.1076, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_F03-T01.tiff
# PCA value: 0.1293, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_G09-T01.tiff
# PCA value: 0.1333, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D05-T01.tiff
# PCA value: 0.1491, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B06-T01.tiff
# PCA value: 0.1808, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F04-T01.tiff
# PCA value: 0.1930, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F03-T01.tiff
# PCA value: 0.1984, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F06-T01.tiff
# PCA value: 0.2097, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F05-T01.tiff
# PCA value: 0.2124, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D11-T01.tiff
# PCA value: 0.2276, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_G11-T01.tiff
# PCA value: 0.2616, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C11-T01.tiff
# PCA value: 0.2873, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D09-T01.tiff
# PCA value: 0.3049, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C10-T01.tiff
# PCA value: 0.3134, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D10-T01.tiff
# PCA value: 0.3292, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C08-T01.tiff
# PCA value: 0.3464, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F08-T01.tiff
# PCA value: 0.3511, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C09-T01.tiff
# PCA value: 0.3555, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_G11-T01.tiff
# PCA value: 0.3909, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C07-T01.tiff
# PCA value: 0.4016, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D08-T01.tiff
# PCA value: 0.4076, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F07-T01.tiff
# PCA value: 0.4158, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_D09-T01.tiff
# PCA value: 0.4234, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_D08-T01.tiff
# PCA value: 0.4306, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C07-T01.tiff
# PCA value: 0.4311, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_G08-T01.tiff
# PCA value: 0.4406, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_G10-T01.tiff
# PCA value: 0.4492, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_D11-T01.tiff
# PCA value: 0.4633, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C10-T01.tiff
# PCA value: 0.4659, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C08-T01.tiff
# PCA value: 0.4764, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D07-T01.tiff
# PCA value: 0.4797, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B11-T01.tiff
# PCA value: 0.4808, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_G07-T01.tiff
# PCA value: 0.4841, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E10-T01.tiff
# PCA value: 0.4872, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_D10-T01.tiff
# PCA value: 0.4876, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_C07-T01.tiff
# PCA value: 0.4901, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C09-T01.tiff
# PCA value: 0.4968, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B07-T01.tiff
# PCA value: 0.4982, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B10-T01.tiff
# PCA value: 0.5018, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_D09-T01.tiff
# PCA value: 0.5102, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F11-T01.tiff
# PCA value: 0.5112, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_D07-T01.tiff
# PCA value: 0.5127, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E11-T01.tiff
# PCA value: 0.5171, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F09-T01.tiff
# PCA value: 0.5227, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E07-T01.tiff
# PCA value: 0.5235, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_G09-T01.tiff
# PCA value: 0.5237, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B08-T01.tiff
# PCA value: 0.5253, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_F07-T01.tiff
# PCA value: 0.5323, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E09-T01.tiff
# PCA value: 0.5699, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F10-T01.tiff
# PCA value: 0.5749, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B09-T01.tiff
#
# Centroids in ascending order:
# Centroid 1: ex, Value: -0.5573
# Centroid 2: control, Value: 0.0304
# Centroid 3: sd, Value: 0.5275

# %% [markdown]
# weighted pca

# %%
import numpy as np
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Function to reduce to 2D PCA and compute weighted 1D metric
def reduce_to_weighted_1D_pca(X, centroids):
    pca = PCA(n_components=2)
    X_2D = pca.fit_transform(X)
    centroids_2D = pca.transform(centroids)
    
    # Get explained variance ratios as weights
    explained_variance = pca.explained_variance_ratio_
    w1, w2 = explained_variance[0], explained_variance[1]
    
    # Compute the weighted 1D metric
    X_weighted_1D = w1 * X_2D[:, 0] + w2 * X_2D[:, 1]
    centroids_weighted_1D = w1 * centroids_2D[:, 0] + w2 * centroids_2D[:, 1]
    
    return X_weighted_1D, centroids_weighted_1D

# Apply PCA and compute weighted 1D metric
X_weighted_1D, centroids_weighted_1D = reduce_to_weighted_1D_pca(feats_np_norm, best_centroids)

# Create a list of tuples containing (Weighted PCA value, path, true_label)
pca_path_pairs = list(zip(X_weighted_1D, paths, labels_np))

# Sort based on the weighted PCA values
sorted_pca_path_pairs = sorted(pca_path_pairs, key=lambda x: x[0])

# Separate sorted values, paths, and labels
sorted_weighted_X_1D = np.array([x[0] for x in sorted_pca_path_pairs])
sorted_paths = [x[1] for x in sorted_pca_path_pairs]
sorted_true_labels = [x[2] for x in sorted_pca_path_pairs]

# Print sorted weighted PCA values with corresponding paths and true labels
true_labels_mapping = ['control', 'sd', 'ex']
print("\nSorted Weighted PCA values with corresponding paths and true labels:")
for pca_val, path, label in zip(sorted_weighted_X_1D, sorted_paths, sorted_true_labels):
    print(f"Weighted PCA value: {pca_val:.4f}, Label: {true_labels_mapping[label]}, Path: {path}")

# Print centroid information
sorted_centroids_idx = np.argsort(centroids_weighted_1D)
sorted_labels = [true_labels_mapping[i] for i in sorted_centroids_idx]

print("\nCentroids in ascending order:")
for i, idx in enumerate(sorted_centroids_idx):
    print(f"Centroid {i+1}: {sorted_labels[i]}, Value: {centroids_weighted_1D[idx]:.4f}")
# Out:
# Sorted Weighted PCA values with corresponding paths and true labels:
# Weighted PCA value: -0.2551, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F02-T01.tiff
# Weighted PCA value: -0.2486, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B11-T01.tiff
# Weighted PCA value: -0.2482, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B10-T01.tiff
# Weighted PCA value: -0.2459, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C11-T01.tiff
# Weighted PCA value: -0.2410, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F05-T01.tiff
# Weighted PCA value: -0.2368, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C11-T01.tiff
# Weighted PCA value: -0.2360, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B07-T01.tiff
# Weighted PCA value: -0.2337, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C10-T01.tiff
# Weighted PCA value: -0.2324, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B10-T01.tiff
# Weighted PCA value: -0.2288, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F03-T01.tiff
# Weighted PCA value: -0.2281, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B09-T01.tiff
# Weighted PCA value: -0.2248, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B09-T01.tiff
# Weighted PCA value: -0.2227, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B07-T01.tiff
# Weighted PCA value: -0.2199, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C08-T01.tiff
# Weighted PCA value: -0.2197, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C09-T01.tiff
# Weighted PCA value: -0.2196, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F04-T01.tiff
# Weighted PCA value: -0.2194, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g6_F06-T01.tiff
# Weighted PCA value: -0.2086, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C06-T01.tiff
# Weighted PCA value: -0.2068, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C07-T01.tiff
# Weighted PCA value: -0.2060, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g8_B11-T01.tiff
# Weighted PCA value: -0.2043, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C09-T01.tiff
# Weighted PCA value: -0.2017, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g9_C07-T01.tiff
# Weighted PCA value: -0.1994, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C04-T01.tiff
# Weighted PCA value: -0.1970, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C03-T01.tiff
# Weighted PCA value: -0.1939, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C08-T01.tiff
# Weighted PCA value: -0.1914, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g8_B08-T01.tiff
# Weighted PCA value: -0.1904, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C05-T01.tiff
# Weighted PCA value: -0.1837, Label: ex, Path: G:\cluster_40\cure\ex\ds62_g9_C10-T01.tiff
# Weighted PCA value: -0.1652, Label: ex, Path: G:\cluster_40\cure\ex\ds61_g3_C02-T01.tiff
# Weighted PCA value: -0.1312, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C05-T01.tiff
# Weighted PCA value: -0.1211, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C7.tif
# Weighted PCA value: -0.1160, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C03-T01.tiff
# Weighted PCA value: -0.1138, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g9_C10-T01.tiff
# Weighted PCA value: -0.1106, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C02-T01.tiff
# Weighted PCA value: -0.1000, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C04-T01.tiff
# Weighted PCA value: -0.0910, Label: ex, Path: G:\cluster_40\cure\ex\ds41_g3_C06-T01.tiff
# Weighted PCA value: -0.0892, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C8.tif
# Weighted PCA value: -0.0860, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C9.tif
# Weighted PCA value: -0.0799, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_c10.tif
# Weighted PCA value: -0.0466, Label: ex, Path: G:\cluster_40\cure\ex\ds1B_g9_C11.tif
# Weighted PCA value: 0.0089, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F08-T01.tiff
# Weighted PCA value: 0.0131, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D09-T01.tiff
# Weighted PCA value: 0.0158, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C08-T01.tiff
# Weighted PCA value: 0.0282, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F07-T01.tiff
# Weighted PCA value: 0.0282, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_G08-T01.tiff
# Weighted PCA value: 0.0477, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C11-T01.tiff
# Weighted PCA value: 0.0486, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D08-T01.tiff
# Weighted PCA value: 0.0493, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D02-T01.tiff
# Weighted PCA value: 0.0507, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E06-T01.tiff
# Weighted PCA value: 0.0512, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D10-T01.tiff
# Weighted PCA value: 0.0522, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_G11-T01.tiff
# Weighted PCA value: 0.0532, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C07-T01.tiff
# Weighted PCA value: 0.0543, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_D08-T01.tiff
# Weighted PCA value: 0.0551, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B07-T01.tiff
# Weighted PCA value: 0.0553, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E10-T01.tiff
# Weighted PCA value: 0.0556, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_G07-T01.tiff
# Weighted PCA value: 0.0568, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D06-T01.tiff
# Weighted PCA value: 0.0581, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B08-T01.tiff
# Weighted PCA value: 0.0595, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C09-T01.tiff
# Weighted PCA value: 0.0622, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C07-T01.tiff
# Weighted PCA value: 0.0629, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C11-T01.tiff
# Weighted PCA value: 0.0683, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_D09-T01.tiff
# Weighted PCA value: 0.0699, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B03-T01.tiff
# Weighted PCA value: 0.0708, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_C07-T01.tiff
# Weighted PCA value: 0.0720, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C09-T01.tiff
# Weighted PCA value: 0.0729, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F11-T01.tiff
# Weighted PCA value: 0.0763, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E10-T01.tiff
# Weighted PCA value: 0.0767, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_D11-T01.tiff
# Weighted PCA value: 0.0798, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_D10-T01.tiff
# Weighted PCA value: 0.0821, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C10-T01.tiff
# Weighted PCA value: 0.0827, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_C08-T01.tiff
# Weighted PCA value: 0.0828, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F09-T01.tiff
# Weighted PCA value: 0.0832, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_G09-T01.tiff
# Weighted PCA value: 0.0858, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B11-T01.tiff
# Weighted PCA value: 0.0864, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E11-T01.tiff
# Weighted PCA value: 0.0895, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E07-T01.tiff
# Weighted PCA value: 0.0897, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_D09-T01.tiff
# Weighted PCA value: 0.0907, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E09-T01.tiff
# Weighted PCA value: 0.0926, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D09-T01.tiff
# Weighted PCA value: 0.0945, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B09-T01.tiff
# Weighted PCA value: 0.0962, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_F07-T01.tiff
# Weighted PCA value: 0.0974, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F08-T01.tiff
# Weighted PCA value: 0.0988, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D05-T01.tiff
# Weighted PCA value: 0.0988, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D08-T01.tiff
# Weighted PCA value: 0.0996, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C09-T01.tiff
# Weighted PCA value: 0.0999, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_B10-T01.tiff
# Weighted PCA value: 0.1000, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F09-T01.tiff
# Weighted PCA value: 0.1009, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E08-T01.tiff
# Weighted PCA value: 0.1015, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT10_E11-T01.tiff
# Weighted PCA value: 0.1032, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F07-T01.tiff
# Weighted PCA value: 0.1052, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_C10-T01.tiff
# Weighted PCA value: 0.1071, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT14_D07-T01.tiff
# Weighted PCA value: 0.1071, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D03-T01.tiff
# Weighted PCA value: 0.1077, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F02-T01.tiff
# Weighted PCA value: 0.1132, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D10-T01.tiff
# Weighted PCA value: 0.1146, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D04-T01.tiff
# Weighted PCA value: 0.1150, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT09_F10-T01.tiff
# Weighted PCA value: 0.1175, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_D07-T01.tiff
# Weighted PCA value: 0.1186, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_F02-T01.tiff
# Weighted PCA value: 0.1187, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B05-T01.tiff
# Weighted PCA value: 0.1205, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D07-T01.tiff
# Weighted PCA value: 0.1216, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B02-T01.tiff
# Weighted PCA value: 0.1223, Label: sd, Path: G:\cluster_40\cure\sdonly_40\RBT04_G10-T01.tiff
# Weighted PCA value: 0.1226, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D05-T01.tiff
# Weighted PCA value: 0.1228, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C08-T01.tiff
# Weighted PCA value: 0.1247, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F06-T01.tiff
# Weighted PCA value: 0.1262, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_D04-T01.tiff
# Weighted PCA value: 0.1268, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_C10-T01.tiff
# Weighted PCA value: 0.1321, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F05-T01.tiff
# Weighted PCA value: 0.1331, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B04-T01.tiff
# Weighted PCA value: 0.1331, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F04-T01.tiff
# Weighted PCA value: 0.1351, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E09-T01.tiff
# Weighted PCA value: 0.1367, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_G09-T01.tiff
# Weighted PCA value: 0.1391, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_E07-T01.tiff
# Weighted PCA value: 0.1405, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B07-T01.tiff
# Weighted PCA value: 0.1581, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_F03-T01.tiff
# Weighted PCA value: 0.1628, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_F03-T01.tiff
# Weighted PCA value: 0.1636, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_D11-T01.tiff
# Weighted PCA value: 0.1691, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBTDS1B_Day_7_B06-T01.tiff
# Weighted PCA value: 0.1692, Label: control, Path: G:\cluster_40\cure\cure_cond7_40\RBT_01.04_Day7_G11-T01.tiff
#
# Centroids in ascending order:
# Centroid 1: ex, Value: -0.2174
# Centroid 2: sd, Value: 0.0847
# Centroid 3: control, Value: 0.1366

# %%
import numpy as np

def calculate_middle_cluster_accuracy(X_1D, idx, centroids_1D):
    # Convert idx to array if it's not already
    if not isinstance(idx, np.ndarray):
        idx = np.array(idx)
    
    # Ensure idx is the same length as X_1D
    if idx.shape != (len(X_1D),):
        print("Warning: Reshaping idx to match data points")
        idx = np.full(len(X_1D), idx)
    
    print("Debugging Information:")
    print(f"Shape of X_1D: {X_1D.shape}")
    print(f"Shape of idx (after fix): {idx.shape}")
    print(f"Shape of centroids_1D: {centroids_1D.shape}")
    print(f"Unique cluster indices: {np.unique(idx)}")
    
    # Sort centroids and get their indices
    centroid_values = centroids_1D.flatten()
    sorted_indices = np.argsort(centroid_values)
    print(f"Centroid values: {centroid_values}")
    print(f"Sorted centroid indices: {sorted_indices}")
    
    # Map old cluster indices to new ordered indices (0, 1, 2)
    index_mapping = {old_idx: new_idx for new_idx, old_idx in enumerate(sorted_indices)}
    
    # Reindex the clusters to be 0, 1, 2 in order of centroid values
    new_idx = np.zeros_like(idx)
    for old_idx, new_idx_val in index_mapping.items():
        new_idx[idx == old_idx] = new_idx_val
    
    # Now we work with the reindexed clusters
    # Get points belonging to each cluster
    first_cluster_points = X_1D[new_idx == 0]
    middle_cluster_points = X_1D[new_idx == 1]
    third_cluster_points = X_1D[new_idx == 2]
    
    print(f"\nCluster sizes after reindexing:")
    print(f"First cluster points: {len(first_cluster_points)}")
    print(f"Middle cluster points: {len(middle_cluster_points)}")
    print(f"Third cluster points: {len(third_cluster_points)}")
    
    # Check if any clusters are empty
    if len(first_cluster_points) == 0 or len(middle_cluster_points) == 0 or len(third_cluster_points) == 0:
        raise ValueError("One or more clusters are empty after reindexing. Please check cluster assignments.")
    
    # Calculate boundary values
    first_cluster_max = np.max(first_cluster_points)
    third_cluster_min = np.min(third_cluster_points)
    
    # Count errors
    errors_below = np.sum(middle_cluster_points < first_cluster_max)
    errors_above = np.sum(middle_cluster_points > third_cluster_min)
    total_errors = errors_below + errors_above
    total_points = 40+40+40
    # Calculate accuracy
    total_middle_points = len(middle_cluster_points)
    accuracy = (total_points - total_errors) / total_points
    
    # Print boundary information
    print(f"\nBoundary Information:")
    print(f"First cluster range: [{np.min(first_cluster_points):.4f}, {first_cluster_max:.4f}]")
    print(f"Middle cluster range: [{np.min(middle_cluster_points):.4f}, {np.max(middle_cluster_points):.4f}]")
    print(f"Third cluster range: [{third_cluster_min:.4f}, {np.max(third_cluster_points):.4f}]")
    
    return {
        'accuracy': accuracy,
        'total_points': total_middle_points,
        'errors_below': errors_below,
        'errors_above': errors_above,
        'total_errors': total_errors,
        'first_cluster_max': first_cluster_max,
        'third_cluster_min': third_cluster_min
    }

# Try to calculate the accuracy metrics with error handling
try:
    # Use best_idx from our successful K-means clustering
    results = calculate_middle_cluster_accuracy(X_1D_pca, best_idx, centroids_1D_pca)
    
    print(f"\nResults:")
    print(f"Total points in middle cluster: {results['total_points']}")
    print(f"Errors below first cluster max: {results['errors_below']}")
    print(f"Errors above third cluster min: {results['errors_above']}")
    print(f"Total errors: {results['total_errors']}")
    print(f"Accuracy: {results['accuracy']:.4f} ({results['accuracy']*100:.2f}%)")
    
except ValueError as e:
    print(f"Error: {e}")
    print("Additional debugging needed. Please check:")
    print("1. The original cluster assignments")
    print("2. The K-means clustering results")
    print("3. The PCA transformation process")
# Out:
# Debugging Information:
# Shape of X_1D: (120, 1)
# Shape of idx (after fix): (120,)
# Shape of centroids_1D: (3, 1)
# Unique cluster indices: [0 1 2]
# Centroid values: [ 0.03042284  0.52752201 -0.55725242]
# Sorted centroid indices: [2 0 1]
#
# Cluster sizes after reindexing:
# First cluster points: 40
# Middle cluster points: 40
# Third cluster points: 40
#
# Boundary Information:
# First cluster range: [-0.6742, -0.2588]
# Middle cluster range: [-0.1987, 0.2276]
# Third cluster range: [0.2616, 0.5749]
#
# Results:
# Total points in middle cluster: 40
# Errors below first cluster max: 0
# Errors above third cluster min: 0
# Total errors: 0
# Accuracy: 1.0000 (100.00%)

# %%
import numpy as np

def calculate_cluster_accuracy_both_metrics(X_1D, idx, centroids_1D):
    # Convert idx to array if it's not already
    if not isinstance(idx, np.ndarray):
        idx = np.array(idx)
    
    # Ensure idx is the same length as X_1D
    if idx.shape != (len(X_1D),):
        print("Warning: Reshaping idx to match data points")
        idx = np.full(len(X_1D), idx)
    
    print("Debugging Information:")
    print(f"Shape of X_1D: {X_1D.shape}")
    print(f"Shape of idx (after fix): {idx.shape}")
    print(f"Shape of centroids_1D: {centroids_1D.shape}")
    print(f"Unique cluster indices: {np.unique(idx)}")
    
    # Sort centroids and get their indices
    centroid_values = centroids_1D.flatten()
    sorted_indices = np.argsort(centroid_values)
    print(f"Centroid values: {centroid_values}")
    print(f"Sorted centroid indices: {sorted_indices}")
    
    # Map old cluster indices to new ordered indices (0, 1, 2)
    index_mapping = {old_idx: new_idx for new_idx, old_idx in enumerate(sorted_indices)}
    
    # Reindex the clusters to be 0, 1, 2 in order of centroid values
    new_idx = np.zeros_like(idx)
    for old_idx, new_idx_val in index_mapping.items():
        new_idx[idx == old_idx] = new_idx_val
    
    # Now we work with the reindexed clusters
    # Get points belonging to each cluster
    first_cluster_points = X_1D[new_idx == 0]
    middle_cluster_points = X_1D[new_idx == 1]
    third_cluster_points = X_1D[new_idx == 2]
    
    print(f"\nCluster sizes after reindexing:")
    print(f"First cluster points: {len(first_cluster_points)}")
    print(f"Middle cluster points: {len(middle_cluster_points)}")
    print(f"Third cluster points: {len(third_cluster_points)}")
    
    # Check if any clusters are empty
    if len(first_cluster_points) == 0 or len(middle_cluster_points) == 0 or len(third_cluster_points) == 0:
        raise ValueError("One or more clusters are empty after reindexing. Please check cluster assignments.")
    
    # Calculate boundary values for original metric
    first_cluster_max = np.max(first_cluster_points)
    third_cluster_min = np.min(third_cluster_points)
    
    # Calculate boundary values for new metric
    middle_cluster_min = np.min(middle_cluster_points)
    middle_cluster_max = np.max(middle_cluster_points)
    
    # Count errors for original metric (middle cluster errors)
    middle_errors_below = np.sum(middle_cluster_points < first_cluster_max)
    middle_errors_above = np.sum(middle_cluster_points > third_cluster_min)
    total_middle_errors = middle_errors_below + middle_errors_above
    
    # Count errors for new metric (outer clusters errors)
    first_cluster_errors = np.sum(first_cluster_points > middle_cluster_min)
    third_cluster_errors = np.sum(third_cluster_points < middle_cluster_max)
    total_outer_errors = first_cluster_errors + third_cluster_errors
    
    total_points = len(first_cluster_points) + len(middle_cluster_points) + len(third_cluster_points)
    
    # Calculate accuracies
    middle_accuracy = (total_points - total_middle_errors) / total_points
    outer_accuracy = (total_points - total_outer_errors) / total_points
    
    # Print boundary information
    print(f"\nBoundary Information:")
    print(f"First cluster range: [{np.min(first_cluster_points):.4f}, {first_cluster_max:.4f}]")
    print(f"Middle cluster range: [{middle_cluster_min:.4f}, {middle_cluster_max:.4f}]")
    print(f"Third cluster range: [{third_cluster_min:.4f}, {np.max(third_cluster_points):.4f}]")
    
    # Print detailed error counts for debugging
    print("\nDetailed Error Analysis:")
    print("Original Metric (Middle cluster errors):")
    print(f"Middle points below first max: {middle_errors_below}")
    print(f"Middle points above third min: {middle_errors_above}")
    print("\nNew Metric (Outer clusters errors):")
    print(f"First cluster points above middle min: {first_cluster_errors}")
    print(f"Third cluster points below middle max: {third_cluster_errors}")
    
    return {
        # Original metric results
        'middle_accuracy': middle_accuracy,
        'middle_errors_below': middle_errors_below,
        'middle_errors_above': middle_errors_above,
        'total_middle_errors': total_middle_errors,
        
        # New metric results
        'outer_accuracy': outer_accuracy,
        'first_cluster_errors': first_cluster_errors,
        'third_cluster_errors': third_cluster_errors,
        'total_outer_errors': total_outer_errors,
        
        # Boundary values
        'first_cluster_max': first_cluster_max,
        'middle_cluster_min': middle_cluster_min,
        'middle_cluster_max': middle_cluster_max,
        'third_cluster_min': third_cluster_min,
        
        'total_points': total_points
    }

# Try to calculate both accuracy metrics with error handling
try:
    # Use best_idx from the K-means clustering
    results = calculate_cluster_accuracy_both_metrics(X_1D_pca, best_idx, centroids_1D_pca)
    
    print(f"\nFinal Results:")
    print("\nOriginal Metric (Middle cluster errors):")
    print(f"Total errors: {results['total_middle_errors']}")
    print(f"Accuracy: {results['middle_accuracy']:.4f} ({results['middle_accuracy']*100:.2f}%)")
    
    print("\nNew Metric (Outer clusters errors):")
    print(f"Total errors: {results['total_outer_errors']}")
    print(f"Accuracy: {results['outer_accuracy']:.4f} ({results['outer_accuracy']*100:.2f}%)")
    
except ValueError as e:
    print(f"Error: {e}")
    print("Additional debugging needed. Please check:")
    print("1. The original cluster assignments")
    print("2. The K-means clustering results")
    print("3. The PCA transformation process")
# Out:
# Debugging Information:
# Shape of X_1D: (120, 1)
# Shape of idx (after fix): (120,)
# Shape of centroids_1D: (3, 1)
# Unique cluster indices: [0 1 2]
# Centroid values: [ 0.03042284  0.52752201 -0.55725242]
# Sorted centroid indices: [2 0 1]
#
# Cluster sizes after reindexing:
# First cluster points: 40
# Middle cluster points: 40
# Third cluster points: 40
#
# Boundary Information:
# First cluster range: [-0.6742, -0.2588]
# Middle cluster range: [-0.1987, 0.2276]
# Third cluster range: [0.2616, 0.5749]
#
# Detailed Error Analysis:
# Original Metric (Middle cluster errors):
# Middle points below first max: 0
# Middle points above third min: 0
#
# New Metric (Outer clusters errors):
# First cluster points above middle min: 0
# Third cluster points below middle max: 0
#
# Final Results:
#
# Original Metric (Middle cluster errors):
# Total errors: 0
# Accuracy: 1.0000 (100.00%)
#
# New Metric (Outer clusters errors):
# Total errors: 0
# Accuracy: 1.0000 (100.00%)

# %% [markdown]
# # Function to reduce the dimensionality of data points and centroids to 2D using PCA
# def reduce_to_2D_pca(X, centroids):
#     # Initialize PCA with 2 components
#     pca = PCA(n_components=2)
#
#     # Apply PCA to the data points (X) and centroids
#     X_2D = pca.fit_transform(X)  # Reducing original data points
#     centroids_2D = pca.transform(centroids)  # Reducing centroids
#
#     return X_2D, centroids_2D
#
# # Function to plot 2D visualization of clustered data points and centroids with true labels
# def plot_2D_clusters_with_labels(X_2D, centroids_2D, idx, labels, K):
#     plt.figure(figsize=(10, 7))
#
#     # Define color map for clusters
#     colors = plt.cm.rainbow(np.linspace(0, 1, K))
#
#     # Plot data points colored by their cluster assignment
#     for k in range(K):
#         cluster_points = X_2D[idx == k]
#         cluster_labels = labels[idx == k]  # Get true labels for the current cluster
#
#         # Scatter plot for each cluster
#         plt.scatter(cluster_points[:, 0], cluster_points[:, 1],
#                     c=[colors[k]], label=f"Cluster {k+1}", alpha=0.6)
#
#         # Annotate each point with its true label
#         for i in range(cluster_points.shape[0]):
#             plt.annotate(str(cluster_labels[i]),
#                          (cluster_points[i, 0], cluster_points[i, 1]),
#                          fontsize=8, alpha=0.75)
#
#     # Plot centroids as larger markers
#     plt.scatter(centroids_2D[:, 0], centroids_2D[:, 1],
#                 c='k', marker='x', s=200, label='Centroids')
#
#     plt.title("2D Visualization of Clusters using PCA with True Labels")
#     plt.xlabel("Component 1")
#     plt.ylabel("Component 2")
#     plt.legend()
#     plt.grid()
#     plt.show()

# %% [markdown]
# # Apply PCA after K-Means clustering for 2D visualization
# X_2D_pca, centroids_2D_pca = reduce_to_2D_pca(feats_np_norm, centroids)
#
# # Plot the 2D clusters with centroids and true labels
# plot_2D_clusters_with_labels(X_2D_pca, centroids_2D_pca, idx, labels_np, K)
