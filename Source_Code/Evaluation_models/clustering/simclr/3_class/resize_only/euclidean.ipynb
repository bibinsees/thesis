# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import tifffile as tiff
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
from copy import deepcopy
import random


from collections import Counter
from scipy.stats import mode

# %%
# Set seed for reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set seed
set_seed(42)

# %%
class SimCLR(nn.Module):
    def __init__(self, hidden_dim, lr, temperature, weight_decay,max_epochs):
        super().__init__()
        self.temperature = temperature
        
        # Load the pretrained ResNet-18 model
        self.convnet = torchvision.models.resnet18(weights='ResNet18_Weights.DEFAULT')
        
        # Modify the fully connected layer
        self.convnet.fc = nn.Sequential(
            nn.Linear(self.convnet.fc.in_features, 4 * hidden_dim),  # Linear layer with 4*hidden_dim output
            nn.ReLU(inplace=True),
            nn.Linear(4 * hidden_dim, 20)  # Output layer with hidden_dim output
        )

        self.optimizer = optim.AdamW(self.parameters(), lr=lr, weight_decay=weight_decay)
        self.lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(self.optimizer, T_max=max_epochs, eta_min=lr / 50)

    def forward(self, x):
        return self.convnet(x)

    def info_nce_loss(self, imgs1, imgs2, device):

        imgs = torch.cat((imgs1, imgs2), dim=0)  # Concatenate along the batch dimension
        imgs = imgs.to(device)  # Move images to the device

        # Encode all images
        feats = self.forward(imgs)
    
        # Calculate cosine similarity
        cos_sim = nn.functional.cosine_similarity(feats[:, None, :], feats[None, :, :], dim=-1)
    
        # Mask out cosine similarity to itself
        self_mask = torch.eye(cos_sim.shape[0], dtype=torch.bool, device=cos_sim.device)
        cos_sim.masked_fill_(self_mask, -9e15)
    
        # Find positive example -> batch_size//2 away from the original example
        pos_mask = self_mask.roll(shifts=cos_sim.shape[0] // 2, dims=0)
    
        # Normalize similarity scores by temperature
        cos_sim = cos_sim / self.temperature

        # InfoNCE loss
        nll = -cos_sim[pos_mask] + torch.logsumexp(cos_sim, dim=-1)
        nll = nll.mean()

        # Accuracy calculations
        # Create a combination of positive and negative similarities for ranking
        comb_sim = torch.cat([cos_sim[pos_mask][:, None],  # Positive example in first position
                          cos_sim.masked_fill(pos_mask, -9e15)], dim=-1)
    
        # Sort and get the ranking position of the positive example
        sim_argsort = comb_sim.argsort(dim=-1, descending=True).argmin(dim=-1)
    
        # Compute accuracy metrics
        top1_acc = (sim_argsort == 0).float().mean()  # Top-1 accuracy
        top5_acc = (sim_argsort < 5).float().mean()   # Top-5 accuracy
        mean_pos = 1 + sim_argsort.float().mean()     # Mean position of the positive example

        return nll, top1_acc, top5_acc, mean_pos

    def train_epoch(self, train_loader, device):
        self.train()
        total_loss = 0.0
        total_top1_acc = 0.0
        total_top5_acc = 0.0
        total_mean_pos = 0.0

        for batch in tqdm(train_loader, desc="Training", leave=False):
            imgs1, imgs2, _ = batch
            imgs1, imgs2 = imgs1.to(device), imgs2.to(device)  # Move data to device
        
            self.optimizer.zero_grad()

            # Calculate loss and accuracy metrics
            loss, top1_acc, top5_acc, mean_pos = self.info_nce_loss(imgs1, imgs2, device)

            loss.backward()
            self.optimizer.step()
            #self.lr_scheduler.step()

            # Accumulate metrics
            total_loss += loss.item()
            total_top1_acc += top1_acc.item()
            total_top5_acc += top5_acc.item()
            total_mean_pos += mean_pos.item()

        avg_loss = total_loss / len(train_loader)
        avg_top1_acc = total_top1_acc / len(train_loader)
        avg_top5_acc = total_top5_acc / len(train_loader)
        avg_mean_pos = total_mean_pos / len(train_loader)

        return avg_loss, avg_top1_acc, avg_top5_acc, avg_mean_pos

    def validate_epoch(self, val_loader, device):
        self.eval()
        total_loss = 0.0
        total_top1_acc = 0.0
        total_top5_acc = 0.0
        total_mean_pos = 0.0

        with torch.no_grad():
            for batch in tqdm(val_loader, desc="Validating", leave=False):
                imgs1, imgs2, _ = batch
                imgs1, imgs2 = imgs1.to(device), imgs2.to(device)  # Move data to device

                # Calculate loss and accuracy metrics
                loss, top1_acc, top5_acc, mean_pos = self.info_nce_loss(imgs1, imgs2, device)

                # Accumulate metrics
                total_loss += loss.item()
                total_top1_acc += top1_acc.item()
                total_top5_acc += top5_acc.item()
                total_mean_pos += mean_pos.item()

        avg_loss = total_loss / len(val_loader)
        avg_top1_acc = total_top1_acc / len(val_loader)
        avg_top5_acc = total_top5_acc / len(val_loader)
        avg_mean_pos = total_mean_pos / len(val_loader)

        return avg_loss, avg_top1_acc, avg_top5_acc, avg_mean_pos
    

    def inference_epoch(self, inference_loader, device):
        self.eval()
        total_loss = 0.0
        total_top1_acc = 0.0
        total_top5_acc = 0.0
        total_mean_pos = 0.0

        with torch.no_grad():
            for batch in tqdm(inference_loader, desc="Inferencing", leave=False):
                imgs1, imgs2, _ = batch
                imgs1, imgs2 = imgs1.to(device), imgs2.to(device)  # Move data to device

                # Calculate loss and accuracy metrics
                loss, top1_acc, top5_acc, mean_pos = self.info_nce_loss(imgs1, imgs2, device)

                # Accumulate metrics
                total_loss += loss.item()
                total_top1_acc += top1_acc.item()
                total_top5_acc += top5_acc.item()
                total_mean_pos += mean_pos.item()

        avg_loss = total_loss / len(inference_loader)
        avg_top1_acc = total_top1_acc / len(inference_loader)
        avg_top5_acc = total_top5_acc / len(inference_loader)
        avg_mean_pos = total_mean_pos / len(inference_loader)

        return avg_loss, avg_top1_acc, avg_top5_acc, avg_mean_pos

# %%
# Device setup for inference
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
full_model_path =  r'C:\Users\k54739\Bibi_new_thesis\saved_model\resize_simclr_modelepoch250.pth' 
simclr_model = torch.load(full_model_path)
simclr_model.to(device)
simclr_model.eval()
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_21028\3495648145.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   simclr_model = torch.load(full_model_path)
# SimCLR(
#   (convnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=512, out_features=20, bias=True)
#     )
#   )
# )

# %% [markdown]
# # Clustering

# %%
class LabeledImageDataset(Dataset):
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        #self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Ensure the image has 3 layers (channels)
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} does not have exactly 3 layers.")

        # Normalize the 16-bit image to [0, 1]
        image = image.astype(np.float32) / 65535.0

        # Convert to a torch tensor and add channel dimension
        image = torch.tensor(image, dtype=torch.float32)
        
        # Apply resize transform
        image = self.resize_transform(image)

        label = self.labels[idx]

        return image, label, img_path

def load_data(root_dir):

    #classes = ['cond7_all', 'sd','ex'] #full dataset
    #classes = ['cond7_curated', 'sd','ex'] # curated full dataset



    #classes = ['cond7_40', 'sd_40','ex'] # 40 subset
    classes = ['curated_cond7_40', 'sd_40','ex'] # curated 40 subset





    image_files = []
    labels = []

    for idx, class_name in enumerate(classes):
        class_dir = os.path.join(root_dir, class_name)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir) if file.endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        labels.extend([idx] * len(files))
    
    # Check if the labels correctly reflect the classes
    print("Label distribution:", {classes[i]: labels.count(i) for i in range(len(classes))})

    return image_files, labels


# Directories for labeled data
#image_dir =  r"C:\Users\k54739\Bibi_new_thesis\thesis\classification"

image_dir =  r"C:\Users\k54739\Bibi_new_thesis\thesis\classification\cluster_40"

# Load data
image_files, labels = load_data(image_dir)

# Create the labeled datasets
labeled_dataset = LabeledImageDataset(image_files, labels)

# Define DataLoaders
batch_size = 16
loader_labeled = DataLoader(labeled_dataset, batch_size=batch_size, shuffle=True, drop_last=False, pin_memory=True, num_workers=0)
# Out:
# Label distribution: {'curated_cond7_40': 40, 'sd_40': 40, 'ex': 40}

# %%
for anchor,label, path in loader_labeled:
    print(anchor.shape, label.shape, anchor.dtype)
    print(label)
    print(path)
    break
# Out:
# torch.Size([16, 3, 96, 96]) torch.Size([16]) torch.float32
# tensor([2, 1, 0, 1, 0, 2, 0, 2, 0, 0, 2, 2, 2, 0, 0, 1])
# ['C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds41_g3_C05-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.04_Day10_E09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_F04-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\ds62_g2_B04-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\sd_04_B06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g3_C06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_41_G05-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds62_g8_B07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_41_G04-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\sd_04_G08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds1B_g9_C9.tif', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g6_F05-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds41_g9_C10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\sd_04_G11-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_F02-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\ds1b_g5_E3.tif']

# %%
@torch.no_grad()
def prepare_data_features(model, dataloader):
    # Prepare model
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()  # Removing projection head g(.)
    network.eval()
    network.to(device)

    # Encode all images
    feats, labels, paths = [], [], []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        print(f"Batch features shape: {batch_feats.shape}")
        print(f"Batch labels shape: {batch_labels.shape}")
        print(f"Batch labels shape: {batch_paths}")
        
        feats.append(batch_feats.detach().cpu())
        labels.append(batch_labels)
        paths.extend(batch_paths) 

    feats = torch.cat(feats, dim=0)
    labels = torch.cat(labels, dim=0)
    
    
    print(f"Features shape after concatenation: {feats.shape}")
    print(f"Labels shape after concatenation: {labels.shape}")
    print(f"Number of paths after concatenation: {len(paths)}")

    return feats, labels, paths

# %%
# Extract features for train and test datasets
feats, labels, paths = prepare_data_features(simclr_model, loader_labeled)
# Out:
#  12%|█▎        | 1/8 [00:00<00:06,  1.06it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g3_C05-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.10_Day10_G10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\sd_04_G11-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.04_Day10_D10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_42_B02-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.10_Day10_G07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g3_C02-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_F04-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g8_B11-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_F05-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds1B_g9_C9.tif', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.14_Day10_D08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_B03-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g3_C03-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\sd_04_B05-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds62_g9_C10-T01.tiff']
#  25%|██▌       | 2/8 [00:01<00:05,  1.20it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds62_g8_B07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.09_Day10_F07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.14_Day10_D07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g9_C08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_51_D09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_41_G06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_41_G04-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds62_g9_C09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_41_G09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds41_g9_C10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_42_B04-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g9_C10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\ds42_g5_E06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds62_g9_C08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g3_C06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_B05-T01.tiff']
#  38%|███▊      | 3/8 [00:02<00:04,  1.25it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.10_Day10_C09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds41_g3_C02-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds1B_g9_C11.tif', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_E11-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_F02-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_42_B05-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.10_Day10_C11-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g9_C09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_41_G08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.14_Day10_D09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.10_Day10_D07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g6_F06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_41_G11-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.10_Day10_G08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds41_g3_C06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_E10-T01.tiff']
#  50%|█████     | 4/8 [00:03<00:03,  1.27it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g8_B08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\ds1b_g5_E2.tif', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.09_Day10_E11-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds1B_g9_c10.tif', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\ds41_g2_B03-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_B04-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_B02-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.09_Day10_B08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_51_D07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.09_Day10_F08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.14_Day10_D10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_42_B03-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_F03-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.04_Day10_E07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g6_F05-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g9_C11-T01.tiff']
#  62%|██████▎   | 5/8 [00:03<00:02,  1.29it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\ds1b_g5_E3.tif', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.09_Day10_B10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.09_Day10_F09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds62_g8_B11-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.04_Day10_D11-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\ds62_g2_B03-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_41_G05-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g6_F02-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds1B_g9_C8.tif', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds41_g3_C03-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds62_g9_C07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.09_Day10_B09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_51_D05-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds1B_g9_C7.tif', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\ds62_g2_B04-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.14_Day10_D11-T01.tiff']
#  75%|███████▌  | 6/8 [00:04<00:01,  1.30it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.09_Day10_C07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.09_Day10_B11-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\sd_04_G09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_42_G06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\sd_04_G08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\ds42_g5_E05-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g9_C07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.04_Day10_E09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g8_B07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_51_D06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_42_G07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_1B_B06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g8_B10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.10_Day10_G09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.10_Day10_G11-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\ds62_g2_B02-T01.tiff']
#  88%|████████▊ | 7/8 [00:05<00:00,  1.30it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch labels shape: ['C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\sd_04_B06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds41_g3_C04-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g8_B09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\sd_04_G06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_42_B06-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\ds1b_g5_E5.tif', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\ds1b_g5_E4.tif', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_51_D10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds62_g8_B10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.09_Day10_E10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g3_C04-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.04_Day10_E08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds62_g8_B09-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_51_D08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\sd_04_G07-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds41_g3_C05-T01.tiff']
# 100%|██████████| 8/8 [00:05<00:00,  1.35it/s]
# Batch features shape: torch.Size([8, 512])
# Batch labels shape: torch.Size([8])
# Batch labels shape: ['C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g6_F03-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.10_Day10_D08-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds62_g9_C11-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\sd_40\\sd_RBT_01.10_Day10_C10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_41_G10-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\sd_04_B04-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\ex\\ds61_g6_F04-T01.tiff', 'C:\\Users\\k54739\\Bibi_new_thesis\\thesis\\classification\\cluster_40\\curated_cond7_40\\ds_41_G07-T01.tiff']
# Features shape after concatenation: torch.Size([120, 512])
# Labels shape after concatenation: torch.Size([120])
# Number of paths after concatenation: 120

# %%
# Convert features and labels to NumPy arrays
feats_np = feats.numpy()
labels_np = labels.numpy()

# Ensure that paths is a list of the correct length
assert len(paths) == feats_np.shape[0], "Mismatch between number of features and paths"

# Check the shapes
print("Shape of features (for K-Means):", feats_np.shape)
print("Shape of labels:", labels_np.shape)
# Out:
# Shape of features (for K-Means): (120, 512)
# Shape of labels: (120,)

# %% [markdown]
# From scratch

# %%
import numpy as np
from scipy.stats import mode
from collections import Counter

# K-Means initialization function
def kMeans_init_centroids(X, K):
    randidx = np.random.permutation(X.shape[0])
    centroids = X[randidx[:K]]
    return centroids

# Function to find the closest centroids
def find_closest_centroids(X, centroids):
    idx = np.zeros(X.shape[0], dtype=int)
    for i in range(X.shape[0]):
        distances = np.linalg.norm(X[i] - centroids, axis=1)
        idx[i] = np.argmin(distances)
    return idx

# Function to compute new centroids
def compute_centroids(X, idx, K):
    centroids = np.zeros((K, X.shape[1]))
    for k in range(K):
        points = X[idx == k]
        centroids[k] = np.mean(points, axis=0) if len(points) > 0 else centroids[k]
    return centroids

# Function to run K-Means algorithm
def run_kMeans(X, initial_centroids, max_iters=10):
    K = initial_centroids.shape[0]
    centroids = initial_centroids
    idx = np.zeros(X.shape[0])

    for i in range(max_iters):
        # Assign each data point to the closest centroid
        idx = find_closest_centroids(X, centroids)
        
        # Compute new centroids
        centroids = compute_centroids(X, idx, K)
        
    return centroids, idx

# Function to reorder K-Means labels to match true labels
def reorder_labels(true_labels, predicted_labels):
    reordered_labels = np.zeros_like(predicted_labels)
    for cluster in np.unique(predicted_labels):
        mask = (predicted_labels == cluster)
        most_common_label = mode(true_labels[mask], axis=None).mode
        if isinstance(most_common_label, np.ndarray):
            most_common_label = most_common_label[0]
        reordered_labels[mask] = most_common_label
    return reordered_labels

# Main loop to run K-Means 100 times and track the best accuracy
K = 3  # Number of clusters
max_iters = 200  # Maximum iterations
num_trials = 150  # Number of trials
max_accuracy = 0  # To store the maximum accuracy achieved

for trial in range(num_trials):
    print(f"Trial {trial + 1}/{num_trials}")
    
    # Initialize centroids
    initial_centroids = kMeans_init_centroids(feats_np, K)
    
    # Run K-Means
    centroids, idx = run_kMeans(feats_np, initial_centroids, max_iters)
    
    # Reorder labels and calculate accuracy
    reordered_idx = reorder_labels(labels_np, idx)
    accuracy = np.sum(reordered_idx == labels_np) / len(labels_np) * 100
    
    print(f"Accuracy for trial {trial + 1}: {accuracy:.2f}%")
    
    # Update maximum accuracy if the current one is better
    if accuracy > max_accuracy:
        max_accuracy = accuracy

print(f"Maximum accuracy achieved over {num_trials} trials: {max_accuracy:.2f}%")
# Out:
# Trial 1/150
# Accuracy for trial 1: 47.50%
# Trial 2/150
# Accuracy for trial 2: 75.83%
# Trial 3/150
# Accuracy for trial 3: 71.67%
# Trial 4/150
# Accuracy for trial 4: 75.00%
# Trial 5/150
# Accuracy for trial 5: 75.83%
# Trial 6/150
# Accuracy for trial 6: 71.67%
# Trial 7/150
# Accuracy for trial 7: 74.17%
# Trial 8/150
# Accuracy for trial 8: 78.33%
# Trial 9/150
# Accuracy for trial 9: 73.33%
# Trial 10/150
# Accuracy for trial 10: 74.17%
# Trial 11/150
# Accuracy for trial 11: 75.83%
# Trial 12/150
# Accuracy for trial 12: 72.50%
# Trial 13/150
# Accuracy for trial 13: 78.33%
# Trial 14/150
# Accuracy for trial 14: 74.17%
# Trial 15/150
# Accuracy for trial 15: 78.33%
# Trial 16/150
# Accuracy for trial 16: 78.33%
# Trial 17/150
# Accuracy for trial 17: 77.50%
# Trial 18/150
# Accuracy for trial 18: 74.17%
# Trial 19/150
# Accuracy for trial 19: 71.67%
# Trial 20/150
# Accuracy for trial 20: 73.33%
# Trial 21/150
# Accuracy for trial 21: 75.83%
# Trial 22/150
# Accuracy for trial 22: 75.00%
# Trial 23/150
# Accuracy for trial 23: 78.33%
# Trial 24/150
# Accuracy for trial 24: 72.50%
# Trial 25/150
# Accuracy for trial 25: 71.67%
# Trial 26/150
# Accuracy for trial 26: 75.83%
# Trial 27/150
# Accuracy for trial 27: 50.00%
# Trial 28/150
# Accuracy for trial 28: 76.67%
# Trial 29/150
# Accuracy for trial 29: 76.67%
# Trial 30/150
# Accuracy for trial 30: 75.83%
# Trial 31/150
# Accuracy for trial 31: 78.33%
# Trial 32/150
# Accuracy for trial 32: 75.83%
# Trial 33/150
# Accuracy for trial 33: 65.83%
# Trial 34/150
# Accuracy for trial 34: 79.17%
# Trial 35/150
# Accuracy for trial 35: 73.33%
# Trial 36/150
# Accuracy for trial 36: 72.50%
# Trial 37/150
# Accuracy for trial 37: 75.83%
# Trial 38/150
# Accuracy for trial 38: 75.83%
# Trial 39/150
# Accuracy for trial 39: 74.17%
# Trial 40/150
# Accuracy for trial 40: 75.83%
# Trial 41/150
# Accuracy for trial 41: 50.83%
# Trial 42/150
# Accuracy for trial 42: 73.33%
# Trial 43/150
# Accuracy for trial 43: 75.83%
# Trial 44/150
# Accuracy for trial 44: 82.50%
# Trial 45/150
# Accuracy for trial 45: 75.83%
# Trial 46/150
# Accuracy for trial 46: 52.50%
# Trial 47/150
# Accuracy for trial 47: 71.67%
# Trial 48/150
# Accuracy for trial 48: 60.83%
# Trial 49/150
# Accuracy for trial 49: 75.83%
# Trial 50/150
# Accuracy for trial 50: 71.67%
# Trial 51/150
# Accuracy for trial 51: 60.83%
# Trial 52/150
# Accuracy for trial 52: 75.00%
# Trial 53/150
# Accuracy for trial 53: 74.17%
# Trial 54/150
# Accuracy for trial 54: 71.67%
# Trial 55/150
# Accuracy for trial 55: 75.00%
# Trial 56/150
# Accuracy for trial 56: 75.83%
# Trial 57/150
# Accuracy for trial 57: 73.33%
# Trial 58/150
# Accuracy for trial 58: 59.17%
# Trial 59/150
# Accuracy for trial 59: 75.83%
# Trial 60/150
# Accuracy for trial 60: 72.50%
# Trial 61/150
# Accuracy for trial 61: 71.67%
# Trial 62/150
# Accuracy for trial 62: 78.33%
# Trial 63/150
# Accuracy for trial 63: 78.33%
# Trial 64/150
# Accuracy for trial 64: 60.83%
# Trial 65/150
# Accuracy for trial 65: 75.00%
# Trial 66/150
# Accuracy for trial 66: 78.33%
# Trial 67/150
# Accuracy for trial 67: 75.00%
# Trial 68/150
# Accuracy for trial 68: 54.17%
# Trial 69/150
# Accuracy for trial 69: 71.67%
# Trial 70/150
# Accuracy for trial 70: 59.17%
# Trial 71/150
# Accuracy for trial 71: 74.17%
# Trial 72/150
# Accuracy for trial 72: 59.17%
# Trial 73/150
# Accuracy for trial 73: 76.67%
# Trial 74/150
# Accuracy for trial 74: 75.83%
# Trial 75/150
# Accuracy for trial 75: 77.50%
# Trial 76/150
# Accuracy for trial 76: 75.00%
# Trial 77/150
# Accuracy for trial 77: 53.33%
# Trial 78/150
# Accuracy for trial 78: 54.17%
# Trial 79/150
# Accuracy for trial 79: 72.50%
# Trial 80/150
# Accuracy for trial 80: 72.50%
# Trial 81/150
# Accuracy for trial 81: 75.83%
# Trial 82/150
# Accuracy for trial 82: 75.83%
# Trial 83/150
# Accuracy for trial 83: 75.83%
# Trial 84/150
# Accuracy for trial 84: 74.17%
# Trial 85/150
# Accuracy for trial 85: 71.67%
# Trial 86/150
# Accuracy for trial 86: 71.67%
# Trial 87/150
# Accuracy for trial 87: 59.17%
# Trial 88/150
# Accuracy for trial 88: 52.50%
# Trial 89/150
# Accuracy for trial 89: 76.67%
# Trial 90/150
# Accuracy for trial 90: 71.67%
# Trial 91/150
# Accuracy for trial 91: 75.83%
# Trial 92/150
# Accuracy for trial 92: 76.67%
# Trial 93/150
# Accuracy for trial 93: 80.00%
# Trial 94/150
# Accuracy for trial 94: 70.83%
# Trial 95/150
# Accuracy for trial 95: 78.33%
# Trial 96/150
# Accuracy for trial 96: 73.33%
# Trial 97/150
# Accuracy for trial 97: 71.67%
# Trial 98/150
# Accuracy for trial 98: 74.17%
# Trial 99/150
# Accuracy for trial 99: 61.67%
# Trial 100/150
# Accuracy for trial 100: 59.17%
# Trial 101/150
# Accuracy for trial 101: 78.33%
# Trial 102/150
# Accuracy for trial 102: 75.83%
# Trial 103/150
# Accuracy for trial 103: 75.83%
# Trial 104/150
# Accuracy for trial 104: 77.50%
# Trial 105/150
# Accuracy for trial 105: 73.33%
# Trial 106/150
# Accuracy for trial 106: 78.33%
# Trial 107/150
# Accuracy for trial 107: 60.83%
# Trial 108/150
# Accuracy for trial 108: 74.17%
# Trial 109/150
# Accuracy for trial 109: 71.67%
# Trial 110/150
# Accuracy for trial 110: 72.50%
# Trial 111/150
# Accuracy for trial 111: 72.50%
# Trial 112/150
# Accuracy for trial 112: 81.67%
# Trial 113/150
# Accuracy for trial 113: 52.50%
# Trial 114/150
# Accuracy for trial 114: 75.00%
# Trial 115/150
# Accuracy for trial 115: 54.17%
# Trial 116/150
# Accuracy for trial 116: 75.83%
# Trial 117/150
# Accuracy for trial 117: 75.83%
# Trial 118/150
# Accuracy for trial 118: 71.67%
# Trial 119/150
# Accuracy for trial 119: 74.17%
# Trial 120/150
# Accuracy for trial 120: 74.17%
# Trial 121/150
# Accuracy for trial 121: 78.33%
# Trial 122/150
# Accuracy for trial 122: 74.17%
# Trial 123/150
# Accuracy for trial 123: 75.83%
# Trial 124/150
# Accuracy for trial 124: 76.67%
# Trial 125/150
# Accuracy for trial 125: 70.00%
# Trial 126/150
# Accuracy for trial 126: 74.17%
# Trial 127/150
# Accuracy for trial 127: 74.17%
# Trial 128/150
# Accuracy for trial 128: 71.67%
# Trial 129/150
# Accuracy for trial 129: 75.00%
# Trial 130/150
# Accuracy for trial 130: 73.33%
# Trial 131/150
# Accuracy for trial 131: 80.00%
# Trial 132/150
# Accuracy for trial 132: 73.33%
# Trial 133/150
# Accuracy for trial 133: 71.67%
# Trial 134/150
# Accuracy for trial 134: 78.33%
# Trial 135/150
# Accuracy for trial 135: 70.00%
# Trial 136/150
# Accuracy for trial 136: 65.00%
# Trial 137/150
# Accuracy for trial 137: 72.50%
# Trial 138/150
# Accuracy for trial 138: 78.33%
# Trial 139/150
# Accuracy for trial 139: 75.83%
# Trial 140/150
# Accuracy for trial 140: 65.83%
# Trial 141/150
# Accuracy for trial 141: 55.83%
# Trial 142/150
# Accuracy for trial 142: 60.00%
# Trial 143/150
# Accuracy for trial 143: 75.00%
# Trial 144/150
# Accuracy for trial 144: 72.50%
# Trial 145/150
# Accuracy for trial 145: 74.17%
# Trial 146/150
# Accuracy for trial 146: 60.83%
# Trial 147/150
# Accuracy for trial 147: 54.17%
# Trial 148/150
# Accuracy for trial 148: 74.17%
# Trial 149/150
# Accuracy for trial 149: 74.17%
# Trial 150/150
# Accuracy for trial 150: 73.33%
# Maximum accuracy achieved over 150 trials: 82.50%

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
# Function to reduce the dimensionality of data points and centroids to 2D using PCA
def reduce_to_2D_pca(X, centroids):
    # Initialize PCA with 2 components
    pca = PCA(n_components=2)
    
    # Apply PCA to the data points (X) and centroids
    X_2D = pca.fit_transform(X)  # Reducing original data points
    centroids_2D = pca.transform(centroids)  # Reducing centroids

    return X_2D, centroids_2D

# Function to plot 2D visualization of clustered data points and centroids with true labels
def plot_2D_clusters_with_labels(X_2D, centroids_2D, idx, labels, K):
    plt.figure(figsize=(10, 7))
    
    # Define color map for clusters
    colors = plt.cm.rainbow(np.linspace(0, 1, K))
    
    # Plot data points colored by their cluster assignment
    for k in range(K):
        cluster_points = X_2D[idx == k]
        cluster_labels = labels[idx == k]  # Get true labels for the current cluster
        
        # Scatter plot for each cluster
        plt.scatter(cluster_points[:, 0], cluster_points[:, 1], 
                    c=[colors[k]], label=f"Cluster {k+1}", alpha=0.6)
        
        # Annotate each point with its true label
        for i in range(cluster_points.shape[0]):
            plt.annotate(str(cluster_labels[i]), 
                         (cluster_points[i, 0], cluster_points[i, 1]), 
                         fontsize=8, alpha=0.75)

    # Plot centroids as larger markers
    plt.scatter(centroids_2D[:, 0], centroids_2D[:, 1], 
                c='k', marker='x', s=200, label='Centroids')

    plt.title("2D Visualization of Clusters using PCA with True Labels")
    plt.xlabel("Component 1")
    plt.ylabel("Component 2")
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Apply PCA after K-Means clustering for 2D visualization
X_2D_pca, centroids_2D_pca = reduce_to_2D_pca(feats_np, centroids)

# Plot the 2D clusters with centroids and true labels
plot_2D_clusters_with_labels(X_2D_pca, centroids_2D_pca, idx, labels_np, K)
