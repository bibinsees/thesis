# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import tifffile as tiff
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
from copy import deepcopy
import random

# %%
# Load the saved day 7 features
combined_ex7 = torch.load('combined_ex7.pt')

# Load the saved day 10 features
combined_ex10 = torch.load('combined_ex10.pt')
# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_ex7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_ex10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([646, 20])
# Loaded Day 10 Features Shape: torch.Size([646, 20])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_12000\1356550951.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_ex7 = torch.load('combined_ex7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_12000\1356550951.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_ex10 = torch.load('combined_ex10.pt')

# %%
# Load the saved day 7 features
combined_cond7 = torch.load('combined_cond7.pt')

# Load the saved day 10 features
combined_cond10 = torch.load('combined_cond10.pt')
# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_cond7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_cond10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([650, 20])
# Loaded Day 10 Features Shape: torch.Size([650, 20])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_12000\3329391658.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_cond7 = torch.load('combined_cond7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_12000\3329391658.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_cond10 = torch.load('combined_cond10.pt')

# %%
# Load the saved day 7 features
combined_sd7 = torch.load('combined_sd7.pt')

# Load the saved day 10 features
combined_sd10 = torch.load('combined_sd10.pt')

# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_sd7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_sd10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([638, 20])
# Loaded Day 10 Features Shape: torch.Size([638, 20])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_12000\1607657786.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_sd7 = torch.load('combined_sd7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_12000\1607657786.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_sd10 = torch.load('combined_sd10.pt')

# %%
train_day7_feats = combined_cond7 
train_day10_feats = combined_cond10

# %%
train_day7_feats = combined_sd7 
train_day10_feats = combined_sd10

# %%
train_day7_feats = combined_ex7 
train_day10_feats = combined_ex10

# %%
train_day7_feats.shape
# Out:
# torch.Size([646, 20])

# %%
type(train_day7_feats)
# Out:
# torch.Tensor

# %%
train_day7_feats[0].shape
# Out:
# torch.Size([20])

# %%
import matplotlib.pyplot as plt

# Plot histograms for input (X) and target (Y)
plt.figure(figsize=(12, 6))

# Flatten tensors to 1D for easier visualization
train_day7_feats_flat = train_day7_feats.flatten().cpu().numpy()
train_day10_feats_flat = train_day10_feats.flatten().cpu().numpy()

# Input (X) histogram
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_flat, bins=50, color='blue', alpha=0.7, label='Input (X)')
plt.title('Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_flat, bins=50, color='green', alpha=0.7, label='Target (Y)')
plt.title('Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"Input (X): Mean={train_day7_feats.mean():.4f}, Std={train_day7_feats.std():.4f}")
print(f"Target (Y): Mean={train_day10_feats.mean():.4f}, Std={train_day10_feats.std():.4f}")
# Out:
# Input (X): Mean=0.2350, Std=1.9760
# Target (Y): Mean=-0.1614, Std=1.8323

# %%
# Convert PyTorch tensor to NumPy array
train_day7_feats_numpy = train_day7_feats.numpy()
train_day10_feats_numpy = train_day10_feats.numpy()

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize separate MinMaxScaler for day7 and day10
scaler_day7 = MinMaxScaler()
scaler_day10 = MinMaxScaler()

# Fit and transform the train_day7_feats
train_day7_feats_minmaxed = scaler_day7.fit_transform(train_day7_feats_numpy)
print(train_day7_feats_minmaxed.shape)
# Get min and max values for day7
min_values_day7 = scaler_day7.data_min_
max_values_day7 = scaler_day7.data_max_

print(min_values_day7.shape)
print(max_values_day7.shape)
#print("Min values for day7:", min_values_day7)
#print("Max values for day7:", max_values_day7)

# Fit and transform the train_day10_feats (target)
train_day10_feats_minmaxed = scaler_day10.fit_transform(train_day10_feats_numpy)
print(train_day10_feats_minmaxed.shape)
# Get min and max values for day10
min_values_day10 = scaler_day10.data_min_
max_values_day10 = scaler_day10.data_max_

print(min_values_day10.shape)
print(max_values_day10.shape)
#print("Min values for day10:", min_values_day10)
#print("Max values for day10:", max_values_day10)

# Convert the scaled data back to PyTorch tensors (optional)
train_day7_feats_minmaxed = torch.tensor(train_day7_feats_minmaxed)
train_day10_feats_minmaxed = torch.tensor(train_day10_feats_minmaxed)
# Out:
# (646, 20)
# (20,)
# (20,)
# (646, 20)
# (20,)
# (20,)

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'ex7.pkl')
joblib.dump(scaler_day10, 'ex10.pkl')

print("Scalers saved!")
# Out:
# Scalers saved!

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'sd7.pkl')
joblib.dump(scaler_day10, 'sd10.pkl')

print("Scalers saved!")

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'cond7.pkl')
joblib.dump(scaler_day10, 'cond10.pkl')

print("Scalers saved!")

# %%
type(train_day7_feats_minmaxed)

# %%
import matplotlib.pyplot as plt

# Flatten the tensors for easier visualization
train_day7_feats_minmaxed_flat = train_day7_feats_minmaxed.flatten().cpu().numpy()
train_day10_feats_minmaxed_flat = train_day10_feats_minmaxed.flatten().cpu().numpy()

# Plot histograms
plt.figure(figsize=(12, 6))

# Input (X) histogram after Min-Max scaling
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_minmaxed_flat, bins=50, color='blue', alpha=0.7, label='Min-Max Scaled Input (X)')
plt.title('Min-Max Scaled Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram after Min-Max scaling
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_minmaxed_flat, bins=50, color='green', alpha=0.7, label='Min-Max Scaled Target (Y)')
plt.title('Min-Max Scaled Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import torch
import torch.nn as nn

class FeaturePredictor(nn.Module):
    def __init__(self, input_size=20, output_size=20):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_size, 16),
            nn.BatchNorm1d(16),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(16, 8),
            nn.BatchNorm1d(8),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(8, 4),
            nn.BatchNorm1d(4),
        )
        self.decoder = nn.Sequential(
            nn.Linear(4, 8),
            nn.BatchNorm1d(8),
            nn.ReLU(),
            nn.Linear(8, 16),
            nn.BatchNorm1d(16),
            nn.ReLU(),
            nn.Linear(16, output_size)
        )
    
    def forward(self, x):
        x = self.encoder(x)
        z = self.decoder(x)
        return z

# Example usage
model = FeaturePredictor()
print(model)
# Out:
# FeaturePredictor(
#   (encoder): Sequential(
#     (0): Linear(in_features=20, out_features=16, bias=True)
#     (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=16, out_features=8, bias=True)
#     (5): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.3, inplace=False)
#     (8): Linear(in_features=8, out_features=4, bias=True)
#     (9): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=4, out_features=8, bias=True)
#     (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=8, out_features=16, bias=True)
#     (4): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Linear(in_features=16, out_features=20, bias=True)
#   )
# )

# %% [markdown]
# class FeaturePredictor(nn.Module):
#     def __init__(self, input_size=512, output_size=512):
#         super().__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_size, 256),
#             nn.BatchNorm1d(256),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(256, 64),
#             nn.BatchNorm1d(64),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(64, 16),
#             nn.BatchNorm1d(16),
#         )
#         self.decoder = nn.Sequential(
#             nn.Linear(16, 64),
#             nn.BatchNorm1d(64),
#             nn.ReLU(),
#             nn.Linear(64, 256),
#             nn.BatchNorm1d(256),
#             nn.ReLU(),
#             nn.Linear(256, output_size)
#         )
#
#     # Corrected indentation for forward method
#     def forward(self, x):
#         x = self.encoder(x)
#         z = self.decoder(x)
#         return z

# %% [markdown]
# import torch.nn as nn
# from torch.utils.data import TensorDataset, DataLoader
#
# class FeaturePredictor(nn.Module):
#     def __init__(self, input_size=512, output_size=512):
#         super(FeaturePredictor, self).__init__()
#         self.model = nn.Sequential(
#             nn.Linear(input_size, 256),
#             nn.ReLU(),
#             nn.Linear(256, 128),
#             nn.ReLU(),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Linear(64, 32),
#             nn.ReLU(),
#             nn.Linear(32, 16),
#             nn.ReLU(),
#             nn.Linear(16,8),
#             nn.ReLU(),
#             nn.Linear(8, 16),
#             nn.ReLU(),
#             nn.Linear(16,32),
#             nn.ReLU(),
#             nn.Linear(32, 64),
#             nn.ReLU(),
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Linear(128,256),
#             nn.ReLU(),
#             nn.Linear(256, output_size)
#         )
#
#     def forward(self, x):
#         return self.model(x)

# %%
model = FeaturePredictor()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset

# %%
from torch.utils.data import TensorDataset

optimizer_class = torch.optim.Adam

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset
import numpy as np
import torch

# %%
class EarlyStopping:
    def __init__(self, patience=10, delta=0.0):
        """
        Args:
            patience (int): How many epochs to wait after the last validation loss improvement.
            delta (float): Minimum change in the validation loss to qualify as an improvement.
        """
        self.patience = patience
        self.delta = delta
        self.best_loss = None
        self.no_improvement_epochs = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.no_improvement_epochs = 0
        else:
            self.no_improvement_epochs += 1
            if self.no_improvement_epochs >= self.patience:
                self.early_stop = True


def cross_validate_with_early_stopping(
    model_class, dataset, criterion, optimizer_class, num_epochs=50, n_splits=10, patience=10, device='cuda'
):
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    histories = []
    best_models = []

    for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset)):
        print(f"Fold {fold + 1}/{n_splits}")

        # Create subsets for this fold
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        # Create DataLoaders
        train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

        # Initialize the model, optimizer, and early stopping for this fold
        model = model_class().to(device)
        optimizer = optimizer_class(model.parameters(), lr=1e-4)
        early_stopping = EarlyStopping(patience=patience)

        # Training and validation loop
        history = {'train_loss': [], 'val_loss': []}
        for epoch in range(num_epochs):
            # Training phase
            model.train()
            train_loss = 0.0
            for batch_inputs, batch_targets in train_loader:
                batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)

                # Forward pass
                outputs = model(batch_inputs)
                loss = criterion(outputs, batch_targets)
                train_loss += loss.item()

                # Backward pass and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            train_loss /= len(train_loader)
            history['train_loss'].append(train_loss)

            # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for batch_inputs, batch_targets in val_loader:
                    batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)
                    outputs = model(batch_inputs)
                    loss = criterion(outputs, batch_targets)
                    val_loss += loss.item()

            val_loss /= len(val_loader)
            history['val_loss'].append(val_loss)

            print(f"Epoch [{epoch + 1}/{num_epochs}] Fold {fold + 1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

            # Check early stopping
            early_stopping(val_loss)
            if early_stopping.early_stop:
                print(f"Early stopping at epoch {epoch + 1} for fold {fold + 1}")
                break

        # Save the best model for this fold
        best_models.append(model.state_dict())
        histories.append(history)

    return histories, best_models

# %%
# MIN MAX
dataset = TensorDataset(train_day7_feats_minmaxed, train_day10_feats_minmaxed)

cv_histories, best_models = cross_validate_with_early_stopping(
    model_class=FeaturePredictor,
    dataset=dataset,
    criterion=nn.MSELoss(),
    optimizer_class=torch.optim.Adam,
    num_epochs=1500,
    patience=500
)
# Out:
# Fold 1/10
# Epoch [1/1500] Fold 1, Train Loss: 0.4318, Val Loss: 0.3275
# Epoch [2/1500] Fold 1, Train Loss: 0.4213, Val Loss: 0.3494
# Epoch [3/1500] Fold 1, Train Loss: 0.3992, Val Loss: 0.3425
# Epoch [4/1500] Fold 1, Train Loss: 0.3878, Val Loss: 0.3316
# Epoch [5/1500] Fold 1, Train Loss: 0.3725, Val Loss: 0.3288
# Epoch [6/1500] Fold 1, Train Loss: 0.3593, Val Loss: 0.3230
# Epoch [7/1500] Fold 1, Train Loss: 0.3451, Val Loss: 0.3115
# Epoch [8/1500] Fold 1, Train Loss: 0.3332, Val Loss: 0.3056
# Epoch [9/1500] Fold 1, Train Loss: 0.3243, Val Loss: 0.2961
# Epoch [10/1500] Fold 1, Train Loss: 0.3121, Val Loss: 0.2829
# Epoch [11/1500] Fold 1, Train Loss: 0.2992, Val Loss: 0.2794
# Epoch [12/1500] Fold 1, Train Loss: 0.2914, Val Loss: 0.2710
# Epoch [13/1500] Fold 1, Train Loss: 0.2779, Val Loss: 0.2620
# Epoch [14/1500] Fold 1, Train Loss: 0.2693, Val Loss: 0.2480
# Epoch [15/1500] Fold 1, Train Loss: 0.2580, Val Loss: 0.2398
# Epoch [16/1500] Fold 1, Train Loss: 0.2553, Val Loss: 0.2348
# Epoch [17/1500] Fold 1, Train Loss: 0.2448, Val Loss: 0.2301
# Epoch [18/1500] Fold 1, Train Loss: 0.2351, Val Loss: 0.2198
# Epoch [19/1500] Fold 1, Train Loss: 0.2255, Val Loss: 0.2151
# Epoch [20/1500] Fold 1, Train Loss: 0.2197, Val Loss: 0.2071
# Epoch [21/1500] Fold 1, Train Loss: 0.2116, Val Loss: 0.1988
# Epoch [22/1500] Fold 1, Train Loss: 0.2059, Val Loss: 0.1944
# Epoch [23/1500] Fold 1, Train Loss: 0.1966, Val Loss: 0.1827
# Epoch [24/1500] Fold 1, Train Loss: 0.1919, Val Loss: 0.1815
# Epoch [25/1500] Fold 1, Train Loss: 0.1863, Val Loss: 0.1759
# Epoch [26/1500] Fold 1, Train Loss: 0.1791, Val Loss: 0.1635
# Epoch [27/1500] Fold 1, Train Loss: 0.1725, Val Loss: 0.1599
# Epoch [28/1500] Fold 1, Train Loss: 0.1657, Val Loss: 0.1562
# Epoch [29/1500] Fold 1, Train Loss: 0.1611, Val Loss: 0.1521
# Epoch [30/1500] Fold 1, Train Loss: 0.1556, Val Loss: 0.1469
# Epoch [31/1500] Fold 1, Train Loss: 0.1516, Val Loss: 0.1483
# Epoch [32/1500] Fold 1, Train Loss: 0.1479, Val Loss: 0.1415
# Epoch [33/1500] Fold 1, Train Loss: 0.1426, Val Loss: 0.1356
# Epoch [34/1500] Fold 1, Train Loss: 0.1348, Val Loss: 0.1265
# Epoch [35/1500] Fold 1, Train Loss: 0.1360, Val Loss: 0.1342
# Epoch [36/1500] Fold 1, Train Loss: 0.1289, Val Loss: 0.1249
# Epoch [37/1500] Fold 1, Train Loss: 0.1276, Val Loss: 0.1147
# Epoch [38/1500] Fold 1, Train Loss: 0.1259, Val Loss: 0.1202
# Epoch [39/1500] Fold 1, Train Loss: 0.1212, Val Loss: 0.1136
# Epoch [40/1500] Fold 1, Train Loss: 0.1160, Val Loss: 0.1054
# Epoch [41/1500] Fold 1, Train Loss: 0.1132, Val Loss: 0.1062
# Epoch [42/1500] Fold 1, Train Loss: 0.1107, Val Loss: 0.1125
# Epoch [43/1500] Fold 1, Train Loss: 0.1085, Val Loss: 0.0991
# Epoch [44/1500] Fold 1, Train Loss: 0.1084, Val Loss: 0.0932
# Epoch [45/1500] Fold 1, Train Loss: 0.1053, Val Loss: 0.0914
# Epoch [46/1500] Fold 1, Train Loss: 0.1004, Val Loss: 0.0946
# Epoch [47/1500] Fold 1, Train Loss: 0.0977, Val Loss: 0.0950
# Epoch [48/1500] Fold 1, Train Loss: 0.0949, Val Loss: 0.0866
# Epoch [49/1500] Fold 1, Train Loss: 0.0953, Val Loss: 0.0817
# Epoch [50/1500] Fold 1, Train Loss: 0.0955, Val Loss: 0.0817
# Epoch [51/1500] Fold 1, Train Loss: 0.0905, Val Loss: 0.0799
# Epoch [52/1500] Fold 1, Train Loss: 0.0884, Val Loss: 0.0793
# Epoch [53/1500] Fold 1, Train Loss: 0.0913, Val Loss: 0.0820
# Epoch [54/1500] Fold 1, Train Loss: 0.0884, Val Loss: 0.0873
# Epoch [55/1500] Fold 1, Train Loss: 0.0832, Val Loss: 0.0856
# Epoch [56/1500] Fold 1, Train Loss: 0.0824, Val Loss: 0.0789
# Epoch [57/1500] Fold 1, Train Loss: 0.0833, Val Loss: 0.0779
# Epoch [58/1500] Fold 1, Train Loss: 0.0818, Val Loss: 0.0742
# Epoch [59/1500] Fold 1, Train Loss: 0.0773, Val Loss: 0.0705
# Epoch [60/1500] Fold 1, Train Loss: 0.0809, Val Loss: 0.0752
# Epoch [61/1500] Fold 1, Train Loss: 0.0792, Val Loss: 0.0695
# Epoch [62/1500] Fold 1, Train Loss: 0.0767, Val Loss: 0.0699
# Epoch [63/1500] Fold 1, Train Loss: 0.0759, Val Loss: 0.0711
# Epoch [64/1500] Fold 1, Train Loss: 0.0724, Val Loss: 0.0664
# Epoch [65/1500] Fold 1, Train Loss: 0.0727, Val Loss: 0.0636
# Epoch [66/1500] Fold 1, Train Loss: 0.0744, Val Loss: 0.0654
# Epoch [67/1500] Fold 1, Train Loss: 0.0714, Val Loss: 0.0657
# Epoch [68/1500] Fold 1, Train Loss: 0.0716, Val Loss: 0.0660
# Epoch [69/1500] Fold 1, Train Loss: 0.0705, Val Loss: 0.0619
# Epoch [70/1500] Fold 1, Train Loss: 0.0715, Val Loss: 0.0646
# Epoch [71/1500] Fold 1, Train Loss: 0.0689, Val Loss: 0.0620
# Epoch [72/1500] Fold 1, Train Loss: 0.0692, Val Loss: 0.0605
# Epoch [73/1500] Fold 1, Train Loss: 0.0691, Val Loss: 0.0607
# Epoch [74/1500] Fold 1, Train Loss: 0.0669, Val Loss: 0.0600
# Epoch [75/1500] Fold 1, Train Loss: 0.0647, Val Loss: 0.0584
# Epoch [76/1500] Fold 1, Train Loss: 0.0654, Val Loss: 0.0617
# Epoch [77/1500] Fold 1, Train Loss: 0.0637, Val Loss: 0.0617
# Epoch [78/1500] Fold 1, Train Loss: 0.0670, Val Loss: 0.0610
# Epoch [79/1500] Fold 1, Train Loss: 0.0644, Val Loss: 0.0593
# Epoch [80/1500] Fold 1, Train Loss: 0.0648, Val Loss: 0.0572
# Epoch [81/1500] Fold 1, Train Loss: 0.0629, Val Loss: 0.0605
# Epoch [82/1500] Fold 1, Train Loss: 0.0609, Val Loss: 0.0634
# Epoch [83/1500] Fold 1, Train Loss: 0.0632, Val Loss: 0.0565
# Epoch [84/1500] Fold 1, Train Loss: 0.0625, Val Loss: 0.0590
# Epoch [85/1500] Fold 1, Train Loss: 0.0622, Val Loss: 0.0568
# Epoch [86/1500] Fold 1, Train Loss: 0.0604, Val Loss: 0.0544
# Epoch [87/1500] Fold 1, Train Loss: 0.0615, Val Loss: 0.0593
# Epoch [88/1500] Fold 1, Train Loss: 0.0598, Val Loss: 0.0558
# Epoch [89/1500] Fold 1, Train Loss: 0.0609, Val Loss: 0.0565
# Epoch [90/1500] Fold 1, Train Loss: 0.0622, Val Loss: 0.0535
# Epoch [91/1500] Fold 1, Train Loss: 0.0594, Val Loss: 0.0561
# Epoch [92/1500] Fold 1, Train Loss: 0.0599, Val Loss: 0.0554
# Epoch [93/1500] Fold 1, Train Loss: 0.0588, Val Loss: 0.0557
# Epoch [94/1500] Fold 1, Train Loss: 0.0617, Val Loss: 0.0552
# Epoch [95/1500] Fold 1, Train Loss: 0.0586, Val Loss: 0.0572
# Epoch [96/1500] Fold 1, Train Loss: 0.0609, Val Loss: 0.0554
# Epoch [97/1500] Fold 1, Train Loss: 0.0574, Val Loss: 0.0547
# Epoch [98/1500] Fold 1, Train Loss: 0.0589, Val Loss: 0.0539
# Epoch [99/1500] Fold 1, Train Loss: 0.0590, Val Loss: 0.0544
# Epoch [100/1500] Fold 1, Train Loss: 0.0575, Val Loss: 0.0532
# Epoch [101/1500] Fold 1, Train Loss: 0.0572, Val Loss: 0.0529
# Epoch [102/1500] Fold 1, Train Loss: 0.0594, Val Loss: 0.0544
# Epoch [103/1500] Fold 1, Train Loss: 0.0587, Val Loss: 0.0523
# Epoch [104/1500] Fold 1, Train Loss: 0.0581, Val Loss: 0.0525
# Epoch [105/1500] Fold 1, Train Loss: 0.0578, Val Loss: 0.0525
# Epoch [106/1500] Fold 1, Train Loss: 0.0562, Val Loss: 0.0533
# Epoch [107/1500] Fold 1, Train Loss: 0.0552, Val Loss: 0.0523
# Epoch [108/1500] Fold 1, Train Loss: 0.0577, Val Loss: 0.0520
# Epoch [109/1500] Fold 1, Train Loss: 0.0558, Val Loss: 0.0525
# Epoch [110/1500] Fold 1, Train Loss: 0.0564, Val Loss: 0.0530
# Epoch [111/1500] Fold 1, Train Loss: 0.0538, Val Loss: 0.0528
# Epoch [112/1500] Fold 1, Train Loss: 0.0552, Val Loss: 0.0518
# Epoch [113/1500] Fold 1, Train Loss: 0.0549, Val Loss: 0.0500
# Epoch [114/1500] Fold 1, Train Loss: 0.0550, Val Loss: 0.0511
# Epoch [115/1500] Fold 1, Train Loss: 0.0547, Val Loss: 0.0516
# Epoch [116/1500] Fold 1, Train Loss: 0.0552, Val Loss: 0.0498
# Epoch [117/1500] Fold 1, Train Loss: 0.0552, Val Loss: 0.0508
# Epoch [118/1500] Fold 1, Train Loss: 0.0535, Val Loss: 0.0513
# Epoch [119/1500] Fold 1, Train Loss: 0.0545, Val Loss: 0.0503
# Epoch [120/1500] Fold 1, Train Loss: 0.0540, Val Loss: 0.0507
# Epoch [121/1500] Fold 1, Train Loss: 0.0554, Val Loss: 0.0509
# Epoch [122/1500] Fold 1, Train Loss: 0.0534, Val Loss: 0.0504
# Epoch [123/1500] Fold 1, Train Loss: 0.0523, Val Loss: 0.0514
# Epoch [124/1500] Fold 1, Train Loss: 0.0548, Val Loss: 0.0507
# Epoch [125/1500] Fold 1, Train Loss: 0.0530, Val Loss: 0.0510
# Epoch [126/1500] Fold 1, Train Loss: 0.0532, Val Loss: 0.0486
# Epoch [127/1500] Fold 1, Train Loss: 0.0530, Val Loss: 0.0518
# Epoch [128/1500] Fold 1, Train Loss: 0.0528, Val Loss: 0.0490
# Epoch [129/1500] Fold 1, Train Loss: 0.0550, Val Loss: 0.0495
# Epoch [130/1500] Fold 1, Train Loss: 0.0549, Val Loss: 0.0494
# Epoch [131/1500] Fold 1, Train Loss: 0.0531, Val Loss: 0.0495
# Epoch [132/1500] Fold 1, Train Loss: 0.0538, Val Loss: 0.0500
# Epoch [133/1500] Fold 1, Train Loss: 0.0539, Val Loss: 0.0491
# Epoch [134/1500] Fold 1, Train Loss: 0.0514, Val Loss: 0.0485
# Epoch [135/1500] Fold 1, Train Loss: 0.0534, Val Loss: 0.0493
# Epoch [136/1500] Fold 1, Train Loss: 0.0517, Val Loss: 0.0482
# Epoch [137/1500] Fold 1, Train Loss: 0.0537, Val Loss: 0.0498
# Epoch [138/1500] Fold 1, Train Loss: 0.0524, Val Loss: 0.0486
# Epoch [139/1500] Fold 1, Train Loss: 0.0507, Val Loss: 0.0497
# Epoch [140/1500] Fold 1, Train Loss: 0.0548, Val Loss: 0.0472
# Epoch [141/1500] Fold 1, Train Loss: 0.0529, Val Loss: 0.0491
# Epoch [142/1500] Fold 1, Train Loss: 0.0535, Val Loss: 0.0479
# Epoch [143/1500] Fold 1, Train Loss: 0.0517, Val Loss: 0.0485
# Epoch [144/1500] Fold 1, Train Loss: 0.0525, Val Loss: 0.0482
# Epoch [145/1500] Fold 1, Train Loss: 0.0514, Val Loss: 0.0488
# Epoch [146/1500] Fold 1, Train Loss: 0.0516, Val Loss: 0.0479
# Epoch [147/1500] Fold 1, Train Loss: 0.0510, Val Loss: 0.0473
# Epoch [148/1500] Fold 1, Train Loss: 0.0510, Val Loss: 0.0469
# Epoch [149/1500] Fold 1, Train Loss: 0.0507, Val Loss: 0.0488
# Epoch [150/1500] Fold 1, Train Loss: 0.0513, Val Loss: 0.0483
# Epoch [151/1500] Fold 1, Train Loss: 0.0511, Val Loss: 0.0489
# Epoch [152/1500] Fold 1, Train Loss: 0.0511, Val Loss: 0.0477
# Epoch [153/1500] Fold 1, Train Loss: 0.0509, Val Loss: 0.0479
# Epoch [154/1500] Fold 1, Train Loss: 0.0499, Val Loss: 0.0480
# Epoch [155/1500] Fold 1, Train Loss: 0.0507, Val Loss: 0.0478
# Epoch [156/1500] Fold 1, Train Loss: 0.0509, Val Loss: 0.0464
# Epoch [157/1500] Fold 1, Train Loss: 0.0503, Val Loss: 0.0487
# Epoch [158/1500] Fold 1, Train Loss: 0.0492, Val Loss: 0.0482
# Epoch [159/1500] Fold 1, Train Loss: 0.0509, Val Loss: 0.0473
# Epoch [160/1500] Fold 1, Train Loss: 0.0512, Val Loss: 0.0446
# Epoch [161/1500] Fold 1, Train Loss: 0.0499, Val Loss: 0.0461
# Epoch [162/1500] Fold 1, Train Loss: 0.0501, Val Loss: 0.0451
# Epoch [163/1500] Fold 1, Train Loss: 0.0499, Val Loss: 0.0460
# Epoch [164/1500] Fold 1, Train Loss: 0.0498, Val Loss: 0.0461
# Epoch [165/1500] Fold 1, Train Loss: 0.0510, Val Loss: 0.0463
# Epoch [166/1500] Fold 1, Train Loss: 0.0511, Val Loss: 0.0460
# Epoch [167/1500] Fold 1, Train Loss: 0.0499, Val Loss: 0.0456
# Epoch [168/1500] Fold 1, Train Loss: 0.0484, Val Loss: 0.0465
# Epoch [169/1500] Fold 1, Train Loss: 0.0492, Val Loss: 0.0465
# Epoch [170/1500] Fold 1, Train Loss: 0.0497, Val Loss: 0.0456
# Epoch [171/1500] Fold 1, Train Loss: 0.0506, Val Loss: 0.0446
# Epoch [172/1500] Fold 1, Train Loss: 0.0494, Val Loss: 0.0457
# Epoch [173/1500] Fold 1, Train Loss: 0.0498, Val Loss: 0.0460
# Epoch [174/1500] Fold 1, Train Loss: 0.0493, Val Loss: 0.0454
# Epoch [175/1500] Fold 1, Train Loss: 0.0503, Val Loss: 0.0453
# Epoch [176/1500] Fold 1, Train Loss: 0.0490, Val Loss: 0.0451
# Epoch [177/1500] Fold 1, Train Loss: 0.0493, Val Loss: 0.0452
# Epoch [178/1500] Fold 1, Train Loss: 0.0494, Val Loss: 0.0467
# Epoch [179/1500] Fold 1, Train Loss: 0.0496, Val Loss: 0.0471
# Epoch [180/1500] Fold 1, Train Loss: 0.0494, Val Loss: 0.0452
# Epoch [181/1500] Fold 1, Train Loss: 0.0494, Val Loss: 0.0450
# Epoch [182/1500] Fold 1, Train Loss: 0.0495, Val Loss: 0.0445
# Epoch [183/1500] Fold 1, Train Loss: 0.0491, Val Loss: 0.0447
# Epoch [184/1500] Fold 1, Train Loss: 0.0496, Val Loss: 0.0445
# Epoch [185/1500] Fold 1, Train Loss: 0.0492, Val Loss: 0.0447
# Epoch [186/1500] Fold 1, Train Loss: 0.0482, Val Loss: 0.0437
# Epoch [187/1500] Fold 1, Train Loss: 0.0496, Val Loss: 0.0440
# Epoch [188/1500] Fold 1, Train Loss: 0.0489, Val Loss: 0.0458
# Epoch [189/1500] Fold 1, Train Loss: 0.0476, Val Loss: 0.0455
# Epoch [190/1500] Fold 1, Train Loss: 0.0494, Val Loss: 0.0452
# Epoch [191/1500] Fold 1, Train Loss: 0.0483, Val Loss: 0.0450
# Epoch [192/1500] Fold 1, Train Loss: 0.0479, Val Loss: 0.0451
# Epoch [193/1500] Fold 1, Train Loss: 0.0494, Val Loss: 0.0452
# Epoch [194/1500] Fold 1, Train Loss: 0.0480, Val Loss: 0.0439
# Epoch [195/1500] Fold 1, Train Loss: 0.0493, Val Loss: 0.0434
# Epoch [196/1500] Fold 1, Train Loss: 0.0481, Val Loss: 0.0454
# Epoch [197/1500] Fold 1, Train Loss: 0.0480, Val Loss: 0.0425
# Epoch [198/1500] Fold 1, Train Loss: 0.0480, Val Loss: 0.0431
# Epoch [199/1500] Fold 1, Train Loss: 0.0480, Val Loss: 0.0421
# Epoch [200/1500] Fold 1, Train Loss: 0.0472, Val Loss: 0.0427
# Epoch [201/1500] Fold 1, Train Loss: 0.0502, Val Loss: 0.0451
# Epoch [202/1500] Fold 1, Train Loss: 0.0485, Val Loss: 0.0442
# Epoch [203/1500] Fold 1, Train Loss: 0.0494, Val Loss: 0.0432
# Epoch [204/1500] Fold 1, Train Loss: 0.0466, Val Loss: 0.0440
# Epoch [205/1500] Fold 1, Train Loss: 0.0479, Val Loss: 0.0423
# Epoch [206/1500] Fold 1, Train Loss: 0.0474, Val Loss: 0.0425
# Epoch [207/1500] Fold 1, Train Loss: 0.0485, Val Loss: 0.0426
# Epoch [208/1500] Fold 1, Train Loss: 0.0488, Val Loss: 0.0425
# Epoch [209/1500] Fold 1, Train Loss: 0.0473, Val Loss: 0.0428
# Epoch [210/1500] Fold 1, Train Loss: 0.0479, Val Loss: 0.0427
# Epoch [211/1500] Fold 1, Train Loss: 0.0481, Val Loss: 0.0428
# Epoch [212/1500] Fold 1, Train Loss: 0.0481, Val Loss: 0.0417
# Epoch [213/1500] Fold 1, Train Loss: 0.0478, Val Loss: 0.0420
# Epoch [214/1500] Fold 1, Train Loss: 0.0480, Val Loss: 0.0426
# Epoch [215/1500] Fold 1, Train Loss: 0.0472, Val Loss: 0.0435
# Epoch [216/1500] Fold 1, Train Loss: 0.0466, Val Loss: 0.0420
# Epoch [217/1500] Fold 1, Train Loss: 0.0464, Val Loss: 0.0426
# Epoch [218/1500] Fold 1, Train Loss: 0.0471, Val Loss: 0.0416
# Epoch [219/1500] Fold 1, Train Loss: 0.0459, Val Loss: 0.0424
# Epoch [220/1500] Fold 1, Train Loss: 0.0469, Val Loss: 0.0425
# Epoch [221/1500] Fold 1, Train Loss: 0.0468, Val Loss: 0.0413
# Epoch [222/1500] Fold 1, Train Loss: 0.0461, Val Loss: 0.0430
# Epoch [223/1500] Fold 1, Train Loss: 0.0454, Val Loss: 0.0425
# Epoch [224/1500] Fold 1, Train Loss: 0.0466, Val Loss: 0.0416
# Epoch [225/1500] Fold 1, Train Loss: 0.0472, Val Loss: 0.0408
# Epoch [226/1500] Fold 1, Train Loss: 0.0474, Val Loss: 0.0408
# Epoch [227/1500] Fold 1, Train Loss: 0.0459, Val Loss: 0.0424
# Epoch [228/1500] Fold 1, Train Loss: 0.0465, Val Loss: 0.0421
# Epoch [229/1500] Fold 1, Train Loss: 0.0464, Val Loss: 0.0421
# Epoch [230/1500] Fold 1, Train Loss: 0.0469, Val Loss: 0.0417
# Epoch [231/1500] Fold 1, Train Loss: 0.0472, Val Loss: 0.0421
# Epoch [232/1500] Fold 1, Train Loss: 0.0480, Val Loss: 0.0409
# Epoch [233/1500] Fold 1, Train Loss: 0.0464, Val Loss: 0.0407
# Epoch [234/1500] Fold 1, Train Loss: 0.0458, Val Loss: 0.0403
# Epoch [235/1500] Fold 1, Train Loss: 0.0477, Val Loss: 0.0395
# Epoch [236/1500] Fold 1, Train Loss: 0.0471, Val Loss: 0.0410
# Epoch [237/1500] Fold 1, Train Loss: 0.0466, Val Loss: 0.0420
# Epoch [238/1500] Fold 1, Train Loss: 0.0456, Val Loss: 0.0401
# Epoch [239/1500] Fold 1, Train Loss: 0.0469, Val Loss: 0.0401
# Epoch [240/1500] Fold 1, Train Loss: 0.0478, Val Loss: 0.0408
# Epoch [241/1500] Fold 1, Train Loss: 0.0471, Val Loss: 0.0394
# Epoch [242/1500] Fold 1, Train Loss: 0.0461, Val Loss: 0.0401
# Epoch [243/1500] Fold 1, Train Loss: 0.0462, Val Loss: 0.0406
# Epoch [244/1500] Fold 1, Train Loss: 0.0466, Val Loss: 0.0401
# Epoch [245/1500] Fold 1, Train Loss: 0.0449, Val Loss: 0.0411
# Epoch [246/1500] Fold 1, Train Loss: 0.0466, Val Loss: 0.0396
# Epoch [247/1500] Fold 1, Train Loss: 0.0466, Val Loss: 0.0398
# Epoch [248/1500] Fold 1, Train Loss: 0.0470, Val Loss: 0.0409
# Epoch [249/1500] Fold 1, Train Loss: 0.0453, Val Loss: 0.0403
# Epoch [250/1500] Fold 1, Train Loss: 0.0460, Val Loss: 0.0398
# Epoch [251/1500] Fold 1, Train Loss: 0.0450, Val Loss: 0.0391
# Epoch [252/1500] Fold 1, Train Loss: 0.0459, Val Loss: 0.0392
# Epoch [253/1500] Fold 1, Train Loss: 0.0450, Val Loss: 0.0398
# Epoch [254/1500] Fold 1, Train Loss: 0.0458, Val Loss: 0.0401
# Epoch [255/1500] Fold 1, Train Loss: 0.0472, Val Loss: 0.0402
# Epoch [256/1500] Fold 1, Train Loss: 0.0451, Val Loss: 0.0401
# Epoch [257/1500] Fold 1, Train Loss: 0.0450, Val Loss: 0.0403
# Epoch [258/1500] Fold 1, Train Loss: 0.0446, Val Loss: 0.0397
# Epoch [259/1500] Fold 1, Train Loss: 0.0447, Val Loss: 0.0391
# Epoch [260/1500] Fold 1, Train Loss: 0.0455, Val Loss: 0.0403
# Epoch [261/1500] Fold 1, Train Loss: 0.0463, Val Loss: 0.0389
# Epoch [262/1500] Fold 1, Train Loss: 0.0439, Val Loss: 0.0386
# Epoch [263/1500] Fold 1, Train Loss: 0.0462, Val Loss: 0.0386
# Epoch [264/1500] Fold 1, Train Loss: 0.0442, Val Loss: 0.0385
# Epoch [265/1500] Fold 1, Train Loss: 0.0443, Val Loss: 0.0389
# Epoch [266/1500] Fold 1, Train Loss: 0.0448, Val Loss: 0.0386
# Epoch [267/1500] Fold 1, Train Loss: 0.0447, Val Loss: 0.0388
# Epoch [268/1500] Fold 1, Train Loss: 0.0448, Val Loss: 0.0399
# Epoch [269/1500] Fold 1, Train Loss: 0.0451, Val Loss: 0.0384
# Epoch [270/1500] Fold 1, Train Loss: 0.0458, Val Loss: 0.0385
# Epoch [271/1500] Fold 1, Train Loss: 0.0466, Val Loss: 0.0385
# Epoch [272/1500] Fold 1, Train Loss: 0.0444, Val Loss: 0.0378
# Epoch [273/1500] Fold 1, Train Loss: 0.0446, Val Loss: 0.0394
# Epoch [274/1500] Fold 1, Train Loss: 0.0453, Val Loss: 0.0384
# Epoch [275/1500] Fold 1, Train Loss: 0.0448, Val Loss: 0.0383
# Epoch [276/1500] Fold 1, Train Loss: 0.0448, Val Loss: 0.0388
# Epoch [277/1500] Fold 1, Train Loss: 0.0457, Val Loss: 0.0391
# Epoch [278/1500] Fold 1, Train Loss: 0.0448, Val Loss: 0.0389
# Epoch [279/1500] Fold 1, Train Loss: 0.0448, Val Loss: 0.0384
# Epoch [280/1500] Fold 1, Train Loss: 0.0450, Val Loss: 0.0381
# Epoch [281/1500] Fold 1, Train Loss: 0.0459, Val Loss: 0.0381
# Epoch [282/1500] Fold 1, Train Loss: 0.0442, Val Loss: 0.0373
# Epoch [283/1500] Fold 1, Train Loss: 0.0440, Val Loss: 0.0382
# Epoch [284/1500] Fold 1, Train Loss: 0.0443, Val Loss: 0.0387
# Epoch [285/1500] Fold 1, Train Loss: 0.0446, Val Loss: 0.0380
# Epoch [286/1500] Fold 1, Train Loss: 0.0445, Val Loss: 0.0390
# Epoch [287/1500] Fold 1, Train Loss: 0.0442, Val Loss: 0.0375
# Epoch [288/1500] Fold 1, Train Loss: 0.0443, Val Loss: 0.0393
# Epoch [289/1500] Fold 1, Train Loss: 0.0463, Val Loss: 0.0394
# Epoch [290/1500] Fold 1, Train Loss: 0.0456, Val Loss: 0.0382
# Epoch [291/1500] Fold 1, Train Loss: 0.0445, Val Loss: 0.0379
# Epoch [292/1500] Fold 1, Train Loss: 0.0439, Val Loss: 0.0383
# Epoch [293/1500] Fold 1, Train Loss: 0.0446, Val Loss: 0.0381
# Epoch [294/1500] Fold 1, Train Loss: 0.0432, Val Loss: 0.0381
# Epoch [295/1500] Fold 1, Train Loss: 0.0461, Val Loss: 0.0376
# Epoch [296/1500] Fold 1, Train Loss: 0.0437, Val Loss: 0.0372
# Epoch [297/1500] Fold 1, Train Loss: 0.0448, Val Loss: 0.0379
# Epoch [298/1500] Fold 1, Train Loss: 0.0448, Val Loss: 0.0378
# Epoch [299/1500] Fold 1, Train Loss: 0.0429, Val Loss: 0.0381
# Epoch [300/1500] Fold 1, Train Loss: 0.0446, Val Loss: 0.0384
# Epoch [301/1500] Fold 1, Train Loss: 0.0438, Val Loss: 0.0373
# Epoch [302/1500] Fold 1, Train Loss: 0.0438, Val Loss: 0.0379
# Epoch [303/1500] Fold 1, Train Loss: 0.0436, Val Loss: 0.0378
# Epoch [304/1500] Fold 1, Train Loss: 0.0438, Val Loss: 0.0379
# Epoch [305/1500] Fold 1, Train Loss: 0.0438, Val Loss: 0.0374
# Epoch [306/1500] Fold 1, Train Loss: 0.0428, Val Loss: 0.0388
# Epoch [307/1500] Fold 1, Train Loss: 0.0430, Val Loss: 0.0378
# Epoch [308/1500] Fold 1, Train Loss: 0.0433, Val Loss: 0.0370
# Epoch [309/1500] Fold 1, Train Loss: 0.0439, Val Loss: 0.0379
# Epoch [310/1500] Fold 1, Train Loss: 0.0437, Val Loss: 0.0368
# Epoch [311/1500] Fold 1, Train Loss: 0.0438, Val Loss: 0.0367
# Epoch [312/1500] Fold 1, Train Loss: 0.0447, Val Loss: 0.0384
# Epoch [313/1500] Fold 1, Train Loss: 0.0436, Val Loss: 0.0378
# Epoch [314/1500] Fold 1, Train Loss: 0.0440, Val Loss: 0.0380
# Epoch [315/1500] Fold 1, Train Loss: 0.0446, Val Loss: 0.0372
# Epoch [316/1500] Fold 1, Train Loss: 0.0440, Val Loss: 0.0386
# Epoch [317/1500] Fold 1, Train Loss: 0.0443, Val Loss: 0.0373
# Epoch [318/1500] Fold 1, Train Loss: 0.0433, Val Loss: 0.0369
# Epoch [319/1500] Fold 1, Train Loss: 0.0437, Val Loss: 0.0370
# Epoch [320/1500] Fold 1, Train Loss: 0.0434, Val Loss: 0.0376
# Epoch [321/1500] Fold 1, Train Loss: 0.0450, Val Loss: 0.0373
# Epoch [322/1500] Fold 1, Train Loss: 0.0434, Val Loss: 0.0371
# Epoch [323/1500] Fold 1, Train Loss: 0.0434, Val Loss: 0.0372
# Epoch [324/1500] Fold 1, Train Loss: 0.0431, Val Loss: 0.0378
# Epoch [325/1500] Fold 1, Train Loss: 0.0433, Val Loss: 0.0363
# Epoch [326/1500] Fold 1, Train Loss: 0.0433, Val Loss: 0.0358
# Epoch [327/1500] Fold 1, Train Loss: 0.0450, Val Loss: 0.0356
# Epoch [328/1500] Fold 1, Train Loss: 0.0436, Val Loss: 0.0368
# Epoch [329/1500] Fold 1, Train Loss: 0.0421, Val Loss: 0.0365
# Epoch [330/1500] Fold 1, Train Loss: 0.0430, Val Loss: 0.0357
# Epoch [331/1500] Fold 1, Train Loss: 0.0436, Val Loss: 0.0366
# Epoch [332/1500] Fold 1, Train Loss: 0.0430, Val Loss: 0.0371
# Epoch [333/1500] Fold 1, Train Loss: 0.0435, Val Loss: 0.0361
# Epoch [334/1500] Fold 1, Train Loss: 0.0425, Val Loss: 0.0366
# Epoch [335/1500] Fold 1, Train Loss: 0.0442, Val Loss: 0.0359
# Epoch [336/1500] Fold 1, Train Loss: 0.0422, Val Loss: 0.0360
# Epoch [337/1500] Fold 1, Train Loss: 0.0437, Val Loss: 0.0373
# Epoch [338/1500] Fold 1, Train Loss: 0.0432, Val Loss: 0.0368
# Epoch [339/1500] Fold 1, Train Loss: 0.0434, Val Loss: 0.0370
# Epoch [340/1500] Fold 1, Train Loss: 0.0428, Val Loss: 0.0368
# Epoch [341/1500] Fold 1, Train Loss: 0.0433, Val Loss: 0.0360
# Epoch [342/1500] Fold 1, Train Loss: 0.0424, Val Loss: 0.0369
# Epoch [343/1500] Fold 1, Train Loss: 0.0427, Val Loss: 0.0363
# Epoch [344/1500] Fold 1, Train Loss: 0.0418, Val Loss: 0.0367
# Epoch [345/1500] Fold 1, Train Loss: 0.0420, Val Loss: 0.0365
# Epoch [346/1500] Fold 1, Train Loss: 0.0427, Val Loss: 0.0357
# Epoch [347/1500] Fold 1, Train Loss: 0.0424, Val Loss: 0.0361
# Epoch [348/1500] Fold 1, Train Loss: 0.0435, Val Loss: 0.0367
# Epoch [349/1500] Fold 1, Train Loss: 0.0442, Val Loss: 0.0364
# Epoch [350/1500] Fold 1, Train Loss: 0.0421, Val Loss: 0.0359
# Epoch [351/1500] Fold 1, Train Loss: 0.0423, Val Loss: 0.0364
# Epoch [352/1500] Fold 1, Train Loss: 0.0437, Val Loss: 0.0362
# Epoch [353/1500] Fold 1, Train Loss: 0.0423, Val Loss: 0.0362
# Epoch [354/1500] Fold 1, Train Loss: 0.0437, Val Loss: 0.0358
# Epoch [355/1500] Fold 1, Train Loss: 0.0419, Val Loss: 0.0371
# Epoch [356/1500] Fold 1, Train Loss: 0.0426, Val Loss: 0.0358
# Epoch [357/1500] Fold 1, Train Loss: 0.0426, Val Loss: 0.0358
# Epoch [358/1500] Fold 1, Train Loss: 0.0427, Val Loss: 0.0366
# Epoch [359/1500] Fold 1, Train Loss: 0.0432, Val Loss: 0.0357
# Epoch [360/1500] Fold 1, Train Loss: 0.0440, Val Loss: 0.0364
# Epoch [361/1500] Fold 1, Train Loss: 0.0418, Val Loss: 0.0369
# Epoch [362/1500] Fold 1, Train Loss: 0.0425, Val Loss: 0.0363
# Epoch [363/1500] Fold 1, Train Loss: 0.0443, Val Loss: 0.0363
# Epoch [364/1500] Fold 1, Train Loss: 0.0419, Val Loss: 0.0357
# Epoch [365/1500] Fold 1, Train Loss: 0.0422, Val Loss: 0.0369
# Epoch [366/1500] Fold 1, Train Loss: 0.0416, Val Loss: 0.0356
# Epoch [367/1500] Fold 1, Train Loss: 0.0408, Val Loss: 0.0362
# Epoch [368/1500] Fold 1, Train Loss: 0.0418, Val Loss: 0.0354
# Epoch [369/1500] Fold 1, Train Loss: 0.0414, Val Loss: 0.0356
# Epoch [370/1500] Fold 1, Train Loss: 0.0417, Val Loss: 0.0365
# Epoch [371/1500] Fold 1, Train Loss: 0.0420, Val Loss: 0.0361
# Epoch [372/1500] Fold 1, Train Loss: 0.0417, Val Loss: 0.0365
# Epoch [373/1500] Fold 1, Train Loss: 0.0422, Val Loss: 0.0364
# Epoch [374/1500] Fold 1, Train Loss: 0.0415, Val Loss: 0.0365
# Epoch [375/1500] Fold 1, Train Loss: 0.0427, Val Loss: 0.0362
# Epoch [376/1500] Fold 1, Train Loss: 0.0421, Val Loss: 0.0355
# Epoch [377/1500] Fold 1, Train Loss: 0.0438, Val Loss: 0.0358
# Epoch [378/1500] Fold 1, Train Loss: 0.0412, Val Loss: 0.0363
# Epoch [379/1500] Fold 1, Train Loss: 0.0426, Val Loss: 0.0356
# Epoch [380/1500] Fold 1, Train Loss: 0.0412, Val Loss: 0.0354
# Epoch [381/1500] Fold 1, Train Loss: 0.0428, Val Loss: 0.0354
# Epoch [382/1500] Fold 1, Train Loss: 0.0411, Val Loss: 0.0358
# Epoch [383/1500] Fold 1, Train Loss: 0.0419, Val Loss: 0.0362
# Epoch [384/1500] Fold 1, Train Loss: 0.0426, Val Loss: 0.0355
# Epoch [385/1500] Fold 1, Train Loss: 0.0421, Val Loss: 0.0354
# Epoch [386/1500] Fold 1, Train Loss: 0.0418, Val Loss: 0.0353
# Epoch [387/1500] Fold 1, Train Loss: 0.0407, Val Loss: 0.0352
# Epoch [388/1500] Fold 1, Train Loss: 0.0423, Val Loss: 0.0359
# Epoch [389/1500] Fold 1, Train Loss: 0.0421, Val Loss: 0.0360
# Epoch [390/1500] Fold 1, Train Loss: 0.0419, Val Loss: 0.0364
# Epoch [391/1500] Fold 1, Train Loss: 0.0409, Val Loss: 0.0358
# Epoch [392/1500] Fold 1, Train Loss: 0.0417, Val Loss: 0.0360
# Epoch [393/1500] Fold 1, Train Loss: 0.0410, Val Loss: 0.0357
# Epoch [394/1500] Fold 1, Train Loss: 0.0431, Val Loss: 0.0357
# Epoch [395/1500] Fold 1, Train Loss: 0.0416, Val Loss: 0.0355
# Epoch [396/1500] Fold 1, Train Loss: 0.0429, Val Loss: 0.0353
# Epoch [397/1500] Fold 1, Train Loss: 0.0414, Val Loss: 0.0364
# Epoch [398/1500] Fold 1, Train Loss: 0.0427, Val Loss: 0.0350
# Epoch [399/1500] Fold 1, Train Loss: 0.0405, Val Loss: 0.0355
# Epoch [400/1500] Fold 1, Train Loss: 0.0423, Val Loss: 0.0362
# Epoch [401/1500] Fold 1, Train Loss: 0.0419, Val Loss: 0.0362
# Epoch [402/1500] Fold 1, Train Loss: 0.0414, Val Loss: 0.0353
# Epoch [403/1500] Fold 1, Train Loss: 0.0409, Val Loss: 0.0352
# Epoch [404/1500] Fold 1, Train Loss: 0.0411, Val Loss: 0.0350
# Epoch [405/1500] Fold 1, Train Loss: 0.0416, Val Loss: 0.0354
# Epoch [406/1500] Fold 1, Train Loss: 0.0436, Val Loss: 0.0358
# Epoch [407/1500] Fold 1, Train Loss: 0.0427, Val Loss: 0.0352
# Epoch [408/1500] Fold 1, Train Loss: 0.0426, Val Loss: 0.0353
# Epoch [409/1500] Fold 1, Train Loss: 0.0431, Val Loss: 0.0343
# Epoch [410/1500] Fold 1, Train Loss: 0.0408, Val Loss: 0.0344
# Epoch [411/1500] Fold 1, Train Loss: 0.0402, Val Loss: 0.0351
# Epoch [412/1500] Fold 1, Train Loss: 0.0411, Val Loss: 0.0339
# Epoch [413/1500] Fold 1, Train Loss: 0.0416, Val Loss: 0.0351
# Epoch [414/1500] Fold 1, Train Loss: 0.0400, Val Loss: 0.0350
# Epoch [415/1500] Fold 1, Train Loss: 0.0402, Val Loss: 0.0343
# Epoch [416/1500] Fold 1, Train Loss: 0.0419, Val Loss: 0.0346
# Epoch [417/1500] Fold 1, Train Loss: 0.0399, Val Loss: 0.0345
# Epoch [418/1500] Fold 1, Train Loss: 0.0418, Val Loss: 0.0348
# Epoch [419/1500] Fold 1, Train Loss: 0.0417, Val Loss: 0.0340
# Epoch [420/1500] Fold 1, Train Loss: 0.0406, Val Loss: 0.0343
# Epoch [421/1500] Fold 1, Train Loss: 0.0412, Val Loss: 0.0345
# Epoch [422/1500] Fold 1, Train Loss: 0.0405, Val Loss: 0.0343
# Epoch [423/1500] Fold 1, Train Loss: 0.0414, Val Loss: 0.0344
# Epoch [424/1500] Fold 1, Train Loss: 0.0413, Val Loss: 0.0346
# Epoch [425/1500] Fold 1, Train Loss: 0.0412, Val Loss: 0.0349
# Epoch [426/1500] Fold 1, Train Loss: 0.0402, Val Loss: 0.0342
# Epoch [427/1500] Fold 1, Train Loss: 0.0410, Val Loss: 0.0341
# Epoch [428/1500] Fold 1, Train Loss: 0.0419, Val Loss: 0.0350
# Epoch [429/1500] Fold 1, Train Loss: 0.0426, Val Loss: 0.0341
# Epoch [430/1500] Fold 1, Train Loss: 0.0417, Val Loss: 0.0341
# Epoch [431/1500] Fold 1, Train Loss: 0.0410, Val Loss: 0.0344
# Epoch [432/1500] Fold 1, Train Loss: 0.0416, Val Loss: 0.0342
# Epoch [433/1500] Fold 1, Train Loss: 0.0419, Val Loss: 0.0344
# Epoch [434/1500] Fold 1, Train Loss: 0.0413, Val Loss: 0.0344
# Epoch [435/1500] Fold 1, Train Loss: 0.0412, Val Loss: 0.0335
# Epoch [436/1500] Fold 1, Train Loss: 0.0401, Val Loss: 0.0343
# Epoch [437/1500] Fold 1, Train Loss: 0.0412, Val Loss: 0.0344
# Epoch [438/1500] Fold 1, Train Loss: 0.0405, Val Loss: 0.0341
# Epoch [439/1500] Fold 1, Train Loss: 0.0410, Val Loss: 0.0346
# Epoch [440/1500] Fold 1, Train Loss: 0.0397, Val Loss: 0.0341
# Epoch [441/1500] Fold 1, Train Loss: 0.0410, Val Loss: 0.0334
# Epoch [442/1500] Fold 1, Train Loss: 0.0411, Val Loss: 0.0339
# Epoch [443/1500] Fold 1, Train Loss: 0.0396, Val Loss: 0.0343
# Epoch [444/1500] Fold 1, Train Loss: 0.0398, Val Loss: 0.0340
# Epoch [445/1500] Fold 1, Train Loss: 0.0412, Val Loss: 0.0343
# Epoch [446/1500] Fold 1, Train Loss: 0.0406, Val Loss: 0.0342
# Epoch [447/1500] Fold 1, Train Loss: 0.0401, Val Loss: 0.0336
# Epoch [448/1500] Fold 1, Train Loss: 0.0394, Val Loss: 0.0344
# Epoch [449/1500] Fold 1, Train Loss: 0.0408, Val Loss: 0.0340
# Epoch [450/1500] Fold 1, Train Loss: 0.0407, Val Loss: 0.0339
# Epoch [451/1500] Fold 1, Train Loss: 0.0409, Val Loss: 0.0332
# Epoch [452/1500] Fold 1, Train Loss: 0.0413, Val Loss: 0.0343
# Epoch [453/1500] Fold 1, Train Loss: 0.0399, Val Loss: 0.0329
# Epoch [454/1500] Fold 1, Train Loss: 0.0411, Val Loss: 0.0330
# Epoch [455/1500] Fold 1, Train Loss: 0.0415, Val Loss: 0.0334
# Epoch [456/1500] Fold 1, Train Loss: 0.0403, Val Loss: 0.0330
# Epoch [457/1500] Fold 1, Train Loss: 0.0404, Val Loss: 0.0329
# Epoch [458/1500] Fold 1, Train Loss: 0.0398, Val Loss: 0.0338
# Epoch [459/1500] Fold 1, Train Loss: 0.0401, Val Loss: 0.0339
# Epoch [460/1500] Fold 1, Train Loss: 0.0410, Val Loss: 0.0336
# Epoch [461/1500] Fold 1, Train Loss: 0.0399, Val Loss: 0.0335
# Epoch [462/1500] Fold 1, Train Loss: 0.0414, Val Loss: 0.0329
# Epoch [463/1500] Fold 1, Train Loss: 0.0399, Val Loss: 0.0343
# Epoch [464/1500] Fold 1, Train Loss: 0.0394, Val Loss: 0.0341
# Epoch [465/1500] Fold 1, Train Loss: 0.0398, Val Loss: 0.0331
# Epoch [466/1500] Fold 1, Train Loss: 0.0397, Val Loss: 0.0328
# Epoch [467/1500] Fold 1, Train Loss: 0.0401, Val Loss: 0.0333
# Epoch [468/1500] Fold 1, Train Loss: 0.0417, Val Loss: 0.0328
# Epoch [469/1500] Fold 1, Train Loss: 0.0396, Val Loss: 0.0339
# Epoch [470/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0329
# Epoch [471/1500] Fold 1, Train Loss: 0.0399, Val Loss: 0.0328
# Epoch [472/1500] Fold 1, Train Loss: 0.0391, Val Loss: 0.0326
# Epoch [473/1500] Fold 1, Train Loss: 0.0399, Val Loss: 0.0330
# Epoch [474/1500] Fold 1, Train Loss: 0.0401, Val Loss: 0.0331
# Epoch [475/1500] Fold 1, Train Loss: 0.0412, Val Loss: 0.0329
# Epoch [476/1500] Fold 1, Train Loss: 0.0409, Val Loss: 0.0328
# Epoch [477/1500] Fold 1, Train Loss: 0.0395, Val Loss: 0.0327
# Epoch [478/1500] Fold 1, Train Loss: 0.0407, Val Loss: 0.0332
# Epoch [479/1500] Fold 1, Train Loss: 0.0402, Val Loss: 0.0326
# Epoch [480/1500] Fold 1, Train Loss: 0.0401, Val Loss: 0.0332
# Epoch [481/1500] Fold 1, Train Loss: 0.0397, Val Loss: 0.0333
# Epoch [482/1500] Fold 1, Train Loss: 0.0390, Val Loss: 0.0327
# Epoch [483/1500] Fold 1, Train Loss: 0.0411, Val Loss: 0.0327
# Epoch [484/1500] Fold 1, Train Loss: 0.0389, Val Loss: 0.0337
# Epoch [485/1500] Fold 1, Train Loss: 0.0396, Val Loss: 0.0328
# Epoch [486/1500] Fold 1, Train Loss: 0.0404, Val Loss: 0.0333
# Epoch [487/1500] Fold 1, Train Loss: 0.0397, Val Loss: 0.0331
# Epoch [488/1500] Fold 1, Train Loss: 0.0397, Val Loss: 0.0335
# Epoch [489/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0334
# Epoch [490/1500] Fold 1, Train Loss: 0.0396, Val Loss: 0.0333
# Epoch [491/1500] Fold 1, Train Loss: 0.0408, Val Loss: 0.0331
# Epoch [492/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0330
# Epoch [493/1500] Fold 1, Train Loss: 0.0390, Val Loss: 0.0328
# Epoch [494/1500] Fold 1, Train Loss: 0.0399, Val Loss: 0.0323
# Epoch [495/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0330
# Epoch [496/1500] Fold 1, Train Loss: 0.0400, Val Loss: 0.0325
# Epoch [497/1500] Fold 1, Train Loss: 0.0399, Val Loss: 0.0324
# Epoch [498/1500] Fold 1, Train Loss: 0.0398, Val Loss: 0.0325
# Epoch [499/1500] Fold 1, Train Loss: 0.0395, Val Loss: 0.0326
# Epoch [500/1500] Fold 1, Train Loss: 0.0409, Val Loss: 0.0329
# Epoch [501/1500] Fold 1, Train Loss: 0.0395, Val Loss: 0.0324
# Epoch [502/1500] Fold 1, Train Loss: 0.0405, Val Loss: 0.0327
# Epoch [503/1500] Fold 1, Train Loss: 0.0397, Val Loss: 0.0323
# Epoch [504/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0329
# Epoch [505/1500] Fold 1, Train Loss: 0.0394, Val Loss: 0.0323
# Epoch [506/1500] Fold 1, Train Loss: 0.0400, Val Loss: 0.0333
# Epoch [507/1500] Fold 1, Train Loss: 0.0396, Val Loss: 0.0324
# Epoch [508/1500] Fold 1, Train Loss: 0.0392, Val Loss: 0.0328
# Epoch [509/1500] Fold 1, Train Loss: 0.0395, Val Loss: 0.0323
# Epoch [510/1500] Fold 1, Train Loss: 0.0398, Val Loss: 0.0323
# Epoch [511/1500] Fold 1, Train Loss: 0.0389, Val Loss: 0.0319
# Epoch [512/1500] Fold 1, Train Loss: 0.0391, Val Loss: 0.0321
# Epoch [513/1500] Fold 1, Train Loss: 0.0383, Val Loss: 0.0323
# Epoch [514/1500] Fold 1, Train Loss: 0.0391, Val Loss: 0.0319
# Epoch [515/1500] Fold 1, Train Loss: 0.0381, Val Loss: 0.0319
# Epoch [516/1500] Fold 1, Train Loss: 0.0394, Val Loss: 0.0315
# Epoch [517/1500] Fold 1, Train Loss: 0.0390, Val Loss: 0.0325
# Epoch [518/1500] Fold 1, Train Loss: 0.0384, Val Loss: 0.0315
# Epoch [519/1500] Fold 1, Train Loss: 0.0390, Val Loss: 0.0318
# Epoch [520/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0313
# Epoch [521/1500] Fold 1, Train Loss: 0.0405, Val Loss: 0.0323
# Epoch [522/1500] Fold 1, Train Loss: 0.0387, Val Loss: 0.0316
# Epoch [523/1500] Fold 1, Train Loss: 0.0396, Val Loss: 0.0320
# Epoch [524/1500] Fold 1, Train Loss: 0.0383, Val Loss: 0.0317
# Epoch [525/1500] Fold 1, Train Loss: 0.0401, Val Loss: 0.0319
# Epoch [526/1500] Fold 1, Train Loss: 0.0380, Val Loss: 0.0321
# Epoch [527/1500] Fold 1, Train Loss: 0.0397, Val Loss: 0.0321
# Epoch [528/1500] Fold 1, Train Loss: 0.0398, Val Loss: 0.0324
# Epoch [529/1500] Fold 1, Train Loss: 0.0390, Val Loss: 0.0324
# Epoch [530/1500] Fold 1, Train Loss: 0.0389, Val Loss: 0.0338
# Epoch [531/1500] Fold 1, Train Loss: 0.0389, Val Loss: 0.0328
# Epoch [532/1500] Fold 1, Train Loss: 0.0397, Val Loss: 0.0315
# Epoch [533/1500] Fold 1, Train Loss: 0.0388, Val Loss: 0.0320
# Epoch [534/1500] Fold 1, Train Loss: 0.0395, Val Loss: 0.0319
# Epoch [535/1500] Fold 1, Train Loss: 0.0412, Val Loss: 0.0314
# Epoch [536/1500] Fold 1, Train Loss: 0.0392, Val Loss: 0.0317
# Epoch [537/1500] Fold 1, Train Loss: 0.0381, Val Loss: 0.0320
# Epoch [538/1500] Fold 1, Train Loss: 0.0379, Val Loss: 0.0319
# Epoch [539/1500] Fold 1, Train Loss: 0.0377, Val Loss: 0.0318
# Epoch [540/1500] Fold 1, Train Loss: 0.0389, Val Loss: 0.0317
# Epoch [541/1500] Fold 1, Train Loss: 0.0390, Val Loss: 0.0325
# Epoch [542/1500] Fold 1, Train Loss: 0.0386, Val Loss: 0.0324
# Epoch [543/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0322
# Epoch [544/1500] Fold 1, Train Loss: 0.0383, Val Loss: 0.0323
# Epoch [545/1500] Fold 1, Train Loss: 0.0385, Val Loss: 0.0319
# Epoch [546/1500] Fold 1, Train Loss: 0.0389, Val Loss: 0.0311
# Epoch [547/1500] Fold 1, Train Loss: 0.0383, Val Loss: 0.0310
# Epoch [548/1500] Fold 1, Train Loss: 0.0384, Val Loss: 0.0316
# Epoch [549/1500] Fold 1, Train Loss: 0.0384, Val Loss: 0.0315
# Epoch [550/1500] Fold 1, Train Loss: 0.0381, Val Loss: 0.0324
# Epoch [551/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0313
# Epoch [552/1500] Fold 1, Train Loss: 0.0394, Val Loss: 0.0311
# Epoch [553/1500] Fold 1, Train Loss: 0.0374, Val Loss: 0.0312
# Epoch [554/1500] Fold 1, Train Loss: 0.0391, Val Loss: 0.0316
# Epoch [555/1500] Fold 1, Train Loss: 0.0381, Val Loss: 0.0312
# Epoch [556/1500] Fold 1, Train Loss: 0.0380, Val Loss: 0.0309
# Epoch [557/1500] Fold 1, Train Loss: 0.0378, Val Loss: 0.0316
# Epoch [558/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0314
# Epoch [559/1500] Fold 1, Train Loss: 0.0377, Val Loss: 0.0311
# Epoch [560/1500] Fold 1, Train Loss: 0.0381, Val Loss: 0.0305
# Epoch [561/1500] Fold 1, Train Loss: 0.0379, Val Loss: 0.0316
# Epoch [562/1500] Fold 1, Train Loss: 0.0376, Val Loss: 0.0311
# Epoch [563/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0308
# Epoch [564/1500] Fold 1, Train Loss: 0.0377, Val Loss: 0.0304
# Epoch [565/1500] Fold 1, Train Loss: 0.0387, Val Loss: 0.0310
# Epoch [566/1500] Fold 1, Train Loss: 0.0388, Val Loss: 0.0302
# Epoch [567/1500] Fold 1, Train Loss: 0.0388, Val Loss: 0.0305
# Epoch [568/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0307
# Epoch [569/1500] Fold 1, Train Loss: 0.0371, Val Loss: 0.0309
# Epoch [570/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0301
# Epoch [571/1500] Fold 1, Train Loss: 0.0399, Val Loss: 0.0302
# Epoch [572/1500] Fold 1, Train Loss: 0.0390, Val Loss: 0.0308
# Epoch [573/1500] Fold 1, Train Loss: 0.0390, Val Loss: 0.0307
# Epoch [574/1500] Fold 1, Train Loss: 0.0377, Val Loss: 0.0319
# Epoch [575/1500] Fold 1, Train Loss: 0.0380, Val Loss: 0.0306
# Epoch [576/1500] Fold 1, Train Loss: 0.0384, Val Loss: 0.0309
# Epoch [577/1500] Fold 1, Train Loss: 0.0387, Val Loss: 0.0304
# Epoch [578/1500] Fold 1, Train Loss: 0.0369, Val Loss: 0.0307
# Epoch [579/1500] Fold 1, Train Loss: 0.0377, Val Loss: 0.0300
# Epoch [580/1500] Fold 1, Train Loss: 0.0392, Val Loss: 0.0302
# Epoch [581/1500] Fold 1, Train Loss: 0.0381, Val Loss: 0.0313
# Epoch [582/1500] Fold 1, Train Loss: 0.0385, Val Loss: 0.0300
# Epoch [583/1500] Fold 1, Train Loss: 0.0390, Val Loss: 0.0297
# Epoch [584/1500] Fold 1, Train Loss: 0.0386, Val Loss: 0.0306
# Epoch [585/1500] Fold 1, Train Loss: 0.0372, Val Loss: 0.0303
# Epoch [586/1500] Fold 1, Train Loss: 0.0381, Val Loss: 0.0301
# Epoch [587/1500] Fold 1, Train Loss: 0.0385, Val Loss: 0.0298
# Epoch [588/1500] Fold 1, Train Loss: 0.0373, Val Loss: 0.0298
# Epoch [589/1500] Fold 1, Train Loss: 0.0384, Val Loss: 0.0304
# Epoch [590/1500] Fold 1, Train Loss: 0.0377, Val Loss: 0.0303
# Epoch [591/1500] Fold 1, Train Loss: 0.0385, Val Loss: 0.0299
# Epoch [592/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0301
# Epoch [593/1500] Fold 1, Train Loss: 0.0384, Val Loss: 0.0307
# Epoch [594/1500] Fold 1, Train Loss: 0.0381, Val Loss: 0.0303
# Epoch [595/1500] Fold 1, Train Loss: 0.0383, Val Loss: 0.0301
# Epoch [596/1500] Fold 1, Train Loss: 0.0374, Val Loss: 0.0302
# Epoch [597/1500] Fold 1, Train Loss: 0.0395, Val Loss: 0.0298
# Epoch [598/1500] Fold 1, Train Loss: 0.0387, Val Loss: 0.0304
# Epoch [599/1500] Fold 1, Train Loss: 0.0381, Val Loss: 0.0304
# Epoch [600/1500] Fold 1, Train Loss: 0.0378, Val Loss: 0.0300
# Epoch [601/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0304
# Epoch [602/1500] Fold 1, Train Loss: 0.0380, Val Loss: 0.0311
# Epoch [603/1500] Fold 1, Train Loss: 0.0379, Val Loss: 0.0295
# Epoch [604/1500] Fold 1, Train Loss: 0.0391, Val Loss: 0.0296
# Epoch [605/1500] Fold 1, Train Loss: 0.0378, Val Loss: 0.0307
# Epoch [606/1500] Fold 1, Train Loss: 0.0377, Val Loss: 0.0297
# Epoch [607/1500] Fold 1, Train Loss: 0.0369, Val Loss: 0.0295
# Epoch [608/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0301
# Epoch [609/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0294
# Epoch [610/1500] Fold 1, Train Loss: 0.0372, Val Loss: 0.0300
# Epoch [611/1500] Fold 1, Train Loss: 0.0392, Val Loss: 0.0296
# Epoch [612/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0305
# Epoch [613/1500] Fold 1, Train Loss: 0.0375, Val Loss: 0.0307
# Epoch [614/1500] Fold 1, Train Loss: 0.0384, Val Loss: 0.0308
# Epoch [615/1500] Fold 1, Train Loss: 0.0374, Val Loss: 0.0296
# Epoch [616/1500] Fold 1, Train Loss: 0.0375, Val Loss: 0.0305
# Epoch [617/1500] Fold 1, Train Loss: 0.0390, Val Loss: 0.0300
# Epoch [618/1500] Fold 1, Train Loss: 0.0379, Val Loss: 0.0295
# Epoch [619/1500] Fold 1, Train Loss: 0.0362, Val Loss: 0.0296
# Epoch [620/1500] Fold 1, Train Loss: 0.0376, Val Loss: 0.0296
# Epoch [621/1500] Fold 1, Train Loss: 0.0384, Val Loss: 0.0294
# Epoch [622/1500] Fold 1, Train Loss: 0.0368, Val Loss: 0.0294
# Epoch [623/1500] Fold 1, Train Loss: 0.0374, Val Loss: 0.0292
# Epoch [624/1500] Fold 1, Train Loss: 0.0373, Val Loss: 0.0296
# Epoch [625/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0288
# Epoch [626/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0299
# Epoch [627/1500] Fold 1, Train Loss: 0.0367, Val Loss: 0.0298
# Epoch [628/1500] Fold 1, Train Loss: 0.0374, Val Loss: 0.0292
# Epoch [629/1500] Fold 1, Train Loss: 0.0373, Val Loss: 0.0289
# Epoch [630/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0285
# Epoch [631/1500] Fold 1, Train Loss: 0.0374, Val Loss: 0.0295
# Epoch [632/1500] Fold 1, Train Loss: 0.0371, Val Loss: 0.0290
# Epoch [633/1500] Fold 1, Train Loss: 0.0387, Val Loss: 0.0298
# Epoch [634/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0291
# Epoch [635/1500] Fold 1, Train Loss: 0.0377, Val Loss: 0.0290
# Epoch [636/1500] Fold 1, Train Loss: 0.0369, Val Loss: 0.0299
# Epoch [637/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0291
# Epoch [638/1500] Fold 1, Train Loss: 0.0369, Val Loss: 0.0299
# Epoch [639/1500] Fold 1, Train Loss: 0.0377, Val Loss: 0.0299
# Epoch [640/1500] Fold 1, Train Loss: 0.0371, Val Loss: 0.0296
# Epoch [641/1500] Fold 1, Train Loss: 0.0390, Val Loss: 0.0293
# Epoch [642/1500] Fold 1, Train Loss: 0.0378, Val Loss: 0.0296
# Epoch [643/1500] Fold 1, Train Loss: 0.0379, Val Loss: 0.0297
# Epoch [644/1500] Fold 1, Train Loss: 0.0369, Val Loss: 0.0297
# Epoch [645/1500] Fold 1, Train Loss: 0.0379, Val Loss: 0.0291
# Epoch [646/1500] Fold 1, Train Loss: 0.0368, Val Loss: 0.0294
# Epoch [647/1500] Fold 1, Train Loss: 0.0363, Val Loss: 0.0293
# Epoch [648/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0283
# Epoch [649/1500] Fold 1, Train Loss: 0.0361, Val Loss: 0.0285
# Epoch [650/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0283
# Epoch [651/1500] Fold 1, Train Loss: 0.0375, Val Loss: 0.0291
# Epoch [652/1500] Fold 1, Train Loss: 0.0380, Val Loss: 0.0285
# Epoch [653/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0292
# Epoch [654/1500] Fold 1, Train Loss: 0.0358, Val Loss: 0.0296
# Epoch [655/1500] Fold 1, Train Loss: 0.0378, Val Loss: 0.0285
# Epoch [656/1500] Fold 1, Train Loss: 0.0378, Val Loss: 0.0279
# Epoch [657/1500] Fold 1, Train Loss: 0.0376, Val Loss: 0.0289
# Epoch [658/1500] Fold 1, Train Loss: 0.0366, Val Loss: 0.0293
# Epoch [659/1500] Fold 1, Train Loss: 0.0370, Val Loss: 0.0283
# Epoch [660/1500] Fold 1, Train Loss: 0.0373, Val Loss: 0.0294
# Epoch [661/1500] Fold 1, Train Loss: 0.0387, Val Loss: 0.0292
# Epoch [662/1500] Fold 1, Train Loss: 0.0376, Val Loss: 0.0287
# Epoch [663/1500] Fold 1, Train Loss: 0.0368, Val Loss: 0.0283
# Epoch [664/1500] Fold 1, Train Loss: 0.0370, Val Loss: 0.0281
# Epoch [665/1500] Fold 1, Train Loss: 0.0379, Val Loss: 0.0278
# Epoch [666/1500] Fold 1, Train Loss: 0.0358, Val Loss: 0.0290
# Epoch [667/1500] Fold 1, Train Loss: 0.0368, Val Loss: 0.0285
# Epoch [668/1500] Fold 1, Train Loss: 0.0372, Val Loss: 0.0279
# Epoch [669/1500] Fold 1, Train Loss: 0.0369, Val Loss: 0.0283
# Epoch [670/1500] Fold 1, Train Loss: 0.0384, Val Loss: 0.0281
# Epoch [671/1500] Fold 1, Train Loss: 0.0375, Val Loss: 0.0286
# Epoch [672/1500] Fold 1, Train Loss: 0.0369, Val Loss: 0.0283
# Epoch [673/1500] Fold 1, Train Loss: 0.0379, Val Loss: 0.0289
# Epoch [674/1500] Fold 1, Train Loss: 0.0388, Val Loss: 0.0290
# Epoch [675/1500] Fold 1, Train Loss: 0.0387, Val Loss: 0.0284
# Epoch [676/1500] Fold 1, Train Loss: 0.0386, Val Loss: 0.0291
# Epoch [677/1500] Fold 1, Train Loss: 0.0364, Val Loss: 0.0277
# Epoch [678/1500] Fold 1, Train Loss: 0.0373, Val Loss: 0.0288
# Epoch [679/1500] Fold 1, Train Loss: 0.0368, Val Loss: 0.0283
# Epoch [680/1500] Fold 1, Train Loss: 0.0376, Val Loss: 0.0275
# Epoch [681/1500] Fold 1, Train Loss: 0.0380, Val Loss: 0.0285
# Epoch [682/1500] Fold 1, Train Loss: 0.0377, Val Loss: 0.0290
# Epoch [683/1500] Fold 1, Train Loss: 0.0367, Val Loss: 0.0287
# Epoch [684/1500] Fold 1, Train Loss: 0.0386, Val Loss: 0.0274
# Epoch [685/1500] Fold 1, Train Loss: 0.0367, Val Loss: 0.0283
# Epoch [686/1500] Fold 1, Train Loss: 0.0368, Val Loss: 0.0282
# Epoch [687/1500] Fold 1, Train Loss: 0.0381, Val Loss: 0.0276
# Epoch [688/1500] Fold 1, Train Loss: 0.0366, Val Loss: 0.0274
# Epoch [689/1500] Fold 1, Train Loss: 0.0348, Val Loss: 0.0288
# Epoch [690/1500] Fold 1, Train Loss: 0.0368, Val Loss: 0.0279
# Epoch [691/1500] Fold 1, Train Loss: 0.0364, Val Loss: 0.0283
# Epoch [692/1500] Fold 1, Train Loss: 0.0360, Val Loss: 0.0277
# Epoch [693/1500] Fold 1, Train Loss: 0.0375, Val Loss: 0.0281
# Epoch [694/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0281
# Epoch [695/1500] Fold 1, Train Loss: 0.0366, Val Loss: 0.0280
# Epoch [696/1500] Fold 1, Train Loss: 0.0358, Val Loss: 0.0286
# Epoch [697/1500] Fold 1, Train Loss: 0.0359, Val Loss: 0.0272
# Epoch [698/1500] Fold 1, Train Loss: 0.0360, Val Loss: 0.0276
# Epoch [699/1500] Fold 1, Train Loss: 0.0369, Val Loss: 0.0280
# Epoch [700/1500] Fold 1, Train Loss: 0.0361, Val Loss: 0.0280
# Epoch [701/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0279
# Epoch [702/1500] Fold 1, Train Loss: 0.0350, Val Loss: 0.0278
# Epoch [703/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0273
# Epoch [704/1500] Fold 1, Train Loss: 0.0377, Val Loss: 0.0274
# Epoch [705/1500] Fold 1, Train Loss: 0.0360, Val Loss: 0.0270
# Epoch [706/1500] Fold 1, Train Loss: 0.0368, Val Loss: 0.0279
# Epoch [707/1500] Fold 1, Train Loss: 0.0371, Val Loss: 0.0279
# Epoch [708/1500] Fold 1, Train Loss: 0.0376, Val Loss: 0.0277
# Epoch [709/1500] Fold 1, Train Loss: 0.0350, Val Loss: 0.0284
# Epoch [710/1500] Fold 1, Train Loss: 0.0378, Val Loss: 0.0276
# Epoch [711/1500] Fold 1, Train Loss: 0.0356, Val Loss: 0.0274
# Epoch [712/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0277
# Epoch [713/1500] Fold 1, Train Loss: 0.0367, Val Loss: 0.0279
# Epoch [714/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0282
# Epoch [715/1500] Fold 1, Train Loss: 0.0378, Val Loss: 0.0275
# Epoch [716/1500] Fold 1, Train Loss: 0.0363, Val Loss: 0.0275
# Epoch [717/1500] Fold 1, Train Loss: 0.0396, Val Loss: 0.0271
# Epoch [718/1500] Fold 1, Train Loss: 0.0359, Val Loss: 0.0280
# Epoch [719/1500] Fold 1, Train Loss: 0.0357, Val Loss: 0.0280
# Epoch [720/1500] Fold 1, Train Loss: 0.0368, Val Loss: 0.0283
# Epoch [721/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0277
# Epoch [722/1500] Fold 1, Train Loss: 0.0368, Val Loss: 0.0280
# Epoch [723/1500] Fold 1, Train Loss: 0.0361, Val Loss: 0.0274
# Epoch [724/1500] Fold 1, Train Loss: 0.0358, Val Loss: 0.0285
# Epoch [725/1500] Fold 1, Train Loss: 0.0358, Val Loss: 0.0270
# Epoch [726/1500] Fold 1, Train Loss: 0.0362, Val Loss: 0.0263
# Epoch [727/1500] Fold 1, Train Loss: 0.0367, Val Loss: 0.0283
# Epoch [728/1500] Fold 1, Train Loss: 0.0385, Val Loss: 0.0292
# Epoch [729/1500] Fold 1, Train Loss: 0.0370, Val Loss: 0.0280
# Epoch [730/1500] Fold 1, Train Loss: 0.0366, Val Loss: 0.0288
# Epoch [731/1500] Fold 1, Train Loss: 0.0358, Val Loss: 0.0275
# Epoch [732/1500] Fold 1, Train Loss: 0.0367, Val Loss: 0.0272
# Epoch [733/1500] Fold 1, Train Loss: 0.0367, Val Loss: 0.0277
# Epoch [734/1500] Fold 1, Train Loss: 0.0355, Val Loss: 0.0272
# Epoch [735/1500] Fold 1, Train Loss: 0.0356, Val Loss: 0.0273
# Epoch [736/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0270
# Epoch [737/1500] Fold 1, Train Loss: 0.0357, Val Loss: 0.0271
# Epoch [738/1500] Fold 1, Train Loss: 0.0363, Val Loss: 0.0280
# Epoch [739/1500] Fold 1, Train Loss: 0.0359, Val Loss: 0.0269
# Epoch [740/1500] Fold 1, Train Loss: 0.0367, Val Loss: 0.0277
# Epoch [741/1500] Fold 1, Train Loss: 0.0358, Val Loss: 0.0267
# Epoch [742/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0271
# Epoch [743/1500] Fold 1, Train Loss: 0.0364, Val Loss: 0.0269
# Epoch [744/1500] Fold 1, Train Loss: 0.0352, Val Loss: 0.0271
# Epoch [745/1500] Fold 1, Train Loss: 0.0361, Val Loss: 0.0273
# Epoch [746/1500] Fold 1, Train Loss: 0.0356, Val Loss: 0.0285
# Epoch [747/1500] Fold 1, Train Loss: 0.0351, Val Loss: 0.0273
# Epoch [748/1500] Fold 1, Train Loss: 0.0384, Val Loss: 0.0269
# Epoch [749/1500] Fold 1, Train Loss: 0.0370, Val Loss: 0.0273
# Epoch [750/1500] Fold 1, Train Loss: 0.0371, Val Loss: 0.0270
# Epoch [751/1500] Fold 1, Train Loss: 0.0357, Val Loss: 0.0271
# Epoch [752/1500] Fold 1, Train Loss: 0.0353, Val Loss: 0.0279
# Epoch [753/1500] Fold 1, Train Loss: 0.0372, Val Loss: 0.0269
# Epoch [754/1500] Fold 1, Train Loss: 0.0385, Val Loss: 0.0268
# Epoch [755/1500] Fold 1, Train Loss: 0.0371, Val Loss: 0.0273
# Epoch [756/1500] Fold 1, Train Loss: 0.0363, Val Loss: 0.0273
# Epoch [757/1500] Fold 1, Train Loss: 0.0372, Val Loss: 0.0262
# Epoch [758/1500] Fold 1, Train Loss: 0.0366, Val Loss: 0.0267
# Epoch [759/1500] Fold 1, Train Loss: 0.0369, Val Loss: 0.0273
# Epoch [760/1500] Fold 1, Train Loss: 0.0361, Val Loss: 0.0265
# Epoch [761/1500] Fold 1, Train Loss: 0.0362, Val Loss: 0.0265
# Epoch [762/1500] Fold 1, Train Loss: 0.0363, Val Loss: 0.0270
# Epoch [763/1500] Fold 1, Train Loss: 0.0359, Val Loss: 0.0273
# Epoch [764/1500] Fold 1, Train Loss: 0.0358, Val Loss: 0.0262
# Epoch [765/1500] Fold 1, Train Loss: 0.0362, Val Loss: 0.0267
# Epoch [766/1500] Fold 1, Train Loss: 0.0371, Val Loss: 0.0264
# Epoch [767/1500] Fold 1, Train Loss: 0.0370, Val Loss: 0.0267
# Epoch [768/1500] Fold 1, Train Loss: 0.0359, Val Loss: 0.0265
# Epoch [769/1500] Fold 1, Train Loss: 0.0356, Val Loss: 0.0271
# Epoch [770/1500] Fold 1, Train Loss: 0.0359, Val Loss: 0.0265
# Epoch [771/1500] Fold 1, Train Loss: 0.0354, Val Loss: 0.0270
# Epoch [772/1500] Fold 1, Train Loss: 0.0349, Val Loss: 0.0267
# Epoch [773/1500] Fold 1, Train Loss: 0.0361, Val Loss: 0.0260
# Epoch [774/1500] Fold 1, Train Loss: 0.0359, Val Loss: 0.0265
# Epoch [775/1500] Fold 1, Train Loss: 0.0351, Val Loss: 0.0255
# ...
# Epoch [1251/1500] Fold 10, Train Loss: 0.0345, Val Loss: 0.0260
# Epoch [1252/1500] Fold 10, Train Loss: 0.0332, Val Loss: 0.0261
# Epoch [1253/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0258
# Epoch [1254/1500] Fold 10, Train Loss: 0.0323, Val Loss: 0.0260
# Epoch [1255/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0256
# Epoch [1256/1500] Fold 10, Train Loss: 0.0339, Val Loss: 0.0258
# Epoch [1257/1500] Fold 10, Train Loss: 0.0343, Val Loss: 0.0259
# Epoch [1258/1500] Fold 10, Train Loss: 0.0331, Val Loss: 0.0260
# Epoch [1259/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0258
# Epoch [1260/1500] Fold 10, Train Loss: 0.0317, Val Loss: 0.0260
# Epoch [1261/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0258
# Epoch [1262/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0258
# Epoch [1263/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0258
# Epoch [1264/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0255
# Epoch [1265/1500] Fold 10, Train Loss: 0.0339, Val Loss: 0.0256
# Epoch [1266/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0255
# Epoch [1267/1500] Fold 10, Train Loss: 0.0346, Val Loss: 0.0260
# Epoch [1268/1500] Fold 10, Train Loss: 0.0316, Val Loss: 0.0260
# Epoch [1269/1500] Fold 10, Train Loss: 0.0324, Val Loss: 0.0259
# Epoch [1270/1500] Fold 10, Train Loss: 0.0344, Val Loss: 0.0258
# Epoch [1271/1500] Fold 10, Train Loss: 0.0334, Val Loss: 0.0259
# Epoch [1272/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0257
# Epoch [1273/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0259
# Epoch [1274/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0254
# Epoch [1275/1500] Fold 10, Train Loss: 0.0335, Val Loss: 0.0254
# Epoch [1276/1500] Fold 10, Train Loss: 0.0339, Val Loss: 0.0257
# Epoch [1277/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0254
# Epoch [1278/1500] Fold 10, Train Loss: 0.0319, Val Loss: 0.0258
# Epoch [1279/1500] Fold 10, Train Loss: 0.0323, Val Loss: 0.0256
# Epoch [1280/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0259
# Epoch [1281/1500] Fold 10, Train Loss: 0.0336, Val Loss: 0.0256
# Epoch [1282/1500] Fold 10, Train Loss: 0.0340, Val Loss: 0.0256
# Epoch [1283/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0258
# Epoch [1284/1500] Fold 10, Train Loss: 0.0331, Val Loss: 0.0257
# Epoch [1285/1500] Fold 10, Train Loss: 0.0332, Val Loss: 0.0262
# Epoch [1286/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0255
# Epoch [1287/1500] Fold 10, Train Loss: 0.0328, Val Loss: 0.0256
# Epoch [1288/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0261
# Epoch [1289/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0260
# Epoch [1290/1500] Fold 10, Train Loss: 0.0312, Val Loss: 0.0259
# Epoch [1291/1500] Fold 10, Train Loss: 0.0322, Val Loss: 0.0257
# Epoch [1292/1500] Fold 10, Train Loss: 0.0343, Val Loss: 0.0255
# Epoch [1293/1500] Fold 10, Train Loss: 0.0322, Val Loss: 0.0256
# Epoch [1294/1500] Fold 10, Train Loss: 0.0322, Val Loss: 0.0257
# Epoch [1295/1500] Fold 10, Train Loss: 0.0331, Val Loss: 0.0255
# Epoch [1296/1500] Fold 10, Train Loss: 0.0337, Val Loss: 0.0253
# Epoch [1297/1500] Fold 10, Train Loss: 0.0320, Val Loss: 0.0257
# Epoch [1298/1500] Fold 10, Train Loss: 0.0331, Val Loss: 0.0258
# Epoch [1299/1500] Fold 10, Train Loss: 0.0338, Val Loss: 0.0261
# Epoch [1300/1500] Fold 10, Train Loss: 0.0322, Val Loss: 0.0259
# Epoch [1301/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0262
# Epoch [1302/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0257
# Epoch [1303/1500] Fold 10, Train Loss: 0.0335, Val Loss: 0.0251
# Epoch [1304/1500] Fold 10, Train Loss: 0.0334, Val Loss: 0.0258
# Epoch [1305/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0258
# Epoch [1306/1500] Fold 10, Train Loss: 0.0324, Val Loss: 0.0260
# Epoch [1307/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0258
# Epoch [1308/1500] Fold 10, Train Loss: 0.0324, Val Loss: 0.0257
# Epoch [1309/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0259
# Epoch [1310/1500] Fold 10, Train Loss: 0.0318, Val Loss: 0.0261
# Epoch [1311/1500] Fold 10, Train Loss: 0.0318, Val Loss: 0.0260
# Epoch [1312/1500] Fold 10, Train Loss: 0.0334, Val Loss: 0.0262
# Epoch [1313/1500] Fold 10, Train Loss: 0.0324, Val Loss: 0.0259
# Epoch [1314/1500] Fold 10, Train Loss: 0.0331, Val Loss: 0.0258
# Epoch [1315/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0258
# Epoch [1316/1500] Fold 10, Train Loss: 0.0322, Val Loss: 0.0259
# Epoch [1317/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0259
# Epoch [1318/1500] Fold 10, Train Loss: 0.0334, Val Loss: 0.0258
# Epoch [1319/1500] Fold 10, Train Loss: 0.0311, Val Loss: 0.0254
# Epoch [1320/1500] Fold 10, Train Loss: 0.0338, Val Loss: 0.0256
# Epoch [1321/1500] Fold 10, Train Loss: 0.0324, Val Loss: 0.0257
# Epoch [1322/1500] Fold 10, Train Loss: 0.0341, Val Loss: 0.0257
# Epoch [1323/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0260
# Epoch [1324/1500] Fold 10, Train Loss: 0.0322, Val Loss: 0.0253
# Epoch [1325/1500] Fold 10, Train Loss: 0.0332, Val Loss: 0.0257
# Epoch [1326/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0261
# Epoch [1327/1500] Fold 10, Train Loss: 0.0315, Val Loss: 0.0259
# Epoch [1328/1500] Fold 10, Train Loss: 0.0340, Val Loss: 0.0258
# Epoch [1329/1500] Fold 10, Train Loss: 0.0328, Val Loss: 0.0254
# Epoch [1330/1500] Fold 10, Train Loss: 0.0336, Val Loss: 0.0257
# Epoch [1331/1500] Fold 10, Train Loss: 0.0328, Val Loss: 0.0255
# Epoch [1332/1500] Fold 10, Train Loss: 0.0328, Val Loss: 0.0256
# Epoch [1333/1500] Fold 10, Train Loss: 0.0339, Val Loss: 0.0254
# Epoch [1334/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0255
# Epoch [1335/1500] Fold 10, Train Loss: 0.0324, Val Loss: 0.0260
# Epoch [1336/1500] Fold 10, Train Loss: 0.0315, Val Loss: 0.0256
# Epoch [1337/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0259
# Epoch [1338/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0256
# Epoch [1339/1500] Fold 10, Train Loss: 0.0333, Val Loss: 0.0255
# Epoch [1340/1500] Fold 10, Train Loss: 0.0322, Val Loss: 0.0253
# Epoch [1341/1500] Fold 10, Train Loss: 0.0336, Val Loss: 0.0254
# Epoch [1342/1500] Fold 10, Train Loss: 0.0331, Val Loss: 0.0256
# Epoch [1343/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0259
# Epoch [1344/1500] Fold 10, Train Loss: 0.0332, Val Loss: 0.0258
# Epoch [1345/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0257
# Epoch [1346/1500] Fold 10, Train Loss: 0.0312, Val Loss: 0.0259
# Epoch [1347/1500] Fold 10, Train Loss: 0.0334, Val Loss: 0.0255
# Epoch [1348/1500] Fold 10, Train Loss: 0.0322, Val Loss: 0.0258
# Epoch [1349/1500] Fold 10, Train Loss: 0.0334, Val Loss: 0.0259
# Epoch [1350/1500] Fold 10, Train Loss: 0.0314, Val Loss: 0.0259
# Epoch [1351/1500] Fold 10, Train Loss: 0.0328, Val Loss: 0.0257
# Epoch [1352/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0257
# Epoch [1353/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0255
# Epoch [1354/1500] Fold 10, Train Loss: 0.0334, Val Loss: 0.0255
# Epoch [1355/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0256
# Epoch [1356/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0255
# Epoch [1357/1500] Fold 10, Train Loss: 0.0346, Val Loss: 0.0260
# Epoch [1358/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0259
# Epoch [1359/1500] Fold 10, Train Loss: 0.0331, Val Loss: 0.0256
# Epoch [1360/1500] Fold 10, Train Loss: 0.0324, Val Loss: 0.0260
# Epoch [1361/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0259
# Epoch [1362/1500] Fold 10, Train Loss: 0.0344, Val Loss: 0.0258
# Epoch [1363/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0261
# Epoch [1364/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0258
# Epoch [1365/1500] Fold 10, Train Loss: 0.0313, Val Loss: 0.0259
# Epoch [1366/1500] Fold 10, Train Loss: 0.0311, Val Loss: 0.0258
# Epoch [1367/1500] Fold 10, Train Loss: 0.0323, Val Loss: 0.0258
# Epoch [1368/1500] Fold 10, Train Loss: 0.0337, Val Loss: 0.0261
# Epoch [1369/1500] Fold 10, Train Loss: 0.0324, Val Loss: 0.0259
# Epoch [1370/1500] Fold 10, Train Loss: 0.0324, Val Loss: 0.0256
# Epoch [1371/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0259
# Epoch [1372/1500] Fold 10, Train Loss: 0.0320, Val Loss: 0.0254
# Epoch [1373/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0254
# Epoch [1374/1500] Fold 10, Train Loss: 0.0315, Val Loss: 0.0255
# Epoch [1375/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0252
# Epoch [1376/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0254
# Epoch [1377/1500] Fold 10, Train Loss: 0.0328, Val Loss: 0.0260
# Epoch [1378/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0257
# Epoch [1379/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0257
# Epoch [1380/1500] Fold 10, Train Loss: 0.0332, Val Loss: 0.0255
# Epoch [1381/1500] Fold 10, Train Loss: 0.0320, Val Loss: 0.0251
# Epoch [1382/1500] Fold 10, Train Loss: 0.0316, Val Loss: 0.0259
# Epoch [1383/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0255
# Epoch [1384/1500] Fold 10, Train Loss: 0.0335, Val Loss: 0.0255
# Epoch [1385/1500] Fold 10, Train Loss: 0.0335, Val Loss: 0.0258
# Epoch [1386/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0252
# Epoch [1387/1500] Fold 10, Train Loss: 0.0334, Val Loss: 0.0252
# Epoch [1388/1500] Fold 10, Train Loss: 0.0342, Val Loss: 0.0253
# Epoch [1389/1500] Fold 10, Train Loss: 0.0318, Val Loss: 0.0255
# Epoch [1390/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0254
# Epoch [1391/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0253
# Epoch [1392/1500] Fold 10, Train Loss: 0.0318, Val Loss: 0.0257
# Epoch [1393/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0254
# Epoch [1394/1500] Fold 10, Train Loss: 0.0318, Val Loss: 0.0255
# Epoch [1395/1500] Fold 10, Train Loss: 0.0324, Val Loss: 0.0251
# Epoch [1396/1500] Fold 10, Train Loss: 0.0328, Val Loss: 0.0256
# Epoch [1397/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0253
# Epoch [1398/1500] Fold 10, Train Loss: 0.0336, Val Loss: 0.0252
# Epoch [1399/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0254
# Epoch [1400/1500] Fold 10, Train Loss: 0.0319, Val Loss: 0.0252
# Epoch [1401/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0249
# Epoch [1402/1500] Fold 10, Train Loss: 0.0323, Val Loss: 0.0254
# Epoch [1403/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0258
# Epoch [1404/1500] Fold 10, Train Loss: 0.0322, Val Loss: 0.0256
# Epoch [1405/1500] Fold 10, Train Loss: 0.0313, Val Loss: 0.0252
# Epoch [1406/1500] Fold 10, Train Loss: 0.0339, Val Loss: 0.0251
# Epoch [1407/1500] Fold 10, Train Loss: 0.0321, Val Loss: 0.0255
# Epoch [1408/1500] Fold 10, Train Loss: 0.0334, Val Loss: 0.0254
# Epoch [1409/1500] Fold 10, Train Loss: 0.0319, Val Loss: 0.0255
# Epoch [1410/1500] Fold 10, Train Loss: 0.0323, Val Loss: 0.0256
# Epoch [1411/1500] Fold 10, Train Loss: 0.0341, Val Loss: 0.0256
# Epoch [1412/1500] Fold 10, Train Loss: 0.0318, Val Loss: 0.0254
# Epoch [1413/1500] Fold 10, Train Loss: 0.0320, Val Loss: 0.0255
# Epoch [1414/1500] Fold 10, Train Loss: 0.0315, Val Loss: 0.0255
# Epoch [1415/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0253
# Epoch [1416/1500] Fold 10, Train Loss: 0.0317, Val Loss: 0.0252
# Epoch [1417/1500] Fold 10, Train Loss: 0.0332, Val Loss: 0.0253
# Epoch [1418/1500] Fold 10, Train Loss: 0.0324, Val Loss: 0.0254
# Epoch [1419/1500] Fold 10, Train Loss: 0.0334, Val Loss: 0.0256
# Epoch [1420/1500] Fold 10, Train Loss: 0.0319, Val Loss: 0.0252
# Epoch [1421/1500] Fold 10, Train Loss: 0.0323, Val Loss: 0.0253
# Epoch [1422/1500] Fold 10, Train Loss: 0.0334, Val Loss: 0.0250
# Epoch [1423/1500] Fold 10, Train Loss: 0.0316, Val Loss: 0.0251
# Epoch [1424/1500] Fold 10, Train Loss: 0.0335, Val Loss: 0.0255
# Epoch [1425/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0257
# Epoch [1426/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0256
# Epoch [1427/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0254
# Epoch [1428/1500] Fold 10, Train Loss: 0.0316, Val Loss: 0.0255
# Epoch [1429/1500] Fold 10, Train Loss: 0.0315, Val Loss: 0.0256
# Epoch [1430/1500] Fold 10, Train Loss: 0.0324, Val Loss: 0.0253
# Epoch [1431/1500] Fold 10, Train Loss: 0.0311, Val Loss: 0.0255
# Epoch [1432/1500] Fold 10, Train Loss: 0.0316, Val Loss: 0.0255
# Epoch [1433/1500] Fold 10, Train Loss: 0.0321, Val Loss: 0.0252
# Epoch [1434/1500] Fold 10, Train Loss: 0.0317, Val Loss: 0.0252
# Epoch [1435/1500] Fold 10, Train Loss: 0.0319, Val Loss: 0.0252
# Epoch [1436/1500] Fold 10, Train Loss: 0.0318, Val Loss: 0.0249
# Epoch [1437/1500] Fold 10, Train Loss: 0.0320, Val Loss: 0.0255
# Epoch [1438/1500] Fold 10, Train Loss: 0.0318, Val Loss: 0.0249
# Epoch [1439/1500] Fold 10, Train Loss: 0.0322, Val Loss: 0.0248
# Epoch [1440/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0250
# Epoch [1441/1500] Fold 10, Train Loss: 0.0313, Val Loss: 0.0251
# Epoch [1442/1500] Fold 10, Train Loss: 0.0316, Val Loss: 0.0252
# Epoch [1443/1500] Fold 10, Train Loss: 0.0333, Val Loss: 0.0253
# Epoch [1444/1500] Fold 10, Train Loss: 0.0333, Val Loss: 0.0252
# Epoch [1445/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0252
# Epoch [1446/1500] Fold 10, Train Loss: 0.0323, Val Loss: 0.0251
# Epoch [1447/1500] Fold 10, Train Loss: 0.0315, Val Loss: 0.0254
# Epoch [1448/1500] Fold 10, Train Loss: 0.0323, Val Loss: 0.0252
# Epoch [1449/1500] Fold 10, Train Loss: 0.0332, Val Loss: 0.0252
# Epoch [1450/1500] Fold 10, Train Loss: 0.0316, Val Loss: 0.0252
# Epoch [1451/1500] Fold 10, Train Loss: 0.0315, Val Loss: 0.0248
# Epoch [1452/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0257
# Epoch [1453/1500] Fold 10, Train Loss: 0.0321, Val Loss: 0.0253
# Epoch [1454/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0250
# Epoch [1455/1500] Fold 10, Train Loss: 0.0336, Val Loss: 0.0248
# Epoch [1456/1500] Fold 10, Train Loss: 0.0328, Val Loss: 0.0252
# Epoch [1457/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0250
# Epoch [1458/1500] Fold 10, Train Loss: 0.0344, Val Loss: 0.0249
# Epoch [1459/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0253
# Epoch [1460/1500] Fold 10, Train Loss: 0.0322, Val Loss: 0.0253
# Epoch [1461/1500] Fold 10, Train Loss: 0.0323, Val Loss: 0.0252
# Epoch [1462/1500] Fold 10, Train Loss: 0.0337, Val Loss: 0.0248
# Epoch [1463/1500] Fold 10, Train Loss: 0.0312, Val Loss: 0.0252
# Epoch [1464/1500] Fold 10, Train Loss: 0.0330, Val Loss: 0.0250
# Epoch [1465/1500] Fold 10, Train Loss: 0.0338, Val Loss: 0.0250
# Epoch [1466/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0249
# Epoch [1467/1500] Fold 10, Train Loss: 0.0310, Val Loss: 0.0255
# Epoch [1468/1500] Fold 10, Train Loss: 0.0323, Val Loss: 0.0254
# Epoch [1469/1500] Fold 10, Train Loss: 0.0320, Val Loss: 0.0256
# Epoch [1470/1500] Fold 10, Train Loss: 0.0313, Val Loss: 0.0252
# Epoch [1471/1500] Fold 10, Train Loss: 0.0314, Val Loss: 0.0249
# Epoch [1472/1500] Fold 10, Train Loss: 0.0337, Val Loss: 0.0250
# Epoch [1473/1500] Fold 10, Train Loss: 0.0321, Val Loss: 0.0251
# Epoch [1474/1500] Fold 10, Train Loss: 0.0306, Val Loss: 0.0252
# Epoch [1475/1500] Fold 10, Train Loss: 0.0317, Val Loss: 0.0251
# Epoch [1476/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0247
# Epoch [1477/1500] Fold 10, Train Loss: 0.0315, Val Loss: 0.0250
# Epoch [1478/1500] Fold 10, Train Loss: 0.0335, Val Loss: 0.0253
# Epoch [1479/1500] Fold 10, Train Loss: 0.0310, Val Loss: 0.0251
# Epoch [1480/1500] Fold 10, Train Loss: 0.0327, Val Loss: 0.0249
# Epoch [1481/1500] Fold 10, Train Loss: 0.0322, Val Loss: 0.0252
# Epoch [1482/1500] Fold 10, Train Loss: 0.0314, Val Loss: 0.0249
# Epoch [1483/1500] Fold 10, Train Loss: 0.0311, Val Loss: 0.0249
# Epoch [1484/1500] Fold 10, Train Loss: 0.0316, Val Loss: 0.0253
# Epoch [1485/1500] Fold 10, Train Loss: 0.0302, Val Loss: 0.0249
# Epoch [1486/1500] Fold 10, Train Loss: 0.0321, Val Loss: 0.0246
# Epoch [1487/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0249
# Epoch [1488/1500] Fold 10, Train Loss: 0.0318, Val Loss: 0.0249
# Epoch [1489/1500] Fold 10, Train Loss: 0.0329, Val Loss: 0.0252
# Epoch [1490/1500] Fold 10, Train Loss: 0.0328, Val Loss: 0.0252
# Epoch [1491/1500] Fold 10, Train Loss: 0.0326, Val Loss: 0.0248
# Epoch [1492/1500] Fold 10, Train Loss: 0.0321, Val Loss: 0.0253
# Epoch [1493/1500] Fold 10, Train Loss: 0.0309, Val Loss: 0.0250
# Epoch [1494/1500] Fold 10, Train Loss: 0.0310, Val Loss: 0.0254
# Epoch [1495/1500] Fold 10, Train Loss: 0.0321, Val Loss: 0.0250
# Epoch [1496/1500] Fold 10, Train Loss: 0.0318, Val Loss: 0.0250
# Epoch [1497/1500] Fold 10, Train Loss: 0.0307, Val Loss: 0.0252
# Epoch [1498/1500] Fold 10, Train Loss: 0.0325, Val Loss: 0.0255
# Epoch [1499/1500] Fold 10, Train Loss: 0.0313, Val Loss: 0.0251
# Epoch [1500/1500] Fold 10, Train Loss: 0.0317, Val Loss: 0.0250

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.0256

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.0206
#   Corresponding Training Loss = 0.0339
#   Best Epoch = 1439
# Fold 2:
#   Best Validation Loss = 0.0254
#   Corresponding Training Loss = 0.0335
#   Best Epoch = 1379
# Fold 3:
#   Best Validation Loss = 0.0237
#   Corresponding Training Loss = 0.0329
#   Best Epoch = 1415
# Fold 4:
#   Best Validation Loss = 0.0274
#   Corresponding Training Loss = 0.0322
#   Best Epoch = 1489
# Fold 5:
#   Best Validation Loss = 0.0247
#   Corresponding Training Loss = 0.0318
#   Best Epoch = 1495
# Fold 6:
#   Best Validation Loss = 0.0262
#   Corresponding Training Loss = 0.0307
#   Best Epoch = 1466
# Fold 7:
#   Best Validation Loss = 0.0247
#   Corresponding Training Loss = 0.0331
#   Best Epoch = 1417
# Fold 8:
#   Best Validation Loss = 0.0280
#   Corresponding Training Loss = 0.0333
#   Best Epoch = 1494
# Fold 9:
#   Best Validation Loss = 0.0226
#   Corresponding Training Loss = 0.0302
#   Best Epoch = 1493
# Fold 10:
#   Best Validation Loss = 0.0246
#   Corresponding Training Loss = 0.0321
#   Best Epoch = 1486

# %%
def plot_loss_curves_separately(cv_histories):
    """
    Plot training and validation loss curves for each fold in separate figures.
    
    Args:
        cv_histories (list): List of loss histories for each fold.
    """
    # Plot Training Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['train_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
    plt.title('Training Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['val_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
    plt.title('Validation Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_loss_curves_separately(cv_histories)

# %%
import torch
import numpy as np

# Track the best validation loss across all folds
lowest_val_loss = float('inf')
best_model_idx = -1  # Index of the best model
best_model_state = None

# Find the fold with the lowest validation loss
for fold_idx, history in enumerate(cv_histories):
    # Get the best validation loss for this fold
    best_val_loss = min(history['val_loss'])
    
    # Check if this is the lowest validation loss across all folds
    if best_val_loss < lowest_val_loss:
        lowest_val_loss = best_val_loss
        best_model_idx = fold_idx
        best_model_state = best_models[fold_idx]

# Save the model with the lowest validation loss
if best_model_state is not None:
    save_path = f'bestmodel_ex_{best_model_idx + 1}.pth'
    torch.save(best_model_state, save_path)
    print(f"Model from fold {best_model_idx + 1} with the lowest validation loss ({lowest_val_loss:.4f}) saved to {save_path}.")
else:
    print("No model to save.")
# Out:
# Model from fold 1 with the lowest validation loss (0.0206) saved to bestmodel_ex_1.pth.

# %%
s
