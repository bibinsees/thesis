# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import tifffile as tiff
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
from copy import deepcopy
import random

# %%
# Load the saved day 7 features
combined_ex7 = torch.load('combined_ex7.pt')

# Load the saved day 10 features
combined_ex10 = torch.load('combined_ex10.pt')
# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_ex7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_ex10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([646, 512])
# Loaded Day 10 Features Shape: torch.Size([646, 512])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_6336\1356550951.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_ex7 = torch.load('combined_ex7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_6336\1356550951.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_ex10 = torch.load('combined_ex10.pt')

# %%
# Load the saved day 7 features
combined_cond7 = torch.load('combined_cond7.pt')

# Load the saved day 10 features
combined_cond10 = torch.load('combined_cond10.pt')
# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_cond7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_cond10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([650, 512])
# Loaded Day 10 Features Shape: torch.Size([650, 512])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_6336\3329391658.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_cond7 = torch.load('combined_cond7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_6336\3329391658.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_cond10 = torch.load('combined_cond10.pt')

# %%
# Load the saved day 7 features
combined_sd7 = torch.load('combined_sd7.pt')

# Load the saved day 10 features
combined_sd10 = torch.load('combined_sd10.pt')

# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_sd7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_sd10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([638, 512])
# Loaded Day 10 Features Shape: torch.Size([638, 512])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_6336\1607657786.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_sd7 = torch.load('combined_sd7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_6336\1607657786.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_sd10 = torch.load('combined_sd10.pt')

# %%
train_day7_feats = combined_cond7 
train_day10_feats = combined_cond10

# %%
train_day7_feats = combined_sd7 
train_day10_feats = combined_sd10

# %%
train_day7_feats = combined_ex7 
train_day10_feats = combined_ex10

# %%
train_day7_feats.shape

# %%
type(train_day7_feats)

# %%
train_day7_feats[0].shape

# %%
import matplotlib.pyplot as plt

# Plot histograms for input (X) and target (Y)
plt.figure(figsize=(12, 6))

# Flatten tensors to 1D for easier visualization
train_day7_feats_flat = train_day7_feats.flatten().cpu().numpy()
train_day10_feats_flat = train_day10_feats.flatten().cpu().numpy()

# Input (X) histogram
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_flat, bins=50, color='blue', alpha=0.7, label='Input (X)')
plt.title('Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_flat, bins=50, color='green', alpha=0.7, label='Target (Y)')
plt.title('Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"Input (X): Mean={train_day7_feats.mean():.4f}, Std={train_day7_feats.std():.4f}")
print(f"Target (Y): Mean={train_day10_feats.mean():.4f}, Std={train_day10_feats.std():.4f}")
# Out:
# Input (X): Mean=1.1292, Std=1.3151
# Target (Y): Mean=0.8309, Std=1.0948

# %%
# Convert PyTorch tensor to NumPy array
train_day7_feats_numpy = train_day7_feats.numpy()
train_day10_feats_numpy = train_day10_feats.numpy()

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize separate MinMaxScaler for day7 and day10
scaler_day7 = MinMaxScaler()
scaler_day10 = MinMaxScaler()

# Fit and transform the train_day7_feats
train_day7_feats_minmaxed = scaler_day7.fit_transform(train_day7_feats_numpy)
print(train_day7_feats_minmaxed.shape)
# Get min and max values for day7
min_values_day7 = scaler_day7.data_min_
max_values_day7 = scaler_day7.data_max_

print(min_values_day7.shape)
print(max_values_day7.shape)
#print("Min values for day7:", min_values_day7)
#print("Max values for day7:", max_values_day7)

# Fit and transform the train_day10_feats (target)
train_day10_feats_minmaxed = scaler_day10.fit_transform(train_day10_feats_numpy)
print(train_day10_feats_minmaxed.shape)
# Get min and max values for day10
min_values_day10 = scaler_day10.data_min_
max_values_day10 = scaler_day10.data_max_

print(min_values_day10.shape)
print(max_values_day10.shape)
#print("Min values for day10:", min_values_day10)
#print("Max values for day10:", max_values_day10)

# Convert the scaled data back to PyTorch tensors (optional)
train_day7_feats_minmaxed = torch.tensor(train_day7_feats_minmaxed)
train_day10_feats_minmaxed = torch.tensor(train_day10_feats_minmaxed)
# Out:
# (646, 512)
# (512,)
# (512,)
# (646, 512)
# (512,)
# (512,)

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'ex7.pkl')
joblib.dump(scaler_day10, 'ex10.pkl')

print("Scalers saved!")
# Out:
# Scalers saved!

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'sd7.pkl')
joblib.dump(scaler_day10, 'sd10.pkl')

print("Scalers saved!")

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'cond7.pkl')
joblib.dump(scaler_day10, 'cond10.pkl')

print("Scalers saved!")

# %%
type(train_day7_feats_minmaxed)

# %%
import matplotlib.pyplot as plt

# Flatten the tensors for easier visualization
train_day7_feats_minmaxed_flat = train_day7_feats_minmaxed.flatten().cpu().numpy()
train_day10_feats_minmaxed_flat = train_day10_feats_minmaxed.flatten().cpu().numpy()

# Plot histograms
plt.figure(figsize=(12, 6))

# Input (X) histogram after Min-Max scaling
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_minmaxed_flat, bins=50, color='blue', alpha=0.7, label='Min-Max Scaled Input (X)')
plt.title('Min-Max Scaled Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram after Min-Max scaling
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_minmaxed_flat, bins=50, color='green', alpha=0.7, label='Min-Max Scaled Target (Y)')
plt.title('Min-Max Scaled Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# import torch
# import torch.nn as nn
#
# class FeaturePredictor(nn.Module):
#     def __init__(self, input_size=20, output_size=20):
#         super().__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_size, 16),
#             nn.BatchNorm1d(16),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(16, 8),
#             nn.BatchNorm1d(8),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(8, 4),
#             nn.BatchNorm1d(4),
#         )
#         self.decoder = nn.Sequential(
#             nn.Linear(4, 8),
#             nn.BatchNorm1d(8),
#             nn.ReLU(),
#             nn.Linear(8, 16),
#             nn.BatchNorm1d(16),
#             nn.ReLU(),
#             nn.Linear(16, output_size)
#         )
#
#     def forward(self, x):
#         x = self.encoder(x)
#         z = self.decoder(x)
#         return z
#
# # Example usage
# model = FeaturePredictor()
# print(model)

# %%
class FeaturePredictor(nn.Module):
    def __init__(self, input_size=512, output_size=512):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, 16),
            nn.BatchNorm1d(16),
        )
        self.decoder = nn.Sequential(
            nn.Linear(16, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Linear(64, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Linear(256, output_size)
        )
    
    # Corrected indentation for forward method
    def forward(self, x):
        x = self.encoder(x)
        z = self.decoder(x)
        return z

# %% [markdown]
# import torch.nn as nn
# from torch.utils.data import TensorDataset, DataLoader
#
# class FeaturePredictor(nn.Module):
#     def __init__(self, input_size=512, output_size=512):
#         super(FeaturePredictor, self).__init__()
#         self.model = nn.Sequential(
#             nn.Linear(input_size, 256),
#             nn.ReLU(),
#             nn.Linear(256, 128),
#             nn.ReLU(),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Linear(64, 32),
#             nn.ReLU(),
#             nn.Linear(32, 16),
#             nn.ReLU(),
#             nn.Linear(16,8),
#             nn.ReLU(),
#             nn.Linear(8, 16),
#             nn.ReLU(),
#             nn.Linear(16,32),
#             nn.ReLU(),
#             nn.Linear(32, 64),
#             nn.ReLU(),
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Linear(128,256),
#             nn.ReLU(),
#             nn.Linear(256, output_size)
#         )
#
#     def forward(self, x):
#         return self.model(x)

# %%
model = FeaturePredictor()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset

# %%
from torch.utils.data import TensorDataset

optimizer_class = torch.optim.Adam

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset
import numpy as np
import torch

# %%
class EarlyStopping:
    def __init__(self, patience=10, delta=0.0):
        """
        Args:
            patience (int): How many epochs to wait after the last validation loss improvement.
            delta (float): Minimum change in the validation loss to qualify as an improvement.
        """
        self.patience = patience
        self.delta = delta
        self.best_loss = None
        self.no_improvement_epochs = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.no_improvement_epochs = 0
        else:
            self.no_improvement_epochs += 1
            if self.no_improvement_epochs >= self.patience:
                self.early_stop = True


def cross_validate_with_early_stopping(
    model_class, dataset, criterion, optimizer_class, num_epochs=50, n_splits=10, patience=10, device='cuda'
):
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    histories = []
    best_models = []

    for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset)):
        print(f"Fold {fold + 1}/{n_splits}")

        # Create subsets for this fold
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        # Create DataLoaders
        train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

        # Initialize the model, optimizer, and early stopping for this fold
        model = model_class().to(device)
        optimizer = optimizer_class(model.parameters(), lr=1e-4)
        early_stopping = EarlyStopping(patience=patience)

        # Training and validation loop
        history = {'train_loss': [], 'val_loss': []}
        for epoch in range(num_epochs):
            # Training phase
            model.train()
            train_loss = 0.0
            for batch_inputs, batch_targets in train_loader:
                batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)

                # Forward pass
                outputs = model(batch_inputs)
                loss = criterion(outputs, batch_targets)
                train_loss += loss.item()

                # Backward pass and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            train_loss /= len(train_loader)
            history['train_loss'].append(train_loss)

            # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for batch_inputs, batch_targets in val_loader:
                    batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)
                    outputs = model(batch_inputs)
                    loss = criterion(outputs, batch_targets)
                    val_loss += loss.item()

            val_loss /= len(val_loader)
            history['val_loss'].append(val_loss)

            print(f"Epoch [{epoch + 1}/{num_epochs}] Fold {fold + 1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

            # Check early stopping
            early_stopping(val_loss)
            if early_stopping.early_stop:
                print(f"Early stopping at epoch {epoch + 1} for fold {fold + 1}")
                break

        # Save the best model for this fold
        best_models.append(model.state_dict())
        histories.append(history)

    return histories, best_models

# %%
# MIN MAX
dataset = TensorDataset(train_day7_feats_minmaxed, train_day10_feats_minmaxed)

cv_histories, best_models = cross_validate_with_early_stopping(
    model_class=FeaturePredictor,
    dataset=dataset,
    criterion=nn.MSELoss(),
    optimizer_class=torch.optim.Adam,
    num_epochs=1000,
    patience=500
)
# Out:
# Fold 1/10
# Epoch [1/1000] Fold 1, Train Loss: 0.1916, Val Loss: 0.0598
# Epoch [2/1000] Fold 1, Train Loss: 0.1394, Val Loss: 0.0594
# Epoch [3/1000] Fold 1, Train Loss: 0.1151, Val Loss: 0.0599
# Epoch [4/1000] Fold 1, Train Loss: 0.0950, Val Loss: 0.0550
# Epoch [5/1000] Fold 1, Train Loss: 0.0819, Val Loss: 0.0495
# Epoch [6/1000] Fold 1, Train Loss: 0.0721, Val Loss: 0.0462
# Epoch [7/1000] Fold 1, Train Loss: 0.0658, Val Loss: 0.0406
# Epoch [8/1000] Fold 1, Train Loss: 0.0592, Val Loss: 0.0401
# Epoch [9/1000] Fold 1, Train Loss: 0.0543, Val Loss: 0.0367
# Epoch [10/1000] Fold 1, Train Loss: 0.0506, Val Loss: 0.0336
# Epoch [11/1000] Fold 1, Train Loss: 0.0485, Val Loss: 0.0322
# Epoch [12/1000] Fold 1, Train Loss: 0.0440, Val Loss: 0.0307
# Epoch [13/1000] Fold 1, Train Loss: 0.0436, Val Loss: 0.0298
# Epoch [14/1000] Fold 1, Train Loss: 0.0422, Val Loss: 0.0285
# Epoch [15/1000] Fold 1, Train Loss: 0.0396, Val Loss: 0.0279
# Epoch [16/1000] Fold 1, Train Loss: 0.0386, Val Loss: 0.0272
# Epoch [17/1000] Fold 1, Train Loss: 0.0379, Val Loss: 0.0271
# Epoch [18/1000] Fold 1, Train Loss: 0.0370, Val Loss: 0.0265
# Epoch [19/1000] Fold 1, Train Loss: 0.0372, Val Loss: 0.0257
# Epoch [20/1000] Fold 1, Train Loss: 0.0355, Val Loss: 0.0253
# Epoch [21/1000] Fold 1, Train Loss: 0.0339, Val Loss: 0.0247
# Epoch [22/1000] Fold 1, Train Loss: 0.0341, Val Loss: 0.0248
# Epoch [23/1000] Fold 1, Train Loss: 0.0338, Val Loss: 0.0245
# Epoch [24/1000] Fold 1, Train Loss: 0.0341, Val Loss: 0.0246
# Epoch [25/1000] Fold 1, Train Loss: 0.0319, Val Loss: 0.0242
# Epoch [26/1000] Fold 1, Train Loss: 0.0323, Val Loss: 0.0237
# Epoch [27/1000] Fold 1, Train Loss: 0.0319, Val Loss: 0.0233
# Epoch [28/1000] Fold 1, Train Loss: 0.0318, Val Loss: 0.0234
# Epoch [29/1000] Fold 1, Train Loss: 0.0308, Val Loss: 0.0236
# Epoch [30/1000] Fold 1, Train Loss: 0.0302, Val Loss: 0.0232
# Epoch [31/1000] Fold 1, Train Loss: 0.0304, Val Loss: 0.0227
# Epoch [32/1000] Fold 1, Train Loss: 0.0303, Val Loss: 0.0227
# Epoch [33/1000] Fold 1, Train Loss: 0.0299, Val Loss: 0.0226
# Epoch [34/1000] Fold 1, Train Loss: 0.0295, Val Loss: 0.0222
# Epoch [35/1000] Fold 1, Train Loss: 0.0287, Val Loss: 0.0222
# Epoch [36/1000] Fold 1, Train Loss: 0.0292, Val Loss: 0.0221
# Epoch [37/1000] Fold 1, Train Loss: 0.0289, Val Loss: 0.0220
# Epoch [38/1000] Fold 1, Train Loss: 0.0303, Val Loss: 0.0221
# Epoch [39/1000] Fold 1, Train Loss: 0.0286, Val Loss: 0.0217
# Epoch [40/1000] Fold 1, Train Loss: 0.0280, Val Loss: 0.0215
# Epoch [41/1000] Fold 1, Train Loss: 0.0295, Val Loss: 0.0213
# Epoch [42/1000] Fold 1, Train Loss: 0.0292, Val Loss: 0.0214
# Epoch [43/1000] Fold 1, Train Loss: 0.0281, Val Loss: 0.0214
# Epoch [44/1000] Fold 1, Train Loss: 0.0284, Val Loss: 0.0209
# Epoch [45/1000] Fold 1, Train Loss: 0.0275, Val Loss: 0.0208
# Epoch [46/1000] Fold 1, Train Loss: 0.0274, Val Loss: 0.0208
# Epoch [47/1000] Fold 1, Train Loss: 0.0276, Val Loss: 0.0208
# Epoch [48/1000] Fold 1, Train Loss: 0.0279, Val Loss: 0.0204
# Epoch [49/1000] Fold 1, Train Loss: 0.0276, Val Loss: 0.0203
# Epoch [50/1000] Fold 1, Train Loss: 0.0271, Val Loss: 0.0203
# Epoch [51/1000] Fold 1, Train Loss: 0.0264, Val Loss: 0.0202
# Epoch [52/1000] Fold 1, Train Loss: 0.0266, Val Loss: 0.0203
# Epoch [53/1000] Fold 1, Train Loss: 0.0270, Val Loss: 0.0204
# Epoch [54/1000] Fold 1, Train Loss: 0.0272, Val Loss: 0.0200
# Epoch [55/1000] Fold 1, Train Loss: 0.0262, Val Loss: 0.0203
# Epoch [56/1000] Fold 1, Train Loss: 0.0260, Val Loss: 0.0199
# Epoch [57/1000] Fold 1, Train Loss: 0.0259, Val Loss: 0.0197
# Epoch [58/1000] Fold 1, Train Loss: 0.0259, Val Loss: 0.0194
# Epoch [59/1000] Fold 1, Train Loss: 0.0253, Val Loss: 0.0194
# Epoch [60/1000] Fold 1, Train Loss: 0.0250, Val Loss: 0.0195
# Epoch [61/1000] Fold 1, Train Loss: 0.0253, Val Loss: 0.0193
# Epoch [62/1000] Fold 1, Train Loss: 0.0260, Val Loss: 0.0193
# Epoch [63/1000] Fold 1, Train Loss: 0.0249, Val Loss: 0.0192
# Epoch [64/1000] Fold 1, Train Loss: 0.0248, Val Loss: 0.0194
# Epoch [65/1000] Fold 1, Train Loss: 0.0258, Val Loss: 0.0192
# Epoch [66/1000] Fold 1, Train Loss: 0.0245, Val Loss: 0.0191
# Epoch [67/1000] Fold 1, Train Loss: 0.0249, Val Loss: 0.0189
# Epoch [68/1000] Fold 1, Train Loss: 0.0245, Val Loss: 0.0189
# Epoch [69/1000] Fold 1, Train Loss: 0.0247, Val Loss: 0.0195
# Epoch [70/1000] Fold 1, Train Loss: 0.0249, Val Loss: 0.0194
# Epoch [71/1000] Fold 1, Train Loss: 0.0240, Val Loss: 0.0192
# Epoch [72/1000] Fold 1, Train Loss: 0.0245, Val Loss: 0.0190
# Epoch [73/1000] Fold 1, Train Loss: 0.0239, Val Loss: 0.0191
# Epoch [74/1000] Fold 1, Train Loss: 0.0259, Val Loss: 0.0187
# Epoch [75/1000] Fold 1, Train Loss: 0.0230, Val Loss: 0.0188
# Epoch [76/1000] Fold 1, Train Loss: 0.0240, Val Loss: 0.0188
# Epoch [77/1000] Fold 1, Train Loss: 0.0235, Val Loss: 0.0187
# Epoch [78/1000] Fold 1, Train Loss: 0.0239, Val Loss: 0.0188
# Epoch [79/1000] Fold 1, Train Loss: 0.0237, Val Loss: 0.0189
# Epoch [80/1000] Fold 1, Train Loss: 0.0232, Val Loss: 0.0186
# Epoch [81/1000] Fold 1, Train Loss: 0.0235, Val Loss: 0.0186
# Epoch [82/1000] Fold 1, Train Loss: 0.0250, Val Loss: 0.0187
# Epoch [83/1000] Fold 1, Train Loss: 0.0233, Val Loss: 0.0187
# Epoch [84/1000] Fold 1, Train Loss: 0.0228, Val Loss: 0.0185
# Epoch [85/1000] Fold 1, Train Loss: 0.0227, Val Loss: 0.0183
# Epoch [86/1000] Fold 1, Train Loss: 0.0230, Val Loss: 0.0184
# Epoch [87/1000] Fold 1, Train Loss: 0.0235, Val Loss: 0.0183
# Epoch [88/1000] Fold 1, Train Loss: 0.0242, Val Loss: 0.0186
# Epoch [89/1000] Fold 1, Train Loss: 0.0231, Val Loss: 0.0184
# Epoch [90/1000] Fold 1, Train Loss: 0.0227, Val Loss: 0.0181
# Epoch [91/1000] Fold 1, Train Loss: 0.0223, Val Loss: 0.0180
# Epoch [92/1000] Fold 1, Train Loss: 0.0229, Val Loss: 0.0183
# Epoch [93/1000] Fold 1, Train Loss: 0.0232, Val Loss: 0.0183
# Epoch [94/1000] Fold 1, Train Loss: 0.0222, Val Loss: 0.0182
# Epoch [95/1000] Fold 1, Train Loss: 0.0229, Val Loss: 0.0183
# Epoch [96/1000] Fold 1, Train Loss: 0.0228, Val Loss: 0.0183
# Epoch [97/1000] Fold 1, Train Loss: 0.0221, Val Loss: 0.0183
# Epoch [98/1000] Fold 1, Train Loss: 0.0229, Val Loss: 0.0179
# Epoch [99/1000] Fold 1, Train Loss: 0.0224, Val Loss: 0.0181
# Epoch [100/1000] Fold 1, Train Loss: 0.0224, Val Loss: 0.0181
# Epoch [101/1000] Fold 1, Train Loss: 0.0221, Val Loss: 0.0179
# Epoch [102/1000] Fold 1, Train Loss: 0.0213, Val Loss: 0.0180
# Epoch [103/1000] Fold 1, Train Loss: 0.0219, Val Loss: 0.0180
# Epoch [104/1000] Fold 1, Train Loss: 0.0223, Val Loss: 0.0179
# Epoch [105/1000] Fold 1, Train Loss: 0.0220, Val Loss: 0.0179
# Epoch [106/1000] Fold 1, Train Loss: 0.0218, Val Loss: 0.0182
# Epoch [107/1000] Fold 1, Train Loss: 0.0215, Val Loss: 0.0181
# Epoch [108/1000] Fold 1, Train Loss: 0.0216, Val Loss: 0.0182
# Epoch [109/1000] Fold 1, Train Loss: 0.0216, Val Loss: 0.0184
# Epoch [110/1000] Fold 1, Train Loss: 0.0211, Val Loss: 0.0180
# Epoch [111/1000] Fold 1, Train Loss: 0.0214, Val Loss: 0.0180
# Epoch [112/1000] Fold 1, Train Loss: 0.0220, Val Loss: 0.0178
# Epoch [113/1000] Fold 1, Train Loss: 0.0217, Val Loss: 0.0179
# Epoch [114/1000] Fold 1, Train Loss: 0.0221, Val Loss: 0.0180
# Epoch [115/1000] Fold 1, Train Loss: 0.0206, Val Loss: 0.0183
# Epoch [116/1000] Fold 1, Train Loss: 0.0229, Val Loss: 0.0179
# Epoch [117/1000] Fold 1, Train Loss: 0.0211, Val Loss: 0.0177
# Epoch [118/1000] Fold 1, Train Loss: 0.0219, Val Loss: 0.0179
# Epoch [119/1000] Fold 1, Train Loss: 0.0202, Val Loss: 0.0176
# Epoch [120/1000] Fold 1, Train Loss: 0.0209, Val Loss: 0.0179
# Epoch [121/1000] Fold 1, Train Loss: 0.0205, Val Loss: 0.0177
# Epoch [122/1000] Fold 1, Train Loss: 0.0211, Val Loss: 0.0178
# Epoch [123/1000] Fold 1, Train Loss: 0.0203, Val Loss: 0.0177
# Epoch [124/1000] Fold 1, Train Loss: 0.0202, Val Loss: 0.0174
# Epoch [125/1000] Fold 1, Train Loss: 0.0209, Val Loss: 0.0175
# Epoch [126/1000] Fold 1, Train Loss: 0.0211, Val Loss: 0.0172
# Epoch [127/1000] Fold 1, Train Loss: 0.0210, Val Loss: 0.0174
# Epoch [128/1000] Fold 1, Train Loss: 0.0198, Val Loss: 0.0173
# Epoch [129/1000] Fold 1, Train Loss: 0.0208, Val Loss: 0.0174
# Epoch [130/1000] Fold 1, Train Loss: 0.0199, Val Loss: 0.0175
# Epoch [131/1000] Fold 1, Train Loss: 0.0200, Val Loss: 0.0175
# Epoch [132/1000] Fold 1, Train Loss: 0.0202, Val Loss: 0.0176
# Epoch [133/1000] Fold 1, Train Loss: 0.0201, Val Loss: 0.0174
# Epoch [134/1000] Fold 1, Train Loss: 0.0202, Val Loss: 0.0172
# Epoch [135/1000] Fold 1, Train Loss: 0.0205, Val Loss: 0.0172
# Epoch [136/1000] Fold 1, Train Loss: 0.0203, Val Loss: 0.0177
# Epoch [137/1000] Fold 1, Train Loss: 0.0201, Val Loss: 0.0174
# Epoch [138/1000] Fold 1, Train Loss: 0.0203, Val Loss: 0.0172
# Epoch [139/1000] Fold 1, Train Loss: 0.0198, Val Loss: 0.0174
# Epoch [140/1000] Fold 1, Train Loss: 0.0208, Val Loss: 0.0178
# Epoch [141/1000] Fold 1, Train Loss: 0.0195, Val Loss: 0.0175
# Epoch [142/1000] Fold 1, Train Loss: 0.0203, Val Loss: 0.0174
# Epoch [143/1000] Fold 1, Train Loss: 0.0194, Val Loss: 0.0175
# Epoch [144/1000] Fold 1, Train Loss: 0.0196, Val Loss: 0.0173
# Epoch [145/1000] Fold 1, Train Loss: 0.0200, Val Loss: 0.0175
# Epoch [146/1000] Fold 1, Train Loss: 0.0195, Val Loss: 0.0175
# Epoch [147/1000] Fold 1, Train Loss: 0.0198, Val Loss: 0.0174
# Epoch [148/1000] Fold 1, Train Loss: 0.0196, Val Loss: 0.0173
# Epoch [149/1000] Fold 1, Train Loss: 0.0198, Val Loss: 0.0179
# Epoch [150/1000] Fold 1, Train Loss: 0.0199, Val Loss: 0.0176
# Epoch [151/1000] Fold 1, Train Loss: 0.0204, Val Loss: 0.0176
# Epoch [152/1000] Fold 1, Train Loss: 0.0207, Val Loss: 0.0175
# Epoch [153/1000] Fold 1, Train Loss: 0.0197, Val Loss: 0.0174
# Epoch [154/1000] Fold 1, Train Loss: 0.0207, Val Loss: 0.0176
# Epoch [155/1000] Fold 1, Train Loss: 0.0190, Val Loss: 0.0176
# Epoch [156/1000] Fold 1, Train Loss: 0.0206, Val Loss: 0.0175
# Epoch [157/1000] Fold 1, Train Loss: 0.0190, Val Loss: 0.0172
# Epoch [158/1000] Fold 1, Train Loss: 0.0199, Val Loss: 0.0179
# Epoch [159/1000] Fold 1, Train Loss: 0.0200, Val Loss: 0.0175
# Epoch [160/1000] Fold 1, Train Loss: 0.0202, Val Loss: 0.0172
# Epoch [161/1000] Fold 1, Train Loss: 0.0194, Val Loss: 0.0178
# Epoch [162/1000] Fold 1, Train Loss: 0.0193, Val Loss: 0.0176
# Epoch [163/1000] Fold 1, Train Loss: 0.0202, Val Loss: 0.0174
# Epoch [164/1000] Fold 1, Train Loss: 0.0196, Val Loss: 0.0174
# Epoch [165/1000] Fold 1, Train Loss: 0.0192, Val Loss: 0.0175
# Epoch [166/1000] Fold 1, Train Loss: 0.0197, Val Loss: 0.0175
# Epoch [167/1000] Fold 1, Train Loss: 0.0193, Val Loss: 0.0173
# Epoch [168/1000] Fold 1, Train Loss: 0.0199, Val Loss: 0.0173
# Epoch [169/1000] Fold 1, Train Loss: 0.0194, Val Loss: 0.0170
# Epoch [170/1000] Fold 1, Train Loss: 0.0192, Val Loss: 0.0174
# Epoch [171/1000] Fold 1, Train Loss: 0.0203, Val Loss: 0.0176
# Epoch [172/1000] Fold 1, Train Loss: 0.0189, Val Loss: 0.0171
# Epoch [173/1000] Fold 1, Train Loss: 0.0198, Val Loss: 0.0171
# Epoch [174/1000] Fold 1, Train Loss: 0.0189, Val Loss: 0.0173
# Epoch [175/1000] Fold 1, Train Loss: 0.0186, Val Loss: 0.0170
# Epoch [176/1000] Fold 1, Train Loss: 0.0192, Val Loss: 0.0173
# Epoch [177/1000] Fold 1, Train Loss: 0.0196, Val Loss: 0.0168
# Epoch [178/1000] Fold 1, Train Loss: 0.0192, Val Loss: 0.0171
# Epoch [179/1000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0174
# Epoch [180/1000] Fold 1, Train Loss: 0.0191, Val Loss: 0.0172
# Epoch [181/1000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0171
# Epoch [182/1000] Fold 1, Train Loss: 0.0200, Val Loss: 0.0172
# Epoch [183/1000] Fold 1, Train Loss: 0.0192, Val Loss: 0.0172
# Epoch [184/1000] Fold 1, Train Loss: 0.0187, Val Loss: 0.0170
# Epoch [185/1000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0169
# Epoch [186/1000] Fold 1, Train Loss: 0.0186, Val Loss: 0.0171
# Epoch [187/1000] Fold 1, Train Loss: 0.0182, Val Loss: 0.0170
# Epoch [188/1000] Fold 1, Train Loss: 0.0185, Val Loss: 0.0177
# Epoch [189/1000] Fold 1, Train Loss: 0.0185, Val Loss: 0.0175
# Epoch [190/1000] Fold 1, Train Loss: 0.0189, Val Loss: 0.0173
# Epoch [191/1000] Fold 1, Train Loss: 0.0182, Val Loss: 0.0172
# Epoch [192/1000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0172
# Epoch [193/1000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0168
# Epoch [194/1000] Fold 1, Train Loss: 0.0181, Val Loss: 0.0173
# Epoch [195/1000] Fold 1, Train Loss: 0.0183, Val Loss: 0.0173
# Epoch [196/1000] Fold 1, Train Loss: 0.0191, Val Loss: 0.0169
# Epoch [197/1000] Fold 1, Train Loss: 0.0190, Val Loss: 0.0170
# Epoch [198/1000] Fold 1, Train Loss: 0.0190, Val Loss: 0.0178
# Epoch [199/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0175
# Epoch [200/1000] Fold 1, Train Loss: 0.0188, Val Loss: 0.0172
# Epoch [201/1000] Fold 1, Train Loss: 0.0186, Val Loss: 0.0167
# Epoch [202/1000] Fold 1, Train Loss: 0.0186, Val Loss: 0.0165
# Epoch [203/1000] Fold 1, Train Loss: 0.0183, Val Loss: 0.0168
# Epoch [204/1000] Fold 1, Train Loss: 0.0179, Val Loss: 0.0167
# Epoch [205/1000] Fold 1, Train Loss: 0.0188, Val Loss: 0.0171
# Epoch [206/1000] Fold 1, Train Loss: 0.0204, Val Loss: 0.0172
# Epoch [207/1000] Fold 1, Train Loss: 0.0202, Val Loss: 0.0170
# Epoch [208/1000] Fold 1, Train Loss: 0.0194, Val Loss: 0.0173
# Epoch [209/1000] Fold 1, Train Loss: 0.0186, Val Loss: 0.0174
# Epoch [210/1000] Fold 1, Train Loss: 0.0225, Val Loss: 0.0171
# Epoch [211/1000] Fold 1, Train Loss: 0.0185, Val Loss: 0.0168
# Epoch [212/1000] Fold 1, Train Loss: 0.0182, Val Loss: 0.0174
# Epoch [213/1000] Fold 1, Train Loss: 0.0186, Val Loss: 0.0170
# Epoch [214/1000] Fold 1, Train Loss: 0.0183, Val Loss: 0.0170
# Epoch [215/1000] Fold 1, Train Loss: 0.0189, Val Loss: 0.0174
# Epoch [216/1000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0168
# Epoch [217/1000] Fold 1, Train Loss: 0.0179, Val Loss: 0.0168
# Epoch [218/1000] Fold 1, Train Loss: 0.0182, Val Loss: 0.0169
# Epoch [219/1000] Fold 1, Train Loss: 0.0186, Val Loss: 0.0170
# Epoch [220/1000] Fold 1, Train Loss: 0.0215, Val Loss: 0.0167
# Epoch [221/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0170
# Epoch [222/1000] Fold 1, Train Loss: 0.0187, Val Loss: 0.0173
# Epoch [223/1000] Fold 1, Train Loss: 0.0181, Val Loss: 0.0172
# Epoch [224/1000] Fold 1, Train Loss: 0.0204, Val Loss: 0.0166
# Epoch [225/1000] Fold 1, Train Loss: 0.0190, Val Loss: 0.0169
# Epoch [226/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0168
# Epoch [227/1000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0172
# Epoch [228/1000] Fold 1, Train Loss: 0.0179, Val Loss: 0.0169
# Epoch [229/1000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0166
# Epoch [230/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0169
# Epoch [231/1000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0170
# Epoch [232/1000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0173
# Epoch [233/1000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0171
# Epoch [234/1000] Fold 1, Train Loss: 0.0177, Val Loss: 0.0180
# Epoch [235/1000] Fold 1, Train Loss: 0.0177, Val Loss: 0.0167
# Epoch [236/1000] Fold 1, Train Loss: 0.0177, Val Loss: 0.0170
# Epoch [237/1000] Fold 1, Train Loss: 0.0176, Val Loss: 0.0168
# Epoch [238/1000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0168
# Epoch [239/1000] Fold 1, Train Loss: 0.0183, Val Loss: 0.0172
# Epoch [240/1000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0169
# Epoch [241/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0169
# Epoch [242/1000] Fold 1, Train Loss: 0.0183, Val Loss: 0.0175
# Epoch [243/1000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0166
# Epoch [244/1000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0171
# Epoch [245/1000] Fold 1, Train Loss: 0.0185, Val Loss: 0.0167
# Epoch [246/1000] Fold 1, Train Loss: 0.0190, Val Loss: 0.0170
# Epoch [247/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0167
# Epoch [248/1000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0166
# Epoch [249/1000] Fold 1, Train Loss: 0.0182, Val Loss: 0.0167
# Epoch [250/1000] Fold 1, Train Loss: 0.0179, Val Loss: 0.0168
# Epoch [251/1000] Fold 1, Train Loss: 0.0172, Val Loss: 0.0167
# Epoch [252/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0171
# Epoch [253/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0169
# Epoch [254/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0168
# Epoch [255/1000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0172
# Epoch [256/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0166
# Epoch [257/1000] Fold 1, Train Loss: 0.0172, Val Loss: 0.0166
# Epoch [258/1000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0166
# Epoch [259/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0165
# Epoch [260/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0165
# Epoch [261/1000] Fold 1, Train Loss: 0.0181, Val Loss: 0.0168
# Epoch [262/1000] Fold 1, Train Loss: 0.0179, Val Loss: 0.0171
# Epoch [263/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0166
# Epoch [264/1000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0169
# Epoch [265/1000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0161
# Epoch [266/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0168
# Epoch [267/1000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0170
# Epoch [268/1000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0167
# Epoch [269/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0165
# Epoch [270/1000] Fold 1, Train Loss: 0.0179, Val Loss: 0.0164
# Epoch [271/1000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0164
# Epoch [272/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0166
# Epoch [273/1000] Fold 1, Train Loss: 0.0172, Val Loss: 0.0165
# Epoch [274/1000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0166
# Epoch [275/1000] Fold 1, Train Loss: 0.0171, Val Loss: 0.0165
# Epoch [276/1000] Fold 1, Train Loss: 0.0183, Val Loss: 0.0166
# Epoch [277/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0164
# Epoch [278/1000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0171
# Epoch [279/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0170
# Epoch [280/1000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0161
# Epoch [281/1000] Fold 1, Train Loss: 0.0171, Val Loss: 0.0164
# Epoch [282/1000] Fold 1, Train Loss: 0.0177, Val Loss: 0.0166
# Epoch [283/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0163
# Epoch [284/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0165
# Epoch [285/1000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0169
# Epoch [286/1000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0170
# Epoch [287/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0167
# Epoch [288/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0166
# Epoch [289/1000] Fold 1, Train Loss: 0.0171, Val Loss: 0.0165
# Epoch [290/1000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0168
# Epoch [291/1000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0169
# Epoch [292/1000] Fold 1, Train Loss: 0.0172, Val Loss: 0.0163
# Epoch [293/1000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0168
# Epoch [294/1000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0169
# Epoch [295/1000] Fold 1, Train Loss: 0.0172, Val Loss: 0.0168
# Epoch [296/1000] Fold 1, Train Loss: 0.0176, Val Loss: 0.0168
# Epoch [297/1000] Fold 1, Train Loss: 0.0167, Val Loss: 0.0171
# Epoch [298/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0170
# Epoch [299/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0168
# Epoch [300/1000] Fold 1, Train Loss: 0.0176, Val Loss: 0.0165
# Epoch [301/1000] Fold 1, Train Loss: 0.0182, Val Loss: 0.0167
# Epoch [302/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0169
# Epoch [303/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0168
# Epoch [304/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0166
# Epoch [305/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0167
# Epoch [306/1000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0177
# Epoch [307/1000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0175
# Epoch [308/1000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0169
# Epoch [309/1000] Fold 1, Train Loss: 0.0177, Val Loss: 0.0169
# Epoch [310/1000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0164
# Epoch [311/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0171
# Epoch [312/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0172
# Epoch [313/1000] Fold 1, Train Loss: 0.0176, Val Loss: 0.0164
# Epoch [314/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0162
# Epoch [315/1000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0163
# Epoch [316/1000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0164
# Epoch [317/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0163
# Epoch [318/1000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0165
# Epoch [319/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0161
# Epoch [320/1000] Fold 1, Train Loss: 0.0171, Val Loss: 0.0163
# Epoch [321/1000] Fold 1, Train Loss: 0.0167, Val Loss: 0.0164
# Epoch [322/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0165
# Epoch [323/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0162
# Epoch [324/1000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0168
# Epoch [325/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0164
# Epoch [326/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0163
# Epoch [327/1000] Fold 1, Train Loss: 0.0172, Val Loss: 0.0163
# Epoch [328/1000] Fold 1, Train Loss: 0.0172, Val Loss: 0.0170
# Epoch [329/1000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0166
# Epoch [330/1000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0165
# Epoch [331/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0170
# Epoch [332/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0166
# Epoch [333/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0168
# Epoch [334/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0174
# Epoch [335/1000] Fold 1, Train Loss: 0.0172, Val Loss: 0.0168
# Epoch [336/1000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0168
# Epoch [337/1000] Fold 1, Train Loss: 0.0171, Val Loss: 0.0165
# Epoch [338/1000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0161
# Epoch [339/1000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0162
# Epoch [340/1000] Fold 1, Train Loss: 0.0167, Val Loss: 0.0163
# Epoch [341/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0164
# Epoch [342/1000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0167
# Epoch [343/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0164
# Epoch [344/1000] Fold 1, Train Loss: 0.0171, Val Loss: 0.0163
# Epoch [345/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0166
# Epoch [346/1000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0160
# Epoch [347/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0161
# Epoch [348/1000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0159
# Epoch [349/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0160
# Epoch [350/1000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0160
# Epoch [351/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0162
# Epoch [352/1000] Fold 1, Train Loss: 0.0167, Val Loss: 0.0163
# Epoch [353/1000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0161
# Epoch [354/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0161
# Epoch [355/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0169
# Epoch [356/1000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0161
# Epoch [357/1000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0167
# Epoch [358/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0165
# Epoch [359/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0163
# Epoch [360/1000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0159
# Epoch [361/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0162
# Epoch [362/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0162
# Epoch [363/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0165
# Epoch [364/1000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0156
# Epoch [365/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0160
# Epoch [366/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0159
# Epoch [367/1000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0160
# Epoch [368/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0160
# Epoch [369/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0161
# Epoch [370/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0164
# Epoch [371/1000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0162
# Epoch [372/1000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0163
# Epoch [373/1000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0165
# Epoch [374/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0163
# Epoch [375/1000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0167
# Epoch [376/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0165
# Epoch [377/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0163
# Epoch [378/1000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0160
# Epoch [379/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0166
# Epoch [380/1000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0160
# Epoch [381/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0165
# Epoch [382/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0160
# Epoch [383/1000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0163
# Epoch [384/1000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0163
# Epoch [385/1000] Fold 1, Train Loss: 0.0167, Val Loss: 0.0170
# Epoch [386/1000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0163
# Epoch [387/1000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0164
# Epoch [388/1000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0166
# Epoch [389/1000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0159
# Epoch [390/1000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0159
# Epoch [391/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0163
# Epoch [392/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0164
# Epoch [393/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0161
# Epoch [394/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0161
# Epoch [395/1000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0169
# Epoch [396/1000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0165
# Epoch [397/1000] Fold 1, Train Loss: 0.0171, Val Loss: 0.0162
# Epoch [398/1000] Fold 1, Train Loss: 0.0177, Val Loss: 0.0161
# Epoch [399/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0160
# Epoch [400/1000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0161
# Epoch [401/1000] Fold 1, Train Loss: 0.0179, Val Loss: 0.0162
# Epoch [402/1000] Fold 1, Train Loss: 0.0167, Val Loss: 0.0160
# Epoch [403/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0161
# Epoch [404/1000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0160
# Epoch [405/1000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0160
# Epoch [406/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0154
# Epoch [407/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0155
# Epoch [408/1000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0153
# Epoch [409/1000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0158
# Epoch [410/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0159
# Epoch [411/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0159
# Epoch [412/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0157
# Epoch [413/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0159
# Epoch [414/1000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0162
# Epoch [415/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0159
# Epoch [416/1000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0157
# Epoch [417/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0162
# Epoch [418/1000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0165
# Epoch [419/1000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0162
# Epoch [420/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0159
# Epoch [421/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0159
# Epoch [422/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0158
# Epoch [423/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0162
# Epoch [424/1000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0157
# Epoch [425/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0162
# Epoch [426/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0158
# Epoch [427/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0161
# Epoch [428/1000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0163
# Epoch [429/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0163
# Epoch [430/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0156
# Epoch [431/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0154
# Epoch [432/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0157
# Epoch [433/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0159
# Epoch [434/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0160
# Epoch [435/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0160
# Epoch [436/1000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0155
# Epoch [437/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0155
# Epoch [438/1000] Fold 1, Train Loss: 0.0177, Val Loss: 0.0156
# Epoch [439/1000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0156
# Epoch [440/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0158
# Epoch [441/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0160
# Epoch [442/1000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0157
# Epoch [443/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0159
# Epoch [444/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0157
# Epoch [445/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0163
# Epoch [446/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0158
# Epoch [447/1000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0158
# Epoch [448/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0157
# Epoch [449/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0158
# Epoch [450/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0157
# Epoch [451/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0158
# Epoch [452/1000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0162
# Epoch [453/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0160
# Epoch [454/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0159
# Epoch [455/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0159
# Epoch [456/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0156
# Epoch [457/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0157
# Epoch [458/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0158
# Epoch [459/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0159
# Epoch [460/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0159
# Epoch [461/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0158
# Epoch [462/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0155
# Epoch [463/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0157
# Epoch [464/1000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0162
# Epoch [465/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0163
# Epoch [466/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0163
# Epoch [467/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0160
# Epoch [468/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0167
# Epoch [469/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0157
# Epoch [470/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0157
# Epoch [471/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0160
# Epoch [472/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0159
# Epoch [473/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0160
# Epoch [474/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0164
# Epoch [475/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0164
# Epoch [476/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0164
# Epoch [477/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0163
# Epoch [478/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0160
# Epoch [479/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0158
# Epoch [480/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0158
# Epoch [481/1000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0161
# Epoch [482/1000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0161
# Epoch [483/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0163
# Epoch [484/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0162
# Epoch [485/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0165
# Epoch [486/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0160
# Epoch [487/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0159
# Epoch [488/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0161
# Epoch [489/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0164
# Epoch [490/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0164
# Epoch [491/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0160
# Epoch [492/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0163
# Epoch [493/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0166
# Epoch [494/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0165
# Epoch [495/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0170
# Epoch [496/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0160
# Epoch [497/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0164
# Epoch [498/1000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0162
# Epoch [499/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0165
# Epoch [500/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0160
# Epoch [501/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0165
# Epoch [502/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0164
# Epoch [503/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0160
# Epoch [504/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0166
# Epoch [505/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0166
# Epoch [506/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0159
# Epoch [507/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0164
# Epoch [508/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0160
# Epoch [509/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0164
# Epoch [510/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0161
# Epoch [511/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0165
# Epoch [512/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0168
# Epoch [513/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0158
# Epoch [514/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0161
# Epoch [515/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0159
# Epoch [516/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0161
# Epoch [517/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0172
# Epoch [518/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0166
# Epoch [519/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0169
# Epoch [520/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0167
# Epoch [521/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0164
# Epoch [522/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0161
# Epoch [523/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0164
# Epoch [524/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0157
# Epoch [525/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0163
# Epoch [526/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0164
# Epoch [527/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0166
# Epoch [528/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0159
# Epoch [529/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0158
# Epoch [530/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0159
# Epoch [531/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0156
# Epoch [532/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0159
# Epoch [533/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0155
# Epoch [534/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0159
# Epoch [535/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0159
# Epoch [536/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0159
# Epoch [537/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0160
# Epoch [538/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0152
# Epoch [539/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0156
# Epoch [540/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0158
# Epoch [541/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0159
# Epoch [542/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0161
# Epoch [543/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0163
# Epoch [544/1000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0162
# Epoch [545/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0165
# Epoch [546/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0162
# Epoch [547/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0161
# Epoch [548/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0158
# Epoch [549/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0159
# Epoch [550/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0158
# Epoch [551/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0159
# Epoch [552/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0158
# Epoch [553/1000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0159
# Epoch [554/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0157
# Epoch [555/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0154
# Epoch [556/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0153
# Epoch [557/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0157
# Epoch [558/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0159
# Epoch [559/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0156
# Epoch [560/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0156
# Epoch [561/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0156
# Epoch [562/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0159
# Epoch [563/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0157
# Epoch [564/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0159
# Epoch [565/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0159
# Epoch [566/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0159
# Epoch [567/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0156
# Epoch [568/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0155
# Epoch [569/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0159
# Epoch [570/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0161
# Epoch [571/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0159
# Epoch [572/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0159
# Epoch [573/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0157
# Epoch [574/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0159
# Epoch [575/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0157
# Epoch [576/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0157
# Epoch [577/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0158
# Epoch [578/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0158
# Epoch [579/1000] Fold 1, Train Loss: 0.0180, Val Loss: 0.0154
# Epoch [580/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0155
# Epoch [581/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0154
# Epoch [582/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0158
# Epoch [583/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0159
# Epoch [584/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0159
# Epoch [585/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0156
# Epoch [586/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0156
# Epoch [587/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0161
# Epoch [588/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0160
# Epoch [589/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0164
# Epoch [590/1000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0163
# Epoch [591/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0156
# Epoch [592/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0155
# Epoch [593/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0159
# Epoch [594/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0161
# Epoch [595/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0159
# Epoch [596/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0159
# Epoch [597/1000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0159
# Epoch [598/1000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0161
# Epoch [599/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0162
# Epoch [600/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0168
# Epoch [601/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0165
# Epoch [602/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0160
# Epoch [603/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0162
# Epoch [604/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0158
# Epoch [605/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0161
# Epoch [606/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0160
# Epoch [607/1000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0166
# Epoch [608/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0162
# Epoch [609/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0161
# Epoch [610/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0163
# Epoch [611/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0161
# Epoch [612/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0163
# Epoch [613/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0162
# Epoch [614/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0160
# Epoch [615/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0159
# Epoch [616/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0162
# Epoch [617/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0166
# Epoch [618/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0166
# Epoch [619/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0160
# Epoch [620/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0156
# Epoch [621/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0159
# Epoch [622/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0160
# Epoch [623/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0160
# Epoch [624/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0158
# Epoch [625/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0160
# Epoch [626/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0158
# Epoch [627/1000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0161
# Epoch [628/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0159
# Epoch [629/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0163
# Epoch [630/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0163
# Epoch [631/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0165
# Epoch [632/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0159
# Epoch [633/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0163
# Epoch [634/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0159
# Epoch [635/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0157
# Epoch [636/1000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0156
# Epoch [637/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0160
# Epoch [638/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0158
# Epoch [639/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0158
# Epoch [640/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0159
# Epoch [641/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0157
# Epoch [642/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0161
# Epoch [643/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0164
# Epoch [644/1000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0158
# Epoch [645/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0157
# Epoch [646/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0161
# Epoch [647/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0161
# Epoch [648/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0159
# Epoch [649/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0161
# Epoch [650/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0161
# Epoch [651/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0159
# Epoch [652/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0163
# Epoch [653/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0167
# Epoch [654/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0158
# Epoch [655/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0163
# Epoch [656/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0164
# Epoch [657/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0164
# Epoch [658/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0163
# Epoch [659/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0162
# Epoch [660/1000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0167
# Epoch [661/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0166
# Epoch [662/1000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0175
# Epoch [663/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0163
# Epoch [664/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0165
# Epoch [665/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0161
# Epoch [666/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0163
# Epoch [667/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0165
# Epoch [668/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0168
# Epoch [669/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0166
# Epoch [670/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0164
# Epoch [671/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0164
# Epoch [672/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0162
# Epoch [673/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0160
# Epoch [674/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0161
# Epoch [675/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0163
# Epoch [676/1000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0157
# Epoch [677/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0160
# Epoch [678/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0160
# Epoch [679/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0159
# Epoch [680/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0154
# Epoch [681/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0156
# Epoch [682/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0159
# Epoch [683/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0162
# Epoch [684/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0159
# Epoch [685/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0163
# Epoch [686/1000] Fold 1, Train Loss: 0.0141, Val Loss: 0.0162
# Epoch [687/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0160
# Epoch [688/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0170
# Epoch [689/1000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0165
# Epoch [690/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0165
# Epoch [691/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0159
# Epoch [692/1000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0158
# Epoch [693/1000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0159
# Epoch [694/1000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0161
# Epoch [695/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0159
# Epoch [696/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0166
# Epoch [697/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0158
# Epoch [698/1000] Fold 1, Train Loss: 0.0144, Val Loss: 0.0154
# Epoch [699/1000] Fold 1, Train Loss: 0.0144, Val Loss: 0.0159
# Epoch [700/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0162
# Epoch [701/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0165
# Epoch [702/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0160
# Epoch [703/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0169
# Epoch [704/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0162
# Epoch [705/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0161
# Epoch [706/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0166
# Epoch [707/1000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0160
# Epoch [708/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0166
# Epoch [709/1000] Fold 1, Train Loss: 0.0164, Val Loss: 0.0161
# Epoch [710/1000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0170
# Epoch [711/1000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0170
# Epoch [712/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0166
# Epoch [713/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0163
# Epoch [714/1000] Fold 1, Train Loss: 0.0143, Val Loss: 0.0162
# Epoch [715/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0164
# Epoch [716/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0160
# Epoch [717/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0163
# Epoch [718/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0160
# Epoch [719/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0160
# Epoch [720/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0161
# Epoch [721/1000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0158
# Epoch [722/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0160
# Epoch [723/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0163
# Epoch [724/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0162
# Epoch [725/1000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0163
# Epoch [726/1000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0161
# Epoch [727/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0165
# Epoch [728/1000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0165
# Epoch [729/1000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0161
# Epoch [730/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0164
# Epoch [731/1000] Fold 1, Train Loss: 0.0143, Val Loss: 0.0161
# Epoch [732/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0164
# Epoch [733/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0159
# Epoch [734/1000] Fold 1, Train Loss: 0.0144, Val Loss: 0.0163
# Epoch [735/1000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0166
# Epoch [736/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0165
# Epoch [737/1000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0164
# Epoch [738/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0163
# Epoch [739/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0162
# Epoch [740/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0164
# Epoch [741/1000] Fold 1, Train Loss: 0.0143, Val Loss: 0.0164
# Epoch [742/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0160
# Epoch [743/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0162
# Epoch [744/1000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0163
# Epoch [745/1000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0161
# Epoch [746/1000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0162
# Epoch [747/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0160
# Epoch [748/1000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0165
# Epoch [749/1000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0160
# Epoch [750/1000] Fold 1, Train Loss: 0.0143, Val Loss: 0.0157
# Epoch [751/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0159
# Epoch [752/1000] Fold 1, Train Loss: 0.0144, Val Loss: 0.0157
# Epoch [753/1000] Fold 1, Train Loss: 0.0141, Val Loss: 0.0156
# Epoch [754/1000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0157
# Epoch [755/1000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0159
# Epoch [756/1000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0161
# Epoch [757/1000] Fold 1, Train Loss: 0.0141, Val Loss: 0.0159
# Epoch [758/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0159
# Epoch [759/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0156
# Epoch [760/1000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0158
# Epoch [761/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0157
# Epoch [762/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0157
# Epoch [763/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0159
# Epoch [764/1000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0155
# Epoch [765/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0154
# Epoch [766/1000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0160
# Epoch [767/1000] Fold 1, Train Loss: 0.0143, Val Loss: 0.0160
# Epoch [768/1000] Fold 1, Train Loss: 0.0140, Val Loss: 0.0159
# Epoch [769/1000] Fold 1, Train Loss: 0.0137, Val Loss: 0.0159
# Epoch [770/1000] Fold 1, Train Loss: 0.0141, Val Loss: 0.0155
# Epoch [771/1000] Fold 1, Train Loss: 0.0144, Val Loss: 0.0160
# Epoch [772/1000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0160
# Epoch [773/1000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0161
# Epoch [774/1000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0164
# Epoch [775/1000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0157
# ...
# Epoch [748/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0171
# Epoch [749/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0170
# Epoch [750/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0171
# Epoch [751/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0170
# Epoch [752/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0172
# Epoch [753/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0172
# Epoch [754/1000] Fold 10, Train Loss: 0.0147, Val Loss: 0.0170
# Epoch [755/1000] Fold 10, Train Loss: 0.0147, Val Loss: 0.0171
# Epoch [756/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0173
# Epoch [757/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0170
# Epoch [758/1000] Fold 10, Train Loss: 0.0146, Val Loss: 0.0171
# Epoch [759/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0170
# Epoch [760/1000] Fold 10, Train Loss: 0.0146, Val Loss: 0.0169
# Epoch [761/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0169
# Epoch [762/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0169
# Epoch [763/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0169
# Epoch [764/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0168
# Epoch [765/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0169
# Epoch [766/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0167
# Epoch [767/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0169
# Epoch [768/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0171
# Epoch [769/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0170
# Epoch [770/1000] Fold 10, Train Loss: 0.0148, Val Loss: 0.0173
# Epoch [771/1000] Fold 10, Train Loss: 0.0152, Val Loss: 0.0173
# Epoch [772/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0170
# Epoch [773/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0170
# Epoch [774/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0170
# Epoch [775/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0171
# Epoch [776/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0169
# Epoch [777/1000] Fold 10, Train Loss: 0.0146, Val Loss: 0.0169
# Epoch [778/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0170
# Epoch [779/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0169
# Epoch [780/1000] Fold 10, Train Loss: 0.0146, Val Loss: 0.0171
# Epoch [781/1000] Fold 10, Train Loss: 0.0148, Val Loss: 0.0170
# Epoch [782/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0170
# Epoch [783/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0171
# Epoch [784/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0170
# Epoch [785/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0170
# Epoch [786/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0171
# Epoch [787/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0170
# Epoch [788/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0169
# Epoch [789/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0172
# Epoch [790/1000] Fold 10, Train Loss: 0.0146, Val Loss: 0.0170
# Epoch [791/1000] Fold 10, Train Loss: 0.0147, Val Loss: 0.0170
# Epoch [792/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0170
# Epoch [793/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0169
# Epoch [794/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0168
# Epoch [795/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0170
# Epoch [796/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0172
# Epoch [797/1000] Fold 10, Train Loss: 0.0146, Val Loss: 0.0171
# Epoch [798/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0169
# Epoch [799/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0171
# Epoch [800/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0171
# Epoch [801/1000] Fold 10, Train Loss: 0.0149, Val Loss: 0.0173
# Epoch [802/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0175
# Epoch [803/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0173
# Epoch [804/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0172
# Epoch [805/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0174
# Epoch [806/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0172
# Epoch [807/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0175
# Epoch [808/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0173
# Epoch [809/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0173
# Epoch [810/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0170
# Epoch [811/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0172
# Epoch [812/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0172
# Epoch [813/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0171
# Epoch [814/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0170
# Epoch [815/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0173
# Epoch [816/1000] Fold 10, Train Loss: 0.0136, Val Loss: 0.0172
# Epoch [817/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0174
# Epoch [818/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0171
# Epoch [819/1000] Fold 10, Train Loss: 0.0149, Val Loss: 0.0171
# Epoch [820/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0172
# Epoch [821/1000] Fold 10, Train Loss: 0.0148, Val Loss: 0.0172
# Epoch [822/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0176
# Epoch [823/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0173
# Epoch [824/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0171
# Epoch [825/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0173
# Epoch [826/1000] Fold 10, Train Loss: 0.0152, Val Loss: 0.0172
# Epoch [827/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0171
# Epoch [828/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0173
# Epoch [829/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0173
# Epoch [830/1000] Fold 10, Train Loss: 0.0147, Val Loss: 0.0173
# Epoch [831/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0172
# Epoch [832/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0172
# Epoch [833/1000] Fold 10, Train Loss: 0.0146, Val Loss: 0.0170
# Epoch [834/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0174
# Epoch [835/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0174
# Epoch [836/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0171
# Epoch [837/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0173
# Epoch [838/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0173
# Epoch [839/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0171
# Epoch [840/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0172
# Epoch [841/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0172
# Epoch [842/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0174
# Epoch [843/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0173
# Epoch [844/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0170
# Epoch [845/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0169
# Epoch [846/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0172
# Epoch [847/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0172
# Epoch [848/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0170
# Epoch [849/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0169
# Epoch [850/1000] Fold 10, Train Loss: 0.0153, Val Loss: 0.0170
# Epoch [851/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0169
# Epoch [852/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0172
# Epoch [853/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0171
# Epoch [854/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0170
# Epoch [855/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0169
# Epoch [856/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0175
# Epoch [857/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0171
# Epoch [858/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0168
# Epoch [859/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0171
# Epoch [860/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0172
# Epoch [861/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0175
# Epoch [862/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0173
# Epoch [863/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0173
# Epoch [864/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0171
# Epoch [865/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0171
# Epoch [866/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0170
# Epoch [867/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0171
# Epoch [868/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0169
# Epoch [869/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0172
# Epoch [870/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0172
# Epoch [871/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0172
# Epoch [872/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0172
# Epoch [873/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0170
# Epoch [874/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0170
# Epoch [875/1000] Fold 10, Train Loss: 0.0148, Val Loss: 0.0172
# Epoch [876/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0171
# Epoch [877/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0175
# Epoch [878/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0171
# Epoch [879/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0172
# Epoch [880/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0170
# Epoch [881/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0170
# Epoch [882/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0169
# Epoch [883/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0170
# Epoch [884/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0170
# Epoch [885/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0171
# Epoch [886/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0169
# Epoch [887/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0169
# Epoch [888/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0172
# Epoch [889/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0173
# Epoch [890/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0172
# Epoch [891/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0170
# Epoch [892/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0169
# Epoch [893/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0169
# Epoch [894/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0170
# Epoch [895/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0169
# Epoch [896/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0172
# Epoch [897/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0173
# Epoch [898/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0171
# Epoch [899/1000] Fold 10, Train Loss: 0.0144, Val Loss: 0.0169
# Epoch [900/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0172
# Epoch [901/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0171
# Epoch [902/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0172
# Epoch [903/1000] Fold 10, Train Loss: 0.0134, Val Loss: 0.0171
# Epoch [904/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0170
# Epoch [905/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0171
# Epoch [906/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0171
# Epoch [907/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0172
# Epoch [908/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0169
# Epoch [909/1000] Fold 10, Train Loss: 0.0147, Val Loss: 0.0171
# Epoch [910/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0170
# Epoch [911/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0169
# Epoch [912/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0169
# Epoch [913/1000] Fold 10, Train Loss: 0.0135, Val Loss: 0.0169
# Epoch [914/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0169
# Epoch [915/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0170
# Epoch [916/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0171
# Epoch [917/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0170
# Epoch [918/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0171
# Epoch [919/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0171
# Epoch [920/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0171
# Epoch [921/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0169
# Epoch [922/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0170
# Epoch [923/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0171
# Epoch [924/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0170
# Epoch [925/1000] Fold 10, Train Loss: 0.0150, Val Loss: 0.0172
# Epoch [926/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0173
# Epoch [927/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0172
# Epoch [928/1000] Fold 10, Train Loss: 0.0150, Val Loss: 0.0170
# Epoch [929/1000] Fold 10, Train Loss: 0.0146, Val Loss: 0.0168
# Epoch [930/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0173
# Epoch [931/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0170
# Epoch [932/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0169
# Epoch [933/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0170
# Epoch [934/1000] Fold 10, Train Loss: 0.0145, Val Loss: 0.0170
# Epoch [935/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0169
# Epoch [936/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0169
# Epoch [937/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0168
# Epoch [938/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0170
# Epoch [939/1000] Fold 10, Train Loss: 0.0136, Val Loss: 0.0169
# Epoch [940/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0170
# Epoch [941/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0169
# Epoch [942/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0168
# Epoch [943/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0168
# Epoch [944/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0169
# Epoch [945/1000] Fold 10, Train Loss: 0.0133, Val Loss: 0.0169
# Epoch [946/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0170
# Epoch [947/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0169
# Epoch [948/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0169
# Epoch [949/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0171
# Epoch [950/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0171
# Epoch [951/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0171
# Epoch [952/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0167
# Epoch [953/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0169
# Epoch [954/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0169
# Epoch [955/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0170
# Epoch [956/1000] Fold 10, Train Loss: 0.0136, Val Loss: 0.0169
# Epoch [957/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0169
# Epoch [958/1000] Fold 10, Train Loss: 0.0133, Val Loss: 0.0169
# Epoch [959/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0172
# Epoch [960/1000] Fold 10, Train Loss: 0.0133, Val Loss: 0.0170
# Epoch [961/1000] Fold 10, Train Loss: 0.0133, Val Loss: 0.0170
# Epoch [962/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0169
# Epoch [963/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0169
# Epoch [964/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0168
# Epoch [965/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0169
# Epoch [966/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0171
# Epoch [967/1000] Fold 10, Train Loss: 0.0135, Val Loss: 0.0169
# Epoch [968/1000] Fold 10, Train Loss: 0.0135, Val Loss: 0.0166
# Epoch [969/1000] Fold 10, Train Loss: 0.0142, Val Loss: 0.0168
# Epoch [970/1000] Fold 10, Train Loss: 0.0135, Val Loss: 0.0170
# Epoch [971/1000] Fold 10, Train Loss: 0.0136, Val Loss: 0.0170
# Epoch [972/1000] Fold 10, Train Loss: 0.0135, Val Loss: 0.0167
# Epoch [973/1000] Fold 10, Train Loss: 0.0133, Val Loss: 0.0169
# Epoch [974/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0167
# Epoch [975/1000] Fold 10, Train Loss: 0.0134, Val Loss: 0.0170
# Epoch [976/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0166
# Epoch [977/1000] Fold 10, Train Loss: 0.0136, Val Loss: 0.0168
# Epoch [978/1000] Fold 10, Train Loss: 0.0143, Val Loss: 0.0168
# Epoch [979/1000] Fold 10, Train Loss: 0.0135, Val Loss: 0.0170
# Epoch [980/1000] Fold 10, Train Loss: 0.0134, Val Loss: 0.0169
# Epoch [981/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0172
# Epoch [982/1000] Fold 10, Train Loss: 0.0141, Val Loss: 0.0172
# Epoch [983/1000] Fold 10, Train Loss: 0.0136, Val Loss: 0.0168
# Epoch [984/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0169
# Epoch [985/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0167
# Epoch [986/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0169
# Epoch [987/1000] Fold 10, Train Loss: 0.0149, Val Loss: 0.0170
# Epoch [988/1000] Fold 10, Train Loss: 0.0136, Val Loss: 0.0169
# Epoch [989/1000] Fold 10, Train Loss: 0.0137, Val Loss: 0.0169
# Epoch [990/1000] Fold 10, Train Loss: 0.0134, Val Loss: 0.0168
# Epoch [991/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0168
# Epoch [992/1000] Fold 10, Train Loss: 0.0139, Val Loss: 0.0168
# Epoch [993/1000] Fold 10, Train Loss: 0.0136, Val Loss: 0.0168
# Epoch [994/1000] Fold 10, Train Loss: 0.0133, Val Loss: 0.0169
# Epoch [995/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0169
# Epoch [996/1000] Fold 10, Train Loss: 0.0146, Val Loss: 0.0169
# Epoch [997/1000] Fold 10, Train Loss: 0.0138, Val Loss: 0.0171
# Epoch [998/1000] Fold 10, Train Loss: 0.0140, Val Loss: 0.0170
# Epoch [999/1000] Fold 10, Train Loss: 0.0133, Val Loss: 0.0171
# Epoch [1000/1000] Fold 10, Train Loss: 0.0136, Val Loss: 0.0171

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.0200

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.0152
#   Corresponding Training Loss = 0.0153
#   Best Epoch = 538
# Fold 2:
#   Best Validation Loss = 0.0141
#   Corresponding Training Loss = 0.0156
#   Best Epoch = 520
# Fold 3:
#   Best Validation Loss = 0.0182
#   Corresponding Training Loss = 0.0147
#   Best Epoch = 611
# Fold 4:
#   Best Validation Loss = 0.0160
#   Corresponding Training Loss = 0.0154
#   Best Epoch = 873
# Fold 5:
#   Best Validation Loss = 0.0383
#   Corresponding Training Loss = 0.0136
#   Best Epoch = 967
# Fold 6:
#   Best Validation Loss = 0.0187
#   Corresponding Training Loss = 0.0156
#   Best Epoch = 604
# Fold 7:
#   Best Validation Loss = 0.0213
#   Corresponding Training Loss = 0.0164
#   Best Epoch = 338
# Fold 8:
#   Best Validation Loss = 0.0138
#   Corresponding Training Loss = 0.0138
#   Best Epoch = 685
# Fold 9:
#   Best Validation Loss = 0.0166
#   Corresponding Training Loss = 0.0157
#   Best Epoch = 551
# Fold 10:
#   Best Validation Loss = 0.0166
#   Corresponding Training Loss = 0.0138
#   Best Epoch = 976

# %%
def plot_loss_curves_separately(cv_histories):
    """
    Plot training and validation loss curves for each fold in separate figures.
    
    Args:
        cv_histories (list): List of loss histories for each fold.
    """
    # Plot Training Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['train_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
    plt.title('Training Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['val_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
    plt.title('Validation Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_loss_curves_separately(cv_histories)

# %%
import torch
import numpy as np

# Track the best validation loss across all folds
lowest_val_loss = float('inf')
best_model_idx = -1  # Index of the best model
best_model_state = None

# Find the fold with the lowest validation loss
for fold_idx, history in enumerate(cv_histories):
    # Get the best validation loss for this fold
    best_val_loss = min(history['val_loss'])
    
    # Check if this is the lowest validation loss across all folds
    if best_val_loss < lowest_val_loss:
        lowest_val_loss = best_val_loss
        best_model_idx = fold_idx
        best_model_state = best_models[fold_idx]

# Save the model with the lowest validation loss
if best_model_state is not None:
    save_path = f'bestmodel_ex_{best_model_idx + 1}.pth'
    torch.save(best_model_state, save_path)
    print(f"Model from fold {best_model_idx + 1} with the lowest validation loss ({lowest_val_loss:.4f}) saved to {save_path}.")
else:
    print("No model to save.")
# Out:
# Model from fold 8 with the lowest validation loss (0.0138) saved to bestmodel_ex_8.pth.

# %%
s
