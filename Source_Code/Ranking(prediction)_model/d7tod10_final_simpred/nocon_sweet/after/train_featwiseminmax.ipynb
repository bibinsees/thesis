# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import tifffile as tiff
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
from copy import deepcopy
import random

# %%
# Load the saved day 7 features
combined_ex7 = torch.load('combined_ex7.pt')

# Load the saved day 10 features
combined_ex10 = torch.load('combined_ex10.pt')
# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_ex7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_ex10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([646, 20])
# Loaded Day 10 Features Shape: torch.Size([646, 20])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_1756\1356550951.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_ex7 = torch.load('combined_ex7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_1756\1356550951.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_ex10 = torch.load('combined_ex10.pt')

# %%
# Load the saved day 7 features
combined_cond7 = torch.load('combined_cond7.pt')

# Load the saved day 10 features
combined_cond10 = torch.load('combined_cond10.pt')
# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_cond7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_cond10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([650, 20])
# Loaded Day 10 Features Shape: torch.Size([650, 20])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_1756\3329391658.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_cond7 = torch.load('combined_cond7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_1756\3329391658.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_cond10 = torch.load('combined_cond10.pt')

# %%
# Load the saved day 7 features
combined_sd7 = torch.load('combined_sd7.pt')

# Load the saved day 10 features
combined_sd10 = torch.load('combined_sd10.pt')

# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_sd7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_sd10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([638, 20])
# Loaded Day 10 Features Shape: torch.Size([638, 20])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_1756\1607657786.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_sd7 = torch.load('combined_sd7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_1756\1607657786.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_sd10 = torch.load('combined_sd10.pt')

# %%
train_day7_feats = combined_cond7 
train_day10_feats = combined_cond10

# %%
train_day7_feats = combined_sd7 
train_day10_feats = combined_sd10

# %%
train_day7_feats = combined_ex7 
train_day10_feats = combined_ex10

# %%
train_day7_feats.shape

# %%
type(train_day7_feats)

# %%
train_day7_feats[0].shape

# %%
import matplotlib.pyplot as plt

# Plot histograms for input (X) and target (Y)
plt.figure(figsize=(12, 6))

# Flatten tensors to 1D for easier visualization
train_day7_feats_flat = train_day7_feats.flatten().cpu().numpy()
train_day10_feats_flat = train_day10_feats.flatten().cpu().numpy()

# Input (X) histogram
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_flat, bins=50, color='blue', alpha=0.7, label='Input (X)')
plt.title('Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_flat, bins=50, color='green', alpha=0.7, label='Target (Y)')
plt.title('Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"Input (X): Mean={train_day7_feats.mean():.4f}, Std={train_day7_feats.std():.4f}")
print(f"Target (Y): Mean={train_day10_feats.mean():.4f}, Std={train_day10_feats.std():.4f}")
# Out:
# Input (X): Mean=-0.0338, Std=1.8610
# Target (Y): Mean=-0.3385, Std=1.5468

# %%
# Convert PyTorch tensor to NumPy array
train_day7_feats_numpy = train_day7_feats.numpy()
train_day10_feats_numpy = train_day10_feats.numpy()

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize separate MinMaxScaler for day7 and day10
scaler_day7 = MinMaxScaler()
scaler_day10 = MinMaxScaler()

# Fit and transform the train_day7_feats
train_day7_feats_minmaxed = scaler_day7.fit_transform(train_day7_feats_numpy)
print(train_day7_feats_minmaxed.shape)
# Get min and max values for day7
min_values_day7 = scaler_day7.data_min_
max_values_day7 = scaler_day7.data_max_

print(min_values_day7.shape)
print(max_values_day7.shape)
#print("Min values for day7:", min_values_day7)
#print("Max values for day7:", max_values_day7)

# Fit and transform the train_day10_feats (target)
train_day10_feats_minmaxed = scaler_day10.fit_transform(train_day10_feats_numpy)
print(train_day10_feats_minmaxed.shape)
# Get min and max values for day10
min_values_day10 = scaler_day10.data_min_
max_values_day10 = scaler_day10.data_max_

print(min_values_day10.shape)
print(max_values_day10.shape)
#print("Min values for day10:", min_values_day10)
#print("Max values for day10:", max_values_day10)

# Convert the scaled data back to PyTorch tensors (optional)
train_day7_feats_minmaxed = torch.tensor(train_day7_feats_minmaxed)
train_day10_feats_minmaxed = torch.tensor(train_day10_feats_minmaxed)
# Out:
# (646, 20)
# (20,)
# (20,)
# (646, 20)
# (20,)
# (20,)

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'ex7.pkl')
joblib.dump(scaler_day10, 'ex10.pkl')

print("Scalers saved!")
# Out:
# Scalers saved!

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'sd7.pkl')
joblib.dump(scaler_day10, 'sd10.pkl')

print("Scalers saved!")

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'cond7.pkl')
joblib.dump(scaler_day10, 'cond10.pkl')

print("Scalers saved!")

# %%
type(train_day7_feats_minmaxed)

# %%
import matplotlib.pyplot as plt

# Flatten the tensors for easier visualization
train_day7_feats_minmaxed_flat = train_day7_feats_minmaxed.flatten().cpu().numpy()
train_day10_feats_minmaxed_flat = train_day10_feats_minmaxed.flatten().cpu().numpy()

# Plot histograms
plt.figure(figsize=(12, 6))

# Input (X) histogram after Min-Max scaling
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_minmaxed_flat, bins=50, color='blue', alpha=0.7, label='Min-Max Scaled Input (X)')
plt.title('Min-Max Scaled Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram after Min-Max scaling
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_minmaxed_flat, bins=50, color='green', alpha=0.7, label='Min-Max Scaled Target (Y)')
plt.title('Min-Max Scaled Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import torch
import torch.nn as nn

class FeaturePredictor(nn.Module):
    def __init__(self, input_size=20, output_size=20):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_size, 16),
            nn.BatchNorm1d(16),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(16, 8),
            nn.BatchNorm1d(8),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(8, 4),
            nn.BatchNorm1d(4),
        )
        self.decoder = nn.Sequential(
            nn.Linear(4, 8),
            nn.BatchNorm1d(8),
            nn.ReLU(),
            nn.Linear(8, 16),
            nn.BatchNorm1d(16),
            nn.ReLU(),
            nn.Linear(16, output_size)
        )
    
    def forward(self, x):
        x = self.encoder(x)
        z = self.decoder(x)
        return z

# Example usage
model = FeaturePredictor()
print(model)
# Out:
# FeaturePredictor(
#   (encoder): Sequential(
#     (0): Linear(in_features=20, out_features=16, bias=True)
#     (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=16, out_features=8, bias=True)
#     (5): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.3, inplace=False)
#     (8): Linear(in_features=8, out_features=4, bias=True)
#     (9): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=4, out_features=8, bias=True)
#     (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=8, out_features=16, bias=True)
#     (4): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Linear(in_features=16, out_features=20, bias=True)
#   )
# )

# %% [markdown]
# class FeaturePredictor(nn.Module):
#     def __init__(self, input_size=512, output_size=512):
#         super().__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_size, 256),
#             nn.BatchNorm1d(256),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(256, 64),
#             nn.BatchNorm1d(64),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(64, 16),
#             nn.BatchNorm1d(16),
#         )
#         self.decoder = nn.Sequential(
#             nn.Linear(16, 64),
#             nn.BatchNorm1d(64),
#             nn.ReLU(),
#             nn.Linear(64, 256),
#             nn.BatchNorm1d(256),
#             nn.ReLU(),
#             nn.Linear(256, output_size)
#         )
#
#     # Corrected indentation for forward method
#     def forward(self, x):
#         x = self.encoder(x)
#         z = self.decoder(x)
#         return z

# %% [markdown]
# import torch.nn as nn
# from torch.utils.data import TensorDataset, DataLoader
#
# class FeaturePredictor(nn.Module):
#     def __init__(self, input_size=512, output_size=512):
#         super(FeaturePredictor, self).__init__()
#         self.model = nn.Sequential(
#             nn.Linear(input_size, 256),
#             nn.ReLU(),
#             nn.Linear(256, 128),
#             nn.ReLU(),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Linear(64, 32),
#             nn.ReLU(),
#             nn.Linear(32, 16),
#             nn.ReLU(),
#             nn.Linear(16,8),
#             nn.ReLU(),
#             nn.Linear(8, 16),
#             nn.ReLU(),
#             nn.Linear(16,32),
#             nn.ReLU(),
#             nn.Linear(32, 64),
#             nn.ReLU(),
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Linear(128,256),
#             nn.ReLU(),
#             nn.Linear(256, output_size)
#         )
#
#     def forward(self, x):
#         return self.model(x)

# %%
model = FeaturePredictor()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset

# %%
from torch.utils.data import TensorDataset

optimizer_class = torch.optim.Adam

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset
import numpy as np
import torch

# %%
class EarlyStopping:
    def __init__(self, patience=10, delta=0.0):
        """
        Args:
            patience (int): How many epochs to wait after the last validation loss improvement.
            delta (float): Minimum change in the validation loss to qualify as an improvement.
        """
        self.patience = patience
        self.delta = delta
        self.best_loss = None
        self.no_improvement_epochs = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.no_improvement_epochs = 0
        else:
            self.no_improvement_epochs += 1
            if self.no_improvement_epochs >= self.patience:
                self.early_stop = True


def cross_validate_with_early_stopping(
    model_class, dataset, criterion, optimizer_class, num_epochs=50, n_splits=10, patience=10, device='cuda'
):
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    histories = []
    best_models = []

    for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset)):
        print(f"Fold {fold + 1}/{n_splits}")

        # Create subsets for this fold
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        # Create DataLoaders
        train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

        # Initialize the model, optimizer, and early stopping for this fold
        model = model_class().to(device)
        optimizer = optimizer_class(model.parameters(), lr=1e-4)
        early_stopping = EarlyStopping(patience=patience)

        # Training and validation loop
        history = {'train_loss': [], 'val_loss': []}
        for epoch in range(num_epochs):
            # Training phase
            model.train()
            train_loss = 0.0
            for batch_inputs, batch_targets in train_loader:
                batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)

                # Forward pass
                outputs = model(batch_inputs)
                loss = criterion(outputs, batch_targets)
                train_loss += loss.item()

                # Backward pass and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            train_loss /= len(train_loader)
            history['train_loss'].append(train_loss)

            # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for batch_inputs, batch_targets in val_loader:
                    batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)
                    outputs = model(batch_inputs)
                    loss = criterion(outputs, batch_targets)
                    val_loss += loss.item()

            val_loss /= len(val_loader)
            history['val_loss'].append(val_loss)

            print(f"Epoch [{epoch + 1}/{num_epochs}] Fold {fold + 1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

            # Check early stopping
            early_stopping(val_loss)
            if early_stopping.early_stop:
                print(f"Early stopping at epoch {epoch + 1} for fold {fold + 1}")
                break

        # Save the best model for this fold
        best_models.append(model.state_dict())
        histories.append(history)

    return histories, best_models

# %%
# MIN MAX
dataset = TensorDataset(train_day7_feats_minmaxed, train_day10_feats_minmaxed)

cv_histories, best_models = cross_validate_with_early_stopping(
    model_class=FeaturePredictor,
    dataset=dataset,
    criterion=nn.MSELoss(),
    optimizer_class=torch.optim.Adam,
    num_epochs=1000,
    patience=500
)
# Out:
# Fold 1/10
# Epoch [1/1000] Fold 1, Train Loss: 0.4168, Val Loss: 0.2556
# Epoch [2/1000] Fold 1, Train Loss: 0.4023, Val Loss: 0.2526
# Epoch [3/1000] Fold 1, Train Loss: 0.3849, Val Loss: 0.2668
# Epoch [4/1000] Fold 1, Train Loss: 0.3717, Val Loss: 0.2702
# Epoch [5/1000] Fold 1, Train Loss: 0.3609, Val Loss: 0.2663
# Epoch [6/1000] Fold 1, Train Loss: 0.3404, Val Loss: 0.2506
# Epoch [7/1000] Fold 1, Train Loss: 0.3356, Val Loss: 0.2499
# Epoch [8/1000] Fold 1, Train Loss: 0.3158, Val Loss: 0.2392
# Epoch [9/1000] Fold 1, Train Loss: 0.3114, Val Loss: 0.2338
# Epoch [10/1000] Fold 1, Train Loss: 0.3008, Val Loss: 0.2292
# Epoch [11/1000] Fold 1, Train Loss: 0.2846, Val Loss: 0.2211
# Epoch [12/1000] Fold 1, Train Loss: 0.2793, Val Loss: 0.2214
# Epoch [13/1000] Fold 1, Train Loss: 0.2722, Val Loss: 0.2089
# Epoch [14/1000] Fold 1, Train Loss: 0.2587, Val Loss: 0.2017
# Epoch [15/1000] Fold 1, Train Loss: 0.2534, Val Loss: 0.1939
# Epoch [16/1000] Fold 1, Train Loss: 0.2387, Val Loss: 0.1855
# Epoch [17/1000] Fold 1, Train Loss: 0.2340, Val Loss: 0.1801
# Epoch [18/1000] Fold 1, Train Loss: 0.2259, Val Loss: 0.1786
# Epoch [19/1000] Fold 1, Train Loss: 0.2167, Val Loss: 0.1721
# Epoch [20/1000] Fold 1, Train Loss: 0.2090, Val Loss: 0.1666
# Epoch [21/1000] Fold 1, Train Loss: 0.2067, Val Loss: 0.1651
# Epoch [22/1000] Fold 1, Train Loss: 0.1988, Val Loss: 0.1614
# Epoch [23/1000] Fold 1, Train Loss: 0.1915, Val Loss: 0.1559
# Epoch [24/1000] Fold 1, Train Loss: 0.1887, Val Loss: 0.1512
# Epoch [25/1000] Fold 1, Train Loss: 0.1817, Val Loss: 0.1470
# Epoch [26/1000] Fold 1, Train Loss: 0.1750, Val Loss: 0.1439
# Epoch [27/1000] Fold 1, Train Loss: 0.1703, Val Loss: 0.1399
# Epoch [28/1000] Fold 1, Train Loss: 0.1626, Val Loss: 0.1381
# Epoch [29/1000] Fold 1, Train Loss: 0.1582, Val Loss: 0.1318
# Epoch [30/1000] Fold 1, Train Loss: 0.1579, Val Loss: 0.1288
# Epoch [31/1000] Fold 1, Train Loss: 0.1530, Val Loss: 0.1236
# Epoch [32/1000] Fold 1, Train Loss: 0.1465, Val Loss: 0.1200
# Epoch [33/1000] Fold 1, Train Loss: 0.1440, Val Loss: 0.1189
# Epoch [34/1000] Fold 1, Train Loss: 0.1351, Val Loss: 0.1137
# Epoch [35/1000] Fold 1, Train Loss: 0.1333, Val Loss: 0.1088
# Epoch [36/1000] Fold 1, Train Loss: 0.1275, Val Loss: 0.1056
# Epoch [37/1000] Fold 1, Train Loss: 0.1280, Val Loss: 0.1074
# Epoch [38/1000] Fold 1, Train Loss: 0.1215, Val Loss: 0.1023
# Epoch [39/1000] Fold 1, Train Loss: 0.1210, Val Loss: 0.1021
# Epoch [40/1000] Fold 1, Train Loss: 0.1155, Val Loss: 0.0959
# Epoch [41/1000] Fold 1, Train Loss: 0.1153, Val Loss: 0.0951
# Epoch [42/1000] Fold 1, Train Loss: 0.1100, Val Loss: 0.0917
# Epoch [43/1000] Fold 1, Train Loss: 0.1076, Val Loss: 0.0917
# Epoch [44/1000] Fold 1, Train Loss: 0.1068, Val Loss: 0.0878
# Epoch [45/1000] Fold 1, Train Loss: 0.1020, Val Loss: 0.0875
# Epoch [46/1000] Fold 1, Train Loss: 0.0990, Val Loss: 0.0850
# Epoch [47/1000] Fold 1, Train Loss: 0.0983, Val Loss: 0.0834
# Epoch [48/1000] Fold 1, Train Loss: 0.0970, Val Loss: 0.0825
# Epoch [49/1000] Fold 1, Train Loss: 0.0940, Val Loss: 0.0802
# Epoch [50/1000] Fold 1, Train Loss: 0.0904, Val Loss: 0.0800
# Epoch [51/1000] Fold 1, Train Loss: 0.0886, Val Loss: 0.0762
# Epoch [52/1000] Fold 1, Train Loss: 0.0865, Val Loss: 0.0755
# Epoch [53/1000] Fold 1, Train Loss: 0.0858, Val Loss: 0.0748
# Epoch [54/1000] Fold 1, Train Loss: 0.0855, Val Loss: 0.0735
# Epoch [55/1000] Fold 1, Train Loss: 0.0859, Val Loss: 0.0729
# Epoch [56/1000] Fold 1, Train Loss: 0.0823, Val Loss: 0.0717
# Epoch [57/1000] Fold 1, Train Loss: 0.0834, Val Loss: 0.0696
# Epoch [58/1000] Fold 1, Train Loss: 0.0820, Val Loss: 0.0700
# Epoch [59/1000] Fold 1, Train Loss: 0.0786, Val Loss: 0.0678
# Epoch [60/1000] Fold 1, Train Loss: 0.0773, Val Loss: 0.0691
# Epoch [61/1000] Fold 1, Train Loss: 0.0760, Val Loss: 0.0666
# Epoch [62/1000] Fold 1, Train Loss: 0.0752, Val Loss: 0.0659
# Epoch [63/1000] Fold 1, Train Loss: 0.0733, Val Loss: 0.0654
# Epoch [64/1000] Fold 1, Train Loss: 0.0711, Val Loss: 0.0641
# Epoch [65/1000] Fold 1, Train Loss: 0.0718, Val Loss: 0.0633
# Epoch [66/1000] Fold 1, Train Loss: 0.0692, Val Loss: 0.0618
# Epoch [67/1000] Fold 1, Train Loss: 0.0713, Val Loss: 0.0612
# Epoch [68/1000] Fold 1, Train Loss: 0.0693, Val Loss: 0.0613
# Epoch [69/1000] Fold 1, Train Loss: 0.0675, Val Loss: 0.0605
# Epoch [70/1000] Fold 1, Train Loss: 0.0677, Val Loss: 0.0596
# Epoch [71/1000] Fold 1, Train Loss: 0.0653, Val Loss: 0.0605
# Epoch [72/1000] Fold 1, Train Loss: 0.0665, Val Loss: 0.0592
# Epoch [73/1000] Fold 1, Train Loss: 0.0648, Val Loss: 0.0583
# Epoch [74/1000] Fold 1, Train Loss: 0.0617, Val Loss: 0.0575
# Epoch [75/1000] Fold 1, Train Loss: 0.0659, Val Loss: 0.0582
# Epoch [76/1000] Fold 1, Train Loss: 0.0650, Val Loss: 0.0575
# Epoch [77/1000] Fold 1, Train Loss: 0.0637, Val Loss: 0.0561
# Epoch [78/1000] Fold 1, Train Loss: 0.0606, Val Loss: 0.0560
# Epoch [79/1000] Fold 1, Train Loss: 0.0614, Val Loss: 0.0569
# Epoch [80/1000] Fold 1, Train Loss: 0.0605, Val Loss: 0.0549
# Epoch [81/1000] Fold 1, Train Loss: 0.0597, Val Loss: 0.0540
# Epoch [82/1000] Fold 1, Train Loss: 0.0638, Val Loss: 0.0548
# Epoch [83/1000] Fold 1, Train Loss: 0.0607, Val Loss: 0.0539
# Epoch [84/1000] Fold 1, Train Loss: 0.0584, Val Loss: 0.0539
# Epoch [85/1000] Fold 1, Train Loss: 0.0585, Val Loss: 0.0524
# Epoch [86/1000] Fold 1, Train Loss: 0.0600, Val Loss: 0.0532
# Epoch [87/1000] Fold 1, Train Loss: 0.0610, Val Loss: 0.0518
# Epoch [88/1000] Fold 1, Train Loss: 0.0572, Val Loss: 0.0521
# Epoch [89/1000] Fold 1, Train Loss: 0.0577, Val Loss: 0.0519
# Epoch [90/1000] Fold 1, Train Loss: 0.0559, Val Loss: 0.0513
# Epoch [91/1000] Fold 1, Train Loss: 0.0569, Val Loss: 0.0522
# Epoch [92/1000] Fold 1, Train Loss: 0.0581, Val Loss: 0.0516
# Epoch [93/1000] Fold 1, Train Loss: 0.0549, Val Loss: 0.0514
# Epoch [94/1000] Fold 1, Train Loss: 0.0559, Val Loss: 0.0515
# Epoch [95/1000] Fold 1, Train Loss: 0.0551, Val Loss: 0.0515
# Epoch [96/1000] Fold 1, Train Loss: 0.0579, Val Loss: 0.0512
# Epoch [97/1000] Fold 1, Train Loss: 0.0550, Val Loss: 0.0506
# Epoch [98/1000] Fold 1, Train Loss: 0.0545, Val Loss: 0.0502
# Epoch [99/1000] Fold 1, Train Loss: 0.0553, Val Loss: 0.0507
# Epoch [100/1000] Fold 1, Train Loss: 0.0555, Val Loss: 0.0496
# Epoch [101/1000] Fold 1, Train Loss: 0.0559, Val Loss: 0.0500
# Epoch [102/1000] Fold 1, Train Loss: 0.0540, Val Loss: 0.0496
# Epoch [103/1000] Fold 1, Train Loss: 0.0536, Val Loss: 0.0495
# Epoch [104/1000] Fold 1, Train Loss: 0.0533, Val Loss: 0.0501
# Epoch [105/1000] Fold 1, Train Loss: 0.0543, Val Loss: 0.0509
# Epoch [106/1000] Fold 1, Train Loss: 0.0533, Val Loss: 0.0498
# Epoch [107/1000] Fold 1, Train Loss: 0.0538, Val Loss: 0.0497
# Epoch [108/1000] Fold 1, Train Loss: 0.0530, Val Loss: 0.0487
# Epoch [109/1000] Fold 1, Train Loss: 0.0563, Val Loss: 0.0494
# Epoch [110/1000] Fold 1, Train Loss: 0.0498, Val Loss: 0.0487
# Epoch [111/1000] Fold 1, Train Loss: 0.0528, Val Loss: 0.0480
# Epoch [112/1000] Fold 1, Train Loss: 0.0522, Val Loss: 0.0494
# Epoch [113/1000] Fold 1, Train Loss: 0.0524, Val Loss: 0.0488
# Epoch [114/1000] Fold 1, Train Loss: 0.0531, Val Loss: 0.0491
# Epoch [115/1000] Fold 1, Train Loss: 0.0537, Val Loss: 0.0478
# Epoch [116/1000] Fold 1, Train Loss: 0.0521, Val Loss: 0.0488
# Epoch [117/1000] Fold 1, Train Loss: 0.0531, Val Loss: 0.0486
# Epoch [118/1000] Fold 1, Train Loss: 0.0503, Val Loss: 0.0485
# Epoch [119/1000] Fold 1, Train Loss: 0.0517, Val Loss: 0.0484
# Epoch [120/1000] Fold 1, Train Loss: 0.0510, Val Loss: 0.0494
# Epoch [121/1000] Fold 1, Train Loss: 0.0516, Val Loss: 0.0482
# Epoch [122/1000] Fold 1, Train Loss: 0.0511, Val Loss: 0.0484
# Epoch [123/1000] Fold 1, Train Loss: 0.0498, Val Loss: 0.0477
# Epoch [124/1000] Fold 1, Train Loss: 0.0511, Val Loss: 0.0477
# Epoch [125/1000] Fold 1, Train Loss: 0.0517, Val Loss: 0.0480
# Epoch [126/1000] Fold 1, Train Loss: 0.0519, Val Loss: 0.0484
# Epoch [127/1000] Fold 1, Train Loss: 0.0508, Val Loss: 0.0482
# Epoch [128/1000] Fold 1, Train Loss: 0.0521, Val Loss: 0.0487
# Epoch [129/1000] Fold 1, Train Loss: 0.0508, Val Loss: 0.0487
# Epoch [130/1000] Fold 1, Train Loss: 0.0521, Val Loss: 0.0482
# Epoch [131/1000] Fold 1, Train Loss: 0.0495, Val Loss: 0.0480
# Epoch [132/1000] Fold 1, Train Loss: 0.0502, Val Loss: 0.0482
# Epoch [133/1000] Fold 1, Train Loss: 0.0502, Val Loss: 0.0482
# Epoch [134/1000] Fold 1, Train Loss: 0.0515, Val Loss: 0.0490
# Epoch [135/1000] Fold 1, Train Loss: 0.0504, Val Loss: 0.0475
# Epoch [136/1000] Fold 1, Train Loss: 0.0509, Val Loss: 0.0478
# Epoch [137/1000] Fold 1, Train Loss: 0.0488, Val Loss: 0.0474
# Epoch [138/1000] Fold 1, Train Loss: 0.0491, Val Loss: 0.0487
# Epoch [139/1000] Fold 1, Train Loss: 0.0495, Val Loss: 0.0478
# Epoch [140/1000] Fold 1, Train Loss: 0.0476, Val Loss: 0.0474
# Epoch [141/1000] Fold 1, Train Loss: 0.0497, Val Loss: 0.0477
# Epoch [142/1000] Fold 1, Train Loss: 0.0488, Val Loss: 0.0482
# Epoch [143/1000] Fold 1, Train Loss: 0.0498, Val Loss: 0.0476
# Epoch [144/1000] Fold 1, Train Loss: 0.0484, Val Loss: 0.0474
# Epoch [145/1000] Fold 1, Train Loss: 0.0481, Val Loss: 0.0483
# Epoch [146/1000] Fold 1, Train Loss: 0.0476, Val Loss: 0.0476
# Epoch [147/1000] Fold 1, Train Loss: 0.0490, Val Loss: 0.0482
# Epoch [148/1000] Fold 1, Train Loss: 0.0492, Val Loss: 0.0479
# Epoch [149/1000] Fold 1, Train Loss: 0.0491, Val Loss: 0.0471
# Epoch [150/1000] Fold 1, Train Loss: 0.0497, Val Loss: 0.0468
# Epoch [151/1000] Fold 1, Train Loss: 0.0504, Val Loss: 0.0479
# Epoch [152/1000] Fold 1, Train Loss: 0.0487, Val Loss: 0.0477
# Epoch [153/1000] Fold 1, Train Loss: 0.0491, Val Loss: 0.0475
# Epoch [154/1000] Fold 1, Train Loss: 0.0470, Val Loss: 0.0470
# Epoch [155/1000] Fold 1, Train Loss: 0.0488, Val Loss: 0.0479
# Epoch [156/1000] Fold 1, Train Loss: 0.0494, Val Loss: 0.0475
# Epoch [157/1000] Fold 1, Train Loss: 0.0502, Val Loss: 0.0484
# Epoch [158/1000] Fold 1, Train Loss: 0.0496, Val Loss: 0.0477
# Epoch [159/1000] Fold 1, Train Loss: 0.0476, Val Loss: 0.0476
# Epoch [160/1000] Fold 1, Train Loss: 0.0462, Val Loss: 0.0464
# Epoch [161/1000] Fold 1, Train Loss: 0.0479, Val Loss: 0.0478
# Epoch [162/1000] Fold 1, Train Loss: 0.0481, Val Loss: 0.0486
# Epoch [163/1000] Fold 1, Train Loss: 0.0486, Val Loss: 0.0481
# Epoch [164/1000] Fold 1, Train Loss: 0.0494, Val Loss: 0.0484
# Epoch [165/1000] Fold 1, Train Loss: 0.0479, Val Loss: 0.0478
# Epoch [166/1000] Fold 1, Train Loss: 0.0485, Val Loss: 0.0474
# Epoch [167/1000] Fold 1, Train Loss: 0.0474, Val Loss: 0.0474
# Epoch [168/1000] Fold 1, Train Loss: 0.0483, Val Loss: 0.0477
# Epoch [169/1000] Fold 1, Train Loss: 0.0472, Val Loss: 0.0471
# Epoch [170/1000] Fold 1, Train Loss: 0.0483, Val Loss: 0.0470
# Epoch [171/1000] Fold 1, Train Loss: 0.0481, Val Loss: 0.0471
# Epoch [172/1000] Fold 1, Train Loss: 0.0473, Val Loss: 0.0474
# Epoch [173/1000] Fold 1, Train Loss: 0.0485, Val Loss: 0.0483
# Epoch [174/1000] Fold 1, Train Loss: 0.0465, Val Loss: 0.0473
# Epoch [175/1000] Fold 1, Train Loss: 0.0475, Val Loss: 0.0469
# Epoch [176/1000] Fold 1, Train Loss: 0.0486, Val Loss: 0.0476
# Epoch [177/1000] Fold 1, Train Loss: 0.0483, Val Loss: 0.0474
# Epoch [178/1000] Fold 1, Train Loss: 0.0473, Val Loss: 0.0473
# Epoch [179/1000] Fold 1, Train Loss: 0.0468, Val Loss: 0.0474
# Epoch [180/1000] Fold 1, Train Loss: 0.0461, Val Loss: 0.0469
# Epoch [181/1000] Fold 1, Train Loss: 0.0484, Val Loss: 0.0478
# Epoch [182/1000] Fold 1, Train Loss: 0.0463, Val Loss: 0.0477
# Epoch [183/1000] Fold 1, Train Loss: 0.0470, Val Loss: 0.0481
# Epoch [184/1000] Fold 1, Train Loss: 0.0472, Val Loss: 0.0474
# Epoch [185/1000] Fold 1, Train Loss: 0.0469, Val Loss: 0.0479
# Epoch [186/1000] Fold 1, Train Loss: 0.0453, Val Loss: 0.0474
# Epoch [187/1000] Fold 1, Train Loss: 0.0463, Val Loss: 0.0475
# Epoch [188/1000] Fold 1, Train Loss: 0.0470, Val Loss: 0.0482
# Epoch [189/1000] Fold 1, Train Loss: 0.0471, Val Loss: 0.0481
# Epoch [190/1000] Fold 1, Train Loss: 0.0472, Val Loss: 0.0481
# Epoch [191/1000] Fold 1, Train Loss: 0.0465, Val Loss: 0.0478
# Epoch [192/1000] Fold 1, Train Loss: 0.0455, Val Loss: 0.0472
# Epoch [193/1000] Fold 1, Train Loss: 0.0470, Val Loss: 0.0470
# Epoch [194/1000] Fold 1, Train Loss: 0.0454, Val Loss: 0.0474
# Epoch [195/1000] Fold 1, Train Loss: 0.0454, Val Loss: 0.0467
# Epoch [196/1000] Fold 1, Train Loss: 0.0463, Val Loss: 0.0471
# Epoch [197/1000] Fold 1, Train Loss: 0.0472, Val Loss: 0.0474
# Epoch [198/1000] Fold 1, Train Loss: 0.0466, Val Loss: 0.0464
# Epoch [199/1000] Fold 1, Train Loss: 0.0460, Val Loss: 0.0470
# Epoch [200/1000] Fold 1, Train Loss: 0.0472, Val Loss: 0.0475
# Epoch [201/1000] Fold 1, Train Loss: 0.0467, Val Loss: 0.0475
# Epoch [202/1000] Fold 1, Train Loss: 0.0455, Val Loss: 0.0471
# Epoch [203/1000] Fold 1, Train Loss: 0.0478, Val Loss: 0.0474
# Epoch [204/1000] Fold 1, Train Loss: 0.0468, Val Loss: 0.0468
# Epoch [205/1000] Fold 1, Train Loss: 0.0454, Val Loss: 0.0466
# Epoch [206/1000] Fold 1, Train Loss: 0.0462, Val Loss: 0.0472
# Epoch [207/1000] Fold 1, Train Loss: 0.0465, Val Loss: 0.0468
# Epoch [208/1000] Fold 1, Train Loss: 0.0465, Val Loss: 0.0465
# Epoch [209/1000] Fold 1, Train Loss: 0.0454, Val Loss: 0.0465
# Epoch [210/1000] Fold 1, Train Loss: 0.0460, Val Loss: 0.0471
# Epoch [211/1000] Fold 1, Train Loss: 0.0464, Val Loss: 0.0469
# Epoch [212/1000] Fold 1, Train Loss: 0.0454, Val Loss: 0.0473
# Epoch [213/1000] Fold 1, Train Loss: 0.0449, Val Loss: 0.0473
# Epoch [214/1000] Fold 1, Train Loss: 0.0452, Val Loss: 0.0472
# Epoch [215/1000] Fold 1, Train Loss: 0.0468, Val Loss: 0.0483
# Epoch [216/1000] Fold 1, Train Loss: 0.0450, Val Loss: 0.0477
# Epoch [217/1000] Fold 1, Train Loss: 0.0461, Val Loss: 0.0466
# Epoch [218/1000] Fold 1, Train Loss: 0.0451, Val Loss: 0.0473
# Epoch [219/1000] Fold 1, Train Loss: 0.0450, Val Loss: 0.0470
# Epoch [220/1000] Fold 1, Train Loss: 0.0447, Val Loss: 0.0472
# Epoch [221/1000] Fold 1, Train Loss: 0.0450, Val Loss: 0.0469
# Epoch [222/1000] Fold 1, Train Loss: 0.0450, Val Loss: 0.0474
# Epoch [223/1000] Fold 1, Train Loss: 0.0468, Val Loss: 0.0468
# Epoch [224/1000] Fold 1, Train Loss: 0.0454, Val Loss: 0.0468
# Epoch [225/1000] Fold 1, Train Loss: 0.0460, Val Loss: 0.0471
# Epoch [226/1000] Fold 1, Train Loss: 0.0470, Val Loss: 0.0465
# Epoch [227/1000] Fold 1, Train Loss: 0.0456, Val Loss: 0.0465
# Epoch [228/1000] Fold 1, Train Loss: 0.0447, Val Loss: 0.0471
# Epoch [229/1000] Fold 1, Train Loss: 0.0448, Val Loss: 0.0470
# Epoch [230/1000] Fold 1, Train Loss: 0.0452, Val Loss: 0.0472
# Epoch [231/1000] Fold 1, Train Loss: 0.0445, Val Loss: 0.0467
# Epoch [232/1000] Fold 1, Train Loss: 0.0449, Val Loss: 0.0471
# Epoch [233/1000] Fold 1, Train Loss: 0.0445, Val Loss: 0.0465
# Epoch [234/1000] Fold 1, Train Loss: 0.0446, Val Loss: 0.0468
# Epoch [235/1000] Fold 1, Train Loss: 0.0446, Val Loss: 0.0473
# Epoch [236/1000] Fold 1, Train Loss: 0.0453, Val Loss: 0.0489
# Epoch [237/1000] Fold 1, Train Loss: 0.0457, Val Loss: 0.0483
# Epoch [238/1000] Fold 1, Train Loss: 0.0438, Val Loss: 0.0471
# Epoch [239/1000] Fold 1, Train Loss: 0.0445, Val Loss: 0.0469
# Epoch [240/1000] Fold 1, Train Loss: 0.0450, Val Loss: 0.0481
# Epoch [241/1000] Fold 1, Train Loss: 0.0460, Val Loss: 0.0478
# Epoch [242/1000] Fold 1, Train Loss: 0.0442, Val Loss: 0.0476
# Epoch [243/1000] Fold 1, Train Loss: 0.0448, Val Loss: 0.0470
# Epoch [244/1000] Fold 1, Train Loss: 0.0441, Val Loss: 0.0472
# Epoch [245/1000] Fold 1, Train Loss: 0.0460, Val Loss: 0.0464
# Epoch [246/1000] Fold 1, Train Loss: 0.0458, Val Loss: 0.0474
# Epoch [247/1000] Fold 1, Train Loss: 0.0451, Val Loss: 0.0469
# Epoch [248/1000] Fold 1, Train Loss: 0.0454, Val Loss: 0.0465
# Epoch [249/1000] Fold 1, Train Loss: 0.0460, Val Loss: 0.0471
# Epoch [250/1000] Fold 1, Train Loss: 0.0462, Val Loss: 0.0469
# Epoch [251/1000] Fold 1, Train Loss: 0.0455, Val Loss: 0.0465
# Epoch [252/1000] Fold 1, Train Loss: 0.0470, Val Loss: 0.0473
# Epoch [253/1000] Fold 1, Train Loss: 0.0445, Val Loss: 0.0465
# Epoch [254/1000] Fold 1, Train Loss: 0.0452, Val Loss: 0.0464
# Epoch [255/1000] Fold 1, Train Loss: 0.0440, Val Loss: 0.0468
# Epoch [256/1000] Fold 1, Train Loss: 0.0439, Val Loss: 0.0468
# Epoch [257/1000] Fold 1, Train Loss: 0.0453, Val Loss: 0.0469
# Epoch [258/1000] Fold 1, Train Loss: 0.0437, Val Loss: 0.0468
# Epoch [259/1000] Fold 1, Train Loss: 0.0447, Val Loss: 0.0467
# Epoch [260/1000] Fold 1, Train Loss: 0.0460, Val Loss: 0.0470
# Epoch [261/1000] Fold 1, Train Loss: 0.0443, Val Loss: 0.0467
# Epoch [262/1000] Fold 1, Train Loss: 0.0436, Val Loss: 0.0466
# Epoch [263/1000] Fold 1, Train Loss: 0.0441, Val Loss: 0.0469
# Epoch [264/1000] Fold 1, Train Loss: 0.0446, Val Loss: 0.0469
# Epoch [265/1000] Fold 1, Train Loss: 0.0447, Val Loss: 0.0467
# Epoch [266/1000] Fold 1, Train Loss: 0.0449, Val Loss: 0.0471
# Epoch [267/1000] Fold 1, Train Loss: 0.0435, Val Loss: 0.0468
# Epoch [268/1000] Fold 1, Train Loss: 0.0444, Val Loss: 0.0475
# Epoch [269/1000] Fold 1, Train Loss: 0.0439, Val Loss: 0.0471
# Epoch [270/1000] Fold 1, Train Loss: 0.0463, Val Loss: 0.0475
# Epoch [271/1000] Fold 1, Train Loss: 0.0439, Val Loss: 0.0474
# Epoch [272/1000] Fold 1, Train Loss: 0.0449, Val Loss: 0.0466
# Epoch [273/1000] Fold 1, Train Loss: 0.0449, Val Loss: 0.0469
# Epoch [274/1000] Fold 1, Train Loss: 0.0444, Val Loss: 0.0469
# Epoch [275/1000] Fold 1, Train Loss: 0.0447, Val Loss: 0.0486
# Epoch [276/1000] Fold 1, Train Loss: 0.0457, Val Loss: 0.0469
# Epoch [277/1000] Fold 1, Train Loss: 0.0449, Val Loss: 0.0470
# Epoch [278/1000] Fold 1, Train Loss: 0.0449, Val Loss: 0.0465
# Epoch [279/1000] Fold 1, Train Loss: 0.0441, Val Loss: 0.0466
# Epoch [280/1000] Fold 1, Train Loss: 0.0430, Val Loss: 0.0464
# Epoch [281/1000] Fold 1, Train Loss: 0.0461, Val Loss: 0.0472
# Epoch [282/1000] Fold 1, Train Loss: 0.0441, Val Loss: 0.0463
# Epoch [283/1000] Fold 1, Train Loss: 0.0441, Val Loss: 0.0466
# Epoch [284/1000] Fold 1, Train Loss: 0.0449, Val Loss: 0.0468
# Epoch [285/1000] Fold 1, Train Loss: 0.0461, Val Loss: 0.0463
# Epoch [286/1000] Fold 1, Train Loss: 0.0435, Val Loss: 0.0479
# Epoch [287/1000] Fold 1, Train Loss: 0.0442, Val Loss: 0.0470
# Epoch [288/1000] Fold 1, Train Loss: 0.0423, Val Loss: 0.0467
# Epoch [289/1000] Fold 1, Train Loss: 0.0447, Val Loss: 0.0462
# Epoch [290/1000] Fold 1, Train Loss: 0.0446, Val Loss: 0.0463
# Epoch [291/1000] Fold 1, Train Loss: 0.0453, Val Loss: 0.0477
# Epoch [292/1000] Fold 1, Train Loss: 0.0434, Val Loss: 0.0464
# Epoch [293/1000] Fold 1, Train Loss: 0.0436, Val Loss: 0.0460
# Epoch [294/1000] Fold 1, Train Loss: 0.0447, Val Loss: 0.0489
# Epoch [295/1000] Fold 1, Train Loss: 0.0430, Val Loss: 0.0473
# Epoch [296/1000] Fold 1, Train Loss: 0.0446, Val Loss: 0.0469
# Epoch [297/1000] Fold 1, Train Loss: 0.0445, Val Loss: 0.0469
# Epoch [298/1000] Fold 1, Train Loss: 0.0433, Val Loss: 0.0466
# Epoch [299/1000] Fold 1, Train Loss: 0.0435, Val Loss: 0.0475
# Epoch [300/1000] Fold 1, Train Loss: 0.0436, Val Loss: 0.0469
# Epoch [301/1000] Fold 1, Train Loss: 0.0442, Val Loss: 0.0470
# Epoch [302/1000] Fold 1, Train Loss: 0.0448, Val Loss: 0.0475
# Epoch [303/1000] Fold 1, Train Loss: 0.0459, Val Loss: 0.0470
# Epoch [304/1000] Fold 1, Train Loss: 0.0421, Val Loss: 0.0465
# Epoch [305/1000] Fold 1, Train Loss: 0.0453, Val Loss: 0.0473
# Epoch [306/1000] Fold 1, Train Loss: 0.0436, Val Loss: 0.0470
# Epoch [307/1000] Fold 1, Train Loss: 0.0432, Val Loss: 0.0465
# Epoch [308/1000] Fold 1, Train Loss: 0.0440, Val Loss: 0.0467
# Epoch [309/1000] Fold 1, Train Loss: 0.0427, Val Loss: 0.0468
# Epoch [310/1000] Fold 1, Train Loss: 0.0432, Val Loss: 0.0470
# Epoch [311/1000] Fold 1, Train Loss: 0.0441, Val Loss: 0.0466
# Epoch [312/1000] Fold 1, Train Loss: 0.0433, Val Loss: 0.0467
# Epoch [313/1000] Fold 1, Train Loss: 0.0446, Val Loss: 0.0463
# Epoch [314/1000] Fold 1, Train Loss: 0.0431, Val Loss: 0.0465
# Epoch [315/1000] Fold 1, Train Loss: 0.0436, Val Loss: 0.0470
# Epoch [316/1000] Fold 1, Train Loss: 0.0432, Val Loss: 0.0466
# Epoch [317/1000] Fold 1, Train Loss: 0.0442, Val Loss: 0.0472
# Epoch [318/1000] Fold 1, Train Loss: 0.0426, Val Loss: 0.0470
# Epoch [319/1000] Fold 1, Train Loss: 0.0435, Val Loss: 0.0465
# Epoch [320/1000] Fold 1, Train Loss: 0.0433, Val Loss: 0.0471
# Epoch [321/1000] Fold 1, Train Loss: 0.0441, Val Loss: 0.0464
# Epoch [322/1000] Fold 1, Train Loss: 0.0434, Val Loss: 0.0468
# Epoch [323/1000] Fold 1, Train Loss: 0.0444, Val Loss: 0.0465
# Epoch [324/1000] Fold 1, Train Loss: 0.0425, Val Loss: 0.0460
# Epoch [325/1000] Fold 1, Train Loss: 0.0428, Val Loss: 0.0464
# Epoch [326/1000] Fold 1, Train Loss: 0.0438, Val Loss: 0.0464
# Epoch [327/1000] Fold 1, Train Loss: 0.0433, Val Loss: 0.0462
# Epoch [328/1000] Fold 1, Train Loss: 0.0427, Val Loss: 0.0466
# Epoch [329/1000] Fold 1, Train Loss: 0.0431, Val Loss: 0.0464
# Epoch [330/1000] Fold 1, Train Loss: 0.0432, Val Loss: 0.0472
# Epoch [331/1000] Fold 1, Train Loss: 0.0433, Val Loss: 0.0468
# Epoch [332/1000] Fold 1, Train Loss: 0.0428, Val Loss: 0.0465
# Epoch [333/1000] Fold 1, Train Loss: 0.0440, Val Loss: 0.0468
# Epoch [334/1000] Fold 1, Train Loss: 0.0442, Val Loss: 0.0464
# Epoch [335/1000] Fold 1, Train Loss: 0.0434, Val Loss: 0.0463
# Epoch [336/1000] Fold 1, Train Loss: 0.0424, Val Loss: 0.0464
# Epoch [337/1000] Fold 1, Train Loss: 0.0428, Val Loss: 0.0462
# Epoch [338/1000] Fold 1, Train Loss: 0.0433, Val Loss: 0.0471
# Epoch [339/1000] Fold 1, Train Loss: 0.0426, Val Loss: 0.0466
# Epoch [340/1000] Fold 1, Train Loss: 0.0441, Val Loss: 0.0460
# Epoch [341/1000] Fold 1, Train Loss: 0.0424, Val Loss: 0.0466
# Epoch [342/1000] Fold 1, Train Loss: 0.0430, Val Loss: 0.0463
# Epoch [343/1000] Fold 1, Train Loss: 0.0419, Val Loss: 0.0462
# Epoch [344/1000] Fold 1, Train Loss: 0.0429, Val Loss: 0.0462
# Epoch [345/1000] Fold 1, Train Loss: 0.0445, Val Loss: 0.0462
# Epoch [346/1000] Fold 1, Train Loss: 0.0437, Val Loss: 0.0468
# Epoch [347/1000] Fold 1, Train Loss: 0.0420, Val Loss: 0.0463
# Epoch [348/1000] Fold 1, Train Loss: 0.0425, Val Loss: 0.0463
# Epoch [349/1000] Fold 1, Train Loss: 0.0420, Val Loss: 0.0469
# Epoch [350/1000] Fold 1, Train Loss: 0.0423, Val Loss: 0.0463
# Epoch [351/1000] Fold 1, Train Loss: 0.0421, Val Loss: 0.0468
# Epoch [352/1000] Fold 1, Train Loss: 0.0422, Val Loss: 0.0461
# Epoch [353/1000] Fold 1, Train Loss: 0.0428, Val Loss: 0.0457
# Epoch [354/1000] Fold 1, Train Loss: 0.0434, Val Loss: 0.0462
# Epoch [355/1000] Fold 1, Train Loss: 0.0437, Val Loss: 0.0457
# Epoch [356/1000] Fold 1, Train Loss: 0.0423, Val Loss: 0.0457
# Epoch [357/1000] Fold 1, Train Loss: 0.0429, Val Loss: 0.0459
# Epoch [358/1000] Fold 1, Train Loss: 0.0425, Val Loss: 0.0459
# Epoch [359/1000] Fold 1, Train Loss: 0.0423, Val Loss: 0.0467
# Epoch [360/1000] Fold 1, Train Loss: 0.0438, Val Loss: 0.0471
# Epoch [361/1000] Fold 1, Train Loss: 0.0429, Val Loss: 0.0467
# Epoch [362/1000] Fold 1, Train Loss: 0.0419, Val Loss: 0.0461
# Epoch [363/1000] Fold 1, Train Loss: 0.0434, Val Loss: 0.0463
# Epoch [364/1000] Fold 1, Train Loss: 0.0431, Val Loss: 0.0462
# Epoch [365/1000] Fold 1, Train Loss: 0.0430, Val Loss: 0.0463
# Epoch [366/1000] Fold 1, Train Loss: 0.0418, Val Loss: 0.0460
# Epoch [367/1000] Fold 1, Train Loss: 0.0423, Val Loss: 0.0460
# Epoch [368/1000] Fold 1, Train Loss: 0.0422, Val Loss: 0.0461
# Epoch [369/1000] Fold 1, Train Loss: 0.0420, Val Loss: 0.0465
# Epoch [370/1000] Fold 1, Train Loss: 0.0419, Val Loss: 0.0464
# Epoch [371/1000] Fold 1, Train Loss: 0.0409, Val Loss: 0.0470
# Epoch [372/1000] Fold 1, Train Loss: 0.0424, Val Loss: 0.0461
# Epoch [373/1000] Fold 1, Train Loss: 0.0420, Val Loss: 0.0467
# Epoch [374/1000] Fold 1, Train Loss: 0.0430, Val Loss: 0.0465
# Epoch [375/1000] Fold 1, Train Loss: 0.0429, Val Loss: 0.0471
# Epoch [376/1000] Fold 1, Train Loss: 0.0418, Val Loss: 0.0463
# Epoch [377/1000] Fold 1, Train Loss: 0.0439, Val Loss: 0.0456
# Epoch [378/1000] Fold 1, Train Loss: 0.0431, Val Loss: 0.0468
# Epoch [379/1000] Fold 1, Train Loss: 0.0432, Val Loss: 0.0470
# Epoch [380/1000] Fold 1, Train Loss: 0.0413, Val Loss: 0.0467
# Epoch [381/1000] Fold 1, Train Loss: 0.0413, Val Loss: 0.0465
# Epoch [382/1000] Fold 1, Train Loss: 0.0424, Val Loss: 0.0459
# Epoch [383/1000] Fold 1, Train Loss: 0.0418, Val Loss: 0.0467
# Epoch [384/1000] Fold 1, Train Loss: 0.0436, Val Loss: 0.0461
# Epoch [385/1000] Fold 1, Train Loss: 0.0419, Val Loss: 0.0461
# Epoch [386/1000] Fold 1, Train Loss: 0.0425, Val Loss: 0.0461
# Epoch [387/1000] Fold 1, Train Loss: 0.0439, Val Loss: 0.0470
# Epoch [388/1000] Fold 1, Train Loss: 0.0432, Val Loss: 0.0467
# Epoch [389/1000] Fold 1, Train Loss: 0.0422, Val Loss: 0.0459
# Epoch [390/1000] Fold 1, Train Loss: 0.0431, Val Loss: 0.0466
# Epoch [391/1000] Fold 1, Train Loss: 0.0425, Val Loss: 0.0460
# Epoch [392/1000] Fold 1, Train Loss: 0.0430, Val Loss: 0.0466
# Epoch [393/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0457
# Epoch [394/1000] Fold 1, Train Loss: 0.0428, Val Loss: 0.0459
# Epoch [395/1000] Fold 1, Train Loss: 0.0421, Val Loss: 0.0453
# Epoch [396/1000] Fold 1, Train Loss: 0.0430, Val Loss: 0.0461
# Epoch [397/1000] Fold 1, Train Loss: 0.0428, Val Loss: 0.0467
# Epoch [398/1000] Fold 1, Train Loss: 0.0432, Val Loss: 0.0463
# Epoch [399/1000] Fold 1, Train Loss: 0.0433, Val Loss: 0.0459
# Epoch [400/1000] Fold 1, Train Loss: 0.0432, Val Loss: 0.0458
# Epoch [401/1000] Fold 1, Train Loss: 0.0418, Val Loss: 0.0456
# Epoch [402/1000] Fold 1, Train Loss: 0.0429, Val Loss: 0.0467
# Epoch [403/1000] Fold 1, Train Loss: 0.0423, Val Loss: 0.0458
# Epoch [404/1000] Fold 1, Train Loss: 0.0421, Val Loss: 0.0458
# Epoch [405/1000] Fold 1, Train Loss: 0.0416, Val Loss: 0.0459
# Epoch [406/1000] Fold 1, Train Loss: 0.0424, Val Loss: 0.0467
# Epoch [407/1000] Fold 1, Train Loss: 0.0428, Val Loss: 0.0459
# Epoch [408/1000] Fold 1, Train Loss: 0.0424, Val Loss: 0.0460
# Epoch [409/1000] Fold 1, Train Loss: 0.0419, Val Loss: 0.0464
# Epoch [410/1000] Fold 1, Train Loss: 0.0413, Val Loss: 0.0458
# Epoch [411/1000] Fold 1, Train Loss: 0.0419, Val Loss: 0.0465
# Epoch [412/1000] Fold 1, Train Loss: 0.0420, Val Loss: 0.0462
# Epoch [413/1000] Fold 1, Train Loss: 0.0422, Val Loss: 0.0461
# Epoch [414/1000] Fold 1, Train Loss: 0.0422, Val Loss: 0.0465
# Epoch [415/1000] Fold 1, Train Loss: 0.0423, Val Loss: 0.0471
# Epoch [416/1000] Fold 1, Train Loss: 0.0424, Val Loss: 0.0463
# Epoch [417/1000] Fold 1, Train Loss: 0.0420, Val Loss: 0.0464
# Epoch [418/1000] Fold 1, Train Loss: 0.0412, Val Loss: 0.0454
# Epoch [419/1000] Fold 1, Train Loss: 0.0422, Val Loss: 0.0463
# Epoch [420/1000] Fold 1, Train Loss: 0.0424, Val Loss: 0.0466
# Epoch [421/1000] Fold 1, Train Loss: 0.0418, Val Loss: 0.0460
# Epoch [422/1000] Fold 1, Train Loss: 0.0415, Val Loss: 0.0464
# Epoch [423/1000] Fold 1, Train Loss: 0.0411, Val Loss: 0.0461
# Epoch [424/1000] Fold 1, Train Loss: 0.0421, Val Loss: 0.0464
# Epoch [425/1000] Fold 1, Train Loss: 0.0416, Val Loss: 0.0457
# Epoch [426/1000] Fold 1, Train Loss: 0.0418, Val Loss: 0.0455
# Epoch [427/1000] Fold 1, Train Loss: 0.0409, Val Loss: 0.0461
# Epoch [428/1000] Fold 1, Train Loss: 0.0428, Val Loss: 0.0473
# Epoch [429/1000] Fold 1, Train Loss: 0.0421, Val Loss: 0.0469
# Epoch [430/1000] Fold 1, Train Loss: 0.0430, Val Loss: 0.0458
# Epoch [431/1000] Fold 1, Train Loss: 0.0410, Val Loss: 0.0465
# Epoch [432/1000] Fold 1, Train Loss: 0.0417, Val Loss: 0.0459
# Epoch [433/1000] Fold 1, Train Loss: 0.0421, Val Loss: 0.0469
# Epoch [434/1000] Fold 1, Train Loss: 0.0428, Val Loss: 0.0464
# Epoch [435/1000] Fold 1, Train Loss: 0.0418, Val Loss: 0.0459
# Epoch [436/1000] Fold 1, Train Loss: 0.0412, Val Loss: 0.0460
# Epoch [437/1000] Fold 1, Train Loss: 0.0412, Val Loss: 0.0455
# Epoch [438/1000] Fold 1, Train Loss: 0.0413, Val Loss: 0.0455
# Epoch [439/1000] Fold 1, Train Loss: 0.0412, Val Loss: 0.0458
# Epoch [440/1000] Fold 1, Train Loss: 0.0414, Val Loss: 0.0458
# Epoch [441/1000] Fold 1, Train Loss: 0.0425, Val Loss: 0.0452
# Epoch [442/1000] Fold 1, Train Loss: 0.0425, Val Loss: 0.0457
# Epoch [443/1000] Fold 1, Train Loss: 0.0417, Val Loss: 0.0464
# Epoch [444/1000] Fold 1, Train Loss: 0.0425, Val Loss: 0.0468
# Epoch [445/1000] Fold 1, Train Loss: 0.0418, Val Loss: 0.0463
# Epoch [446/1000] Fold 1, Train Loss: 0.0410, Val Loss: 0.0461
# Epoch [447/1000] Fold 1, Train Loss: 0.0417, Val Loss: 0.0456
# Epoch [448/1000] Fold 1, Train Loss: 0.0411, Val Loss: 0.0462
# Epoch [449/1000] Fold 1, Train Loss: 0.0415, Val Loss: 0.0460
# Epoch [450/1000] Fold 1, Train Loss: 0.0413, Val Loss: 0.0459
# Epoch [451/1000] Fold 1, Train Loss: 0.0421, Val Loss: 0.0459
# Epoch [452/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0456
# Epoch [453/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0458
# Epoch [454/1000] Fold 1, Train Loss: 0.0413, Val Loss: 0.0462
# Epoch [455/1000] Fold 1, Train Loss: 0.0418, Val Loss: 0.0455
# Epoch [456/1000] Fold 1, Train Loss: 0.0411, Val Loss: 0.0454
# Epoch [457/1000] Fold 1, Train Loss: 0.0413, Val Loss: 0.0459
# Epoch [458/1000] Fold 1, Train Loss: 0.0422, Val Loss: 0.0462
# Epoch [459/1000] Fold 1, Train Loss: 0.0411, Val Loss: 0.0463
# Epoch [460/1000] Fold 1, Train Loss: 0.0414, Val Loss: 0.0462
# Epoch [461/1000] Fold 1, Train Loss: 0.0418, Val Loss: 0.0454
# Epoch [462/1000] Fold 1, Train Loss: 0.0406, Val Loss: 0.0453
# Epoch [463/1000] Fold 1, Train Loss: 0.0417, Val Loss: 0.0469
# Epoch [464/1000] Fold 1, Train Loss: 0.0404, Val Loss: 0.0466
# Epoch [465/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0457
# Epoch [466/1000] Fold 1, Train Loss: 0.0429, Val Loss: 0.0458
# Epoch [467/1000] Fold 1, Train Loss: 0.0413, Val Loss: 0.0458
# Epoch [468/1000] Fold 1, Train Loss: 0.0408, Val Loss: 0.0450
# Epoch [469/1000] Fold 1, Train Loss: 0.0415, Val Loss: 0.0455
# Epoch [470/1000] Fold 1, Train Loss: 0.0422, Val Loss: 0.0469
# Epoch [471/1000] Fold 1, Train Loss: 0.0405, Val Loss: 0.0463
# Epoch [472/1000] Fold 1, Train Loss: 0.0405, Val Loss: 0.0452
# Epoch [473/1000] Fold 1, Train Loss: 0.0402, Val Loss: 0.0454
# Epoch [474/1000] Fold 1, Train Loss: 0.0412, Val Loss: 0.0459
# Epoch [475/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0458
# Epoch [476/1000] Fold 1, Train Loss: 0.0398, Val Loss: 0.0454
# Epoch [477/1000] Fold 1, Train Loss: 0.0417, Val Loss: 0.0459
# Epoch [478/1000] Fold 1, Train Loss: 0.0409, Val Loss: 0.0459
# Epoch [479/1000] Fold 1, Train Loss: 0.0433, Val Loss: 0.0459
# Epoch [480/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0459
# Epoch [481/1000] Fold 1, Train Loss: 0.0417, Val Loss: 0.0463
# Epoch [482/1000] Fold 1, Train Loss: 0.0406, Val Loss: 0.0459
# Epoch [483/1000] Fold 1, Train Loss: 0.0415, Val Loss: 0.0462
# Epoch [484/1000] Fold 1, Train Loss: 0.0427, Val Loss: 0.0467
# Epoch [485/1000] Fold 1, Train Loss: 0.0405, Val Loss: 0.0466
# Epoch [486/1000] Fold 1, Train Loss: 0.0414, Val Loss: 0.0456
# Epoch [487/1000] Fold 1, Train Loss: 0.0409, Val Loss: 0.0452
# Epoch [488/1000] Fold 1, Train Loss: 0.0427, Val Loss: 0.0455
# Epoch [489/1000] Fold 1, Train Loss: 0.0411, Val Loss: 0.0455
# Epoch [490/1000] Fold 1, Train Loss: 0.0426, Val Loss: 0.0450
# Epoch [491/1000] Fold 1, Train Loss: 0.0410, Val Loss: 0.0459
# Epoch [492/1000] Fold 1, Train Loss: 0.0415, Val Loss: 0.0456
# Epoch [493/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0450
# Epoch [494/1000] Fold 1, Train Loss: 0.0413, Val Loss: 0.0462
# Epoch [495/1000] Fold 1, Train Loss: 0.0408, Val Loss: 0.0456
# Epoch [496/1000] Fold 1, Train Loss: 0.0402, Val Loss: 0.0455
# Epoch [497/1000] Fold 1, Train Loss: 0.0410, Val Loss: 0.0457
# Epoch [498/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0457
# Epoch [499/1000] Fold 1, Train Loss: 0.0422, Val Loss: 0.0463
# Epoch [500/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0457
# Epoch [501/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0456
# Epoch [502/1000] Fold 1, Train Loss: 0.0397, Val Loss: 0.0454
# Epoch [503/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0452
# Epoch [504/1000] Fold 1, Train Loss: 0.0412, Val Loss: 0.0456
# Epoch [505/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0453
# Epoch [506/1000] Fold 1, Train Loss: 0.0411, Val Loss: 0.0458
# Epoch [507/1000] Fold 1, Train Loss: 0.0409, Val Loss: 0.0452
# Epoch [508/1000] Fold 1, Train Loss: 0.0413, Val Loss: 0.0460
# Epoch [509/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0455
# Epoch [510/1000] Fold 1, Train Loss: 0.0417, Val Loss: 0.0461
# Epoch [511/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0455
# Epoch [512/1000] Fold 1, Train Loss: 0.0404, Val Loss: 0.0457
# Epoch [513/1000] Fold 1, Train Loss: 0.0405, Val Loss: 0.0449
# Epoch [514/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0450
# Epoch [515/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0468
# Epoch [516/1000] Fold 1, Train Loss: 0.0420, Val Loss: 0.0459
# Epoch [517/1000] Fold 1, Train Loss: 0.0412, Val Loss: 0.0451
# Epoch [518/1000] Fold 1, Train Loss: 0.0418, Val Loss: 0.0457
# Epoch [519/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0449
# Epoch [520/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0453
# Epoch [521/1000] Fold 1, Train Loss: 0.0402, Val Loss: 0.0458
# Epoch [522/1000] Fold 1, Train Loss: 0.0411, Val Loss: 0.0453
# Epoch [523/1000] Fold 1, Train Loss: 0.0413, Val Loss: 0.0458
# Epoch [524/1000] Fold 1, Train Loss: 0.0399, Val Loss: 0.0451
# Epoch [525/1000] Fold 1, Train Loss: 0.0409, Val Loss: 0.0445
# Epoch [526/1000] Fold 1, Train Loss: 0.0406, Val Loss: 0.0447
# Epoch [527/1000] Fold 1, Train Loss: 0.0414, Val Loss: 0.0448
# Epoch [528/1000] Fold 1, Train Loss: 0.0415, Val Loss: 0.0455
# Epoch [529/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0455
# Epoch [530/1000] Fold 1, Train Loss: 0.0417, Val Loss: 0.0464
# Epoch [531/1000] Fold 1, Train Loss: 0.0398, Val Loss: 0.0453
# Epoch [532/1000] Fold 1, Train Loss: 0.0406, Val Loss: 0.0448
# Epoch [533/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0449
# Epoch [534/1000] Fold 1, Train Loss: 0.0391, Val Loss: 0.0453
# Epoch [535/1000] Fold 1, Train Loss: 0.0409, Val Loss: 0.0451
# Epoch [536/1000] Fold 1, Train Loss: 0.0420, Val Loss: 0.0459
# Epoch [537/1000] Fold 1, Train Loss: 0.0402, Val Loss: 0.0451
# Epoch [538/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0457
# Epoch [539/1000] Fold 1, Train Loss: 0.0411, Val Loss: 0.0451
# Epoch [540/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0448
# Epoch [541/1000] Fold 1, Train Loss: 0.0422, Val Loss: 0.0453
# Epoch [542/1000] Fold 1, Train Loss: 0.0406, Val Loss: 0.0446
# Epoch [543/1000] Fold 1, Train Loss: 0.0405, Val Loss: 0.0454
# Epoch [544/1000] Fold 1, Train Loss: 0.0415, Val Loss: 0.0450
# Epoch [545/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0452
# Epoch [546/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0447
# Epoch [547/1000] Fold 1, Train Loss: 0.0415, Val Loss: 0.0446
# Epoch [548/1000] Fold 1, Train Loss: 0.0419, Val Loss: 0.0449
# Epoch [549/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0445
# Epoch [550/1000] Fold 1, Train Loss: 0.0408, Val Loss: 0.0450
# Epoch [551/1000] Fold 1, Train Loss: 0.0411, Val Loss: 0.0444
# Epoch [552/1000] Fold 1, Train Loss: 0.0405, Val Loss: 0.0451
# Epoch [553/1000] Fold 1, Train Loss: 0.0395, Val Loss: 0.0444
# Epoch [554/1000] Fold 1, Train Loss: 0.0417, Val Loss: 0.0455
# Epoch [555/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0453
# Epoch [556/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0448
# Epoch [557/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0446
# Epoch [558/1000] Fold 1, Train Loss: 0.0404, Val Loss: 0.0440
# Epoch [559/1000] Fold 1, Train Loss: 0.0402, Val Loss: 0.0440
# Epoch [560/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0433
# Epoch [561/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0438
# Epoch [562/1000] Fold 1, Train Loss: 0.0402, Val Loss: 0.0449
# Epoch [563/1000] Fold 1, Train Loss: 0.0392, Val Loss: 0.0451
# Epoch [564/1000] Fold 1, Train Loss: 0.0390, Val Loss: 0.0447
# Epoch [565/1000] Fold 1, Train Loss: 0.0398, Val Loss: 0.0451
# Epoch [566/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0450
# Epoch [567/1000] Fold 1, Train Loss: 0.0404, Val Loss: 0.0446
# Epoch [568/1000] Fold 1, Train Loss: 0.0402, Val Loss: 0.0442
# Epoch [569/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0447
# Epoch [570/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0446
# Epoch [571/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0441
# Epoch [572/1000] Fold 1, Train Loss: 0.0393, Val Loss: 0.0448
# Epoch [573/1000] Fold 1, Train Loss: 0.0398, Val Loss: 0.0440
# Epoch [574/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0454
# Epoch [575/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0441
# Epoch [576/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0448
# Epoch [577/1000] Fold 1, Train Loss: 0.0398, Val Loss: 0.0442
# Epoch [578/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0438
# Epoch [579/1000] Fold 1, Train Loss: 0.0402, Val Loss: 0.0444
# Epoch [580/1000] Fold 1, Train Loss: 0.0396, Val Loss: 0.0443
# Epoch [581/1000] Fold 1, Train Loss: 0.0392, Val Loss: 0.0437
# Epoch [582/1000] Fold 1, Train Loss: 0.0384, Val Loss: 0.0429
# Epoch [583/1000] Fold 1, Train Loss: 0.0393, Val Loss: 0.0432
# Epoch [584/1000] Fold 1, Train Loss: 0.0405, Val Loss: 0.0442
# Epoch [585/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0436
# Epoch [586/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0435
# Epoch [587/1000] Fold 1, Train Loss: 0.0393, Val Loss: 0.0440
# Epoch [588/1000] Fold 1, Train Loss: 0.0398, Val Loss: 0.0441
# Epoch [589/1000] Fold 1, Train Loss: 0.0399, Val Loss: 0.0439
# Epoch [590/1000] Fold 1, Train Loss: 0.0398, Val Loss: 0.0443
# Epoch [591/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0452
# Epoch [592/1000] Fold 1, Train Loss: 0.0412, Val Loss: 0.0446
# Epoch [593/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0435
# Epoch [594/1000] Fold 1, Train Loss: 0.0405, Val Loss: 0.0433
# Epoch [595/1000] Fold 1, Train Loss: 0.0405, Val Loss: 0.0432
# Epoch [596/1000] Fold 1, Train Loss: 0.0404, Val Loss: 0.0437
# Epoch [597/1000] Fold 1, Train Loss: 0.0397, Val Loss: 0.0439
# Epoch [598/1000] Fold 1, Train Loss: 0.0392, Val Loss: 0.0445
# Epoch [599/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0439
# Epoch [600/1000] Fold 1, Train Loss: 0.0406, Val Loss: 0.0431
# Epoch [601/1000] Fold 1, Train Loss: 0.0391, Val Loss: 0.0431
# Epoch [602/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0424
# Epoch [603/1000] Fold 1, Train Loss: 0.0390, Val Loss: 0.0441
# Epoch [604/1000] Fold 1, Train Loss: 0.0402, Val Loss: 0.0447
# Epoch [605/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0439
# Epoch [606/1000] Fold 1, Train Loss: 0.0407, Val Loss: 0.0435
# Epoch [607/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0431
# Epoch [608/1000] Fold 1, Train Loss: 0.0412, Val Loss: 0.0436
# Epoch [609/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0444
# Epoch [610/1000] Fold 1, Train Loss: 0.0392, Val Loss: 0.0426
# Epoch [611/1000] Fold 1, Train Loss: 0.0402, Val Loss: 0.0441
# Epoch [612/1000] Fold 1, Train Loss: 0.0397, Val Loss: 0.0445
# Epoch [613/1000] Fold 1, Train Loss: 0.0393, Val Loss: 0.0443
# Epoch [614/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0425
# Epoch [615/1000] Fold 1, Train Loss: 0.0390, Val Loss: 0.0421
# Epoch [616/1000] Fold 1, Train Loss: 0.0402, Val Loss: 0.0432
# Epoch [617/1000] Fold 1, Train Loss: 0.0390, Val Loss: 0.0429
# Epoch [618/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0433
# Epoch [619/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0428
# Epoch [620/1000] Fold 1, Train Loss: 0.0383, Val Loss: 0.0434
# Epoch [621/1000] Fold 1, Train Loss: 0.0387, Val Loss: 0.0430
# Epoch [622/1000] Fold 1, Train Loss: 0.0411, Val Loss: 0.0426
# Epoch [623/1000] Fold 1, Train Loss: 0.0398, Val Loss: 0.0425
# Epoch [624/1000] Fold 1, Train Loss: 0.0386, Val Loss: 0.0426
# Epoch [625/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0423
# Epoch [626/1000] Fold 1, Train Loss: 0.0379, Val Loss: 0.0425
# Epoch [627/1000] Fold 1, Train Loss: 0.0399, Val Loss: 0.0423
# Epoch [628/1000] Fold 1, Train Loss: 0.0393, Val Loss: 0.0428
# Epoch [629/1000] Fold 1, Train Loss: 0.0399, Val Loss: 0.0420
# Epoch [630/1000] Fold 1, Train Loss: 0.0396, Val Loss: 0.0420
# Epoch [631/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0422
# Epoch [632/1000] Fold 1, Train Loss: 0.0397, Val Loss: 0.0430
# Epoch [633/1000] Fold 1, Train Loss: 0.0410, Val Loss: 0.0421
# Epoch [634/1000] Fold 1, Train Loss: 0.0393, Val Loss: 0.0421
# Epoch [635/1000] Fold 1, Train Loss: 0.0396, Val Loss: 0.0429
# Epoch [636/1000] Fold 1, Train Loss: 0.0403, Val Loss: 0.0427
# Epoch [637/1000] Fold 1, Train Loss: 0.0395, Val Loss: 0.0432
# Epoch [638/1000] Fold 1, Train Loss: 0.0398, Val Loss: 0.0432
# Epoch [639/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0426
# Epoch [640/1000] Fold 1, Train Loss: 0.0396, Val Loss: 0.0416
# Epoch [641/1000] Fold 1, Train Loss: 0.0406, Val Loss: 0.0422
# Epoch [642/1000] Fold 1, Train Loss: 0.0389, Val Loss: 0.0424
# Epoch [643/1000] Fold 1, Train Loss: 0.0390, Val Loss: 0.0416
# Epoch [644/1000] Fold 1, Train Loss: 0.0393, Val Loss: 0.0420
# Epoch [645/1000] Fold 1, Train Loss: 0.0411, Val Loss: 0.0413
# Epoch [646/1000] Fold 1, Train Loss: 0.0398, Val Loss: 0.0413
# Epoch [647/1000] Fold 1, Train Loss: 0.0402, Val Loss: 0.0417
# Epoch [648/1000] Fold 1, Train Loss: 0.0384, Val Loss: 0.0415
# Epoch [649/1000] Fold 1, Train Loss: 0.0389, Val Loss: 0.0416
# Epoch [650/1000] Fold 1, Train Loss: 0.0384, Val Loss: 0.0415
# Epoch [651/1000] Fold 1, Train Loss: 0.0424, Val Loss: 0.0425
# Epoch [652/1000] Fold 1, Train Loss: 0.0391, Val Loss: 0.0414
# Epoch [653/1000] Fold 1, Train Loss: 0.0391, Val Loss: 0.0418
# Epoch [654/1000] Fold 1, Train Loss: 0.0380, Val Loss: 0.0425
# Epoch [655/1000] Fold 1, Train Loss: 0.0387, Val Loss: 0.0411
# Epoch [656/1000] Fold 1, Train Loss: 0.0399, Val Loss: 0.0409
# Epoch [657/1000] Fold 1, Train Loss: 0.0381, Val Loss: 0.0409
# Epoch [658/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0421
# Epoch [659/1000] Fold 1, Train Loss: 0.0382, Val Loss: 0.0416
# Epoch [660/1000] Fold 1, Train Loss: 0.0393, Val Loss: 0.0414
# Epoch [661/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0415
# Epoch [662/1000] Fold 1, Train Loss: 0.0388, Val Loss: 0.0415
# Epoch [663/1000] Fold 1, Train Loss: 0.0385, Val Loss: 0.0403
# Epoch [664/1000] Fold 1, Train Loss: 0.0381, Val Loss: 0.0407
# Epoch [665/1000] Fold 1, Train Loss: 0.0387, Val Loss: 0.0402
# Epoch [666/1000] Fold 1, Train Loss: 0.0396, Val Loss: 0.0412
# Epoch [667/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0405
# Epoch [668/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0412
# Epoch [669/1000] Fold 1, Train Loss: 0.0383, Val Loss: 0.0408
# Epoch [670/1000] Fold 1, Train Loss: 0.0393, Val Loss: 0.0408
# Epoch [671/1000] Fold 1, Train Loss: 0.0395, Val Loss: 0.0413
# Epoch [672/1000] Fold 1, Train Loss: 0.0383, Val Loss: 0.0406
# Epoch [673/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0413
# Epoch [674/1000] Fold 1, Train Loss: 0.0400, Val Loss: 0.0407
# Epoch [675/1000] Fold 1, Train Loss: 0.0386, Val Loss: 0.0404
# Epoch [676/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0403
# Epoch [677/1000] Fold 1, Train Loss: 0.0399, Val Loss: 0.0417
# Epoch [678/1000] Fold 1, Train Loss: 0.0383, Val Loss: 0.0409
# Epoch [679/1000] Fold 1, Train Loss: 0.0391, Val Loss: 0.0411
# Epoch [680/1000] Fold 1, Train Loss: 0.0382, Val Loss: 0.0409
# Epoch [681/1000] Fold 1, Train Loss: 0.0399, Val Loss: 0.0404
# Epoch [682/1000] Fold 1, Train Loss: 0.0386, Val Loss: 0.0406
# Epoch [683/1000] Fold 1, Train Loss: 0.0398, Val Loss: 0.0407
# Epoch [684/1000] Fold 1, Train Loss: 0.0383, Val Loss: 0.0405
# Epoch [685/1000] Fold 1, Train Loss: 0.0389, Val Loss: 0.0408
# Epoch [686/1000] Fold 1, Train Loss: 0.0381, Val Loss: 0.0408
# Epoch [687/1000] Fold 1, Train Loss: 0.0390, Val Loss: 0.0409
# Epoch [688/1000] Fold 1, Train Loss: 0.0388, Val Loss: 0.0405
# Epoch [689/1000] Fold 1, Train Loss: 0.0389, Val Loss: 0.0404
# Epoch [690/1000] Fold 1, Train Loss: 0.0369, Val Loss: 0.0407
# Epoch [691/1000] Fold 1, Train Loss: 0.0397, Val Loss: 0.0405
# Epoch [692/1000] Fold 1, Train Loss: 0.0380, Val Loss: 0.0404
# Epoch [693/1000] Fold 1, Train Loss: 0.0392, Val Loss: 0.0406
# Epoch [694/1000] Fold 1, Train Loss: 0.0387, Val Loss: 0.0412
# Epoch [695/1000] Fold 1, Train Loss: 0.0389, Val Loss: 0.0401
# Epoch [696/1000] Fold 1, Train Loss: 0.0377, Val Loss: 0.0410
# Epoch [697/1000] Fold 1, Train Loss: 0.0382, Val Loss: 0.0410
# Epoch [698/1000] Fold 1, Train Loss: 0.0395, Val Loss: 0.0403
# Epoch [699/1000] Fold 1, Train Loss: 0.0385, Val Loss: 0.0407
# Epoch [700/1000] Fold 1, Train Loss: 0.0383, Val Loss: 0.0400
# Epoch [701/1000] Fold 1, Train Loss: 0.0382, Val Loss: 0.0404
# Epoch [702/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0406
# Epoch [703/1000] Fold 1, Train Loss: 0.0388, Val Loss: 0.0401
# Epoch [704/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0404
# Epoch [705/1000] Fold 1, Train Loss: 0.0382, Val Loss: 0.0397
# Epoch [706/1000] Fold 1, Train Loss: 0.0387, Val Loss: 0.0406
# Epoch [707/1000] Fold 1, Train Loss: 0.0384, Val Loss: 0.0404
# Epoch [708/1000] Fold 1, Train Loss: 0.0390, Val Loss: 0.0411
# Epoch [709/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0400
# Epoch [710/1000] Fold 1, Train Loss: 0.0376, Val Loss: 0.0401
# Epoch [711/1000] Fold 1, Train Loss: 0.0385, Val Loss: 0.0398
# Epoch [712/1000] Fold 1, Train Loss: 0.0388, Val Loss: 0.0401
# Epoch [713/1000] Fold 1, Train Loss: 0.0376, Val Loss: 0.0397
# Epoch [714/1000] Fold 1, Train Loss: 0.0396, Val Loss: 0.0411
# Epoch [715/1000] Fold 1, Train Loss: 0.0401, Val Loss: 0.0407
# Epoch [716/1000] Fold 1, Train Loss: 0.0391, Val Loss: 0.0402
# Epoch [717/1000] Fold 1, Train Loss: 0.0389, Val Loss: 0.0398
# Epoch [718/1000] Fold 1, Train Loss: 0.0381, Val Loss: 0.0411
# Epoch [719/1000] Fold 1, Train Loss: 0.0390, Val Loss: 0.0401
# Epoch [720/1000] Fold 1, Train Loss: 0.0386, Val Loss: 0.0400
# Epoch [721/1000] Fold 1, Train Loss: 0.0383, Val Loss: 0.0402
# Epoch [722/1000] Fold 1, Train Loss: 0.0374, Val Loss: 0.0397
# Epoch [723/1000] Fold 1, Train Loss: 0.0382, Val Loss: 0.0398
# Epoch [724/1000] Fold 1, Train Loss: 0.0390, Val Loss: 0.0399
# Epoch [725/1000] Fold 1, Train Loss: 0.0384, Val Loss: 0.0410
# Epoch [726/1000] Fold 1, Train Loss: 0.0373, Val Loss: 0.0399
# Epoch [727/1000] Fold 1, Train Loss: 0.0396, Val Loss: 0.0395
# Epoch [728/1000] Fold 1, Train Loss: 0.0405, Val Loss: 0.0393
# Epoch [729/1000] Fold 1, Train Loss: 0.0390, Val Loss: 0.0401
# Epoch [730/1000] Fold 1, Train Loss: 0.0389, Val Loss: 0.0398
# Epoch [731/1000] Fold 1, Train Loss: 0.0375, Val Loss: 0.0402
# Epoch [732/1000] Fold 1, Train Loss: 0.0393, Val Loss: 0.0403
# Epoch [733/1000] Fold 1, Train Loss: 0.0383, Val Loss: 0.0394
# Epoch [734/1000] Fold 1, Train Loss: 0.0396, Val Loss: 0.0390
# Epoch [735/1000] Fold 1, Train Loss: 0.0385, Val Loss: 0.0395
# Epoch [736/1000] Fold 1, Train Loss: 0.0378, Val Loss: 0.0398
# Epoch [737/1000] Fold 1, Train Loss: 0.0393, Val Loss: 0.0404
# Epoch [738/1000] Fold 1, Train Loss: 0.0376, Val Loss: 0.0396
# Epoch [739/1000] Fold 1, Train Loss: 0.0389, Val Loss: 0.0391
# Epoch [740/1000] Fold 1, Train Loss: 0.0373, Val Loss: 0.0399
# Epoch [741/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0395
# Epoch [742/1000] Fold 1, Train Loss: 0.0375, Val Loss: 0.0400
# Epoch [743/1000] Fold 1, Train Loss: 0.0385, Val Loss: 0.0395
# Epoch [744/1000] Fold 1, Train Loss: 0.0388, Val Loss: 0.0397
# Epoch [745/1000] Fold 1, Train Loss: 0.0383, Val Loss: 0.0396
# Epoch [746/1000] Fold 1, Train Loss: 0.0374, Val Loss: 0.0408
# Epoch [747/1000] Fold 1, Train Loss: 0.0394, Val Loss: 0.0393
# Epoch [748/1000] Fold 1, Train Loss: 0.0371, Val Loss: 0.0399
# Epoch [749/1000] Fold 1, Train Loss: 0.0390, Val Loss: 0.0395
# Epoch [750/1000] Fold 1, Train Loss: 0.0382, Val Loss: 0.0400
# Epoch [751/1000] Fold 1, Train Loss: 0.0370, Val Loss: 0.0401
# Epoch [752/1000] Fold 1, Train Loss: 0.0383, Val Loss: 0.0397
# Epoch [753/1000] Fold 1, Train Loss: 0.0387, Val Loss: 0.0390
# Epoch [754/1000] Fold 1, Train Loss: 0.0391, Val Loss: 0.0389
# Epoch [755/1000] Fold 1, Train Loss: 0.0387, Val Loss: 0.0403
# Epoch [756/1000] Fold 1, Train Loss: 0.0377, Val Loss: 0.0392
# Epoch [757/1000] Fold 1, Train Loss: 0.0375, Val Loss: 0.0406
# Epoch [758/1000] Fold 1, Train Loss: 0.0397, Val Loss: 0.0387
# Epoch [759/1000] Fold 1, Train Loss: 0.0384, Val Loss: 0.0392
# Epoch [760/1000] Fold 1, Train Loss: 0.0379, Val Loss: 0.0393
# Epoch [761/1000] Fold 1, Train Loss: 0.0379, Val Loss: 0.0390
# Epoch [762/1000] Fold 1, Train Loss: 0.0373, Val Loss: 0.0396
# Epoch [763/1000] Fold 1, Train Loss: 0.0398, Val Loss: 0.0398
# Epoch [764/1000] Fold 1, Train Loss: 0.0380, Val Loss: 0.0397
# Epoch [765/1000] Fold 1, Train Loss: 0.0382, Val Loss: 0.0393
# Epoch [766/1000] Fold 1, Train Loss: 0.0384, Val Loss: 0.0393
# Epoch [767/1000] Fold 1, Train Loss: 0.0383, Val Loss: 0.0394
# Epoch [768/1000] Fold 1, Train Loss: 0.0391, Val Loss: 0.0396
# Epoch [769/1000] Fold 1, Train Loss: 0.0375, Val Loss: 0.0394
# Epoch [770/1000] Fold 1, Train Loss: 0.0376, Val Loss: 0.0393
# Epoch [771/1000] Fold 1, Train Loss: 0.0380, Val Loss: 0.0394
# Epoch [772/1000] Fold 1, Train Loss: 0.0387, Val Loss: 0.0392
# Epoch [773/1000] Fold 1, Train Loss: 0.0375, Val Loss: 0.0392
# Epoch [774/1000] Fold 1, Train Loss: 0.0380, Val Loss: 0.0388
# Epoch [775/1000] Fold 1, Train Loss: 0.0378, Val Loss: 0.0392
# ...
# Epoch [748/1000] Fold 10, Train Loss: 0.0378, Val Loss: 0.0329
# Epoch [749/1000] Fold 10, Train Loss: 0.0370, Val Loss: 0.0331
# Epoch [750/1000] Fold 10, Train Loss: 0.0381, Val Loss: 0.0330
# Epoch [751/1000] Fold 10, Train Loss: 0.0386, Val Loss: 0.0328
# Epoch [752/1000] Fold 10, Train Loss: 0.0379, Val Loss: 0.0323
# Epoch [753/1000] Fold 10, Train Loss: 0.0390, Val Loss: 0.0325
# Epoch [754/1000] Fold 10, Train Loss: 0.0386, Val Loss: 0.0328
# Epoch [755/1000] Fold 10, Train Loss: 0.0377, Val Loss: 0.0326
# Epoch [756/1000] Fold 10, Train Loss: 0.0371, Val Loss: 0.0326
# Epoch [757/1000] Fold 10, Train Loss: 0.0380, Val Loss: 0.0328
# Epoch [758/1000] Fold 10, Train Loss: 0.0369, Val Loss: 0.0327
# Epoch [759/1000] Fold 10, Train Loss: 0.0382, Val Loss: 0.0326
# Epoch [760/1000] Fold 10, Train Loss: 0.0382, Val Loss: 0.0328
# Epoch [761/1000] Fold 10, Train Loss: 0.0383, Val Loss: 0.0329
# Epoch [762/1000] Fold 10, Train Loss: 0.0381, Val Loss: 0.0329
# Epoch [763/1000] Fold 10, Train Loss: 0.0383, Val Loss: 0.0323
# Epoch [764/1000] Fold 10, Train Loss: 0.0372, Val Loss: 0.0325
# Epoch [765/1000] Fold 10, Train Loss: 0.0379, Val Loss: 0.0321
# Epoch [766/1000] Fold 10, Train Loss: 0.0365, Val Loss: 0.0327
# Epoch [767/1000] Fold 10, Train Loss: 0.0383, Val Loss: 0.0324
# Epoch [768/1000] Fold 10, Train Loss: 0.0388, Val Loss: 0.0330
# Epoch [769/1000] Fold 10, Train Loss: 0.0369, Val Loss: 0.0331
# Epoch [770/1000] Fold 10, Train Loss: 0.0381, Val Loss: 0.0324
# Epoch [771/1000] Fold 10, Train Loss: 0.0374, Val Loss: 0.0324
# Epoch [772/1000] Fold 10, Train Loss: 0.0391, Val Loss: 0.0322
# Epoch [773/1000] Fold 10, Train Loss: 0.0375, Val Loss: 0.0326
# Epoch [774/1000] Fold 10, Train Loss: 0.0372, Val Loss: 0.0329
# Epoch [775/1000] Fold 10, Train Loss: 0.0385, Val Loss: 0.0319
# Epoch [776/1000] Fold 10, Train Loss: 0.0382, Val Loss: 0.0320
# Epoch [777/1000] Fold 10, Train Loss: 0.0371, Val Loss: 0.0327
# Epoch [778/1000] Fold 10, Train Loss: 0.0380, Val Loss: 0.0323
# Epoch [779/1000] Fold 10, Train Loss: 0.0391, Val Loss: 0.0326
# Epoch [780/1000] Fold 10, Train Loss: 0.0380, Val Loss: 0.0330
# Epoch [781/1000] Fold 10, Train Loss: 0.0372, Val Loss: 0.0323
# Epoch [782/1000] Fold 10, Train Loss: 0.0368, Val Loss: 0.0324
# Epoch [783/1000] Fold 10, Train Loss: 0.0383, Val Loss: 0.0326
# Epoch [784/1000] Fold 10, Train Loss: 0.0380, Val Loss: 0.0323
# Epoch [785/1000] Fold 10, Train Loss: 0.0375, Val Loss: 0.0325
# Epoch [786/1000] Fold 10, Train Loss: 0.0368, Val Loss: 0.0323
# Epoch [787/1000] Fold 10, Train Loss: 0.0367, Val Loss: 0.0319
# Epoch [788/1000] Fold 10, Train Loss: 0.0373, Val Loss: 0.0324
# Epoch [789/1000] Fold 10, Train Loss: 0.0383, Val Loss: 0.0323
# Epoch [790/1000] Fold 10, Train Loss: 0.0374, Val Loss: 0.0325
# Epoch [791/1000] Fold 10, Train Loss: 0.0363, Val Loss: 0.0322
# Epoch [792/1000] Fold 10, Train Loss: 0.0375, Val Loss: 0.0327
# Epoch [793/1000] Fold 10, Train Loss: 0.0375, Val Loss: 0.0322
# Epoch [794/1000] Fold 10, Train Loss: 0.0385, Val Loss: 0.0324
# Epoch [795/1000] Fold 10, Train Loss: 0.0377, Val Loss: 0.0320
# Epoch [796/1000] Fold 10, Train Loss: 0.0372, Val Loss: 0.0325
# Epoch [797/1000] Fold 10, Train Loss: 0.0367, Val Loss: 0.0322
# Epoch [798/1000] Fold 10, Train Loss: 0.0368, Val Loss: 0.0324
# Epoch [799/1000] Fold 10, Train Loss: 0.0365, Val Loss: 0.0320
# Epoch [800/1000] Fold 10, Train Loss: 0.0379, Val Loss: 0.0319
# Epoch [801/1000] Fold 10, Train Loss: 0.0383, Val Loss: 0.0319
# Epoch [802/1000] Fold 10, Train Loss: 0.0374, Val Loss: 0.0321
# Epoch [803/1000] Fold 10, Train Loss: 0.0382, Val Loss: 0.0316
# Epoch [804/1000] Fold 10, Train Loss: 0.0364, Val Loss: 0.0321
# Epoch [805/1000] Fold 10, Train Loss: 0.0375, Val Loss: 0.0319
# Epoch [806/1000] Fold 10, Train Loss: 0.0367, Val Loss: 0.0318
# Epoch [807/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0319
# Epoch [808/1000] Fold 10, Train Loss: 0.0368, Val Loss: 0.0320
# Epoch [809/1000] Fold 10, Train Loss: 0.0384, Val Loss: 0.0319
# Epoch [810/1000] Fold 10, Train Loss: 0.0365, Val Loss: 0.0318
# Epoch [811/1000] Fold 10, Train Loss: 0.0371, Val Loss: 0.0315
# Epoch [812/1000] Fold 10, Train Loss: 0.0363, Val Loss: 0.0322
# Epoch [813/1000] Fold 10, Train Loss: 0.0365, Val Loss: 0.0314
# Epoch [814/1000] Fold 10, Train Loss: 0.0379, Val Loss: 0.0321
# Epoch [815/1000] Fold 10, Train Loss: 0.0378, Val Loss: 0.0323
# Epoch [816/1000] Fold 10, Train Loss: 0.0368, Val Loss: 0.0324
# Epoch [817/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0320
# Epoch [818/1000] Fold 10, Train Loss: 0.0381, Val Loss: 0.0318
# Epoch [819/1000] Fold 10, Train Loss: 0.0371, Val Loss: 0.0318
# Epoch [820/1000] Fold 10, Train Loss: 0.0367, Val Loss: 0.0321
# Epoch [821/1000] Fold 10, Train Loss: 0.0364, Val Loss: 0.0316
# Epoch [822/1000] Fold 10, Train Loss: 0.0360, Val Loss: 0.0322
# Epoch [823/1000] Fold 10, Train Loss: 0.0368, Val Loss: 0.0316
# Epoch [824/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0316
# Epoch [825/1000] Fold 10, Train Loss: 0.0372, Val Loss: 0.0319
# Epoch [826/1000] Fold 10, Train Loss: 0.0361, Val Loss: 0.0317
# Epoch [827/1000] Fold 10, Train Loss: 0.0379, Val Loss: 0.0312
# Epoch [828/1000] Fold 10, Train Loss: 0.0375, Val Loss: 0.0315
# Epoch [829/1000] Fold 10, Train Loss: 0.0367, Val Loss: 0.0315
# Epoch [830/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0312
# Epoch [831/1000] Fold 10, Train Loss: 0.0357, Val Loss: 0.0315
# Epoch [832/1000] Fold 10, Train Loss: 0.0375, Val Loss: 0.0316
# Epoch [833/1000] Fold 10, Train Loss: 0.0364, Val Loss: 0.0320
# Epoch [834/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0315
# Epoch [835/1000] Fold 10, Train Loss: 0.0373, Val Loss: 0.0319
# Epoch [836/1000] Fold 10, Train Loss: 0.0373, Val Loss: 0.0316
# Epoch [837/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0316
# Epoch [838/1000] Fold 10, Train Loss: 0.0370, Val Loss: 0.0316
# Epoch [839/1000] Fold 10, Train Loss: 0.0384, Val Loss: 0.0318
# Epoch [840/1000] Fold 10, Train Loss: 0.0376, Val Loss: 0.0319
# Epoch [841/1000] Fold 10, Train Loss: 0.0370, Val Loss: 0.0318
# Epoch [842/1000] Fold 10, Train Loss: 0.0376, Val Loss: 0.0318
# Epoch [843/1000] Fold 10, Train Loss: 0.0381, Val Loss: 0.0315
# Epoch [844/1000] Fold 10, Train Loss: 0.0367, Val Loss: 0.0315
# Epoch [845/1000] Fold 10, Train Loss: 0.0376, Val Loss: 0.0313
# Epoch [846/1000] Fold 10, Train Loss: 0.0365, Val Loss: 0.0312
# Epoch [847/1000] Fold 10, Train Loss: 0.0367, Val Loss: 0.0316
# Epoch [848/1000] Fold 10, Train Loss: 0.0365, Val Loss: 0.0319
# Epoch [849/1000] Fold 10, Train Loss: 0.0353, Val Loss: 0.0318
# Epoch [850/1000] Fold 10, Train Loss: 0.0368, Val Loss: 0.0318
# Epoch [851/1000] Fold 10, Train Loss: 0.0373, Val Loss: 0.0321
# Epoch [852/1000] Fold 10, Train Loss: 0.0348, Val Loss: 0.0311
# Epoch [853/1000] Fold 10, Train Loss: 0.0370, Val Loss: 0.0312
# Epoch [854/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0313
# Epoch [855/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0315
# Epoch [856/1000] Fold 10, Train Loss: 0.0363, Val Loss: 0.0309
# Epoch [857/1000] Fold 10, Train Loss: 0.0368, Val Loss: 0.0309
# Epoch [858/1000] Fold 10, Train Loss: 0.0360, Val Loss: 0.0310
# Epoch [859/1000] Fold 10, Train Loss: 0.0374, Val Loss: 0.0313
# Epoch [860/1000] Fold 10, Train Loss: 0.0371, Val Loss: 0.0311
# Epoch [861/1000] Fold 10, Train Loss: 0.0367, Val Loss: 0.0320
# Epoch [862/1000] Fold 10, Train Loss: 0.0356, Val Loss: 0.0312
# Epoch [863/1000] Fold 10, Train Loss: 0.0361, Val Loss: 0.0311
# Epoch [864/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0312
# Epoch [865/1000] Fold 10, Train Loss: 0.0358, Val Loss: 0.0311
# Epoch [866/1000] Fold 10, Train Loss: 0.0359, Val Loss: 0.0311
# Epoch [867/1000] Fold 10, Train Loss: 0.0358, Val Loss: 0.0306
# Epoch [868/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0314
# Epoch [869/1000] Fold 10, Train Loss: 0.0379, Val Loss: 0.0308
# Epoch [870/1000] Fold 10, Train Loss: 0.0364, Val Loss: 0.0312
# Epoch [871/1000] Fold 10, Train Loss: 0.0361, Val Loss: 0.0307
# Epoch [872/1000] Fold 10, Train Loss: 0.0373, Val Loss: 0.0312
# Epoch [873/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0311
# Epoch [874/1000] Fold 10, Train Loss: 0.0369, Val Loss: 0.0316
# Epoch [875/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0311
# Epoch [876/1000] Fold 10, Train Loss: 0.0363, Val Loss: 0.0306
# Epoch [877/1000] Fold 10, Train Loss: 0.0370, Val Loss: 0.0310
# Epoch [878/1000] Fold 10, Train Loss: 0.0364, Val Loss: 0.0309
# Epoch [879/1000] Fold 10, Train Loss: 0.0370, Val Loss: 0.0310
# Epoch [880/1000] Fold 10, Train Loss: 0.0360, Val Loss: 0.0316
# Epoch [881/1000] Fold 10, Train Loss: 0.0357, Val Loss: 0.0313
# Epoch [882/1000] Fold 10, Train Loss: 0.0369, Val Loss: 0.0311
# Epoch [883/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0306
# Epoch [884/1000] Fold 10, Train Loss: 0.0363, Val Loss: 0.0309
# Epoch [885/1000] Fold 10, Train Loss: 0.0369, Val Loss: 0.0311
# Epoch [886/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0309
# Epoch [887/1000] Fold 10, Train Loss: 0.0357, Val Loss: 0.0306
# Epoch [888/1000] Fold 10, Train Loss: 0.0367, Val Loss: 0.0309
# Epoch [889/1000] Fold 10, Train Loss: 0.0359, Val Loss: 0.0309
# Epoch [890/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0311
# Epoch [891/1000] Fold 10, Train Loss: 0.0370, Val Loss: 0.0306
# Epoch [892/1000] Fold 10, Train Loss: 0.0363, Val Loss: 0.0312
# Epoch [893/1000] Fold 10, Train Loss: 0.0359, Val Loss: 0.0309
# Epoch [894/1000] Fold 10, Train Loss: 0.0365, Val Loss: 0.0305
# Epoch [895/1000] Fold 10, Train Loss: 0.0364, Val Loss: 0.0311
# Epoch [896/1000] Fold 10, Train Loss: 0.0360, Val Loss: 0.0313
# Epoch [897/1000] Fold 10, Train Loss: 0.0361, Val Loss: 0.0311
# Epoch [898/1000] Fold 10, Train Loss: 0.0359, Val Loss: 0.0310
# Epoch [899/1000] Fold 10, Train Loss: 0.0358, Val Loss: 0.0305
# Epoch [900/1000] Fold 10, Train Loss: 0.0355, Val Loss: 0.0309
# Epoch [901/1000] Fold 10, Train Loss: 0.0356, Val Loss: 0.0305
# Epoch [902/1000] Fold 10, Train Loss: 0.0376, Val Loss: 0.0304
# Epoch [903/1000] Fold 10, Train Loss: 0.0349, Val Loss: 0.0309
# Epoch [904/1000] Fold 10, Train Loss: 0.0358, Val Loss: 0.0304
# Epoch [905/1000] Fold 10, Train Loss: 0.0374, Val Loss: 0.0303
# Epoch [906/1000] Fold 10, Train Loss: 0.0349, Val Loss: 0.0310
# Epoch [907/1000] Fold 10, Train Loss: 0.0361, Val Loss: 0.0306
# Epoch [908/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0301
# Epoch [909/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0306
# Epoch [910/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0303
# Epoch [911/1000] Fold 10, Train Loss: 0.0355, Val Loss: 0.0309
# Epoch [912/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0305
# Epoch [913/1000] Fold 10, Train Loss: 0.0353, Val Loss: 0.0308
# Epoch [914/1000] Fold 10, Train Loss: 0.0349, Val Loss: 0.0308
# Epoch [915/1000] Fold 10, Train Loss: 0.0369, Val Loss: 0.0304
# Epoch [916/1000] Fold 10, Train Loss: 0.0360, Val Loss: 0.0308
# Epoch [917/1000] Fold 10, Train Loss: 0.0361, Val Loss: 0.0303
# Epoch [918/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0300
# Epoch [919/1000] Fold 10, Train Loss: 0.0350, Val Loss: 0.0305
# Epoch [920/1000] Fold 10, Train Loss: 0.0354, Val Loss: 0.0306
# Epoch [921/1000] Fold 10, Train Loss: 0.0358, Val Loss: 0.0307
# Epoch [922/1000] Fold 10, Train Loss: 0.0355, Val Loss: 0.0307
# Epoch [923/1000] Fold 10, Train Loss: 0.0364, Val Loss: 0.0313
# Epoch [924/1000] Fold 10, Train Loss: 0.0376, Val Loss: 0.0305
# Epoch [925/1000] Fold 10, Train Loss: 0.0370, Val Loss: 0.0306
# Epoch [926/1000] Fold 10, Train Loss: 0.0371, Val Loss: 0.0303
# Epoch [927/1000] Fold 10, Train Loss: 0.0373, Val Loss: 0.0303
# Epoch [928/1000] Fold 10, Train Loss: 0.0360, Val Loss: 0.0300
# Epoch [929/1000] Fold 10, Train Loss: 0.0358, Val Loss: 0.0302
# Epoch [930/1000] Fold 10, Train Loss: 0.0364, Val Loss: 0.0305
# Epoch [931/1000] Fold 10, Train Loss: 0.0353, Val Loss: 0.0302
# Epoch [932/1000] Fold 10, Train Loss: 0.0359, Val Loss: 0.0305
# Epoch [933/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0304
# Epoch [934/1000] Fold 10, Train Loss: 0.0353, Val Loss: 0.0302
# Epoch [935/1000] Fold 10, Train Loss: 0.0363, Val Loss: 0.0300
# Epoch [936/1000] Fold 10, Train Loss: 0.0352, Val Loss: 0.0307
# Epoch [937/1000] Fold 10, Train Loss: 0.0341, Val Loss: 0.0306
# Epoch [938/1000] Fold 10, Train Loss: 0.0364, Val Loss: 0.0299
# Epoch [939/1000] Fold 10, Train Loss: 0.0354, Val Loss: 0.0300
# Epoch [940/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0301
# Epoch [941/1000] Fold 10, Train Loss: 0.0354, Val Loss: 0.0304
# Epoch [942/1000] Fold 10, Train Loss: 0.0360, Val Loss: 0.0306
# Epoch [943/1000] Fold 10, Train Loss: 0.0352, Val Loss: 0.0306
# Epoch [944/1000] Fold 10, Train Loss: 0.0360, Val Loss: 0.0300
# Epoch [945/1000] Fold 10, Train Loss: 0.0350, Val Loss: 0.0299
# Epoch [946/1000] Fold 10, Train Loss: 0.0360, Val Loss: 0.0304
# Epoch [947/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0304
# Epoch [948/1000] Fold 10, Train Loss: 0.0365, Val Loss: 0.0302
# Epoch [949/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0300
# Epoch [950/1000] Fold 10, Train Loss: 0.0357, Val Loss: 0.0299
# Epoch [951/1000] Fold 10, Train Loss: 0.0358, Val Loss: 0.0300
# Epoch [952/1000] Fold 10, Train Loss: 0.0357, Val Loss: 0.0299
# Epoch [953/1000] Fold 10, Train Loss: 0.0372, Val Loss: 0.0299
# Epoch [954/1000] Fold 10, Train Loss: 0.0365, Val Loss: 0.0302
# Epoch [955/1000] Fold 10, Train Loss: 0.0349, Val Loss: 0.0301
# Epoch [956/1000] Fold 10, Train Loss: 0.0366, Val Loss: 0.0301
# Epoch [957/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0304
# Epoch [958/1000] Fold 10, Train Loss: 0.0345, Val Loss: 0.0302
# Epoch [959/1000] Fold 10, Train Loss: 0.0345, Val Loss: 0.0299
# Epoch [960/1000] Fold 10, Train Loss: 0.0354, Val Loss: 0.0301
# Epoch [961/1000] Fold 10, Train Loss: 0.0367, Val Loss: 0.0301
# Epoch [962/1000] Fold 10, Train Loss: 0.0355, Val Loss: 0.0298
# Epoch [963/1000] Fold 10, Train Loss: 0.0359, Val Loss: 0.0299
# Epoch [964/1000] Fold 10, Train Loss: 0.0358, Val Loss: 0.0299
# Epoch [965/1000] Fold 10, Train Loss: 0.0360, Val Loss: 0.0299
# Epoch [966/1000] Fold 10, Train Loss: 0.0349, Val Loss: 0.0301
# Epoch [967/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0298
# Epoch [968/1000] Fold 10, Train Loss: 0.0361, Val Loss: 0.0295
# Epoch [969/1000] Fold 10, Train Loss: 0.0358, Val Loss: 0.0304
# Epoch [970/1000] Fold 10, Train Loss: 0.0344, Val Loss: 0.0298
# Epoch [971/1000] Fold 10, Train Loss: 0.0360, Val Loss: 0.0299
# Epoch [972/1000] Fold 10, Train Loss: 0.0351, Val Loss: 0.0302
# Epoch [973/1000] Fold 10, Train Loss: 0.0355, Val Loss: 0.0301
# Epoch [974/1000] Fold 10, Train Loss: 0.0353, Val Loss: 0.0302
# Epoch [975/1000] Fold 10, Train Loss: 0.0356, Val Loss: 0.0301
# Epoch [976/1000] Fold 10, Train Loss: 0.0342, Val Loss: 0.0297
# Epoch [977/1000] Fold 10, Train Loss: 0.0353, Val Loss: 0.0299
# Epoch [978/1000] Fold 10, Train Loss: 0.0379, Val Loss: 0.0295
# Epoch [979/1000] Fold 10, Train Loss: 0.0354, Val Loss: 0.0299
# Epoch [980/1000] Fold 10, Train Loss: 0.0348, Val Loss: 0.0299
# Epoch [981/1000] Fold 10, Train Loss: 0.0356, Val Loss: 0.0294
# Epoch [982/1000] Fold 10, Train Loss: 0.0361, Val Loss: 0.0298
# Epoch [983/1000] Fold 10, Train Loss: 0.0351, Val Loss: 0.0298
# Epoch [984/1000] Fold 10, Train Loss: 0.0361, Val Loss: 0.0300
# Epoch [985/1000] Fold 10, Train Loss: 0.0353, Val Loss: 0.0301
# Epoch [986/1000] Fold 10, Train Loss: 0.0354, Val Loss: 0.0296
# Epoch [987/1000] Fold 10, Train Loss: 0.0357, Val Loss: 0.0297
# Epoch [988/1000] Fold 10, Train Loss: 0.0364, Val Loss: 0.0299
# Epoch [989/1000] Fold 10, Train Loss: 0.0357, Val Loss: 0.0301
# Epoch [990/1000] Fold 10, Train Loss: 0.0362, Val Loss: 0.0295
# Epoch [991/1000] Fold 10, Train Loss: 0.0367, Val Loss: 0.0301
# Epoch [992/1000] Fold 10, Train Loss: 0.0356, Val Loss: 0.0299
# Epoch [993/1000] Fold 10, Train Loss: 0.0352, Val Loss: 0.0296
# Epoch [994/1000] Fold 10, Train Loss: 0.0361, Val Loss: 0.0295
# Epoch [995/1000] Fold 10, Train Loss: 0.0351, Val Loss: 0.0294
# Epoch [996/1000] Fold 10, Train Loss: 0.0351, Val Loss: 0.0295
# Epoch [997/1000] Fold 10, Train Loss: 0.0361, Val Loss: 0.0299
# Epoch [998/1000] Fold 10, Train Loss: 0.0354, Val Loss: 0.0296
# Epoch [999/1000] Fold 10, Train Loss: 0.0361, Val Loss: 0.0302
# Epoch [1000/1000] Fold 10, Train Loss: 0.0356, Val Loss: 0.0293

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.0319

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.0334
#   Corresponding Training Loss = 0.0364
#   Best Epoch = 987
# Fold 2:
#   Best Validation Loss = 0.0336
#   Corresponding Training Loss = 0.0352
#   Best Epoch = 977
# Fold 3:
#   Best Validation Loss = 0.0279
#   Corresponding Training Loss = 0.0369
#   Best Epoch = 967
# Fold 4:
#   Best Validation Loss = 0.0274
#   Corresponding Training Loss = 0.0375
#   Best Epoch = 958
# Fold 5:
#   Best Validation Loss = 0.0323
#   Corresponding Training Loss = 0.0377
#   Best Epoch = 986
# Fold 6:
#   Best Validation Loss = 0.0288
#   Corresponding Training Loss = 0.0377
#   Best Epoch = 985
# Fold 7:
#   Best Validation Loss = 0.0336
#   Corresponding Training Loss = 0.0368
#   Best Epoch = 1000
# Fold 8:
#   Best Validation Loss = 0.0280
#   Corresponding Training Loss = 0.0353
#   Best Epoch = 988
# Fold 9:
#   Best Validation Loss = 0.0325
#   Corresponding Training Loss = 0.0376
#   Best Epoch = 979
# Fold 10:
#   Best Validation Loss = 0.0293
#   Corresponding Training Loss = 0.0356
#   Best Epoch = 1000

# %%
def plot_loss_curves_separately(cv_histories):
    """
    Plot training and validation loss curves for each fold in separate figures.
    
    Args:
        cv_histories (list): List of loss histories for each fold.
    """
    # Plot Training Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['train_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
    plt.title('Training Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['val_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
    plt.title('Validation Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_loss_curves_separately(cv_histories)

# %%
import torch
import numpy as np

# Track the best validation loss across all folds
lowest_val_loss = float('inf')
best_model_idx = -1  # Index of the best model
best_model_state = None

# Find the fold with the lowest validation loss
for fold_idx, history in enumerate(cv_histories):
    # Get the best validation loss for this fold
    best_val_loss = min(history['val_loss'])
    
    # Check if this is the lowest validation loss across all folds
    if best_val_loss < lowest_val_loss:
        lowest_val_loss = best_val_loss
        best_model_idx = fold_idx
        best_model_state = best_models[fold_idx]

# Save the model with the lowest validation loss
if best_model_state is not None:
    save_path = f'bestmodel_ex_{best_model_idx + 1}.pth'
    torch.save(best_model_state, save_path)
    print(f"Model from fold {best_model_idx + 1} with the lowest validation loss ({lowest_val_loss:.4f}) saved to {save_path}.")
else:
    print("No model to save.")
# Out:
# Model from fold 4 with the lowest validation loss (0.0274) saved to bestmodel_ex_4.pth.

# %%
s
