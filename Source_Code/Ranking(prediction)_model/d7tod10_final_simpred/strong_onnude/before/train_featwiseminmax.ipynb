# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import tifffile as tiff
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
from copy import deepcopy
import random

# %%
# Load the saved day 7 features
combined_ex7 = torch.load('combined_ex7.pt')

# Load the saved day 10 features
combined_ex10 = torch.load('combined_ex10.pt')
# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_ex7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_ex10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([646, 512])
# Loaded Day 10 Features Shape: torch.Size([646, 512])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_11176\1356550951.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_ex7 = torch.load('combined_ex7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_11176\1356550951.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_ex10 = torch.load('combined_ex10.pt')

# %%
# Load the saved day 7 features
combined_cond7 = torch.load('combined_cond7.pt')

# Load the saved day 10 features
combined_cond10 = torch.load('combined_cond10.pt')
# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_cond7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_cond10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([650, 512])
# Loaded Day 10 Features Shape: torch.Size([650, 512])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_11176\3329391658.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_cond7 = torch.load('combined_cond7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_11176\3329391658.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_cond10 = torch.load('combined_cond10.pt')

# %%
# Load the saved day 7 features
combined_sd7 = torch.load('combined_sd7.pt')

# Load the saved day 10 features
combined_sd10 = torch.load('combined_sd10.pt')

# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_sd7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_sd10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([638, 512])
# Loaded Day 10 Features Shape: torch.Size([638, 512])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_11176\1607657786.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_sd7 = torch.load('combined_sd7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_11176\1607657786.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_sd10 = torch.load('combined_sd10.pt')

# %%
train_day7_feats = combined_cond7 
train_day10_feats = combined_cond10

# %%
train_day7_feats = combined_sd7 
train_day10_feats = combined_sd10

# %%
train_day7_feats = combined_ex7 
train_day10_feats = combined_ex10

# %%
import matplotlib.pyplot as plt

# Plot histograms for input (X) and target (Y)
plt.figure(figsize=(12, 6))

# Flatten tensors to 1D for easier visualization
train_day7_feats_flat = train_day7_feats.flatten().cpu().numpy()
train_day10_feats_flat = train_day10_feats.flatten().cpu().numpy()

# Input (X) histogram
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_flat, bins=50, color='blue', alpha=0.7, label='Input (X)')
plt.title('Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_flat, bins=50, color='green', alpha=0.7, label='Target (Y)')
plt.title('Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"Input (X): Mean={train_day7_feats.mean():.4f}, Std={train_day7_feats.std():.4f}")
print(f"Target (Y): Mean={train_day10_feats.mean():.4f}, Std={train_day10_feats.std():.4f}")
# Out:
# Input (X): Mean=0.8592, Std=1.0920
# Target (Y): Mean=0.9172, Std=1.1365

# %%
# Convert PyTorch tensor to NumPy array
train_day7_feats_numpy = train_day7_feats.numpy()
train_day10_feats_numpy = train_day10_feats.numpy()

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize separate MinMaxScaler for day7 and day10
scaler_day7 = MinMaxScaler()
scaler_day10 = MinMaxScaler()

# Fit and transform the train_day7_feats
train_day7_feats_minmaxed = scaler_day7.fit_transform(train_day7_feats_numpy)
print(train_day7_feats_minmaxed.shape)
# Get min and max values for day7
min_values_day7 = scaler_day7.data_min_
max_values_day7 = scaler_day7.data_max_

print(min_values_day7.shape)
print(max_values_day7.shape)
#print("Min values for day7:", min_values_day7)
#print("Max values for day7:", max_values_day7)

# Fit and transform the train_day10_feats (target)
train_day10_feats_minmaxed = scaler_day10.fit_transform(train_day10_feats_numpy)
print(train_day10_feats_minmaxed.shape)
# Get min and max values for day10
min_values_day10 = scaler_day10.data_min_
max_values_day10 = scaler_day10.data_max_

print(min_values_day10.shape)
print(max_values_day10.shape)
#print("Min values for day10:", min_values_day10)
#print("Max values for day10:", max_values_day10)

# Convert the scaled data back to PyTorch tensors (optional)
train_day7_feats_minmaxed = torch.tensor(train_day7_feats_minmaxed)
train_day10_feats_minmaxed = torch.tensor(train_day10_feats_minmaxed)
# Out:
# (638, 512)
# (512,)
# (512,)
# (638, 512)
# (512,)
# (512,)

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'ex7.pkl')
joblib.dump(scaler_day10, 'ex10.pkl')

print("Scalers saved!")

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'sd7.pkl')
joblib.dump(scaler_day10, 'sd10.pkl')

print("Scalers saved!")

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'cond7.pkl')
joblib.dump(scaler_day10, 'cond10.pkl')

print("Scalers saved!")

# %%
type(train_day7_feats_minmaxed)

# %%
import matplotlib.pyplot as plt

# Flatten the tensors for easier visualization
train_day7_feats_minmaxed_flat = train_day7_feats_minmaxed.flatten().cpu().numpy()
train_day10_feats_minmaxed_flat = train_day10_feats_minmaxed.flatten().cpu().numpy()

# Plot histograms
plt.figure(figsize=(12, 6))

# Input (X) histogram after Min-Max scaling
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_minmaxed_flat, bins=50, color='blue', alpha=0.7, label='Min-Max Scaled Input (X)')
plt.title('Min-Max Scaled Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram after Min-Max scaling
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_minmaxed_flat, bins=50, color='green', alpha=0.7, label='Min-Max Scaled Target (Y)')
plt.title('Min-Max Scaled Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# import torch
# import torch.nn as nn
#
# class FeaturePredictor(nn.Module):
#     def __init__(self, input_size=20, output_size=20):
#         super().__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_size, 16),
#             nn.BatchNorm1d(16),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(16, 8),
#             nn.BatchNorm1d(8),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(8, 4),
#             nn.BatchNorm1d(4),
#         )
#         self.decoder = nn.Sequential(
#             nn.Linear(4, 8),
#             nn.BatchNorm1d(8),
#             nn.ReLU(),
#             nn.Linear(8, 16),
#             nn.BatchNorm1d(16),
#             nn.ReLU(),
#             nn.Linear(16, output_size)
#         )
#
#     def forward(self, x):
#         x = self.encoder(x)
#         z = self.decoder(x)
#         return z
#
# # Example usage
# model = FeaturePredictor()
# print(model)

# %%
class FeaturePredictor(nn.Module):
    def __init__(self, input_size=512, output_size=512):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, 16),
            nn.BatchNorm1d(16),
        )
        self.decoder = nn.Sequential(
            nn.Linear(16, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Linear(64, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Linear(256, output_size)
        )
    
    # Corrected indentation for forward method
    def forward(self, x):
        x = self.encoder(x)
        z = self.decoder(x)
        return z

# %% [markdown]
# import torch.nn as nn
# from torch.utils.data import TensorDataset, DataLoader
#
# class FeaturePredictor(nn.Module):
#     def __init__(self, input_size=512, output_size=512):
#         super(FeaturePredictor, self).__init__()
#         self.model = nn.Sequential(
#             nn.Linear(input_size, 256),
#             nn.ReLU(),
#             nn.Linear(256, 128),
#             nn.ReLU(),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Linear(64, 32),
#             nn.ReLU(),
#             nn.Linear(32, 16),
#             nn.ReLU(),
#             nn.Linear(16,8),
#             nn.ReLU(),
#             nn.Linear(8, 16),
#             nn.ReLU(),
#             nn.Linear(16,32),
#             nn.ReLU(),
#             nn.Linear(32, 64),
#             nn.ReLU(),
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Linear(128,256),
#             nn.ReLU(),
#             nn.Linear(256, output_size)
#         )
#
#     def forward(self, x):
#         return self.model(x)

# %%
model = FeaturePredictor()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset

# %%
from torch.utils.data import TensorDataset

optimizer_class = torch.optim.Adam

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset
import numpy as np
import torch

# %%
class EarlyStopping:
    def __init__(self, patience=10, delta=0.0):
        """
        Args:
            patience (int): How many epochs to wait after the last validation loss improvement.
            delta (float): Minimum change in the validation loss to qualify as an improvement.
        """
        self.patience = patience
        self.delta = delta
        self.best_loss = None
        self.no_improvement_epochs = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.no_improvement_epochs = 0
        else:
            self.no_improvement_epochs += 1
            if self.no_improvement_epochs >= self.patience:
                self.early_stop = True


def cross_validate_with_early_stopping(
    model_class, dataset, criterion, optimizer_class, num_epochs=50, n_splits=10, patience=10, device='cuda'
):
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    histories = []
    best_models = []

    for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset)):
        print(f"Fold {fold + 1}/{n_splits}")

        # Create subsets for this fold
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        # Create DataLoaders
        train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

        # Initialize the model, optimizer, and early stopping for this fold
        model = model_class().to(device)
        optimizer = optimizer_class(model.parameters(), lr=1e-4)
        early_stopping = EarlyStopping(patience=patience)

        # Training and validation loop
        history = {'train_loss': [], 'val_loss': []}
        for epoch in range(num_epochs):
            # Training phase
            model.train()
            train_loss = 0.0
            for batch_inputs, batch_targets in train_loader:
                batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)

                # Forward pass
                outputs = model(batch_inputs)
                loss = criterion(outputs, batch_targets)
                train_loss += loss.item()

                # Backward pass and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            train_loss /= len(train_loader)
            history['train_loss'].append(train_loss)

            # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for batch_inputs, batch_targets in val_loader:
                    batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)
                    outputs = model(batch_inputs)
                    loss = criterion(outputs, batch_targets)
                    val_loss += loss.item()

            val_loss /= len(val_loader)
            history['val_loss'].append(val_loss)

            print(f"Epoch [{epoch + 1}/{num_epochs}] Fold {fold + 1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

            # Check early stopping
            early_stopping(val_loss)
            if early_stopping.early_stop:
                print(f"Early stopping at epoch {epoch + 1} for fold {fold + 1}")
                break

        # Save the best model for this fold
        best_models.append(model.state_dict())
        histories.append(history)

    return histories, best_models

# %%
# MIN MAX
dataset = TensorDataset(train_day7_feats_minmaxed, train_day10_feats_minmaxed)

cv_histories, best_models = cross_validate_with_early_stopping(
    model_class=FeaturePredictor,
    dataset=dataset,
    criterion=nn.MSELoss(),
    optimizer_class=torch.optim.Adam,
    num_epochs=1500,
    patience=500
)
# Out:
# Fold 1/10
# Epoch [1/1500] Fold 1, Train Loss: 0.2504, Val Loss: 0.1260
# Epoch [2/1500] Fold 1, Train Loss: 0.1824, Val Loss: 0.1096
# Epoch [3/1500] Fold 1, Train Loss: 0.1448, Val Loss: 0.0959
# Epoch [4/1500] Fold 1, Train Loss: 0.1207, Val Loss: 0.0846
# Epoch [5/1500] Fold 1, Train Loss: 0.1040, Val Loss: 0.0756
# Epoch [6/1500] Fold 1, Train Loss: 0.0920, Val Loss: 0.0665
# Epoch [7/1500] Fold 1, Train Loss: 0.0821, Val Loss: 0.0606
# Epoch [8/1500] Fold 1, Train Loss: 0.0744, Val Loss: 0.0562
# Epoch [9/1500] Fold 1, Train Loss: 0.0684, Val Loss: 0.0530
# Epoch [10/1500] Fold 1, Train Loss: 0.0639, Val Loss: 0.0499
# Epoch [11/1500] Fold 1, Train Loss: 0.0602, Val Loss: 0.0481
# Epoch [12/1500] Fold 1, Train Loss: 0.0585, Val Loss: 0.0467
# Epoch [13/1500] Fold 1, Train Loss: 0.0561, Val Loss: 0.0454
# Epoch [14/1500] Fold 1, Train Loss: 0.0537, Val Loss: 0.0443
# Epoch [15/1500] Fold 1, Train Loss: 0.0511, Val Loss: 0.0436
# Epoch [16/1500] Fold 1, Train Loss: 0.0504, Val Loss: 0.0426
# Epoch [17/1500] Fold 1, Train Loss: 0.0498, Val Loss: 0.0421
# Epoch [18/1500] Fold 1, Train Loss: 0.0481, Val Loss: 0.0418
# Epoch [19/1500] Fold 1, Train Loss: 0.0474, Val Loss: 0.0414
# Epoch [20/1500] Fold 1, Train Loss: 0.0466, Val Loss: 0.0408
# Epoch [21/1500] Fold 1, Train Loss: 0.0457, Val Loss: 0.0407
# Epoch [22/1500] Fold 1, Train Loss: 0.0449, Val Loss: 0.0401
# Epoch [23/1500] Fold 1, Train Loss: 0.0443, Val Loss: 0.0400
# Epoch [24/1500] Fold 1, Train Loss: 0.0448, Val Loss: 0.0398
# Epoch [25/1500] Fold 1, Train Loss: 0.0438, Val Loss: 0.0395
# Epoch [26/1500] Fold 1, Train Loss: 0.0441, Val Loss: 0.0395
# Epoch [27/1500] Fold 1, Train Loss: 0.0429, Val Loss: 0.0392
# Epoch [28/1500] Fold 1, Train Loss: 0.0429, Val Loss: 0.0390
# Epoch [29/1500] Fold 1, Train Loss: 0.0412, Val Loss: 0.0387
# Epoch [30/1500] Fold 1, Train Loss: 0.0415, Val Loss: 0.0388
# Epoch [31/1500] Fold 1, Train Loss: 0.0420, Val Loss: 0.0385
# Epoch [32/1500] Fold 1, Train Loss: 0.0419, Val Loss: 0.0385
# Epoch [33/1500] Fold 1, Train Loss: 0.0407, Val Loss: 0.0383
# Epoch [34/1500] Fold 1, Train Loss: 0.0415, Val Loss: 0.0381
# Epoch [35/1500] Fold 1, Train Loss: 0.0410, Val Loss: 0.0379
# Epoch [36/1500] Fold 1, Train Loss: 0.0401, Val Loss: 0.0380
# Epoch [37/1500] Fold 1, Train Loss: 0.0399, Val Loss: 0.0378
# Epoch [38/1500] Fold 1, Train Loss: 0.0394, Val Loss: 0.0377
# Epoch [39/1500] Fold 1, Train Loss: 0.0403, Val Loss: 0.0376
# Epoch [40/1500] Fold 1, Train Loss: 0.0391, Val Loss: 0.0375
# Epoch [41/1500] Fold 1, Train Loss: 0.0393, Val Loss: 0.0374
# Epoch [42/1500] Fold 1, Train Loss: 0.0394, Val Loss: 0.0377
# Epoch [43/1500] Fold 1, Train Loss: 0.0389, Val Loss: 0.0374
# Epoch [44/1500] Fold 1, Train Loss: 0.0392, Val Loss: 0.0373
# Epoch [45/1500] Fold 1, Train Loss: 0.0390, Val Loss: 0.0369
# Epoch [46/1500] Fold 1, Train Loss: 0.0389, Val Loss: 0.0373
# Epoch [47/1500] Fold 1, Train Loss: 0.0383, Val Loss: 0.0371
# Epoch [48/1500] Fold 1, Train Loss: 0.0385, Val Loss: 0.0372
# Epoch [49/1500] Fold 1, Train Loss: 0.0383, Val Loss: 0.0371
# Epoch [50/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0370
# Epoch [51/1500] Fold 1, Train Loss: 0.0388, Val Loss: 0.0367
# Epoch [52/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0367
# Epoch [53/1500] Fold 1, Train Loss: 0.0383, Val Loss: 0.0365
# Epoch [54/1500] Fold 1, Train Loss: 0.0378, Val Loss: 0.0367
# Epoch [55/1500] Fold 1, Train Loss: 0.0376, Val Loss: 0.0367
# Epoch [56/1500] Fold 1, Train Loss: 0.0369, Val Loss: 0.0364
# Epoch [57/1500] Fold 1, Train Loss: 0.0373, Val Loss: 0.0368
# Epoch [58/1500] Fold 1, Train Loss: 0.0372, Val Loss: 0.0365
# Epoch [59/1500] Fold 1, Train Loss: 0.0376, Val Loss: 0.0367
# Epoch [60/1500] Fold 1, Train Loss: 0.0367, Val Loss: 0.0365
# Epoch [61/1500] Fold 1, Train Loss: 0.0372, Val Loss: 0.0367
# Epoch [62/1500] Fold 1, Train Loss: 0.0368, Val Loss: 0.0367
# Epoch [63/1500] Fold 1, Train Loss: 0.0369, Val Loss: 0.0365
# Epoch [64/1500] Fold 1, Train Loss: 0.0362, Val Loss: 0.0368
# Epoch [65/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0364
# Epoch [66/1500] Fold 1, Train Loss: 0.0372, Val Loss: 0.0361
# Epoch [67/1500] Fold 1, Train Loss: 0.0363, Val Loss: 0.0365
# Epoch [68/1500] Fold 1, Train Loss: 0.0362, Val Loss: 0.0367
# Epoch [69/1500] Fold 1, Train Loss: 0.0360, Val Loss: 0.0365
# Epoch [70/1500] Fold 1, Train Loss: 0.0362, Val Loss: 0.0367
# Epoch [71/1500] Fold 1, Train Loss: 0.0357, Val Loss: 0.0365
# Epoch [72/1500] Fold 1, Train Loss: 0.0360, Val Loss: 0.0364
# Epoch [73/1500] Fold 1, Train Loss: 0.0354, Val Loss: 0.0368
# Epoch [74/1500] Fold 1, Train Loss: 0.0359, Val Loss: 0.0362
# Epoch [75/1500] Fold 1, Train Loss: 0.0363, Val Loss: 0.0360
# Epoch [76/1500] Fold 1, Train Loss: 0.0362, Val Loss: 0.0364
# Epoch [77/1500] Fold 1, Train Loss: 0.0360, Val Loss: 0.0366
# Epoch [78/1500] Fold 1, Train Loss: 0.0350, Val Loss: 0.0367
# Epoch [79/1500] Fold 1, Train Loss: 0.0357, Val Loss: 0.0365
# Epoch [80/1500] Fold 1, Train Loss: 0.0356, Val Loss: 0.0370
# Epoch [81/1500] Fold 1, Train Loss: 0.0351, Val Loss: 0.0370
# Epoch [82/1500] Fold 1, Train Loss: 0.0355, Val Loss: 0.0365
# Epoch [83/1500] Fold 1, Train Loss: 0.0348, Val Loss: 0.0365
# Epoch [84/1500] Fold 1, Train Loss: 0.0347, Val Loss: 0.0369
# Epoch [85/1500] Fold 1, Train Loss: 0.0348, Val Loss: 0.0367
# Epoch [86/1500] Fold 1, Train Loss: 0.0350, Val Loss: 0.0367
# Epoch [87/1500] Fold 1, Train Loss: 0.0353, Val Loss: 0.0371
# Epoch [88/1500] Fold 1, Train Loss: 0.0347, Val Loss: 0.0361
# Epoch [89/1500] Fold 1, Train Loss: 0.0348, Val Loss: 0.0363
# Epoch [90/1500] Fold 1, Train Loss: 0.0344, Val Loss: 0.0366
# Epoch [91/1500] Fold 1, Train Loss: 0.0345, Val Loss: 0.0368
# Epoch [92/1500] Fold 1, Train Loss: 0.0345, Val Loss: 0.0371
# Epoch [93/1500] Fold 1, Train Loss: 0.0338, Val Loss: 0.0372
# Epoch [94/1500] Fold 1, Train Loss: 0.0347, Val Loss: 0.0370
# Epoch [95/1500] Fold 1, Train Loss: 0.0340, Val Loss: 0.0376
# Epoch [96/1500] Fold 1, Train Loss: 0.0342, Val Loss: 0.0367
# Epoch [97/1500] Fold 1, Train Loss: 0.0332, Val Loss: 0.0376
# Epoch [98/1500] Fold 1, Train Loss: 0.0338, Val Loss: 0.0381
# Epoch [99/1500] Fold 1, Train Loss: 0.0340, Val Loss: 0.0376
# Epoch [100/1500] Fold 1, Train Loss: 0.0340, Val Loss: 0.0371
# Epoch [101/1500] Fold 1, Train Loss: 0.0336, Val Loss: 0.0371
# Epoch [102/1500] Fold 1, Train Loss: 0.0334, Val Loss: 0.0373
# Epoch [103/1500] Fold 1, Train Loss: 0.0334, Val Loss: 0.0373
# Epoch [104/1500] Fold 1, Train Loss: 0.0334, Val Loss: 0.0378
# Epoch [105/1500] Fold 1, Train Loss: 0.0330, Val Loss: 0.0376
# Epoch [106/1500] Fold 1, Train Loss: 0.0331, Val Loss: 0.0368
# Epoch [107/1500] Fold 1, Train Loss: 0.0326, Val Loss: 0.0381
# Epoch [108/1500] Fold 1, Train Loss: 0.0333, Val Loss: 0.0384
# Epoch [109/1500] Fold 1, Train Loss: 0.0336, Val Loss: 0.0376
# Epoch [110/1500] Fold 1, Train Loss: 0.0333, Val Loss: 0.0379
# Epoch [111/1500] Fold 1, Train Loss: 0.0334, Val Loss: 0.0378
# Epoch [112/1500] Fold 1, Train Loss: 0.0328, Val Loss: 0.0373
# Epoch [113/1500] Fold 1, Train Loss: 0.0326, Val Loss: 0.0377
# Epoch [114/1500] Fold 1, Train Loss: 0.0326, Val Loss: 0.0370
# Epoch [115/1500] Fold 1, Train Loss: 0.0332, Val Loss: 0.0369
# Epoch [116/1500] Fold 1, Train Loss: 0.0330, Val Loss: 0.0374
# Epoch [117/1500] Fold 1, Train Loss: 0.0325, Val Loss: 0.0374
# Epoch [118/1500] Fold 1, Train Loss: 0.0330, Val Loss: 0.0376
# Epoch [119/1500] Fold 1, Train Loss: 0.0325, Val Loss: 0.0378
# Epoch [120/1500] Fold 1, Train Loss: 0.0326, Val Loss: 0.0389
# Epoch [121/1500] Fold 1, Train Loss: 0.0328, Val Loss: 0.0373
# Epoch [122/1500] Fold 1, Train Loss: 0.0331, Val Loss: 0.0374
# Epoch [123/1500] Fold 1, Train Loss: 0.0325, Val Loss: 0.0366
# Epoch [124/1500] Fold 1, Train Loss: 0.0335, Val Loss: 0.0369
# Epoch [125/1500] Fold 1, Train Loss: 0.0326, Val Loss: 0.0368
# Epoch [126/1500] Fold 1, Train Loss: 0.0321, Val Loss: 0.0379
# Epoch [127/1500] Fold 1, Train Loss: 0.0317, Val Loss: 0.0377
# Epoch [128/1500] Fold 1, Train Loss: 0.0321, Val Loss: 0.0372
# Epoch [129/1500] Fold 1, Train Loss: 0.0324, Val Loss: 0.0378
# Epoch [130/1500] Fold 1, Train Loss: 0.0320, Val Loss: 0.0375
# Epoch [131/1500] Fold 1, Train Loss: 0.0320, Val Loss: 0.0375
# Epoch [132/1500] Fold 1, Train Loss: 0.0314, Val Loss: 0.0380
# Epoch [133/1500] Fold 1, Train Loss: 0.0326, Val Loss: 0.0375
# Epoch [134/1500] Fold 1, Train Loss: 0.0320, Val Loss: 0.0381
# Epoch [135/1500] Fold 1, Train Loss: 0.0326, Val Loss: 0.0385
# Epoch [136/1500] Fold 1, Train Loss: 0.0320, Val Loss: 0.0372
# Epoch [137/1500] Fold 1, Train Loss: 0.0313, Val Loss: 0.0380
# Epoch [138/1500] Fold 1, Train Loss: 0.0319, Val Loss: 0.0377
# Epoch [139/1500] Fold 1, Train Loss: 0.0318, Val Loss: 0.0380
# Epoch [140/1500] Fold 1, Train Loss: 0.0323, Val Loss: 0.0377
# Epoch [141/1500] Fold 1, Train Loss: 0.0316, Val Loss: 0.0382
# Epoch [142/1500] Fold 1, Train Loss: 0.0319, Val Loss: 0.0381
# Epoch [143/1500] Fold 1, Train Loss: 0.0318, Val Loss: 0.0373
# Epoch [144/1500] Fold 1, Train Loss: 0.0320, Val Loss: 0.0388
# Epoch [145/1500] Fold 1, Train Loss: 0.0315, Val Loss: 0.0372
# Epoch [146/1500] Fold 1, Train Loss: 0.0316, Val Loss: 0.0379
# Epoch [147/1500] Fold 1, Train Loss: 0.0316, Val Loss: 0.0384
# Epoch [148/1500] Fold 1, Train Loss: 0.0316, Val Loss: 0.0382
# Epoch [149/1500] Fold 1, Train Loss: 0.0314, Val Loss: 0.0370
# Epoch [150/1500] Fold 1, Train Loss: 0.0316, Val Loss: 0.0371
# Epoch [151/1500] Fold 1, Train Loss: 0.0315, Val Loss: 0.0374
# Epoch [152/1500] Fold 1, Train Loss: 0.0316, Val Loss: 0.0383
# Epoch [153/1500] Fold 1, Train Loss: 0.0308, Val Loss: 0.0379
# Epoch [154/1500] Fold 1, Train Loss: 0.0318, Val Loss: 0.0383
# Epoch [155/1500] Fold 1, Train Loss: 0.0311, Val Loss: 0.0373
# Epoch [156/1500] Fold 1, Train Loss: 0.0304, Val Loss: 0.0377
# Epoch [157/1500] Fold 1, Train Loss: 0.0314, Val Loss: 0.0377
# Epoch [158/1500] Fold 1, Train Loss: 0.0318, Val Loss: 0.0376
# Epoch [159/1500] Fold 1, Train Loss: 0.0306, Val Loss: 0.0370
# Epoch [160/1500] Fold 1, Train Loss: 0.0306, Val Loss: 0.0391
# Epoch [161/1500] Fold 1, Train Loss: 0.0310, Val Loss: 0.0386
# Epoch [162/1500] Fold 1, Train Loss: 0.0317, Val Loss: 0.0381
# Epoch [163/1500] Fold 1, Train Loss: 0.0316, Val Loss: 0.0374
# Epoch [164/1500] Fold 1, Train Loss: 0.0309, Val Loss: 0.0375
# Epoch [165/1500] Fold 1, Train Loss: 0.0307, Val Loss: 0.0372
# Epoch [166/1500] Fold 1, Train Loss: 0.0314, Val Loss: 0.0378
# Epoch [167/1500] Fold 1, Train Loss: 0.0308, Val Loss: 0.0373
# Epoch [168/1500] Fold 1, Train Loss: 0.0304, Val Loss: 0.0369
# Epoch [169/1500] Fold 1, Train Loss: 0.0303, Val Loss: 0.0378
# Epoch [170/1500] Fold 1, Train Loss: 0.0304, Val Loss: 0.0379
# Epoch [171/1500] Fold 1, Train Loss: 0.0306, Val Loss: 0.0368
# Epoch [172/1500] Fold 1, Train Loss: 0.0305, Val Loss: 0.0387
# Epoch [173/1500] Fold 1, Train Loss: 0.0304, Val Loss: 0.0372
# Epoch [174/1500] Fold 1, Train Loss: 0.0310, Val Loss: 0.0371
# Epoch [175/1500] Fold 1, Train Loss: 0.0312, Val Loss: 0.0370
# Epoch [176/1500] Fold 1, Train Loss: 0.0306, Val Loss: 0.0377
# Epoch [177/1500] Fold 1, Train Loss: 0.0304, Val Loss: 0.0374
# Epoch [178/1500] Fold 1, Train Loss: 0.0294, Val Loss: 0.0377
# Epoch [179/1500] Fold 1, Train Loss: 0.0300, Val Loss: 0.0393
# Epoch [180/1500] Fold 1, Train Loss: 0.0303, Val Loss: 0.0381
# Epoch [181/1500] Fold 1, Train Loss: 0.0313, Val Loss: 0.0393
# Epoch [182/1500] Fold 1, Train Loss: 0.0300, Val Loss: 0.0380
# Epoch [183/1500] Fold 1, Train Loss: 0.0302, Val Loss: 0.0385
# Epoch [184/1500] Fold 1, Train Loss: 0.0296, Val Loss: 0.0388
# Epoch [185/1500] Fold 1, Train Loss: 0.0293, Val Loss: 0.0385
# Epoch [186/1500] Fold 1, Train Loss: 0.0315, Val Loss: 0.0379
# Epoch [187/1500] Fold 1, Train Loss: 0.0306, Val Loss: 0.0382
# Epoch [188/1500] Fold 1, Train Loss: 0.0301, Val Loss: 0.0373
# Epoch [189/1500] Fold 1, Train Loss: 0.0296, Val Loss: 0.0372
# Epoch [190/1500] Fold 1, Train Loss: 0.0301, Val Loss: 0.0390
# Epoch [191/1500] Fold 1, Train Loss: 0.0298, Val Loss: 0.0385
# Epoch [192/1500] Fold 1, Train Loss: 0.0295, Val Loss: 0.0382
# Epoch [193/1500] Fold 1, Train Loss: 0.0303, Val Loss: 0.0398
# Epoch [194/1500] Fold 1, Train Loss: 0.0297, Val Loss: 0.0373
# Epoch [195/1500] Fold 1, Train Loss: 0.0303, Val Loss: 0.0376
# Epoch [196/1500] Fold 1, Train Loss: 0.0305, Val Loss: 0.0378
# Epoch [197/1500] Fold 1, Train Loss: 0.0301, Val Loss: 0.0369
# Epoch [198/1500] Fold 1, Train Loss: 0.0300, Val Loss: 0.0377
# Epoch [199/1500] Fold 1, Train Loss: 0.0302, Val Loss: 0.0370
# Epoch [200/1500] Fold 1, Train Loss: 0.0295, Val Loss: 0.0379
# Epoch [201/1500] Fold 1, Train Loss: 0.0296, Val Loss: 0.0374
# Epoch [202/1500] Fold 1, Train Loss: 0.0295, Val Loss: 0.0366
# Epoch [203/1500] Fold 1, Train Loss: 0.0292, Val Loss: 0.0386
# Epoch [204/1500] Fold 1, Train Loss: 0.0292, Val Loss: 0.0377
# Epoch [205/1500] Fold 1, Train Loss: 0.0290, Val Loss: 0.0395
# Epoch [206/1500] Fold 1, Train Loss: 0.0297, Val Loss: 0.0376
# Epoch [207/1500] Fold 1, Train Loss: 0.0302, Val Loss: 0.0383
# Epoch [208/1500] Fold 1, Train Loss: 0.0295, Val Loss: 0.0378
# Epoch [209/1500] Fold 1, Train Loss: 0.0298, Val Loss: 0.0385
# Epoch [210/1500] Fold 1, Train Loss: 0.0296, Val Loss: 0.0378
# Epoch [211/1500] Fold 1, Train Loss: 0.0299, Val Loss: 0.0388
# Epoch [212/1500] Fold 1, Train Loss: 0.0291, Val Loss: 0.0385
# Epoch [213/1500] Fold 1, Train Loss: 0.0292, Val Loss: 0.0374
# Epoch [214/1500] Fold 1, Train Loss: 0.0290, Val Loss: 0.0382
# Epoch [215/1500] Fold 1, Train Loss: 0.0294, Val Loss: 0.0381
# Epoch [216/1500] Fold 1, Train Loss: 0.0295, Val Loss: 0.0391
# Epoch [217/1500] Fold 1, Train Loss: 0.0286, Val Loss: 0.0390
# Epoch [218/1500] Fold 1, Train Loss: 0.0288, Val Loss: 0.0393
# Epoch [219/1500] Fold 1, Train Loss: 0.0300, Val Loss: 0.0390
# Epoch [220/1500] Fold 1, Train Loss: 0.0287, Val Loss: 0.0383
# Epoch [221/1500] Fold 1, Train Loss: 0.0291, Val Loss: 0.0384
# Epoch [222/1500] Fold 1, Train Loss: 0.0292, Val Loss: 0.0390
# Epoch [223/1500] Fold 1, Train Loss: 0.0287, Val Loss: 0.0385
# Epoch [224/1500] Fold 1, Train Loss: 0.0291, Val Loss: 0.0387
# Epoch [225/1500] Fold 1, Train Loss: 0.0290, Val Loss: 0.0378
# Epoch [226/1500] Fold 1, Train Loss: 0.0289, Val Loss: 0.0384
# Epoch [227/1500] Fold 1, Train Loss: 0.0293, Val Loss: 0.0378
# Epoch [228/1500] Fold 1, Train Loss: 0.0295, Val Loss: 0.0387
# Epoch [229/1500] Fold 1, Train Loss: 0.0290, Val Loss: 0.0386
# Epoch [230/1500] Fold 1, Train Loss: 0.0291, Val Loss: 0.0386
# Epoch [231/1500] Fold 1, Train Loss: 0.0280, Val Loss: 0.0381
# Epoch [232/1500] Fold 1, Train Loss: 0.0290, Val Loss: 0.0390
# Epoch [233/1500] Fold 1, Train Loss: 0.0296, Val Loss: 0.0392
# Epoch [234/1500] Fold 1, Train Loss: 0.0286, Val Loss: 0.0389
# Epoch [235/1500] Fold 1, Train Loss: 0.0284, Val Loss: 0.0391
# Epoch [236/1500] Fold 1, Train Loss: 0.0289, Val Loss: 0.0379
# Epoch [237/1500] Fold 1, Train Loss: 0.0291, Val Loss: 0.0390
# Epoch [238/1500] Fold 1, Train Loss: 0.0284, Val Loss: 0.0387
# Epoch [239/1500] Fold 1, Train Loss: 0.0295, Val Loss: 0.0393
# Epoch [240/1500] Fold 1, Train Loss: 0.0284, Val Loss: 0.0381
# Epoch [241/1500] Fold 1, Train Loss: 0.0284, Val Loss: 0.0385
# Epoch [242/1500] Fold 1, Train Loss: 0.0293, Val Loss: 0.0386
# Epoch [243/1500] Fold 1, Train Loss: 0.0285, Val Loss: 0.0376
# Epoch [244/1500] Fold 1, Train Loss: 0.0289, Val Loss: 0.0372
# Epoch [245/1500] Fold 1, Train Loss: 0.0287, Val Loss: 0.0397
# Epoch [246/1500] Fold 1, Train Loss: 0.0287, Val Loss: 0.0371
# Epoch [247/1500] Fold 1, Train Loss: 0.0282, Val Loss: 0.0378
# Epoch [248/1500] Fold 1, Train Loss: 0.0288, Val Loss: 0.0384
# Epoch [249/1500] Fold 1, Train Loss: 0.0280, Val Loss: 0.0390
# Epoch [250/1500] Fold 1, Train Loss: 0.0289, Val Loss: 0.0397
# Epoch [251/1500] Fold 1, Train Loss: 0.0287, Val Loss: 0.0393
# Epoch [252/1500] Fold 1, Train Loss: 0.0286, Val Loss: 0.0384
# Epoch [253/1500] Fold 1, Train Loss: 0.0278, Val Loss: 0.0387
# Epoch [254/1500] Fold 1, Train Loss: 0.0288, Val Loss: 0.0381
# Epoch [255/1500] Fold 1, Train Loss: 0.0288, Val Loss: 0.0392
# Epoch [256/1500] Fold 1, Train Loss: 0.0293, Val Loss: 0.0376
# Epoch [257/1500] Fold 1, Train Loss: 0.0280, Val Loss: 0.0396
# Epoch [258/1500] Fold 1, Train Loss: 0.0281, Val Loss: 0.0395
# Epoch [259/1500] Fold 1, Train Loss: 0.0287, Val Loss: 0.0378
# Epoch [260/1500] Fold 1, Train Loss: 0.0287, Val Loss: 0.0386
# Epoch [261/1500] Fold 1, Train Loss: 0.0285, Val Loss: 0.0378
# Epoch [262/1500] Fold 1, Train Loss: 0.0282, Val Loss: 0.0388
# Epoch [263/1500] Fold 1, Train Loss: 0.0280, Val Loss: 0.0379
# Epoch [264/1500] Fold 1, Train Loss: 0.0282, Val Loss: 0.0395
# Epoch [265/1500] Fold 1, Train Loss: 0.0282, Val Loss: 0.0382
# Epoch [266/1500] Fold 1, Train Loss: 0.0282, Val Loss: 0.0393
# Epoch [267/1500] Fold 1, Train Loss: 0.0284, Val Loss: 0.0396
# Epoch [268/1500] Fold 1, Train Loss: 0.0278, Val Loss: 0.0381
# Epoch [269/1500] Fold 1, Train Loss: 0.0285, Val Loss: 0.0377
# Epoch [270/1500] Fold 1, Train Loss: 0.0284, Val Loss: 0.0376
# Epoch [271/1500] Fold 1, Train Loss: 0.0277, Val Loss: 0.0411
# Epoch [272/1500] Fold 1, Train Loss: 0.0281, Val Loss: 0.0393
# Epoch [273/1500] Fold 1, Train Loss: 0.0273, Val Loss: 0.0391
# Epoch [274/1500] Fold 1, Train Loss: 0.0276, Val Loss: 0.0388
# Epoch [275/1500] Fold 1, Train Loss: 0.0283, Val Loss: 0.0387
# Epoch [276/1500] Fold 1, Train Loss: 0.0274, Val Loss: 0.0380
# Epoch [277/1500] Fold 1, Train Loss: 0.0278, Val Loss: 0.0382
# Epoch [278/1500] Fold 1, Train Loss: 0.0283, Val Loss: 0.0378
# Epoch [279/1500] Fold 1, Train Loss: 0.0279, Val Loss: 0.0388
# Epoch [280/1500] Fold 1, Train Loss: 0.0277, Val Loss: 0.0379
# Epoch [281/1500] Fold 1, Train Loss: 0.0279, Val Loss: 0.0383
# Epoch [282/1500] Fold 1, Train Loss: 0.0278, Val Loss: 0.0383
# Epoch [283/1500] Fold 1, Train Loss: 0.0276, Val Loss: 0.0377
# Epoch [284/1500] Fold 1, Train Loss: 0.0277, Val Loss: 0.0389
# Epoch [285/1500] Fold 1, Train Loss: 0.0273, Val Loss: 0.0375
# Epoch [286/1500] Fold 1, Train Loss: 0.0279, Val Loss: 0.0380
# Epoch [287/1500] Fold 1, Train Loss: 0.0270, Val Loss: 0.0379
# Epoch [288/1500] Fold 1, Train Loss: 0.0282, Val Loss: 0.0387
# Epoch [289/1500] Fold 1, Train Loss: 0.0287, Val Loss: 0.0367
# Epoch [290/1500] Fold 1, Train Loss: 0.0281, Val Loss: 0.0387
# Epoch [291/1500] Fold 1, Train Loss: 0.0277, Val Loss: 0.0368
# Epoch [292/1500] Fold 1, Train Loss: 0.0276, Val Loss: 0.0392
# Epoch [293/1500] Fold 1, Train Loss: 0.0279, Val Loss: 0.0389
# Epoch [294/1500] Fold 1, Train Loss: 0.0275, Val Loss: 0.0385
# Epoch [295/1500] Fold 1, Train Loss: 0.0279, Val Loss: 0.0370
# Epoch [296/1500] Fold 1, Train Loss: 0.0280, Val Loss: 0.0378
# Epoch [297/1500] Fold 1, Train Loss: 0.0280, Val Loss: 0.0397
# Epoch [298/1500] Fold 1, Train Loss: 0.0277, Val Loss: 0.0396
# Epoch [299/1500] Fold 1, Train Loss: 0.0277, Val Loss: 0.0372
# Epoch [300/1500] Fold 1, Train Loss: 0.0278, Val Loss: 0.0388
# Epoch [301/1500] Fold 1, Train Loss: 0.0279, Val Loss: 0.0369
# Epoch [302/1500] Fold 1, Train Loss: 0.0277, Val Loss: 0.0388
# Epoch [303/1500] Fold 1, Train Loss: 0.0280, Val Loss: 0.0372
# Epoch [304/1500] Fold 1, Train Loss: 0.0280, Val Loss: 0.0377
# Epoch [305/1500] Fold 1, Train Loss: 0.0268, Val Loss: 0.0370
# Epoch [306/1500] Fold 1, Train Loss: 0.0272, Val Loss: 0.0392
# Epoch [307/1500] Fold 1, Train Loss: 0.0269, Val Loss: 0.0374
# Epoch [308/1500] Fold 1, Train Loss: 0.0282, Val Loss: 0.0387
# Epoch [309/1500] Fold 1, Train Loss: 0.0281, Val Loss: 0.0394
# Epoch [310/1500] Fold 1, Train Loss: 0.0273, Val Loss: 0.0385
# Epoch [311/1500] Fold 1, Train Loss: 0.0279, Val Loss: 0.0380
# Epoch [312/1500] Fold 1, Train Loss: 0.0265, Val Loss: 0.0382
# Epoch [313/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0403
# Epoch [314/1500] Fold 1, Train Loss: 0.0272, Val Loss: 0.0380
# Epoch [315/1500] Fold 1, Train Loss: 0.0273, Val Loss: 0.0371
# Epoch [316/1500] Fold 1, Train Loss: 0.0266, Val Loss: 0.0391
# Epoch [317/1500] Fold 1, Train Loss: 0.0276, Val Loss: 0.0377
# Epoch [318/1500] Fold 1, Train Loss: 0.0277, Val Loss: 0.0377
# Epoch [319/1500] Fold 1, Train Loss: 0.0282, Val Loss: 0.0387
# Epoch [320/1500] Fold 1, Train Loss: 0.0273, Val Loss: 0.0379
# Epoch [321/1500] Fold 1, Train Loss: 0.0270, Val Loss: 0.0394
# Epoch [322/1500] Fold 1, Train Loss: 0.0277, Val Loss: 0.0375
# Epoch [323/1500] Fold 1, Train Loss: 0.0275, Val Loss: 0.0384
# Epoch [324/1500] Fold 1, Train Loss: 0.0267, Val Loss: 0.0378
# Epoch [325/1500] Fold 1, Train Loss: 0.0276, Val Loss: 0.0398
# Epoch [326/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0375
# Epoch [327/1500] Fold 1, Train Loss: 0.0275, Val Loss: 0.0391
# Epoch [328/1500] Fold 1, Train Loss: 0.0274, Val Loss: 0.0390
# Epoch [329/1500] Fold 1, Train Loss: 0.0275, Val Loss: 0.0375
# Epoch [330/1500] Fold 1, Train Loss: 0.0273, Val Loss: 0.0376
# Epoch [331/1500] Fold 1, Train Loss: 0.0270, Val Loss: 0.0407
# Epoch [332/1500] Fold 1, Train Loss: 0.0273, Val Loss: 0.0378
# Epoch [333/1500] Fold 1, Train Loss: 0.0268, Val Loss: 0.0385
# Epoch [334/1500] Fold 1, Train Loss: 0.0267, Val Loss: 0.0379
# Epoch [335/1500] Fold 1, Train Loss: 0.0269, Val Loss: 0.0384
# Epoch [336/1500] Fold 1, Train Loss: 0.0274, Val Loss: 0.0383
# Epoch [337/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0392
# Epoch [338/1500] Fold 1, Train Loss: 0.0272, Val Loss: 0.0385
# Epoch [339/1500] Fold 1, Train Loss: 0.0266, Val Loss: 0.0383
# Epoch [340/1500] Fold 1, Train Loss: 0.0267, Val Loss: 0.0377
# Epoch [341/1500] Fold 1, Train Loss: 0.0269, Val Loss: 0.0382
# Epoch [342/1500] Fold 1, Train Loss: 0.0268, Val Loss: 0.0398
# Epoch [343/1500] Fold 1, Train Loss: 0.0274, Val Loss: 0.0372
# Epoch [344/1500] Fold 1, Train Loss: 0.0265, Val Loss: 0.0393
# Epoch [345/1500] Fold 1, Train Loss: 0.0268, Val Loss: 0.0378
# Epoch [346/1500] Fold 1, Train Loss: 0.0267, Val Loss: 0.0388
# Epoch [347/1500] Fold 1, Train Loss: 0.0266, Val Loss: 0.0392
# Epoch [348/1500] Fold 1, Train Loss: 0.0261, Val Loss: 0.0384
# Epoch [349/1500] Fold 1, Train Loss: 0.0274, Val Loss: 0.0396
# Epoch [350/1500] Fold 1, Train Loss: 0.0268, Val Loss: 0.0383
# Epoch [351/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0393
# Epoch [352/1500] Fold 1, Train Loss: 0.0274, Val Loss: 0.0374
# Epoch [353/1500] Fold 1, Train Loss: 0.0267, Val Loss: 0.0373
# Epoch [354/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0391
# Epoch [355/1500] Fold 1, Train Loss: 0.0270, Val Loss: 0.0384
# Epoch [356/1500] Fold 1, Train Loss: 0.0271, Val Loss: 0.0396
# Epoch [357/1500] Fold 1, Train Loss: 0.0272, Val Loss: 0.0392
# Epoch [358/1500] Fold 1, Train Loss: 0.0263, Val Loss: 0.0385
# Epoch [359/1500] Fold 1, Train Loss: 0.0263, Val Loss: 0.0365
# Epoch [360/1500] Fold 1, Train Loss: 0.0265, Val Loss: 0.0362
# Epoch [361/1500] Fold 1, Train Loss: 0.0273, Val Loss: 0.0384
# Epoch [362/1500] Fold 1, Train Loss: 0.0267, Val Loss: 0.0390
# Epoch [363/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0385
# Epoch [364/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0387
# Epoch [365/1500] Fold 1, Train Loss: 0.0263, Val Loss: 0.0387
# Epoch [366/1500] Fold 1, Train Loss: 0.0270, Val Loss: 0.0386
# Epoch [367/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0362
# Epoch [368/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0391
# Epoch [369/1500] Fold 1, Train Loss: 0.0253, Val Loss: 0.0380
# Epoch [370/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0389
# Epoch [371/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0373
# Epoch [372/1500] Fold 1, Train Loss: 0.0266, Val Loss: 0.0384
# Epoch [373/1500] Fold 1, Train Loss: 0.0268, Val Loss: 0.0388
# Epoch [374/1500] Fold 1, Train Loss: 0.0263, Val Loss: 0.0375
# Epoch [375/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0376
# Epoch [376/1500] Fold 1, Train Loss: 0.0263, Val Loss: 0.0381
# Epoch [377/1500] Fold 1, Train Loss: 0.0265, Val Loss: 0.0390
# Epoch [378/1500] Fold 1, Train Loss: 0.0259, Val Loss: 0.0380
# Epoch [379/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0385
# Epoch [380/1500] Fold 1, Train Loss: 0.0275, Val Loss: 0.0373
# Epoch [381/1500] Fold 1, Train Loss: 0.0265, Val Loss: 0.0367
# Epoch [382/1500] Fold 1, Train Loss: 0.0270, Val Loss: 0.0389
# Epoch [383/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0385
# Epoch [384/1500] Fold 1, Train Loss: 0.0266, Val Loss: 0.0381
# Epoch [385/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0383
# Epoch [386/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0369
# Epoch [387/1500] Fold 1, Train Loss: 0.0263, Val Loss: 0.0373
# Epoch [388/1500] Fold 1, Train Loss: 0.0259, Val Loss: 0.0378
# Epoch [389/1500] Fold 1, Train Loss: 0.0267, Val Loss: 0.0399
# Epoch [390/1500] Fold 1, Train Loss: 0.0256, Val Loss: 0.0381
# Epoch [391/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0380
# Epoch [392/1500] Fold 1, Train Loss: 0.0259, Val Loss: 0.0393
# Epoch [393/1500] Fold 1, Train Loss: 0.0267, Val Loss: 0.0380
# Epoch [394/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0388
# Epoch [395/1500] Fold 1, Train Loss: 0.0254, Val Loss: 0.0385
# Epoch [396/1500] Fold 1, Train Loss: 0.0266, Val Loss: 0.0393
# Epoch [397/1500] Fold 1, Train Loss: 0.0252, Val Loss: 0.0376
# Epoch [398/1500] Fold 1, Train Loss: 0.0253, Val Loss: 0.0378
# Epoch [399/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0369
# Epoch [400/1500] Fold 1, Train Loss: 0.0263, Val Loss: 0.0384
# Epoch [401/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0382
# Epoch [402/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0385
# Epoch [403/1500] Fold 1, Train Loss: 0.0267, Val Loss: 0.0385
# Epoch [404/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0381
# Epoch [405/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0373
# Epoch [406/1500] Fold 1, Train Loss: 0.0254, Val Loss: 0.0377
# Epoch [407/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0384
# Epoch [408/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0380
# Epoch [409/1500] Fold 1, Train Loss: 0.0256, Val Loss: 0.0373
# Epoch [410/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0387
# Epoch [411/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0390
# Epoch [412/1500] Fold 1, Train Loss: 0.0270, Val Loss: 0.0368
# Epoch [413/1500] Fold 1, Train Loss: 0.0257, Val Loss: 0.0385
# Epoch [414/1500] Fold 1, Train Loss: 0.0263, Val Loss: 0.0380
# Epoch [415/1500] Fold 1, Train Loss: 0.0254, Val Loss: 0.0381
# Epoch [416/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0403
# Epoch [417/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0385
# Epoch [418/1500] Fold 1, Train Loss: 0.0256, Val Loss: 0.0382
# Epoch [419/1500] Fold 1, Train Loss: 0.0254, Val Loss: 0.0392
# Epoch [420/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0392
# Epoch [421/1500] Fold 1, Train Loss: 0.0261, Val Loss: 0.0387
# Epoch [422/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0401
# Epoch [423/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0388
# Epoch [424/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0385
# Epoch [425/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0373
# Epoch [426/1500] Fold 1, Train Loss: 0.0252, Val Loss: 0.0389
# Epoch [427/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0389
# Epoch [428/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0381
# Epoch [429/1500] Fold 1, Train Loss: 0.0259, Val Loss: 0.0384
# Epoch [430/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0389
# Epoch [431/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0377
# Epoch [432/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0377
# Epoch [433/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0383
# Epoch [434/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0374
# Epoch [435/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0385
# Epoch [436/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0382
# Epoch [437/1500] Fold 1, Train Loss: 0.0252, Val Loss: 0.0363
# Epoch [438/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0401
# Epoch [439/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0386
# Epoch [440/1500] Fold 1, Train Loss: 0.0256, Val Loss: 0.0391
# Epoch [441/1500] Fold 1, Train Loss: 0.0261, Val Loss: 0.0386
# Epoch [442/1500] Fold 1, Train Loss: 0.0249, Val Loss: 0.0372
# Epoch [443/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0367
# Epoch [444/1500] Fold 1, Train Loss: 0.0243, Val Loss: 0.0390
# Epoch [445/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0378
# Epoch [446/1500] Fold 1, Train Loss: 0.0263, Val Loss: 0.0371
# Epoch [447/1500] Fold 1, Train Loss: 0.0252, Val Loss: 0.0383
# Epoch [448/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0376
# Epoch [449/1500] Fold 1, Train Loss: 0.0259, Val Loss: 0.0389
# Epoch [450/1500] Fold 1, Train Loss: 0.0252, Val Loss: 0.0373
# Epoch [451/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0384
# Epoch [452/1500] Fold 1, Train Loss: 0.0256, Val Loss: 0.0370
# Epoch [453/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0396
# Epoch [454/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0385
# Epoch [455/1500] Fold 1, Train Loss: 0.0254, Val Loss: 0.0395
# Epoch [456/1500] Fold 1, Train Loss: 0.0256, Val Loss: 0.0389
# Epoch [457/1500] Fold 1, Train Loss: 0.0254, Val Loss: 0.0383
# Epoch [458/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0385
# Epoch [459/1500] Fold 1, Train Loss: 0.0259, Val Loss: 0.0376
# Epoch [460/1500] Fold 1, Train Loss: 0.0259, Val Loss: 0.0374
# Epoch [461/1500] Fold 1, Train Loss: 0.0244, Val Loss: 0.0362
# Epoch [462/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0381
# Epoch [463/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0373
# Epoch [464/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0374
# Epoch [465/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0388
# Epoch [466/1500] Fold 1, Train Loss: 0.0256, Val Loss: 0.0373
# Epoch [467/1500] Fold 1, Train Loss: 0.0249, Val Loss: 0.0382
# Epoch [468/1500] Fold 1, Train Loss: 0.0250, Val Loss: 0.0367
# Epoch [469/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0381
# Epoch [470/1500] Fold 1, Train Loss: 0.0252, Val Loss: 0.0367
# Epoch [471/1500] Fold 1, Train Loss: 0.0250, Val Loss: 0.0386
# Epoch [472/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0384
# Epoch [473/1500] Fold 1, Train Loss: 0.0245, Val Loss: 0.0367
# Epoch [474/1500] Fold 1, Train Loss: 0.0252, Val Loss: 0.0390
# Epoch [475/1500] Fold 1, Train Loss: 0.0253, Val Loss: 0.0382
# Epoch [476/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0378
# Epoch [477/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0380
# Epoch [478/1500] Fold 1, Train Loss: 0.0244, Val Loss: 0.0386
# Epoch [479/1500] Fold 1, Train Loss: 0.0254, Val Loss: 0.0389
# Epoch [480/1500] Fold 1, Train Loss: 0.0250, Val Loss: 0.0377
# Epoch [481/1500] Fold 1, Train Loss: 0.0254, Val Loss: 0.0380
# Epoch [482/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0385
# Epoch [483/1500] Fold 1, Train Loss: 0.0254, Val Loss: 0.0385
# Epoch [484/1500] Fold 1, Train Loss: 0.0245, Val Loss: 0.0389
# Epoch [485/1500] Fold 1, Train Loss: 0.0249, Val Loss: 0.0381
# Epoch [486/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0376
# Epoch [487/1500] Fold 1, Train Loss: 0.0248, Val Loss: 0.0383
# Epoch [488/1500] Fold 1, Train Loss: 0.0253, Val Loss: 0.0378
# Epoch [489/1500] Fold 1, Train Loss: 0.0242, Val Loss: 0.0392
# Epoch [490/1500] Fold 1, Train Loss: 0.0245, Val Loss: 0.0394
# Epoch [491/1500] Fold 1, Train Loss: 0.0253, Val Loss: 0.0394
# Epoch [492/1500] Fold 1, Train Loss: 0.0240, Val Loss: 0.0375
# Epoch [493/1500] Fold 1, Train Loss: 0.0257, Val Loss: 0.0390
# Epoch [494/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0398
# Epoch [495/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0363
# Epoch [496/1500] Fold 1, Train Loss: 0.0250, Val Loss: 0.0386
# Epoch [497/1500] Fold 1, Train Loss: 0.0248, Val Loss: 0.0372
# Epoch [498/1500] Fold 1, Train Loss: 0.0254, Val Loss: 0.0379
# Epoch [499/1500] Fold 1, Train Loss: 0.0249, Val Loss: 0.0380
# Epoch [500/1500] Fold 1, Train Loss: 0.0249, Val Loss: 0.0379
# Epoch [501/1500] Fold 1, Train Loss: 0.0246, Val Loss: 0.0392
# Epoch [502/1500] Fold 1, Train Loss: 0.0253, Val Loss: 0.0369
# Epoch [503/1500] Fold 1, Train Loss: 0.0247, Val Loss: 0.0389
# Epoch [504/1500] Fold 1, Train Loss: 0.0243, Val Loss: 0.0392
# Epoch [505/1500] Fold 1, Train Loss: 0.0256, Val Loss: 0.0373
# Epoch [506/1500] Fold 1, Train Loss: 0.0244, Val Loss: 0.0389
# Epoch [507/1500] Fold 1, Train Loss: 0.0237, Val Loss: 0.0373
# Epoch [508/1500] Fold 1, Train Loss: 0.0249, Val Loss: 0.0381
# Epoch [509/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0378
# Epoch [510/1500] Fold 1, Train Loss: 0.0244, Val Loss: 0.0379
# Epoch [511/1500] Fold 1, Train Loss: 0.0245, Val Loss: 0.0381
# Epoch [512/1500] Fold 1, Train Loss: 0.0252, Val Loss: 0.0367
# Epoch [513/1500] Fold 1, Train Loss: 0.0241, Val Loss: 0.0375
# Epoch [514/1500] Fold 1, Train Loss: 0.0252, Val Loss: 0.0380
# Epoch [515/1500] Fold 1, Train Loss: 0.0241, Val Loss: 0.0386
# Epoch [516/1500] Fold 1, Train Loss: 0.0252, Val Loss: 0.0383
# Epoch [517/1500] Fold 1, Train Loss: 0.0247, Val Loss: 0.0370
# Epoch [518/1500] Fold 1, Train Loss: 0.0253, Val Loss: 0.0386
# Epoch [519/1500] Fold 1, Train Loss: 0.0249, Val Loss: 0.0390
# Epoch [520/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0388
# Epoch [521/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0383
# Epoch [522/1500] Fold 1, Train Loss: 0.0243, Val Loss: 0.0386
# Epoch [523/1500] Fold 1, Train Loss: 0.0244, Val Loss: 0.0370
# Epoch [524/1500] Fold 1, Train Loss: 0.0242, Val Loss: 0.0393
# Epoch [525/1500] Fold 1, Train Loss: 0.0247, Val Loss: 0.0376
# Epoch [526/1500] Fold 1, Train Loss: 0.0243, Val Loss: 0.0379
# Epoch [527/1500] Fold 1, Train Loss: 0.0250, Val Loss: 0.0397
# Epoch [528/1500] Fold 1, Train Loss: 0.0240, Val Loss: 0.0377
# Epoch [529/1500] Fold 1, Train Loss: 0.0241, Val Loss: 0.0378
# Epoch [530/1500] Fold 1, Train Loss: 0.0244, Val Loss: 0.0382
# Epoch [531/1500] Fold 1, Train Loss: 0.0243, Val Loss: 0.0376
# Epoch [532/1500] Fold 1, Train Loss: 0.0247, Val Loss: 0.0376
# Epoch [533/1500] Fold 1, Train Loss: 0.0246, Val Loss: 0.0382
# Epoch [534/1500] Fold 1, Train Loss: 0.0245, Val Loss: 0.0392
# Epoch [535/1500] Fold 1, Train Loss: 0.0243, Val Loss: 0.0374
# Epoch [536/1500] Fold 1, Train Loss: 0.0242, Val Loss: 0.0386
# Epoch [537/1500] Fold 1, Train Loss: 0.0234, Val Loss: 0.0379
# Epoch [538/1500] Fold 1, Train Loss: 0.0254, Val Loss: 0.0414
# Epoch [539/1500] Fold 1, Train Loss: 0.0254, Val Loss: 0.0392
# Epoch [540/1500] Fold 1, Train Loss: 0.0242, Val Loss: 0.0388
# Epoch [541/1500] Fold 1, Train Loss: 0.0244, Val Loss: 0.0389
# Epoch [542/1500] Fold 1, Train Loss: 0.0248, Val Loss: 0.0380
# Epoch [543/1500] Fold 1, Train Loss: 0.0246, Val Loss: 0.0388
# Epoch [544/1500] Fold 1, Train Loss: 0.0242, Val Loss: 0.0369
# Epoch [545/1500] Fold 1, Train Loss: 0.0246, Val Loss: 0.0377
# Epoch [546/1500] Fold 1, Train Loss: 0.0248, Val Loss: 0.0380
# Epoch [547/1500] Fold 1, Train Loss: 0.0245, Val Loss: 0.0389
# Epoch [548/1500] Fold 1, Train Loss: 0.0245, Val Loss: 0.0369
# Epoch [549/1500] Fold 1, Train Loss: 0.0239, Val Loss: 0.0384
# Epoch [550/1500] Fold 1, Train Loss: 0.0241, Val Loss: 0.0374
# Epoch [551/1500] Fold 1, Train Loss: 0.0239, Val Loss: 0.0375
# Epoch [552/1500] Fold 1, Train Loss: 0.0257, Val Loss: 0.0363
# Epoch [553/1500] Fold 1, Train Loss: 0.0242, Val Loss: 0.0390
# Epoch [554/1500] Fold 1, Train Loss: 0.0239, Val Loss: 0.0392
# Epoch [555/1500] Fold 1, Train Loss: 0.0242, Val Loss: 0.0377
# Epoch [556/1500] Fold 1, Train Loss: 0.0234, Val Loss: 0.0388
# Epoch [557/1500] Fold 1, Train Loss: 0.0244, Val Loss: 0.0386
# Epoch [558/1500] Fold 1, Train Loss: 0.0248, Val Loss: 0.0380
# Epoch [559/1500] Fold 1, Train Loss: 0.0246, Val Loss: 0.0379
# Epoch [560/1500] Fold 1, Train Loss: 0.0241, Val Loss: 0.0384
# Epoch [561/1500] Fold 1, Train Loss: 0.0247, Val Loss: 0.0386
# Epoch [562/1500] Fold 1, Train Loss: 0.0253, Val Loss: 0.0381
# Epoch [563/1500] Fold 1, Train Loss: 0.0247, Val Loss: 0.0385
# Epoch [564/1500] Fold 1, Train Loss: 0.0244, Val Loss: 0.0400
# Epoch [565/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0377
# Epoch [566/1500] Fold 1, Train Loss: 0.0243, Val Loss: 0.0383
# Epoch [567/1500] Fold 1, Train Loss: 0.0244, Val Loss: 0.0392
# Epoch [568/1500] Fold 1, Train Loss: 0.0234, Val Loss: 0.0366
# Epoch [569/1500] Fold 1, Train Loss: 0.0234, Val Loss: 0.0393
# Epoch [570/1500] Fold 1, Train Loss: 0.0242, Val Loss: 0.0363
# Epoch [571/1500] Fold 1, Train Loss: 0.0248, Val Loss: 0.0391
# Epoch [572/1500] Fold 1, Train Loss: 0.0241, Val Loss: 0.0381
# Epoch [573/1500] Fold 1, Train Loss: 0.0238, Val Loss: 0.0371
# Epoch [574/1500] Fold 1, Train Loss: 0.0246, Val Loss: 0.0375
# Epoch [575/1500] Fold 1, Train Loss: 0.0238, Val Loss: 0.0384
# Early stopping at epoch 575 for fold 1
# Fold 2/10
# Epoch [1/1500] Fold 2, Train Loss: 0.2343, Val Loss: 0.1234
# Epoch [2/1500] Fold 2, Train Loss: 0.1739, Val Loss: 0.1085
# Epoch [3/1500] Fold 2, Train Loss: 0.1393, Val Loss: 0.0990
# Epoch [4/1500] Fold 2, Train Loss: 0.1181, Val Loss: 0.0927
# Epoch [5/1500] Fold 2, Train Loss: 0.1021, Val Loss: 0.0811
# Epoch [6/1500] Fold 2, Train Loss: 0.0895, Val Loss: 0.0730
# Epoch [7/1500] Fold 2, Train Loss: 0.0813, Val Loss: 0.0670
# Epoch [8/1500] Fold 2, Train Loss: 0.0734, Val Loss: 0.0615
# Epoch [9/1500] Fold 2, Train Loss: 0.0672, Val Loss: 0.0578
# Epoch [10/1500] Fold 2, Train Loss: 0.0631, Val Loss: 0.0553
# Epoch [11/1500] Fold 2, Train Loss: 0.0590, Val Loss: 0.0534
# Epoch [12/1500] Fold 2, Train Loss: 0.0560, Val Loss: 0.0515
# Epoch [13/1500] Fold 2, Train Loss: 0.0540, Val Loss: 0.0503
# Epoch [14/1500] Fold 2, Train Loss: 0.0518, Val Loss: 0.0495
# Epoch [15/1500] Fold 2, Train Loss: 0.0500, Val Loss: 0.0488
# Epoch [16/1500] Fold 2, Train Loss: 0.0488, Val Loss: 0.0479
# Epoch [17/1500] Fold 2, Train Loss: 0.0478, Val Loss: 0.0476
# Epoch [18/1500] Fold 2, Train Loss: 0.0470, Val Loss: 0.0472
# Epoch [19/1500] Fold 2, Train Loss: 0.0459, Val Loss: 0.0471
# Epoch [20/1500] Fold 2, Train Loss: 0.0460, Val Loss: 0.0468
# Epoch [21/1500] Fold 2, Train Loss: 0.0447, Val Loss: 0.0466
# Epoch [22/1500] Fold 2, Train Loss: 0.0441, Val Loss: 0.0465
# Epoch [23/1500] Fold 2, Train Loss: 0.0443, Val Loss: 0.0463
# Epoch [24/1500] Fold 2, Train Loss: 0.0433, Val Loss: 0.0457
# Epoch [25/1500] Fold 2, Train Loss: 0.0425, Val Loss: 0.0456
# Epoch [26/1500] Fold 2, Train Loss: 0.0423, Val Loss: 0.0458
# Epoch [27/1500] Fold 2, Train Loss: 0.0426, Val Loss: 0.0457
# Epoch [28/1500] Fold 2, Train Loss: 0.0418, Val Loss: 0.0459
# Epoch [29/1500] Fold 2, Train Loss: 0.0415, Val Loss: 0.0451
# Epoch [30/1500] Fold 2, Train Loss: 0.0410, Val Loss: 0.0450
# Epoch [31/1500] Fold 2, Train Loss: 0.0409, Val Loss: 0.0454
# Epoch [32/1500] Fold 2, Train Loss: 0.0411, Val Loss: 0.0450
# Epoch [33/1500] Fold 2, Train Loss: 0.0406, Val Loss: 0.0447
# Epoch [34/1500] Fold 2, Train Loss: 0.0402, Val Loss: 0.0447
# Epoch [35/1500] Fold 2, Train Loss: 0.0399, Val Loss: 0.0449
# Epoch [36/1500] Fold 2, Train Loss: 0.0402, Val Loss: 0.0450
# Epoch [37/1500] Fold 2, Train Loss: 0.0397, Val Loss: 0.0446
# Epoch [38/1500] Fold 2, Train Loss: 0.0397, Val Loss: 0.0444
# Epoch [39/1500] Fold 2, Train Loss: 0.0394, Val Loss: 0.0442
# Epoch [40/1500] Fold 2, Train Loss: 0.0391, Val Loss: 0.0443
# Epoch [41/1500] Fold 2, Train Loss: 0.0393, Val Loss: 0.0441
# Epoch [42/1500] Fold 2, Train Loss: 0.0390, Val Loss: 0.0443
# Epoch [43/1500] Fold 2, Train Loss: 0.0384, Val Loss: 0.0441
# Epoch [44/1500] Fold 2, Train Loss: 0.0384, Val Loss: 0.0440
# Epoch [45/1500] Fold 2, Train Loss: 0.0383, Val Loss: 0.0439
# Epoch [46/1500] Fold 2, Train Loss: 0.0386, Val Loss: 0.0438
# Epoch [47/1500] Fold 2, Train Loss: 0.0379, Val Loss: 0.0438
# Epoch [48/1500] Fold 2, Train Loss: 0.0383, Val Loss: 0.0435
# Epoch [49/1500] Fold 2, Train Loss: 0.0381, Val Loss: 0.0434
# Epoch [50/1500] Fold 2, Train Loss: 0.0376, Val Loss: 0.0436
# Epoch [51/1500] Fold 2, Train Loss: 0.0374, Val Loss: 0.0434
# Epoch [52/1500] Fold 2, Train Loss: 0.0372, Val Loss: 0.0431
# Epoch [53/1500] Fold 2, Train Loss: 0.0379, Val Loss: 0.0433
# Epoch [54/1500] Fold 2, Train Loss: 0.0378, Val Loss: 0.0439
# Epoch [55/1500] Fold 2, Train Loss: 0.0378, Val Loss: 0.0433
# Epoch [56/1500] Fold 2, Train Loss: 0.0370, Val Loss: 0.0430
# Epoch [57/1500] Fold 2, Train Loss: 0.0368, Val Loss: 0.0428
# Epoch [58/1500] Fold 2, Train Loss: 0.0368, Val Loss: 0.0428
# Epoch [59/1500] Fold 2, Train Loss: 0.0370, Val Loss: 0.0429
# Epoch [60/1500] Fold 2, Train Loss: 0.0365, Val Loss: 0.0425
# Epoch [61/1500] Fold 2, Train Loss: 0.0366, Val Loss: 0.0425
# Epoch [62/1500] Fold 2, Train Loss: 0.0366, Val Loss: 0.0425
# Epoch [63/1500] Fold 2, Train Loss: 0.0368, Val Loss: 0.0426
# Epoch [64/1500] Fold 2, Train Loss: 0.0367, Val Loss: 0.0424
# Epoch [65/1500] Fold 2, Train Loss: 0.0362, Val Loss: 0.0427
# Epoch [66/1500] Fold 2, Train Loss: 0.0365, Val Loss: 0.0424
# Epoch [67/1500] Fold 2, Train Loss: 0.0358, Val Loss: 0.0424
# Epoch [68/1500] Fold 2, Train Loss: 0.0363, Val Loss: 0.0422
# Epoch [69/1500] Fold 2, Train Loss: 0.0358, Val Loss: 0.0419
# Epoch [70/1500] Fold 2, Train Loss: 0.0359, Val Loss: 0.0421
# Epoch [71/1500] Fold 2, Train Loss: 0.0357, Val Loss: 0.0420
# Epoch [72/1500] Fold 2, Train Loss: 0.0351, Val Loss: 0.0421
# Epoch [73/1500] Fold 2, Train Loss: 0.0353, Val Loss: 0.0421
# Epoch [74/1500] Fold 2, Train Loss: 0.0353, Val Loss: 0.0425
# Epoch [75/1500] Fold 2, Train Loss: 0.0350, Val Loss: 0.0420
# Epoch [76/1500] Fold 2, Train Loss: 0.0348, Val Loss: 0.0421
# Epoch [77/1500] Fold 2, Train Loss: 0.0347, Val Loss: 0.0420
# Epoch [78/1500] Fold 2, Train Loss: 0.0353, Val Loss: 0.0420
# Epoch [79/1500] Fold 2, Train Loss: 0.0351, Val Loss: 0.0420
# Epoch [80/1500] Fold 2, Train Loss: 0.0347, Val Loss: 0.0417
# Epoch [81/1500] Fold 2, Train Loss: 0.0346, Val Loss: 0.0422
# Epoch [82/1500] Fold 2, Train Loss: 0.0348, Val Loss: 0.0411
# Epoch [83/1500] Fold 2, Train Loss: 0.0352, Val Loss: 0.0422
# Epoch [84/1500] Fold 2, Train Loss: 0.0349, Val Loss: 0.0423
# Epoch [85/1500] Fold 2, Train Loss: 0.0346, Val Loss: 0.0416
# Epoch [86/1500] Fold 2, Train Loss: 0.0348, Val Loss: 0.0420
# Epoch [87/1500] Fold 2, Train Loss: 0.0344, Val Loss: 0.0422
# Epoch [88/1500] Fold 2, Train Loss: 0.0346, Val Loss: 0.0415
# Epoch [89/1500] Fold 2, Train Loss: 0.0341, Val Loss: 0.0416
# Epoch [90/1500] Fold 2, Train Loss: 0.0346, Val Loss: 0.0413
# Epoch [91/1500] Fold 2, Train Loss: 0.0340, Val Loss: 0.0413
# Epoch [92/1500] Fold 2, Train Loss: 0.0344, Val Loss: 0.0416
# Epoch [93/1500] Fold 2, Train Loss: 0.0335, Val Loss: 0.0416
# Epoch [94/1500] Fold 2, Train Loss: 0.0340, Val Loss: 0.0415
# Epoch [95/1500] Fold 2, Train Loss: 0.0340, Val Loss: 0.0421
# Epoch [96/1500] Fold 2, Train Loss: 0.0339, Val Loss: 0.0427
# Epoch [97/1500] Fold 2, Train Loss: 0.0334, Val Loss: 0.0419
# Epoch [98/1500] Fold 2, Train Loss: 0.0337, Val Loss: 0.0421
# Epoch [99/1500] Fold 2, Train Loss: 0.0338, Val Loss: 0.0419
# Epoch [100/1500] Fold 2, Train Loss: 0.0345, Val Loss: 0.0418
# Epoch [101/1500] Fold 2, Train Loss: 0.0338, Val Loss: 0.0414
# Epoch [102/1500] Fold 2, Train Loss: 0.0339, Val Loss: 0.0411
# Epoch [103/1500] Fold 2, Train Loss: 0.0331, Val Loss: 0.0417
# Epoch [104/1500] Fold 2, Train Loss: 0.0332, Val Loss: 0.0412
# Epoch [105/1500] Fold 2, Train Loss: 0.0330, Val Loss: 0.0418
# Epoch [106/1500] Fold 2, Train Loss: 0.0328, Val Loss: 0.0419
# Epoch [107/1500] Fold 2, Train Loss: 0.0329, Val Loss: 0.0422
# Epoch [108/1500] Fold 2, Train Loss: 0.0336, Val Loss: 0.0413
# Epoch [109/1500] Fold 2, Train Loss: 0.0335, Val Loss: 0.0415
# Epoch [110/1500] Fold 2, Train Loss: 0.0335, Val Loss: 0.0412
# Epoch [111/1500] Fold 2, Train Loss: 0.0337, Val Loss: 0.0412
# Epoch [112/1500] Fold 2, Train Loss: 0.0332, Val Loss: 0.0423
# Epoch [113/1500] Fold 2, Train Loss: 0.0326, Val Loss: 0.0411
# Epoch [114/1500] Fold 2, Train Loss: 0.0330, Val Loss: 0.0416
# Epoch [115/1500] Fold 2, Train Loss: 0.0336, Val Loss: 0.0415
# Epoch [116/1500] Fold 2, Train Loss: 0.0325, Val Loss: 0.0418
# Epoch [117/1500] Fold 2, Train Loss: 0.0324, Val Loss: 0.0424
# Epoch [118/1500] Fold 2, Train Loss: 0.0325, Val Loss: 0.0420
# Epoch [119/1500] Fold 2, Train Loss: 0.0327, Val Loss: 0.0414
# Epoch [120/1500] Fold 2, Train Loss: 0.0323, Val Loss: 0.0422
# Epoch [121/1500] Fold 2, Train Loss: 0.0325, Val Loss: 0.0415
# Epoch [122/1500] Fold 2, Train Loss: 0.0327, Val Loss: 0.0418
# Epoch [123/1500] Fold 2, Train Loss: 0.0326, Val Loss: 0.0421
# Epoch [124/1500] Fold 2, Train Loss: 0.0328, Val Loss: 0.0417
# Epoch [125/1500] Fold 2, Train Loss: 0.0326, Val Loss: 0.0416
# Epoch [126/1500] Fold 2, Train Loss: 0.0327, Val Loss: 0.0425
# Epoch [127/1500] Fold 2, Train Loss: 0.0322, Val Loss: 0.0417
# Epoch [128/1500] Fold 2, Train Loss: 0.0322, Val Loss: 0.0417
# Epoch [129/1500] Fold 2, Train Loss: 0.0323, Val Loss: 0.0415
# Epoch [130/1500] Fold 2, Train Loss: 0.0330, Val Loss: 0.0420
# Epoch [131/1500] Fold 2, Train Loss: 0.0321, Val Loss: 0.0416
# Epoch [132/1500] Fold 2, Train Loss: 0.0323, Val Loss: 0.0422
# Epoch [133/1500] Fold 2, Train Loss: 0.0326, Val Loss: 0.0416
# Epoch [134/1500] Fold 2, Train Loss: 0.0316, Val Loss: 0.0417
# Epoch [135/1500] Fold 2, Train Loss: 0.0318, Val Loss: 0.0425
# Epoch [136/1500] Fold 2, Train Loss: 0.0320, Val Loss: 0.0423
# Epoch [137/1500] Fold 2, Train Loss: 0.0314, Val Loss: 0.0423
# Epoch [138/1500] Fold 2, Train Loss: 0.0313, Val Loss: 0.0423
# Epoch [139/1500] Fold 2, Train Loss: 0.0321, Val Loss: 0.0410
# Epoch [140/1500] Fold 2, Train Loss: 0.0318, Val Loss: 0.0419
# Epoch [141/1500] Fold 2, Train Loss: 0.0312, Val Loss: 0.0423
# Epoch [142/1500] Fold 2, Train Loss: 0.0315, Val Loss: 0.0416
# Epoch [143/1500] Fold 2, Train Loss: 0.0317, Val Loss: 0.0420
# Epoch [144/1500] Fold 2, Train Loss: 0.0310, Val Loss: 0.0432
# Epoch [145/1500] Fold 2, Train Loss: 0.0319, Val Loss: 0.0417
# Epoch [146/1500] Fold 2, Train Loss: 0.0311, Val Loss: 0.0419
# Epoch [147/1500] Fold 2, Train Loss: 0.0311, Val Loss: 0.0419
# Epoch [148/1500] Fold 2, Train Loss: 0.0315, Val Loss: 0.0425
# Epoch [149/1500] Fold 2, Train Loss: 0.0314, Val Loss: 0.0422
# Epoch [150/1500] Fold 2, Train Loss: 0.0312, Val Loss: 0.0431
# Epoch [151/1500] Fold 2, Train Loss: 0.0315, Val Loss: 0.0418
# Epoch [152/1500] Fold 2, Train Loss: 0.0314, Val Loss: 0.0429
# Epoch [153/1500] Fold 2, Train Loss: 0.0315, Val Loss: 0.0426
# Epoch [154/1500] Fold 2, Train Loss: 0.0313, Val Loss: 0.0423
# Epoch [155/1500] Fold 2, Train Loss: 0.0310, Val Loss: 0.0429
# Epoch [156/1500] Fold 2, Train Loss: 0.0308, Val Loss: 0.0426
# Epoch [157/1500] Fold 2, Train Loss: 0.0313, Val Loss: 0.0428
# Epoch [158/1500] Fold 2, Train Loss: 0.0308, Val Loss: 0.0423
# Epoch [159/1500] Fold 2, Train Loss: 0.0319, Val Loss: 0.0427
# Epoch [160/1500] Fold 2, Train Loss: 0.0305, Val Loss: 0.0426
# Epoch [161/1500] Fold 2, Train Loss: 0.0309, Val Loss: 0.0434
# Epoch [162/1500] Fold 2, Train Loss: 0.0310, Val Loss: 0.0424
# Epoch [163/1500] Fold 2, Train Loss: 0.0309, Val Loss: 0.0438
# Epoch [164/1500] Fold 2, Train Loss: 0.0309, Val Loss: 0.0429
# Epoch [165/1500] Fold 2, Train Loss: 0.0303, Val Loss: 0.0419
# Epoch [166/1500] Fold 2, Train Loss: 0.0306, Val Loss: 0.0424
# Epoch [167/1500] Fold 2, Train Loss: 0.0310, Val Loss: 0.0432
# Epoch [168/1500] Fold 2, Train Loss: 0.0309, Val Loss: 0.0423
# Epoch [169/1500] Fold 2, Train Loss: 0.0308, Val Loss: 0.0426
# Epoch [170/1500] Fold 2, Train Loss: 0.0309, Val Loss: 0.0422
# Epoch [171/1500] Fold 2, Train Loss: 0.0307, Val Loss: 0.0425
# Epoch [172/1500] Fold 2, Train Loss: 0.0316, Val Loss: 0.0427
# Epoch [173/1500] Fold 2, Train Loss: 0.0305, Val Loss: 0.0422
# Epoch [174/1500] Fold 2, Train Loss: 0.0301, Val Loss: 0.0428
# Epoch [175/1500] Fold 2, Train Loss: 0.0314, Val Loss: 0.0428
# Epoch [176/1500] Fold 2, Train Loss: 0.0306, Val Loss: 0.0414
# Epoch [177/1500] Fold 2, Train Loss: 0.0301, Val Loss: 0.0422
# Epoch [178/1500] Fold 2, Train Loss: 0.0307, Val Loss: 0.0423
# Epoch [179/1500] Fold 2, Train Loss: 0.0316, Val Loss: 0.0421
# Epoch [180/1500] Fold 2, Train Loss: 0.0301, Val Loss: 0.0427
# Epoch [181/1500] Fold 2, Train Loss: 0.0303, Val Loss: 0.0427
# Epoch [182/1500] Fold 2, Train Loss: 0.0302, Val Loss: 0.0427
# Epoch [183/1500] Fold 2, Train Loss: 0.0299, Val Loss: 0.0435
# Epoch [184/1500] Fold 2, Train Loss: 0.0305, Val Loss: 0.0425
# Epoch [185/1500] Fold 2, Train Loss: 0.0303, Val Loss: 0.0427
# Epoch [186/1500] Fold 2, Train Loss: 0.0300, Val Loss: 0.0433
# Epoch [187/1500] Fold 2, Train Loss: 0.0294, Val Loss: 0.0430
# Epoch [188/1500] Fold 2, Train Loss: 0.0300, Val Loss: 0.0429
# Epoch [189/1500] Fold 2, Train Loss: 0.0303, Val Loss: 0.0438
# Epoch [190/1500] Fold 2, Train Loss: 0.0294, Val Loss: 0.0430
# Epoch [191/1500] Fold 2, Train Loss: 0.0300, Val Loss: 0.0430
# Epoch [192/1500] Fold 2, Train Loss: 0.0298, Val Loss: 0.0427
# Epoch [193/1500] Fold 2, Train Loss: 0.0298, Val Loss: 0.0432
# Epoch [194/1500] Fold 2, Train Loss: 0.0301, Val Loss: 0.0424
# Epoch [195/1500] Fold 2, Train Loss: 0.0295, Val Loss: 0.0433
# Epoch [196/1500] Fold 2, Train Loss: 0.0309, Val Loss: 0.0432
# Epoch [197/1500] Fold 2, Train Loss: 0.0303, Val Loss: 0.0435
# Epoch [198/1500] Fold 2, Train Loss: 0.0295, Val Loss: 0.0439
# Epoch [199/1500] Fold 2, Train Loss: 0.0299, Val Loss: 0.0431
# Epoch [200/1500] Fold 2, Train Loss: 0.0297, Val Loss: 0.0432
# Epoch [201/1500] Fold 2, Train Loss: 0.0301, Val Loss: 0.0419
# ...
# Epoch [418/1500] Fold 10, Train Loss: 0.0268, Val Loss: 0.0400
# Epoch [419/1500] Fold 10, Train Loss: 0.0257, Val Loss: 0.0393
# Epoch [420/1500] Fold 10, Train Loss: 0.0267, Val Loss: 0.0392
# Epoch [421/1500] Fold 10, Train Loss: 0.0260, Val Loss: 0.0390
# Epoch [422/1500] Fold 10, Train Loss: 0.0260, Val Loss: 0.0377
# Epoch [423/1500] Fold 10, Train Loss: 0.0261, Val Loss: 0.0386
# Epoch [424/1500] Fold 10, Train Loss: 0.0261, Val Loss: 0.0387
# Epoch [425/1500] Fold 10, Train Loss: 0.0266, Val Loss: 0.0388
# Epoch [426/1500] Fold 10, Train Loss: 0.0267, Val Loss: 0.0385
# Epoch [427/1500] Fold 10, Train Loss: 0.0260, Val Loss: 0.0386
# Epoch [428/1500] Fold 10, Train Loss: 0.0264, Val Loss: 0.0388
# Epoch [429/1500] Fold 10, Train Loss: 0.0260, Val Loss: 0.0384
# Epoch [430/1500] Fold 10, Train Loss: 0.0262, Val Loss: 0.0383
# Epoch [431/1500] Fold 10, Train Loss: 0.0254, Val Loss: 0.0399
# Epoch [432/1500] Fold 10, Train Loss: 0.0259, Val Loss: 0.0393
# Epoch [433/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0393
# Epoch [434/1500] Fold 10, Train Loss: 0.0255, Val Loss: 0.0399
# Epoch [435/1500] Fold 10, Train Loss: 0.0260, Val Loss: 0.0397
# Epoch [436/1500] Fold 10, Train Loss: 0.0261, Val Loss: 0.0399
# Epoch [437/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0396
# Epoch [438/1500] Fold 10, Train Loss: 0.0253, Val Loss: 0.0401
# Epoch [439/1500] Fold 10, Train Loss: 0.0251, Val Loss: 0.0392
# Epoch [440/1500] Fold 10, Train Loss: 0.0255, Val Loss: 0.0386
# Epoch [441/1500] Fold 10, Train Loss: 0.0267, Val Loss: 0.0396
# Epoch [442/1500] Fold 10, Train Loss: 0.0262, Val Loss: 0.0396
# Epoch [443/1500] Fold 10, Train Loss: 0.0258, Val Loss: 0.0383
# Epoch [444/1500] Fold 10, Train Loss: 0.0251, Val Loss: 0.0386
# Epoch [445/1500] Fold 10, Train Loss: 0.0249, Val Loss: 0.0394
# Epoch [446/1500] Fold 10, Train Loss: 0.0255, Val Loss: 0.0397
# Epoch [447/1500] Fold 10, Train Loss: 0.0263, Val Loss: 0.0395
# Epoch [448/1500] Fold 10, Train Loss: 0.0256, Val Loss: 0.0384
# Epoch [449/1500] Fold 10, Train Loss: 0.0257, Val Loss: 0.0384
# Epoch [450/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0389
# Epoch [451/1500] Fold 10, Train Loss: 0.0256, Val Loss: 0.0393
# Epoch [452/1500] Fold 10, Train Loss: 0.0251, Val Loss: 0.0397
# Epoch [453/1500] Fold 10, Train Loss: 0.0258, Val Loss: 0.0405
# Epoch [454/1500] Fold 10, Train Loss: 0.0253, Val Loss: 0.0399
# Epoch [455/1500] Fold 10, Train Loss: 0.0253, Val Loss: 0.0395
# Epoch [456/1500] Fold 10, Train Loss: 0.0257, Val Loss: 0.0407
# Epoch [457/1500] Fold 10, Train Loss: 0.0254, Val Loss: 0.0395
# Epoch [458/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0411
# Epoch [459/1500] Fold 10, Train Loss: 0.0258, Val Loss: 0.0401
# Epoch [460/1500] Fold 10, Train Loss: 0.0261, Val Loss: 0.0389
# Epoch [461/1500] Fold 10, Train Loss: 0.0260, Val Loss: 0.0397
# Epoch [462/1500] Fold 10, Train Loss: 0.0255, Val Loss: 0.0395
# Epoch [463/1500] Fold 10, Train Loss: 0.0257, Val Loss: 0.0395
# Epoch [464/1500] Fold 10, Train Loss: 0.0254, Val Loss: 0.0392
# Epoch [465/1500] Fold 10, Train Loss: 0.0256, Val Loss: 0.0394
# Epoch [466/1500] Fold 10, Train Loss: 0.0254, Val Loss: 0.0406
# Epoch [467/1500] Fold 10, Train Loss: 0.0260, Val Loss: 0.0395
# Epoch [468/1500] Fold 10, Train Loss: 0.0261, Val Loss: 0.0398
# Epoch [469/1500] Fold 10, Train Loss: 0.0260, Val Loss: 0.0391
# Epoch [470/1500] Fold 10, Train Loss: 0.0258, Val Loss: 0.0399
# Epoch [471/1500] Fold 10, Train Loss: 0.0257, Val Loss: 0.0398
# Epoch [472/1500] Fold 10, Train Loss: 0.0251, Val Loss: 0.0407
# Epoch [473/1500] Fold 10, Train Loss: 0.0255, Val Loss: 0.0403
# Epoch [474/1500] Fold 10, Train Loss: 0.0255, Val Loss: 0.0406
# Epoch [475/1500] Fold 10, Train Loss: 0.0255, Val Loss: 0.0402
# Epoch [476/1500] Fold 10, Train Loss: 0.0259, Val Loss: 0.0408
# Epoch [477/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0395
# Epoch [478/1500] Fold 10, Train Loss: 0.0251, Val Loss: 0.0404
# Epoch [479/1500] Fold 10, Train Loss: 0.0249, Val Loss: 0.0399
# Epoch [480/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0397
# Epoch [481/1500] Fold 10, Train Loss: 0.0253, Val Loss: 0.0408
# Epoch [482/1500] Fold 10, Train Loss: 0.0255, Val Loss: 0.0385
# Epoch [483/1500] Fold 10, Train Loss: 0.0260, Val Loss: 0.0390
# Epoch [484/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0401
# Epoch [485/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0401
# Epoch [486/1500] Fold 10, Train Loss: 0.0261, Val Loss: 0.0410
# Epoch [487/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0409
# Epoch [488/1500] Fold 10, Train Loss: 0.0253, Val Loss: 0.0407
# Epoch [489/1500] Fold 10, Train Loss: 0.0258, Val Loss: 0.0400
# Epoch [490/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0397
# Epoch [491/1500] Fold 10, Train Loss: 0.0258, Val Loss: 0.0398
# Epoch [492/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0407
# Epoch [493/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0394
# Epoch [494/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0397
# Epoch [495/1500] Fold 10, Train Loss: 0.0258, Val Loss: 0.0393
# Epoch [496/1500] Fold 10, Train Loss: 0.0247, Val Loss: 0.0389
# Epoch [497/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0404
# Epoch [498/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0395
# Epoch [499/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0399
# Epoch [500/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0406
# Epoch [501/1500] Fold 10, Train Loss: 0.0255, Val Loss: 0.0396
# Epoch [502/1500] Fold 10, Train Loss: 0.0254, Val Loss: 0.0405
# Epoch [503/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0390
# Epoch [504/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0403
# Epoch [505/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0401
# Epoch [506/1500] Fold 10, Train Loss: 0.0256, Val Loss: 0.0404
# Epoch [507/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0406
# Epoch [508/1500] Fold 10, Train Loss: 0.0253, Val Loss: 0.0394
# Epoch [509/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0409
# Epoch [510/1500] Fold 10, Train Loss: 0.0251, Val Loss: 0.0424
# Epoch [511/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0408
# Epoch [512/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0419
# Epoch [513/1500] Fold 10, Train Loss: 0.0246, Val Loss: 0.0406
# Epoch [514/1500] Fold 10, Train Loss: 0.0258, Val Loss: 0.0400
# Epoch [515/1500] Fold 10, Train Loss: 0.0251, Val Loss: 0.0385
# Epoch [516/1500] Fold 10, Train Loss: 0.0256, Val Loss: 0.0399
# Epoch [517/1500] Fold 10, Train Loss: 0.0255, Val Loss: 0.0401
# Epoch [518/1500] Fold 10, Train Loss: 0.0255, Val Loss: 0.0392
# Epoch [519/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0406
# Epoch [520/1500] Fold 10, Train Loss: 0.0251, Val Loss: 0.0416
# Epoch [521/1500] Fold 10, Train Loss: 0.0257, Val Loss: 0.0406
# Epoch [522/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0401
# Epoch [523/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0406
# Epoch [524/1500] Fold 10, Train Loss: 0.0249, Val Loss: 0.0415
# Epoch [525/1500] Fold 10, Train Loss: 0.0246, Val Loss: 0.0416
# Epoch [526/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0398
# Epoch [527/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0408
# Epoch [528/1500] Fold 10, Train Loss: 0.0253, Val Loss: 0.0404
# Epoch [529/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0408
# Epoch [530/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0399
# Epoch [531/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0406
# Epoch [532/1500] Fold 10, Train Loss: 0.0249, Val Loss: 0.0398
# Epoch [533/1500] Fold 10, Train Loss: 0.0253, Val Loss: 0.0399
# Epoch [534/1500] Fold 10, Train Loss: 0.0258, Val Loss: 0.0400
# Epoch [535/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0405
# Epoch [536/1500] Fold 10, Train Loss: 0.0246, Val Loss: 0.0399
# Epoch [537/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0397
# Epoch [538/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0409
# Epoch [539/1500] Fold 10, Train Loss: 0.0249, Val Loss: 0.0402
# Epoch [540/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0410
# Epoch [541/1500] Fold 10, Train Loss: 0.0249, Val Loss: 0.0408
# Epoch [542/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0410
# Epoch [543/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0402
# Epoch [544/1500] Fold 10, Train Loss: 0.0246, Val Loss: 0.0408
# Epoch [545/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0407
# Epoch [546/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0392
# Epoch [547/1500] Fold 10, Train Loss: 0.0246, Val Loss: 0.0409
# Epoch [548/1500] Fold 10, Train Loss: 0.0246, Val Loss: 0.0403
# Epoch [549/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0401
# Epoch [550/1500] Fold 10, Train Loss: 0.0239, Val Loss: 0.0408
# Epoch [551/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0404
# Epoch [552/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0399
# Epoch [553/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0413
# Epoch [554/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0406
# Epoch [555/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0403
# Epoch [556/1500] Fold 10, Train Loss: 0.0251, Val Loss: 0.0405
# Epoch [557/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0406
# Epoch [558/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0419
# Epoch [559/1500] Fold 10, Train Loss: 0.0241, Val Loss: 0.0408
# Epoch [560/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0416
# Epoch [561/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0413
# Epoch [562/1500] Fold 10, Train Loss: 0.0254, Val Loss: 0.0424
# Epoch [563/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0405
# Epoch [564/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0426
# Epoch [565/1500] Fold 10, Train Loss: 0.0247, Val Loss: 0.0404
# Epoch [566/1500] Fold 10, Train Loss: 0.0242, Val Loss: 0.0415
# Epoch [567/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0417
# Epoch [568/1500] Fold 10, Train Loss: 0.0238, Val Loss: 0.0412
# Epoch [569/1500] Fold 10, Train Loss: 0.0247, Val Loss: 0.0416
# Epoch [570/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0418
# Epoch [571/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0413
# Epoch [572/1500] Fold 10, Train Loss: 0.0249, Val Loss: 0.0408
# Epoch [573/1500] Fold 10, Train Loss: 0.0244, Val Loss: 0.0410
# Epoch [574/1500] Fold 10, Train Loss: 0.0241, Val Loss: 0.0415
# Epoch [575/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0401
# Epoch [576/1500] Fold 10, Train Loss: 0.0239, Val Loss: 0.0408
# Epoch [577/1500] Fold 10, Train Loss: 0.0244, Val Loss: 0.0407
# Epoch [578/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0417
# Epoch [579/1500] Fold 10, Train Loss: 0.0244, Val Loss: 0.0419
# Epoch [580/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0416
# Epoch [581/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0421
# Epoch [582/1500] Fold 10, Train Loss: 0.0241, Val Loss: 0.0425
# Epoch [583/1500] Fold 10, Train Loss: 0.0250, Val Loss: 0.0410
# Epoch [584/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0422
# Epoch [585/1500] Fold 10, Train Loss: 0.0241, Val Loss: 0.0400
# Epoch [586/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0413
# Epoch [587/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0421
# Epoch [588/1500] Fold 10, Train Loss: 0.0252, Val Loss: 0.0413
# Epoch [589/1500] Fold 10, Train Loss: 0.0249, Val Loss: 0.0399
# Epoch [590/1500] Fold 10, Train Loss: 0.0239, Val Loss: 0.0408
# Epoch [591/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0409
# Epoch [592/1500] Fold 10, Train Loss: 0.0236, Val Loss: 0.0416
# Epoch [593/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0408
# Epoch [594/1500] Fold 10, Train Loss: 0.0236, Val Loss: 0.0403
# Epoch [595/1500] Fold 10, Train Loss: 0.0234, Val Loss: 0.0405
# Epoch [596/1500] Fold 10, Train Loss: 0.0241, Val Loss: 0.0405
# Epoch [597/1500] Fold 10, Train Loss: 0.0247, Val Loss: 0.0412
# Epoch [598/1500] Fold 10, Train Loss: 0.0238, Val Loss: 0.0409
# Epoch [599/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0416
# Epoch [600/1500] Fold 10, Train Loss: 0.0251, Val Loss: 0.0389
# Epoch [601/1500] Fold 10, Train Loss: 0.0242, Val Loss: 0.0408
# Epoch [602/1500] Fold 10, Train Loss: 0.0241, Val Loss: 0.0412
# Epoch [603/1500] Fold 10, Train Loss: 0.0238, Val Loss: 0.0410
# Epoch [604/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0404
# Epoch [605/1500] Fold 10, Train Loss: 0.0244, Val Loss: 0.0398
# Epoch [606/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0398
# Epoch [607/1500] Fold 10, Train Loss: 0.0241, Val Loss: 0.0397
# Epoch [608/1500] Fold 10, Train Loss: 0.0234, Val Loss: 0.0420
# Epoch [609/1500] Fold 10, Train Loss: 0.0244, Val Loss: 0.0421
# Epoch [610/1500] Fold 10, Train Loss: 0.0244, Val Loss: 0.0403
# Epoch [611/1500] Fold 10, Train Loss: 0.0233, Val Loss: 0.0416
# Epoch [612/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0405
# Epoch [613/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0414
# Epoch [614/1500] Fold 10, Train Loss: 0.0238, Val Loss: 0.0424
# Epoch [615/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0405
# Epoch [616/1500] Fold 10, Train Loss: 0.0236, Val Loss: 0.0401
# Epoch [617/1500] Fold 10, Train Loss: 0.0235, Val Loss: 0.0421
# Epoch [618/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0420
# Epoch [619/1500] Fold 10, Train Loss: 0.0249, Val Loss: 0.0414
# Epoch [620/1500] Fold 10, Train Loss: 0.0234, Val Loss: 0.0408
# Epoch [621/1500] Fold 10, Train Loss: 0.0235, Val Loss: 0.0410
# Epoch [622/1500] Fold 10, Train Loss: 0.0233, Val Loss: 0.0418
# Epoch [623/1500] Fold 10, Train Loss: 0.0246, Val Loss: 0.0400
# Epoch [624/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0408
# Epoch [625/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0397
# Epoch [626/1500] Fold 10, Train Loss: 0.0231, Val Loss: 0.0402
# Epoch [627/1500] Fold 10, Train Loss: 0.0247, Val Loss: 0.0413
# Epoch [628/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0403
# Epoch [629/1500] Fold 10, Train Loss: 0.0237, Val Loss: 0.0402
# Epoch [630/1500] Fold 10, Train Loss: 0.0242, Val Loss: 0.0403
# Epoch [631/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0404
# Epoch [632/1500] Fold 10, Train Loss: 0.0236, Val Loss: 0.0408
# Epoch [633/1500] Fold 10, Train Loss: 0.0242, Val Loss: 0.0410
# Epoch [634/1500] Fold 10, Train Loss: 0.0230, Val Loss: 0.0403
# Epoch [635/1500] Fold 10, Train Loss: 0.0248, Val Loss: 0.0410
# Epoch [636/1500] Fold 10, Train Loss: 0.0235, Val Loss: 0.0417
# Epoch [637/1500] Fold 10, Train Loss: 0.0245, Val Loss: 0.0415
# Epoch [638/1500] Fold 10, Train Loss: 0.0241, Val Loss: 0.0415
# Epoch [639/1500] Fold 10, Train Loss: 0.0239, Val Loss: 0.0406
# Epoch [640/1500] Fold 10, Train Loss: 0.0235, Val Loss: 0.0409
# Epoch [641/1500] Fold 10, Train Loss: 0.0243, Val Loss: 0.0396
# Epoch [642/1500] Fold 10, Train Loss: 0.0246, Val Loss: 0.0404
# Epoch [643/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0413
# Epoch [644/1500] Fold 10, Train Loss: 0.0235, Val Loss: 0.0415
# Epoch [645/1500] Fold 10, Train Loss: 0.0244, Val Loss: 0.0395
# Epoch [646/1500] Fold 10, Train Loss: 0.0232, Val Loss: 0.0417
# Epoch [647/1500] Fold 10, Train Loss: 0.0244, Val Loss: 0.0395
# Epoch [648/1500] Fold 10, Train Loss: 0.0241, Val Loss: 0.0392
# Epoch [649/1500] Fold 10, Train Loss: 0.0232, Val Loss: 0.0393
# Epoch [650/1500] Fold 10, Train Loss: 0.0237, Val Loss: 0.0409
# Epoch [651/1500] Fold 10, Train Loss: 0.0242, Val Loss: 0.0412
# Epoch [652/1500] Fold 10, Train Loss: 0.0239, Val Loss: 0.0400
# Epoch [653/1500] Fold 10, Train Loss: 0.0233, Val Loss: 0.0406
# Epoch [654/1500] Fold 10, Train Loss: 0.0239, Val Loss: 0.0410
# Epoch [655/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0404
# Epoch [656/1500] Fold 10, Train Loss: 0.0231, Val Loss: 0.0413
# Epoch [657/1500] Fold 10, Train Loss: 0.0234, Val Loss: 0.0403
# Epoch [658/1500] Fold 10, Train Loss: 0.0225, Val Loss: 0.0405
# Epoch [659/1500] Fold 10, Train Loss: 0.0234, Val Loss: 0.0417
# Epoch [660/1500] Fold 10, Train Loss: 0.0239, Val Loss: 0.0410
# Epoch [661/1500] Fold 10, Train Loss: 0.0235, Val Loss: 0.0396
# Epoch [662/1500] Fold 10, Train Loss: 0.0241, Val Loss: 0.0415
# Epoch [663/1500] Fold 10, Train Loss: 0.0238, Val Loss: 0.0421
# Epoch [664/1500] Fold 10, Train Loss: 0.0239, Val Loss: 0.0415
# Epoch [665/1500] Fold 10, Train Loss: 0.0234, Val Loss: 0.0405
# Epoch [666/1500] Fold 10, Train Loss: 0.0236, Val Loss: 0.0411
# Epoch [667/1500] Fold 10, Train Loss: 0.0233, Val Loss: 0.0412
# Epoch [668/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0397
# Epoch [669/1500] Fold 10, Train Loss: 0.0240, Val Loss: 0.0395
# Epoch [670/1500] Fold 10, Train Loss: 0.0241, Val Loss: 0.0408
# Early stopping at epoch 670 for fold 10

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.0397

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.0360
#   Corresponding Training Loss = 0.0363
#   Best Epoch = 75
# Fold 2:
#   Best Validation Loss = 0.0410
#   Corresponding Training Loss = 0.0321
#   Best Epoch = 139
# Fold 3:
#   Best Validation Loss = 0.0343
#   Corresponding Training Loss = 0.0307
#   Best Epoch = 200
# Fold 4:
#   Best Validation Loss = 0.0342
#   Corresponding Training Loss = 0.0358
#   Best Epoch = 88
# Fold 5:
#   Best Validation Loss = 0.0309
#   Corresponding Training Loss = 0.0342
#   Best Epoch = 110
# Fold 6:
#   Best Validation Loss = 0.0353
#   Corresponding Training Loss = 0.0322
#   Best Epoch = 139
# Fold 7:
#   Best Validation Loss = 0.0326
#   Corresponding Training Loss = 0.0312
#   Best Epoch = 222
# Fold 8:
#   Best Validation Loss = 0.0362
#   Corresponding Training Loss = 0.0327
#   Best Epoch = 136
# Fold 9:
#   Best Validation Loss = 0.0327
#   Corresponding Training Loss = 0.0238
#   Best Epoch = 791
# Fold 10:
#   Best Validation Loss = 0.0360
#   Corresponding Training Loss = 0.0315
#   Best Epoch = 170

# %%
def plot_loss_curves_separately(cv_histories):
    """
    Plot training and validation loss curves for each fold in separate figures.
    
    Args:
        cv_histories (list): List of loss histories for each fold.
    """
    # Plot Training Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['train_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
    plt.title('Training Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['val_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
    plt.title('Validation Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_loss_curves_separately(cv_histories)

# %%
import torch
import numpy as np

# Track the best validation loss across all folds
lowest_val_loss = float('inf')
best_model_idx = -1  # Index of the best model
best_model_state = None

# Find the fold with the lowest validation loss
for fold_idx, history in enumerate(cv_histories):
    # Get the best validation loss for this fold
    best_val_loss = min(history['val_loss'])
    
    # Check if this is the lowest validation loss across all folds
    if best_val_loss < lowest_val_loss:
        lowest_val_loss = best_val_loss
        best_model_idx = fold_idx
        best_model_state = best_models[fold_idx]

# Save the model with the lowest validation loss
if best_model_state is not None:
    save_path = f'1500_sd_{best_model_idx + 1}.pth'
    torch.save(best_model_state, save_path)
    print(f"Model from fold {best_model_idx + 1} with the lowest validation loss ({lowest_val_loss:.4f}) saved to {save_path}.")
else:
    print("No model to save.")
# Out:
# Model from fold 5 with the lowest validation loss (0.0309) saved to 1500_sd_5.pth.

# %%
s
