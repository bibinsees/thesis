# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import tifffile as tiff
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
from copy import deepcopy
import random

# %%
# Load the saved day 7 features
combined_ex7 = torch.load('combined_ex7.pt')

# Load the saved day 10 features
combined_ex10 = torch.load('combined_ex10.pt')
# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_ex7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_ex10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([646, 512])
# Loaded Day 10 Features Shape: torch.Size([646, 512])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_18116\1356550951.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_ex7 = torch.load('combined_ex7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_18116\1356550951.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_ex10 = torch.load('combined_ex10.pt')

# %%
# Load the saved day 7 features
combined_cond7 = torch.load('combined_cond7.pt')

# Load the saved day 10 features
combined_cond10 = torch.load('combined_cond10.pt')
# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_cond7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_cond10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([650, 512])
# Loaded Day 10 Features Shape: torch.Size([650, 512])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_18116\3329391658.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_cond7 = torch.load('combined_cond7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_18116\3329391658.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_cond10 = torch.load('combined_cond10.pt')

# %%
# Load the saved day 7 features
combined_sd7 = torch.load('combined_sd7.pt')

# Load the saved day 10 features
combined_sd10 = torch.load('combined_sd10.pt')

# Verify the shapes
print(f"Loaded Day 7 Features Shape: {combined_sd7.shape}")
print(f"Loaded Day 10 Features Shape: {combined_sd10.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([638, 512])
# Loaded Day 10 Features Shape: torch.Size([638, 512])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_18116\1607657786.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_sd7 = torch.load('combined_sd7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_18116\1607657786.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   combined_sd10 = torch.load('combined_sd10.pt')

# %%
train_day7_feats = combined_ex7 
train_day10_feats = combined_ex10

# %%
train_day7_feats = combined_sd7 
train_day10_feats = combined_sd10

# %%
train_day7_feats.shape
# Out:
# torch.Size([646, 512])

# %% [markdown]
# train_day7_feats = combined_cond7
# train_day10_feats = combined_cond10

# %%
type(train_day7_feats)

# %%
train_day7_feats[0].shape

# %%
import matplotlib.pyplot as plt

# Plot histograms for input (X) and target (Y)
plt.figure(figsize=(12, 6))

# Flatten tensors to 1D for easier visualization
train_day7_feats_flat = train_day7_feats.flatten().cpu().numpy()
train_day10_feats_flat = train_day10_feats.flatten().cpu().numpy()

# Input (X) histogram
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_flat, bins=50, color='blue', alpha=0.7, label='Input (X)')
plt.title('Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_flat, bins=50, color='green', alpha=0.7, label='Target (Y)')
plt.title('Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"Input (X): Mean={train_day7_feats.mean():.4f}, Std={train_day7_feats.std():.4f}")
print(f"Target (Y): Mean={train_day10_feats.mean():.4f}, Std={train_day10_feats.std():.4f}")
# Out:
# Input (X): Mean=0.8442, Std=1.1278
# Target (Y): Mean=0.9293, Std=1.2253

# %%
# Convert PyTorch tensor to NumPy array
train_day7_feats_numpy = train_day7_feats.numpy()
train_day10_feats_numpy = train_day10_feats.numpy()

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize separate MinMaxScaler for day7 and day10
scaler_day7 = MinMaxScaler()
scaler_day10 = MinMaxScaler()

# Fit and transform the train_day7_feats
train_day7_feats_minmaxed = scaler_day7.fit_transform(train_day7_feats_numpy)
print(train_day7_feats_minmaxed.shape)
# Get min and max values for day7
min_values_day7 = scaler_day7.data_min_
max_values_day7 = scaler_day7.data_max_

print(min_values_day7.shape)
print(max_values_day7.shape)
#print("Min values for day7:", min_values_day7)
#print("Max values for day7:", max_values_day7)

# Fit and transform the train_day10_feats (target)
train_day10_feats_minmaxed = scaler_day10.fit_transform(train_day10_feats_numpy)
print(train_day10_feats_minmaxed.shape)
# Get min and max values for day10
min_values_day10 = scaler_day10.data_min_
max_values_day10 = scaler_day10.data_max_

print(min_values_day10.shape)
print(max_values_day10.shape)
#print("Min values for day10:", min_values_day10)
#print("Max values for day10:", max_values_day10)

# Convert the scaled data back to PyTorch tensors (optional)
train_day7_feats_minmaxed = torch.tensor(train_day7_feats_minmaxed)
train_day10_feats_minmaxed = torch.tensor(train_day10_feats_minmaxed)
# Out:
# (646, 512)
# (512,)
# (512,)
# (646, 512)
# (512,)
# (512,)

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'ex7.pkl')
joblib.dump(scaler_day10, 'ex10.pkl')

print("Scalers saved!")
# Out:
# Scalers saved!

# %%
import joblib

# Save the scalers to disk
joblib.dump(scaler_day7, 'sd7.pkl')
joblib.dump(scaler_day10, 'sd10.pkl')

print("Scalers saved!")

# %%
type(train_day7_feats_minmaxed)
# Out:
# torch.Tensor

# %%
import matplotlib.pyplot as plt

# Flatten the tensors for easier visualization
train_day7_feats_minmaxed_flat = train_day7_feats_minmaxed.flatten().cpu().numpy()
train_day10_feats_minmaxed_flat = train_day10_feats_minmaxed.flatten().cpu().numpy()

# Plot histograms
plt.figure(figsize=(12, 6))

# Input (X) histogram after Min-Max scaling
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_minmaxed_flat, bins=50, color='blue', alpha=0.7, label='Min-Max Scaled Input (X)')
plt.title('Min-Max Scaled Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram after Min-Max scaling
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_minmaxed_flat, bins=50, color='green', alpha=0.7, label='Min-Max Scaled Target (Y)')
plt.title('Min-Max Scaled Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %%
class FeaturePredictor(nn.Module):
    def __init__(self, input_size=512, output_size=512):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, 16),
            nn.BatchNorm1d(16),
        )
        self.decoder = nn.Sequential(
            nn.Linear(16, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Linear(64, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Linear(256, output_size)
        )
    
    # Corrected indentation for forward method
    def forward(self, x):
        x = self.encoder(x)
        z = self.decoder(x)
        return z

# %% [markdown]
# class FeaturePredictor(nn.Module):
#     def __init__(self, input_size=512, output_size=512):
#         super().__init__()
#         self.encoder = nn.Sequential(
#             nn.Linear(input_size, 256),
#             nn.BatchNorm1d(256),  # Added batch norm
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(256, 64),
#             nn.BatchNorm1d(64),   # Added batch norm
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(64, 16),     # Bottleneck
#             nn.BatchNorm1d(16),    # Added batch norm for bottleneck
#         )
#         self.decoder = nn.Sequential(
#             nn.Linear(16, 64),
#             nn.BatchNorm1d(64),   # Added batch norm
#             nn.ReLU(),
#             nn.Linear(64, 256),
#             nn.BatchNorm1d(256),  # Added batch norm
#             nn.ReLU(),
#             nn.Linear(256, output_size)
#         )
#
#     def forward(self, x):
#         z = self.encoder(x)
#         return self.decoder(z) + x  # Skip connection
#
#     '''def forward(self, x):
#         x = self.encoder(x)
#         z = self.decoder(x)
#         return z'''

# %% [markdown]
# import torch.nn as nn
# from torch.utils.data import TensorDataset, DataLoader
#
# class FeaturePredictor(nn.Module):
#     def __init__(self, input_size=512, output_size=512):
#         super(FeaturePredictor, self).__init__()
#         self.model = nn.Sequential(
#             nn.Linear(input_size, 256),
#             nn.ReLU(),
#             nn.Linear(256, 128),
#             nn.ReLU(),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Linear(64, 32),
#             nn.ReLU(),
#             nn.Linear(32, 16),
#             nn.ReLU(),
#             nn.Linear(16,8),
#             nn.ReLU(),
#             nn.Linear(8, 16),
#             nn.ReLU(),
#             nn.Linear(16,32),
#             nn.ReLU(),
#             nn.Linear(32, 64),
#             nn.ReLU(),
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Linear(128,256),
#             nn.ReLU(),
#             nn.Linear(256, output_size)
#         )
#
#     def forward(self, x):
#         return self.model(x)

# %%
model = FeaturePredictor()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset

# %%
from torch.utils.data import TensorDataset

optimizer_class = torch.optim.Adam

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset
import numpy as np
import torch

# %%
class EarlyStopping:
    def __init__(self, patience=10, delta=0.0):
        """
        Args:
            patience (int): How many epochs to wait after the last validation loss improvement.
            delta (float): Minimum change in the validation loss to qualify as an improvement.
        """
        self.patience = patience
        self.delta = delta
        self.best_loss = None
        self.no_improvement_epochs = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.no_improvement_epochs = 0
        else:
            self.no_improvement_epochs += 1
            if self.no_improvement_epochs >= self.patience:
                self.early_stop = True


def cross_validate_with_early_stopping(
    model_class, dataset, criterion, optimizer_class, num_epochs=50, n_splits=10, patience=10, device='cuda'
):
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    histories = []
    best_models = []

    for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset)):
        print(f"Fold {fold + 1}/{n_splits}")

        # Create subsets for this fold
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        # Create DataLoaders
        train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

        # Initialize the model, optimizer, and early stopping for this fold
        model = model_class().to(device)
        optimizer = optimizer_class(model.parameters(), lr=1e-4)
        early_stopping = EarlyStopping(patience=patience)

        # Training and validation loop
        history = {'train_loss': [], 'val_loss': []}
        for epoch in range(num_epochs):
            # Training phase
            model.train()
            train_loss = 0.0
            for batch_inputs, batch_targets in train_loader:
                batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)

                # Forward pass
                outputs = model(batch_inputs)
                loss = criterion(outputs, batch_targets)
                train_loss += loss.item()

                # Backward pass and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            train_loss /= len(train_loader)
            history['train_loss'].append(train_loss)

            # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for batch_inputs, batch_targets in val_loader:
                    batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)
                    outputs = model(batch_inputs)
                    loss = criterion(outputs, batch_targets)
                    val_loss += loss.item()

            val_loss /= len(val_loader)
            history['val_loss'].append(val_loss)

            print(f"Epoch [{epoch + 1}/{num_epochs}] Fold {fold + 1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

            # Check early stopping
            early_stopping(val_loss)
            if early_stopping.early_stop:
                print(f"Early stopping at epoch {epoch + 1} for fold {fold + 1}")
                break

        # Save the best model for this fold
        best_models.append(model.state_dict())
        histories.append(history)

    return histories, best_models

# %%
# MIN MAX
dataset = TensorDataset(train_day7_feats_minmaxed, train_day10_feats_minmaxed)

cv_histories, best_models = cross_validate_with_early_stopping(
    model_class=FeaturePredictor,
    dataset=dataset,
    criterion=nn.MSELoss(),
    optimizer_class=torch.optim.Adam,
    num_epochs=1500,
    patience=500
)
# Out:
# Fold 1/10
# Epoch [1/1500] Fold 1, Train Loss: 0.2283, Val Loss: 0.1100
# Epoch [2/1500] Fold 1, Train Loss: 0.1661, Val Loss: 0.0981
# Epoch [3/1500] Fold 1, Train Loss: 0.1315, Val Loss: 0.0885
# Epoch [4/1500] Fold 1, Train Loss: 0.1126, Val Loss: 0.0754
# Epoch [5/1500] Fold 1, Train Loss: 0.0990, Val Loss: 0.0684
# Epoch [6/1500] Fold 1, Train Loss: 0.0872, Val Loss: 0.0609
# Epoch [7/1500] Fold 1, Train Loss: 0.0790, Val Loss: 0.0545
# Epoch [8/1500] Fold 1, Train Loss: 0.0717, Val Loss: 0.0510
# Epoch [9/1500] Fold 1, Train Loss: 0.0676, Val Loss: 0.0470
# Epoch [10/1500] Fold 1, Train Loss: 0.0630, Val Loss: 0.0428
# Epoch [11/1500] Fold 1, Train Loss: 0.0589, Val Loss: 0.0413
# Epoch [12/1500] Fold 1, Train Loss: 0.0565, Val Loss: 0.0384
# Epoch [13/1500] Fold 1, Train Loss: 0.0536, Val Loss: 0.0372
# Epoch [14/1500] Fold 1, Train Loss: 0.0511, Val Loss: 0.0384
# Epoch [15/1500] Fold 1, Train Loss: 0.0501, Val Loss: 0.0351
# Epoch [16/1500] Fold 1, Train Loss: 0.0474, Val Loss: 0.0345
# Epoch [17/1500] Fold 1, Train Loss: 0.0470, Val Loss: 0.0340
# Epoch [18/1500] Fold 1, Train Loss: 0.0463, Val Loss: 0.0337
# Epoch [19/1500] Fold 1, Train Loss: 0.0456, Val Loss: 0.0332
# Epoch [20/1500] Fold 1, Train Loss: 0.0446, Val Loss: 0.0336
# Epoch [21/1500] Fold 1, Train Loss: 0.0429, Val Loss: 0.0314
# Epoch [22/1500] Fold 1, Train Loss: 0.0432, Val Loss: 0.0309
# Epoch [23/1500] Fold 1, Train Loss: 0.0417, Val Loss: 0.0317
# Epoch [24/1500] Fold 1, Train Loss: 0.0412, Val Loss: 0.0316
# Epoch [25/1500] Fold 1, Train Loss: 0.0407, Val Loss: 0.0304
# Epoch [26/1500] Fold 1, Train Loss: 0.0397, Val Loss: 0.0306
# Epoch [27/1500] Fold 1, Train Loss: 0.0403, Val Loss: 0.0296
# Epoch [28/1500] Fold 1, Train Loss: 0.0383, Val Loss: 0.0299
# Epoch [29/1500] Fold 1, Train Loss: 0.0394, Val Loss: 0.0301
# Epoch [30/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0290
# Epoch [31/1500] Fold 1, Train Loss: 0.0392, Val Loss: 0.0283
# Epoch [32/1500] Fold 1, Train Loss: 0.0381, Val Loss: 0.0289
# Epoch [33/1500] Fold 1, Train Loss: 0.0382, Val Loss: 0.0280
# Epoch [34/1500] Fold 1, Train Loss: 0.0376, Val Loss: 0.0284
# Epoch [35/1500] Fold 1, Train Loss: 0.0373, Val Loss: 0.0292
# Epoch [36/1500] Fold 1, Train Loss: 0.0369, Val Loss: 0.0297
# Epoch [37/1500] Fold 1, Train Loss: 0.0380, Val Loss: 0.0284
# Epoch [38/1500] Fold 1, Train Loss: 0.0378, Val Loss: 0.0291
# Epoch [39/1500] Fold 1, Train Loss: 0.0365, Val Loss: 0.0284
# Epoch [40/1500] Fold 1, Train Loss: 0.0361, Val Loss: 0.0277
# Epoch [41/1500] Fold 1, Train Loss: 0.0359, Val Loss: 0.0274
# Epoch [42/1500] Fold 1, Train Loss: 0.0359, Val Loss: 0.0279
# Epoch [43/1500] Fold 1, Train Loss: 0.0360, Val Loss: 0.0286
# Epoch [44/1500] Fold 1, Train Loss: 0.0363, Val Loss: 0.0292
# Epoch [45/1500] Fold 1, Train Loss: 0.0348, Val Loss: 0.0279
# Epoch [46/1500] Fold 1, Train Loss: 0.0350, Val Loss: 0.0277
# Epoch [47/1500] Fold 1, Train Loss: 0.0340, Val Loss: 0.0281
# Epoch [48/1500] Fold 1, Train Loss: 0.0349, Val Loss: 0.0281
# Epoch [49/1500] Fold 1, Train Loss: 0.0350, Val Loss: 0.0276
# Epoch [50/1500] Fold 1, Train Loss: 0.0342, Val Loss: 0.0274
# Epoch [51/1500] Fold 1, Train Loss: 0.0336, Val Loss: 0.0271
# Epoch [52/1500] Fold 1, Train Loss: 0.0341, Val Loss: 0.0267
# Epoch [53/1500] Fold 1, Train Loss: 0.0346, Val Loss: 0.0271
# Epoch [54/1500] Fold 1, Train Loss: 0.0334, Val Loss: 0.0270
# Epoch [55/1500] Fold 1, Train Loss: 0.0349, Val Loss: 0.0269
# Epoch [56/1500] Fold 1, Train Loss: 0.0349, Val Loss: 0.0262
# Epoch [57/1500] Fold 1, Train Loss: 0.0338, Val Loss: 0.0264
# Epoch [58/1500] Fold 1, Train Loss: 0.0335, Val Loss: 0.0274
# Epoch [59/1500] Fold 1, Train Loss: 0.0331, Val Loss: 0.0270
# Epoch [60/1500] Fold 1, Train Loss: 0.0351, Val Loss: 0.0265
# Epoch [61/1500] Fold 1, Train Loss: 0.0333, Val Loss: 0.0257
# Epoch [62/1500] Fold 1, Train Loss: 0.0345, Val Loss: 0.0253
# Epoch [63/1500] Fold 1, Train Loss: 0.0324, Val Loss: 0.0256
# Epoch [64/1500] Fold 1, Train Loss: 0.0333, Val Loss: 0.0251
# Epoch [65/1500] Fold 1, Train Loss: 0.0325, Val Loss: 0.0251
# Epoch [66/1500] Fold 1, Train Loss: 0.0332, Val Loss: 0.0252
# Epoch [67/1500] Fold 1, Train Loss: 0.0314, Val Loss: 0.0250
# Epoch [68/1500] Fold 1, Train Loss: 0.0320, Val Loss: 0.0252
# Epoch [69/1500] Fold 1, Train Loss: 0.0315, Val Loss: 0.0248
# Epoch [70/1500] Fold 1, Train Loss: 0.0313, Val Loss: 0.0250
# Epoch [71/1500] Fold 1, Train Loss: 0.0327, Val Loss: 0.0246
# Epoch [72/1500] Fold 1, Train Loss: 0.0306, Val Loss: 0.0251
# Epoch [73/1500] Fold 1, Train Loss: 0.0309, Val Loss: 0.0251
# Epoch [74/1500] Fold 1, Train Loss: 0.0315, Val Loss: 0.0250
# Epoch [75/1500] Fold 1, Train Loss: 0.0323, Val Loss: 0.0243
# Epoch [76/1500] Fold 1, Train Loss: 0.0316, Val Loss: 0.0248
# Epoch [77/1500] Fold 1, Train Loss: 0.0299, Val Loss: 0.0247
# Epoch [78/1500] Fold 1, Train Loss: 0.0310, Val Loss: 0.0252
# Epoch [79/1500] Fold 1, Train Loss: 0.0298, Val Loss: 0.0254
# Epoch [80/1500] Fold 1, Train Loss: 0.0298, Val Loss: 0.0245
# Epoch [81/1500] Fold 1, Train Loss: 0.0292, Val Loss: 0.0251
# Epoch [82/1500] Fold 1, Train Loss: 0.0294, Val Loss: 0.0244
# Epoch [83/1500] Fold 1, Train Loss: 0.0318, Val Loss: 0.0245
# Epoch [84/1500] Fold 1, Train Loss: 0.0307, Val Loss: 0.0245
# Epoch [85/1500] Fold 1, Train Loss: 0.0314, Val Loss: 0.0245
# Epoch [86/1500] Fold 1, Train Loss: 0.0297, Val Loss: 0.0239
# Epoch [87/1500] Fold 1, Train Loss: 0.0293, Val Loss: 0.0235
# Epoch [88/1500] Fold 1, Train Loss: 0.0301, Val Loss: 0.0238
# Epoch [89/1500] Fold 1, Train Loss: 0.0311, Val Loss: 0.0240
# Epoch [90/1500] Fold 1, Train Loss: 0.0291, Val Loss: 0.0236
# Epoch [91/1500] Fold 1, Train Loss: 0.0292, Val Loss: 0.0238
# Epoch [92/1500] Fold 1, Train Loss: 0.0298, Val Loss: 0.0241
# Epoch [93/1500] Fold 1, Train Loss: 0.0287, Val Loss: 0.0235
# Epoch [94/1500] Fold 1, Train Loss: 0.0287, Val Loss: 0.0228
# Epoch [95/1500] Fold 1, Train Loss: 0.0286, Val Loss: 0.0231
# Epoch [96/1500] Fold 1, Train Loss: 0.0286, Val Loss: 0.0228
# Epoch [97/1500] Fold 1, Train Loss: 0.0278, Val Loss: 0.0231
# Epoch [98/1500] Fold 1, Train Loss: 0.0274, Val Loss: 0.0228
# Epoch [99/1500] Fold 1, Train Loss: 0.0291, Val Loss: 0.0234
# Epoch [100/1500] Fold 1, Train Loss: 0.0299, Val Loss: 0.0227
# Epoch [101/1500] Fold 1, Train Loss: 0.0283, Val Loss: 0.0224
# Epoch [102/1500] Fold 1, Train Loss: 0.0275, Val Loss: 0.0224
# Epoch [103/1500] Fold 1, Train Loss: 0.0277, Val Loss: 0.0226
# Epoch [104/1500] Fold 1, Train Loss: 0.0274, Val Loss: 0.0222
# Epoch [105/1500] Fold 1, Train Loss: 0.0266, Val Loss: 0.0220
# Epoch [106/1500] Fold 1, Train Loss: 0.0280, Val Loss: 0.0211
# Epoch [107/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0212
# Epoch [108/1500] Fold 1, Train Loss: 0.0275, Val Loss: 0.0216
# Epoch [109/1500] Fold 1, Train Loss: 0.0276, Val Loss: 0.0224
# Epoch [110/1500] Fold 1, Train Loss: 0.0259, Val Loss: 0.0216
# Epoch [111/1500] Fold 1, Train Loss: 0.0280, Val Loss: 0.0220
# Epoch [112/1500] Fold 1, Train Loss: 0.0289, Val Loss: 0.0227
# Epoch [113/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0221
# Epoch [114/1500] Fold 1, Train Loss: 0.0269, Val Loss: 0.0209
# Epoch [115/1500] Fold 1, Train Loss: 0.0286, Val Loss: 0.0207
# Epoch [116/1500] Fold 1, Train Loss: 0.0279, Val Loss: 0.0213
# Epoch [117/1500] Fold 1, Train Loss: 0.0263, Val Loss: 0.0214
# Epoch [118/1500] Fold 1, Train Loss: 0.0275, Val Loss: 0.0210
# Epoch [119/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0206
# Epoch [120/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0209
# Epoch [121/1500] Fold 1, Train Loss: 0.0261, Val Loss: 0.0215
# Epoch [122/1500] Fold 1, Train Loss: 0.0260, Val Loss: 0.0207
# Epoch [123/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0206
# Epoch [124/1500] Fold 1, Train Loss: 0.0259, Val Loss: 0.0204
# Epoch [125/1500] Fold 1, Train Loss: 0.0271, Val Loss: 0.0205
# Epoch [126/1500] Fold 1, Train Loss: 0.0249, Val Loss: 0.0204
# Epoch [127/1500] Fold 1, Train Loss: 0.0256, Val Loss: 0.0199
# Epoch [128/1500] Fold 1, Train Loss: 0.0249, Val Loss: 0.0198
# Epoch [129/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0200
# Epoch [130/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0208
# Epoch [131/1500] Fold 1, Train Loss: 0.0267, Val Loss: 0.0221
# Epoch [132/1500] Fold 1, Train Loss: 0.0253, Val Loss: 0.0210
# Epoch [133/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0209
# Epoch [134/1500] Fold 1, Train Loss: 0.0249, Val Loss: 0.0203
# Epoch [135/1500] Fold 1, Train Loss: 0.0253, Val Loss: 0.0198
# Epoch [136/1500] Fold 1, Train Loss: 0.0257, Val Loss: 0.0205
# Epoch [137/1500] Fold 1, Train Loss: 0.0262, Val Loss: 0.0200
# Epoch [138/1500] Fold 1, Train Loss: 0.0252, Val Loss: 0.0212
# Epoch [139/1500] Fold 1, Train Loss: 0.0250, Val Loss: 0.0208
# Epoch [140/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0212
# Epoch [141/1500] Fold 1, Train Loss: 0.0249, Val Loss: 0.0199
# Epoch [142/1500] Fold 1, Train Loss: 0.0273, Val Loss: 0.0193
# Epoch [143/1500] Fold 1, Train Loss: 0.0241, Val Loss: 0.0199
# Epoch [144/1500] Fold 1, Train Loss: 0.0243, Val Loss: 0.0203
# Epoch [145/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0192
# Epoch [146/1500] Fold 1, Train Loss: 0.0255, Val Loss: 0.0192
# Epoch [147/1500] Fold 1, Train Loss: 0.0251, Val Loss: 0.0202
# Epoch [148/1500] Fold 1, Train Loss: 0.0236, Val Loss: 0.0195
# Epoch [149/1500] Fold 1, Train Loss: 0.0250, Val Loss: 0.0196
# Epoch [150/1500] Fold 1, Train Loss: 0.0236, Val Loss: 0.0195
# Epoch [151/1500] Fold 1, Train Loss: 0.0239, Val Loss: 0.0202
# Epoch [152/1500] Fold 1, Train Loss: 0.0258, Val Loss: 0.0192
# Epoch [153/1500] Fold 1, Train Loss: 0.0238, Val Loss: 0.0196
# Epoch [154/1500] Fold 1, Train Loss: 0.0233, Val Loss: 0.0189
# Epoch [155/1500] Fold 1, Train Loss: 0.0250, Val Loss: 0.0190
# Epoch [156/1500] Fold 1, Train Loss: 0.0242, Val Loss: 0.0192
# Epoch [157/1500] Fold 1, Train Loss: 0.0241, Val Loss: 0.0192
# Epoch [158/1500] Fold 1, Train Loss: 0.0246, Val Loss: 0.0189
# Epoch [159/1500] Fold 1, Train Loss: 0.0241, Val Loss: 0.0214
# Epoch [160/1500] Fold 1, Train Loss: 0.0239, Val Loss: 0.0208
# Epoch [161/1500] Fold 1, Train Loss: 0.0244, Val Loss: 0.0192
# Epoch [162/1500] Fold 1, Train Loss: 0.0264, Val Loss: 0.0199
# Epoch [163/1500] Fold 1, Train Loss: 0.0247, Val Loss: 0.0205
# Epoch [164/1500] Fold 1, Train Loss: 0.0239, Val Loss: 0.0198
# Epoch [165/1500] Fold 1, Train Loss: 0.0240, Val Loss: 0.0193
# Epoch [166/1500] Fold 1, Train Loss: 0.0228, Val Loss: 0.0201
# Epoch [167/1500] Fold 1, Train Loss: 0.0232, Val Loss: 0.0188
# Epoch [168/1500] Fold 1, Train Loss: 0.0245, Val Loss: 0.0184
# Epoch [169/1500] Fold 1, Train Loss: 0.0235, Val Loss: 0.0192
# Epoch [170/1500] Fold 1, Train Loss: 0.0231, Val Loss: 0.0187
# Epoch [171/1500] Fold 1, Train Loss: 0.0240, Val Loss: 0.0188
# Epoch [172/1500] Fold 1, Train Loss: 0.0245, Val Loss: 0.0190
# Epoch [173/1500] Fold 1, Train Loss: 0.0235, Val Loss: 0.0186
# Epoch [174/1500] Fold 1, Train Loss: 0.0231, Val Loss: 0.0191
# Epoch [175/1500] Fold 1, Train Loss: 0.0223, Val Loss: 0.0185
# Epoch [176/1500] Fold 1, Train Loss: 0.0225, Val Loss: 0.0188
# Epoch [177/1500] Fold 1, Train Loss: 0.0221, Val Loss: 0.0196
# Epoch [178/1500] Fold 1, Train Loss: 0.0234, Val Loss: 0.0191
# Epoch [179/1500] Fold 1, Train Loss: 0.0238, Val Loss: 0.0186
# Epoch [180/1500] Fold 1, Train Loss: 0.0225, Val Loss: 0.0183
# Epoch [181/1500] Fold 1, Train Loss: 0.0223, Val Loss: 0.0187
# Epoch [182/1500] Fold 1, Train Loss: 0.0220, Val Loss: 0.0184
# Epoch [183/1500] Fold 1, Train Loss: 0.0227, Val Loss: 0.0183
# Epoch [184/1500] Fold 1, Train Loss: 0.0234, Val Loss: 0.0187
# Epoch [185/1500] Fold 1, Train Loss: 0.0234, Val Loss: 0.0188
# Epoch [186/1500] Fold 1, Train Loss: 0.0242, Val Loss: 0.0184
# Epoch [187/1500] Fold 1, Train Loss: 0.0228, Val Loss: 0.0185
# Epoch [188/1500] Fold 1, Train Loss: 0.0231, Val Loss: 0.0184
# Epoch [189/1500] Fold 1, Train Loss: 0.0229, Val Loss: 0.0183
# Epoch [190/1500] Fold 1, Train Loss: 0.0231, Val Loss: 0.0179
# Epoch [191/1500] Fold 1, Train Loss: 0.0223, Val Loss: 0.0181
# Epoch [192/1500] Fold 1, Train Loss: 0.0218, Val Loss: 0.0176
# Epoch [193/1500] Fold 1, Train Loss: 0.0223, Val Loss: 0.0177
# Epoch [194/1500] Fold 1, Train Loss: 0.0224, Val Loss: 0.0178
# Epoch [195/1500] Fold 1, Train Loss: 0.0212, Val Loss: 0.0183
# Epoch [196/1500] Fold 1, Train Loss: 0.0219, Val Loss: 0.0174
# Epoch [197/1500] Fold 1, Train Loss: 0.0225, Val Loss: 0.0178
# Epoch [198/1500] Fold 1, Train Loss: 0.0219, Val Loss: 0.0179
# Epoch [199/1500] Fold 1, Train Loss: 0.0234, Val Loss: 0.0168
# Epoch [200/1500] Fold 1, Train Loss: 0.0219, Val Loss: 0.0179
# Epoch [201/1500] Fold 1, Train Loss: 0.0231, Val Loss: 0.0170
# Epoch [202/1500] Fold 1, Train Loss: 0.0216, Val Loss: 0.0177
# Epoch [203/1500] Fold 1, Train Loss: 0.0212, Val Loss: 0.0174
# Epoch [204/1500] Fold 1, Train Loss: 0.0214, Val Loss: 0.0175
# Epoch [205/1500] Fold 1, Train Loss: 0.0227, Val Loss: 0.0173
# Epoch [206/1500] Fold 1, Train Loss: 0.0228, Val Loss: 0.0173
# Epoch [207/1500] Fold 1, Train Loss: 0.0234, Val Loss: 0.0169
# Epoch [208/1500] Fold 1, Train Loss: 0.0229, Val Loss: 0.0176
# Epoch [209/1500] Fold 1, Train Loss: 0.0218, Val Loss: 0.0173
# Epoch [210/1500] Fold 1, Train Loss: 0.0227, Val Loss: 0.0179
# Epoch [211/1500] Fold 1, Train Loss: 0.0228, Val Loss: 0.0176
# Epoch [212/1500] Fold 1, Train Loss: 0.0214, Val Loss: 0.0175
# Epoch [213/1500] Fold 1, Train Loss: 0.0234, Val Loss: 0.0172
# Epoch [214/1500] Fold 1, Train Loss: 0.0230, Val Loss: 0.0173
# Epoch [215/1500] Fold 1, Train Loss: 0.0227, Val Loss: 0.0174
# Epoch [216/1500] Fold 1, Train Loss: 0.0212, Val Loss: 0.0174
# Epoch [217/1500] Fold 1, Train Loss: 0.0228, Val Loss: 0.0174
# Epoch [218/1500] Fold 1, Train Loss: 0.0224, Val Loss: 0.0171
# Epoch [219/1500] Fold 1, Train Loss: 0.0212, Val Loss: 0.0168
# Epoch [220/1500] Fold 1, Train Loss: 0.0219, Val Loss: 0.0170
# Epoch [221/1500] Fold 1, Train Loss: 0.0214, Val Loss: 0.0173
# Epoch [222/1500] Fold 1, Train Loss: 0.0213, Val Loss: 0.0174
# Epoch [223/1500] Fold 1, Train Loss: 0.0218, Val Loss: 0.0168
# Epoch [224/1500] Fold 1, Train Loss: 0.0225, Val Loss: 0.0166
# Epoch [225/1500] Fold 1, Train Loss: 0.0236, Val Loss: 0.0178
# Epoch [226/1500] Fold 1, Train Loss: 0.0216, Val Loss: 0.0173
# Epoch [227/1500] Fold 1, Train Loss: 0.0227, Val Loss: 0.0169
# Epoch [228/1500] Fold 1, Train Loss: 0.0235, Val Loss: 0.0171
# Epoch [229/1500] Fold 1, Train Loss: 0.0210, Val Loss: 0.0174
# Epoch [230/1500] Fold 1, Train Loss: 0.0208, Val Loss: 0.0179
# Epoch [231/1500] Fold 1, Train Loss: 0.0207, Val Loss: 0.0175
# Epoch [232/1500] Fold 1, Train Loss: 0.0217, Val Loss: 0.0165
# Epoch [233/1500] Fold 1, Train Loss: 0.0207, Val Loss: 0.0171
# Epoch [234/1500] Fold 1, Train Loss: 0.0214, Val Loss: 0.0170
# Epoch [235/1500] Fold 1, Train Loss: 0.0211, Val Loss: 0.0169
# Epoch [236/1500] Fold 1, Train Loss: 0.0202, Val Loss: 0.0169
# Epoch [237/1500] Fold 1, Train Loss: 0.0212, Val Loss: 0.0163
# Epoch [238/1500] Fold 1, Train Loss: 0.0210, Val Loss: 0.0166
# Epoch [239/1500] Fold 1, Train Loss: 0.0216, Val Loss: 0.0164
# Epoch [240/1500] Fold 1, Train Loss: 0.0223, Val Loss: 0.0167
# Epoch [241/1500] Fold 1, Train Loss: 0.0212, Val Loss: 0.0172
# Epoch [242/1500] Fold 1, Train Loss: 0.0216, Val Loss: 0.0165
# Epoch [243/1500] Fold 1, Train Loss: 0.0207, Val Loss: 0.0169
# Epoch [244/1500] Fold 1, Train Loss: 0.0213, Val Loss: 0.0172
# Epoch [245/1500] Fold 1, Train Loss: 0.0212, Val Loss: 0.0164
# Epoch [246/1500] Fold 1, Train Loss: 0.0204, Val Loss: 0.0174
# Epoch [247/1500] Fold 1, Train Loss: 0.0205, Val Loss: 0.0169
# Epoch [248/1500] Fold 1, Train Loss: 0.0231, Val Loss: 0.0167
# Epoch [249/1500] Fold 1, Train Loss: 0.0212, Val Loss: 0.0174
# Epoch [250/1500] Fold 1, Train Loss: 0.0211, Val Loss: 0.0167
# Epoch [251/1500] Fold 1, Train Loss: 0.0207, Val Loss: 0.0170
# Epoch [252/1500] Fold 1, Train Loss: 0.0204, Val Loss: 0.0165
# Epoch [253/1500] Fold 1, Train Loss: 0.0212, Val Loss: 0.0179
# Epoch [254/1500] Fold 1, Train Loss: 0.0202, Val Loss: 0.0170
# Epoch [255/1500] Fold 1, Train Loss: 0.0218, Val Loss: 0.0172
# Epoch [256/1500] Fold 1, Train Loss: 0.0200, Val Loss: 0.0165
# Epoch [257/1500] Fold 1, Train Loss: 0.0201, Val Loss: 0.0168
# Epoch [258/1500] Fold 1, Train Loss: 0.0199, Val Loss: 0.0168
# Epoch [259/1500] Fold 1, Train Loss: 0.0205, Val Loss: 0.0168
# Epoch [260/1500] Fold 1, Train Loss: 0.0210, Val Loss: 0.0166
# Epoch [261/1500] Fold 1, Train Loss: 0.0199, Val Loss: 0.0163
# Epoch [262/1500] Fold 1, Train Loss: 0.0203, Val Loss: 0.0160
# Epoch [263/1500] Fold 1, Train Loss: 0.0197, Val Loss: 0.0177
# Epoch [264/1500] Fold 1, Train Loss: 0.0209, Val Loss: 0.0168
# Epoch [265/1500] Fold 1, Train Loss: 0.0197, Val Loss: 0.0170
# Epoch [266/1500] Fold 1, Train Loss: 0.0197, Val Loss: 0.0170
# Epoch [267/1500] Fold 1, Train Loss: 0.0200, Val Loss: 0.0169
# Epoch [268/1500] Fold 1, Train Loss: 0.0214, Val Loss: 0.0168
# Epoch [269/1500] Fold 1, Train Loss: 0.0210, Val Loss: 0.0181
# Epoch [270/1500] Fold 1, Train Loss: 0.0196, Val Loss: 0.0163
# Epoch [271/1500] Fold 1, Train Loss: 0.0206, Val Loss: 0.0158
# Epoch [272/1500] Fold 1, Train Loss: 0.0198, Val Loss: 0.0162
# Epoch [273/1500] Fold 1, Train Loss: 0.0207, Val Loss: 0.0165
# Epoch [274/1500] Fold 1, Train Loss: 0.0201, Val Loss: 0.0168
# Epoch [275/1500] Fold 1, Train Loss: 0.0205, Val Loss: 0.0169
# Epoch [276/1500] Fold 1, Train Loss: 0.0217, Val Loss: 0.0164
# Epoch [277/1500] Fold 1, Train Loss: 0.0210, Val Loss: 0.0164
# Epoch [278/1500] Fold 1, Train Loss: 0.0226, Val Loss: 0.0163
# Epoch [279/1500] Fold 1, Train Loss: 0.0214, Val Loss: 0.0166
# Epoch [280/1500] Fold 1, Train Loss: 0.0206, Val Loss: 0.0172
# Epoch [281/1500] Fold 1, Train Loss: 0.0211, Val Loss: 0.0168
# Epoch [282/1500] Fold 1, Train Loss: 0.0206, Val Loss: 0.0173
# Epoch [283/1500] Fold 1, Train Loss: 0.0221, Val Loss: 0.0169
# Epoch [284/1500] Fold 1, Train Loss: 0.0215, Val Loss: 0.0167
# Epoch [285/1500] Fold 1, Train Loss: 0.0204, Val Loss: 0.0180
# Epoch [286/1500] Fold 1, Train Loss: 0.0217, Val Loss: 0.0177
# Epoch [287/1500] Fold 1, Train Loss: 0.0202, Val Loss: 0.0172
# Epoch [288/1500] Fold 1, Train Loss: 0.0202, Val Loss: 0.0165
# Epoch [289/1500] Fold 1, Train Loss: 0.0199, Val Loss: 0.0165
# Epoch [290/1500] Fold 1, Train Loss: 0.0198, Val Loss: 0.0164
# Epoch [291/1500] Fold 1, Train Loss: 0.0200, Val Loss: 0.0168
# Epoch [292/1500] Fold 1, Train Loss: 0.0197, Val Loss: 0.0169
# Epoch [293/1500] Fold 1, Train Loss: 0.0207, Val Loss: 0.0174
# Epoch [294/1500] Fold 1, Train Loss: 0.0198, Val Loss: 0.0173
# Epoch [295/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0170
# Epoch [296/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0169
# Epoch [297/1500] Fold 1, Train Loss: 0.0196, Val Loss: 0.0160
# Epoch [298/1500] Fold 1, Train Loss: 0.0202, Val Loss: 0.0160
# Epoch [299/1500] Fold 1, Train Loss: 0.0199, Val Loss: 0.0168
# Epoch [300/1500] Fold 1, Train Loss: 0.0199, Val Loss: 0.0165
# Epoch [301/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0166
# Epoch [302/1500] Fold 1, Train Loss: 0.0188, Val Loss: 0.0165
# Epoch [303/1500] Fold 1, Train Loss: 0.0197, Val Loss: 0.0168
# Epoch [304/1500] Fold 1, Train Loss: 0.0194, Val Loss: 0.0164
# Epoch [305/1500] Fold 1, Train Loss: 0.0193, Val Loss: 0.0167
# Epoch [306/1500] Fold 1, Train Loss: 0.0201, Val Loss: 0.0161
# Epoch [307/1500] Fold 1, Train Loss: 0.0215, Val Loss: 0.0164
# Epoch [308/1500] Fold 1, Train Loss: 0.0196, Val Loss: 0.0178
# Epoch [309/1500] Fold 1, Train Loss: 0.0202, Val Loss: 0.0170
# Epoch [310/1500] Fold 1, Train Loss: 0.0192, Val Loss: 0.0168
# Epoch [311/1500] Fold 1, Train Loss: 0.0202, Val Loss: 0.0173
# Epoch [312/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0172
# Epoch [313/1500] Fold 1, Train Loss: 0.0203, Val Loss: 0.0165
# Epoch [314/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0171
# Epoch [315/1500] Fold 1, Train Loss: 0.0193, Val Loss: 0.0165
# Epoch [316/1500] Fold 1, Train Loss: 0.0201, Val Loss: 0.0164
# Epoch [317/1500] Fold 1, Train Loss: 0.0188, Val Loss: 0.0163
# Epoch [318/1500] Fold 1, Train Loss: 0.0199, Val Loss: 0.0166
# Epoch [319/1500] Fold 1, Train Loss: 0.0205, Val Loss: 0.0158
# Epoch [320/1500] Fold 1, Train Loss: 0.0201, Val Loss: 0.0159
# Epoch [321/1500] Fold 1, Train Loss: 0.0205, Val Loss: 0.0161
# Epoch [322/1500] Fold 1, Train Loss: 0.0201, Val Loss: 0.0165
# Epoch [323/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0163
# Epoch [324/1500] Fold 1, Train Loss: 0.0205, Val Loss: 0.0156
# Epoch [325/1500] Fold 1, Train Loss: 0.0210, Val Loss: 0.0167
# Epoch [326/1500] Fold 1, Train Loss: 0.0198, Val Loss: 0.0168
# Epoch [327/1500] Fold 1, Train Loss: 0.0194, Val Loss: 0.0153
# Epoch [328/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0158
# Epoch [329/1500] Fold 1, Train Loss: 0.0197, Val Loss: 0.0157
# Epoch [330/1500] Fold 1, Train Loss: 0.0194, Val Loss: 0.0163
# Epoch [331/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0165
# Epoch [332/1500] Fold 1, Train Loss: 0.0186, Val Loss: 0.0159
# Epoch [333/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0163
# Epoch [334/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0159
# Epoch [335/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0161
# Epoch [336/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0162
# Epoch [337/1500] Fold 1, Train Loss: 0.0194, Val Loss: 0.0166
# Epoch [338/1500] Fold 1, Train Loss: 0.0209, Val Loss: 0.0156
# Epoch [339/1500] Fold 1, Train Loss: 0.0202, Val Loss: 0.0164
# Epoch [340/1500] Fold 1, Train Loss: 0.0196, Val Loss: 0.0158
# Epoch [341/1500] Fold 1, Train Loss: 0.0194, Val Loss: 0.0162
# Epoch [342/1500] Fold 1, Train Loss: 0.0197, Val Loss: 0.0161
# Epoch [343/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0158
# Epoch [344/1500] Fold 1, Train Loss: 0.0194, Val Loss: 0.0160
# Epoch [345/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0157
# Epoch [346/1500] Fold 1, Train Loss: 0.0186, Val Loss: 0.0156
# Epoch [347/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0154
# Epoch [348/1500] Fold 1, Train Loss: 0.0205, Val Loss: 0.0155
# Epoch [349/1500] Fold 1, Train Loss: 0.0195, Val Loss: 0.0149
# Epoch [350/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0151
# Epoch [351/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0156
# Epoch [352/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0156
# Epoch [353/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0162
# Epoch [354/1500] Fold 1, Train Loss: 0.0188, Val Loss: 0.0153
# Epoch [355/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0156
# Epoch [356/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0156
# Epoch [357/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0149
# Epoch [358/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0161
# Epoch [359/1500] Fold 1, Train Loss: 0.0193, Val Loss: 0.0160
# Epoch [360/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0159
# Epoch [361/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0156
# Epoch [362/1500] Fold 1, Train Loss: 0.0208, Val Loss: 0.0156
# Epoch [363/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0153
# Epoch [364/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0159
# Epoch [365/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0159
# Epoch [366/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0162
# Epoch [367/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0154
# Epoch [368/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0160
# Epoch [369/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0156
# Epoch [370/1500] Fold 1, Train Loss: 0.0193, Val Loss: 0.0156
# Epoch [371/1500] Fold 1, Train Loss: 0.0188, Val Loss: 0.0156
# Epoch [372/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0160
# Epoch [373/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0162
# Epoch [374/1500] Fold 1, Train Loss: 0.0204, Val Loss: 0.0162
# Epoch [375/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0155
# Epoch [376/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0154
# Epoch [377/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0165
# Epoch [378/1500] Fold 1, Train Loss: 0.0196, Val Loss: 0.0153
# Epoch [379/1500] Fold 1, Train Loss: 0.0184, Val Loss: 0.0155
# Epoch [380/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0155
# Epoch [381/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0160
# Epoch [382/1500] Fold 1, Train Loss: 0.0199, Val Loss: 0.0160
# Epoch [383/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0156
# Epoch [384/1500] Fold 1, Train Loss: 0.0192, Val Loss: 0.0155
# Epoch [385/1500] Fold 1, Train Loss: 0.0195, Val Loss: 0.0151
# Epoch [386/1500] Fold 1, Train Loss: 0.0195, Val Loss: 0.0150
# Epoch [387/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0158
# Epoch [388/1500] Fold 1, Train Loss: 0.0203, Val Loss: 0.0152
# Epoch [389/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0154
# Epoch [390/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0150
# Epoch [391/1500] Fold 1, Train Loss: 0.0193, Val Loss: 0.0156
# Epoch [392/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0158
# Epoch [393/1500] Fold 1, Train Loss: 0.0188, Val Loss: 0.0150
# Epoch [394/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0150
# Epoch [395/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0155
# Epoch [396/1500] Fold 1, Train Loss: 0.0195, Val Loss: 0.0150
# Epoch [397/1500] Fold 1, Train Loss: 0.0179, Val Loss: 0.0149
# Epoch [398/1500] Fold 1, Train Loss: 0.0196, Val Loss: 0.0152
# Epoch [399/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0149
# Epoch [400/1500] Fold 1, Train Loss: 0.0202, Val Loss: 0.0155
# Epoch [401/1500] Fold 1, Train Loss: 0.0199, Val Loss: 0.0155
# Epoch [402/1500] Fold 1, Train Loss: 0.0198, Val Loss: 0.0149
# Epoch [403/1500] Fold 1, Train Loss: 0.0199, Val Loss: 0.0156
# Epoch [404/1500] Fold 1, Train Loss: 0.0201, Val Loss: 0.0153
# Epoch [405/1500] Fold 1, Train Loss: 0.0197, Val Loss: 0.0148
# Epoch [406/1500] Fold 1, Train Loss: 0.0192, Val Loss: 0.0152
# Epoch [407/1500] Fold 1, Train Loss: 0.0194, Val Loss: 0.0152
# Epoch [408/1500] Fold 1, Train Loss: 0.0198, Val Loss: 0.0144
# Epoch [409/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0147
# Epoch [410/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0149
# Epoch [411/1500] Fold 1, Train Loss: 0.0180, Val Loss: 0.0155
# Epoch [412/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0152
# Epoch [413/1500] Fold 1, Train Loss: 0.0197, Val Loss: 0.0155
# Epoch [414/1500] Fold 1, Train Loss: 0.0195, Val Loss: 0.0151
# Epoch [415/1500] Fold 1, Train Loss: 0.0193, Val Loss: 0.0159
# Epoch [416/1500] Fold 1, Train Loss: 0.0182, Val Loss: 0.0155
# Epoch [417/1500] Fold 1, Train Loss: 0.0196, Val Loss: 0.0158
# Epoch [418/1500] Fold 1, Train Loss: 0.0184, Val Loss: 0.0154
# Epoch [419/1500] Fold 1, Train Loss: 0.0186, Val Loss: 0.0153
# Epoch [420/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0152
# Epoch [421/1500] Fold 1, Train Loss: 0.0180, Val Loss: 0.0146
# Epoch [422/1500] Fold 1, Train Loss: 0.0196, Val Loss: 0.0151
# Epoch [423/1500] Fold 1, Train Loss: 0.0184, Val Loss: 0.0155
# Epoch [424/1500] Fold 1, Train Loss: 0.0195, Val Loss: 0.0153
# Epoch [425/1500] Fold 1, Train Loss: 0.0188, Val Loss: 0.0154
# Epoch [426/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0146
# Epoch [427/1500] Fold 1, Train Loss: 0.0179, Val Loss: 0.0154
# Epoch [428/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0159
# Epoch [429/1500] Fold 1, Train Loss: 0.0182, Val Loss: 0.0148
# Epoch [430/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0148
# Epoch [431/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0148
# Epoch [432/1500] Fold 1, Train Loss: 0.0182, Val Loss: 0.0149
# Epoch [433/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0159
# Epoch [434/1500] Fold 1, Train Loss: 0.0193, Val Loss: 0.0146
# Epoch [435/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0158
# Epoch [436/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0149
# Epoch [437/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0153
# Epoch [438/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0149
# Epoch [439/1500] Fold 1, Train Loss: 0.0195, Val Loss: 0.0155
# Epoch [440/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0154
# Epoch [441/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0150
# Epoch [442/1500] Fold 1, Train Loss: 0.0194, Val Loss: 0.0146
# Epoch [443/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0148
# Epoch [444/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0148
# Epoch [445/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0151
# Epoch [446/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0151
# Epoch [447/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0150
# Epoch [448/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0145
# Epoch [449/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0151
# Epoch [450/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0147
# Epoch [451/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0150
# Epoch [452/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0149
# Epoch [453/1500] Fold 1, Train Loss: 0.0200, Val Loss: 0.0152
# Epoch [454/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0156
# Epoch [455/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0147
# Epoch [456/1500] Fold 1, Train Loss: 0.0180, Val Loss: 0.0148
# Epoch [457/1500] Fold 1, Train Loss: 0.0199, Val Loss: 0.0149
# Epoch [458/1500] Fold 1, Train Loss: 0.0186, Val Loss: 0.0147
# Epoch [459/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0151
# Epoch [460/1500] Fold 1, Train Loss: 0.0182, Val Loss: 0.0154
# Epoch [461/1500] Fold 1, Train Loss: 0.0192, Val Loss: 0.0153
# Epoch [462/1500] Fold 1, Train Loss: 0.0188, Val Loss: 0.0154
# Epoch [463/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0152
# Epoch [464/1500] Fold 1, Train Loss: 0.0179, Val Loss: 0.0156
# Epoch [465/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0156
# Epoch [466/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0153
# Epoch [467/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0155
# Epoch [468/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0149
# Epoch [469/1500] Fold 1, Train Loss: 0.0186, Val Loss: 0.0155
# Epoch [470/1500] Fold 1, Train Loss: 0.0192, Val Loss: 0.0163
# Epoch [471/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0160
# Epoch [472/1500] Fold 1, Train Loss: 0.0200, Val Loss: 0.0150
# Epoch [473/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0155
# Epoch [474/1500] Fold 1, Train Loss: 0.0180, Val Loss: 0.0147
# Epoch [475/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0150
# Epoch [476/1500] Fold 1, Train Loss: 0.0198, Val Loss: 0.0158
# Epoch [477/1500] Fold 1, Train Loss: 0.0188, Val Loss: 0.0162
# Epoch [478/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0161
# Epoch [479/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0159
# Epoch [480/1500] Fold 1, Train Loss: 0.0172, Val Loss: 0.0159
# Epoch [481/1500] Fold 1, Train Loss: 0.0202, Val Loss: 0.0156
# Epoch [482/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0156
# Epoch [483/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0157
# Epoch [484/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0148
# Epoch [485/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0154
# Epoch [486/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0159
# Epoch [487/1500] Fold 1, Train Loss: 0.0180, Val Loss: 0.0156
# Epoch [488/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0164
# Epoch [489/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0151
# Epoch [490/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0158
# Epoch [491/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0164
# Epoch [492/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0162
# Epoch [493/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0154
# Epoch [494/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0155
# Epoch [495/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0153
# Epoch [496/1500] Fold 1, Train Loss: 0.0195, Val Loss: 0.0151
# Epoch [497/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0151
# Epoch [498/1500] Fold 1, Train Loss: 0.0184, Val Loss: 0.0151
# Epoch [499/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0155
# Epoch [500/1500] Fold 1, Train Loss: 0.0195, Val Loss: 0.0157
# Epoch [501/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0157
# Epoch [502/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0148
# Epoch [503/1500] Fold 1, Train Loss: 0.0179, Val Loss: 0.0150
# Epoch [504/1500] Fold 1, Train Loss: 0.0184, Val Loss: 0.0150
# Epoch [505/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0149
# Epoch [506/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0148
# Epoch [507/1500] Fold 1, Train Loss: 0.0182, Val Loss: 0.0150
# Epoch [508/1500] Fold 1, Train Loss: 0.0180, Val Loss: 0.0160
# Epoch [509/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0158
# Epoch [510/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0157
# Epoch [511/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0161
# Epoch [512/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0158
# Epoch [513/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0154
# Epoch [514/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0154
# Epoch [515/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0154
# Epoch [516/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0151
# Epoch [517/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0153
# Epoch [518/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0156
# Epoch [519/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0153
# Epoch [520/1500] Fold 1, Train Loss: 0.0184, Val Loss: 0.0155
# Epoch [521/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0156
# Epoch [522/1500] Fold 1, Train Loss: 0.0180, Val Loss: 0.0153
# Epoch [523/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0155
# Epoch [524/1500] Fold 1, Train Loss: 0.0184, Val Loss: 0.0153
# Epoch [525/1500] Fold 1, Train Loss: 0.0172, Val Loss: 0.0155
# Epoch [526/1500] Fold 1, Train Loss: 0.0195, Val Loss: 0.0158
# Epoch [527/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0155
# Epoch [528/1500] Fold 1, Train Loss: 0.0182, Val Loss: 0.0155
# Epoch [529/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0152
# Epoch [530/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0153
# Epoch [531/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0155
# Epoch [532/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0154
# Epoch [533/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0149
# Epoch [534/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0159
# Epoch [535/1500] Fold 1, Train Loss: 0.0164, Val Loss: 0.0152
# Epoch [536/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0150
# Epoch [537/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0157
# Epoch [538/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0157
# Epoch [539/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0148
# Epoch [540/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0150
# Epoch [541/1500] Fold 1, Train Loss: 0.0195, Val Loss: 0.0149
# Epoch [542/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0146
# Epoch [543/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0156
# Epoch [544/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0157
# Epoch [545/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0156
# Epoch [546/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0150
# Epoch [547/1500] Fold 1, Train Loss: 0.0180, Val Loss: 0.0150
# Epoch [548/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0152
# Epoch [549/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0158
# Epoch [550/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0155
# Epoch [551/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0149
# Epoch [552/1500] Fold 1, Train Loss: 0.0165, Val Loss: 0.0153
# Epoch [553/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0147
# Epoch [554/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0150
# Epoch [555/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0155
# Epoch [556/1500] Fold 1, Train Loss: 0.0168, Val Loss: 0.0153
# Epoch [557/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0149
# Epoch [558/1500] Fold 1, Train Loss: 0.0168, Val Loss: 0.0149
# Epoch [559/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0153
# Epoch [560/1500] Fold 1, Train Loss: 0.0196, Val Loss: 0.0151
# Epoch [561/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0146
# Epoch [562/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0150
# Epoch [563/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0160
# Epoch [564/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0156
# Epoch [565/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0161
# Epoch [566/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0158
# Epoch [567/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0161
# Epoch [568/1500] Fold 1, Train Loss: 0.0182, Val Loss: 0.0157
# Epoch [569/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0165
# Epoch [570/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0153
# Epoch [571/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0149
# Epoch [572/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0160
# Epoch [573/1500] Fold 1, Train Loss: 0.0180, Val Loss: 0.0157
# Epoch [574/1500] Fold 1, Train Loss: 0.0188, Val Loss: 0.0154
# Epoch [575/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0155
# Epoch [576/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0162
# Epoch [577/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0154
# Epoch [578/1500] Fold 1, Train Loss: 0.0180, Val Loss: 0.0153
# Epoch [579/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0150
# Epoch [580/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0149
# Epoch [581/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0146
# Epoch [582/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0144
# Epoch [583/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0149
# Epoch [584/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0145
# Epoch [585/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0146
# Epoch [586/1500] Fold 1, Train Loss: 0.0182, Val Loss: 0.0153
# Epoch [587/1500] Fold 1, Train Loss: 0.0183, Val Loss: 0.0144
# Epoch [588/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0152
# Epoch [589/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0143
# Epoch [590/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0145
# Epoch [591/1500] Fold 1, Train Loss: 0.0163, Val Loss: 0.0148
# Epoch [592/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0148
# Epoch [593/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0147
# Epoch [594/1500] Fold 1, Train Loss: 0.0172, Val Loss: 0.0144
# Epoch [595/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0155
# Epoch [596/1500] Fold 1, Train Loss: 0.0205, Val Loss: 0.0157
# Epoch [597/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0162
# Epoch [598/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0153
# Epoch [599/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0152
# Epoch [600/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0150
# Epoch [601/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0147
# Epoch [602/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0146
# Epoch [603/1500] Fold 1, Train Loss: 0.0182, Val Loss: 0.0148
# Epoch [604/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0145
# Epoch [605/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0153
# Epoch [606/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0151
# Epoch [607/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0149
# Epoch [608/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0155
# Epoch [609/1500] Fold 1, Train Loss: 0.0182, Val Loss: 0.0153
# Epoch [610/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0147
# Epoch [611/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0152
# Epoch [612/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0151
# Epoch [613/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0150
# Epoch [614/1500] Fold 1, Train Loss: 0.0184, Val Loss: 0.0148
# Epoch [615/1500] Fold 1, Train Loss: 0.0182, Val Loss: 0.0155
# Epoch [616/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0152
# Epoch [617/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0146
# Epoch [618/1500] Fold 1, Train Loss: 0.0164, Val Loss: 0.0146
# Epoch [619/1500] Fold 1, Train Loss: 0.0196, Val Loss: 0.0146
# Epoch [620/1500] Fold 1, Train Loss: 0.0190, Val Loss: 0.0145
# Epoch [621/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0149
# Epoch [622/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0154
# Epoch [623/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0151
# Epoch [624/1500] Fold 1, Train Loss: 0.0179, Val Loss: 0.0152
# Epoch [625/1500] Fold 1, Train Loss: 0.0166, Val Loss: 0.0157
# Epoch [626/1500] Fold 1, Train Loss: 0.0158, Val Loss: 0.0154
# Epoch [627/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0152
# Epoch [628/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0146
# Epoch [629/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0157
# Epoch [630/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0159
# Epoch [631/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0156
# Epoch [632/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0151
# Epoch [633/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0157
# Epoch [634/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0156
# Epoch [635/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0156
# Epoch [636/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0164
# Epoch [637/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0163
# Epoch [638/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0155
# Epoch [639/1500] Fold 1, Train Loss: 0.0161, Val Loss: 0.0151
# Epoch [640/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0157
# Epoch [641/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0162
# Epoch [642/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0158
# Epoch [643/1500] Fold 1, Train Loss: 0.0188, Val Loss: 0.0151
# Epoch [644/1500] Fold 1, Train Loss: 0.0160, Val Loss: 0.0154
# Epoch [645/1500] Fold 1, Train Loss: 0.0189, Val Loss: 0.0152
# Epoch [646/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0150
# Epoch [647/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0146
# Epoch [648/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0149
# Epoch [649/1500] Fold 1, Train Loss: 0.0168, Val Loss: 0.0149
# Epoch [650/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0157
# Epoch [651/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0156
# Epoch [652/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0160
# Epoch [653/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0151
# Epoch [654/1500] Fold 1, Train Loss: 0.0186, Val Loss: 0.0154
# Epoch [655/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0154
# Epoch [656/1500] Fold 1, Train Loss: 0.0166, Val Loss: 0.0162
# Epoch [657/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0148
# Epoch [658/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0148
# Epoch [659/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0155
# Epoch [660/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0155
# Epoch [661/1500] Fold 1, Train Loss: 0.0188, Val Loss: 0.0148
# Epoch [662/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0150
# Epoch [663/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0154
# Epoch [664/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0147
# Epoch [665/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0149
# Epoch [666/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0152
# Epoch [667/1500] Fold 1, Train Loss: 0.0166, Val Loss: 0.0153
# Epoch [668/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0147
# Epoch [669/1500] Fold 1, Train Loss: 0.0168, Val Loss: 0.0151
# Epoch [670/1500] Fold 1, Train Loss: 0.0185, Val Loss: 0.0155
# Epoch [671/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0148
# Epoch [672/1500] Fold 1, Train Loss: 0.0186, Val Loss: 0.0144
# Epoch [673/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0148
# Epoch [674/1500] Fold 1, Train Loss: 0.0168, Val Loss: 0.0142
# Epoch [675/1500] Fold 1, Train Loss: 0.0165, Val Loss: 0.0150
# Epoch [676/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0147
# Epoch [677/1500] Fold 1, Train Loss: 0.0179, Val Loss: 0.0150
# Epoch [678/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0153
# Epoch [679/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0153
# Epoch [680/1500] Fold 1, Train Loss: 0.0191, Val Loss: 0.0150
# Epoch [681/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0144
# Epoch [682/1500] Fold 1, Train Loss: 0.0164, Val Loss: 0.0145
# Epoch [683/1500] Fold 1, Train Loss: 0.0156, Val Loss: 0.0149
# Epoch [684/1500] Fold 1, Train Loss: 0.0160, Val Loss: 0.0146
# Epoch [685/1500] Fold 1, Train Loss: 0.0186, Val Loss: 0.0148
# Epoch [686/1500] Fold 1, Train Loss: 0.0181, Val Loss: 0.0147
# Epoch [687/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0153
# Epoch [688/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0145
# Epoch [689/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0149
# Epoch [690/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0155
# Epoch [691/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0159
# Epoch [692/1500] Fold 1, Train Loss: 0.0163, Val Loss: 0.0152
# Epoch [693/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0145
# Epoch [694/1500] Fold 1, Train Loss: 0.0172, Val Loss: 0.0144
# Epoch [695/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0167
# Epoch [696/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0155
# Epoch [697/1500] Fold 1, Train Loss: 0.0171, Val Loss: 0.0151
# Epoch [698/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0157
# Epoch [699/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0147
# Epoch [700/1500] Fold 1, Train Loss: 0.0166, Val Loss: 0.0150
# Epoch [701/1500] Fold 1, Train Loss: 0.0177, Val Loss: 0.0161
# Epoch [702/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0152
# Epoch [703/1500] Fold 1, Train Loss: 0.0166, Val Loss: 0.0143
# Epoch [704/1500] Fold 1, Train Loss: 0.0162, Val Loss: 0.0144
# Epoch [705/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0149
# Epoch [706/1500] Fold 1, Train Loss: 0.0160, Val Loss: 0.0150
# Epoch [707/1500] Fold 1, Train Loss: 0.0160, Val Loss: 0.0149
# Epoch [708/1500] Fold 1, Train Loss: 0.0164, Val Loss: 0.0147
# Epoch [709/1500] Fold 1, Train Loss: 0.0188, Val Loss: 0.0146
# Epoch [710/1500] Fold 1, Train Loss: 0.0186, Val Loss: 0.0147
# Epoch [711/1500] Fold 1, Train Loss: 0.0178, Val Loss: 0.0143
# Epoch [712/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0143
# Epoch [713/1500] Fold 1, Train Loss: 0.0184, Val Loss: 0.0148
# Epoch [714/1500] Fold 1, Train Loss: 0.0168, Val Loss: 0.0141
# Epoch [715/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0147
# Epoch [716/1500] Fold 1, Train Loss: 0.0156, Val Loss: 0.0149
# Epoch [717/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0151
# Epoch [718/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0148
# Epoch [719/1500] Fold 1, Train Loss: 0.0176, Val Loss: 0.0147
# Epoch [720/1500] Fold 1, Train Loss: 0.0201, Val Loss: 0.0146
# Epoch [721/1500] Fold 1, Train Loss: 0.0172, Val Loss: 0.0142
# Epoch [722/1500] Fold 1, Train Loss: 0.0172, Val Loss: 0.0146
# Epoch [723/1500] Fold 1, Train Loss: 0.0165, Val Loss: 0.0150
# Epoch [724/1500] Fold 1, Train Loss: 0.0166, Val Loss: 0.0149
# Epoch [725/1500] Fold 1, Train Loss: 0.0161, Val Loss: 0.0146
# Epoch [726/1500] Fold 1, Train Loss: 0.0166, Val Loss: 0.0146
# Epoch [727/1500] Fold 1, Train Loss: 0.0165, Val Loss: 0.0154
# Epoch [728/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0149
# Epoch [729/1500] Fold 1, Train Loss: 0.0164, Val Loss: 0.0151
# Epoch [730/1500] Fold 1, Train Loss: 0.0153, Val Loss: 0.0143
# Epoch [731/1500] Fold 1, Train Loss: 0.0162, Val Loss: 0.0142
# Epoch [732/1500] Fold 1, Train Loss: 0.0165, Val Loss: 0.0149
# Epoch [733/1500] Fold 1, Train Loss: 0.0168, Val Loss: 0.0146
# Epoch [734/1500] Fold 1, Train Loss: 0.0163, Val Loss: 0.0147
# Epoch [735/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0145
# Epoch [736/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0151
# Epoch [737/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0154
# Epoch [738/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0150
# Epoch [739/1500] Fold 1, Train Loss: 0.0168, Val Loss: 0.0145
# Epoch [740/1500] Fold 1, Train Loss: 0.0168, Val Loss: 0.0147
# Epoch [741/1500] Fold 1, Train Loss: 0.0160, Val Loss: 0.0147
# Epoch [742/1500] Fold 1, Train Loss: 0.0180, Val Loss: 0.0152
# Epoch [743/1500] Fold 1, Train Loss: 0.0158, Val Loss: 0.0148
# Epoch [744/1500] Fold 1, Train Loss: 0.0163, Val Loss: 0.0146
# Epoch [745/1500] Fold 1, Train Loss: 0.0158, Val Loss: 0.0146
# Epoch [746/1500] Fold 1, Train Loss: 0.0163, Val Loss: 0.0149
# Epoch [747/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0147
# Epoch [748/1500] Fold 1, Train Loss: 0.0159, Val Loss: 0.0145
# Epoch [749/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0147
# Epoch [750/1500] Fold 1, Train Loss: 0.0158, Val Loss: 0.0145
# Epoch [751/1500] Fold 1, Train Loss: 0.0184, Val Loss: 0.0156
# Epoch [752/1500] Fold 1, Train Loss: 0.0175, Val Loss: 0.0152
# Epoch [753/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0148
# Epoch [754/1500] Fold 1, Train Loss: 0.0158, Val Loss: 0.0146
# Epoch [755/1500] Fold 1, Train Loss: 0.0165, Val Loss: 0.0145
# Epoch [756/1500] Fold 1, Train Loss: 0.0161, Val Loss: 0.0155
# Epoch [757/1500] Fold 1, Train Loss: 0.0166, Val Loss: 0.0152
# Epoch [758/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0148
# Epoch [759/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0149
# Epoch [760/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0142
# Epoch [761/1500] Fold 1, Train Loss: 0.0162, Val Loss: 0.0147
# Epoch [762/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0144
# Epoch [763/1500] Fold 1, Train Loss: 0.0169, Val Loss: 0.0150
# Epoch [764/1500] Fold 1, Train Loss: 0.0168, Val Loss: 0.0148
# Epoch [765/1500] Fold 1, Train Loss: 0.0167, Val Loss: 0.0159
# Epoch [766/1500] Fold 1, Train Loss: 0.0155, Val Loss: 0.0150
# Epoch [767/1500] Fold 1, Train Loss: 0.0173, Val Loss: 0.0153
# Epoch [768/1500] Fold 1, Train Loss: 0.0187, Val Loss: 0.0147
# Epoch [769/1500] Fold 1, Train Loss: 0.0174, Val Loss: 0.0149
# Epoch [770/1500] Fold 1, Train Loss: 0.0172, Val Loss: 0.0141
# Epoch [771/1500] Fold 1, Train Loss: 0.0163, Val Loss: 0.0146
# Epoch [772/1500] Fold 1, Train Loss: 0.0165, Val Loss: 0.0145
# Epoch [773/1500] Fold 1, Train Loss: 0.0158, Val Loss: 0.0146
# Epoch [774/1500] Fold 1, Train Loss: 0.0170, Val Loss: 0.0143
# Epoch [775/1500] Fold 1, Train Loss: 0.0164, Val Loss: 0.0142
# ...
# Epoch [647/1500] Fold 10, Train Loss: 0.0162, Val Loss: 0.0181
# Epoch [648/1500] Fold 10, Train Loss: 0.0167, Val Loss: 0.0183
# Epoch [649/1500] Fold 10, Train Loss: 0.0156, Val Loss: 0.0183
# Epoch [650/1500] Fold 10, Train Loss: 0.0171, Val Loss: 0.0182
# Epoch [651/1500] Fold 10, Train Loss: 0.0161, Val Loss: 0.0183
# Epoch [652/1500] Fold 10, Train Loss: 0.0176, Val Loss: 0.0182
# Epoch [653/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0178
# Epoch [654/1500] Fold 10, Train Loss: 0.0160, Val Loss: 0.0180
# Epoch [655/1500] Fold 10, Train Loss: 0.0163, Val Loss: 0.0180
# Epoch [656/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0178
# Epoch [657/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0180
# Epoch [658/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0181
# Epoch [659/1500] Fold 10, Train Loss: 0.0166, Val Loss: 0.0181
# Epoch [660/1500] Fold 10, Train Loss: 0.0161, Val Loss: 0.0182
# Epoch [661/1500] Fold 10, Train Loss: 0.0162, Val Loss: 0.0184
# Epoch [662/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0184
# Epoch [663/1500] Fold 10, Train Loss: 0.0167, Val Loss: 0.0186
# Epoch [664/1500] Fold 10, Train Loss: 0.0166, Val Loss: 0.0184
# Epoch [665/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0185
# Epoch [666/1500] Fold 10, Train Loss: 0.0169, Val Loss: 0.0179
# Epoch [667/1500] Fold 10, Train Loss: 0.0160, Val Loss: 0.0180
# Epoch [668/1500] Fold 10, Train Loss: 0.0163, Val Loss: 0.0186
# Epoch [669/1500] Fold 10, Train Loss: 0.0170, Val Loss: 0.0180
# Epoch [670/1500] Fold 10, Train Loss: 0.0156, Val Loss: 0.0182
# Epoch [671/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0187
# Epoch [672/1500] Fold 10, Train Loss: 0.0157, Val Loss: 0.0183
# Epoch [673/1500] Fold 10, Train Loss: 0.0174, Val Loss: 0.0181
# Epoch [674/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0184
# Epoch [675/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0184
# Epoch [676/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0180
# Epoch [677/1500] Fold 10, Train Loss: 0.0168, Val Loss: 0.0180
# Epoch [678/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0177
# Epoch [679/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0181
# Epoch [680/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0183
# Epoch [681/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0179
# Epoch [682/1500] Fold 10, Train Loss: 0.0173, Val Loss: 0.0184
# Epoch [683/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0179
# Epoch [684/1500] Fold 10, Train Loss: 0.0160, Val Loss: 0.0182
# Epoch [685/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0183
# Epoch [686/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0183
# Epoch [687/1500] Fold 10, Train Loss: 0.0163, Val Loss: 0.0184
# Epoch [688/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0182
# Epoch [689/1500] Fold 10, Train Loss: 0.0157, Val Loss: 0.0186
# Epoch [690/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0187
# Epoch [691/1500] Fold 10, Train Loss: 0.0161, Val Loss: 0.0183
# Epoch [692/1500] Fold 10, Train Loss: 0.0167, Val Loss: 0.0186
# Epoch [693/1500] Fold 10, Train Loss: 0.0160, Val Loss: 0.0185
# Epoch [694/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0185
# Epoch [695/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0184
# Epoch [696/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0175
# Epoch [697/1500] Fold 10, Train Loss: 0.0157, Val Loss: 0.0179
# Epoch [698/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0176
# Epoch [699/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0181
# Epoch [700/1500] Fold 10, Train Loss: 0.0178, Val Loss: 0.0184
# Epoch [701/1500] Fold 10, Train Loss: 0.0161, Val Loss: 0.0181
# Epoch [702/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0184
# Epoch [703/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0183
# Epoch [704/1500] Fold 10, Train Loss: 0.0160, Val Loss: 0.0184
# Epoch [705/1500] Fold 10, Train Loss: 0.0156, Val Loss: 0.0181
# Epoch [706/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0186
# Epoch [707/1500] Fold 10, Train Loss: 0.0168, Val Loss: 0.0188
# Epoch [708/1500] Fold 10, Train Loss: 0.0162, Val Loss: 0.0187
# Epoch [709/1500] Fold 10, Train Loss: 0.0160, Val Loss: 0.0178
# Epoch [710/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0182
# Epoch [711/1500] Fold 10, Train Loss: 0.0164, Val Loss: 0.0180
# Epoch [712/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0183
# Epoch [713/1500] Fold 10, Train Loss: 0.0163, Val Loss: 0.0181
# Epoch [714/1500] Fold 10, Train Loss: 0.0157, Val Loss: 0.0180
# Epoch [715/1500] Fold 10, Train Loss: 0.0161, Val Loss: 0.0185
# Epoch [716/1500] Fold 10, Train Loss: 0.0160, Val Loss: 0.0185
# Epoch [717/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0186
# Epoch [718/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0184
# Epoch [719/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0186
# Epoch [720/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0184
# Epoch [721/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0185
# Epoch [722/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0185
# Epoch [723/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0184
# Epoch [724/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0180
# Epoch [725/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0182
# Epoch [726/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0178
# Epoch [727/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0181
# Epoch [728/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0181
# Epoch [729/1500] Fold 10, Train Loss: 0.0175, Val Loss: 0.0181
# Epoch [730/1500] Fold 10, Train Loss: 0.0156, Val Loss: 0.0181
# Epoch [731/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0185
# Epoch [732/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0183
# Epoch [733/1500] Fold 10, Train Loss: 0.0157, Val Loss: 0.0187
# Epoch [734/1500] Fold 10, Train Loss: 0.0157, Val Loss: 0.0183
# Epoch [735/1500] Fold 10, Train Loss: 0.0156, Val Loss: 0.0186
# Epoch [736/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0183
# Epoch [737/1500] Fold 10, Train Loss: 0.0156, Val Loss: 0.0186
# Epoch [738/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0183
# Epoch [739/1500] Fold 10, Train Loss: 0.0161, Val Loss: 0.0181
# Epoch [740/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0184
# Epoch [741/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0184
# Epoch [742/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0182
# Epoch [743/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0184
# Epoch [744/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0184
# Epoch [745/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0182
# Epoch [746/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0182
# Epoch [747/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0183
# Epoch [748/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0183
# Epoch [749/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0184
# Epoch [750/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0187
# Epoch [751/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0181
# Epoch [752/1500] Fold 10, Train Loss: 0.0162, Val Loss: 0.0180
# Epoch [753/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0177
# Epoch [754/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0179
# Epoch [755/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0180
# Epoch [756/1500] Fold 10, Train Loss: 0.0156, Val Loss: 0.0182
# Epoch [757/1500] Fold 10, Train Loss: 0.0163, Val Loss: 0.0182
# Epoch [758/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0177
# Epoch [759/1500] Fold 10, Train Loss: 0.0160, Val Loss: 0.0182
# Epoch [760/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0180
# Epoch [761/1500] Fold 10, Train Loss: 0.0161, Val Loss: 0.0178
# Epoch [762/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0181
# Epoch [763/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0185
# Epoch [764/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0182
# Epoch [765/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0182
# Epoch [766/1500] Fold 10, Train Loss: 0.0160, Val Loss: 0.0180
# Epoch [767/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0181
# Epoch [768/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0183
# Epoch [769/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0181
# Epoch [770/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0181
# Epoch [771/1500] Fold 10, Train Loss: 0.0157, Val Loss: 0.0181
# Epoch [772/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0181
# Epoch [773/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0182
# Epoch [774/1500] Fold 10, Train Loss: 0.0157, Val Loss: 0.0180
# Epoch [775/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0187
# Epoch [776/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0184
# Epoch [777/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0185
# Epoch [778/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0183
# Epoch [779/1500] Fold 10, Train Loss: 0.0174, Val Loss: 0.0185
# Epoch [780/1500] Fold 10, Train Loss: 0.0159, Val Loss: 0.0187
# Epoch [781/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0183
# Epoch [782/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0191
# Epoch [783/1500] Fold 10, Train Loss: 0.0160, Val Loss: 0.0187
# Epoch [784/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0187
# Epoch [785/1500] Fold 10, Train Loss: 0.0167, Val Loss: 0.0188
# Epoch [786/1500] Fold 10, Train Loss: 0.0168, Val Loss: 0.0186
# Epoch [787/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0183
# Epoch [788/1500] Fold 10, Train Loss: 0.0156, Val Loss: 0.0185
# Epoch [789/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0189
# Epoch [790/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0186
# Epoch [791/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0184
# Epoch [792/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0183
# Epoch [793/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0184
# Epoch [794/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0190
# Epoch [795/1500] Fold 10, Train Loss: 0.0159, Val Loss: 0.0188
# Epoch [796/1500] Fold 10, Train Loss: 0.0162, Val Loss: 0.0184
# Epoch [797/1500] Fold 10, Train Loss: 0.0142, Val Loss: 0.0187
# Epoch [798/1500] Fold 10, Train Loss: 0.0157, Val Loss: 0.0187
# Epoch [799/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0188
# Epoch [800/1500] Fold 10, Train Loss: 0.0144, Val Loss: 0.0186
# Epoch [801/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0186
# Epoch [802/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0185
# Epoch [803/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0184
# Epoch [804/1500] Fold 10, Train Loss: 0.0164, Val Loss: 0.0186
# Epoch [805/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0183
# Epoch [806/1500] Fold 10, Train Loss: 0.0147, Val Loss: 0.0187
# Epoch [807/1500] Fold 10, Train Loss: 0.0156, Val Loss: 0.0187
# Epoch [808/1500] Fold 10, Train Loss: 0.0147, Val Loss: 0.0186
# Epoch [809/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0185
# Epoch [810/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0186
# Epoch [811/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0191
# Epoch [812/1500] Fold 10, Train Loss: 0.0159, Val Loss: 0.0188
# Epoch [813/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0188
# Epoch [814/1500] Fold 10, Train Loss: 0.0163, Val Loss: 0.0183
# Epoch [815/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0181
# Epoch [816/1500] Fold 10, Train Loss: 0.0171, Val Loss: 0.0187
# Epoch [817/1500] Fold 10, Train Loss: 0.0163, Val Loss: 0.0190
# Epoch [818/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0187
# Epoch [819/1500] Fold 10, Train Loss: 0.0148, Val Loss: 0.0186
# Epoch [820/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0186
# Epoch [821/1500] Fold 10, Train Loss: 0.0148, Val Loss: 0.0183
# Epoch [822/1500] Fold 10, Train Loss: 0.0145, Val Loss: 0.0189
# Epoch [823/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0183
# Epoch [824/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0183
# Epoch [825/1500] Fold 10, Train Loss: 0.0156, Val Loss: 0.0187
# Epoch [826/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0187
# Epoch [827/1500] Fold 10, Train Loss: 0.0161, Val Loss: 0.0186
# Epoch [828/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0185
# Epoch [829/1500] Fold 10, Train Loss: 0.0148, Val Loss: 0.0186
# Epoch [830/1500] Fold 10, Train Loss: 0.0146, Val Loss: 0.0181
# Epoch [831/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0191
# Epoch [832/1500] Fold 10, Train Loss: 0.0159, Val Loss: 0.0194
# Epoch [833/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0191
# Epoch [834/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0189
# Epoch [835/1500] Fold 10, Train Loss: 0.0165, Val Loss: 0.0194
# Epoch [836/1500] Fold 10, Train Loss: 0.0160, Val Loss: 0.0197
# Epoch [837/1500] Fold 10, Train Loss: 0.0157, Val Loss: 0.0188
# Epoch [838/1500] Fold 10, Train Loss: 0.0157, Val Loss: 0.0184
# Epoch [839/1500] Fold 10, Train Loss: 0.0175, Val Loss: 0.0182
# Epoch [840/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0185
# Epoch [841/1500] Fold 10, Train Loss: 0.0147, Val Loss: 0.0189
# Epoch [842/1500] Fold 10, Train Loss: 0.0161, Val Loss: 0.0185
# Epoch [843/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0188
# Epoch [844/1500] Fold 10, Train Loss: 0.0163, Val Loss: 0.0187
# Epoch [845/1500] Fold 10, Train Loss: 0.0169, Val Loss: 0.0194
# Epoch [846/1500] Fold 10, Train Loss: 0.0163, Val Loss: 0.0188
# Epoch [847/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0184
# Epoch [848/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0188
# Epoch [849/1500] Fold 10, Train Loss: 0.0159, Val Loss: 0.0184
# Epoch [850/1500] Fold 10, Train Loss: 0.0161, Val Loss: 0.0187
# Epoch [851/1500] Fold 10, Train Loss: 0.0163, Val Loss: 0.0184
# Epoch [852/1500] Fold 10, Train Loss: 0.0170, Val Loss: 0.0185
# Epoch [853/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0184
# Epoch [854/1500] Fold 10, Train Loss: 0.0159, Val Loss: 0.0186
# Epoch [855/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0188
# Epoch [856/1500] Fold 10, Train Loss: 0.0167, Val Loss: 0.0188
# Epoch [857/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0187
# Epoch [858/1500] Fold 10, Train Loss: 0.0144, Val Loss: 0.0184
# Epoch [859/1500] Fold 10, Train Loss: 0.0165, Val Loss: 0.0184
# Epoch [860/1500] Fold 10, Train Loss: 0.0146, Val Loss: 0.0183
# Epoch [861/1500] Fold 10, Train Loss: 0.0161, Val Loss: 0.0182
# Epoch [862/1500] Fold 10, Train Loss: 0.0159, Val Loss: 0.0185
# Epoch [863/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0185
# Epoch [864/1500] Fold 10, Train Loss: 0.0146, Val Loss: 0.0186
# Epoch [865/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0184
# Epoch [866/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0186
# Epoch [867/1500] Fold 10, Train Loss: 0.0146, Val Loss: 0.0186
# Epoch [868/1500] Fold 10, Train Loss: 0.0146, Val Loss: 0.0181
# Epoch [869/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0180
# Epoch [870/1500] Fold 10, Train Loss: 0.0147, Val Loss: 0.0183
# Epoch [871/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0187
# Epoch [872/1500] Fold 10, Train Loss: 0.0170, Val Loss: 0.0187
# Epoch [873/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0185
# Epoch [874/1500] Fold 10, Train Loss: 0.0165, Val Loss: 0.0187
# Epoch [875/1500] Fold 10, Train Loss: 0.0159, Val Loss: 0.0187
# Epoch [876/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0186
# Epoch [877/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0186
# Epoch [878/1500] Fold 10, Train Loss: 0.0162, Val Loss: 0.0182
# Epoch [879/1500] Fold 10, Train Loss: 0.0148, Val Loss: 0.0188
# Epoch [880/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0190
# Epoch [881/1500] Fold 10, Train Loss: 0.0151, Val Loss: 0.0190
# Epoch [882/1500] Fold 10, Train Loss: 0.0159, Val Loss: 0.0188
# Epoch [883/1500] Fold 10, Train Loss: 0.0158, Val Loss: 0.0190
# Epoch [884/1500] Fold 10, Train Loss: 0.0163, Val Loss: 0.0194
# Epoch [885/1500] Fold 10, Train Loss: 0.0152, Val Loss: 0.0189
# Epoch [886/1500] Fold 10, Train Loss: 0.0163, Val Loss: 0.0190
# Epoch [887/1500] Fold 10, Train Loss: 0.0167, Val Loss: 0.0187
# Epoch [888/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0187
# Epoch [889/1500] Fold 10, Train Loss: 0.0150, Val Loss: 0.0183
# Epoch [890/1500] Fold 10, Train Loss: 0.0154, Val Loss: 0.0180
# Epoch [891/1500] Fold 10, Train Loss: 0.0147, Val Loss: 0.0186
# Epoch [892/1500] Fold 10, Train Loss: 0.0148, Val Loss: 0.0183
# Epoch [893/1500] Fold 10, Train Loss: 0.0144, Val Loss: 0.0189
# Epoch [894/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0187
# Epoch [895/1500] Fold 10, Train Loss: 0.0155, Val Loss: 0.0188
# Epoch [896/1500] Fold 10, Train Loss: 0.0144, Val Loss: 0.0183
# Epoch [897/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0179
# Epoch [898/1500] Fold 10, Train Loss: 0.0149, Val Loss: 0.0181
# Epoch [899/1500] Fold 10, Train Loss: 0.0153, Val Loss: 0.0186
# Early stopping at epoch 899 for fold 10

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.0180

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.0134
#   Corresponding Training Loss = 0.0167
#   Best Epoch = 928
# Fold 2:
#   Best Validation Loss = 0.0206
#   Corresponding Training Loss = 0.0178
#   Best Epoch = 501
# Fold 3:
#   Best Validation Loss = 0.0174
#   Corresponding Training Loss = 0.0192
#   Best Epoch = 538
# Fold 4:
#   Best Validation Loss = 0.0151
#   Corresponding Training Loss = 0.0169
#   Best Epoch = 762
# Fold 5:
#   Best Validation Loss = 0.0140
#   Corresponding Training Loss = 0.0191
#   Best Epoch = 355
# Fold 6:
#   Best Validation Loss = 0.0129
#   Corresponding Training Loss = 0.0161
#   Best Epoch = 1042
# Fold 7:
#   Best Validation Loss = 0.0193
#   Corresponding Training Loss = 0.0163
#   Best Epoch = 583
# Fold 8:
#   Best Validation Loss = 0.0168
#   Corresponding Training Loss = 0.0148
#   Best Epoch = 777
# Fold 9:
#   Best Validation Loss = 0.0184
#   Corresponding Training Loss = 0.0168
#   Best Epoch = 527
# Fold 10:
#   Best Validation Loss = 0.0169
#   Corresponding Training Loss = 0.0179
#   Best Epoch = 399

# %%
def plot_loss_curves_separately(cv_histories):
    """
    Plot training and validation loss curves for each fold in separate figures.
    
    Args:
        cv_histories (list): List of loss histories for each fold.
    """
    # Plot Training Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['train_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
    plt.title('Training Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['val_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
    plt.title('Validation Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_loss_curves_separately(cv_histories)

# %%
import torch
import numpy as np

# Track the best validation loss across all folds
lowest_val_loss = float('inf')
best_model_idx = -1  # Index of the best model
best_model_state = None

# Find the fold with the lowest validation loss
for fold_idx, history in enumerate(cv_histories):
    # Get the best validation loss for this fold
    best_val_loss = min(history['val_loss'])
    
    # Check if this is the lowest validation loss across all folds
    if best_val_loss < lowest_val_loss:
        lowest_val_loss = best_val_loss
        best_model_idx = fold_idx
        best_model_state = best_models[fold_idx]

# Save the model with the lowest validation loss
if best_model_state is not None:
    save_path = f'bestmodel_ex_{best_model_idx + 1}.pth'
    torch.save(best_model_state, save_path)
    print(f"Model from fold {best_model_idx + 1} with the lowest validation loss ({lowest_val_loss:.4f}) saved to {save_path}.")
else:
    print("No model to save.")
# Out:
# Model from fold 6 with the lowest validation loss (0.0129) saved to bestmodel_ex_6.pth.

# %% [markdown]
# import torch
#
# # Save each fold's best model to the current directory
# for i, model_state in enumerate(best_models):
#     save_path = f'10fold_{i+1}.pth'  # Save in the current directory
#     torch.save(model_state, save_path)
#
# print("Models saved to the current directory.")
