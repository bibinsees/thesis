# %% [markdown]
# # Pretrained model weights are not frozen it changes during training
#  unless  explicitly set them to requires_grad=False
#
#  #Freeze the pretrained layers
#         for param in self.convnet.parameters():
#             param.requires_grad = False

# %% [markdown]
# import os
# import random
# import shutil
#
# def split_images(image_dir, train_dir, valid_dir, validation_percentage=20):
#     # Create train and validation directories if they don't exist
#     os.makedirs(train_dir, exist_ok=True)
#     os.makedirs(valid_dir, exist_ok=True)
#
#     # Collect all .tiff files from all subdirectories
#     image_files = []
#     for root, _, files in os.walk(image_dir):
#         for file in files:
#             if file.lower().endswith(('.tiff', 'tiff')):
#                 image_files.append(os.path.join(root, file))
#
#     # Shuffle the files randomly
#     random.shuffle(image_files)
#
#     # Split the images into training and validation sets
#     total_images = len(image_files)
#     validation_count = int(total_images * validation_percentage / 100)
#
#     validation_files = image_files[:validation_count]
#     training_files = image_files[validation_count:]
#
#     # Move files to train and validation directories
#     for file_path in training_files:
#         destination = os.path.join(train_dir, os.path.basename(file_path))
#         shutil.copy(file_path, destination)
#
#     for file_path in validation_files:
#         destination = os.path.join(valid_dir, os.path.basename(file_path))
#         shutil.copy(file_path, destination)
#
#     print(f"Total images: {total_images}")
#     print(f"Training images: {len(training_files)}")
#     print(f"Validation images: {len(validation_files)}")
#
# # Example usage
# image_dir = r"../../tiff_experiment_unsupervised_data/combined"
# train_dir = r"../../tiff_experiment_unsupervised_data/train"
# valid_dir = r"../../tiff_experiment_unsupervised_data/validation"
#
# split_images(image_dir, train_dir, valid_dir, validation_percentage=20)

# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
from torchvision import transforms

import tifffile as tiff
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
import random
#from helper import set_seed

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Now you can use the `device` variable
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class SimCLR(nn.Module):
    def __init__(self, hidden_dim, lr, temperature, weight_decay,max_epochs):
        super().__init__()
        self.temperature = temperature
        
        # Load the pretrained ResNet-18 model
        self.convnet = torchvision.models.resnet18(weights='ResNet18_Weights.DEFAULT')
        
        # Modify the fully connected layer
        self.convnet.fc = nn.Sequential(
            nn.Linear(self.convnet.fc.in_features, 4 * hidden_dim),  # Linear layer with 4*hidden_dim output
            nn.ReLU(inplace=True),
            nn.Linear(4 * hidden_dim, 20)  # Output layer with hidden_dim output
        )

        self.optimizer = optim.AdamW(self.parameters(), lr=lr, weight_decay=weight_decay)
        self.lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(self.optimizer, T_max=max_epochs, eta_min=lr / 50)

    def forward(self, x):
        return self.convnet(x)

    def info_nce_loss(self, imgs1, imgs2, device):

        imgs = torch.cat((imgs1, imgs2), dim=0)  # Concatenate along the batch dimension
        imgs = imgs.to(device)  # Move images to the device

        # Encode all images
        feats = self.forward(imgs)
    
        # Calculate cosine similarity
        cos_sim = nn.functional.cosine_similarity(feats[:, None, :], feats[None, :, :], dim=-1)
    
        # Mask out cosine similarity to itself
        self_mask = torch.eye(cos_sim.shape[0], dtype=torch.bool, device=cos_sim.device)
        cos_sim.masked_fill_(self_mask, -9e15)
    
        # Find positive example -> batch_size//2 away from the original example
        pos_mask = self_mask.roll(shifts=cos_sim.shape[0] // 2, dims=0)
    
        # Normalize similarity scores by temperature
        cos_sim = cos_sim / self.temperature

        # InfoNCE loss
        nll = -cos_sim[pos_mask] + torch.logsumexp(cos_sim, dim=-1)
        nll = nll.mean()

        # Accuracy calculations
        # Create a combination of positive and negative similarities for ranking
        comb_sim = torch.cat([cos_sim[pos_mask][:, None],  # Positive example in first position
                          cos_sim.masked_fill(pos_mask, -9e15)], dim=-1)
    
        # Sort and get the ranking position of the positive example
        sim_argsort = comb_sim.argsort(dim=-1, descending=True).argmin(dim=-1)
    
        # Compute accuracy metrics
        top1_acc = (sim_argsort == 0).float().mean()  # Top-1 accuracy
        top5_acc = (sim_argsort < 5).float().mean()   # Top-5 accuracy
        mean_pos = 1 + sim_argsort.float().mean()     # Mean position of the positive example

        return nll, top1_acc, top5_acc, mean_pos

    def train_epoch(self, train_loader, device):
        self.train()
        total_loss = 0.0
        total_top1_acc = 0.0
        total_top5_acc = 0.0
        total_mean_pos = 0.0

        for batch in tqdm(train_loader, desc="Training", leave=False):
            imgs1, imgs2, _ = batch
            imgs1, imgs2 = imgs1.to(device), imgs2.to(device)  # Move data to device
        
            self.optimizer.zero_grad()

            # Calculate loss and accuracy metrics
            loss, top1_acc, top5_acc, mean_pos = self.info_nce_loss(imgs1, imgs2, device)

            loss.backward()
            self.optimizer.step()
            #self.lr_scheduler.step()

            # Accumulate metrics
            total_loss += loss.item()
            total_top1_acc += top1_acc.item()
            total_top5_acc += top5_acc.item()
            total_mean_pos += mean_pos.item()

        avg_loss = total_loss / len(train_loader)
        avg_top1_acc = total_top1_acc / len(train_loader)
        avg_top5_acc = total_top5_acc / len(train_loader)
        avg_mean_pos = total_mean_pos / len(train_loader)

        return avg_loss, avg_top1_acc, avg_top5_acc, avg_mean_pos

    def validate_epoch(self, val_loader, device):
        self.eval()
        total_loss = 0.0
        total_top1_acc = 0.0
        total_top5_acc = 0.0
        total_mean_pos = 0.0

        with torch.no_grad():
            for batch in tqdm(val_loader, desc="Validating", leave=False):
                imgs1, imgs2, _ = batch
                imgs1, imgs2 = imgs1.to(device), imgs2.to(device)  # Move data to device

                # Calculate loss and accuracy metrics
                loss, top1_acc, top5_acc, mean_pos = self.info_nce_loss(imgs1, imgs2, device)

                # Accumulate metrics
                total_loss += loss.item()
                total_top1_acc += top1_acc.item()
                total_top5_acc += top5_acc.item()
                total_mean_pos += mean_pos.item()

        avg_loss = total_loss / len(val_loader)
        avg_top1_acc = total_top1_acc / len(val_loader)
        avg_top5_acc = total_top5_acc / len(val_loader)
        avg_mean_pos = total_mean_pos / len(val_loader)

        return avg_loss, avg_top1_acc, avg_top5_acc, avg_mean_pos
    

    def inference_epoch(self, inference_loader, device):
        self.eval()
        total_loss = 0.0
        total_top1_acc = 0.0
        total_top5_acc = 0.0
        total_mean_pos = 0.0

        with torch.no_grad():
            for batch in tqdm(inference_loader, desc="Inferencing", leave=False):
                imgs1, imgs2, _ = batch
                imgs1, imgs2 = imgs1.to(device), imgs2.to(device)  # Move data to device

                # Calculate loss and accuracy metrics
                loss, top1_acc, top5_acc, mean_pos = self.info_nce_loss(imgs1, imgs2, device)

                # Accumulate metrics
                total_loss += loss.item()
                total_top1_acc += top1_acc.item()
                total_top5_acc += top5_acc.item()
                total_mean_pos += mean_pos.item()

        avg_loss = total_loss / len(inference_loader)
        avg_top1_acc = total_top1_acc / len(inference_loader)
        avg_top5_acc = total_top5_acc / len(inference_loader)
        avg_mean_pos = total_mean_pos / len(inference_loader)

        return avg_loss, avg_top1_acc, avg_top5_acc, avg_mean_pos

# %%
# Reinitialize the model
full_model_path =  r'C:\Users\k54739\saved_model\simclr_strongcrop_245.pth'
simclr_model = SimCLR(hidden_dim=128, lr=5e-4, temperature=0.07, weight_decay=1e-4,max_epochs=245)
simclr_model.load_state_dict(torch.load(full_model_path))
simclr_model.to(device)
simclr_model.eval()
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_24004\753954344.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   simclr_model.load_state_dict(torch.load(full_model_path))
# SimCLR(
#   (convnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=512, out_features=20, bias=True)
#     )
#   )
# )

# %% [markdown]
# Inference before projection head

# %% [markdown]
# # Logistic

# %%
from sklearn.model_selection import train_test_split
from copy import deepcopy
from sklearn.metrics import accuracy_score

# %%
class LabeledImageDataset(Dataset):
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Ensure the image has 3 layers (channels)
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} does not have exactly 3 layers.")

        # Normalize the 16-bit image to [0, 1]
        image = image.astype(np.float32) / 65535.0

        # Convert to a torch tensor and add channel dimension
        image = torch.tensor(image, dtype=torch.float32)
        
        # Apply resize transform
        image = self.resize_transform(image)

        label = self.labels[idx]

        return image, label

def load_and_split_data(root_dir, test_size=0.2):
    #classes = ['untreated', 'single_dose', 'drug_screened']
    classes = ['control', 'treated']
    image_files = []
    labels = []

    for idx, class_name in enumerate(classes):
        class_dir = os.path.join(root_dir, class_name)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir) if file.endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        labels.extend([idx] * len(files))
    
    # Check if the labels correctly reflect the classes
    #print("Label distribution:", {classes[i]: labels.count(i) for i in range(len(classes))})
    
    # Split data into training and test sets
    train_files, test_files, train_labels, test_labels = train_test_split(
        image_files, labels, test_size=test_size, stratify=labels, random_state=42)

    return train_files, test_files, train_labels, test_labels


# Directories for labeled data
image_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\train_sd"

# Load and split the data
train_files, test_files, train_labels, test_labels = load_and_split_data(image_dir, test_size=0.2)

# Create the labeled datasets
train_labeled_dataset = LabeledImageDataset(train_files, train_labels)
test_labeled_dataset = LabeledImageDataset(test_files, test_labels)

# Define DataLoaders
batch_size = 16
train_loader_labeled = DataLoader(train_labeled_dataset, batch_size=batch_size, shuffle=True, drop_last=False, pin_memory=True, num_workers=0)
test_loader_labeled = DataLoader(test_labeled_dataset, batch_size=batch_size, shuffle=False, drop_last=False, pin_memory=True, num_workers=0)

# %%
for anchor,label in train_loader_labeled:
    print(anchor.shape, label.shape, anchor.dtype)
    print(label)
    break
# Out:
# torch.Size([16, 3, 96, 96]) torch.Size([16]) torch.float32
# tensor([0, 0, 0, 0, 1, 1, 0, 1, 0, 0, 0, 0, 1, 1, 0, 1])

# %%
# Initialize a counter
total_images = 0

# Iterate through the DataLoader
for anchor, label in train_loader_labeled:
    total_images += anchor.size(0)  # Increment by the batch size (number of images in the current batch)

# Print the total number of images
print(f"Total number of images in train_loader_labeled: {total_images}")
# Out:
# Total number of images in train_loader_labeled: 178

# %%
# Initialize a counter
total_images = 0

# Iterate through the DataLoader
for anchor, label in test_loader_labeled:
    total_images += anchor.size(0)  # Increment by the batch size (number of images in the current batch)

# Print the total number of images
print(f"Total number of images in test_loader_labeled: {total_images}")
# Out:
# Total number of images in test_loader_labeled: 45

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
@torch.no_grad()
def prepare_data_features(model, dataloader):
    # Prepare model
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()  # Removing projection head g(.)
    network.eval()
    network.to(device)

    # Encode all images
    feats, labels = [], []
    for batch_imgs, batch_labels in tqdm(dataloader):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        print(f"Batch features shape: {batch_feats.shape}")
        print(f"Batch labels shape: {batch_labels.shape}")
        
        feats.append(batch_feats.detach().cpu())
        labels.append(batch_labels)

    feats = torch.cat(feats, dim=0)
    labels = torch.cat(labels, dim=0)
    
    print(f"Features shape after concatenation: {feats.shape}")
    print(f"Labels shape after concatenation: {labels.shape}")

    return torch.utils.data.TensorDataset(feats, labels)

# %%
# Extract features for train and test datasets
train_feats_simclr = prepare_data_features(simclr_model, train_loader_labeled)
test_feats_simclr = prepare_data_features(simclr_model, test_loader_labeled)
# Out:
#   8%|▊         | 1/12 [00:00<00:10,  1.09it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
#  17%|█▋        | 2/12 [00:01<00:08,  1.19it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
#  25%|██▌       | 3/12 [00:02<00:07,  1.26it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
#  33%|███▎      | 4/12 [00:03<00:05,  1.33it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
#  42%|████▏     | 5/12 [00:03<00:04,  1.41it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
#  50%|█████     | 6/12 [00:04<00:04,  1.44it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
#  58%|█████▊    | 7/12 [00:05<00:03,  1.46it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
#  67%|██████▋   | 8/12 [00:05<00:02,  1.47it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
#  75%|███████▌  | 9/12 [00:06<00:02,  1.48it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
#  83%|████████▎ | 10/12 [00:07<00:01,  1.49it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# 100%|██████████| 12/12 [00:07<00:00,  1.53it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# Batch features shape: torch.Size([2, 512])
# Batch labels shape: torch.Size([2])
# Features shape after concatenation: torch.Size([178, 512])
# Labels shape after concatenation: torch.Size([178])
#  33%|███▎      | 1/3 [00:00<00:01,  1.42it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
#  67%|██████▋   | 2/3 [00:01<00:00,  1.44it/s]
# Batch features shape: torch.Size([16, 512])
# Batch labels shape: torch.Size([16])
# 100%|██████████| 3/3 [00:01<00:00,  1.54it/s]
# Batch features shape: torch.Size([13, 512])
# Batch labels shape: torch.Size([13])
# Features shape after concatenation: torch.Size([45, 512])
# Labels shape after concatenation: torch.Size([45])

# %%
# Logistic Regression model definition
class LogisticRegression(nn.Module):
    def __init__(self, feature_dim, num_classes):
        super(LogisticRegression, self).__init__()
        self.linear = nn.Linear(feature_dim, num_classes)

    def forward(self, x):
        return self.linear(x)

# %%
# Training function
def train_logistic_regression(model, train_loader, optimizer, scheduler, device):
    model.train()
    total_loss = 0.0
    all_preds = []
    all_labels = []

    for batch_feats, batch_labels in tqdm(train_loader, desc="Training"):
        batch_feats, batch_labels = batch_feats.to(device), batch_labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(batch_feats)
        loss = nn.functional.cross_entropy(outputs, batch_labels)
        loss.backward()
        optimizer.step()
        
        # Update learning rate scheduler
        scheduler.step()

        total_loss += loss.item()

        preds = outputs.argmax(dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(batch_labels.cpu().numpy())

    avg_loss = total_loss / len(train_loader)
    accuracy = accuracy_score(all_labels, all_preds)
    return avg_loss, accuracy

# %%
# Evaluation function
def evaluate_logistic_regression(model, test_loader, criterion, device):
    model.eval()
    total_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch_feats, batch_labels in tqdm(test_loader, desc="Evaluating"):
            batch_feats, batch_labels = batch_feats.to(device), batch_labels.to(device)
            
            outputs = model(batch_feats)
            loss = nn.functional.cross_entropy(outputs, batch_labels)
            total_loss += loss.item()

            preds = outputs.argmax(dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(batch_labels.cpu().numpy())

    avg_loss = total_loss / len(test_loader)
    accuracy = accuracy_score(all_labels, all_preds)
    return avg_loss, accuracy

# %%
def train_logreg_simplified(batch_size, train_feats_data, test_feats_data, feature_dim, num_classes, lr=5e-4, weight_decay=1e-4, max_epochs=50):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Data loaders
    train_loader = DataLoader(train_feats_data, batch_size=batch_size, shuffle=True,
                              drop_last=False, pin_memory=True, num_workers=0)
    test_loader = DataLoader(test_feats_data, batch_size=batch_size, shuffle=False,
                             drop_last=False, pin_memory=True, num_workers=0)

    # Model, loss, and optimizer
    model = LogisticRegression(feature_dim, num_classes).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer,
                                               milestones=[int(max_epochs * 0.6), int(max_epochs * 0.8)],
                                               gamma=0.1)

    # Store metrics for plotting
    train_losses = []
    test_losses = []
    train_accuracies = []
    test_accuracies = []

    # Track best by accuracy
    best_test_acc = -1.0
    best_model_state_acc = None

    # Track best by loss (with accuracy as a tiebreaker)
    best_test_loss = float('inf')
    best_test_loss_acc = -1.0
    best_model_state_loss = None

    for epoch in range(max_epochs):
        print(f"Epoch {epoch+1}/{max_epochs}")

        train_loss, train_acc = train_logistic_regression(model, train_loader, optimizer, scheduler, device)
        test_loss, test_acc = evaluate_logistic_regression(model, test_loader, criterion, device)

        print(f"Training loss: {train_loss:.4f}, Training accuracy: {train_acc:.4f}")
        print(f"Test loss: {test_loss:.4f}, Test accuracy: {test_acc:.4f}")

        train_losses.append(train_loss)
        test_losses.append(test_loss)
        train_accuracies.append(train_acc)
        test_accuracies.append(test_acc)

        # Check for best accuracy model
        if test_acc > best_test_acc:
            best_test_acc = test_acc
            best_model_state_acc = model.state_dict()

        # Check for best loss model
        # Condition: strictly lower loss OR equal loss but higher accuracy
        if (test_loss < best_test_loss) or (test_loss == best_test_loss and test_acc > best_test_loss_acc):
            best_test_loss = test_loss
            best_test_loss_acc = test_acc
            best_model_state_loss = model.state_dict()

    # Now we have two best states: best_model_state_acc and best_model_state_loss
    # Create two separate model instances for them
    best_acc_model = LogisticRegression(feature_dim, num_classes).to(device)
    best_acc_model.load_state_dict(best_model_state_acc)
    best_acc_model.eval()

    best_loss_model = LogisticRegression(feature_dim, num_classes).to(device)
    best_loss_model.load_state_dict(best_model_state_loss)
    best_loss_model.eval()

    # Plot results
    plt.figure(figsize=(15, 5))

    # Loss curve
    plt.subplot(1, 2, 1)
    plt.plot(range(max_epochs), train_losses, label='Train Loss')
    plt.plot(range(max_epochs), test_losses, label='Test Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss Curve')
    plt.legend()

    # Accuracy curve
    plt.subplot(1, 2, 2)
    plt.plot(range(max_epochs), train_accuracies, label='Train Accuracy')
    plt.plot(range(max_epochs), test_accuracies, label='Test Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Accuracy Curve')
    plt.legend()

    plt.tight_layout()
    plt.show()

    # Return both models and the final results (e.g., last train_acc and test_acc recorded)
    return best_acc_model, best_loss_model, {"train_acc": train_acc, "test_acc": test_acc}

# %%
# Train the logistic regression model
# Example usage:
best_acc_model, best_loss_model, results = train_logreg_simplified(
    batch_size=8,
    train_feats_data=train_feats_simclr,
    test_feats_data=test_feats_simclr,
    feature_dim=train_feats_simclr.tensors[0].shape[1],
    num_classes=2,
    lr=5e-4,
    weight_decay=1e-4,
    max_epochs=1000
)
#print(f"Final Train Accuracy: {results['train_acc']:.4f}, Final Test Accuracy: {results['test_acc']:.4f}")
# Out:
# Epoch 1/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 93.72it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 159.15it/s]
# Training loss: 0.4996, Training accuracy: 0.7360
# Test loss: 0.0869, Test accuracy: 1.0000
# Epoch 2/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 146.77it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 292.50it/s]
# Training loss: 0.0463, Training accuracy: 1.0000
# Test loss: 0.0309, Test accuracy: 1.0000
# Epoch 3/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 171.83it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 413.78it/s]
# Training loss: 0.0227, Training accuracy: 1.0000
# Test loss: 0.0218, Test accuracy: 1.0000
# Epoch 4/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 170.11it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 186.42it/s]
# Training loss: 0.0169, Training accuracy: 1.0000
# Test loss: 0.0170, Test accuracy: 1.0000
# Epoch 5/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 175.52it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 322.34it/s]
# Training loss: 0.0143, Training accuracy: 1.0000
# Test loss: 0.0135, Test accuracy: 1.0000
# Epoch 6/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 174.38it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 182.71it/s]
# Training loss: 0.0112, Training accuracy: 1.0000
# Test loss: 0.0120, Test accuracy: 1.0000
# Epoch 7/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 194.12it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 189.87it/s]
# Training loss: 0.0094, Training accuracy: 1.0000
# Test loss: 0.0102, Test accuracy: 1.0000
# Epoch 8/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 197.98it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 365.76it/s]
# Training loss: 0.0082, Training accuracy: 1.0000
# Test loss: 0.0088, Test accuracy: 1.0000
# Epoch 9/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 225.35it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 178.00it/s]
# Training loss: 0.0070, Training accuracy: 1.0000
# Test loss: 0.0074, Test accuracy: 1.0000
# Epoch 10/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 201.97it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 162.89it/s]
# Training loss: 0.0062, Training accuracy: 1.0000
# Test loss: 0.0066, Test accuracy: 1.0000
# Epoch 11/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 172.57it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 185.33it/s]
# Training loss: 0.0081, Training accuracy: 1.0000
# Test loss: 0.0059, Test accuracy: 1.0000
# Epoch 12/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 198.77it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 158.10it/s]
# Training loss: 0.0051, Training accuracy: 1.0000
# Test loss: 0.0063, Test accuracy: 1.0000
# Epoch 13/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 180.60it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 176.76it/s]
# Training loss: 0.0045, Training accuracy: 1.0000
# Test loss: 0.0052, Test accuracy: 1.0000
# Epoch 14/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 195.79it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 301.04it/s]
# Training loss: 0.0041, Training accuracy: 1.0000
# Test loss: 0.0044, Test accuracy: 1.0000
# Epoch 15/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 155.09it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 364.49it/s]
# Training loss: 0.0038, Training accuracy: 1.0000
# Test loss: 0.0040, Test accuracy: 1.0000
# Epoch 16/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 140.07it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 220.17it/s]
# Training loss: 0.0033, Training accuracy: 1.0000
# Test loss: 0.0038, Test accuracy: 1.0000
# Epoch 17/1000
# Training: 100%|██████████| 23/23 [00:00<00:00,
1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 196.51it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 181.39it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 979/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 204.63it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 263.21it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 980/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 157.81it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 191.98it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 981/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 198.84it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 383.99it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 982/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 186.01it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 180.47it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 983/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 197.08it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 307.19it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 984/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 200.88it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 300.62it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 985/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 155.73it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 351.75it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 986/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 173.62it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 179.52it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 987/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 175.05it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 172.59it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 988/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 195.68it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 191.37it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 989/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 202.58it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 363.49it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 990/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 167.85it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 283.09it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 991/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 155.57it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 288.64it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 992/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 172.75it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 356.75it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 993/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 170.90it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 371.13it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 994/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 197.05it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 163.85it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 995/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 166.24it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 245.57it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 996/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 168.82it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 383.97it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 997/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 169.19it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 148.50it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 998/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 189.45it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 178.49it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 999/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 198.98it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 182.56it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000
# Epoch 1000/1000
# Training: 100%|██████████| 23/23 [00:00<00:00, 194.56it/s]
# Evaluating: 100%|██████████| 6/6 [00:00<00:00, 183.04it/s]
# Training loss: 0.0000, Training accuracy: 1.0000
# Test loss: 0.0000, Test accuracy: 1.0000

# %%
logreg_model= best_loss_model
logreg_model
# Out:
# LogisticRegression(
#   (linear): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# # Train the logistic regression model
# # Example usage:
# best_acc_model, best_loss_model, results = train_logreg_simplified(
#     batch_size=8,
#     train_feats_data=train_feats_simclr,
#     test_feats_data=test_feats_simclr,
#     feature_dim=train_feats_simclr.tensors[0].shape[1],
#     num_classes=2,
#     lr=5e-4,
#     weight_decay=1e-4,
#     max_epochs=100
# )
# #print(f"Final Train Accuracy: {results['train_acc']:.4f}, Final Test Accuracy: {results['test_acc']:.4f}")

# %%
# Save the best models by accuracy and loss
torch.save(best_acc_model.state_dict(), "1000epoch_best_acc_model.pth")
torch.save(best_loss_model.state_dict(), "1000epoch_best_loss_model.pth")

# %%
logreg_model = LogisticRegression(512,2)
logreg_model = logreg_model.to(device)

# %%
# Step 2: Load the saved state dict
state_dict = torch.load("1000epoch_best_loss_model.pth")  # Load weights from the file
logreg_model.load_state_dict(state_dict)  # Load state dict into the model

# Step 3: Set the model to evaluation mode (if not training)
logreg_model.eval()  # This disables dropout and batchnorm for inference
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_24004\1935246668.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load("1000epoch_best_loss_model.pth")  # Load weights from the file
# LogisticRegression(
#   (linear): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# # 512= feature_dim = train_feats_simclr.tensors[0].shape[1] =  before projection head

# %% [markdown]
# # Save model state_dict
# torch.save(logreg_model.state_dict(), "logreg_model_best.pth")

# %%
# 1000 epochs: no outlier amoung exploded, control7, single dose
#500 epochs, one outlier of exploder in ds closer to sd: which is ds41_g9_C10-T01   inbetween 4 ds closer
# 100 epochs, one outlier of exploder also one outlier from ds_clos_tosd ds41_g5_E04-T01

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 18/18 [00:12<00:00,  1.42it/s]

# %%
all_images_data = []
for grp in groups:
    # each entry is [p_control, p_treated, img_path]
    all_images_data.extend(groups_data[grp])

# Sort by p(treated) in ascending order
all_images_data.sort(key=lambda x: x[1])  # No reverse=True

# Now all_images_data is sorted by p(treated) in ascending order
sorted_by_treated = [(entry[2], entry[1], entry[0]) for entry in all_images_data]

# Print sorted images
print("Images sorted by p(treated) in ascending order:")
for img_path, p_tr, p_ctrl in sorted_by_treated:
    print(f"{img_path}: p(treated)={p_tr:.4f}, p(control)={p_ctrl:.4f}")

# Initialize group-wise data
grouped_data = {group: [] for group in groups}
for group in groups:
    grouped_data[group].extend(groups_data[group])

# Step 1: Sort distances and keep track of group membership
sorted_distances = []
for group, data in grouped_data.items():
    for _, p_treated, _ in data:
        sorted_distances.append((p_treated, group))

sorted_distances.sort(key=lambda x: x[0])  # Sort by p(treated)

# Step 2: Check for correct transitions between groups
correct_transitions = 0
total_transitions = len(groups) - 1  # Total possible adjacent group transitions

for i in range(total_transitions):
    group_i = groups[i]
    group_j = groups[i + 1]

    # Get all distances for groups i and j
    distances_i = [dist for dist, grp in sorted_distances if grp == group_i]
    distances_j = [dist for dist, grp in sorted_distances if grp == group_j]

    # Check the condition: all d in G_i < all d in G_j
    if all(d_i < d_j for d_i in distances_i for d_j in distances_j):
        correct_transitions += 1

# Step 3: Calculate ranking accuracy
ranking_accuracy = correct_transitions / total_transitions if total_transitions > 0 else 1.0

# Step 4: Print the group-wise ranking accuracy
print("\nGroup-Wise Ranking Accuracy:")
print(f"Correct Transitions: {correct_transitions}")
print(f"Total Possible Transitions: {total_transitions}")
print(f"Ranking Accuracy: {ranking_accuracy:.4f}")
# Out:
# Images sorted by p(treated) in ascending order:
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_G06-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_G08-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_F06-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_C06-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_D06-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_E05-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_F05-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_F08-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_E06-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_G04-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_G11-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_C07-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_G03-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_C09-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_E08-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_G10-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_F09-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_E10-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_G05-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_G07-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_C08-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_D10-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_E03-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_D07-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_D08-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_D09-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_D04-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_F02-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_E07-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_C03-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_D11-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_B07-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_C02-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_C11-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_D03-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_C10-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_F02-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_D02-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_F07-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_E02-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_C04-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_G09-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_B02-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_D04-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_D03-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_D05-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_C08-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_B06-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_F10-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_B05-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_D07-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_F10-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_G04-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_E10-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_D08-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_G09-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_C04-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_E04-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_E11-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_C03-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_G02-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_E09-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_F04-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_G08-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_D02-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_B08-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_D06-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_C05-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_E04-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_B09-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_E05-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_B10-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_B10-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_C10-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_B09-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_F11-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_G05-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_B07-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_C06-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_B06-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_D09-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_C09-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_G10-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_C07-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_F03-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_C05-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_B05-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_G06-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_E08-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_B11-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_G11-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_E07-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_D05-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_E09-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_B11-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_B03-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_D11-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_F07-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_B02-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_G02-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_F11-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_E06-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_F08-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_C02-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_G03-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_C11-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_E11-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_F04-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_B04-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_F03-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g9_C07-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_E03-T01.tiff: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds1B_g9_C8.tif: p(treated)=0.0000, p(control)=1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_F09-T01.tiff: p(treated)=0.0001, p(control)=0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_E02-T01.tiff: p(treated)=0.0001, p(control)=0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBTDS1B_Day_7_B04-T01.tiff: p(treated)=0.0001, p(control)=0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_G07-T01.tiff: p(treated)=0.0001, p(control)=0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_F06-T01.tiff: p(treated)=0.0001, p(control)=0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_B08-T01.tiff: p(treated)=0.0001, p(control)=0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g6_F03-T01.tiff: p(treated)=0.0001, p(control)=0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_D10-T01.tiff: p(treated)=0.0001, p(control)=0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_F05-T01.tiff: p(treated)=0.0001, p(control)=0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\cond7\RBT_01.04_Day7_B03-T01.tiff: p(treated)=0.0002, p(control)=0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds1B_g9_C7.tif: p(treated)=0.0005, p(control)=0.9995
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g9_C11-T01.tiff: p(treated)=0.0007, p(control)=0.9993
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds1B_g9_C9.tif: p(treated)=0.0007, p(control)=0.9993
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds1B_g9_C11.tif: p(treated)=0.0008, p(control)=0.9992
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g8_B11-T01.tiff: p(treated)=0.0009, p(control)=0.9991
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g9_C10-T01.tiff: p(treated)=0.0017, p(control)=0.9983
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g6_F02-T01.tiff: p(treated)=0.0020, p(control)=0.9980
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g9_C09-T01.tiff: p(treated)=0.0036, p(control)=0.9964
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds1B_g9_c10.tif: p(treated)=0.0040, p(control)=0.9960
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g8_B08-T01.tiff: p(treated)=0.0060, p(control)=0.9940
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds41_g3_C06-T01.tiff: p(treated)=0.0092, p(control)=0.9908
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g8_B07-T01.tiff: p(treated)=0.0252, p(control)=0.9748
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds41_g3_C04-T01.tiff: p(treated)=0.0265, p(control)=0.9735
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g9_C08-T01.tiff: p(treated)=0.0271, p(control)=0.9729
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g6_F06-T01.tiff: p(treated)=0.0317, p(control)=0.9683
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g8_B09-T01.tiff: p(treated)=0.0427, p(control)=0.9573
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g8_B10-T01.tiff: p(treated)=0.0503, p(control)=0.9497
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds41_g3_C03-T01.tiff: p(treated)=0.0508, p(control)=0.9492
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g6_F05-T01.tiff: p(treated)=0.0551, p(control)=0.9449
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds41_g3_C02-T01.tiff: p(treated)=0.0572, p(control)=0.9428
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds62_g8_B10-T01.tiff: p(treated)=0.1441, p(control)=0.8559
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds41_g3_C05-T01.tiff: p(treated)=0.1463, p(control)=0.8537
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g3_C06-T01.tiff: p(treated)=0.1782, p(control)=0.8218
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g3_C05-T01.tiff: p(treated)=0.2687, p(control)=0.7313
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds62_g9_C11-T01.tiff: p(treated)=0.2976, p(control)=0.7024
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g6_F04-T01.tiff: p(treated)=0.3509, p(control)=0.6491
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds62_g9_C10-T01.tiff: p(treated)=0.5735, p(control)=0.4265
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g3_C02-T01.tiff: p(treated)=0.7266, p(control)=0.2734
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g3_C04-T01.tiff: p(treated)=0.7924, p(control)=0.2076
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds62_g8_B09-T01.tiff: p(treated)=0.8538, p(control)=0.1462
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds62_g9_C09-T01.tiff: p(treated)=0.8855, p(control)=0.1145
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds61_g3_C03-T01.tiff: p(treated)=0.8951, p(control)=0.1049
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds41_g9_C10-T01.tiff: p(treated)=0.9344, p(control)=0.0656
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds62_g9_C07-T01.tiff: p(treated)=0.9686, p(control)=0.0314
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds62_g2_B04-T01.tiff: p(treated)=0.9731, p(control)=0.0269
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds62_g8_B11-T01.tiff: p(treated)=0.9759, p(control)=0.0241
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds62_g8_B07-T01.tiff: p(treated)=0.9782, p(control)=0.0218
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds42_g5_E04-T01.tiff: p(treated)=0.9969, p(control)=0.0031
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds62_g2_B02-T01.tiff: p(treated)=0.9981, p(control)=0.0019
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\ex_40\ds62_g9_C08-T01.tiff: p(treated)=0.9988, p(control)=0.0012
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds62_g2_B03-T01.tiff: p(treated)=0.9990, p(control)=0.0010
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_C10-T01.tiff: p(treated)=0.9993, p(control)=0.0007
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds42_g5_E06-T01.tiff: p(treated)=0.9997, p(control)=0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_E07-T01.tiff: p(treated)=0.9998, p(control)=0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds42_g5_E05-T01.tiff: p(treated)=0.9998, p(control)=0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds1b_g5_E3.tif: p(treated)=0.9999, p(control)=0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds41_g2_B04-T01.tiff: p(treated)=0.9999, p(control)=0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds41_g2_B06-T01.tiff: p(treated)=0.9999, p(control)=0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_B11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds41_g5_E05-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_G10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_G08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds1b_g5_E5.tif: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds1b_g5_E2.tif: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_D07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds41_g2_B03-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_D10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_B10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_D07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds41_g5_E04-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_D11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_E09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds42_g2_B04-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_E08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_D09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_E07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_D09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_B07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_F08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds42_g2_B06-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds42_g5_E02-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_E10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_F10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds41_g5_E06-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_D08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_G09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_D07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_D11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_C07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_D11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_C11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_C09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_G11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_C08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds42_g2_B05-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds42_g5_E03-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_C07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_F09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_E07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_B11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_D10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_F10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_G11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_G10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_F07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_B10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_F11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_B08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_D08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_E09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_B11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_C09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_C11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_B08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_B09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_C08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_C10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_C11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_D10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_F07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_F08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_F09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_F10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_G07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds1b_g5_E4.tif: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\ds42_g2_B03-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_B09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_B10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_F07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_F09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_B10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_D10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_F11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_G07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_G09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_B11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_C09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_D07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_D08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_E09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_E11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_B07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_B09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_C08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_C09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_C10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_D08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_D09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_C08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_D09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_E08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_E10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_E11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_F11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_G07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.04_Day10_G08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_B07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_B08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_B09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_C10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_D11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_E11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_F08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_G08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.09_Day10_G10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_B07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_C07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_E10-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_G09-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.10_Day10_G11-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_B08-T01.tiff: p(treated)=1.0000, p(control)=0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference_for_accuracy\single_dose\sd_RBT_01.14_Day10_C07-T01.tiff: p(treated)=1.0000, p(control)=0.0000
#
# Group-Wise Ranking Accuracy:
# Correct Transitions: 0
# Total Possible Transitions: 2
# Ranking Accuracy: 0.0000

# %%
all_images_data = []
for grp in groups:
    # each entry is [p_control, p_treated, img_path]
    all_images_data.extend(groups_data[grp])

# Sort by p(treated) in ascending order
all_images_data.sort(key=lambda x: x[1])  # No reverse=True

# Now all_images_data is sorted by p(treated) in ascending ordergroups_data[group_name]
sorted_by_treated = [(entry[2], entry[1]) for entry in all_images_data]

print("Images sorted by p(treated) in ascending order:")
for img_path, p_tr in sorted_by_treated:
    print(f"{img_path}: {p_tr:.4f}")
# Out:
# Images sorted by p(treated) in ascending order:
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B03-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E06-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B02-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G03-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F04-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G02-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds1B_g9_C8.tif: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F08-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C02-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E09-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F11-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C11-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B04-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E11-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G07-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E03-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B08-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E02-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F09-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D10-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B04-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F06-T01.tiff: 0.0004
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B03-T01.tiff: 0.0006
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g9_C07-T01.tiff: 0.0006
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F05-T01.tiff: 0.0007
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds1B_g9_C11.tif: 0.0010
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g6_F03-T01.tiff: 0.0018
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds1B_g9_C7.tif: 0.0019
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds1B_g9_C9.tif: 0.0024
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds1B_g9_c10.tif: 0.0081
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g9_C11-T01.tiff: 0.0130
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g8_B11-T01.tiff: 0.0133
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds41_g3_C06-T01.tiff: 0.0206
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g8_B08-T01.tiff: 0.0244
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds41_g3_C04-T01.tiff: 0.0270
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g6_F02-T01.tiff: 0.0401
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g9_C10-T01.tiff: 0.0419
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g9_C09-T01.tiff: 0.0521
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds41_g3_C02-T01.tiff: 0.0646
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds41_g3_C03-T01.tiff: 0.0772
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g9_C08-T01.tiff: 0.0874
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g8_B07-T01.tiff: 0.0904
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g6_F06-T01.tiff: 0.1440
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g8_B09-T01.tiff: 0.2111
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g8_B10-T01.tiff: 0.2150
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds41_g3_C05-T01.tiff: 0.2476
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g6_F05-T01.tiff: 0.4043
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g3_C06-T01.tiff: 0.4773
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds62_g8_B10-T01.tiff: 0.5029
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g3_C05-T01.tiff: 0.5475
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g6_F04-T01.tiff: 0.6275
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds62_g9_C11-T01.tiff: 0.8011
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds62_g9_C10-T01.tiff: 0.8162
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g3_C02-T01.tiff: 0.8188
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g3_C04-T01.tiff: 0.9005
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds41_g9_C10-T01.tiff: 0.9313
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds62_g2_B04-T01.tiff: 0.9428
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds61_g3_C03-T01.tiff: 0.9484
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds62_g8_B09-T01.tiff: 0.9572
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds62_g9_C09-T01.tiff: 0.9820
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds62_g8_B11-T01.tiff: 0.9893
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds62_g2_B02-T01.tiff: 0.9910
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds62_g2_B03-T01.tiff: 0.9921
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds62_g9_C07-T01.tiff: 0.9924
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds62_g8_B07-T01.tiff: 0.9960
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g5_E04-T01.tiff: 0.9970
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_C10-T01.tiff: 0.9978
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds1b_g5_E3.tif: 0.9991
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_E07-T01.tiff: 0.9992
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\exploded_all\ds62_g9_C08-T01.tiff: 0.9995
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g5_E06-T01.tiff: 0.9995
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds1b_g5_E2.tif: 0.9997
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds1b_g5_E5.tif: 0.9997
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g5_E05-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds41_g2_B06-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_G10-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds41_g2_B04-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_B11-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_G08-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds41_g5_E05-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_D10-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_D07-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds41_g2_B03-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_E09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g2_B04-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_E08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_C11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_E07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_D09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_D09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_F08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds41_g5_E04-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g2_B06-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_F10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_E10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_G11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_G09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_E07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g5_E02-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_C07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_F09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g2_B05-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_B11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g5_E03-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_G11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_C07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds1b_g5_E4.tif: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_G10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_F11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds41_g5_E06-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_C11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_G07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_D09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_F10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_B11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_F07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_F09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_F07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_F08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_F10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g2_B03-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_C11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_E09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_E09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_F09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_F11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_E11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_G07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_F07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_G09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_B11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_C07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_G07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_F08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_E10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_G09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_E08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_E10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_F11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_E11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_G08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_G10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_G11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_C07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_D09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_E11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_G08-T01.tiff: 1.0000

# %%
import os
import shutil

# Assuming 'sorted_by_treated' is already defined as:
# sorted_by_treated = [(img_path, p_tr), ...] sorted in ascending order by p_tr

new_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\sorted_explodall"
os.makedirs(new_dir, exist_ok=True)

for i, (img_path, p_tr) in enumerate(sorted_by_treated, start=1):
    # Extract the parent directory name and the original filename
    parent_dir_name = os.path.basename(os.path.dirname(img_path))  # e.g. "cond7"
    base_filename = os.path.basename(img_path)  # e.g. "ds_41.tif"
    
    # Combine them to get "cond7_ds_41.tif"
    original_filename = f"{parent_dir_name}_{base_filename}"

    # Format the probability score
    formatted_score = f"{p_tr:.4f}"
    
    # Construct the new filename with index and score
    new_filename = f"{i}_{formatted_score}_{original_filename}"
    new_path = os.path.join(new_dir, new_filename)
    
    shutil.copy2(img_path, new_path)

print("Images copied and renamed successfully!")
# Out:
# Images copied and renamed successfully!

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features:   0%|          | 0/28 [00:00<?, ?it/s]
# Extracting Features: 100%|██████████| 28/28 [00:20<00:00,  1.36it/s]

# %%
all_images_data = []
for grp in groups:
    # each entry is [p_control, p_treated, img_path]
    all_images_data.extend(groups_data[grp])

# Sort by p(treated) in ascending order
all_images_data.sort(key=lambda x: x[1])  # No reverse=True

# Now all_images_data is sorted by p(treated) in ascending order
sorted_by_treated = [(entry[2], entry[1]) for entry in all_images_data]

print("Images sorted by p(treated) in ascending order:")
for img_path, p_tr in sorted_by_treated:
    print(f"{img_path}: {p_tr:.4f}")
# Out:
# Images sorted by p(treated) in ascending order:
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_E06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_D05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_E06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_F02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_D05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_114_C03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_F04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_D02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_B11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_F03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_E05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_114_D06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_F02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_B06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_114_B02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_F03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_F06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_F06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_F09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_E02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_B11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_C04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_C02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_D05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_B05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_E05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_B04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_E06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_G05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_C10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_D06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_B05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_114_D04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_D06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBTDS1B_Day_7_G11-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_F05-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_D03-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G10-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_C03-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_114_C06-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_114_C05-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_C06-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_E08-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_E02-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_E05-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_C02-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_114_B06-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\RBTDS1B_F11.tif: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_D05-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\RBTDS1B_E10.tif: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_E04-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\RBTDS1B_G08.tif: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_D04-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond7\RBT_01.04_Day7_G03-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_G04-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_F05-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_114_D02-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_114_B04-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_B06-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_C04-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_114_C04-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_E03-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_61_D09-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_114_D05-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_62_E08-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_G04-T01.tiff: 0.0004
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_114_B05-T01.tiff: 0.0004
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_C06-T01.tiff: 0.0004
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_E04-T01.tiff: 0.0005
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_D05-T01.tiff: 0.0005
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_61_E07-T01.tiff: 0.0005
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_61_F10-T01.tiff: 0.0005
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_C04-T01.tiff: 0.0006
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_61_D07-T01.tiff: 0.0006
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_F04-T01.tiff: 0.0007
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_B03-T01.tiff: 0.0007
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_F03-T01.tiff: 0.0007
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\RBTDS1B_G11.tif: 0.0007
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\RBTDS1B_G10.tif: 0.0007
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_D03-T01.tiff: 0.0008
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_G04-T01.tiff: 0.0009
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_D06-T01.tiff: 0.0011
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_61_F08-T01.tiff: 0.0011
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_C06-T01.tiff: 0.0011
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_G03-T01.tiff: 0.0011
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_62_E09-T01.tiff: 0.0012
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_D03-T01.tiff: 0.0012
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_F06-T01.tiff: 0.0013
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_B05-T01.tiff: 0.0013
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_62_D09-T01.tiff: 0.0014
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_B04-T01.tiff: 0.0014
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_61_F11-T01.tiff: 0.0015
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_61_E09-T01.tiff: 0.0015
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_41_D07-T01.tiff: 0.0015
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_41_D08-T01.tiff: 0.0018
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_D02-T01.tiff: 0.0018
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_G06-T01.tiff: 0.0018
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_41_E10-T01.tiff: 0.0019
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_G03-T01.tiff: 0.0019
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\RBTDS1B_D7.tif: 0.0019
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\RBTDS1B_E7.tif: 0.0022
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_D02-T01.tiff: 0.0023
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\RBTDS1B_E8.tif: 0.0024
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\RBTDS1B_F09.tif: 0.0026
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\RBTDS1B_G09.tif: 0.0029
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_F04-T01.tiff: 0.0031
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110_B02-T01.tiff: 0.0032
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_F02-T01.tiff: 0.0032
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_42_D11-T01.tiff: 0.0034
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_G05-T01.tiff: 0.0037
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_14_C05-T01.tiff: 0.0039
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_61_G11-T01.tiff: 0.0040
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_E03-T01.tiff: 0.0041
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_19_C03-T01.tiff: 0.0045
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_42_D09-T01.tiff: 0.0049
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\sd_110
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_62_F11-T01.tiff: 0.7556
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_42_D08-T01.tiff: 0.7720
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_62_G10-T01.tiff: 0.7723
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_41_F11-T01.tiff: 0.7788
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_41_G11-T01.tiff: 0.8465
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_42_G09-T01.tiff: 0.8803
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_42_G10-T01.tiff: 0.9566
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_62_F09-T01.tiff: 0.9582
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_61_D08-T01.tiff: 0.9735
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_62_F07-T01.tiff: 0.9758
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\cond10\ds_42_F08-T01.tiff: 0.9849
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g2_B05-T01.tiff: 0.9981
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds1b_g5_E5.tif: 0.9981
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds41_g2_B06-T01.tiff: 0.9983
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds1b_g5_E3.tif: 0.9985
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds1b_g5_E2.tif: 0.9986
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g2_B04-T01.tiff: 0.9992
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g5_E04-T01.tiff: 0.9993
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds41_g2_B04-T01.tiff: 0.9996
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds1b_g5_E4.tif: 0.9997
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g2_B06-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_B11-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds41_g2_B03-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_F08-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_E10-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_D09-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_C07-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g5_E02-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds41_g5_E05-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_E08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g2_B03-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_F07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_E09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g5_E03-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds41_g5_E04-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_B11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_G11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_D09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_F11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_B11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_E11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_B11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_G08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g5_E06-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_E08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_E07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_C11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_E07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds62_g2_B04-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_C07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_G07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_F08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_F09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_F09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_F10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_E10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_E10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_G11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_G08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_D09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_F07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_G10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds41_g5_E06-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_E09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_D09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_F08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds42_g5_E05-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_F10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_G09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_C11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds62_g2_B02-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_F07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_F11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_C11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_C07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_F10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_G10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_E07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_F09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_C07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\ds_closeto_sd\ds62_g2_B03-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_E11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_F11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_G07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_G08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_G09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.04_Day10_G11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.09_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_E09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_E11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_G07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_G09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.10_Day10_G10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference\single_dose\sd_RBT_01.14_Day10_D10-T01.tiff: 1.0000

# %%
import os
import shutil

# Assuming 'sorted_by_treated' is already defined as:
# sorted_by_treated = [(img_path, p_tr), ...] sorted in ascending order by p_tr

new_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\sorted_cond10"
os.makedirs(new_dir, exist_ok=True)

for i, (img_path, p_tr) in enumerate(sorted_by_treated, start=1):
    # Extract the parent directory name and the original filename
    parent_dir_name = os.path.basename(os.path.dirname(img_path))  # e.g. "cond7"
    base_filename = os.path.basename(img_path)  # e.g. "ds_41.tif"
    
    # Combine them to get "cond7_ds_41.tif"
    original_filename = f"{parent_dir_name}_{base_filename}"

    # Format the probability score
    formatted_score = f"{p_tr:.4f}"
    
    # Construct the new filename with index and score
    new_filename = f"{i}_{formatted_score}_{original_filename}"
    new_path = os.path.join(new_dir, new_filename)
    
    shutil.copy2(img_path, new_path)

print("Images copied and renamed successfully!")
# Out:
# Images copied and renamed successfully!

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\2_class\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 18/18 [00:13<00:00,  1.36it/s]

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 10/10 [00:07<00:00,  1.35it/s]

# %%
all_images_data = []
for grp in groups:
    # each entry is [p_control, p_treated, img_path]
    all_images_data.extend(groups_data[grp])

# Sort by p(treated) in ascending order
all_images_data.sort(key=lambda x: x[1])  # No reverse=True

# Now all_images_data is sorted by p(treated) in ascending order
sorted_by_treated = [(entry[2], entry[1]) for entry in all_images_data]

print("Images sorted by p(treated) in ascending order:")
for img_path, p_tr in sorted_by_treated:
    print(f"{img_path}: {p_tr:.4f}")
# Out:
# Images sorted by p(treated) in ascending order:
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G11-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G10-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E08-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G03-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B08-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B11-T01.tiff: 0.0005
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B07-T01.tiff: 0.0007
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F06-T01.tiff: 0.0011
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C8.tif: 0.0011
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C7.tif: 0.0020
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C02-T01.tiff: 0.0032
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F02-T01.tiff: 0.0050
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F03-T01.tiff: 0.0052
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C07-T01.tiff: 0.0062
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C11-T01.tiff: 0.0070
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C11.tif: 0.0077
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B10-T01.tiff: 0.0080
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F04-T01.tiff: 0.0108
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B10-T01.tiff: 0.0108
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C9.tif: 0.0109
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C03-T01.tiff: 0.0126
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C05-T01.tiff: 0.0141
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C08-T01.tiff: 0.0215
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C06-T01.tiff: 0.0248
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C04-T01.tiff: 0.0300
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_c10.tif: 0.0308
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F05-T01.tiff: 0.0519
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C09-T01.tiff: 0.0854
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B11-T01.tiff: 0.1111
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C08-T01.tiff: 0.1362
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C10-T01.tiff: 0.1618
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B07-T01.tiff: 0.1881
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C10-T01.tiff: 0.1923
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C04-T01.tiff: 0.2556
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B09-T01.tiff: 0.2595
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B09-T01.tiff: 0.2754
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C03-T01.tiff: 0.4365
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C11-T01.tiff: 0.5039
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C05-T01.tiff: 0.5302
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C02-T01.tiff: 0.7032
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C06-T01.tiff: 0.7293
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C09-T01.tiff: 0.7878
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C07-T01.tiff: 0.8724
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g9_C10-T01.tiff: 0.9972

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 11/11 [00:07<00:00,  1.42it/s]

# %%
all_images_data = []
for grp in groups:
    # each entry is [p_control, p_treated, img_path]
    all_images_data.extend(groups_data[grp])

# Sort by p(treated) in ascending order
all_images_data.sort(key=lambda x: x[1])  # No reverse=True

# Now all_images_data is sorted by p(treated) in ascending order
sorted_by_treated = [(entry[2], entry[1]) for entry in all_images_data]

print("Images sorted by p(treated) in ascending order:")
for img_path, p_tr in sorted_by_treated:
    print(f"{img_path}: {p_tr:.4f}")
# Out:
# Images sorted by p(treated) in ascending order:
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B08-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B11-T01.tiff: 0.0005
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B07-T01.tiff: 0.0007
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F06-T01.tiff: 0.0011
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C8.tif: 0.0011
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C7.tif: 0.0020
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C02-T01.tiff: 0.0032
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F02-T01.tiff: 0.0050
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F03-T01.tiff: 0.0052
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C07-T01.tiff: 0.0062
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C11-T01.tiff: 0.0070
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C11.tif: 0.0077
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B10-T01.tiff: 0.0080
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F04-T01.tiff: 0.0108
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B10-T01.tiff: 0.0108
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C9.tif: 0.0109
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C03-T01.tiff: 0.0126
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C05-T01.tiff: 0.0141
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C08-T01.tiff: 0.0215
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C06-T01.tiff: 0.0248
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C04-T01.tiff: 0.0300
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_c10.tif: 0.0308
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F05-T01.tiff: 0.0519
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C09-T01.tiff: 0.0854
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B11-T01.tiff: 0.1111
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C08-T01.tiff: 0.1362
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C10-T01.tiff: 0.1618
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B07-T01.tiff: 0.1881
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C10-T01.tiff: 0.1923
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C04-T01.tiff: 0.2556
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B09-T01.tiff: 0.2595
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B09-T01.tiff: 0.2754
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C03-T01.tiff: 0.4365
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C11-T01.tiff: 0.5039
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C05-T01.tiff: 0.5302
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C02-T01.tiff: 0.7032
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C06-T01.tiff: 0.7293
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C09-T01.tiff: 0.7878
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C07-T01.tiff: 0.8724
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g9_C10-T01.tiff: 0.9972
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g2_B05-T01.tiff: 0.9981
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds1b_g5_E5.tif: 0.9981
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g2_B06-T01.tiff: 0.9983
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds1b_g5_E3.tif: 0.9985
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds1b_g5_E2.tif: 0.9986
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g2_B04-T01.tiff: 0.9992
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E04-T01.tiff: 0.9993
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g2_B04-T01.tiff: 0.9996
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds1b_g5_E4.tif: 0.9997
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g2_B06-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_B11-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g2_B03-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_F08-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_E10-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_D09-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_C07-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E02-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g5_E05-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_E08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g2_B03-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_F07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_E09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E03-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g5_E04-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_B11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_G11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_D09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_F11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_B11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_E11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_B11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_G08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E06-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_E08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_E07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_C11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_E07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds62_g2_B04-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_C07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_G07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_F08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_F09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_F09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_F10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_E10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_E10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_G11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_G08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_D09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_F07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_G10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g5_E06-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_E09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_D09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_F08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E05-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_F10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_G09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_C11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds62_g2_B02-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_F07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_F11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_C11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_C07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_F10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_G10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_E07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_F09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_C07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds62_g2_B03-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_E11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_F11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_G07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_G08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_G09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_G11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_E09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_E11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_G07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_G09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_G10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_D10-T01.tiff: 1.0000

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s]

# %%
all_images_data = []
for grp in groups:
    # each entry is [p_control, p_treated, img_path]
    all_images_data.extend(groups_data[grp])

# Sort by p(treated) in ascending order
all_images_data.sort(key=lambda x: x[1])  # No reverse=True

# Now all_images_data is sorted by p(treated) in ascending order
sorted_by_treated = [(entry[2], entry[1]) for entry in all_images_data]

print("Images sorted by p(treated) in ascending order:")
for img_path, p_tr in sorted_by_treated:
    print(f"{img_path}: {p_tr:.4f}")
# Out:
# Images sorted by p(treated) in ascending order:
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B08-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B11-T01.tiff: 0.0005
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B07-T01.tiff: 0.0007
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F06-T01.tiff: 0.0011
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C8.tif: 0.0011
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C7.tif: 0.0020
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C02-T01.tiff: 0.0032
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F02-T01.tiff: 0.0050
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F03-T01.tiff: 0.0052
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C07-T01.tiff: 0.0062
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C11-T01.tiff: 0.0070
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C11.tif: 0.0077
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B10-T01.tiff: 0.0080
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F04-T01.tiff: 0.0108
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B10-T01.tiff: 0.0108
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C9.tif: 0.0109
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C03-T01.tiff: 0.0126
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C05-T01.tiff: 0.0141
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C08-T01.tiff: 0.0215
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C06-T01.tiff: 0.0248
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C04-T01.tiff: 0.0300
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_c10.tif: 0.0308
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F05-T01.tiff: 0.0519
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C09-T01.tiff: 0.0853
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B11-T01.tiff: 0.1111
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C08-T01.tiff: 0.1362
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C10-T01.tiff: 0.1618
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B07-T01.tiff: 0.1883
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C10-T01.tiff: 0.1923
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C04-T01.tiff: 0.2556
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B09-T01.tiff: 0.2597
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B09-T01.tiff: 0.2754
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C03-T01.tiff: 0.4365
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C11-T01.tiff: 0.5042
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C05-T01.tiff: 0.5302
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C02-T01.tiff: 0.7032
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C06-T01.tiff: 0.7293
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C09-T01.tiff: 0.7878
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C07-T01.tiff: 0.8722
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g9_C10-T01.tiff: 0.9972
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g2_B05-T01.tiff: 0.9981
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds1b_g5_E5.tif: 0.9981
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g2_B06-T01.tiff: 0.9983
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds1b_g5_E3.tif: 0.9985
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds1b_g5_E2.tif: 0.9986
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g2_B04-T01.tiff: 0.9992
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E04-T01.tiff: 0.9993
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g2_B04-T01.tiff: 0.9996
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds1b_g5_E4.tif: 0.9997
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g2_B06-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g2_B03-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E02-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g5_E05-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g2_B03-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E03-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g5_E04-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E06-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds62_g2_B04-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g5_E06-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E05-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds62_g2_B02-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds62_g2_B03-T01.tiff: 1.0000

# %%
#500 epochs, one outlier of exploder in ds closer to sd: which is ds41_g9_C10-T01   inbetween 4 ds closer
# 100 epochs, one outlier of exploder also one outlier from ds_clos_tosd ds41_g5_E04-T01

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 18/18 [00:13<00:00,  1.36it/s]

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 8/8 [00:05<00:00,  1.39it/s]

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 11/11 [00:07<00:00,  1.43it/s]

# %%
all_images_data = []
for grp in groups:
    # each entry is [p_control, p_treated, img_path]
    all_images_data.extend(groups_data[grp])

# Sort by p(treated) in ascending order
all_images_data.sort(key=lambda x: x[1])  # No reverse=True

# Now all_images_data is sorted by p(treated) in ascending order
sorted_by_treated = [(entry[2], entry[1]) for entry in all_images_data]

print("Images sorted by p(treated) in ascending order:")
for img_path, p_tr in sorted_by_treated:
    print(f"{img_path}: {p_tr:.4f}")
# Out:
# Images sorted by p(treated) in ascending order:
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C8.tif: 0.0018
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B08-T01.tiff: 0.0026
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C7.tif: 0.0034
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B07-T01.tiff: 0.0050
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C11.tif: 0.0087
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C02-T01.tiff: 0.0088
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B11-T01.tiff: 0.0120
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C9.tif: 0.0129
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F06-T01.tiff: 0.0174
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C06-T01.tiff: 0.0193
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C05-T01.tiff: 0.0322
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C03-T01.tiff: 0.0328
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_c10.tif: 0.0329
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F04-T01.tiff: 0.0379
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B10-T01.tiff: 0.0594
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F03-T01.tiff: 0.0605
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C04-T01.tiff: 0.0642
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F02-T01.tiff: 0.0676
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B10-T01.tiff: 0.0948
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C08-T01.tiff: 0.1116
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C07-T01.tiff: 0.1198
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C11-T01.tiff: 0.1593
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B11-T01.tiff: 0.2031
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C08-T01.tiff: 0.2458
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C04-T01.tiff: 0.3437
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F05-T01.tiff: 0.4007
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C09-T01.tiff: 0.4838
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B09-T01.tiff: 0.5151
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B07-T01.tiff: 0.5228
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C10-T01.tiff: 0.5816
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B09-T01.tiff: 0.6152
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C10-T01.tiff: 0.6521
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C03-T01.tiff: 0.6737
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C11-T01.tiff: 0.7863
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C06-T01.tiff: 0.7894
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C02-T01.tiff: 0.7927
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C05-T01.tiff: 0.8017
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C09-T01.tiff: 0.9155
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C07-T01.tiff: 0.9160
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds1b_g5_E2.tif: 0.9734
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g2_B05-T01.tiff: 0.9735
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds1b_g5_E5.tif: 0.9770
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds1b_g5_E3.tif: 0.9816
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g9_C10-T01.tiff: 0.9873
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g2_B04-T01.tiff: 0.9884
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g2_B06-T01.tiff: 0.9958
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E04-T01.tiff: 0.9959
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g2_B06-T01.tiff: 0.9970
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds1b_g5_E4.tif: 0.9974
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_E10-T01.tiff: 0.9988
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g2_B04-T01.tiff: 0.9989
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_B11-T01.tiff: 0.9990
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_F08-T01.tiff: 0.9991
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_E08-T01.tiff: 0.9992
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_C07-T01.tiff: 0.9993
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g2_B03-T01.tiff: 0.9993
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_C08-T01.tiff: 0.9994
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_F07-T01.tiff: 0.9995
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E02-T01.tiff: 0.9995
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_E09-T01.tiff: 0.9996
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g2_B03-T01.tiff: 0.9996
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_D09-T01.tiff: 0.9997
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_F11-T01.tiff: 0.9997
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E03-T01.tiff: 0.9997
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_D07-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_G11-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_C09-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_E11-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g5_E05-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_B11-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E06-T01.tiff: 0.9998
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_C10-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_B11-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_B10-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_B11-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_C11-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_C07-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_D11-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_C10-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_G07-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_F09-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_D07-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_G08-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g5_E04-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_D11-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_F09-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_D09-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_C09-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_F08-T01.tiff: 0.9999
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds62_g2_B04-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_E08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_E10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_F10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_E07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_E07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_G10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_G11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_D09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_G08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_E10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds41_g5_E06-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_F10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_G09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_D09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_F08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_F07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds42_g5_E05-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_F11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_C11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_C11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_E09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_C07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_F07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_F10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_G10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds62_g2_B02-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_F09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_G09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_C09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_C08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_F11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_E11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_E07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_G07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_G08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_C07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_D11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_D08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_G10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds62_g2_B03-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_G07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_G09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_B08-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_D07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_E11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_D10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_B07-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_B09-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_B10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_G11-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_C10-T01.tiff: 1.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_E09-T01.tiff: 1.0000

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 10/10 [00:07<00:00,  1.39it/s]

# %%
all_images_data = []
for grp in groups:
    # each entry is [p_control, p_treated, img_path]
    all_images_data.extend(groups_data[grp])

# Sort by p(treated) in ascending order
all_images_data.sort(key=lambda x: x[1])  # No reverse=True

# Now all_images_data is sorted by p(treated) in ascending order
sorted_by_treated = [(entry[2], entry[1]) for entry in all_images_data]

print("Images sorted by p(treated) in ascending order:")
for img_path, p_tr in sorted_by_treated:
    print(f"{img_path}: {p_tr:.4f}")
# Out:
# Images sorted by p(treated) in ascending order:
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D10-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C07-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B03-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D08-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F11-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B09-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F06-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B05-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D04-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D02-T01.tiff: 0.0000
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G06-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G08-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D06-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F10-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F04-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_B11-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E05-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_F02-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C11-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E04-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F11-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F04-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C04-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E09-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C06-T01.tiff: 0.0001
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C10-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B03-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C08-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C09-T01.tiff: 0.0002
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D10-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C03-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E09-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_D05-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E02-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B02-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C03-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E06-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_F09-T01.tiff: 0.0003
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G10-T01.tiff: 0.0004
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G11-T01.tiff: 0.0004
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_G04-T01.tiff: 0.0004
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_C10-T01.tiff: 0.0004
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_E06-T01.tiff: 0.0005
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_B11-T01.tiff: 0.0005
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_C02-T01.tiff: 0.0005
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_D05-T01.tiff: 0.0005
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_E08-T01.tiff: 0.0009
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBT_01.04_Day7_G03-T01.tiff: 0.0016
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C8.tif: 0.0018
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B08-T01.tiff: 0.0026
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C7.tif: 0.0034
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B07-T01.tiff: 0.0050
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C11.tif: 0.0087
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C02-T01.tiff: 0.0088
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B11-T01.tiff: 0.0120
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_C9.tif: 0.0129
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F06-T01.tiff: 0.0174
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C06-T01.tiff: 0.0193
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C05-T01.tiff: 0.0322
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C03-T01.tiff: 0.0328
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds1B_g9_c10.tif: 0.0329
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F04-T01.tiff: 0.0379
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B10-T01.tiff: 0.0594
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F03-T01.tiff: 0.0605
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g3_C04-T01.tiff: 0.0642
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F02-T01.tiff: 0.0676
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B10-T01.tiff: 0.0948
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C08-T01.tiff: 0.1116
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C07-T01.tiff: 0.1198
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C11-T01.tiff: 0.1593
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B11-T01.tiff: 0.2031
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C08-T01.tiff: 0.2458
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C04-T01.tiff: 0.3437
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g6_F05-T01.tiff: 0.4007
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C09-T01.tiff: 0.4838
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B09-T01.tiff: 0.5151
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g8_B07-T01.tiff: 0.5228
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C10-T01.tiff: 0.5816
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g8_B09-T01.tiff: 0.6152
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g9_C10-T01.tiff: 0.6521
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C03-T01.tiff: 0.6737
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C11-T01.tiff: 0.7863
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C06-T01.tiff: 0.7894
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C02-T01.tiff: 0.7927
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds61_g3_C05-T01.tiff: 0.8017
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C09-T01.tiff: 0.9155
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds62_g9_C07-T01.tiff: 0.9160
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\exploded_all\ds41_g9_C10-T01.tiff: 0.9873

# %% [markdown]
# # Inference

# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
from torchvision import transforms

import tifffile as tiff
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
import random
#from helper import set_seed

# %%
# Logistic Regression model definition
class LogisticRegression(nn.Module):
    def __init__(self, feature_dim, num_classes):
        super(LogisticRegression, self).__init__()
        self.linear = nn.Linear(feature_dim, num_classes)

    def forward(self, x):
        return self.linear(x)

# %% [markdown]
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# # Recreate the model structure
# feature_dim = 512 # Set this to the same dimension used during training
# num_classes = 2   # Since you trained for 2 classes
# logreg_model = LogisticRegression(feature_dim, num_classes).to(device)
#
# # Load the saved weights
# logreg_model.load_state_dict(torch.load("best_loss_model.pth", map_location=device))
# logreg_model.eval()

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features:   0%|          | 0/16 [00:00<?, ?it/s]
# Extracting Features: 100%|██████████| 16/16 [00:11<00:00,  1.44it/s]

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 18/18 [00:13<00:00,  1.38it/s]

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 30/30 [00:21<00:00,  1.42it/s]

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 31/31 [00:22<00:00,  1.39it/s]

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import tifffile as tiff
from torchvision import transforms

# Assume simclr_model, logreg_model, device are already defined and loaded.
# simclr_model: the feature extractor model
# logreg_model: the logistic regression model for control vs treated classification.

def get_all_groups(root_dir):
    # All directories in root_dir are considered different groups
    groups = []
    for d in os.listdir(root_dir):
        dir_path = os.path.join(root_dir, d)
        if os.path.isdir(dir_path):
            groups.append(d)
    return groups

def load_inference_data(root_dir):
    groups = get_all_groups(root_dir)
    
    image_files = []
    group_names = []
    
    # We won't use numeric labels for correctness here since our model is only binary.
    # However, we still need a label tensor. We'll just assign a dummy label (e.g. 0) 
    # because we only need to run inference. The label doesn't affect inference.
    dummy_labels = []

    for group in groups:
        class_dir = os.path.join(root_dir, group)
        files = [os.path.join(class_dir, file) for file in os.listdir(class_dir)
                 if file.lower().endswith(('.tiff', '.tif'))]
        image_files.extend(files)
        group_names.extend([group] * len(files))
        dummy_labels.extend([0]*len(files))  # dummy label

    return image_files, dummy_labels, group_names, groups

# Dataset that returns image, a dummy label, path, and keeps track of group name externally
class LabeledImageDatasetWithPath:
    def __init__(self, image_files, labels, transform=None):
        self.image_files = image_files
        self.labels = labels
        self.transform = transform
        self.resize_transform = transforms.Resize((96, 96))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = tiff.imread(img_path)

        # Handle shape: ensure CxHxW
        if image.ndim == 3 and image.shape[2] == 3:
            image = np.transpose(image, (2, 0, 1))
        if image.shape[0] != 3:
            raise ValueError(f"Image {img_path} doesn't have 3 channels.")

        image = image.astype(np.float32) / 65535.0
        image = torch.tensor(image, dtype=torch.float32)
        image = self.resize_transform(image)

        label = self.labels[idx]
        return image, label, img_path

@torch.no_grad()
def extract_features(model, dataloader, device):
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()
    network.eval()
    network.to(device)

    all_features = []
    all_labels = []
    all_paths = []
    for batch_imgs, batch_labels, batch_paths in tqdm(dataloader, desc="Extracting Features"):
        batch_imgs = batch_imgs.to(device)
        batch_feats = network(batch_imgs)
        all_features.append(batch_feats.cpu())
        all_labels.append(batch_labels)
        all_paths.extend(batch_paths)
    all_features = torch.cat(all_features, dim=0)
    all_labels = torch.cat(all_labels, dim=0)
    return all_features, all_labels, all_paths

@torch.no_grad()
def predict_with_probs(model, features, device):
    model.eval()
    features = features.to(device)
    logits = model(features)  # shape: [N, 2]
    probs = F.softmax(logits, dim=1)  # Convert logits to probabilities
    return probs.cpu().numpy()

# --------------------
# MAIN INFERENCE FLOW
# --------------------

root_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference"

# 1. Load data from all groups
image_files, dummy_labels, group_names, groups = load_inference_data(root_dir)

# 2. Create dataset and dataloader for inference
inference_dataset = LabeledImageDatasetWithPath(image_files, dummy_labels)
inference_loader = DataLoader(inference_dataset, batch_size=16, shuffle=False, pin_memory=True, num_workers=0)

# 3. Extract features
inference_feats, inference_true_labels, inference_paths = extract_features(simclr_model, inference_loader, device)

# 4. Get probabilities from logistic regression model
probs = predict_with_probs(logreg_model, inference_feats, device)  # shape [N, 2]
# probs[:, 0] = probability of control
# probs[:, 1] = probability of treated

# Let's store results in a dictionary keyed by group name
# groups_data[group_name] = list of [p_control, p_treated, img_path]
groups_data = {g: [] for g in groups}

# Since group_names aligns with inference_paths and probs, we can pair them up
for p_control, p_treated, grp, path in zip(probs[:,0], probs[:,1], group_names, inference_paths):
    groups_data[grp].append([p_control, p_treated, path])

# Now we have groups_data with each group having a list of probabilities and paths.

# 5. Plot distributions

# Individual distributions per group:
# We'll create subplots dynamically based on how many groups we have.
num_groups = len(groups)
fig, axs = plt.subplots(num_groups, 2, figsize=(10, 4*num_groups))
# axs[i,0] -> p(control) distribution for group i
# axs[i,1] -> p(treated) distribution for group i

if num_groups == 1:
    # If there's only one group, axs is not a 2D array
    axs = np.array([axs])  # make it 2D for consistency

for i, grp in enumerate(groups):
    p_control_list = [item[0] for item in groups_data[grp]]
    p_treated_list = [item[1] for item in groups_data[grp]]

    axs[i, 0].hist(p_control_list, bins=20, alpha=0.7, edgecolor='black')
    axs[i, 0].set_title(f"{grp} Group p(control)")
    axs[i, 0].set_xlabel("Probability")
    axs[i, 0].set_ylabel("Count")

    axs[i, 1].hist(p_treated_list, bins=20, alpha=0.7, edgecolor='black', color='orange')
    axs[i, 1].set_title(f"{grp} Group p(treated)")
    axs[i, 1].set_xlabel("Probability")
    axs[i, 1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# 6. Plot combined distributions
# 6.1: Compare all groups p(control) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_control_list = [item[0] for item in groups_data[grp]]
    plt.hist(p_control_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(control) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# 6.2: Compare all groups p(treated) together
plt.figure(figsize=(10, 5))
for grp in groups:
    p_treated_list = [item[1] for item in groups_data[grp]]
    plt.hist(p_treated_list, bins=20, alpha=0.5, edgecolor='black', label=grp)
plt.title("p(treated) Distribution Across All Groups")
plt.xlabel("Probability")
plt.ylabel("Count")
plt.legend()
plt.show()

# At this point:
# - We've dynamically handled any number of groups in the directory.
# - We plotted individual probability distributions for each group.
# - We also plotted combined distributions comparing all groups together for both p(control) and p(treated).
# Out:
# Extracting Features: 100%|██████████| 18/18 [00:12<00:00,  1.39it/s]

# %% [markdown]
# # descending order

# %% [markdown]
# all_images_data = []
# for grp in groups:
#     # each entry is [p_control, p_treated, img_path]
#     all_images_data.extend(groups_data[grp])
#
# # Sort by p(treated) in descending order (highest p(treated) first)
# all_images_data.sort(key=lambda x: x[1], reverse=True)
#
# # Now all_images_data is sorted by p(treated)
# # Extract (img_path, p_treated)
# sorted_by_treated = [(entry[2], entry[1]) for entry in all_images_data]
#
# # Print or handle as needed
# print("Images sorted by p(treated) in descending order:")
# for img_path, p_tr in sorted_by_treated:
#     print(f"{img_path}: {p_tr:.4f}")

# %%
# ascending order

# %%
all_images_data = []
for grp in groups:
    # each entry is [p_control, p_treated, img_path]
    all_images_data.extend(groups_data[grp])

# Sort by p(treated) in ascending order
all_images_data.sort(key=lambda x: x[1])  # No reverse=True

# Now all_images_data is sorted by p(treated) in ascending order
sorted_by_treated = [(entry[2], entry[1]) for entry in all_images_data]

print("Images sorted by p(treated) in ascending order:")
for img_path, p_tr in sorted_by_treated:
    print(f"{img_path}: {p_tr:.4f}")
# Out:
# Images sorted by p(treated) in ascending order:
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\cond7\RBTDS1B_Day_7_
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_B07-T01.tiff: 0.9994
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.09_Day10_B09-T01.tiff: 0.9995
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.14_Day10_D10-T01.tiff: 0.9995
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.10_Day10_E09-T01.tiff: 0.9996
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\single_dose\sd_RBT_01.04_Day10_G11-T01.tiff: 0.9996
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds62_g2_B02-T01.tiff: 0.9997
# C:\Users\k54739\Bibi_new_thesis\thesis\softmax_dataset\inference\ds_closeto_sd\ds62_g2_B03-T01.tiff: 0.9998

# %%
from copy import deepcopy
import torchvision.transforms.functional as TF

# %%
# Device setup for inference
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def Preprocess_Image(image_path):
    # Load the image
    image = tiff.imread(image_path)
    
    # Ensure the image has 3 layers (channels)
    if image.shape[0] != 3:
        raise ValueError(f"Image at {image_path} does not have exactly 3 layers.")
    
    # Normalize the 16-bit image to [0, 1]
    image = image.astype(np.float32) / 65535.0
    
    # Convert to a torch tensor
    image = torch.tensor(image, dtype=torch.float32)
    
    # Resize to (96, 96)
    image = TF.resize(image, (96, 96))
    
    return image

# %%
path_of_image = r'C:\Users\k54739\Bibi_new_thesis\thesis\Data_supervised\single_dose\B07-T01.tiff'

# %%
first_image = Preprocess_Image(path_of_image)
print(first_image.shape)
prep_first_image = first_image.unsqueeze(0)
print(prep_first_image.shape)
# Out:
# torch.Size([3, 96, 96])
# torch.Size([1, 3, 96, 96])

# %%
first_image_np = first_image.numpy().transpose(1, 2, 0)  # (C, H, W) -> (H, W, C)

# Display the image
plt.figure(figsize=(5, 5))
plt.imshow(first_image_np, cmap='gray')  # Use `cmap='gray'` if it's grayscale
plt.title('First Image')
plt.axis('off')  # Optional: turn off the axis for a cleaner look
plt.show()

# %%
pathimage = r'C:\Users\k54739\Bibi_new_thesis\thesis\Data_supervised\single_dose\B08-T01.tiff'
second_image = Preprocess_Image(pathimage)
print(second_image.shape)
prep_second_image = second_image.unsqueeze(0)
print(prep_second_image.shape)
# Out:
# torch.Size([3, 96, 96])
# torch.Size([1, 3, 96, 96])

# %%
second_image.shape
# Out:
# torch.Size([3, 96, 96])

# %%
second_image_np = second_image.numpy().transpose(1, 2, 0)  # (C, H, W) -> (H, W, C)

# Display the image
plt.figure(figsize=(5, 5))
plt.imshow(second_image_np, cmap='gray')  # Use `cmap='gray'` if it's grayscale
plt.title('second Image')
plt.axis('off')  # Optional: turn off the axis for a cleaner look
plt.show()

# %%
@torch.no_grad()
def extract_features(model, image_tensor):
    # prepare model
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()  # Removing projection head g(.)
    network.eval()
    network.to(device)
    
    # Move image tensor to device
    image_tensor = image_tensor.to(device)
    
    # Extract features
    features = network(image_tensor)
    return features

# %%
print(f"simclr_model: {simclr_model}")
# Out:
# simclr_model: SimCLR(
#   (convnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=512, out_features=20, bias=True)
#     )
#   )
# )

# %%
# Extract features for both images
first_image_feats = extract_features(simclr_model, prep_first_image)
second_image_feats = extract_features(simclr_model, prep_second_image)
print(first_image_feats.shape)
print(second_image_feats.shape)
# Out:
# torch.Size([1, 512])
# torch.Size([1, 512])

# %%
# COSINE FROM NEWDATA CROP VAL&INFER
# Compute cosine similarity between the feature vectors
cosine_similarity = nn.functional.cosine_similarity(first_image_feats, second_image_feats, dim=1)
print(f"Cosine similarity between features: {cosine_similarity.item()}")
# Out:
# Cosine similarity between features: 0.821189820766449

# %%
# COSINE old data crop
cosine_similarity = nn.functional.cosine_similarity(first_image_feats, second_image_feats, dim=1)
print(f"Cosine similarity between features: {cosine_similarity.item()}")
# Out:
# Cosine similarity between features: 0.8204046487808228

# %%
im_path = r'C:\Users\k54739\Bibi_new_thesis\thesis\Data_supervised\untreated\D08-T01.tiff'
untreated_image = Preprocess_Image(im_path)
print(untreated_image.shape)
prep_untreated_image = untreated_image.unsqueeze(0)
print(prep_untreated_image.shape)
# Out:
# torch.Size([3, 96, 96])
# torch.Size([1, 3, 96, 96])

# %%
untreated_image_np = untreated_image.numpy().transpose(1, 2, 0)  # (C, H, W) -> (H, W, C)

# Display the image
plt.figure(figsize=(5, 5))
plt.imshow(untreated_image_np, cmap='gray')  # Use `cmap='gray'` if it's grayscale
plt.title('untreated Image')
plt.axis('off')  # Optional: turn off the axis for a cleaner look
plt.show()

# %%
untreated_image_feats = extract_features(simclr_model, prep_untreated_image)

# %%
# COSINE NEW DATA CROP
cosine_similarity = nn.functional.cosine_similarity(first_image_feats, untreated_image_feats, dim=1)
print(f"Cosine similarity between features: {cosine_similarity.item()}")
# Out:
# Cosine similarity between features: 0.298863023519516

# %%
# cosine old data crop
cosine_similarity = nn.functional.cosine_similarity(first_image_feats, untreated_image_feats, dim=1)
print(f"Cosine similarity between features: {cosine_similarity.item()}")
# Out:
# Cosine similarity between features: 0.19446787238121033

# %% [markdown]
# Inference after projection head

# %%
@torch.no_grad()
def features_after_projection(model, image_tensor):
    # prepare model
    network = deepcopy(model.convnet)
    #network.fc = nn.Identity()  # Removing projection head g(.)
    network.eval()
    network.to(device)
    
    # Move image tensor to device
    image_tensor = image_tensor.to(device)
    
    # Extract features
    features = network(image_tensor)
    return features

# %%
# Extract features for both images
first_image_feats_after = features_after_projection(simclr_model, prep_first_image)
second_image_feats_after = features_after_projection(simclr_model, prep_second_image)
print(first_image_feats_after.shape)
print(second_image_feats_after.shape)
# Out:
# torch.Size([1, 20])
# torch.Size([1, 20])

# %%
# Cosine newdata crop 
cosine_similarity = nn.functional.cosine_similarity(first_image_feats_after, second_image_feats_after, dim=1)
print(f"Cosine similarity between features: {cosine_similarity.item()}")
# Out:
# Cosine similarity between features: 0.55315762758255

# %%
# Cosine old data crop
cosine_similarity = nn.functional.cosine_similarity(first_image_feats_after, second_image_feats_after, dim=1)
print(f"Cosine similarity between features: {cosine_similarity.item()}")

#Cosine similarity between features: 0.8507535457611084

# %% [markdown]
# as expected after projection head cosine similarity is higher this leads to the question that maybe for ranking images with time series, this after projection maybe better option.

# %%
untreated_image_feats_after = features_after_projection(simclr_model, prep_untreated_image)
print(untreated_image_feats_after.shape)
# Out:
# torch.Size([1, 20])

# %%
# Compute cosine similarity between the feature vectors
cosine_similarity = nn.functional.cosine_similarity(first_image_feats_after, untreated_image_feats_after, dim=1)
print(f"Cosine similarity between features: {cosine_similarity.item()}")
# Out:
# Cosine similarity between features: 0.26108598709106445

# %%
# Compute cosine similarity between the feature vectors
cosine_similarity = nn.functional.cosine_similarity(first_image_feats_after, untreated_image_feats_after, dim=1)
print(f"Cosine similarity between features: {cosine_similarity.item()}")
# Out:
# Cosine similarity between features: 0.18768171966075897

# %% [markdown]
# as expected after projection head cosine similarity is lower for different class images this leads to the question that maybe for ranking images with time series, this after projection maybe better option.

# %% [markdown]
# Orig images (without simclr)

# %%
print(first_image)
first_image.view(-1).shape
# Out:
# tensor([[[0.5470, 0.5567, 0.5606,  ..., 0.5938, 0.5943, 0.5934],
#          [0.5529, 0.5582, 0.5605,  ..., 0.5936, 0.5938, 0.5925],
#          [0.5568, 0.5596, 0.5608,  ..., 0.5942, 0.5940, 0.5944],
#          ...,
#          [0.5541, 0.5543, 0.5565,  ..., 0.5892, 0.5886, 0.5892],
#          [0.5542, 0.5552, 0.5562,  ..., 0.5879, 0.5885, 0.5889],
#          [0.5540, 0.5557, 0.5556,  ..., 0.5879, 0.5893, 0.5899]],
#
#         [[0.5493, 0.5567, 0.5601,  ..., 0.5925, 0.5925, 0.5928],
#          [0.5534, 0.5577, 0.5596,  ..., 0.5928, 0.5925, 0.5917],
#          [0.5566, 0.5582, 0.5598,  ..., 0.5935, 0.5934, 0.5935],
#          ...,
#          [0.5527, 0.5535, 0.5554,  ..., 0.5882, 0.5880, 0.5887],
#          [0.5528, 0.5538, 0.5552,  ..., 0.5873, 0.5875, 0.5885],
#          [0.5527, 0.5552, 0.5550,  ..., 0.5877, 0.5885, 0.5891]],
#
#         [[0.5513, 0.5575, 0.5597,  ..., 0.5920, 0.5915, 0.5917],
#          [0.5549, 0.5581, 0.5595,  ..., 0.5924, 0.5924, 0.5921],
#          [0.5574, 0.5582, 0.5601,  ..., 0.5923, 0.5935, 0.5934],
#          ...,
#          [0.5522, 0.5533, 0.5554,  ..., 0.5877, 0.5882, 0.5894],
#          [0.5522, 0.5532, 0.5551,  ..., 0.5869, 0.5875, 0.5885],
#          [0.5520, 0.5536, 0.5543,  ..., 0.5878, 0.5888, 0.5891]]])
# torch.Size([27648])

# %%
print(second_image)
second_image.view(-1).shape
# Out:
# tensor([[[0.5667, 0.5681, 0.5692,  ..., 0.6117, 0.6131, 0.6123],
#          [0.5668, 0.5676, 0.5689,  ..., 0.6129, 0.6132, 0.6120],
#          [0.5672, 0.5673, 0.5695,  ..., 0.6136, 0.6136, 0.6136],
#          ...,
#          [0.5707, 0.5719, 0.5733,  ..., 0.6065, 0.6071, 0.6066],
#          [0.5709, 0.5718, 0.5733,  ..., 0.6054, 0.6066, 0.6055],
#          [0.5712, 0.5710, 0.5731,  ..., 0.6048, 0.6062, 0.6054]],
#
#         [[0.5658, 0.5665, 0.5675,  ..., 0.6108, 0.6114, 0.6110],
#          [0.5656, 0.5661, 0.5677,  ..., 0.6119, 0.6123, 0.6115],
#          [0.5656, 0.5665, 0.5685,  ..., 0.6126, 0.6120, 0.6122],
#          ...,
#          [0.5698, 0.5702, 0.5724,  ..., 0.6060, 0.6059, 0.6056],
#          [0.5689, 0.5699, 0.5719,  ..., 0.6044, 0.6053, 0.6034],
#          [0.5692, 0.5697, 0.5727,  ..., 0.6040, 0.6049, 0.6042]],
#
#         [[0.5648, 0.5659, 0.5666,  ..., 0.6107, 0.6111, 0.6106],
#          [0.5654, 0.5659, 0.5673,  ..., 0.6115, 0.6118, 0.6110],
#          [0.5651, 0.5663, 0.5677,  ..., 0.6125, 0.6118, 0.6117],
#          ...,
#          [0.5689, 0.5697, 0.5724,  ..., 0.6052, 0.6055, 0.6053],
#          [0.5679, 0.5691, 0.5720,  ..., 0.6040, 0.6054, 0.6034],
#          [0.5674, 0.5694, 0.5719,  ..., 0.6045, 0.6049, 0.6036]]])
# torch.Size([27648])

# %%
first_flat = first_image.view(-1)
second_flat = second_image.view(-1)

# %%
first_flat.unsqueeze(0).shape == untreated_flat.unsqueeze(0)
# Out:
# False

# %%
import torch.nn.functional as F
similarity = F.cosine_similarity(first_flat.unsqueeze(0), second_flat.unsqueeze(0))
similarity
# Out:
# tensor([0.9914])

# %%
untreated_flat = untreated_image.view(-1)

# %%
similarity = F.cosine_similarity(first_flat.unsqueeze(0), untreated_flat.unsqueeze(0))
similarity
# Out:
# tensor([0.9834])

# %%
first_flat == untreated_flat
# Out:
# tensor([False, False, False,  ..., False, False, False])

# %% [markdown]
# orig without resizing

# %%
import numpy as np
import tifffile as tiff
from numpy.linalg import norm

# Load and normalize both images
im1 = tiff.imread(r'C:\Users\k54739\Bibi_new_thesis\thesis\Data_supervised\single_dose\B07-T01.tiff')
im2 = tiff.imread(r'C:\Users\k54739\Bibi_new_thesis\thesis\Data_supervised\single_dose\B08-T01.tiff')

# Ensure each image has 3 layers (channels)
if im1.shape[0] != 3 or im2.shape[0] != 3:
    raise ValueError("Each image must have exactly 3 layers.")

# Normalize the 16-bit images to [0, 1]
im1 = im1.astype(np.float32) / 65535.0
im2 = im2.astype(np.float32) / 65535.0
print(im2.shape)

# Flatten the 3D images to 1D vectors
im1_flattened = im1.flatten()
im2_flattened = im2.flatten()
print(im2_flattened.shape)

# Calculate cosine similarity
cosine_similarity = np.dot(im1_flattened, im2_flattened) / (norm(im1_flattened) * norm(im2_flattened))

print(f"Cosine Similarity between the two images: {cosine_similarity}")
# Out:
# (3, 2054, 2456)
# (15133872,)
# Cosine Similarity between the two images: 0.9906225204467773

# %%
im1 = tiff.imread(r'C:\Users\k54739\Bibi_new_thesis\thesis\Data_supervised\single_dose\B07-T01.tiff')
im2 = tiff.imread(r'C:\Users\k54739\Bibi_new_thesis\thesis\Data_supervised\untreated\D08-T01.tiff')

# Ensure each image has 3 layers (channels)
if im1.shape[0] != 3 or im2.shape[0] != 3:
    raise ValueError("Each image must have exactly 3 layers.")

# Normalize the 16-bit images to [0, 1]
im1 = im1.astype(np.float32) / 65535.0
im2 = im2.astype(np.float32) / 65535.0
print(im2.shape)

# Flatten the 3D images to 1D vectors
im1_flattened = im1.flatten()
im2_flattened = im2.flatten()
print(im2_flattened.shape)

# Calculate cosine similarity
cosine_similarity = np.dot(im1_flattened, im2_flattened) / (norm(im1_flattened) * norm(im2_flattened))

print(f"Cosine Similarity between the two images: {cosine_similarity}")
# Out:
# (3, 2054, 2456)
# (15133872,)
# Cosine Similarity between the two images: 0.9821854829788208

# %%
WAS IST DAS?
Mach kein Sinn!
# Out:
#   Cell In[62], line 2
#     Mach Kein Sinn!
#          ^
# SyntaxError: invalid syntax

# %%
img1 = tiff.imread(r'C:\Users\k54739\Bibi_new_thesis\thesis\Data_supervised\single_dose\B07-T01.tiff')
img2 = tiff.imread(r'C:\Users\k54739\Bibi_new_thesis\thesis\Data_supervised\single_dose\B08-T01.tiff')
img3 = tiff.imread(r'C:\Users\k54739\Bibi_new_thesis\thesis\Data_supervised\untreated\D08-T01.tiff')
img1_flattened = img1.flatten()
img2_flattened = img2.flatten()
img3_flattened = img3.flatten()

# %%
cosine_similarity = np.dot(img1_flattened, img2_flattened) / (norm(img1_flattened) * norm(img2_flattened))
print(f"Cosine Similarity between the two images: {cosine_similarity}")
# Out:
# Cosine Similarity between the two images: 3.129988785460241e-12

# %%
cosine_similarity = np.dot(img1_flattened, img3_flattened) / (norm(img1_flattened) * norm(img3_flattened))
print(f"Cosine Similarity between the two images: {cosine_similarity}")
# Out:
# Cosine Similarity between the two images: 1.0155029384685969e-13

# %%
img1
# Out:
# array([[[34168, 35304, 34600, ..., 39241, 39289, 39033],
#         [34168, 35224, 34568, ..., 39225, 38569, 38761],
#         [34280, 34984, 35048, ..., 38249, 38249, 39817],
#         ...,
#         [36792, 35864, 36200, ..., 38009, 36376, 38729],
#         [36889, 36504, 36504, ..., 40025, 38297, 38041],
#         [36280, 37209, 35656, ..., 37753, 37849, 39897]],
#
#        [[36328, 35848, 34584, ..., 39785, 39609, 38585],
#         [35032, 34168, 35944, ..., 39609, 39673, 38201],
#         [36392, 35608, 35112, ..., 36953, 39433, 38585],
#         ...,
#         [35736, 35528, 35240, ..., 39017, 37369, 39017],
#         [35144, 35464, 36937, ..., 38697, 38921, 38569],
#         [35976, 35752, 35928, ..., 39513, 38921, 37897]],
#
#        [[36680, 35688, 36104, ..., 39977, 39001, 38137],
#         [35208, 35848, 35480, ..., 39401, 38681, 37321],
#         [35240, 35272, 34856, ..., 37705, 39673, 38265],
#         ...,
#         [35992, 35560, 34696, ..., 37513, 38393, 38745],
#         [35496, 34392, 35272, ..., 37929, 38825, 38249],
#         [35112, 35800, 36728, ..., 38857, 38681, 38345]]], dtype=uint16)

# %%
img2
# Out:
# array([[[37577, 37369, 36792, ..., 39769, 41050, 39209],
#         [37689, 36440, 36873, ..., 39929, 40105, 39881],
#         [36728, 37337, 36488, ..., 39097, 40521, 40249],
#         ...,
#         [37561, 37577, 37449, ..., 38793, 38137, 40297],
#         [35784, 38121, 37833, ..., 40025, 39689, 39481],
#         [38345, 37065, 38569, ..., 39561, 39497, 39753]],
#
#        [[37321, 37529, 36840, ..., 39881, 39961, 41162],
#         [36440, 37049, 37049, ..., 40089, 39321, 40889],
#         [36056, 36136, 36376, ..., 38713, 40009, 39321],
#         ...,
#         [36873, 37625, 38121, ..., 39065, 38425, 39737],
#         [36889, 37625, 36328, ..., 39929, 39801, 39033],
#         [38233, 37385, 38905, ..., 38953, 38809, 39593]],
#
#        [[36969, 36536, 36536, ..., 41098, 41050, 39577],
#         [36680, 36296, 36728, ..., 40073, 40970, 39929],
#         [36824, 37353, 37241, ..., 39881, 40249, 40697],
#         ...,
#         [37449, 37097, 37145, ..., 39177, 38409, 40233],
#         [37465, 37993, 37865, ..., 39273, 40105, 37993],
#         [36937, 36168, 37161, ..., 38377, 39225, 40489]]], dtype=uint16)

# %%
img3
# Out:
# array([[[46155, 46875, 44570, ..., 46283, 45947, 44842],
#         [46987, 46747, 45995, ..., 47003, 47467, 46251],
#         [45403, 46635, 45915, ..., 45387, 46059, 46059],
#         ...,
#         [45675, 46555, 44666, ..., 45563, 44538, 47003],
#         [46091, 45563, 45851, ..., 47083, 46811, 45435],
#         [45131, 45787, 46475, ..., 45995, 45835, 46795]],
#
#        [[46891, 45819, 45979, ..., 46299, 46683, 46507],
#         [45371, 45675, 46315, ..., 46427, 45403, 45307],
#         [45531, 45307, 45723, ..., 44266, 44858, 45979],
#         ...,
#         [45707, 45627, 45819, ..., 44538, 44922, 46667],
#         [46539, 45611, 45147, ..., 46315, 45755, 45034],
#         [45179, 45659, 45851, ..., 46779, 46411, 46011]],
#
#        [[45531, 46171, 45883, ..., 45915, 45579, 46795],
#         [46363, 47003, 46331, ..., 46507, 44922, 46507],
#         [45531, 45515, 46203, ..., 44554, 45467, 45707],
#         ...,
#         [45707, 44858, 45451, ..., 45131, 45259, 45691],
#         [45787, 47019, 44842, ..., 45819, 45307, 44954],
#         [46459, 46475, 45963, ..., 46139, 45739, 45915]]], dtype=uint16)

# %% [markdown]
# so, if we didn't use simclr and just try to find the cosine similarity between orig images: it doesn't deviate too  much not good.
