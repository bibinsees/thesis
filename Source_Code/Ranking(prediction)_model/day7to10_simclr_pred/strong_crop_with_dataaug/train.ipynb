# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import tifffile as tiff
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
from copy import deepcopy
import random

# %%
# Load the saved day 7 features
loaded_day7_feats = torch.load('combined_cond7.pt')

# Load the saved day 10 features
loaded_day10_feats = torch.load('combined_cond10.pt')

# Verify the shapes
print(f"Loaded Day 7 Features Shape: {loaded_day7_feats.shape}")
print(f"Loaded Day 10 Features Shape: {loaded_day10_feats.shape}")
# Out:
# Loaded Day 7 Features Shape: torch.Size([780, 512])
# Loaded Day 10 Features Shape: torch.Size([780, 512])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_11560\3131424418.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_day7_feats = torch.load('combined_cond7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_11560\3131424418.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_day10_feats = torch.load('combined_cond10.pt')

# %%
train_day7_feats = loaded_day7_feats 
train_day10_feats = loaded_day10_feats

# %%
import matplotlib.pyplot as plt

# Plot histograms for input (X) and target (Y)
plt.figure(figsize=(12, 6))

# Flatten tensors to 1D for easier visualization
train_day7_feats_flat = train_day7_feats.flatten().cpu().numpy()
train_day10_feats_flat = train_day10_feats.flatten().cpu().numpy()

# Input (X) histogram
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_flat, bins=50, color='blue', alpha=0.7, label='Input (X)')
plt.title('Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_flat, bins=50, color='green', alpha=0.7, label='Target (Y)')
plt.title('Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"Input (X): Mean={train_day7_feats.mean():.4f}, Std={train_day7_feats.std():.4f}")
print(f"Target (Y): Mean={train_day10_feats.mean():.4f}, Std={train_day10_feats.std():.4f}")
# Out:
# Input (X): Mean=0.9166, Std=1.1727
# Target (Y): Mean=0.9179, Std=1.2474

# %%
# Min-Max Scaling for Input (X) and Target (Y)
def min_max_scaling(data):
    data_min = data.min()
    data_max = data.max()
    return (data - data_min) / (data_max - data_min), data_min, data_max  # Return scaled data and min/max for inverse scaling

# Apply Min-Max Scaling
train_day7_feats_minmaxed, day7_min, day7_max = min_max_scaling(train_day7_feats)
train_day10_feats_minmaxed, day10_min, day10_max = min_max_scaling(train_day10_feats)

# Print summary to confirm
print("After Min-Max Scaling:")
print(f"Input (X): Min={train_day7_feats_minmaxed.min():.4f}, Max={train_day7_feats_minmaxed.max():.4f}")
print(f"Target (Y): Min={train_day10_feats_minmaxed.min():.4f}, Max={train_day10_feats_minmaxed.max():.4f}")
# Out:
# After Min-Max Scaling:
# Input (X): Min=0.0000, Max=1.0000
# Target (Y): Min=0.0000, Max=1.0000

# %%
import matplotlib.pyplot as plt

# Flatten the tensors for easier visualization
train_day7_feats_minmaxed_flat = train_day7_feats_minmaxed.flatten().cpu().numpy()
train_day10_feats_minmaxed_flat = train_day10_feats_minmaxed.flatten().cpu().numpy()

# Plot histograms
plt.figure(figsize=(12, 6))

# Input (X) histogram after Min-Max scaling
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_minmaxed_flat, bins=50, color='blue', alpha=0.7, label='Min-Max Scaled Input (X)')
plt.title('Min-Max Scaled Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram after Min-Max scaling
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_minmaxed_flat, bins=50, color='green', alpha=0.7, label='Min-Max Scaled Target (Y)')
plt.title('Min-Max Scaled Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

class FeaturePredictor(nn.Module):
    def __init__(self, input_size=512, output_size=512):
        super(FeaturePredictor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16,8),
            nn.ReLU(),
            nn.Linear(8, 16),
            nn.ReLU(),
            nn.Linear(16,32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128,256),
            nn.ReLU(),
            nn.Linear(256, output_size)
        )
    
    def forward(self, x):
        return self.model(x)

# %%
model = FeaturePredictor()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset

# %%
from torch.utils.data import TensorDataset

optimizer_class = torch.optim.Adam

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset
import numpy as np
import torch

# %%
class EarlyStopping:
    def __init__(self, patience=10, delta=0.0):
        """
        Args:
            patience (int): How many epochs to wait after the last validation loss improvement.
            delta (float): Minimum change in the validation loss to qualify as an improvement.
        """
        self.patience = patience
        self.delta = delta
        self.best_loss = None
        self.no_improvement_epochs = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.no_improvement_epochs = 0
        else:
            self.no_improvement_epochs += 1
            if self.no_improvement_epochs >= self.patience:
                self.early_stop = True


def cross_validate_with_early_stopping(
    model_class, dataset, criterion, optimizer_class, num_epochs=50, n_splits=5, patience=10, device='cuda'
):
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    histories = []
    best_models = []

    for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset)):
        print(f"Fold {fold + 1}/{n_splits}")

        # Create subsets for this fold
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        # Create DataLoaders
        train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

        # Initialize the model, optimizer, and early stopping for this fold
        model = model_class().to(device)
        optimizer = optimizer_class(model.parameters(), lr=1e-4)
        early_stopping = EarlyStopping(patience=patience)

        # Training and validation loop
        history = {'train_loss': [], 'val_loss': []}
        for epoch in range(num_epochs):
            # Training phase
            model.train()
            train_loss = 0.0
            for batch_inputs, batch_targets in train_loader:
                batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)

                # Forward pass
                outputs = model(batch_inputs)
                loss = criterion(outputs, batch_targets)
                train_loss += loss.item()

                # Backward pass and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            train_loss /= len(train_loader)
            history['train_loss'].append(train_loss)

            # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for batch_inputs, batch_targets in val_loader:
                    batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)
                    outputs = model(batch_inputs)
                    loss = criterion(outputs, batch_targets)
                    val_loss += loss.item()

            val_loss /= len(val_loader)
            history['val_loss'].append(val_loss)

            print(f"Epoch [{epoch + 1}/{num_epochs}] Fold {fold + 1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

            # Check early stopping
            early_stopping(val_loss)
            if early_stopping.early_stop:
                print(f"Early stopping at epoch {epoch + 1} for fold {fold + 1}")
                break

        # Save the best model for this fold
        best_models.append(model.state_dict())
        histories.append(history)

    return histories, best_models

# %%
# MIN MAX
dataset = TensorDataset(train_day7_feats_minmaxed, train_day10_feats_minmaxed)

cv_histories, best_models = cross_validate_with_early_stopping(
    model_class=FeaturePredictor,
    dataset=dataset,
    criterion=nn.MSELoss(),
    optimizer_class=torch.optim.Adam,
    num_epochs=2000,
    patience=500
)
# Out:
# Fold 1/5
# Epoch [1/2000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0140
# Epoch [2/2000] Fold 1, Train Loss: 0.0128, Val Loss: 0.0117
# Epoch [3/2000] Fold 1, Train Loss: 0.0107, Val Loss: 0.0098
# Epoch [4/2000] Fold 1, Train Loss: 0.0091, Val Loss: 0.0086
# Epoch [5/2000] Fold 1, Train Loss: 0.0083, Val Loss: 0.0082
# Epoch [6/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0081
# Epoch [7/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0081
# Epoch [8/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [9/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [10/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [11/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0081
# Epoch [12/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [13/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [14/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [15/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [16/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [17/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [18/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [19/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [20/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [21/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [22/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [23/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [24/2000] Fold 1, Train Loss: 0.0079, Val Loss: 0.0079
# Epoch [25/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0078
# Epoch [26/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0072
# Epoch [27/2000] Fold 1, Train Loss: 0.0070, Val Loss: 0.0066
# Epoch [28/2000] Fold 1, Train Loss: 0.0066, Val Loss: 0.0064
2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0051
# Epoch [369/2000] Fold 1, Train Loss: 0.0035, Val Loss: 0.0053
# Epoch [370/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [371/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [372/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [373/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [374/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [375/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [376/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [377/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [378/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [379/2000] Fold 1, Train Loss: 0.0035, Val Loss: 0.0054
# Epoch [380/2000] Fold 1, Train Loss: 0.0035, Val Loss: 0.0051
# Epoch [381/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [382/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [383/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [384/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [385/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [386/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [387/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [388/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [389/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [390/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [391/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [392/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [393/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [394/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [395/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [396/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [397/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [398/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [399/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0052
# Epoch [400/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0052
# Epoch [401/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [402/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [403/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [404/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [405/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [406/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [407/2000] Fold 1, Train Loss: 0.0036, Val Loss: 0.0055
# Epoch [408/2000] Fold 1, Train Loss: 0.0035, Val Loss: 0.0052
# Epoch [409/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [410/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0052
# Epoch [411/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [412/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0052
# Epoch [413/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [414/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [415/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0052
# Epoch [416/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [417/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0054
# Epoch [418/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [419/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0052
# Epoch [420/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [421/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [422/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0054
# Epoch [423/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [424/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0052
# Epoch [425/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [426/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0052
# Epoch [427/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [428/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [429/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0054
# Epoch [430/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0052
# Epoch [431/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [432/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [433/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0054
# Epoch [434/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [435/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [436/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [437/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [438/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [439/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [440/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [441/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [442/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0055
# Epoch [443/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [444/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0052
# Epoch [445/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [446/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0053
# Epoch [447/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0054
# Epoch [448/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0054
# Epoch [449/2000] Fold 1, Train Loss: 0.0034, Val Loss: 0.0054
# Epoch [450/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0054
# Epoch [451/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [452/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [453/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0052
# Epoch [454/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [455/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [456/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [457/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [458/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [459/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0053
# Epoch [460/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0054
# Epoch [461/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [462/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0054
# Epoch [463/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [464/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [465/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0054
# Epoch [466/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [467/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [468/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [469/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [470/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [471/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [472/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [473/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [474/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [475/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [476/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0054
# Epoch [477/2000] Fold 1, Train Loss: 0.0033, Val Loss: 0.0054
# Epoch [478/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0052
# Epoch [479/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [480/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [481/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0054
# Epoch [482/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [483/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0054
# Epoch [484/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [485/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0054
# Epoch [486/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [487/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0054
# Epoch [488/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [489/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0054
# Epoch [490/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0052
# Epoch [491/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [492/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0052
# Epoch [493/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0052
# Epoch [494/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0054
# Epoch [495/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [496/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0052
# Epoch [497/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0055
# Epoch [498/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [499/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [500/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [501/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0054
# Epoch [502/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.0053
# Epoch [503/2000] Fold 1, Train Loss: 0.0032, Val Loss: 0.
2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1217/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1218/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0047
# Epoch [1219/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0047
# Epoch [1220/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1221/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1222/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1223/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1224/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1225/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1226/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0047
# Epoch [1227/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1228/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1229/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1230/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1231/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1232/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0048
# Epoch [1233/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1234/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1235/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1236/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0048
# Epoch [1237/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1238/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1239/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1240/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1241/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1242/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0047
# Epoch [1243/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0047
# Epoch [1244/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0047
# Epoch [1245/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1246/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1247/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0048
# Epoch [1248/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1249/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0048
# Epoch [1250/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1251/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1252/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1253/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1254/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1255/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1256/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1257/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0048
# Epoch [1258/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0048
# Epoch [1259/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1260/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1261/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0048
# Epoch [1262/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0048
# Epoch [1263/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1264/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1265/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1266/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1267/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1268/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1269/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1270/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0048
# Epoch [1271/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0048
# Epoch [1272/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1273/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1274/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Epoch [1275/2000] Fold 5, Train Loss: 0.0027, Val Loss: 0.0047
# Early stopping at epoch 1275 for fold 5

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.0051

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.0048
#   Corresponding Training Loss = 0.0043
#   Best Epoch = 150
# Fold 2:
#   Best Validation Loss = 0.0047
#   Corresponding Training Loss = 0.0037
#   Best Epoch = 293
# Fold 3:
#   Best Validation Loss = 0.0049
#   Corresponding Training Loss = 0.0040
#   Best Epoch = 184
# Fold 4:
#   Best Validation Loss = 0.0046
#   Corresponding Training Loss = 0.0032
#   Best Epoch = 749
# Fold 5:
#   Best Validation Loss = 0.0043
#   Corresponding Training Loss = 0.0030
#   Best Epoch = 775

# %%
import torch

# Save each fold's best model to the current directory
for i, model_state in enumerate(best_models):
    save_path = f'best_model_fold_{i+1}.pth'  # Save in the current directory
    torch.save(model_state, save_path)

print("Models saved to the current directory.")
# Out:
# Models saved to the current directory.

# %%
def plot_loss_curves_separately(cv_histories):
    """
    Plot training and validation loss curves for each fold in separate figures.
    
    Args:
        cv_histories (list): List of loss histories for each fold.
    """
    # Plot Training Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['train_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
    plt.title('Training Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['val_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
    plt.title('Validation Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_loss_curves_separately(cv_histories)
