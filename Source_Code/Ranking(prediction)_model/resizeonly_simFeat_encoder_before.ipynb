# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import tifffile as tiff
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
from copy import deepcopy
import random


from collections import Counter
from scipy.stats import mode

# %%
# Set seed for reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set seed
set_seed(42)

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
full_model_path =  r'C:\Users\k54739\saved_model\simclr_modelepoch250.pth'

# %%
class SimCLR(nn.Module):
    def __init__(self, hidden_dim, lr, temperature, weight_decay):
        super().__init__()
        self.temperature = temperature
        
        # Load the pretrained ResNet-18 model
        self.convnet = torchvision.models.resnet18(weights='ResNet18_Weights.DEFAULT')
        
        # Modify the fully connected layer
        self.convnet.fc = nn.Sequential(
            nn.Linear(self.convnet.fc.in_features, 4 * hidden_dim),  # Linear layer with 4*hidden_dim output
            nn.ReLU(inplace=True),
            nn.Linear(4 * hidden_dim, 20)  # Output layer with hidden_dim output
        )

        self.optimizer = optim.AdamW(self.parameters(), lr=lr, weight_decay=weight_decay)
        self.lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(self.optimizer, T_max=50, eta_min=lr / 50)

    def forward(self, x):
        return self.convnet(x)

    def info_nce_loss(self, imgs1, imgs2, device):

        imgs = torch.cat((imgs1, imgs2), dim=0)  # Concatenate along the batch dimension
        imgs = imgs.to(device)  # Move images to the device

        # Encode all images
        feats = self.forward(imgs)
    
        # Calculate cosine similarity
        cos_sim = nn.functional.cosine_similarity(feats[:, None, :], feats[None, :, :], dim=-1)
    
        # Mask out cosine similarity to itself
        self_mask = torch.eye(cos_sim.shape[0], dtype=torch.bool, device=cos_sim.device)
        cos_sim.masked_fill_(self_mask, -9e15)
    
        # Find positive example -> batch_size//2 away from the original example
        pos_mask = self_mask.roll(shifts=cos_sim.shape[0] // 2, dims=0)
    
        # Normalize similarity scores by temperature
        cos_sim = cos_sim / self.temperature

        # InfoNCE loss
        nll = -cos_sim[pos_mask] + torch.logsumexp(cos_sim, dim=-1)
        nll = nll.mean()

        # Accuracy calculations
        # Create a combination of positive and negative similarities for ranking
        comb_sim = torch.cat([cos_sim[pos_mask][:, None],  # Positive example in first position
                          cos_sim.masked_fill(pos_mask, -9e15)], dim=-1)
    
        # Sort and get the ranking position of the positive example
        sim_argsort = comb_sim.argsort(dim=-1, descending=True).argmin(dim=-1)
    
        # Compute accuracy metrics
        top1_acc = (sim_argsort == 0).float().mean()  # Top-1 accuracy
        top5_acc = (sim_argsort < 5).float().mean()   # Top-5 accuracy
        mean_pos = 1 + sim_argsort.float().mean()     # Mean position of the positive example

        return nll, top1_acc, top5_acc, mean_pos

    def train_epoch(self, train_loader, device):
        self.train()
        total_loss = 0.0
        total_top1_acc = 0.0
        total_top5_acc = 0.0
        total_mean_pos = 0.0

        for batch in tqdm(train_loader, desc="Training", leave=False):
            imgs1, imgs2, _ = batch
            imgs1, imgs2 = imgs1.to(device), imgs2.to(device)  # Move data to device
        
            self.optimizer.zero_grad()

            # Calculate loss and accuracy metrics
            loss, top1_acc, top5_acc, mean_pos = self.info_nce_loss(imgs1, imgs2, device)

            loss.backward()
            self.optimizer.step()
            self.lr_scheduler.step()

            # Accumulate metrics
            total_loss += loss.item()
            total_top1_acc += top1_acc.item()
            total_top5_acc += top5_acc.item()
            total_mean_pos += mean_pos.item()

        avg_loss = total_loss / len(train_loader)
        avg_top1_acc = total_top1_acc / len(train_loader)
        avg_top5_acc = total_top5_acc / len(train_loader)
        avg_mean_pos = total_mean_pos / len(train_loader)

        return avg_loss, avg_top1_acc, avg_top5_acc, avg_mean_pos

    def validate_epoch(self, val_loader, device):
        self.eval()
        total_loss = 0.0
        total_top1_acc = 0.0
        total_top5_acc = 0.0
        total_mean_pos = 0.0

        with torch.no_grad():
            for batch in tqdm(val_loader, desc="Validating", leave=False):
                imgs1, imgs2, _ = batch
                imgs1, imgs2 = imgs1.to(device), imgs2.to(device)  # Move data to device

                # Calculate loss and accuracy metrics
                loss, top1_acc, top5_acc, mean_pos = self.info_nce_loss(imgs1, imgs2, device)

                # Accumulate metrics
                total_loss += loss.item()
                total_top1_acc += top1_acc.item()
                total_top5_acc += top5_acc.item()
                total_mean_pos += mean_pos.item()

        avg_loss = total_loss / len(val_loader)
        avg_top1_acc = total_top1_acc / len(val_loader)
        avg_top5_acc = total_top5_acc / len(val_loader)
        avg_mean_pos = total_mean_pos / len(val_loader)

        return avg_loss, avg_top1_acc, avg_top5_acc, avg_mean_pos

# %%
# Device setup for inference
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
simclr_model = torch.load(full_model_path)
simclr_model.to(device)
simclr_model.eval()
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_22924\1117632957.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   simclr_model = torch.load(full_model_path)
# SimCLR(
#   (convnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=512, out_features=20, bias=True)
#     )
#   )
# )

# %%
from torchvision.transforms import Resize

# %% [markdown]
# # Simclr feature Encoder-decoder

# %%
class ImageDataset(Dataset):
    def __init__(self, day7_dir, day10_dir):
        self.day7_files = {os.path.basename(file): os.path.join(day7_dir, file) for file in os.listdir(day7_dir) if file.endswith('.tiff')}
        self.day10_files = {os.path.basename(file): os.path.join(day10_dir, file) for file in os.listdir(day10_dir) if file.endswith('.tiff')}
      
        # Ensure all day7 files have a corresponding day10 file
        self.common_files = list(self.day7_files.keys())
        assert set(self.common_files) <= set(self.day10_files.keys()), "Mismatch between day7 and day10 filenames."
        self.resize = Resize((96, 96))
       

    def __len__(self):
        return len(self.common_files)

    def __getitem__(self, idx):
        filename = self.common_files[idx]
        day7_img_path = self.day7_files[filename]
        day10_img_path = self.day10_files[filename]

        # Load the images
        day7_img = tiff.imread(day7_img_path)
        day10_img = tiff.imread(day10_img_path)

        # Ensure the images have 3 layers (channels)
        if day7_img.shape[0] != 3:
            raise ValueError(f"Day7 image at {day7_img_path} does not have exactly 3 layers. Found shape: {day7_img.shape}.")
        if day10_img.shape[0] != 3:
            raise ValueError(f"Day10 image at {day10_img_path} does not have exactly 3 layers. Found shape: {day10_img.shape}.")

        # Normalize and convert both images
        day7_img = day7_img.astype(np.float32) / 65535.0
        day10_img = day10_img.astype(np.float32) / 65535.0

        # Convert to tensors
        day7_img = torch.tensor(day7_img, dtype=torch.float32)
        day10_img = torch.tensor(day10_img, dtype=torch.float32)

        day7_img = self.resize(day7_img)
        day10_img = self.resize(day10_img)

        return day7_img, day10_img
        #return day7_img, day10_img,day7_img_path,day10_img_path

    
# Specify paths for both day7 and day10 folders
train_day7_dir = r'C:\Users\k54739\Bibi_new_thesis\thesis\day7_day10\sd_ds\single_dose\RBT 01.04_gant61\Before (untreated) Day7\GANT61'
train_day10_dir = r'C:\Users\k54739\Bibi_new_thesis\thesis\day7_day10\sd_ds\single_dose\RBT 01.04_gant61\After Day10\GANT61'


# Create the dataset
train_dataset = ImageDataset(train_day7_dir, train_day10_dir)

# %%
batch_size = 16
# Define DataLoaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=False, pin_memory=True, num_workers=0) #num_workers=os.cpu count() using cluster gpu

# %%
# Calculate the total number of images in the training dataset
total_images_in_train = len(train_loader.dataset)
print(f"Total number of images: {total_images_in_train}")
# Out:
# Total number of images: 29

# %%
# Print the shape of both pairs and total number of images in one epoch
for i, (input_image, target_image) in enumerate(train_loader):
    print(f"Batch {i}:")
    print(f"  Input image (day7): {input_image.shape}")
    print(f"  Target image (day10): {target_image.shape}")
    break
# Out:
# Batch 0:
#   Input image (day7): torch.Size([16, 3, 96, 96])
#   Target image (day10): torch.Size([16, 3, 96, 96])

# %% [markdown]
# # Retrieve one dataset sample
# day7_img, day10_img, day7_img_path, day10_img_path = train_dataset[2]
#
# # Convert tensors to numpy arrays for visualization
# day7_img_np = day7_img.permute(1, 2, 0).numpy()
# day10_img_np = day10_img.permute(1, 2, 0).numpy()
#
# # Display images with paths
# plt.figure(figsize=(12, 8))
#
# # Day7 Original
# plt.subplot(2, 2, 1)
# plt.imshow(day7_img_np)
# plt.title(f"Day7 Original\n{day7_img_path}")
# plt.axis("off")
#
#
# # Day10 Original
# plt.subplot(2, 2, 3)
# plt.imshow(day10_img_np)
# plt.title(f"Day10 Original\n{day10_img_path}")
# plt.axis("off")
#
#
# plt.tight_layout()
# plt.show()

# %% [markdown]
# # Retrieve one dataset sample
# day7_img, day10_img, day7_img_path, day10_img_path = val_dataset[2]
#
# # Convert tensors to numpy arrays for visualization
# day7_img_np = day7_img.permute(1, 2, 0).numpy()
# day10_img_np = day10_img.permute(1, 2, 0).numpy()
#
# # Display images with paths
# plt.figure(figsize=(12, 8))
#
# # Day7 Original
# plt.subplot(2, 2, 1)
# plt.imshow(day7_img_np)
# plt.title(f"Day7 Original\n{day7_img_path}")
# plt.axis("off")
#
#
# # Day10 Original
# plt.subplot(2, 2, 3)
# plt.imshow(day10_img_np)
# plt.title(f"Day10 Original\n{day10_img_path}")
# plt.axis("off")
#
#
# plt.tight_layout()
# plt.show()

# %% [markdown]
# class ImageDataset(Dataset):
#     def __init__(self, image_dir):
#         self.image_dir = image_dir
#
#         # Recursively find all .tiff and .tif files in subdirectories
#         self.image_files = []
#         for root, _, files in os.walk(image_dir):
#             for file in files:
#                 if file.lower().endswith(('.tiff', '.tif')):
#                     self.image_files.append(os.path.join(root, file))
#
#         # Debugging: Print the number of images found
#         print(f"Found {len(self.image_files)} image files in directory: {image_dir}")
#         self.resize_transform = transforms.Resize((96, 96))
#
#     def __len__(self):
#         return len(self.image_files)
#
#     def __getitem__(self, idx):
#         img_path = self.image_files[idx]
#         image = tiff.imread(img_path)
#
#         # Ensure the image has 3 layers (channels)
#         if image.shape[0] != 3:
#             raise ValueError(f"Image {img_path} does not have exactly 3 layers.")
#
#         # Normalize the 16-bit image to [0, 1]
#         image = image.astype(np.float32) / 65535.0
#
#         # Convert to a torch tensor
#         image = torch.tensor(image, dtype=torch.float32)
#
#         # Apply resize transform
#         image = self.resize_transform(image)
#
#         return image
#
#
# # Directories for labeled data
# image_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\control_day7_day10"
# dataset = ImageDataset(image_dir=image_dir)
#
# # Define DataLoaders
# batch_size = 16
# train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=False, pin_memory=True, num_workers=0)

# %%
@torch.no_grad()
def prepare_data_features(model, dataloader):
    # Prepare model
    network = deepcopy(model.convnet)
    network.fc = nn.Identity()  # Removing projection head g(.)
    network.eval()
    network.to(device)

    # Encode all paired images
    day7_feats = []
    day10_feats = []
    
    for batch_day7_imgs, batch_day10_imgs in tqdm(dataloader):
        # Move images to the device
        batch_day7_imgs = batch_day7_imgs.to(device)
        batch_day10_imgs = batch_day10_imgs.to(device)

        # Extract features for day7 and day10 images
        batch_day7_feats = network(batch_day7_imgs)
        batch_day10_feats = network(batch_day10_imgs)

        print(f"Day 7 Batch features shape: {batch_day7_feats.shape}")
        print(f"Day 10 Batch features shape: {batch_day10_feats.shape}")

        # Collect features
        day7_feats.append(batch_day7_feats.detach().cpu())
        day10_feats.append(batch_day10_feats.detach().cpu())

    # Concatenate features
    day7_feats = torch.cat(day7_feats, dim=0)
    day10_feats = torch.cat(day10_feats, dim=0)

    print(f"Day 7 Features shape after concatenation: {day7_feats.shape}")
    print(f"Day 10 Features shape after concatenation: {day10_feats.shape}")

    return day7_feats, day10_feats

# %%
# Assuming you have a pre-trained model and DataLoader
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Extract features from the training dataset
sd_day7, sd_day10 = prepare_data_features(simclr_model, train_loader)


# Use the extracted features for your MLP model training
# Example: MLP(input_dim=train_day7_feats.shape[1], output_dim=train_day10_feats.shape[1])
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:01<00:01,  1.78s/it]
# Day 7 Batch features shape: torch.Size([16, 512])
# Day 10 Batch features shape: torch.Size([16, 512])
# 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
# Day 7 Batch features shape: torch.Size([13, 512])
# Day 10 Batch features shape: torch.Size([13, 512])
# Day 7 Features shape after concatenation: torch.Size([29, 512])
# Day 10 Features shape after concatenation: torch.Size([29, 512])

# %%
save_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\Source_Code\Ranking(prediction)_model\resizeonly_feats"

torch.save(sd_day7, os.path.join(save_dir, 'sd_day7.pt'))
torch.save(sd_day10, os.path.join(save_dir, 'sd_day10.pt'))

print("Features saved successfully!")
# Out:
# Features saved successfully!

# %% [markdown]
# # Save training features
# torch.save(train_day7_feats, 'train_day7_feats.pt')
# torch.save(train_day10_feats, 'train_day10_feats.pt')
#
# print("Features saved successfully!")

# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision

# %%
# Load training features
exploded40_day7 = torch.load('exploded40_day7.pt')
exploded40_day10 = torch.load('exploded40_day10.pt')
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_5728\2674064639.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   exploded40_day7 = torch.load('exploded40_day7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_5728\2674064639.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   exploded40_day10 = torch.load('exploded40_day10.pt')

# %%
# Print lengths of feature tensors
print(f"Number of training Day 7 features: {len(exploded40_day7)}")
print(f"Number of training Day 10 features: {len(exploded40_day10)}")
# Out:
# Number of training Day 7 features: 40
# Number of training Day 10 features: 40

# %%
# Print shapes of feature tensors
print(f"Shape of training Day 7 features: {exploded40_day7.shape}")
print(f"Shape of training Day 10 features: {exploded40_day10.shape}")
# Out:
# Shape of training Day 7 features: torch.Size([40, 512])
# Shape of training Day 10 features: torch.Size([40, 512])

# %%
import matplotlib.pyplot as plt

# Plot histograms for input (X) and target (Y)
plt.figure(figsize=(12, 6))

# Flatten tensors to 1D for easier visualization
exploded40_day7_flat = exploded40_day7.flatten().cpu().numpy()
exploded40_day10_flat = exploded40_day10.flatten().cpu().numpy()

# Input (X) histogram
plt.subplot(1, 2, 1)
plt.hist(exploded40_day7_flat, bins=50, color='blue', alpha=0.7, label='Input (X)')
plt.title('Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram
plt.subplot(1, 2, 2)
plt.hist(exploded40_day10_flat, bins=50, color='green', alpha=0.7, label='Target (Y)')
plt.title('Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"Input (X): Mean={exploded40_day7.mean():.4f}, Std={exploded40_day7.std():.4f}")
print(f"Target (Y): Mean={exploded40_day10.mean():.4f}, Std={exploded40_day10.std():.4f}")
# Out:
# Input (X): Mean=0.9550, Std=1.2049
# Target (Y): Mean=0.8566, Std=1.2297

# %%
# Min-Max Scaling for Input (X) and Target (Y)
def min_max_scaling(data):
    data_min = data.min()
    data_max = data.max()
    return (data - data_min) / (data_max - data_min), data_min, data_max  # Return scaled data and min/max for inverse scaling

# Apply Min-Max Scaling
exploded40_day7_minmaxed, day7_min, day7_max = min_max_scaling(exploded40_day7)
exploded40_day10_minmaxed, day10_min, day10_max = min_max_scaling(exploded40_day10)

# Print summary to confirm
print("After Min-Max Scaling:")
print(f"Input (X): Min={exploded40_day7_minmaxed.min():.4f}, Max={exploded40_day7_minmaxed.max():.4f}")
print(f"Target (Y): Min={exploded40_day10_minmaxed.min():.4f}, Max={exploded40_day10_minmaxed.max():.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5     return (data - data_min) / (data_max - data_min), data_min, data_max  # Return scaled data and min/max for inverse scaling
#       7 # Apply Min-Max Scaling
# ----> 8 exploded40_day7_minmaxed, day7_min, day7_max = min_max_scaling(exploded40_day7)
#       9 exploded40_day10_minmaxed, day10_min, day10_max = min_max_scaling(exploded40_day10)
#      11 # Print summary to confirm
#
# NameError: name 'exploded40_day7' is not defined

# %%
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

class FeaturePredictor(nn.Module):
    def __init__(self, input_size=512, output_size=512):
        super(FeaturePredictor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16,8),
            nn.ReLU(),
            nn.Linear(8, 16),
            nn.ReLU(),
            nn.Linear(16,32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128,256),
            nn.ReLU(),
            nn.Linear(256, output_size)
        )
    
    def forward(self, x):
        return self.model(x)

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Define the directory where models are saved
load_dir = r'C:\Users\k54739\saved_model\ranking\simclr\minmax_scaled'

# Load a specific fold's best model
model = FeaturePredictor()
load_path = os.path.join(load_dir, 'best_model_fold_5.pth')
model.load_state_dict(torch.load(load_path))
model.to(device)
model.eval()

print(f"Loaded model from {load_path}")
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_5728\187304485.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(load_path))
# Loaded model from C:\Users\k54739\saved_model\ranking\simclr\minmax_scaled\best_model_fold_5.pth

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn


with torch.no_grad():
        exploded40_day7_minmaxed = exploded40_day7_minmaxed.to(device)
        exploded40_day10_minmaxed = exploded40_day10_minmaxed.to(device)

        predicted_day10 = model(exploded40_day7_minmaxed)

print(predicted_day10.shape)

# Initialize the MSE loss function
mse_loss_fn = nn.MSELoss(reduction='none')  # 'none' to get element-wise loss

# Compute the per-feature-vector MSE
mse_per_vector = mse_loss_fn(exploded40_day10_minmaxed, predicted_day10).mean(dim=1)  # Mean over feature dimension (512)

# Convert MSE values to a list for plotting
mse_values = mse_per_vector.cpu().numpy()

# Calculate statistics
mean_mse = mse_per_vector.mean().item()
std_mse = mse_per_vector.std().item()
min_mse = mse_per_vector.min().item()
max_mse = mse_per_vector.max().item()


# Plot the distribution of MSE values
plt.figure(figsize=(10, 6))
plt.hist(mse_values, bins=5, alpha=0.7, density=True, label=f"Mean: {mean_mse:.4f}, Std: {std_mse:.4f}")

# Add vertical lines for min and max
plt.axvline(min_mse, color='green', linestyle='--', linewidth=1, label=f"Min: {min_mse:.4f}")
plt.axvline(max_mse, color='red', linestyle='--', linewidth=1, label=f"Max: {max_mse:.4f}")

plt.title('Distribution of MSE Loss for Feature Vectors')
plt.xlabel('MSE')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# torch.Size([40, 512])

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F

# Assume exploded40_day7_minmaxed and exploded40_day10_minmaxed are already loaded and processed
with torch.no_grad():
    exploded40_day7_minmaxed = exploded40_day7_minmaxed.to(device)
    exploded40_day10_minmaxed = exploded40_day10_minmaxed.to(device)

    predicted_day10 = model(exploded40_day7_minmaxed)

print(predicted_day10.shape)

# Initialize the MSE loss function
mse_loss_fn = nn.MSELoss(reduction='none')  # 'none' to get element-wise loss

# Calculate metrics
# MSE loss
mse_per_vector = mse_loss_fn(exploded40_day10_minmaxed, predicted_day10).mean(dim=1)  # Mean over feature dimension (512)
mse_values = mse_per_vector.cpu().numpy()

# Euclidean distance
euclidean_distances = torch.norm(predicted_day10 - exploded40_day10_minmaxed, dim=1, p=2).cpu().numpy()

# Cosine distance (1 - cosine similarity)
cosine_distances = (1 - F.cosine_similarity(predicted_day10, exploded40_day10_minmaxed, dim=1)).cpu().numpy()

# Function to calculate statistics and plot distributions
def plot_distribution(values, title, xlabel, bins=5, color='blue'):
    mean_val = values.mean()
    std_val = values.std()
    min_val = values.min()
    max_val = values.max()
    
    print(f"{title} - Mean: {mean_val:.4f}, Std: {std_val:.4f}, Min: {min_val:.4f}, Max: {max_val:.4f}")
    
    plt.figure(figsize=(10, 6))
    plt.hist(values, bins=bins, alpha=0.7, density=True, label=f"Mean: {mean_val:.4f}, Std: {std_val:.4f}")
    plt.axvline(min_val, color='green', linestyle='--', linewidth=1, label=f"Min: {min_val:.4f}")
    plt.axvline(max_val, color='red', linestyle='--', linewidth=1, label=f"Max: {max_val:.4f}")
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot the distributions
plot_distribution(mse_values, "MSE Loss Distribution", "MSE")
plot_distribution(euclidean_distances, "Euclidean Distance Distribution", "Euclidean Distance")
plot_distribution(cosine_distances, "Cosine Distance Distribution", "Cosine Distance")
# Out:
# torch.Size([40, 512])
# MSE Loss Distribution - Mean: 0.0276, Std: 0.0114, Min: 0.0071, Max: 0.0499
# Euclidean Distance Distribution - Mean: 3.6734, Std: 0.7995, Min: 1.9002, Max: 5.0550
# Cosine Distance Distribution - Mean: 0.4913, Std: 0.1022, Min: 0.1948, Max: 0.6801

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn

# Assume train_day7_feats_minmaxed and train_day10_feats_minmaxed are already loaded
# Example shapes: [130, 512]

# Ensure the tensors are on the same device as the model
exploded40_day7_minmaxed = exploded40_day7_minmaxed.to(device)
exploded40_day10_minmaxed = exploded40_day10_minmaxed.to(device)

# Initialize the MSE loss function
mse_loss_fn = nn.MSELoss()

# List to store MSE for each feature vector
mse_values = []

# Loop through each feature vector
for i in range(exploded40_day7_minmaxed.shape[0]):
    exploded40_day7 = exploded40_day7_minmaxed[i].unsqueeze(0)  # Shape: [1, 512]
    exploded40_day10 = exploded40_day10_minmaxed[i].unsqueeze(0)  # Shape: [1, 512]
    
    # Get prediction
    with torch.no_grad():
        predicted_day10 = model(exploded40_day7)
    
    # Compute MSE for this feature vector
    mse = mse_loss_fn(predicted_day10, exploded40_day10).item()
    mse_values.append(mse)

# Convert MSE values to a tensor for statistical calculations
mse_values_tensor = torch.tensor(mse_values)

# Calculate mean and standard deviation
mean_mse = mse_values_tensor.mean().item()
std_mse = mse_values_tensor.std().item()
min_mse = mse_values_tensor.min().item()
max_mse = mse_values_tensor.max().item()

print(f"Mean MSE: {mean_mse:.4f}, Standard Deviation: {std_mse:.4f}")
print(f"Min MSE: {min_mse:.4f}, Max MSE: {max_mse:.4f}")

# Plot the distribution of MSE values
plt.figure(figsize=(10, 6))
plt.hist(mse_values, bins=5, alpha=0.7, density=True, label=f"Mean: {mean_mse:.4f}, Std: {std_mse:.4f}")

# Add vertical lines for min and max values
plt.axvline(min_mse, color='green', linestyle='--', linewidth=1, label=f"Min: {min_mse:.4f}")
plt.axvline(max_mse, color='red', linestyle='--', linewidth=1, label=f"Max: {max_mse:.4f}")

plt.title('Distribution of MSE Loss for Feature Vectors')
plt.xlabel('MSE')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean MSE: 0.0276, Standard Deviation: 0.0115
# Min MSE: 0.0071, Max MSE: 0.0499

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F

# Assume exploded40_day7_minmaxed and exploded40_day10_minmaxed are already loaded
# Example shapes: [N, 512], where N is the number of feature vectors

# Ensure the tensors are on the same device as the model
exploded40_day7_minmaxed = exploded40_day7_minmaxed.to(device)
exploded40_day10_minmaxed = exploded40_day10_minmaxed.to(device)

# Initialize the MSE loss function
mse_loss_fn = nn.MSELoss()

# Lists to store metrics for each feature vector
mse_values = []
euclidean_distances = []
cosine_distances = []

# Loop through each feature vector
for i in range(exploded40_day7_minmaxed.shape[0]):
    exploded40_day7 = exploded40_day7_minmaxed[i].unsqueeze(0)  # Shape: [1, 512]
    exploded40_day10 = exploded40_day10_minmaxed[i].unsqueeze(0)  # Shape: [1, 512]
    
    # Get prediction
    with torch.no_grad():
        predicted_day10 = model(exploded40_day7)
    
    # Compute MSE for this feature vector
    mse = mse_loss_fn(predicted_day10, exploded40_day10).item()
    mse_values.append(mse)
    
    # Compute Euclidean distance
    euclidean_distance = torch.norm(predicted_day10 - exploded40_day10, p=2).item()
    euclidean_distances.append(euclidean_distance)
    
    # Compute Cosine distance
    cosine_distance = 1 - F.cosine_similarity(predicted_day10, exploded40_day10, dim=1).item()
    cosine_distances.append(cosine_distance)

# Convert metrics to tensors for statistical calculations
mse_values_tensor = torch.tensor(mse_values)
euclidean_distances_tensor = torch.tensor(euclidean_distances)
cosine_distances_tensor = torch.tensor(cosine_distances)

# Function to calculate and plot the distribution
def plot_distribution(values, title, xlabel, bins=5, color='blue'):
    mean_val = values.mean().item()
    std_val = values.std().item()
    min_val = values.min().item()
    max_val = values.max().item()
    
    print(f"{title} - Mean: {mean_val:.4f}, Std: {std_val:.4f}, Min: {min_val:.4f}, Max: {max_val:.4f}")
    
    plt.figure(figsize=(10, 6))
    plt.hist(values.cpu().numpy(), bins=bins, alpha=0.7, density=True, label=f"Mean: {mean_val:.4f}, Std: {std_val:.4f}")
    plt.axvline(min_val, color='green', linestyle='--', linewidth=1, label=f"Min: {min_val:.4f}")
    plt.axvline(max_val, color='red', linestyle='--', linewidth=1, label=f"Max: {max_val:.4f}")
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot the distributions
plot_distribution(mse_values_tensor, "MSE Loss Distribution", "MSE")
plot_distribution(euclidean_distances_tensor, "Euclidean Distance Distribution", "Euclidean Distance")
plot_distribution(cosine_distances_tensor, "Cosine Distance Distribution", "Cosine Distance")
# Out:
# MSE Loss Distribution - Mean: 0.0276, Std: 0.0115, Min: 0.0071, Max: 0.0499
# Euclidean Distance Distribution - Mean: 3.6734, Std: 0.8097, Min: 1.9002, Max: 5.0550
# Cosine Distance Distribution - Mean: 0.4913, Std: 0.1035, Min: 0.1948, Max: 0.6801

# %%
# Load training features
control29_day7 = torch.load('control29_day7.pt')
control29_day10 = torch.load('control29_day10.pt')

# %%
# Print lengths of feature tensors
print(f"Number of training Day 7 features: {len(control29_day7)}")
print(f"Number of training Day 10 features: {len(control29_day10)}")
# Out:
# Number of training Day 7 features: 29
# Number of training Day 10 features: 29

# %%
# Print shapes of feature tensors
print(f"Shape of training Day 7 features: {control29_day7.shape}")
print(f"Shape of training Day 10 features: {control29_day10.shape}")
# Out:
# Shape of training Day 7 features: torch.Size([29, 512])
# Shape of training Day 10 features: torch.Size([29, 512])

# %%
import matplotlib.pyplot as plt

# Plot histograms for input (X) and target (Y)
plt.figure(figsize=(12, 6))

# Flatten tensors to 1D for easier visualization
control29_day7_flat = control29_day7.flatten().cpu().numpy()
control29_day10_flat = control29_day10.flatten().cpu().numpy()

# Input (X) histogram
plt.subplot(1, 2, 1)
plt.hist(control29_day7_flat, bins=50, color='blue', alpha=0.7, label='Input (X)')
plt.title('Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram
plt.subplot(1, 2, 2)
plt.hist(control29_day10_flat, bins=50, color='green', alpha=0.7, label='Target (Y)')
plt.title('Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"Input (X): Mean={control29_day7.mean():.4f}, Std={control29_day7.std():.4f}")
print(f"Target (Y): Mean={control29_day10.mean():.4f}, Std={control29_day10.std():.4f}")
# Out:
# Input (X): Mean=0.8859, Std=1.1473
# Target (Y): Mean=0.9528, Std=1.2515

# %%
# orig distribution

# Single dose
# Input (X): Mean=0.8487, Std=1.1187
# Target (Y): Mean=0.9356, Std=1.2985

# control29
# Input (X): Mean=0.8859, Std=1.1473
# Target (Y): Mean=0.9528, Std=1.2515

# %%
# Min-Max Scaling for Input (X) and Target (Y)
control29_day7_min = control29_day7.min()
control29_day7_max = control29_day7.max()
print(control29_day7_min,control29_day7_max)
train_day7_feats_scaled = (control29_day7 - control29_day7_min) / (control29_day7_max - control29_day7_min)

control29_day10_min = control29_day10.min()
control29_day10_max = control29_day10.max()
print(control29_day10_min,control29_day10_max)
train_day10_feats_scaled = (control29_day10 - control29_day10_min) / (control29_day10_max - control29_day10_min)
# Out:
# tensor(0.) tensor(7.2069)
# tensor(0.) tensor(8.2259)

# %%
# inference sd
# inference_sd_day7_min,inference_sd_day7_max = tensor(0.) tensor(6.5900)
# inference_sd_day10_min,inference_sd_day10_max = tensor(0.) tensor(11.7951)

# %%
# Min-Max Scaling for Input (X) and Target (Y)
def min_max_scaling(data):
    data_min = data.min()
    data_max = data.max()
    return (data - data_min) / (data_max - data_min), data_min, data_max  # Return scaled data and min/max for inverse scaling

# Apply Min-Max Scaling
control29_day7_minmaxed, day7_min, day7_max = min_max_scaling(control29_day7)
control29_day10_minmaxed, day10_min, day10_max = min_max_scaling(control29_day10)

# Print summary to confirm
print("After Min-Max Scaling:")
print(f"Input (X): Min={control29_day7_minmaxed.min():.4f}, Max={control29_day7_minmaxed.max():.4f}")
print(f"Target (Y): Min={control29_day10_minmaxed.min():.4f}, Max={control29_day10_minmaxed.max():.4f}")
# Out:
# After Min-Max Scaling:
# Input (X): Min=0.0000, Max=1.0000
# Target (Y): Min=0.0000, Max=1.0000

# %%
import matplotlib.pyplot as plt

# Flatten the tensors for easier visualization
control29_day7_minmaxed_flat = control29_day7_minmaxed.flatten().cpu().numpy()
control29_day10_minmaxed_flat = control29_day10_minmaxed.flatten().cpu().numpy()

# Plot histograms
plt.figure(figsize=(12, 6))

# Input (X) histogram after Min-Max scaling
plt.subplot(1, 2, 1)
plt.hist(control29_day7_minmaxed_flat, bins=50, color='blue', alpha=0.7, label='Min-Max Scaled Input (X)')
plt.title('Min-Max Scaled Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram after Min-Max scaling
plt.subplot(1, 2, 2)
plt.hist(control29_day10_minmaxed_flat, bins=50, color='green', alpha=0.7, label='Min-Max Scaled Target (Y)')
plt.title('Min-Max Scaled Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from scipy.stats import boxcox
import torch

# Flatten the data and apply Box-Cox (Box-Cox requires positive values)
control29_day7_flat = control29_day7.flatten().cpu().numpy() + 1e-6  # Add small constant to avoid zero
control29_day10_flat = control29_day10.flatten().cpu().numpy() + 1e-6

control29_day7_boxcox, lambda_7 = boxcox(control29_day7_flat)
control29_day10_boxcox, lambda_10 = boxcox(control29_day10_flat)

print(f"Box-Cox Lambda for Input (X): {lambda_7}")
print(f"Box-Cox Lambda for Target (Y): {lambda_10}")
# Out:
# Box-Cox Lambda for Input (X): 0.1493379534526844
# Box-Cox Lambda for Target (Y): 0.12748067757085635

# %%
# Plot histograms after Box-Cox transformation
plt.figure(figsize=(12, 6))

# Input (X)
plt.subplot(1, 2, 1)
plt.hist(control29_day7_boxcox, bins=50, color='blue', alpha=0.7, label='Box-Cox Transformed Input (X)')
plt.title('Box-Cox Transformed Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y)
plt.subplot(1, 2, 2)
plt.hist(control29_day10_boxcox, bins=50, color='green', alpha=0.7, label='Box-Cox Transformed Target (Y)')
plt.title('Box-Cox Transformed Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision

# %%
# Load training features
inference_sd_day7 = torch.load('inference_sd_day7.pt')
inference_sd_day10 = torch.load('inference_sd_day10.pt')
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_8780\414216957.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   inference_sd_day7 = torch.load('inference_sd_day7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_8780\414216957.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   inference_sd_day10 = torch.load('inference_sd_day10.pt')

# %%
inference_sd_day7
# Out:
# tensor([[0.0000, 0.0000, 1.1177,  ..., 4.7554, 0.0000, 1.2192],
#         [1.5634, 0.0768, 0.0073,  ..., 2.1748, 0.9543, 2.6965],
#         [0.3505, 0.1033, 0.0952,  ..., 2.0586, 0.0000, 0.9589],
#         ...,
#         [1.0277, 0.0124, 0.1167,  ..., 3.5348, 0.0294, 2.4753],
#         [0.0000, 0.0000, 0.8155,  ..., 2.2120, 0.0000, 0.0000],
#         [1.7956, 0.0471, 0.0369,  ..., 2.6556, 0.4420, 3.8215]])

# %%
inference_sd_day10
# Out:
# tensor([[2.3463e+00, 0.0000e+00, 0.0000e+00,  ..., 4.3236e-01, 0.0000e+00,
#          7.5951e-01],
#         [1.8805e+00, 8.1934e-01, 4.6434e-02,  ..., 1.2804e-01, 0.0000e+00,
#          3.9649e-01],
#         [0.0000e+00, 1.9232e-01, 7.9683e-01,  ..., 6.2674e-02, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [3.2696e+00, 1.6963e+00, 0.0000e+00,  ..., 1.3728e+00, 3.9278e-03,
#          1.7484e+00],
#         [4.5861e+00, 0.0000e+00, 0.0000e+00,  ..., 1.0434e+00, 0.0000e+00,
#          2.1944e+00],
#         [0.0000e+00, 7.1825e-01, 3.9650e-01,  ..., 1.1747e-01, 0.0000e+00,
#          0.0000e+00]])

# %%
# Print lengths of feature tensors
print(f"Number of training Day 7 features: {len(inference_sd_day7)}")
print(f"Number of training Day 10 features: {len(inference_sd_day10)}")
# Out:
# Number of training Day 7 features: 29
# Number of training Day 10 features: 29

# %%
# Print shapes of feature tensors
print(f"Shape of training Day 7 features: {inference_sd_day7.shape}")
print(f"Shape of training Day 10 features: {inference_sd_day10.shape}")
# Out:
# Shape of training Day 7 features: torch.Size([29, 512])
# Shape of training Day 10 features: torch.Size([29, 512])

# %%
import matplotlib.pyplot as plt

# Plot histograms for input (X) and target (Y)
plt.figure(figsize=(12, 6))

# Flatten tensors to 1D for easier visualization
inference_sd_day7_flat = inference_sd_day7.flatten().cpu().numpy()
inference_sd_day10_flat = inference_sd_day10.flatten().cpu().numpy()

# Input (X) histogram
plt.subplot(1, 2, 1)
plt.hist(inference_sd_day7_flat, bins=50, color='blue', alpha=0.7, label='Input (X)')
plt.title('Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram
plt.subplot(1, 2, 2)
plt.hist(inference_sd_day10_flat, bins=50, color='green', alpha=0.7, label='Target (Y)')
plt.title('Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"Input (X): Mean={inference_sd_day7.mean():.4f}, Std={inference_sd_day7.std():.4f}")
print(f"Target (Y): Mean={inference_sd_day10.mean():.4f}, Std={inference_sd_day10.std():.4f}")
# Out:
# Input (X): Mean=0.8487, Std=1.1187
# Target (Y): Mean=0.9356, Std=1.2985

# %%
# orig distribution

# Single dose
# Input (X): Mean=0.8487, Std=1.1187
# Target (Y): Mean=0.9356, Std=1.2985

# control
# Input (X): Mean=0.9220, Std=1.1895
# Target (Y): Mean=0.9411, Std=1.2415

# %%
# Min-Max Scaling for Input (X) and Target (Y)
inference_sd_day7_min = inference_sd_day7.min()
inference_sd_day7_max = inference_sd_day7.max()
print(inference_sd_day7_min,inference_sd_day7_max)
train_day7_feats_scaled = (inference_sd_day7 - inference_sd_day7_min) / (inference_sd_day7_max - inference_sd_day7_min)

inference_sd_day10_min = inference_sd_day10.min()
inference_sd_day10_max = inference_sd_day10.max()
print(inference_sd_day10_min,inference_sd_day10_max)
train_day10_feats_scaled = (inference_sd_day10 - inference_sd_day10_min) / (inference_sd_day10_max - inference_sd_day10_min)
# Out:
# tensor(0.) tensor(6.5900)
# tensor(0.) tensor(11.7951)

# %%
# inference sd
# inference_sd_day7_min,inference_sd_day7_max = tensor(0.) tensor(6.5900)
# inference_sd_day10_min,inference_sd_day10_max = tensor(0.) tensor(11.7951)

#control

# control_day7_min, control_day7_max  = tensor(0.) tensor(9.1844)
# control_day10_min, control_day10_max = tensor(0.) tensor(9.1225)

# %%
# Min-Max Scaling for Input (X) and Target (Y)
def min_max_scaling(data):
    data_min = data.min()
    data_max = data.max()
    return (data - data_min) / (data_max - data_min), data_min, data_max  # Return scaled data and min/max for inverse scaling

# Apply Min-Max Scaling
inference_sd_day7_minmaxed, day7_min, day7_max = min_max_scaling(inference_sd_day7)
inference_sd_day10_minmaxed, day10_min, day10_max = min_max_scaling(inference_sd_day10)

# Print summary to confirm
print("After Min-Max Scaling:")
print(f"Input (X): Min={inference_sd_day7_minmaxed.min():.4f}, Max={inference_sd_day7_minmaxed.max():.4f}")
print(f"Target (Y): Min={inference_sd_day10_minmaxed.min():.4f}, Max={inference_sd_day10_minmaxed.max():.4f}")
# Out:
# After Min-Max Scaling:
# Input (X): Min=0.0000, Max=1.0000
# Target (Y): Min=0.0000, Max=1.0000

# %%
import matplotlib.pyplot as plt

# Flatten the tensors for easier visualization
inference_sd_day7_minmaxed_flat = inference_sd_day7_minmaxed.flatten().cpu().numpy()
inference_sd_day10_minmaxed_flat = inference_sd_day10_minmaxed.flatten().cpu().numpy()

# Plot histograms
plt.figure(figsize=(12, 6))

# Input (X) histogram after Min-Max scaling
plt.subplot(1, 2, 1)
plt.hist(inference_sd_day7_minmaxed_flat, bins=50, color='blue', alpha=0.7, label='Min-Max Scaled Input (X)')
plt.title('Min-Max Scaled Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram after Min-Max scaling
plt.subplot(1, 2, 2)
plt.hist(inference_sd_day10_minmaxed_flat, bins=50, color='green', alpha=0.7, label='Min-Max Scaled Target (Y)')
plt.title('Min-Max Scaled Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from scipy.stats import boxcox
import torch

# Flatten the data and apply Box-Cox (Box-Cox requires positive values)
inference_sd_day7_flat = inference_sd_day7.flatten().cpu().numpy() + 1e-6  # Add small constant to avoid zero
inference_sd_day10_flat = inference_sd_day10.flatten().cpu().numpy() + 1e-6

inference_sd_day7_boxcox, lambda_7 = boxcox(inference_sd_day7_flat)
inference_sd_day10_boxcox, lambda_10 = boxcox(inference_sd_day10_flat)

print(f"Box-Cox Lambda for Input (X): {lambda_7}")
print(f"Box-Cox Lambda for Target (Y): {lambda_10}")
# Out:
# Box-Cox Lambda for Input (X): 0.12615580108057536
# Box-Cox Lambda for Target (Y): 0.1262638047055569

# %%
# Plot histograms after Box-Cox transformation
plt.figure(figsize=(12, 6))

# Input (X)
plt.subplot(1, 2, 1)
plt.hist(inference_sd_day7_boxcox, bins=50, color='blue', alpha=0.7, label='Box-Cox Transformed Input (X)')
plt.title('Box-Cox Transformed Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y)
plt.subplot(1, 2, 2)
plt.hist(inference_sd_day10_boxcox, bins=50, color='green', alpha=0.7, label='Box-Cox Transformed Target (Y)')
plt.title('Box-Cox Transformed Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # CONTROL

# %%
save_dir = r"C:\Users\k54739\Bibi_new_thesis\thesis\Source_Code\Ranking(prediction)_model\resizeonly_feats"

train_day7_feats = torch.load(os.path.join(save_dir, 'controlall_day7.pt'))
train_day10_feats = torch.load(os.path.join(save_dir, 'controlall_day10.pt'))

# Load training features
#train_day7_feats = torch.load('train_day7_control.pt')
#train_day10_feats = torch.load('train_day10_control.pt')
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_22924\456382596.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_day7_feats = torch.load(os.path.join(save_dir, 'controlall_day7.pt'))
# C:\Users\k54739\AppData\Local\Temp\ipykernel_22924\456382596.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_day10_feats = torch.load(os.path.join(save_dir, 'controlall_day10.pt'))

# %%
train_day7_feats
# Out:
# tensor([[1.4577e+01, 7.0089e-01, 6.5830e-01,  ..., 6.9869e-01, 8.6726e-01,
#          1.1091e+00],
#         [3.0227e-01, 1.4913e+00, 0.0000e+00,  ..., 1.1422e+00, 7.8712e-02,
#          1.2441e-01],
#         [6.0099e-01, 1.7033e+00, 4.4047e-04,  ..., 3.6205e+00, 4.8179e+00,
#          1.0069e+00],
#         ...,
#         [6.4510e-02, 2.1978e+00, 2.7736e-01,  ..., 3.8809e+00, 3.5232e+00,
#          2.1444e+00],
#         [2.9444e-01, 1.3660e+00, 3.2244e+00,  ..., 7.6528e-01, 6.4878e-01,
#          0.0000e+00],
#         [2.6827e+00, 2.3456e+00, 0.0000e+00,  ..., 3.6781e+00, 4.3700e+00,
#          2.6825e+00]])

# %%
train_day10_feats
# Out:
# tensor([[0.4687, 0.0000, 0.4768,  ..., 1.3775, 0.3475, 2.8391],
#         [0.7747, 0.0000, 2.4161,  ..., 1.8863, 0.4188, 4.1295],
#         [0.3203, 0.0207, 0.6915,  ..., 3.4565, 0.0000, 0.0155],
#         ...,
#         [0.5353, 0.0000, 1.6642,  ..., 2.2918, 0.0537, 1.0297],
#         [1.0986, 0.0640, 0.0000,  ..., 0.0124, 0.0651, 0.0000],
#         [0.0000, 0.0000, 0.8671,  ..., 1.0542, 0.0000, 0.2388]])

# %%
# Print lengths of feature tensors
print(f"Number of training Day 7 features: {len(train_day7_feats)}")
print(f"Number of training Day 10 features: {len(train_day10_feats)}")
# Out:
# Number of training Day 7 features: 130
# Number of training Day 10 features: 130

# %%
# Print shapes of feature tensors
print(f"Shape of training Day 7 features: {train_day7_feats.shape}")
print(f"Shape of training Day 10 features: {train_day10_feats.shape}")
# Out:
# Shape of training Day 7 features: torch.Size([130, 512])
# Shape of training Day 10 features: torch.Size([130, 512])

# %%
import matplotlib.pyplot as plt

# Plot histograms for input (X) and target (Y)
plt.figure(figsize=(12, 6))

# Flatten tensors to 1D for easier visualization
train_day7_feats_flat = train_day7_feats.flatten().cpu().numpy()
train_day10_feats_flat = train_day10_feats.flatten().cpu().numpy()

# Input (X) histogram
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_flat, bins=50, color='blue', alpha=0.7, label='Input (X)')
plt.title('Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_flat, bins=50, color='green', alpha=0.7, label='Target (Y)')
plt.title('Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"Input (X): Mean={train_day7_feats.mean():.4f}, Std={train_day7_feats.std():.4f}")
print(f"Target (Y): Mean={train_day10_feats.mean():.4f}, Std={train_day10_feats.std():.4f}")
# Out:
# Input (X): Mean=1.2473, Std=1.5186
# Target (Y): Mean=0.7621, Std=0.9564

# %% [markdown]
# from scipy.stats import boxcox
# import torch
#
# # Flatten the data and apply Box-Cox (Box-Cox requires positive values)
# train_day7_feats_flat = train_day7_feats.flatten().cpu().numpy() + 1e-6  # Add small constant to avoid zero
# train_day10_feats_flat = train_day10_feats.flatten().cpu().numpy() + 1e-6
#
# train_day7_feats_boxcox, lambda_7 = boxcox(train_day7_feats_flat)
# train_day10_feats_boxcox, lambda_10 = boxcox(train_day10_feats_flat)
#
# print(f"Box-Cox Lambda for Input (X): {lambda_7}")
# print(f"Box-Cox Lambda for Target (Y): {lambda_10}")

# %% [markdown]
# # Plot histograms after Box-Cox transformation
# plt.figure(figsize=(12, 6))
#
# # Input (X)
# plt.subplot(1, 2, 1)
# plt.hist(train_day7_feats_boxcox, bins=50, color='blue', alpha=0.7, label='Box-Cox Transformed Input (X)')
# plt.title('Box-Cox Transformed Distribution of Input (X)')
# plt.xlabel('Value')
# plt.ylabel('Frequency')
# plt.legend()
#
# # Target (Y)
# plt.subplot(1, 2, 2)
# plt.hist(train_day10_feats_boxcox, bins=50, color='green', alpha=0.7, label='Box-Cox Transformed Target (Y)')
# plt.title('Box-Cox Transformed Distribution of Target (Y)')
# plt.xlabel('Value')
# plt.ylabel('Frequency')
# plt.legend()
#
# plt.tight_layout()
# plt.show()

# %% [markdown]
# # Log Transformation + Min-Max Scaling
# def log_transform(data):
#     return torch.log(data + 1)  # Add 1 to avoid log(0)
#
# # Apply Log Transformation
# train_day7_feats_log = log_transform(train_day7_feats)
# train_day10_feats_log = log_transform(train_day10_feats)

# %% [markdown]
# import matplotlib.pyplot as plt
#
# # Flatten the tensors for easier visualization
# train_day7_feats_log_flat = train_day7_feats_log.flatten().cpu().numpy()
# train_day10_feats_log_flat = train_day10_feats_log.flatten().cpu().numpy()
#
# # Plot histograms
# plt.figure(figsize=(12, 6))
#
# # Input (X) histogram after log transformation
# plt.subplot(1, 2, 1)
# plt.hist(train_day7_feats_log_flat, bins=50, color='blue', alpha=0.7, label='Log-Transformed Input (X)')
# plt.title('Log-Transformed Distribution of Input (X)')
# plt.xlabel('Value')
# plt.ylabel('Frequency')
# plt.legend()
#
# # Target (Y) histogram after log transformation
# plt.subplot(1, 2, 2)
# plt.hist(train_day10_feats_log_flat, bins=50, color='green', alpha=0.7, label='Log-Transformed Target (Y)')
# plt.title('Log-Transformed Distribution of Target (Y)')
# plt.xlabel('Value')
# plt.ylabel('Frequency')
# plt.legend()
#
# plt.tight_layout()
# plt.show()

# %%
# Min-Max Scaling for Input (X) and Target (Y)
train_day7_feats_min = train_day7_feats.min()
train_day7_feats_max = train_day7_feats.max()
print(train_day7_feats_min,train_day7_feats_max)
train_day7_feats_scaled = (train_day7_feats - train_day7_feats_min) / (train_day7_feats_max - train_day7_feats_min)

train_day10_feats_min = train_day10_feats.min()
train_day10_feats_max = train_day10_feats.max()
print(train_day10_feats_min,train_day10_feats_max)
train_day10_feats_scaled = (train_day10_feats - train_day10_feats_min) / (train_day10_feats_max - train_day10_feats_min)
# Out:
# tensor(0.) tensor(16.8638)
# tensor(0.) tensor(11.3422)

# %%
# Min-Max Scaling for Input (X) and Target (Y)
def min_max_scaling(data):
    data_min = data.min()
    data_max = data.max()
    return (data - data_min) / (data_max - data_min), data_min, data_max  # Return scaled data and min/max for inverse scaling

# Apply Min-Max Scaling
train_day7_feats_minmaxed, day7_min, day7_max = min_max_scaling(train_day7_feats)
train_day10_feats_minmaxed, day10_min, day10_max = min_max_scaling(train_day10_feats)

# Print summary to confirm
print("After Min-Max Scaling:")
print(f"Input (X): Min={train_day7_feats_minmaxed.min():.4f}, Max={train_day7_feats_minmaxed.max():.4f}")
print(f"Target (Y): Min={train_day10_feats_minmaxed.min():.4f}, Max={train_day10_feats_minmaxed.max():.4f}")
# Out:
# After Min-Max Scaling:
# Input (X): Min=0.0000, Max=1.0000
# Target (Y): Min=0.0000, Max=1.0000

# %%
import matplotlib.pyplot as plt

# Flatten the tensors for easier visualization
train_day7_feats_minmaxed_flat = train_day7_feats_minmaxed.flatten().cpu().numpy()
train_day10_feats_minmaxed_flat = train_day10_feats_minmaxed.flatten().cpu().numpy()

# Plot histograms
plt.figure(figsize=(12, 6))

# Input (X) histogram after Min-Max scaling
plt.subplot(1, 2, 1)
plt.hist(train_day7_feats_minmaxed_flat, bins=50, color='blue', alpha=0.7, label='Min-Max Scaled Input (X)')
plt.title('Min-Max Scaled Distribution of Input (X)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

# Target (Y) histogram after Min-Max scaling
plt.subplot(1, 2, 2)
plt.hist(train_day10_feats_minmaxed_flat, bins=50, color='green', alpha=0.7, label='Min-Max Scaled Target (Y)')
plt.title('Min-Max Scaled Distribution of Target (Y)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# import torch.nn as nn
# from torch.utils.data import TensorDataset, DataLoader
#
# class FeaturePredictor(nn.Module):
#     def __init__(self, input_size=512, output_size=512):
#         super(FeaturePredictor, self).__init__()
#         self.model = nn.Sequential(
#             # 512 → 256
#             nn.Linear(input_size, 256),
#             nn.BatchNorm1d(256),  # Batch Normalization
#             nn.ReLU(),
#             nn.Dropout(0.3),  # Dropout with 30% probability
#
#             # 256 → 128
#             nn.Linear(256, 128),
#             nn.BatchNorm1d(128),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 128 → 64
#             nn.Linear(128, 64),
#             nn.BatchNorm1d(64),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 64 → 32
#             nn.Linear(64, 32),
#             nn.BatchNorm1d(32),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 32 → 16
#             nn.Linear(32, 16),
#             nn.BatchNorm1d(16),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 16 → 8
#             nn.Linear(16, 8),
#             nn.BatchNorm1d(8),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 8 → 16
#             nn.Linear(8, 16),
#             nn.BatchNorm1d(16),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 16 → 32
#             nn.Linear(16, 32),
#             nn.BatchNorm1d(32),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 32 → 64
#             nn.Linear(32, 64),
#             nn.BatchNorm1d(64),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 64 → 128
#             nn.Linear(64, 128),
#             nn.BatchNorm1d(128),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 128 → 256
#             nn.Linear(128, 256),
#             nn.BatchNorm1d(256),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 256 → 512
#             nn.Linear(256, output_size),
#             nn.BatchNorm1d(output_size),  # BatchNorm for the output
#             nn.ReLU()
#         )
#
#     def forward(self, x):
#         return self.model(x)

# %% [markdown]
# import torch.nn as nn
#
# class FeaturePredictor(nn.Module):
#     def __init__(self, input_size=512, output_size=512):
#         super(FeaturePredictor, self).__init__()
#         self.model = nn.Sequential(
#             # 512 → 256
#             nn.Linear(input_size, 256),
#             nn.BatchNorm1d(256),  # Batch Normalization
#             nn.ReLU(),
#             nn.Dropout(0.3),  # Dropout with 30% probability
#
#             # 256 → 64
#             nn.Linear(256, 64),
#             nn.BatchNorm1d(64),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 64 → 8
#             nn.Linear(64, 8),
#             nn.BatchNorm1d(8),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 8 → 64
#             nn.Linear(8, 64),
#             nn.BatchNorm1d(64),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 64 → 256
#             nn.Linear(64, 256),
#             nn.BatchNorm1d(256),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#
#             # 256 → 512
#             nn.Linear(256, output_size),
#             nn.BatchNorm1d(output_size),  # Add BatchNorm for the output as well
#             nn.ReLU()
#         )
#
#     def forward(self, x):
#         return self.model(x)

# %%
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

class FeaturePredictor(nn.Module):
    def __init__(self, input_size=512, output_size=512):
        super(FeaturePredictor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16,8),
            nn.ReLU(),
            nn.Linear(8, 16),
            nn.ReLU(),
            nn.Linear(16,32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128,256),
            nn.ReLU(),
            nn.Linear(256, output_size)
        )
    
    def forward(self, x):
        return self.model(x)

# %%
model = FeaturePredictor()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset

# %%
from torch.utils.data import TensorDataset

optimizer_class = torch.optim.Adam

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset
import numpy as np
import torch

# %%
class EarlyStopping:
    def __init__(self, patience=10, delta=0.0):
        """
        Args:
            patience (int): How many epochs to wait after the last validation loss improvement.
            delta (float): Minimum change in the validation loss to qualify as an improvement.
        """
        self.patience = patience
        self.delta = delta
        self.best_loss = None
        self.no_improvement_epochs = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.no_improvement_epochs = 0
        else:
            self.no_improvement_epochs += 1
            if self.no_improvement_epochs >= self.patience:
                self.early_stop = True


def cross_validate_with_early_stopping(
    model_class, dataset, criterion, optimizer_class, num_epochs=50, n_splits=5, patience=10, device='cuda'
):
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    histories = []
    best_models = []

    for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset)):
        print(f"Fold {fold + 1}/{n_splits}")

        # Create subsets for this fold
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        # Create DataLoaders
        train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

        # Initialize the model, optimizer, and early stopping for this fold
        model = model_class().to(device)
        optimizer = optimizer_class(model.parameters(), lr=1e-4)
        early_stopping = EarlyStopping(patience=patience)

        # Training and validation loop
        history = {'train_loss': [], 'val_loss': []}
        for epoch in range(num_epochs):
            # Training phase
            model.train()
            train_loss = 0.0
            for batch_inputs, batch_targets in train_loader:
                batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)

                # Forward pass
                outputs = model(batch_inputs)
                loss = criterion(outputs, batch_targets)
                train_loss += loss.item()

                # Backward pass and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            train_loss /= len(train_loader)
            history['train_loss'].append(train_loss)

            # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for batch_inputs, batch_targets in val_loader:
                    batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)
                    outputs = model(batch_inputs)
                    loss = criterion(outputs, batch_targets)
                    val_loss += loss.item()

            val_loss /= len(val_loader)
            history['val_loss'].append(val_loss)

            print(f"Epoch [{epoch + 1}/{num_epochs}] Fold {fold + 1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

            # Check early stopping
            early_stopping(val_loss)
            if early_stopping.early_stop:
                print(f"Early stopping at epoch {epoch + 1} for fold {fold + 1}")
                break

        # Save the best model for this fold
        best_models.append(model.state_dict())
        histories.append(history)

    return histories, best_models

# %%
# MIN MAX
dataset = TensorDataset(train_day7_feats_minmaxed, train_day10_feats_minmaxed)

cv_histories, best_models = cross_validate_with_early_stopping(
    model_class=FeaturePredictor,
    dataset=dataset,
    criterion=nn.MSELoss(),
    optimizer_class=torch.optim.Adam,
    num_epochs=1500,
    patience=500
)
# Out:
# Fold 1/5
# Epoch [1/1500] Fold 1, Train Loss: 0.0136, Val Loss: 0.0104
# Epoch [2/1500] Fold 1, Train Loss: 0.0132, Val Loss: 0.0100
# Epoch [3/1500] Fold 1, Train Loss: 0.0133, Val Loss: 0.0096
# Epoch [4/1500] Fold 1, Train Loss: 0.0126, Val Loss: 0.0093
# Epoch [5/1500] Fold 1, Train Loss: 0.0131, Val Loss: 0.0089
# Epoch [6/1500] Fold 1, Train Loss: 0.0115, Val Loss: 0.0086
# Epoch [7/1500] Fold 1, Train Loss: 0.0120, Val Loss: 0.0083
# Epoch [8/1500] Fold 1, Train Loss: 0.0116, Val Loss: 0.0080
# Epoch [9/1500] Fold 1, Train Loss: 0.0110, Val Loss: 0.0076
# Epoch [10/1500] Fold 1, Train Loss: 0.0110, Val Loss: 0.0073
# Epoch [11/1500] Fold 1, Train Loss: 0.0103, Val Loss: 0.0070
# Epoch [12/1500] Fold 1, Train Loss: 0.0095, Val Loss: 0.0067
# Epoch [13/1500] Fold 1, Train Loss: 0.0098, Val Loss: 0.0064
# Epoch [14/1500] Fold 1, Train Loss: 0.0092, Val Loss: 0.0061
# Epoch [15/1500] Fold 1, Train Loss: 0.0085, Val Loss: 0.0058
# Epoch [16/1500] Fold 1, Train Loss: 0.0080, Val Loss: 0.0056
# Epoch [17/1500] Fold 1, Train Loss: 0.0081, Val Loss: 0.0054
# Epoch [18/1500] Fold 1, Train Loss: 0.0080, Val Loss: 0.0052
# Epoch [19/1500] Fold 1, Train Loss: 0.0074, Val Loss: 0.0051
# Epoch [20/1500] Fold 1, Train Loss: 0.0077, Val Loss: 0.0049
# Epoch [21/1500] Fold 1, Train Loss: 0.0070, Val Loss: 0.0048
# Epoch [22/1500] Fold 1, Train Loss: 0.0065, Val Loss: 0.0048
# Epoch [23/1500] Fold 1, Train Loss: 0.0069, Val Loss: 0.0047
# Epoch [24/1500] Fold 1, Train Loss: 0.0066, Val Loss: 0.0046
# Epoch [25/1500] Fold 1, Train Loss: 0.0065, Val Loss: 0.0046
# Epoch [26/1500] Fold 1, Train Loss: 0.0067, Val Loss: 0.0045
# Epoch [27/1500] Fold 1, Train Loss: 0.0065, Val Loss: 0.0045
# Epoch [28/1500] Fold 1, Train Loss: 0.0061, Val Loss: 0.0044
# Epoch [29/1500] Fold 1, Train Loss: 0.0070, Val Loss: 0.0044
# Epoch [30/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0044
# Epoch [31/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0044
# Epoch [32/1500] Fold 1, Train Loss: 0.0061, Val Loss: 0.0044
# Epoch [33/1500] Fold 1, Train Loss: 0.0068, Val Loss: 0.0044
# Epoch [34/1500] Fold 1, Train Loss: 0.0061, Val Loss: 0.0044
# Epoch [35/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0044
# Epoch [36/1500] Fold 1, Train Loss: 0.0060, Val Loss: 0.0043
# Epoch [37/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0043
# Epoch [38/1500] Fold 1, Train Loss: 0.0067, Val Loss: 0.0043
# Epoch [39/1500] Fold 1, Train Loss: 0.0060, Val Loss: 0.0043
# Epoch [40/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [41/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0043
# Epoch [42/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [43/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [44/1500] Fold 1, Train Loss: 0.0063, Val Loss: 0.0043
# Epoch [45/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0043
# Epoch [46/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [47/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [48/1500] Fold 1, Train Loss: 0.0068, Val Loss: 0.0043
# Epoch [49/1500] Fold 1, Train Loss: 0.0072, Val Loss: 0.0043
# Epoch [50/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0043
# Epoch [51/1500] Fold 1, Train Loss: 0.0060, Val Loss: 0.0043
# Epoch [52/1500] Fold 1, Train Loss: 0.0063, Val Loss: 0.0044
# Epoch [53/1500] Fold 1, Train Loss: 0.0060, Val Loss: 0.0044
# Epoch [54/1500] Fold 1, Train Loss: 0.0060, Val Loss: 0.0044
# Epoch [55/1500] Fold 1, Train Loss: 0.0065, Val Loss: 0.0044
# Epoch [56/1500] Fold 1, Train Loss: 0.0064, Val Loss: 0.0044
# Epoch [57/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [58/1500] Fold 1, Train Loss: 0.0064, Val Loss: 0.0043
# Epoch [59/1500] Fold 1, Train Loss: 0.0067, Val Loss: 0.0043
# Epoch [60/1500] Fold 1, Train Loss: 0.0071, Val Loss: 0.0044
# Epoch [61/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0044
# Epoch [62/1500] Fold 1, Train Loss: 0.0070, Val Loss: 0.0045
# Epoch [63/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0045
# Epoch [64/1500] Fold 1, Train Loss: 0.0070, Val Loss: 0.0045
# Epoch [65/1500] Fold 1, Train Loss: 0.0060, Val Loss: 0.0045
# Epoch [66/1500] Fold 1, Train Loss: 0.0066, Val Loss: 0.0045
# Epoch [67/1500] Fold 1, Train Loss: 0.0060, Val Loss: 0.0044
# Epoch [68/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0044
# Epoch [69/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [70/1500] Fold 1, Train Loss: 0.0061, Val Loss: 0.0043
# Epoch [71/1500] Fold 1, Train Loss: 0.0061, Val Loss: 0.0043
# Epoch [72/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [73/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0043
# Epoch [74/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0043
# Epoch [75/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0043
# Epoch [76/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0042
# Epoch [77/1500] Fold 1, Train Loss: 0.0066, Val Loss: 0.0042
# Epoch [78/1500] Fold 1, Train Loss: 0.0066, Val Loss: 0.0043
# Epoch [79/1500] Fold 1, Train Loss: 0.0064, Val Loss: 0.0043
# Epoch [80/1500] Fold 1, Train Loss: 0.0061, Val Loss: 0.0043
# Epoch [81/1500] Fold 1, Train Loss: 0.0058, Val Loss: 0.0043
# Epoch [82/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0043
# Epoch [83/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [84/1500] Fold 1, Train Loss: 0.0066, Val Loss: 0.0043
# Epoch [85/1500] Fold 1, Train Loss: 0.0071, Val Loss: 0.0043
# Epoch [86/1500] Fold 1, Train Loss: 0.0060, Val Loss: 0.0043
# Epoch [87/1500] Fold 1, Train Loss: 0.0060, Val Loss: 0.0043
# Epoch [88/1500] Fold 1, Train Loss: 0.0064, Val Loss: 0.0043
# Epoch [89/1500] Fold 1, Train Loss: 0.0071, Val Loss: 0.0043
# Epoch [90/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [91/1500] Fold 1, Train Loss: 0.0063, Val Loss: 0.0043
# Epoch [92/1500] Fold 1, Train Loss: 0.0061, Val Loss: 0.0044
# Epoch [93/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [94/1500] Fold 1, Train Loss: 0.0069, Val Loss: 0.0043
# Epoch [95/1500] Fold 1, Train Loss: 0.0061, Val Loss: 0.0043
# Epoch [96/1500] Fold 1, Train Loss: 0.0063, Val Loss: 0.0043
# Epoch [97/1500] Fold 1, Train Loss: 0.0062, Val Loss: 0.0043
# Epoch [98/1500] Fold 1, Train Loss: 0.0058, Val Loss: 0.0043
# Epoch [99/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [100/1500] Fold 1, Train Loss: 0.0067, Val Loss: 0.0043
# Epoch [101/1500] Fold 1, Train Loss: 0.0065, Val Loss: 0.0043
# Epoch [102/1500] Fold 1, Train Loss: 0.0060, Val Loss: 0.0044
# Epoch [103/1500] Fold 1, Train Loss: 0.0059, Val Loss: 0.0043
# Epoch [104/1500] Fold 1, Train Loss: 0.0063, Val Loss: 0.0043
# Epoch [105/1500] Fold 1, Train Loss: 0.0058, Val Loss: 0.0044
# Epoch [106/1500] Fold 1, Train Loss: 0.0058, Val Loss: 0.0044
# Epoch [107/1500] Fold 1, Train Loss: 0.0063, Val Loss: 0.0044
# Epoch [108/1500] Fold 1, Train Loss: 0.0063, Val Loss: 0.0044
# Epoch [109/1500] Fold 1, Train Loss: 0.0058, Val Loss: 0.0046
# Epoch [110/1500] Fold 1, Train Loss: 0.0060, Val Loss: 0.0045
# Epoch [111/1500] Fold 1, Train Loss: 0.0055, Val Loss: 0.0045
# Epoch [112/1500] Fold 1, Train Loss: 0.0055, Val Loss: 0.0045
# Epoch [113/1500] Fold 1, Train Loss: 0.0056, Val Loss: 0.0044
# Epoch [114/1500] Fold 1, Train Loss: 0.0053, Val Loss: 0.0046
# Epoch [115/1500] Fold 1, Train Loss: 0.0056, Val Loss: 0.0045
# Epoch [116/1500] Fold 1, Train Loss: 0.0053, Val Loss: 0.0045
# Epoch [117/1500] Fold 1, Train Loss: 0.0054, Val Loss: 0.0044
# Epoch [118/1500] Fold 1, Train Loss: 0.0052, Val Loss: 0.0045
# Epoch [119/1500] Fold 1, Train Loss: 0.0051, Val Loss: 0.0043
# Epoch [120/1500] Fold 1, Train Loss: 0.0050, Val Loss: 0.0043
# Epoch [121/1500] Fold 1, Train Loss: 0.0053, Val Loss: 0.0044
# Epoch [122/1500] Fold 1, Train Loss: 0.0048, Val Loss: 0.0043
# Epoch [123/1500] Fold 1, Train Loss: 0.0047, Val Loss: 0.0043
# Epoch [124/1500] Fold 1, Train Loss: 0.0055, Val Loss: 0.0043
# Epoch [125/1500] Fold 1, Train Loss: 0.0047, Val Loss: 0.0043
# Epoch [126/1500] Fold 1, Train Loss: 0.0046, Val Loss: 0.0043
# Epoch [127/1500] Fold 1, Train Loss: 0.0046, Val Loss: 0.0041
# Epoch [128/1500] Fold 1, Train Loss: 0.0048, Val Loss: 0.0044
# Epoch [129/1500] Fold 1, Train Loss: 0.0046, Val Loss: 0.0042
# Epoch [130/1500] Fold 1, Train Loss: 0.0050, Val Loss: 0.0041
# Epoch [131/1500] Fold 1, Train Loss: 0.0046, Val Loss: 0.0041
# Epoch [132/1500] Fold 1, Train Loss: 0.0049, Val Loss: 0.0041
# Epoch [133/1500] Fold 1, Train Loss: 0.0046, Val Loss: 0.0040
# Epoch [134/1500] Fold 1, Train Loss: 0.0043, Val Loss: 0.0041
# Epoch [135/1500] Fold 1, Train Loss: 0.0043, Val Loss: 0.0041
# Epoch [136/1500] Fold 1, Train Loss: 0.0046, Val Loss: 0.0041
# Epoch [137/1500] Fold 1, Train Loss: 0.0044, Val Loss: 0.0041
# Epoch [138/1500] Fold 1, Train Loss: 0.0044, Val Loss: 0.0041
# Epoch [139/1500] Fold 1, Train Loss: 0.0047, Val Loss: 0.0039
# Epoch [140/1500] Fold 1, Train Loss: 0.0046, Val Loss: 0.0043
# Epoch [141/1500] Fold 1, Train Loss: 0.0042, Val Loss: 0.0040
# Epoch [142/1500] Fold 1, Train Loss: 0.0044, Val Loss: 0.0039
# Epoch [143/1500] Fold 1, Train Loss: 0.0042, Val Loss: 0.0041
# Epoch [144/1500] Fold 1, Train Loss: 0.0044, Val Loss: 0.0040
# Epoch [145/1500] Fold 1, Train Loss: 0.0043, Val Loss: 0.0041
# Epoch [146/1500] Fold 1, Train Loss: 0.0043, Val Loss: 0.0041
# Epoch [147/1500] Fold 1, Train Loss: 0.0044, Val Loss: 0.0039
# Epoch [148/1500] Fold 1, Train Loss: 0.0041, Val Loss: 0.0041
# Epoch [149/1500] Fold 1, Train Loss: 0.0041, Val Loss: 0.0040
# Epoch [150/1500] Fold 1, Train Loss: 0.0040, Val Loss: 0.0039
# Epoch [151/1500] Fold 1, Train Loss: 0.0041, Val Loss: 0.0040
# Epoch [152/1500] Fold 1, Train Loss: 0.0039, Val Loss: 0.0040
# Epoch [153/1500] Fold 1, Train Loss: 0.0039, Val Loss: 0.0040
# Epoch [154/1500] Fold 1, Train Loss: 0.0044, Val Loss: 0.0040
# Epoch [155/1500] Fold 1, Train Loss: 0.0042, Val Loss: 0.0039
# Epoch [156/1500] Fold 1, Train Loss: 0.0041, Val Loss: 0.0041
# Epoch [157/1500] Fold 1, Train Loss: 0.0041, Val Loss: 0.0040
# Epoch [158/1500] Fold 1, Train Loss: 0.0040, Val Loss: 0.0039
# Epoch [159/1500] Fold 1, Train Loss: 0.0041, Val Loss: 0.0042
# Epoch [160/1500] Fold 1, Train Loss: 0.0039, Val Loss: 0.0039
# Epoch [161/1500] Fold 1, Train Loss: 0.0040, Val Loss: 0.0039
# Epoch [162/1500] Fold 1, Train Loss: 0.0041, Val Loss: 0.0041
# Epoch [163/1500] Fold 1, Train Loss: 0.0040, Val Loss: 0.0039
# Epoch [164/1500] Fold 1, Train Loss: 0.0039, Val Loss: 0.0039
# Epoch [165/1500] Fold 1, Train Loss: 0.0038, Val Loss: 0.0039
# Epoch [166/1500] Fold 1, Train Loss: 0.0040, Val Loss: 0.0038
# Epoch [167/1500] Fold 1, Train Loss: 0.0041, Val Loss: 0.0040
# Epoch [168/1500] Fold 1, Train Loss: 0.0039, Val Loss: 0.0039
# Epoch [169/1500] Fold 1, Train Loss: 0.0043, Val Loss: 0.0039
# Epoch [170/1500] Fold 1, Train Loss: 0.0039, Val Loss: 0.0039
# Epoch [171/1500] Fold 1, Train Loss: 0.0039, Val Loss: 0.0038
# Epoch [172/1500] Fold 1, Train Loss: 0.0038, Val Loss: 0.0039
# Epoch [173/1500] Fold 1, Train Loss: 0.0039, Val Loss: 0.0039
# Epoch [174/1500] Fold 1, Train Loss: 0.0044, Val Loss: 0.0039
# Epoch [175/1500] Fold 1, Train Loss: 0.0040, Val Loss: 0.0039
# Epoch [176/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0039
# Epoch [177/1500] Fold 1, Train Loss: 0.0039, Val Loss: 0.0039
# Epoch [178/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0038
# Epoch [179/1500] Fold 1, Train Loss: 0.0041, Val Loss: 0.0039
# Epoch [180/1500] Fold 1, Train Loss: 0.0041, Val Loss: 0.0038
# Epoch [181/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0038
# Epoch [182/1500] Fold 1, Train Loss: 0.0038, Val Loss: 0.0038
# Epoch [183/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0039
# Epoch [184/1500] Fold 1, Train Loss: 0.0038, Val Loss: 0.0038
# Epoch [185/1500] Fold 1, Train Loss: 0.0038, Val Loss: 0.0038
# Epoch [186/1500] Fold 1, Train Loss: 0.0038, Val Loss: 0.0038
# Epoch [187/1500] Fold 1, Train Loss: 0.0038, Val Loss: 0.0039
# Epoch [188/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0038
# Epoch [189/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0039
# Epoch [190/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0039
# Epoch [191/1500] Fold 1, Train Loss: 0.0038, Val Loss: 0.0038
# Epoch [192/1500] Fold 1, Train Loss: 0.0040, Val Loss: 0.0038
# Epoch [193/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0038
# Epoch [194/1500] Fold 1, Train Loss: 0.0041, Val Loss: 0.0038
# Epoch [195/1500] Fold 1, Train Loss: 0.0038, Val Loss: 0.0039
# Epoch [196/1500] Fold 1, Train Loss: 0.0039, Val Loss: 0.0038
# Epoch [197/1500] Fold 1, Train Loss: 0.0040, Val Loss: 0.0039
# Epoch [198/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0037
# Epoch [199/1500] Fold 1, Train Loss: 0.0035, Val Loss: 0.0039
# Epoch [200/1500] Fold 1, Train Loss: 0.0035, Val Loss: 0.0037
# Epoch [201/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0038
# Epoch [202/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0038
# Epoch [203/1500] Fold 1, Train Loss: 0.0034, Val Loss: 0.0037
# Epoch [204/1500] Fold 1, Train Loss: 0.0035, Val Loss: 0.0038
# Epoch [205/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0037
# Epoch [206/1500] Fold 1, Train Loss: 0.0043, Val Loss: 0.0037
# Epoch [207/1500] Fold 1, Train Loss: 0.0035, Val Loss: 0.0037
# Epoch [208/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0038
# Epoch [209/1500] Fold 1, Train Loss: 0.0035, Val Loss: 0.0038
# Epoch [210/1500] Fold 1, Train Loss: 0.0035, Val Loss: 0.0038
# Epoch [211/1500] Fold 1, Train Loss: 0.0035, Val Loss: 0.0038
# Epoch [212/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0037
# Epoch [213/1500] Fold 1, Train Loss: 0.0039, Val Loss: 0.0038
# Epoch [214/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0037
# Epoch [215/1500] Fold 1, Train Loss: 0.0034, Val Loss: 0.0038
# Epoch [216/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0038
# Epoch [217/1500] Fold 1, Train Loss: 0.0035, Val Loss: 0.0038
# Epoch [218/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0037
# Epoch [219/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0038
# Epoch [220/1500] Fold 1, Train Loss: 0.0038, Val Loss: 0.0037
# Epoch [221/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0038
# Epoch [222/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0038
# Epoch [223/1500] Fold 1, Train Loss: 0.0038, Val Loss: 0.0037
# Epoch [224/1500] Fold 1, Train Loss: 0.0034, Val Loss: 0.0038
# Epoch [225/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0036
# Epoch [226/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0038
# Epoch [227/1500] Fold 1, Train Loss: 0.0034, Val Loss: 0.0037
# Epoch [228/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch [229/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0037
# Epoch [230/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0038
# Epoch [231/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch [232/1500] Fold 1, Train Loss: 0.0034, Val Loss: 0.0037
# Epoch [233/1500] Fold 1, Train Loss: 0.0035, Val Loss: 0.0038
# Epoch [234/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0038
# Epoch [235/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0037
# Epoch [236/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0039
# Epoch [237/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0037
# Epoch [238/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0038
# Epoch [239/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch [240/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0038
# Epoch [241/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch [242/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch [243/1500] Fold 1, Train Loss: 0.0035, Val Loss: 0.0038
# Epoch [244/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0038
# Epoch [245/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0037
# Epoch [246/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch [247/1500] Fold 1, Train Loss: 0.0034, Val Loss: 0.0038
# Epoch [248/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0037
# Epoch [249/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0038
# Epoch [250/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0038
# Epoch [251/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0038
# Epoch [252/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0038
# Epoch [253/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0038
# Epoch [254/1500] Fold 1, Train Loss: 0.0034, Val Loss: 0.0038
# Epoch [255/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch [256/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch [257/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0037
# Epoch [258/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0038
# Epoch [259/1500] Fold 1, Train Loss: 0.0034, Val Loss: 0.0037
# Epoch [260/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0039
# Epoch [261/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0038
# Epoch [262/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0039
# Epoch [263/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0039
# Epoch [264/1500] Fold 1, Train Loss: 0.0037, Val Loss: 0.0038
# Epoch [265/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch [266/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0038
# Epoch [267/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0039
# Epoch [268/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0038
# Epoch [269/1500] Fold 1, Train Loss: 0.0035, Val Loss: 0.0039
# Epoch [270/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0038
# Epoch [271/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0039
# Epoch [272/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0039
# Epoch [273/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0039
# Epoch [274/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch [275/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0038
# Epoch [276/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0038
# Epoch [277/1500] Fold 1, Train Loss: 0.0035, Val Loss: 0.0038
# Epoch [278/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0039
# Epoch [279/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0039
# Epoch [280/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0040
# Epoch [281/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0039
# Epoch [282/1500] Fold 1, Train Loss: 0.0034, Val Loss: 0.0038
# Epoch [283/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0039
# Epoch [284/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0039
# Epoch [285/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0040
# Epoch [286/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0039
# Epoch [287/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0039
# Epoch [288/1500] Fold 1, Train Loss: 0.0034, Val Loss: 0.0039
# Epoch [289/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0039
# Epoch [290/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0040
# Epoch [291/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0038
# Epoch [292/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0040
# Epoch [293/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0039
# Epoch [294/1500] Fold 1, Train Loss: 0.0034, Val Loss: 0.0039
# Epoch [295/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0039
# Epoch [296/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0040
# Epoch [297/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0039
# Epoch [298/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0039
# Epoch [299/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0039
# Epoch [300/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0039
# Epoch [301/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0040
# Epoch [302/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0040
# Epoch [303/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0040
# Epoch [304/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0040
# Epoch [305/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0040
# Epoch [306/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0040
# Epoch [307/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0040
# Epoch [308/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0040
# Epoch [309/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0041
# Epoch [310/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0039
# Epoch [311/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0040
# Epoch [312/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0041
# Epoch [313/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0041
# Epoch [314/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0041
# Epoch [315/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0041
# Epoch [316/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0040
# Epoch [317/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0040
# Epoch [318/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0041
# Epoch [319/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0041
# Epoch [320/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0041
# Epoch [321/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0040
# Epoch [322/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0042
# Epoch [323/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0040
# Epoch [324/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0042
# Epoch [325/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0040
# Epoch [326/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [327/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0040
# Epoch [328/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0041
# Epoch [329/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0042
# Epoch [330/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0041
# Epoch [331/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0042
# Epoch [332/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0041
# Epoch [333/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0041
# Epoch [334/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [335/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0041
# Epoch [336/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0041
# Epoch [337/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0042
# Epoch [338/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0040
# Epoch [339/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [340/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0041
# Epoch [341/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0041
# Epoch [342/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0042
# Epoch [343/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0041
# Epoch [344/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0043
# Epoch [345/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0041
# Epoch [346/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [347/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0042
# Epoch [348/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0041
# Epoch [349/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [350/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0042
# Epoch [351/1500] Fold 1, Train Loss: 0.0036, Val Loss: 0.0042
# Epoch [352/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0043
# Epoch [353/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0040
# Epoch [354/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0044
# Epoch [355/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0040
# Epoch [356/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0043
# Epoch [357/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [358/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0042
# Epoch [359/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0042
# Epoch [360/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0042
# Epoch [361/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0042
# Epoch [362/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0043
# Epoch [363/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0043
# Epoch [364/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [365/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0042
# Epoch [366/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [367/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0042
# Epoch [368/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0041
# Epoch [369/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0044
# Epoch [370/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0041
# Epoch [371/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0043
# Epoch [372/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0043
# Epoch [373/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0041
# Epoch [374/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0044
# Epoch [375/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0041
# Epoch [376/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0043
# Epoch [377/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0043
# Epoch [378/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0043
# Epoch [379/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [380/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0043
# Epoch [381/1500] Fold 1, Train Loss: 0.0033, Val Loss: 0.0042
# Epoch [382/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [383/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0043
# Epoch [384/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [385/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0043
# Epoch [386/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0043
# Epoch [387/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [388/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0043
# Epoch [389/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0042
# Epoch [390/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0042
# Epoch [391/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0044
# Epoch [392/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [393/1500] Fold 1, Train Loss: 0.0032, Val Loss: 0.0042
# Epoch [394/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0043
# Epoch [395/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [396/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0044
# Epoch [397/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [398/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0043
# Epoch [399/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0043
# Epoch [400/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0041
# Epoch [401/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0044
# Epoch [402/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0041
# Epoch [403/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0043
# Epoch [404/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0043
# Epoch [405/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0041
# Epoch [406/1500] Fold 1, Train Loss: 0.0031, Val Loss: 0.0044
# Epoch [407/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0041
# Epoch [408/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0043
# Epoch [409/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0043
# Epoch [410/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [411/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0044
# Epoch [412/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0041
# Epoch [413/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0043
# Epoch [414/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0041
# Epoch [415/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0043
# Epoch [416/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0043
# Epoch [417/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0040
# Epoch [418/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0043
# Epoch [419/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0040
# Epoch [420/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0043
# Epoch [421/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [422/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [423/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [424/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0041
# Epoch [425/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [426/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0041
# Epoch [427/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0042
# Epoch [428/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [429/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [430/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [431/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [432/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [433/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0042
# Epoch [434/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0041
# Epoch [435/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [436/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [437/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0041
# Epoch [438/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0043
# Epoch [439/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0041
# Epoch [440/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [441/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [442/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [443/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [444/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [445/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [446/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [447/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [448/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [449/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0043
# Epoch [450/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0041
# Epoch [451/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [452/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [453/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [454/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0043
# Epoch [455/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [456/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [457/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [458/1500] Fold 1, Train Loss: 0.0030, Val Loss: 0.0041
# Epoch [459/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [460/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [461/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [462/1500] Fold 1, Train Loss: 0.0028, Val Loss: 0.0042
# Epoch [463/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [464/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [465/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [466/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [467/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [468/1500] Fold 1, Train Loss: 0.0029, Val Loss: 0.0042
# Epoch [469/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [470/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [471/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [472/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [473/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [474/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [475/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [476/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [477/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [478/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [479/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [480/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [481/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0041
# Epoch [482/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [483/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [484/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [485/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [486/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [487/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0041
# Epoch [488/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [489/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [490/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [491/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [492/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [493/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [494/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0041
# Epoch [495/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0042
# Epoch [496/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [497/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0041
# Epoch [498/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [499/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [500/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [501/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [502/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [503/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [504/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [505/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0041
# Epoch [506/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [507/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [508/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0042
# Epoch [509/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [510/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [511/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0041
# Epoch [512/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0042
# Epoch [513/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0040
# Epoch [514/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [515/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0044
# Epoch [516/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0040
# Epoch [517/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0042
# Epoch [518/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [519/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0040
# Epoch [520/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0043
# Epoch [521/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [522/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0040
# Epoch [523/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0043
# Epoch [524/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0040
# Epoch [525/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0042
# Epoch [526/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [527/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0040
# Epoch [528/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0043
# Epoch [529/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0040
# Epoch [530/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0042
# Epoch [531/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [532/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [533/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [534/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [535/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [536/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [537/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [538/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [539/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [540/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0041
# Epoch [541/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [542/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [543/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [544/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [545/1500] Fold 1, Train Loss: 0.0027, Val Loss: 0.0041
# Epoch [546/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [547/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [548/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [549/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0040
# Epoch [550/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [551/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [552/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [553/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [554/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [555/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [556/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0041
# Epoch [557/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [558/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [559/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [560/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [561/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0040
# Epoch [562/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [563/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0040
# Epoch [564/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0040
# Epoch [565/1500] Fold 1, Train Loss: 0.0026, Val Loss: 0.0042
# Epoch [566/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0040
# Epoch [567/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0040
# Epoch [568/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [569/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0040
# Epoch [570/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [571/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [572/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0039
# Epoch [573/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [574/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [575/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [576/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [577/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [578/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [579/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [580/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0042
# Epoch [581/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0040
# Epoch [582/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [583/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [584/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [585/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [586/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [587/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [588/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [589/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [590/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0040
# Epoch [591/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [592/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [593/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0040
# Epoch [594/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [595/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0042
# Epoch [596/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [597/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0042
# Epoch [598/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [599/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [600/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0042
# Epoch [601/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0040
# Epoch [602/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [603/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [604/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [605/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [606/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0042
# Epoch [607/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [608/1500] Fold 1, Train Loss: 0.0025, Val Loss: 0.0041
# Epoch [609/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [610/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0040
# Epoch [611/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [612/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [613/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [614/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [615/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [616/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [617/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [618/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [619/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [620/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0040
# Epoch [621/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [622/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [623/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0040
# Epoch [624/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [625/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [626/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [627/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [628/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [629/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [630/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [631/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [632/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [633/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [634/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0042
# Epoch [635/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0042
# Epoch [636/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [637/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [638/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0042
# Epoch [639/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [640/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0042
# Epoch [641/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [642/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [643/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [644/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0042
# Epoch [645/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [646/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0042
# Epoch [647/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0041
# Epoch [648/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0040
# Epoch [649/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [650/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [651/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [652/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [653/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [654/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [655/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [656/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [657/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0040
# Epoch [658/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [659/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0042
# Epoch [660/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [661/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [662/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0042
# Epoch [663/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0040
# Epoch [664/1500] Fold 1, Train Loss: 0.0019, Val Loss: 0.0041
# Epoch [665/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0042
# Epoch [666/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [667/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [668/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0042
# Epoch [669/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0040
# Epoch [670/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [671/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [672/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [673/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0042
# Epoch [674/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [675/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [676/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [677/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0042
# Epoch [678/1500] Fold 1, Train Loss: 0.0023, Val Loss: 0.0040
# Epoch [679/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [680/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [681/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0040
# Epoch [682/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0041
# Epoch [683/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0042
# Epoch [684/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [685/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [686/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [687/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [688/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [689/1500] Fold 1, Train Loss: 0.0024, Val Loss: 0.0041
# Epoch [690/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0040
# Epoch [691/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [692/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0042
# Epoch [693/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0040
# Epoch [694/1500] Fold 1, Train Loss: 0.0019, Val Loss: 0.0041
# Epoch [695/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0042
# Epoch [696/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0040
# Epoch [697/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [698/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [699/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [700/1500] Fold 1, Train Loss: 0.0019, Val Loss: 0.0040
# Epoch [701/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [702/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0040
# Epoch [703/1500] Fold 1, Train Loss: 0.0018, Val Loss: 0.0042
# Epoch [704/1500] Fold 1, Train Loss: 0.0019, Val Loss: 0.0040
# Epoch [705/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [706/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0042
# Epoch [707/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [708/1500] Fold 1, Train Loss: 0.0019, Val Loss: 0.0040
# Epoch [709/1500] Fold 1, Train Loss: 0.0019, Val Loss: 0.0041
# Epoch [710/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0040
# Epoch [711/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0040
# Epoch [712/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0042
# Epoch [713/1500] Fold 1, Train Loss: 0.0019, Val Loss: 0.0041
# Epoch [714/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0040
# Epoch [715/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0042
# Epoch [716/1500] Fold 1, Train Loss: 0.0022, Val Loss: 0.0042
# Epoch [717/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0040
# Epoch [718/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0042
# Epoch [719/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [720/1500] Fold 1, Train Loss: 0.0021, Val Loss: 0.0041
# Epoch [721/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [722/1500] Fold 1, Train Loss: 0.0019, Val Loss: 0.0041
# Epoch [723/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0042
# Epoch [724/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0041
# Epoch [725/1500] Fold 1, Train Loss: 0.0020, Val Loss: 0.0040
# Early stopping at epoch 725 for fold 1
# Fold 2/5
# Epoch [1/1500] Fold 2, Train Loss: 0.0129, Val Loss: 0.0129
# Epoch [2/1500] Fold 2, Train Loss: 0.0135, Val Loss: 0.0125
# Epoch [3/1500] Fold 2, Train Loss: 0.0131, Val Loss: 0.0121
# Epoch [4/1500] Fold 2, Train Loss: 0.0135, Val Loss: 0.0117
# Epoch [5/1500] Fold 2, Train Loss: 0.0111, Val Loss: 0.0113
# Epoch [6/1500] Fold 2, Train Loss: 0.0108, Val Loss: 0.0109
# Epoch [7/1500] Fold 2, Train Loss: 0.0116, Val Loss: 0.0106
# Epoch [8/1500] Fold 2, Train Loss: 0.0111, Val Loss: 0.0102
# Epoch [9/1500] Fold 2, Train Loss: 0.0107, Val Loss: 0.0099
# Epoch [10/1500] Fold 2, Train Loss: 0.0105, Val Loss: 0.0096
# Epoch [11/1500] Fold 2, Train Loss: 0.0092, Val Loss: 0.0092
# Epoch [12/1500] Fold 2, Train Loss: 0.0087, Val Loss: 0.0089
# Epoch [13/1500] Fold 2, Train Loss: 0.0083, Val Loss: 0.0086
# Epoch [14/1500] Fold 2, Train Loss: 0.0085, Val Loss: 0.0083
# Epoch [15/1500] Fold 2, Train Loss: 0.0080, Val Loss: 0.0080
# Epoch [16/1500] Fold 2, Train Loss: 0.0080, Val Loss: 0.0077
# Epoch [17/1500] Fold 2, Train Loss: 0.0073, Val Loss: 0.0075
# Epoch [18/1500] Fold 2, Train Loss: 0.0070, Val Loss: 0.0073
# Epoch [19/1500] Fold 2, Train Loss: 0.0078, Val Loss: 0.0070
# Epoch [20/1500] Fold 2, Train Loss: 0.0069, Val Loss: 0.0068
# Epoch [21/1500] Fold 2, Train Loss: 0.0067, Val Loss: 0.0067
# Epoch [22/1500] Fold 2, Train Loss: 0.0067, Val Loss: 0.0065
# Epoch [23/1500] Fold 2, Train Loss: 0.0062, Val Loss: 0.0064
# Epoch [24/1500] Fold 2, Train Loss: 0.0062, Val Loss: 0.0063
# Epoch [25/1500] Fold 2, Train Loss: 0.0073, Val Loss: 0.0062
# Epoch [26/1500] Fold 2, Train Loss: 0.0065, Val Loss: 0.0061
# Epoch [27/1500] Fold 2, Train Loss: 0.0064, Val Loss: 0.0060
# Epoch [28/1500] Fold 2, Train Loss: 0.0060, Val Loss: 0.0060
# Epoch [29/1500] Fold 2, Train Loss: 0.0061, Val Loss: 0.0059
# Epoch [30/1500] Fold 2, Train Loss: 0.0056, Val Loss: 0.0059
# Epoch [31/1500] Fold 2, Train Loss: 0.0063, Val Loss: 0.0059
# Epoch [32/1500] Fold 2, Train Loss: 0.0057, Val Loss: 0.0058
# Epoch [33/1500] Fold 2, Train Loss: 0.0064, Val Loss: 0.0058
# Epoch [34/1500] Fold 2, Train Loss: 0.0057, Val Loss: 0.0058
# Epoch [35/1500] Fold 2, Train Loss: 0.0056, Val Loss: 0.0058
# Epoch [36/1500] Fold 2, Train Loss: 0.0059, Val Loss: 0.0058
# Epoch [37/1500] Fold 2, Train Loss: 0.0056, Val Loss: 0.0058
# Epoch [38/1500] Fold 2, Train Loss: 0.0056, Val Loss: 0.0058
# Epoch [39/1500] Fold 2, Train Loss: 0.0065, Val Loss: 0.0058
# Epoch [40/1500] Fold 2, Train Loss: 0.0057, Val Loss: 0.0058
# Epoch [41/1500] Fold 2, Train Loss: 0.0060, Val Loss: 0.0058
# Epoch [42/1500] Fold 2, Train Loss: 0.0056, Val Loss: 0.0058
# Epoch [43/1500] Fold 2, Train Loss: 0.0060, Val Loss: 0.0058
# Epoch [44/1500] Fold 2, Train Loss: 0.0058, Val Loss: 0.0058
# Epoch [45/1500] Fold 2, Train Loss: 0.0063, Val Loss: 0.0058
# Epoch [46/1500] Fold 2, Train Loss: 0.0056, Val Loss: 0.0057
# Epoch [47/1500] Fold 2, Train Loss: 0.0062, Val Loss: 0.0057
# Epoch [48/1500] Fold 2, Train Loss: 0.0055, Val Loss: 0.0057
# Epoch [49/1500] Fold 2, Train Loss: 0.0060, Val Loss: 0.0057
# Epoch [50/1500] Fold 2, Train Loss: 0.0059, Val Loss: 0.0057
# ...
# Epoch [1248/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1249/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1250/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1251/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1252/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1253/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1254/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1255/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1256/1500] Fold 5, Train Loss: 0.0014, Val Loss: 0.0049
# Epoch [1257/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1258/1500] Fold 5, Train Loss: 0.0014, Val Loss: 0.0049
# Epoch [1259/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1260/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1261/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1262/1500] Fold 5, Train Loss: 0.0014, Val Loss: 0.0049
# Epoch [1263/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1264/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1265/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1266/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1267/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1268/1500] Fold 5, Train Loss: 0.0014, Val Loss: 0.0049
# Epoch [1269/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1270/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1271/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1272/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1273/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1274/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1275/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1276/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1277/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1278/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1279/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1280/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1281/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1282/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1283/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1284/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1285/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1286/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1287/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1288/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1289/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1290/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1291/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1292/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1293/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1294/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1295/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1296/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1297/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1298/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1299/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1300/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1301/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1302/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1303/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1304/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1305/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1306/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1307/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1308/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1309/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1310/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1311/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1312/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1313/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1314/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1315/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1316/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1317/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1318/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1319/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1320/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1321/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1322/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1323/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1324/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1325/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1326/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1327/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1328/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1329/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1330/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1331/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1332/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1333/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1334/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1335/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1336/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1337/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1338/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1339/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1340/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1341/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1342/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1343/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1344/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1345/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1346/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1347/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1348/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1349/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1350/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1351/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1352/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1353/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1354/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1355/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1356/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1357/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1358/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1359/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1360/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1361/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1362/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1363/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1364/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1365/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1366/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1367/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1368/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1369/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0049
# Epoch [1370/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1371/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1372/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1373/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1374/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1375/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1376/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1377/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1378/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1379/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1380/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1381/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1382/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1383/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1384/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1385/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1386/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1387/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1388/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1389/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1390/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1391/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1392/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1393/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1394/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1395/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1396/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1397/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1398/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1399/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1400/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1401/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1402/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1403/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1404/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1405/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1406/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1407/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1408/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1409/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1410/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1411/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1412/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1413/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1414/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1415/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1416/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1417/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1418/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1419/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1420/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1421/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1422/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1423/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1424/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1425/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1426/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1427/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1428/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1429/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1430/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1431/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1432/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1433/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1434/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1435/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1436/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1437/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1438/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1439/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1440/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1441/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1442/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050
# Epoch [1443/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1444/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1445/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0049
# Epoch [1446/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0049
# Epoch [1447/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1448/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1449/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1450/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1451/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1452/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1453/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0051
# Epoch [1454/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1455/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1456/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1457/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1458/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1459/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1460/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1461/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1462/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1463/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1464/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1465/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1466/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1467/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1468/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1469/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1470/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1471/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1472/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1473/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1474/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1475/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0051
# Epoch [1476/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0051
# Epoch [1477/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0051
# Epoch [1478/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1479/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1480/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0051
# Epoch [1481/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1482/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1483/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0051
# Epoch [1484/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1485/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1486/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0051
# Epoch [1487/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0051
# Epoch [1488/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0051
# Epoch [1489/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1490/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1491/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1492/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0050
# Epoch [1493/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1494/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0051
# Epoch [1495/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0051
# Epoch [1496/1500] Fold 5, Train Loss: 0.0011, Val Loss: 0.0051
# Epoch [1497/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1498/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1499/1500] Fold 5, Train Loss: 0.0012, Val Loss: 0.0050
# Epoch [1500/1500] Fold 5, Train Loss: 0.0013, Val Loss: 0.0050

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.0060

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.0036
#   Corresponding Training Loss = 0.0036
#   Best Epoch = 225
# Fold 2:
#   Best Validation Loss = 0.0054
#   Corresponding Training Loss = 0.0049
#   Best Epoch = 123
# Fold 3:
#   Best Validation Loss = 0.0072
#   Corresponding Training Loss = 0.0037
#   Best Epoch = 215
# Fold 4:
#   Best Validation Loss = 0.0051
#   Corresponding Training Loss = 0.0024
#   Best Epoch = 349
# Fold 5:
#   Best Validation Loss = 0.0049
#   Corresponding Training Loss = 0.0013
#   Best Epoch = 1366

# %% [markdown]
# # MIN MAX
# dataset = TensorDataset(train_day7_feats_minmaxed, train_day10_feats_minmaxed)
#
# cv_histories, best_models = cross_validate_with_early_stopping(
#     model_class=FeaturePredictor,
#     dataset=dataset,
#     criterion=nn.MSELoss(),
#     optimizer_class=torch.optim.Adam,
#     num_epochs=1500,
#     patience=500
# )

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.0155

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.0134
#   Corresponding Training Loss = 0.0216
#   Best Epoch = 1460
# Fold 2:
#   Best Validation Loss = 0.0142
#   Corresponding Training Loss = 0.0149
#   Best Epoch = 1495
# Fold 3:
#   Best Validation Loss = 0.0158
#   Corresponding Training Loss = 0.0177
#   Best Epoch = 936
# Fold 4:
#   Best Validation Loss = 0.0159
#   Corresponding Training Loss = 0.0191
#   Best Epoch = 784
# Fold 5:
#   Best Validation Loss = 0.0143
#   Corresponding Training Loss = 0.0210
#   Best Epoch = 709

# %% [markdown]
# # MIN MAX
# dataset = TensorDataset(train_day7_feats_minmaxed, train_day10_feats_minmaxed)
#
# cv_histories, best_models = cross_validate_with_early_stopping(
#     model_class=FeaturePredictor,
#     dataset=dataset,
#     criterion=nn.MSELoss(),
#     optimizer_class=torch.optim.Adam,
#     num_epochs=1500,
#     patience=500
# )

# %% [markdown]
# # without normalisation
# dataset = TensorDataset(train_day7_feats, train_day10_feats)
#
# cv_histories, best_models = cross_validate_with_early_stopping(
#     model_class=FeaturePredictor,
#     dataset=dataset,
#     criterion=nn.MSELoss(),
#     optimizer_class=torch.optim.Adam,
#     num_epochs=1500,
#     patience=500
# )

# %% [markdown]
# # MIN MAX

# %%
import os

# Define the directory where models will be saved
save_dir = r'C:\Users\k54739\saved_model\ranking\simclr\minmax_scaled\resizeonly'
os.makedirs(save_dir, exist_ok=True)  # Create the directory if it doesn't exist

# Save each fold's best model to the directory
for i, model_state in enumerate(best_models):
    save_path = os.path.join(save_dir, f'best_model_fold_{i+1}.pth')
    torch.save(model_state, save_path)

print(f"Models saved to {save_dir}")
# Out:
# Models saved to C:\Users\k54739\saved_model\ranking\simclr\minmax_scaled\resizeonly

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.0129

# %%
#loss started from 0.03

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.0104
#   Corresponding Training Loss = 0.0088
#   Best Epoch = 169
# Fold 2:
#   Best Validation Loss = 0.0120
#   Corresponding Training Loss = 0.0082
#   Best Epoch = 227
# Fold 3:
#   Best Validation Loss = 0.0116
#   Corresponding Training Loss = 0.0084
#   Best Epoch = 271
# Fold 4:
#   Best Validation Loss = 0.0099
#   Corresponding Training Loss = 0.0088
#   Best Epoch = 185
# Fold 5:
#   Best Validation Loss = 0.0093
#   Corresponding Training Loss = 0.0087
#   Best Epoch = 302

# %%
def plot_loss_curves_separately(cv_histories):
    """
    Plot training and validation loss curves for each fold in separate figures.
    
    Args:
        cv_histories (list): List of loss histories for each fold.
    """
    # Plot Training Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['train_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
    plt.title('Training Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['val_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
    plt.title('Validation Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_loss_curves_separately(cv_histories)

# %% [markdown]
# # without normalisation second try

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.8875
#   Corresponding Training Loss = 0.7412
#   Best Epoch = 499
# Fold 2:
#   Best Validation Loss = 1.0025
#   Corresponding Training Loss = 0.7160
#   Best Epoch = 431
# Fold 3:
#   Best Validation Loss = 0.9107
#   Corresponding Training Loss = 0.7098
#   Best Epoch = 367
# Fold 4:
#   Best Validation Loss = 0.7906
#   Corresponding Training Loss = 0.6153
#   Best Epoch = 939
# Fold 5:
#   Best Validation Loss = 0.8438
#   Corresponding Training Loss = 0.7240
#   Best Epoch = 453

# %%
import os

# Define the directory where models will be saved
save_dir = r'C:\Users\k54739\saved_model\ranking\simclr\minmax_scaled'
os.makedirs(save_dir, exist_ok=True)  # Create the directory if it doesn't exist

# Save each fold's best model to the directory
for i, model_state in enumerate(best_models):
    save_path = os.path.join(save_dir, f'best_model_fold_{i+1}.pth')
    torch.save(model_state, save_path)

print(f"Models saved to {save_dir}")
# Out:
# Models saved to C:\Users\k54739\saved_model\ranking\simclr\minmax_scaled

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 1.0335

# %%
def plot_loss_curves_separately(cv_histories):
    """
    Plot training and validation loss curves for each fold in separate figures.
    
    Args:
        cv_histories (list): List of loss histories for each fold.
    """
    # Plot Training Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['train_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
    plt.title('Training Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['val_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
    plt.title('Validation Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plot_loss_curves_separately(cv_histories)
import matplotlib.pyplot as plt

# %% [markdown]
# # without normalisation first try

# %%
plot_loss_curves_separately(cv_histories)

# %% [markdown]
# # Inference

# %%
import os
import torch
from torch import nn, optim
import numpy

from torch.utils.data import TensorDataset, DataLoader

# %%
# Load training features
train_day7_feats = torch.load('train_day7_control.pt')
train_day10_feats = torch.load('train_day10_control.pt')
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_22920\2729202165.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_day7_feats = torch.load('train_day7_control.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_22920\2729202165.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_day10_feats = torch.load('train_day10_control.pt')

# %%
print(type(train_day7_feats))
print(type(train_day10_feats))
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>

# %%
import matplotlib.pyplot as plt
import torch


# Extract the first feature vector from both
values_day7 = train_day7_feats[0].numpy()  # Convert to NumPy array
values_day10 = train_day10_feats[0].numpy()  # Convert to NumPy array

# Plot histograms to compare distributions
plt.figure(figsize=(10, 6))

plt.hist(values_day7, bins=30, alpha=0.5, label='Day 7 Features', density=True)
plt.hist(values_day10, bins=30, alpha=0.5, label='Day 10 Features', density=True)

plt.title('Distribution of Feature Values: First Vector')
plt.xlabel('Feature Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Print lengths of feature tensors
print(f"Number of training Day 7 features: {len(train_day7_feats)}")
print(f"Number of training Day 10 features: {len(train_day10_feats)}")
# Print shapes of feature tensors
print(f"Shape of training Day 7 features: {train_day7_feats.shape}")
print(f"Shape of training Day 10 features: {train_day10_feats.shape}")
# Out:
# Number of training Day 7 features: 130
# Number of training Day 10 features: 130
# Shape of training Day 7 features: torch.Size([130, 512])
# Shape of training Day 10 features: torch.Size([130, 512])

# %%
import os
import torch
from torch import nn, optim
import numpy

from torch.utils.data import TensorDataset, DataLoader

# %%
# Load training features
inference_sd_day7 = torch.load('inference_sd_day7.pt')
inference_sd_day10 = torch.load('inference_sd_day10.pt')
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_20432\414216957.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   inference_sd_day7 = torch.load('inference_sd_day7.pt')
# C:\Users\k54739\AppData\Local\Temp\ipykernel_20432\414216957.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   inference_sd_day10 = torch.load('inference_sd_day10.pt')

# %%
print(type(inference_sd_day7))
print(type(inference_sd_day10))
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>

# %%
inference_sd_day7
# Out:
# tensor([[0.0000, 0.0000, 1.1177,  ..., 4.7554, 0.0000, 1.2192],
#         [1.5634, 0.0768, 0.0073,  ..., 2.1748, 0.9543, 2.6965],
#         [0.3505, 0.1033, 0.0952,  ..., 2.0586, 0.0000, 0.9589],
#         ...,
#         [1.0277, 0.0124, 0.1167,  ..., 3.5348, 0.0294, 2.4753],
#         [0.0000, 0.0000, 0.8155,  ..., 2.2120, 0.0000, 0.0000],
#         [1.7956, 0.0471, 0.0369,  ..., 2.6556, 0.4420, 3.8215]])

# %%
inference_sd_day10
# Out:
# tensor([[2.3463e+00, 0.0000e+00, 0.0000e+00,  ..., 4.3236e-01, 0.0000e+00,
#          7.5951e-01],
#         [1.8805e+00, 8.1934e-01, 4.6434e-02,  ..., 1.2804e-01, 0.0000e+00,
#          3.9649e-01],
#         [0.0000e+00, 1.9232e-01, 7.9683e-01,  ..., 6.2674e-02, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [3.2696e+00, 1.6963e+00, 0.0000e+00,  ..., 1.3728e+00, 3.9278e-03,
#          1.7484e+00],
#         [4.5861e+00, 0.0000e+00, 0.0000e+00,  ..., 1.0434e+00, 0.0000e+00,
#          2.1944e+00],
#         [0.0000e+00, 7.1825e-01, 3.9650e-01,  ..., 1.1747e-01, 0.0000e+00,
#          0.0000e+00]])

# %%
#inference_sd_day7[0].shape
#inference_sd_day10[0].shape

# %%
import matplotlib.pyplot as plt
import torch


# Extract the first feature vector from both
values_day7 = inference_sd_day7[0].numpy()  # Convert to NumPy array
values_day10 = inference_sd_day10[0].numpy()  # Convert to NumPy array

# Plot histograms to compare distributions
plt.figure(figsize=(10, 6))

plt.hist(values_day7, bins=30, alpha=0.5, label='Day 7 Features', density=True)
plt.hist(values_day10, bins=30, alpha=0.5, label='Day 10 Features', density=True)

plt.title('Distribution of Feature Values: First Vector')
plt.xlabel('Feature Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Print lengths of feature tensors
print(f"Number of training Day 7 features: {len(inference_sd_day7)}")
print(f"Number of training Day 10 features: {len(inference_sd_day10)}")
# Print shapes of feature tensors
print(f"Shape of training Day 7 features: {inference_sd_day7.shape}")
print(f"Shape of training Day 10 features: {inference_sd_day10.shape}")
# Out:
# Number of training Day 7 features: 29
# Number of training Day 10 features: 29
# Shape of training Day 7 features: torch.Size([29, 512])
# Shape of training Day 10 features: torch.Size([29, 512])

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class FeaturePredictor(nn.Module):
    def __init__(self, input_size=512, output_size=512):
        super(FeaturePredictor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16,8),
            nn.ReLU(),
            nn.Linear(8, 16),
            nn.ReLU(),
            nn.Linear(16,32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128,256),
            nn.ReLU(),
            nn.Linear(256, output_size)
        )
    
    def forward(self, x):
        return self.model(x)

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Define the directory where models are saved
load_dir = r'C:\Users\k54739\saved_model\ranking\simclr\minmax_scaled'

# Load a specific fold's best model
model = FeaturePredictor()
load_path = os.path.join(load_dir, 'best_model_fold_5.pth')
model.load_state_dict(torch.load(load_path))
model.to(device)
model.eval()

print(f"Loaded model from {load_path}")
# Out:
# Loaded model from C:\Users\k54739\saved_model\ranking\simclr\minmax_scaled\best_model_fold_5.pth
# C:\Users\k54739\AppData\Local\Temp\ipykernel_22920\313922780.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(load_path))

# %% [markdown]
# # train

# %%
# Min-Max Scaling for Input (X) and Target (Y)
def min_max_scaling(data):
    data_min = data.min()
    data_max = data.max()
    return (data - data_min) / (data_max - data_min), data_min, data_max  # Return scaled data and min/max for inverse scaling

# Apply Min-Max Scaling
train_day7_feats_minmaxed, day7_min, day7_max = min_max_scaling(train_day7_feats)
train_day10_feats_minmaxed, day10_min, day10_max = min_max_scaling(train_day10_feats)
print(day7_min)
print(day7_max)
print(day10_min)
print(day10_max)
# Print summary to confirm
print("After Min-Max Scaling:")
print(f"Input (X): Min={train_day7_feats_minmaxed.min():.4f}, Max={train_day7_feats_minmaxed.max():.4f}")
print(f"Target (Y): Min={train_day10_feats_minmaxed.min():.4f}, Max={train_day10_feats_minmaxed.max():.4f}")
# Out:
# tensor(0.)
# tensor(9.1844)
# tensor(0.)
# tensor(9.1225)
# After Min-Max Scaling:
# Input (X): Min=0.0000, Max=1.0000
# Target (Y): Min=0.0000, Max=1.0000

# %%
# Perform inference
with torch.no_grad():
    # Ensure the input features are on the same device as the model
    train_day7_feats_minmaxed = train_day7_feats_minmaxed[2].to(device)
    train_day10_feats_minmaxed = train_day10_feats_minmaxed[2].to(device)
    
    # Predict the target (Day 10) from the input (Day 7)
    predicted_day10 = model(train_day7_feats_minmaxed)

# Evaluate predictions (optional)
# If you have a target (e.g., inference_feat_day10_minmaxed), calculate MSE or another metric
mse_loss = nn.MSELoss()(predicted_day10, train_day10_feats_minmaxed)
print(f"Mean Squared Error on training Data: {mse_loss.item():.4f}")

# Print or save the predictions
#print("Predicted Target (Day 10 features):")
#print(predicted_day10.cpu().numpy())
# Out:
# Mean Squared Error on training Data: 0.0131

# %%
import numpy as np

# Predicted and true values (ensure they are detached from PyTorch computation graph)
predicted_day10_np = predicted_day10.cpu().numpy()
train_day10_feats_minmaxed_np = train_day10_feats_minmaxed.cpu().numpy()

# Manually compute the MSE
def compute_mse_manual(predicted, true):
    differences = predicted - true  # Element-wise difference
    squared_differences = differences ** 2  # Element-wise squared difference
    mse = squared_differences.mean()  # Mean of squared differences
    return mse

# Calculate MSE
manual_mse = compute_mse_manual(predicted_day10_np, train_day10_feats_minmaxed_np)

print(f"Manual MSE: {manual_mse:.4f}")
# Out:
# Manual MSE: 0.0131

# %%
print(train_day7_feats_minmaxed.shape)
print(train_day10_feats_minmaxed.shape)
print(predicted_day10.shape)
# Out:
# torch.Size([512])
# torch.Size([512])
# torch.Size([512])

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn

# Assume train_day7_feats_minmaxed and train_day10_feats_minmaxed are already loaded
# Extract the third feature vector (index 2)

with torch.no_grad():
        train_day7_feats_minmaxed = train_day7_feats_minmaxed[2].to(device)  # Shape: [512]
        train_day10_feats_minmaxed = train_day10_feats_minmaxed[2].to(device)  # Shape: [512]
        
        predicted_day10 = model(train_day7_feats_minmaxed)
        
print(predicted_day10.shape)
# Initialize the MSE loss function
mse_loss_fn = nn.MSELoss(reduction='none')  # 'none' to get element-wise loss

# Compute element-wise squared differences
squared_diff = mse_loss_fn(train_day10_feats_minmaxed, predicted_day10)  # Shape: [512]

# Calculate the mean of squared differences
mse = squared_diff.mean().item()

print(f"MSE for Single Feature Vector: {mse:.4f}")
# Out:
# torch.Size([512])
# MSE for Single Feature Vector: 0.0131

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn

# Assume train_day7_feats_minmaxed and train_day10_feats_minmaxed are already loaded
# Example shapes: [130, 512]

# Ensure the tensors are on the same device as the model

with torch.no_grad():
        train_day7_feats_minmaxed = train_day7_feats_minmaxed.to(device)
        train_day10_feats_minmaxed = train_day10_feats_minmaxed.to(device)

        predicted_day10 = model(train_day7_feats_minmaxed)

print(predicted_day10.shape)

# Initialize the MSE loss function
mse_loss_fn = nn.MSELoss(reduction='none')  # 'none' to get element-wise loss

# Compute the per-feature-vector MSE
mse_per_vector = mse_loss_fn(train_day10_feats_minmaxed, predicted_day10).mean(dim=1)  # Mean over feature dimension (512)

# Convert MSE values to a list for plotting
mse_values = mse_per_vector.cpu().numpy()

# Calculate statistics
mean_mse = mse_per_vector.mean().item()
std_mse = mse_per_vector.std().item()
min_mse = mse_per_vector.min().item()
max_mse = mse_per_vector.max().item()

# Plot the distribution of MSE values
plt.figure(figsize=(10, 6))
plt.hist(mse_values, bins=5, alpha=0.7, density=True, label=f"Mean: {mean_mse:.4f}, Std: {std_mse:.4f}")

# Add vertical lines for min and max
plt.axvline(min_mse, color='green', linestyle='--', linewidth=1, label=f"Min: {min_mse:.4f}")
plt.axvline(max_mse, color='red', linestyle='--', linewidth=1, label=f"Max: {max_mse:.4f}")

plt.title('Distribution of MSE Loss for Feature Vectors')
plt.xlabel('MSE')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# torch.Size([130, 512])

# %%
mse_values.shape

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn

# Assume train_day7_feats_minmaxed and train_day10_feats_minmaxed are already loaded
# Example shapes: [130, 512]

# Ensure the tensors are on the same device as the model
train_day7_feats_minmaxed = train_day7_feats_minmaxed.to(device)
train_day10_feats_minmaxed = train_day10_feats_minmaxed.to(device)

# Initialize the MSE loss function
mse_loss_fn = nn.MSELoss()

# List to store MSE for each feature vector
mse_values = []

# Loop through each feature vector
for i in range(train_day7_feats_minmaxed.shape[0]):
    train_day7_feat = train_day7_feats_minmaxed[i].unsqueeze(0)  # Shape: [1, 512]
    train_day10_feat = train_day10_feats_minmaxed[i].unsqueeze(0)  # Shape: [1, 512]
    
    # Get prediction
    with torch.no_grad():
        predicted_day10 = model(train_day7_feat)
    
    # Compute MSE for this feature vector
    mse = mse_loss_fn(predicted_day10, train_day10_feat).item()
    mse_values.append(mse)

# Convert MSE values to a tensor for statistical calculations
mse_values_tensor = torch.tensor(mse_values)

# Calculate mean and standard deviation
mean_mse = mse_values_tensor.mean().item()
std_mse = mse_values_tensor.std().item()

print(f"Mean MSE: {mean_mse:.4f}, Standard Deviation: {std_mse:.4f}")

# Plot the distribution of MSE values
plt.figure(figsize=(10, 6))
plt.hist(mse_values, bins=30, alpha=0.7, density=True, label=f"Mean: {mean_mse:.4f}, Std: {std_mse:.4f}")
plt.title('Distribution of MSE Loss for Feature Vectors')
plt.xlabel('MSE')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean MSE: 0.0074, Standard Deviation: 0.0057

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn

# Assume train_day7_feats_minmaxed and train_day10_feats_minmaxed are already loaded
# Example shapes: [130, 512]

# Ensure the tensors are on the same device as the model
train_day7_feats_minmaxed = train_day7_feats_minmaxed.to(device)
train_day10_feats_minmaxed = train_day10_feats_minmaxed.to(device)

# Initialize the MSE loss function
mse_loss_fn = nn.MSELoss()

# List to store MSE for each feature vector
mse_values = []

# Loop through each feature vector
for i in range(train_day7_feats_minmaxed.shape[0]):
    train_day7_feat = train_day7_feats_minmaxed[i].unsqueeze(0)  # Shape: [1, 512]
    train_day10_feat = train_day10_feats_minmaxed[i].unsqueeze(0)  # Shape: [1, 512]
    
    # Get prediction
    with torch.no_grad():
        predicted_day10 = model(train_day7_feat)
    
    # Compute MSE for this feature vector
    mse = mse_loss_fn(predicted_day10, train_day10_feat).item()
    mse_values.append(mse)

# Convert MSE values to a tensor for statistical calculations
mse_values_tensor = torch.tensor(mse_values)

# Calculate mean and standard deviation
mean_mse = mse_values_tensor.mean().item()
std_mse = mse_values_tensor.std().item()

print(f"Mean MSE: {mean_mse:.4f}, Standard Deviation: {std_mse:.4f}")

# Plot the distribution of MSE values
plt.figure(figsize=(10, 6))
plt.hist(mse_values, bins=5, alpha=0.7, density=True, label=f"Mean: {mean_mse:.4f}, Std: {std_mse:.4f}")
plt.title('Distribution of MSE Loss for Feature Vectors')
plt.xlabel('MSE')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# %%
#control trained
#torch.Size([130, 512])
#Mean MSE: 0.0074, Standard Deviation: 0.0057


#inference sd
#torch.Size([29, 512])
#Mean MSE: 0.0356, Standard Deviation: 0.0089

# %% [markdown]
# # inference

# %%
# Min-Max Scaling for Input (X) and Target (Y)
def min_max_scaling(data):
    data_min = data.min()
    data_max = data.max()
    return (data - data_min) / (data_max - data_min), data_min, data_max  # Return scaled data and min/max for inverse scaling

# Apply Min-Max Scaling
inference_sd_day7_minmaxed, day7_min, day7_max = min_max_scaling(inference_sd_day7)
inference_sd_day10_minmaxed, day10_min, day10_max = min_max_scaling(inference_sd_day10)
print(day7_min)
print(day7_max)
print(day10_min)
print(day10_max)
# Print summary to confirm
print("After Min-Max Scaling:")
print(f"Input (X): Min={inference_sd_day7_minmaxed.min():.4f}, Max={inference_sd_day7_minmaxed.max():.4f}")
print(f"Target (Y): Min={inference_sd_day10_minmaxed.min():.4f}, Max={inference_sd_day10_minmaxed.max():.4f}")
# Out:
# tensor(0.)
# tensor(6.5900)
# tensor(0.)
# tensor(11.7951)
# After Min-Max Scaling:
# Input (X): Min=0.0000, Max=1.0000
# Target (Y): Min=0.0000, Max=1.0000

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn

# Assume inference_sd_day7_minmaxed and inference_sd_day10_minmaxed are already loaded and processed
with torch.no_grad():
    inference_sd_day7_minmaxed = inference_sd_day7_minmaxed.to(device)
    inference_sd_day10_minmaxed = inference_sd_day10_minmaxed.to(device)

    predicted_day10 = model(inference_sd_day7_minmaxed)

print(predicted_day10.shape)

# Initialize the MSE loss function
mse_loss_fn = nn.MSELoss(reduction='none')  # 'none' to get element-wise loss

# Compute the per-feature-vector MSE
mse_per_vector = mse_loss_fn(inference_sd_day10_minmaxed, predicted_day10).mean(dim=1)  # Mean over feature dimension (512)

# Convert MSE values to a list for plotting
mse_values = mse_per_vector.cpu().numpy()

# Calculate statistics
mean_mse = mse_per_vector.mean().item()
std_mse = mse_per_vector.std().item()
min_mse = mse_per_vector.min().item()
max_mse = mse_per_vector.max().item()

print(f"Mean MSE: {mean_mse:.4f}, Standard Deviation: {std_mse:.4f}")
print(f"Min MSE: {min_mse:.4f}, Max MSE: {max_mse:.4f}")

# Plot the distribution of MSE values
plt.figure(figsize=(10, 6))
import numpy as np

optimal_bins = int(np.sqrt(len(mse_values)))

print(optimal_bins)  # Calculate the number of bins based on the data size
plt.hist(mse_values, bins=optimal_bins, alpha=0.7, density=True, label=f"Mean: {mean_mse:.4f}, Std: {std_mse:.4f}")


# Add vertical lines for min and max
plt.axvline(min_mse, color='green', linestyle='--', linewidth=1, label=f"Min: {min_mse:.4f}")
plt.axvline(max_mse, color='red', linestyle='--', linewidth=1, label=f"Max: {max_mse:.4f}")

plt.title('Distribution of MSE Loss for Feature Vectors')
plt.xlabel('MSE')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# torch.Size([29, 512])
# Mean MSE: 0.0356, Standard Deviation: 0.0089
# Min MSE: 0.0221, Max MSE: 0.0570
# 5

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn

# Assume inference_sd_day7_minmaxed and inference_sd_day10_minmaxed are already loaded and processed
with torch.no_grad():
    inference_sd_day7_minmaxed = inference_sd_day7_minmaxed.to(device)
    inference_sd_day10_minmaxed = inference_sd_day10_minmaxed.to(device)

    predicted_day10 = model(inference_sd_day7_minmaxed)

print(predicted_day10.shape)

# Initialize the MSE loss function
mse_loss_fn = nn.MSELoss(reduction='none')  # 'none' to get element-wise loss

# Compute the per-feature-vector MSE
mse_per_vector = mse_loss_fn(inference_sd_day10_minmaxed, predicted_day10).mean(dim=1)  # Mean over feature dimension (512)

# Convert MSE values to a list for plotting
mse_values = mse_per_vector.cpu().numpy()

# Calculate statistics
mean_mse = mse_per_vector.mean().item()
std_mse = mse_per_vector.std().item()
min_mse = mse_per_vector.min().item()
max_mse = mse_per_vector.max().item()

print(f"Mean MSE: {mean_mse:.4f}, Standard Deviation: {std_mse:.4f}")
print(f"Min MSE: {min_mse:.4f}, Max MSE: {max_mse:.4f}")

# Plot the distribution of MSE values
plt.figure(figsize=(10, 6))
plt.hist(mse_values, bins=30, alpha=0.7, density=True, label=f"Mean: {mean_mse:.4f}, Std: {std_mse:.4f}")

# Add vertical lines for min and max
plt.axvline(min_mse, color='green', linestyle='--', linewidth=1, label=f"Min: {min_mse:.4f}")
plt.axvline(max_mse, color='red', linestyle='--', linewidth=1, label=f"Max: {max_mse:.4f}")

plt.title('Distribution of MSE Loss for Feature Vectors')
plt.xlabel('MSE')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# torch.Size([29, 512])
# Mean MSE: 0.0356, Standard Deviation: 0.0089
# Min MSE: 0.0221, Max MSE: 0.0570

# %%
mse_values.shape
# Out:
# (29,)

# %% [markdown]
# import torch
# import matplotlib.pyplot as plt
# import torch.nn as nn
#
# # Ensure the tensors are on the same device as the model
#
# with torch.no_grad():
#         inference_sd_day7_minmaxed = inference_sd_day7_minmaxed.to(device)
#         inference_sd_day10_minmaxed = inference_sd_day10_minmaxed.to(device)
#
#         predicted_day10 = model(inference_sd_day7_minmaxed)
#
# print(predicted_day10.shape)
#
# # Initialize the MSE loss function
# mse_loss_fn = nn.MSELoss(reduction='none')  # 'none' to get element-wise loss
#
# # Compute the per-feature-vector MSE
# mse_per_vector = mse_loss_fn(inference_sd_day10_minmaxed, predicted_day10).mean(dim=1)  # Mean over feature dimension (512)
#
# # Convert MSE values to a list for plotting
# mse_values = mse_per_vector.cpu().numpy()
#
# # Calculate statistics
# mean_mse = mse_per_vector.mean().item()
# std_mse = mse_per_vector.std().item()
#
# print(f"Mean MSE: {mean_mse:.4f}, Standard Deviation: {std_mse:.4f}")
#
# # Plot the distribution of MSE values
# plt.figure(figsize=(10, 6))
# plt.hist(mse_values, bins=30, alpha=0.7, density=True, label=f"Mean: {mean_mse:.4f}, Std: {std_mse:.4f}")
# plt.title('Distribution of MSE Loss for Feature Vectors')
# plt.xlabel('MSE')
# plt.ylabel('Density')
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn

# Ensure the tensors are on the same device as the model
inference_sd_day7_minmaxed = inference_sd_day7_minmaxed.to(device)
inference_sd_day10_minmaxed = inference_sd_day10_minmaxed.to(device)

# Initialize the MSE loss function
mse_loss_fn = nn.MSELoss()

# List to store MSE for each feature vector
mse_values = []

# Loop through each feature vector
for i in range(inference_sd_day7_minmaxed.shape[0]):
    inference_sd_day7 = inference_sd_day7_minmaxed[i].unsqueeze(0)  # Shape: [1, 512]
    inference_sd_day10 = inference_sd_day10_minmaxed[i].unsqueeze(0)  # Shape: [1, 512]
    
    # Get prediction
    with torch.no_grad():
        predicted_day10 = model(inference_sd_day7)
    
    # Compute MSE for this feature vector
    mse = mse_loss_fn(predicted_day10, inference_sd_day10).item()
    mse_values.append(mse)

# Convert MSE values to a tensor for statistical calculations
mse_values_tensor = torch.tensor(mse_values)

# Calculate mean, standard deviation, min, and max
mean_mse = mse_values_tensor.mean().item()
std_mse = mse_values_tensor.std().item()
min_mse = mse_values_tensor.min().item()
max_mse = mse_values_tensor.max().item()

print(f"Mean MSE: {mean_mse:.4f}, Standard Deviation: {std_mse:.4f}")
print(f"Min MSE: {min_mse:.4f}, Max MSE: {max_mse:.4f}")

# Plot the distribution of MSE values
plt.figure(figsize=(10, 6))
plt.hist(mse_values, bins=30, alpha=0.7, density=True, label=f"Mean: {mean_mse:.4f}, Std: {std_mse:.4f}")

# Add vertical lines for min and max values
plt.axvline(min_mse, color='green', linestyle='--', linewidth=1, label=f"Min: {min_mse:.4f}")
plt.axvline(max_mse, color='red', linestyle='--', linewidth=1, label=f"Max: {max_mse:.4f}")

plt.title('Distribution of MSE Loss for Feature Vectors')
plt.xlabel('MSE')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean MSE: 0.0356, Standard Deviation: 0.0089
# Min MSE: 0.0221, Max MSE: 0.0570

# %% [markdown]
# import torch
# import matplotlib.pyplot as plt
# import torch.nn as nn
#
# # Assume train_day7_feats_minmaxed and train_day10_feats_minmaxed are already loaded
# # Example shapes: [130, 512]
#
# # Ensure the tensors are on the same device as the model
# inference_sd_day7_minmaxed = inference_sd_day7_minmaxed.to(device)
# inference_sd_day10_minmaxed = inference_sd_day10_minmaxed.to(device)
#
# # Initialize the MSE loss function
# mse_loss_fn = nn.MSELoss()
#
# # List to store MSE for each feature vector
# mse_values = []
#
# # Loop through each feature vector
# for i in range(inference_sd_day7_minmaxed.shape[0]):
#     inference_sd_day7 = inference_sd_day7_minmaxed[i].unsqueeze(0)  # Shape: [1, 512]
#     inference_sd_day10 = inference_sd_day10_minmaxed[i].unsqueeze(0)  # Shape: [1, 512]
#
#     # Get prediction
#     with torch.no_grad():
#         predicted_day10 = model(inference_sd_day7)
#
#     # Compute MSE for this feature vector
#     mse = mse_loss_fn(predicted_day10, inference_sd_day10).item()
#     mse_values.append(mse)
#
# # Convert MSE values to a tensor for statistical calculations
# mse_values_tensor = torch.tensor(mse_values)
#
# # Calculate mean and standard deviation
# mean_mse = mse_values_tensor.mean().item()
# std_mse = mse_values_tensor.std().item()
#
# print(f"Mean MSE: {mean_mse:.4f}, Standard Deviation: {std_mse:.4f}")
#
# # Plot the distribution of MSE values
# plt.figure(figsize=(10, 6))
# plt.hist(mse_values, bins=30, alpha=0.7, density=True, label=f"Mean: {mean_mse:.4f}, Std: {std_mse:.4f}")
# plt.title('Distribution of MSE Loss for Feature Vectors')
# plt.xlabel('MSE')
# plt.ylabel('Density')
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
# Perform inference
with torch.no_grad():
    # Ensure the input features are on the same device as the model
    inference_sd_day7_minmaxed = inference_sd_day7_minmaxed.to(device)
    inference_sd_day10_minmaxed = inference_sd_day10_minmaxed.to(device)
    
    # Predict the target (Day 10) from the input (Day 7)
    predicted_day10 = model(inference_sd_day7_minmaxed)

# Evaluate predictions (optional)
# If you have a target (e.g., inference_feat_day10_minmaxed), calculate MSE or another metric
mse_loss = nn.MSELoss()(predicted_day10, inference_sd_day10_minmaxed)
print(f"Mean Squared Error on Inference Data: {mse_loss.item():.4f}")

# Print or save the predictions
print("Predicted Target (Day 10 features):")
print(predicted_day10.cpu().numpy())
print(predicted_day10.shape)
# Out:
# Mean Squared Error on Inference Data: 0.0356
# Predicted Target (Day 10 features):
# [[ 0.03824107 -0.00809979  0.26290122 ...  0.19787881  0.0905065
#    0.13490143]
#  [ 0.13701724  0.04185124  0.18898141 ...  0.37782115  0.3402086
#    0.38382533]
#  [ 0.13669428  0.04162186  0.18533179 ...  0.3726402   0.33925337
#    0.37942627]
#  ...
#  [ 0.1408076   0.04361168  0.19064978 ...  0.38572806  0.3474722
#    0.3929438 ]
#  [ 0.10590675  0.02734081  0.17735776 ...  0.30963027  0.2760213
#    0.30296117]
#  [ 0.14663166  0.04642853  0.19253469 ...  0.39802122  0.358813
#    0.4065541 ]]
# torch.Size([29, 512])

# %% [markdown]
# def train_and_evaluate(
#     model,
#     train_loader,
#     val_loader,
#     criterion,
#     optimizer,
#     num_epochs=50,
#     device='cuda' if torch.cuda.is_available() else 'cpu'
# ):
#
#     model = model.to(device)
#     history = {'train_loss': [], 'val_loss': []}
#
#     for epoch in range(num_epochs):
#         # Training phase
#         model.train()
#         train_loss = 0.0
#         for batch_inputs, batch_targets in train_loader:
#             # Move data to the appropriate device
#             batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)
#
#             # Forward pass
#             outputs = model(batch_inputs)
#             loss = criterion(outputs, batch_targets)
#             train_loss += loss.item()
#
#             # Backward and optimize
#             optimizer.zero_grad()
#             loss.backward()
#             optimizer.step()
#
#         train_loss /= len(train_loader)
#         history['train_loss'].append(train_loss)
#
#         # Validation phase
#         model.eval()
#         val_loss = 0.0
#         with torch.no_grad():
#             for batch_inputs, batch_targets in val_loader:
#                 # Move data to the appropriate device
#                 batch_inputs, batch_targets = batch_inputs.to(device), batch_targets.to(device)
#
#                 # Forward pass
#                 outputs = model(batch_inputs)
#                 loss = criterion(outputs, batch_targets)
#                 val_loss += loss.item()
#
#         val_loss /= len(val_loader)
#         history['val_loss'].append(val_loss)
#
#         # Print epoch stats
#         print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}')
#
#     return history

# %% [markdown]
# def cross_validate_and_train(
#     model_class,  # Pass the class, not an instance
#     dataset,
#     criterion,
#     optimizer_class,
#     num_epochs=50,
#     n_splits=5,
#     device='cuda' if torch.cuda.is_available() else 'cpu'
# ):
#     """
#     Perform cross-validation and train the model on each fold.
#
#     Args:
#         model_class: The class of the model to train (not an instance).
#         dataset: The dataset containing features and targets.
#         criterion: The loss function.
#         optimizer_class: The optimizer class (e.g., torch.optim.Adam).
#         num_epochs: Number of epochs for each fold.
#         n_splits: Number of cross-validation splits.
#         device: Device to use for training ('cuda' or 'cpu').
#
#     Returns:
#         list: A list containing the history (losses) for each fold.
#     """
#     kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
#     histories = []
#
#     for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset)):
#         print(f"Fold {fold + 1}/{n_splits}")
#
#         # Create subsets for this fold
#         train_subset = Subset(dataset, train_idx)
#         val_subset = Subset(dataset, val_idx)
#
#         # Create DataLoaders
#         train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
#         val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)
#
#         # Initialize the model and optimizer for this fold
#         model = model_class().to(device)
#         optimizer = optimizer_class(model.parameters(), lr=1e-4)
#
#         # Train and evaluate for this fold
#         history = train_and_evaluate(
#             model=model,
#             train_loader=train_loader,
#             val_loader=val_loader,
#             criterion=criterion,
#             optimizer=optimizer,
#             num_epochs=num_epochs,
#             device=device
#         )
#
#         histories.append(history)
#
#     return histories

# %% [markdown]
# dataset = TensorDataset(train_day7_feats, train_day10_feats)
#
# # Perform cross-validation
# cv_histories = cross_validate_and_train(
#     model_class=FeaturePredictor,  # Pass the model class
#     dataset=dataset,
#     criterion=criterion,
#     optimizer_class=torch.optim.Adam,
#     num_epochs=1000,
#     n_splits=5
# )

# %% [markdown]
# import matplotlib.pyplot as plt
#
# def plot_loss_curves(cv_histories, num_epochs):
#     """
#     Plot training and validation loss curves for each fold.
#
#     Args:
#         cv_histories (list): List of loss histories for each fold.
#         num_epochs (int): Number of epochs.
#     """
#     plt.figure(figsize=(10, 6))
#
#     for fold, history in enumerate(cv_histories):
#         epochs = range(1, num_epochs + 1)
#         plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
#         plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
#
#     plt.title('Training and Validation Loss per Fold')
#     plt.xlabel('Epochs')
#     plt.ylabel('Loss')
#     plt.legend()
#     plt.grid(True)
#     plt.show()
#
# # Example usage
# plot_loss_curves(cv_histories, num_epochs=1000)

# %% [markdown]
# import matplotlib.pyplot as plt
#
# def plot_loss_curves_separately(cv_histories, num_epochs):
#     """
#     Plot training and validation loss curves for each fold in separate figures.
#
#     Args:
#         cv_histories (list): List of loss histories for each fold.
#         num_epochs (int): Number of epochs.
#     """
#     # Plot Training Loss
#     plt.figure(figsize=(10, 6))
#     for fold, history in enumerate(cv_histories):
#         epochs = range(1, num_epochs + 1)
#         plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
#     plt.title('Training Loss per Fold')
#     plt.xlabel('Epochs')
#     plt.ylabel('Loss')
#     plt.legend()
#     plt.grid(True)
#     plt.show()
#
#     # Plot Validation Loss
#     plt.figure(figsize=(10, 6))
#     for fold, history in enumerate(cv_histories):
#         epochs = range(1, num_epochs + 1)
#         plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
#     plt.title('Validation Loss per Fold')
#     plt.xlabel('Epochs')
#     plt.ylabel('Loss')
#     plt.legend()
#     plt.grid(True)
#     plt.show()
#
# # Example usage
# plot_loss_curves_separately(cv_histories, num_epochs=1000)

# %% [markdown]
# # Average the training and validation losses across folds
# avg_train_loss = np.mean([history['train_loss'][-1] for history in cv_histories])
# avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
#
# print(f"Average Training Loss: {avg_train_loss:.4f}")
# print(f"Average Validation Loss: {avg_val_loss:.4f}")
