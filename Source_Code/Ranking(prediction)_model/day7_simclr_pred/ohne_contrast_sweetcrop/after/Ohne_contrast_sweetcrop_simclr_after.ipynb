# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import pandas as pd

# %%
# Load the CSV file
df = pd.read_csv("cond7_combined_features.csv")

# Extract paths, labels, and features
loaded_paths = df["path"].tolist()
loaded_labels = df["label"].tolist()
loaded_features = torch.tensor(df["features"].apply(eval).to_list(), dtype=torch.float32)
feats = loaded_features
print(df.head())
print(f"Loaded features shape: {loaded_features.shape}")
print(f"Loaded paths: {len(loaded_paths)}")
print(f"Loaded labels: {len(loaded_labels)}")
# Out:
#                                                 path label  \
# 0  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
# 1  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
# 2  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
# 3  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
# 4  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
#
#                                             features
# 0  [0.8690898418426514, 2.59390926361084, -0.4739...
# 1  [-0.21843068301677704, 4.499393463134766, 1.31...
# 2  [-0.3621220290660858, 1.862504005432129, 0.652...
# 3  [-0.41327592730522156, 2.8305280208587646, -2....
# 4  [-0.186064213514328, 2.6914637088775635, -2.90...
# Loaded features shape: torch.Size([944, 20])
# Loaded paths: 944
# Loaded labels: 944

# %%
import matplotlib.pyplot as plt

# Flatten the features for plotting (if needed)
flattened_features = feats.flatten().numpy()

# Plot the histogram of feature values
plt.figure(figsize=(10, 6))
plt.hist(flattened_features, bins=50, alpha=0.7, color='blue', edgecolor='black')
plt.title("Feature Value Distribution")
plt.xlabel("Feature Value")
plt.ylabel("Frequency")
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# # plot z score normalised

# %%
features_mean = feats.mean(dim=0, keepdim=True)
features_std = feats.std(dim=0, keepdim=True)

normalized_feats = (feats - features_mean) / features_std

# Check the new distribution
flattened_normalized_features = normalized_feats.flatten().numpy()

# Plot the normalized distribution
plt.figure(figsize=(10, 6))
plt.hist(flattened_normalized_features, bins=50, alpha=0.7, color='green', edgecolor='black')
plt.title("Normalized Feature Value Distribution (Standardized)")
plt.xlabel("Feature Value")
plt.ylabel("Frequency")
plt.grid(alpha=0.3)
plt.show()

# %%
from torch.utils.data import TensorDataset
dataset = TensorDataset(normalized_feats)
len(dataset)
# Out:
# 944

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch.nn as nn

class FeaturePredictor(nn.Module):
    def __init__(self, input_size=20, output_size=20):
        super(FeaturePredictor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 16),
            nn.ReLU(),
            nn.Linear(16, 8),
            nn.ReLU(),
            nn.Linear(8, 4),
            nn.ReLU(),
            nn.Linear(4, 8),
            nn.ReLU(),
            nn.Linear(8, 16),
            nn.ReLU(),
            nn.Linear(16,output_size)
        )
    
    def forward(self, x):
        return self.model(x)

# %%
model = FeaturePredictor()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
optimizer_class = torch.optim.Adam

from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset
import numpy as np
import torch

# %%
class EarlyStopping:
    def __init__(self, patience=10, delta=0.0):
        """
        Args:
            patience (int): How many epochs to wait after the last validation loss improvement.
            delta (float): Minimum change in the validation loss to qualify as an improvement.
        """
        self.patience = patience
        self.delta = delta
        self.best_loss = None
        self.no_improvement_epochs = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.no_improvement_epochs = 0
        else:
            self.no_improvement_epochs += 1
            if self.no_improvement_epochs >= self.patience:
                self.early_stop = True


def cross_validate_with_early_stopping(
    model_class, dataset, criterion, optimizer_class, num_epochs=50, n_splits=5, patience=10, delta=0.0, device='cuda'
):
    """
    Cross-validation with early stopping.

    Args:
        model_class: The model class to initialize.
        dataset: The dataset to perform cross-validation on.
        criterion: Loss function.
        optimizer_class: Optimizer class to use.
        num_epochs: Maximum number of epochs for training.
        n_splits: Number of cross-validation splits.
        patience: Number of epochs to wait for validation loss improvement.
        delta: Minimum change in validation loss to consider as improvement.
        device: Device to run the model on ('cuda' or 'cpu').

    Returns:
        histories: A list of training/validation loss histories for each fold.
        best_models: A list of best model states for each fold.
    """
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    histories = []
    best_models = []

    for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset)):
        print(f"Fold {fold + 1}/{n_splits}")

        # Create subsets for this fold
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        # Create DataLoaders
        train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

        # Initialize the model, optimizer, and early stopping for this fold
        model = model_class().to(device)
        optimizer = optimizer_class(model.parameters(), lr=1e-4)
        early_stopping = EarlyStopping(patience=patience, delta=delta)  # Pass delta here

        # Training and validation loop
        history = {'train_loss': [], 'val_loss': []}
        for epoch in range(num_epochs):
            # Training phase
            model.train()
            train_loss = 0.0
            for batch_feats in train_loader:
                batch_feats = batch_feats[0].to(device)

                # Forward pass
                outputs = model(batch_feats)
                loss = criterion(outputs, batch_feats)
                train_loss += loss.item()

                # Backward pass and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            train_loss /= len(train_loader)
            history['train_loss'].append(train_loss)

            # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for batch_feats in val_loader:
                    batch_feats = batch_feats[0].to(device)
                    outputs = model(batch_feats)
                    loss = criterion(outputs, batch_feats)
                    val_loss += loss.item()

            val_loss /= len(val_loader)
            history['val_loss'].append(val_loss)

            print(f"Epoch [{epoch + 1}/{num_epochs}] Fold {fold + 1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

            # Check early stopping
            early_stopping(val_loss)
            if early_stopping.early_stop:
                print(f"Early stopping at epoch {epoch + 1} for fold {fold + 1}")
                break

        # Save the best model for this fold
        best_models.append(model.state_dict())
        histories.append(history)

    return histories, best_models

# %%
cv_histories, best_models = cross_validate_with_early_stopping(
    model_class=FeaturePredictor,
    dataset=dataset,
    criterion=nn.MSELoss(),
    optimizer_class=torch.optim.Adam,
    num_epochs=4000,
    patience=500,
    delta=0.0000  # Example delta value
)
# Out:
# Fold 1/5
# Epoch [1/4000] Fold 1, Train Loss: 1.0307, Val Loss: 1.0508
# Epoch [2/4000] Fold 1, Train Loss: 1.0265, Val Loss: 1.0487
# Epoch [3/4000] Fold 1, Train Loss: 1.0246, Val Loss: 1.0466
# Epoch [4/4000] Fold 1, Train Loss: 1.0221, Val Loss: 1.0447
# Epoch [5/4000] Fold 1, Train Loss: 1.0198, Val Loss: 1.0430
# Epoch [6/4000] Fold 1, Train Loss: 1.0168, Val Loss: 1.0414
# Epoch [7/4000] Fold 1, Train Loss: 1.0185, Val Loss: 1.0399
# Epoch [8/4000] Fold 1, Train Loss: 1.0133, Val Loss: 1.0384
# Epoch [9/4000] Fold 1, Train Loss: 1.0147, Val Loss: 1.0370
# Epoch [10/4000] Fold 1, Train Loss: 1.0104, Val Loss: 1.0357
# Epoch [11/4000] Fold 1, Train Loss: 1.0111, Val Loss: 1.0343
# Epoch [12/4000] Fold 1, Train Loss: 1.0110, Val Loss: 1.0331
# Epoch [13/4000] Fold 1, Train Loss: 1.0098, Val Loss: 1.0318
# Epoch [14/4000] Fold 1, Train Loss: 1.0070, Val Loss: 1.0305
# Epoch [15/4000] Fold 1, Train Loss: 1.0056, Val Loss: 1.0292
# Epoch [16/4000] Fold 1, Train Loss: 1.0040, Val Loss: 1.0277
# Epoch [17/4000] Fold 1, Train Loss: 1.0017, Val Loss: 1.0262
# Epoch [18/4000] Fold 1, Train Loss: 1.0018, Val Loss: 1.0247
# Epoch [19/4000] Fold 1, Train Loss: 0.9978, Val Loss: 1.0230
# Epoch [20/4000] Fold 1, Train Loss: 0.9983, Val Loss: 1.0213
# Epoch [21/4000] Fold 1, Train Loss: 0.9974, Val Loss: 1.0193
# Epoch [22/4000] Fold 1, Train Loss: 0.9916, Val Loss: 1.0172
# Epoch [23/4000] Fold 1, Train Loss: 0.9923, Val Loss: 1.0147
# Epoch [24/4000] Fold 1, Train Loss: 0.9889, Val Loss: 1.0120
# Epoch [25/4000] Fold 1, Train Loss: 0.9846, Val Loss: 1.0092
# Epoch [26/4000] Fold 1, Train Loss: 0.9815, Val Loss: 1.0061
# Epoch [27/4000] Fold 1, Train Loss: 0.9810, Val Loss: 1.0029
# Epoch [28/4000] Fold 1, Train Loss: 0.9762, Val Loss: 0.9994
# Epoch [29/4000] Fold 1, Train Loss: 0.9726, Val Loss: 0.9957
# Epoch [30/4000] Fold 1, Train Loss: 0.9671, Val Loss: 0.9920
# Epoch [31/4000] Fold 1, Train Loss: 0.9621, Val Loss: 0.9880
# Epoch [32/4000] Fold 1, Train Loss: 0.9579, Val Loss: 0.9839
# Epoch [33/4000] Fold 1, Train Loss: 0.9560, Val Loss: 0.9798
# Epoch [34/4000] Fold 1, Train Loss: 0.9497, Val Loss: 0.9758
# Epoch [35/4000] Fold 1, Train Loss: 0.9458, Val Loss: 0.9720
# Epoch [36/4000] Fold 1, Train Loss: 0.9419, Val Loss: 0.9681
# Epoch [37/4000] Fold 1, Train Loss: 0.9394, Val Loss: 0.9646
# Epoch [38/4000] Fold 1, Train Loss: 0.9333, Val Loss: 0.9612
# Epoch [39/4000] Fold 1, Train Loss: 0.9302, Val Loss: 0.9582
# Epoch [40/4000] Fold 1, Train Loss: 0.9306, Val Loss: 0.9555
# Epoch [41/4000] Fold 1, Train Loss: 0.9258, Val Loss: 0.9531
# Epoch [42/4000] Fold 1, Train Loss: 0.9245, Val Loss: 0.9508
# Epoch [43/4000] Fold 1, Train Loss: 0.9193, Val Loss: 0.9489
# Epoch [44/4000] Fold 1, Train Loss: 0.9169, Val Loss: 0.9470
# Epoch [45/4000] Fold 1, Train Loss: 0.9153, Val Loss: 0.9455
# Epoch [46/4000] Fold 1, Train Loss: 0.9167, Val Loss: 0.9440
# Epoch [47/4000] Fold 1, Train Loss: 0.9127, Val Loss: 0.9427
# Epoch [48/4000] Fold 1, Train Loss: 0.9143, Val Loss: 0.9414
# Epoch [49/4000] Fold 1, Train Loss: 0.9107, Val Loss: 0.9402
# Epoch [50/4000] Fold 1, Train Loss: 0.9107, Val Loss: 0.9391
# Epoch [51/4000] Fold 1, Train Loss: 0.9089, Val Loss: 0.9380
# Epoch [52/4000] Fold 1, Train Loss: 0.9093, Val Loss: 0.9370
# Epoch [53/4000] Fold 1, Train Loss: 0.9084, Val Loss: 0.9361
# Epoch [54/4000] Fold 1, Train Loss: 0.9054, Val Loss: 0.9352
# Epoch [55/4000] Fold 1, Train Loss: 0.9041, Val Loss: 0.9343
# Epoch [56/4000] Fold 1, Train Loss: 0.9020, Val Loss: 0.9334
# Epoch [57/4000] Fold 1, Train Loss: 0.9013, Val Loss: 0.9326
# Epoch [58/4000] Fold 1, Train Loss: 0.9040, Val Loss: 0.9319
# Epoch [59/4000] Fold 1, Train Loss: 0.9018, Val Loss: 0.9311
# Epoch [60/4000] Fold 1, Train Loss: 0.8999, Val Loss: 0.9305
# Epoch [61/4000] Fold 1, Train Loss: 0.8991, Val Loss: 0.9298
# Epoch [62/4000] Fold 1, Train Loss: 0.8991, Val Loss: 0.9292
# Epoch [63/4000] Fold 1, Train Loss: 0.9007, Val Loss: 0.9285
# Epoch [64/4000] Fold 1, Train Loss: 0.8981, Val Loss: 0.9278
# Epoch [65/4000] Fold 1, Train Loss: 0.8987, Val Loss: 0.9273
# Epoch [66/4000] Fold 1, Train Loss: 0.8969, Val Loss: 0.9267
# Epoch [67/4000] Fold 1, Train Loss: 0.8935, Val Loss: 0.9261
# Epoch [68/4000] Fold 1, Train Loss: 0.8959, Val Loss: 0.9256
# Epoch [69/4000] Fold 1, Train Loss: 0.8958, Val Loss: 0.9250
# Epoch [70/4000] Fold 1, Train Loss: 0.8915, Val Loss: 0.9245
# Epoch [71/4000] Fold 1, Train Loss: 0.8939, Val Loss: 0.9240
# Epoch [72/4000] Fold 1, Train Loss: 0.8938, Val Loss: 0.9234
# Epoch [73/4000] Fold 1, Train Loss: 0.8914, Val Loss: 0.9229
# Epoch [74/4000] Fold 1, Train Loss: 0.8906, Val Loss: 0.9223
# Epoch [75/4000] Fold 1, Train Loss: 0.8931, Val Loss: 0.9218
# Epoch [76/4000] Fold 1, Train Loss: 0.8932, Val Loss: 0.9213
# Epoch [77/4000] Fold 1, Train Loss: 0.8924, Val Loss: 0.9208
# Epoch [78/4000] Fold 1, Train Loss: 0.8891, Val Loss: 0.9203
# Epoch [79/4000] Fold 1, Train Loss: 0.8909, Val Loss: 0.9198
# Epoch [80/4000] Fold 1, Train Loss: 0.8907, Val Loss: 0.9193
# Epoch [81/4000] Fold 1, Train Loss: 0.8882, Val Loss: 0.9187
# Epoch [82/4000] Fold 1, Train Loss: 0.8870, Val Loss: 0.9183
# Epoch [83/4000] Fold 1, Train Loss: 0.8899, Val Loss: 0.9178
# Epoch [84/4000] Fold 1, Train Loss: 0.8880, Val Loss: 0.9172
# Epoch [85/4000] Fold 1, Train Loss: 0.8854, Val Loss: 0.9168
# Epoch [86/4000] Fold 1, Train Loss: 0.8857, Val Loss: 0.9162
# Epoch [87/4000] Fold 1, Train Loss: 0.8845, Val Loss: 0.9157
# Epoch [88/4000] Fold 1, Train Loss: 0.8869, Val Loss: 0.9152
# Epoch [89/4000] Fold 1, Train Loss: 0.8869, Val Loss: 0.9146
# Epoch [90/4000] Fold 1, Train Loss: 0.8849, Val Loss: 0.9141
# Epoch [91/4000] Fold 1, Train Loss: 0.8844, Val Loss: 0.9136
# Epoch [92/4000] Fold 1, Train Loss: 0.8842, Val Loss: 0.9131
# Epoch [93/4000] Fold 1, Train Loss: 0.8850, Val Loss: 0.9125
# Epoch [94/4000] Fold 1, Train Loss: 0.8841, Val Loss: 0.9120
# Epoch [95/4000] Fold 1, Train Loss: 0.8813, Val Loss: 0.9113
# Epoch [96/4000] Fold 1, Train Loss: 0.8796, Val Loss: 0.9108
# Epoch [97/4000] Fold 1, Train Loss: 0.8797, Val Loss: 0.9102
# Epoch [98/4000] Fold 1, Train Loss: 0.8801, Val Loss: 0.9095
# Epoch [99/4000] Fold 1, Train Loss: 0.8790, Val Loss: 0.9088
# Epoch [100/4000] Fold 1, Train Loss: 0.8788, Val Loss: 0.9082
# Epoch [101/4000] Fold 1, Train Loss: 0.8776, Val Loss: 0.9074
# Epoch [102/4000] Fold 1, Train Loss: 0.8782, Val Loss: 0.9067
# Epoch [103/4000] Fold 1, Train Loss: 0.8767, Val Loss: 0.9059
# Epoch [104/4000] Fold 1, Train Loss: 0.8742, Val Loss: 0.9050
# Epoch [105/4000] Fold 1, Train Loss: 0.8756, Val Loss: 0.9042
# Epoch [106/4000] Fold 1, Train Loss: 0.8748, Val Loss: 0.9032
# Epoch [107/4000] Fold 1, Train Loss: 0.8730, Val Loss: 0.9021
# Epoch [108/4000] Fold 1, Train Loss: 0.8713, Val Loss: 0.9010
# Epoch [109/4000] Fold 1, Train Loss: 0.8692, Val Loss: 0.8999
# Epoch [110/4000] Fold 1, Train Loss: 0.8685, Val Loss: 0.8987
# Epoch [111/4000] Fold 1, Train Loss: 0.8695, Val Loss: 0.8974
# Epoch [112/4000] Fold 1, Train Loss: 0.8663, Val Loss: 0.8961
# Epoch [113/4000] Fold 1, Train Loss: 0.8652, Val Loss: 0.8947
# Epoch [114/4000] Fold 1, Train Loss: 0.8630, Val Loss: 0.8931
# Epoch [115/4000] Fold 1, Train Loss: 0.8654, Val Loss: 0.8916
# Epoch [116/4000] Fold 1, Train Loss: 0.8615, Val Loss: 0.8900
# Epoch [117/4000] Fold 1, Train Loss: 0.8596, Val Loss: 0.8883
# Epoch [118/4000] Fold 1, Train Loss: 0.8582, Val Loss: 0.8865
# Epoch [119/4000] Fold 1, Train Loss: 0.8574, Val Loss: 0.8846
# Epoch [120/4000] Fold 1, Train Loss: 0.8557, Val Loss: 0.8826
# Epoch [121/4000] Fold 1, Train Loss: 0.8537, Val Loss: 0.8806
# Epoch [122/4000] Fold 1, Train Loss: 0.8513, Val Loss: 0.8783
# Epoch [123/4000] Fold 1, Train Loss: 0.8500, Val Loss: 0.8759
# Epoch [124/4000] Fold 1, Train Loss: 0.8461, Val Loss: 0.8734
# Epoch [125/4000] Fold 1, Train Loss: 0.8475, Val Loss: 0.8709
# Epoch [126/4000] Fold 1, Train Loss: 0.8434, Val Loss: 0.8684
# Epoch [127/4000] Fold 1, Train Loss: 0.8411, Val Loss: 0.8661
# Epoch [128/4000] Fold 1, Train Loss: 0.8391, Val Loss: 0.8637
# Epoch [129/4000] Fold 1, Train Loss: 0.8357, Val Loss: 0.8613
# Epoch [130/4000] Fold 1, Train Loss: 0.8343, Val Loss: 0.8588
# Epoch [131/4000] Fold 1, Train Loss: 0.8320, Val Loss: 0.8564
# Epoch [132/4000] Fold 1, Train Loss: 0.8299, Val Loss: 0.8540
# Epoch [133/4000] Fold 1, Train Loss: 0.8289, Val Loss: 0.8518
# Epoch [134/4000] Fold 1, Train Loss: 0.8266, Val Loss: 0.8497
# Epoch [135/4000] Fold 1, Train Loss: 0.8235, Val Loss: 0.8476
# Epoch [136/4000] Fold 1, Train Loss: 0.8224, Val Loss: 0.8456
# Epoch [137/4000] Fold 1, Train Loss: 0.8230, Val Loss: 0.8438
# Epoch [138/4000] Fold 1, Train Loss: 0.8175, Val Loss: 0.8418
# Epoch [139/4000] Fold 1, Train Loss: 0.8151, Val Loss: 0.8400
# Epoch [140/4000] Fold 1, Train Loss: 0.8158, Val Loss: 0.8381
# Epoch [141/4000] Fold 1, Train Loss: 0.8158, Val Loss: 0.8363
# Epoch [142/4000] Fold 1, Train Loss: 0.8124, Val Loss: 0.8345
# Epoch [143/4000] Fold 1, Train Loss: 0.8137, Val Loss: 0.8326
# Epoch [144/4000] Fold 1, Train Loss: 0.8126, Val Loss: 0.8309
# Epoch [145/4000] Fold 1, Train Loss: 0.8099, Val Loss: 0.8290
# Epoch [146/4000] Fold 1, Train Loss: 0.8045, Val Loss: 0.8274
# Epoch [147/4000] Fold 1, Train Loss: 0.8066, Val Loss: 0.8257
# Epoch [148/4000] Fold 1, Train Loss: 0.8007, Val Loss: 0.8241
# Epoch [149/4000] Fold 1, Train Loss: 0.8022, Val Loss: 0.8223
# Epoch [150/4000] Fold 1, Train Loss: 0.8006, Val Loss: 0.8210
# Epoch [151/4000] Fold 1, Train Loss: 0.7998, Val Loss: 0.8194
# Epoch [152/4000] Fold 1, Train Loss: 0.7973, Val Loss: 0.8175
# Epoch [153/4000] Fold 1, Train Loss: 0.7992, Val Loss: 0.8163
# Epoch [154/4000] Fold 1, Train Loss: 0.7978, Val Loss: 0.8149
# Epoch [155/4000] Fold 1, Train Loss: 0.7964, Val Loss: 0.8134
# Epoch [156/4000] Fold 1, Train Loss: 0.7942, Val Loss: 0.8124
# Epoch [157/4000] Fold 1, Train Loss: 0.7922, Val Loss: 0.8109
# Epoch [158/4000] Fold 1, Train Loss: 0.7915, Val Loss: 0.8097
# Epoch [159/4000] Fold 1, Train Loss: 0.7896, Val Loss: 0.8086
# Epoch [160/4000] Fold 1, Train Loss: 0.7877, Val Loss: 0.8075
# Epoch [161/4000] Fold 1, Train Loss: 0.7884, Val Loss: 0.8061
# Epoch [162/4000] Fold 1, Train Loss: 0.7867, Val Loss: 0.8053
# Epoch [163/4000] Fold 1, Train Loss: 0.7846, Val Loss: 0.8041
# Epoch [164/4000] Fold 1, Train Loss: 0.7869, Val Loss: 0.8033
# Epoch [165/4000] Fold 1, Train Loss: 0.7851, Val Loss: 0.8022
# Epoch [166/4000] Fold 1, Train Loss: 0.7840, Val Loss: 0.8015
# Epoch [167/4000] Fold 1, Train Loss: 0.7827, Val Loss: 0.8005
# Epoch [168/4000] Fold 1, Train Loss: 0.7818, Val Loss: 0.7995
# Epoch [169/4000] Fold 1, Train Loss: 0.7787, Val Loss: 0.7990
# Epoch [170/4000] Fold 1, Train Loss: 0.7822, Val Loss: 0.7982
# Epoch [171/4000] Fold 1, Train Loss: 0.7780, Val Loss: 0.7971
# Epoch [172/4000] Fold 1, Train Loss: 0.7782, Val Loss: 0.7964
# Epoch [173/4000] Fold 1, Train Loss: 0.7759, Val Loss: 0.7957
# Epoch [174/4000] Fold 1, Train Loss: 0.7750, Val Loss: 0.7947
# Epoch [175/4000] Fold 1, Train Loss: 0.7732, Val Loss: 0.7941
# Epoch [176/4000] Fold 1, Train Loss: 0.7752, Val Loss: 0.7934
# Epoch [177/4000] Fold 1, Train Loss: 0.7741, Val Loss: 0.7926
# Epoch [178/4000] Fold 1, Train Loss: 0.7714, Val Loss: 0.7921
# Epoch [179/4000] Fold 1, Train Loss: 0.7739, Val Loss: 0.7913
# Epoch [180/4000] Fold 1, Train Loss: 0.7691, Val Loss: 0.7906
# Epoch [181/4000] Fold 1, Train Loss: 0.7693, Val Loss: 0.7899
# Epoch [182/4000] Fold 1, Train Loss: 0.7702, Val Loss: 0.7893
# Epoch [183/4000] Fold 1, Train Loss: 0.7679, Val Loss: 0.7885
# Epoch [184/4000] Fold 1, Train Loss: 0.7666, Val Loss: 0.7880
# Epoch [185/4000] Fold 1, Train Loss: 0.7672, Val Loss: 0.7875
# Epoch [186/4000] Fold 1, Train Loss: 0.7658, Val Loss: 0.7869
# Epoch [187/4000] Fold 1, Train Loss: 0.7660, Val Loss: 0.7865
# Epoch [188/4000] Fold 1, Train Loss: 0.7642, Val Loss: 0.7856
# Epoch [189/4000] Fold 1, Train Loss: 0.7638, Val Loss: 0.7849
# Epoch [190/4000] Fold 1, Train Loss: 0.7641, Val Loss: 0.7846
# Epoch [191/4000] Fold 1, Train Loss: 0.7615, Val Loss: 0.7838
# Epoch [192/4000] Fold 1, Train Loss: 0.7606, Val Loss: 0.7835
# Epoch [193/4000] Fold 1, Train Loss: 0.7612, Val Loss: 0.7830
# Epoch [194/4000] Fold 1, Train Loss: 0.7613, Val Loss: 0.7824
# Epoch [195/4000] Fold 1, Train Loss: 0.7622, Val Loss: 0.7820
# Epoch [196/4000] Fold 1, Train Loss: 0.7590, Val Loss: 0.7813
# Epoch [197/4000] Fold 1, Train Loss: 0.7594, Val Loss: 0.7806
# Epoch [198/4000] Fold 1, Train Loss: 0.7582, Val Loss: 0.7803
# Epoch [199/4000] Fold 1, Train Loss: 0.7573, Val Loss: 0.7796
# Epoch [200/4000] Fold 1, Train Loss: 0.7566, Val Loss: 0.7791
# Epoch [201/4000] Fold 1, Train Loss: 0.7573, Val Loss: 0.7785
# Epoch [202/4000] Fold 1, Train Loss: 0.7552, Val Loss: 0.7780
# Epoch [203/4000] Fold 1, Train Loss: 0.7529, Val Loss: 0.7777
# Epoch [204/4000] Fold 1, Train Loss: 0.7564, Val Loss: 0.7771
# Epoch [205/4000] Fold 1, Train Loss: 0.7530, Val Loss: 0.7763
# Epoch [206/4000] Fold 1, Train Loss: 0.7527, Val Loss: 0.7760
# Epoch [207/4000] Fold 1, Train Loss: 0.7513, Val Loss: 0.7756
# Epoch [208/4000] Fold 1, Train Loss: 0.7545, Val Loss: 0.7751
# Epoch [209/4000] Fold 1, Train Loss: 0.7499, Val Loss: 0.7747
# Epoch [210/4000] Fold 1, Train Loss: 0.7490, Val Loss: 0.7741
# Epoch [211/4000] Fold 1, Train Loss: 0.7480, Val Loss: 0.7738
# Epoch [212/4000] Fold 1, Train Loss: 0.7501, Val Loss: 0.7735
# Epoch [213/4000] Fold 1, Train Loss: 0.7484, Val Loss: 0.7730
# Epoch [214/4000] Fold 1, Train Loss: 0.7499, Val Loss: 0.7726
# Epoch [215/4000] Fold 1, Train Loss: 0.7471, Val Loss: 0.7720
# Epoch [216/4000] Fold 1, Train Loss: 0.7497, Val Loss: 0.7716
# Epoch [217/4000] Fold 1, Train Loss: 0.7470, Val Loss: 0.7709
# Epoch [218/4000] Fold 1, Train Loss: 0.7465, Val Loss: 0.7708
# Epoch [219/4000] Fold 1, Train Loss: 0.7449, Val Loss: 0.7703
# Epoch [220/4000] Fold 1, Train Loss: 0.7479, Val Loss: 0.7701
# Epoch [221/4000] Fold 1, Train Loss: 0.7450, Val Loss: 0.7696
# Epoch [222/4000] Fold 1, Train Loss: 0.7461, Val Loss: 0.7690
# Epoch [223/4000] Fold 1, Train Loss: 0.7444, Val Loss: 0.7685
# Epoch [224/4000] Fold 1, Train Loss: 0.7439, Val Loss: 0.7682
# Epoch [225/4000] Fold 1, Train Loss: 0.7425, Val Loss: 0.7681
# Epoch [226/4000] Fold 1, Train Loss: 0.7434, Val Loss: 0.7677
# Epoch [227/4000] Fold 1, Train Loss: 0.7419, Val Loss: 0.7674
# Epoch [228/4000] Fold 1, Train Loss: 0.7417, Val Loss: 0.7669
# Epoch [229/4000] Fold 1, Train Loss: 0.7420, Val Loss: 0.7667
# Epoch [230/4000] Fold 1, Train Loss: 0.7391, Val Loss: 0.7663
# Epoch [231/4000] Fold 1, Train Loss: 0.7410, Val Loss: 0.7662
# Epoch [232/4000] Fold 1, Train Loss: 0.7399, Val Loss: 0.7656
# Epoch [233/4000] Fold 1, Train Loss: 0.7399, Val Loss: 0.7655
# Epoch [234/4000] Fold 1, Train Loss: 0.7389, Val Loss: 0.7649
# Epoch [235/4000] Fold 1, Train Loss: 0.7401, Val Loss: 0.7644
# Epoch [236/4000] Fold 1, Train Loss: 0.7390, Val Loss: 0.7641
# Epoch [237/4000] Fold 1, Train Loss: 0.7410, Val Loss: 0.7639
# Epoch [238/4000] Fold 1, Train Loss: 0.7359, Val Loss: 0.7634
# Epoch [239/4000] Fold 1, Train Loss: 0.7381, Val Loss: 0.7630
# Epoch [240/4000] Fold 1, Train Loss: 0.7374, Val Loss: 0.7629
# Epoch [241/4000] Fold 1, Train Loss: 0.7382, Val Loss: 0.7627
# Epoch [242/4000] Fold 1, Train Loss: 0.7396, Val Loss: 0.7623
# Epoch [243/4000] Fold 1, Train Loss: 0.7384, Val Loss: 0.7620
# Epoch [244/4000] Fold 1, Train Loss: 0.7365, Val Loss: 0.7616
# Epoch [245/4000] Fold 1, Train Loss: 0.7361, Val Loss: 0.7610
# Epoch [246/4000] Fold 1, Train Loss: 0.7356, Val Loss: 0.7608
# Epoch [247/4000] Fold 1, Train Loss: 0.7331, Val Loss: 0.7607
# Epoch [248/4000] Fold 1, Train Loss: 0.7349, Val Loss: 0.7605
# Epoch [249/4000] Fold 1, Train Loss: 0.7335, Val Loss: 0.7601
# Epoch [250/4000] Fold 1, Train Loss: 0.7334, Val Loss: 0.7601
# Epoch [251/4000] Fold 1, Train Loss: 0.7343, Val Loss: 0.7595
# Epoch [252/4000] Fold 1, Train Loss: 0.7323, Val Loss: 0.7594
# Epoch [253/4000] Fold 1, Train Loss: 0.7315, Val Loss: 0.7590
# Epoch [254/4000] Fold 1, Train Loss: 0.7335, Val Loss: 0.7587
# Epoch [255/4000] Fold 1, Train Loss: 0.7299, Val Loss: 0.7588
# Epoch [256/4000] Fold 1, Train Loss: 0.7303, Val Loss: 0.7585
# Epoch [257/4000] Fold 1, Train Loss: 0.7301, Val Loss: 0.7581
# Epoch [258/4000] Fold 1, Train Loss: 0.7330, Val Loss: 0.7577
# Epoch [259/4000] Fold 1, Train Loss: 0.7324, Val Loss: 0.7574
# Epoch [260/4000] Fold 1, Train Loss: 0.7305, Val Loss: 0.7572
# Epoch [261/4000] Fold 1, Train Loss: 0.7299, Val Loss: 0.7570
# Epoch [262/4000] Fold 1, Train Loss: 0.7314, Val Loss: 0.7568
# Epoch [263/4000] Fold 1, Train Loss: 0.7289, Val Loss: 0.7565
# Epoch [264/4000] Fold 1, Train Loss: 0.7275, Val Loss: 0.7561
# Epoch [265/4000] Fold 1, Train Loss: 0.7290, Val Loss: 0.7560
# Epoch [266/4000] Fold 1, Train Loss: 0.7303, Val Loss: 0.7557
# Epoch [267/4000] Fold 1, Train Loss: 0.7284, Val Loss: 0.7555
# Epoch [268/4000] Fold 1, Train Loss: 0.7281, Val Loss: 0.7553
# Epoch [269/4000] Fold 1, Train Loss: 0.7282, Val Loss: 0.7554
# Epoch [270/4000] Fold 1, Train Loss: 0.7286, Val Loss: 0.7549
# Epoch [271/4000] Fold 1, Train Loss: 0.7275, Val Loss: 0.7544
# Epoch [272/4000] Fold 1, Train Loss: 0.7272, Val Loss: 0.7544
# Epoch [273/4000] Fold 1, Train Loss: 0.7249, Val Loss: 0.7542
# Epoch [274/4000] Fold 1, Train Loss: 0.7283, Val Loss: 0.7541
# Epoch [275/4000] Fold 1, Train Loss: 0.7246, Val Loss: 0.7538
# Epoch [276/4000] Fold 1, Train Loss: 0.7248, Val Loss: 0.7535
# Epoch [277/4000] Fold 1, Train Loss: 0.7253, Val Loss: 0.7529
# Epoch [278/4000] Fold 1, Train Loss: 0.7256, Val Loss: 0.7528
# Epoch [279/4000] Fold 1, Train Loss: 0.7238, Val Loss: 0.7530
# Epoch [280/4000] Fold 1, Train Loss: 0.7237, Val Loss: 0.7527
# Epoch [281/4000] Fold 1, Train Loss: 0.7228, Val Loss: 0.7522
# Epoch [282/4000] Fold 1, Train Loss: 0.7233, Val Loss: 0.7523
# Epoch [283/4000] Fold 1, Train Loss: 0.7219, Val Loss: 0.7519
# Epoch [284/4000] Fold 1, Train Loss: 0.7243, Val Loss: 0.7518
# Epoch [285/4000] Fold 1, Train Loss: 0.7230, Val Loss: 0.7517
# Epoch [286/4000] Fold 1, Train Loss: 0.7247, Val Loss: 0.7516
# Epoch [287/4000] Fold 1, Train Loss: 0.7227, Val Loss: 0.7513
# Epoch [288/4000] Fold 1, Train Loss: 0.7207, Val Loss: 0.7511
# Epoch [289/4000] Fold 1, Train Loss: 0.7210, Val Loss: 0.7509
# Epoch [290/4000] Fold 1, Train Loss: 0.7218, Val Loss: 0.7507
# Epoch [291/4000] Fold 1, Train Loss: 0.7211, Val Loss: 0.7504
# Epoch [292/4000] Fold 1, Train Loss: 0.7234, Val Loss: 0.7504
# Epoch [293/4000] Fold 1, Train Loss: 0.7206, Val Loss: 0.7501
# Epoch [294/4000] Fold 1, Train Loss: 0.7220, Val Loss: 0.7501
# Epoch [295/4000] Fold 1, Train Loss: 0.7194, Val Loss: 0.7499
# Epoch [296/4000] Fold 1, Train Loss: 0.7180, Val Loss: 0.7497
# Epoch [297/4000] Fold 1, Train Loss: 0.7171, Val Loss: 0.7495
# Epoch [298/4000] Fold 1, Train Loss: 0.7203, Val Loss: 0.7497
# Epoch [299/4000] Fold 1, Train Loss: 0.7193, Val Loss: 0.7492
# Epoch [300/4000] Fold 1, Train Loss: 0.7211, Val Loss: 0.7491
# Epoch [301/4000] Fold 1, Train Loss: 0.7189, Val Loss: 0.7488
# Epoch [302/4000] Fold 1, Train Loss: 0.7194, Val Loss: 0.7486
# Epoch [303/4000] Fold 1, Train Loss: 0.7171, Val Loss: 0.7484
# Epoch [304/4000] Fold 1, Train Loss: 0.7197, Val Loss: 0.7484
# Epoch [305/4000] Fold 1, Train Loss: 0.7190, Val Loss: 0.7481
# Epoch [306/4000] Fold 1, Train Loss: 0.7172, Val Loss: 0.7480
# Epoch [307/4000] Fold 1, Train Loss: 0.7157, Val Loss: 0.7478
# Epoch [308/4000] Fold 1, Train Loss: 0.7180, Val Loss: 0.7479
# Epoch [309/4000] Fold 1, Train Loss: 0.7187, Val Loss: 0.7476
# Epoch [310/4000] Fold 1, Train Loss: 0.7185, Val Loss: 0.7473
# Epoch [311/4000] Fold 1, Train Loss: 0.7171, Val Loss: 0.7474
# Epoch [312/4000] Fold 1, Train Loss: 0.7174, Val Loss: 0.7470
# Epoch [313/4000] Fold 1, Train Loss: 0.7167, Val Loss: 0.7470
# Epoch [314/4000] Fold 1, Train Loss: 0.7160, Val Loss: 0.7470
# Epoch [315/4000] Fold 1, Train Loss: 0.7149, Val Loss: 0.7465
# Epoch [316/4000] Fold 1, Train Loss: 0.7175, Val Loss: 0.7466
# Epoch [317/4000] Fold 1, Train Loss: 0.7169, Val Loss: 0.7462
# Epoch [318/4000] Fold 1, Train Loss: 0.7157, Val Loss: 0.7463
# Epoch [319/4000] Fold 1, Train Loss: 0.7136, Val Loss: 0.7458
# Epoch [320/4000] Fold 1, Train Loss: 0.7147, Val Loss: 0.7460
# Epoch [321/4000] Fold 1, Train Loss: 0.7146, Val Loss: 0.7459
# Epoch [322/4000] Fold 1, Train Loss: 0.7151, Val Loss: 0.7459
# Epoch [323/4000] Fold 1, Train Loss: 0.7135, Val Loss: 0.7453
# Epoch [324/4000] Fold 1, Train Loss: 0.7152, Val Loss: 0.7454
# Epoch [325/4000] Fold 1, Train Loss: 0.7160, Val Loss: 0.7454
# Epoch [326/4000] Fold 1, Train Loss: 0.7137, Val Loss: 0.7453
# Epoch [327/4000] Fold 1, Train Loss: 0.7161, Val Loss: 0.7451
# Epoch [328/4000] Fold 1, Train Loss: 0.7136, Val Loss: 0.7448
# Epoch [329/4000] Fold 1, Train Loss: 0.7135, Val Loss: 0.7447
# Epoch [330/4000] Fold 1, Train Loss: 0.7135, Val Loss: 0.7446
# Epoch [331/4000] Fold 1, Train Loss: 0.7142, Val Loss: 0.7446
# Epoch [332/4000] Fold 1, Train Loss: 0.7129, Val Loss: 0.7443
# Epoch [333/4000] Fold 1, Train Loss: 0.7147, Val Loss: 0.7441
# Epoch [334/4000] Fold 1, Train Loss: 0.7142, Val Loss: 0.7442
# Epoch [335/4000] Fold 1, Train Loss: 0.7127, Val Loss: 0.7439
# Epoch [336/4000] Fold 1, Train Loss: 0.7142, Val Loss: 0.7436
# Epoch [337/4000] Fold 1, Train Loss: 0.7136, Val Loss: 0.7436
# Epoch [338/4000] Fold 1, Train Loss: 0.7127, Val Loss: 0.7438
# Epoch [339/4000] Fold 1, Train Loss: 0.7117, Val Loss: 0.7434
# Epoch [340/4000] Fold 1, Train Loss: 0.7124, Val Loss: 0.7434
# Epoch [341/4000] Fold 1, Train Loss: 0.7112, Val Loss: 0.7433
# Epoch [342/4000] Fold 1, Train Loss: 0.7126, Val Loss: 0.7432
# Epoch [343/4000] Fold 1, Train Loss: 0.7134, Val Loss: 0.7430
# Epoch [344/4000] Fold 1, Train Loss: 0.7115, Val Loss: 0.7431
# Epoch [345/4000] Fold 1, Train Loss: 0.7115, Val Loss: 0.7426
# Epoch [346/4000] Fold 1, Train Loss: 0.7123, Val Loss: 0.7428
# Epoch [347/4000] Fold 1, Train Loss: 0.7125, Val Loss: 0.7428
# Epoch [348/4000] Fold 1, Train Loss: 0.7099, Val Loss: 0.7428
# Epoch [349/4000] Fold 1, Train Loss: 0.7111, Val Loss: 0.7423
# Epoch [350/4000] Fold 1, Train Loss: 0.7116, Val Loss: 0.7424
# Epoch [351/4000] Fold 1, Train Loss: 0.7100, Val Loss: 0.7420
# Epoch [352/4000] Fold 1, Train Loss: 0.7115, Val Loss: 0.7421
# Epoch [353/4000] Fold 1, Train Loss: 0.7099, Val Loss: 0.7421
# Epoch [354/4000] Fold 1, Train Loss: 0.7121, Val Loss: 0.7418
# Epoch [355/4000] Fold 1, Train Loss: 0.7115, Val Loss: 0.7420
# Epoch [356/4000] Fold 1, Train Loss: 0.7119, Val Loss: 0.7417
# Epoch [357/4000] Fold 1, Train Loss: 0.7091, Val Loss: 0.7414
# Epoch [358/4000] Fold 1, Train Loss: 0.7089, Val Loss: 0.7413
# Epoch [359/4000] Fold 1, Train Loss: 0.7090, Val Loss: 0.7414
# Epoch [360/4000] Fold 1, Train Loss: 0.7094, Val Loss: 0.7413
# Epoch [361/4000] Fold 1, Train Loss: 0.7083, Val Loss: 0.7411
# Epoch [362/4000] Fold 1, Train Loss: 0.7092, Val Loss: 0.7411
# Epoch [363/4000] Fold 1, Train Loss: 0.7094, Val Loss: 0.7412
# Epoch [364/4000] Fold 1, Train Loss: 0.7079, Val Loss: 0.7410
# Epoch [365/4000] Fold 1, Train Loss: 0.7083, Val Loss: 0.7409
# Epoch [366/4000] Fold 1, Train Loss: 0.7109, Val Loss: 0.7405
# Epoch [367/4000] Fold 1, Train Loss: 0.7081, Val Loss: 0.7402
# Epoch [368/4000] Fold 1, Train Loss: 0.7090, Val Loss: 0.7403
# Epoch [369/4000] Fold 1, Train Loss: 0.7075, Val Loss: 0.7404
# Epoch [370/4000] Fold 1, Train Loss: 0.7078, Val Loss: 0.7401
# Epoch [371/4000] Fold 1, Train Loss: 0.7068, Val Loss: 0.7400
# Epoch [372/4000] Fold 1, Train Loss: 0.7065, Val Loss: 0.7403
# Epoch [373/4000] Fold 1, Train Loss: 0.7071, Val Loss: 0.7401
# Epoch [374/4000] Fold 1, Train Loss: 0.7082, Val Loss: 0.7397
# Epoch [375/4000] Fold 1, Train Loss: 0.7075, Val Loss: 0.7397
# Epoch [376/4000] Fold 1, Train Loss: 0.7063, Val Loss: 0.7395
# Epoch [377/4000] Fold 1, Train Loss: 0.7065, Val Loss: 0.7394
# Epoch [378/4000] Fold 1, Train Loss: 0.7054, Val Loss: 0.7393
# Epoch [379/4000] Fold 1, Train Loss: 0.7074, Val Loss: 0.7392
# Epoch [380/4000] Fold 1, Train Loss: 0.7086, Val Loss: 0.7393
# Epoch [381/4000] Fold 1, Train Loss: 0.7071, Val Loss: 0.7389
# Epoch [382/4000] Fold 1, Train Loss: 0.7058, Val Loss: 0.7389
# Epoch [383/4000] Fold 1, Train Loss: 0.7075, Val Loss: 0.7390
# Epoch [384/4000] Fold 1, Train Loss: 0.7079, Val Loss: 0.7388
# Epoch [385/4000] Fold 1, Train Loss: 0.7058, Val Loss: 0.7387
# Epoch [386/4000] Fold 1, Train Loss: 0.7075, Val Loss: 0.7386
# Epoch [387/4000] Fold 1, Train Loss: 0.7090, Val Loss: 0.7383
# Epoch [388/4000] Fold 1, Train Loss: 0.7051, Val Loss: 0.7381
# Epoch [389/4000] Fold 1, Train Loss: 0.7043, Val Loss: 0.7379
# Epoch [390/4000] Fold 1, Train Loss: 0.7079, Val Loss: 0.7379
# Epoch [391/4000] Fold 1, Train Loss: 0.7070, Val Loss: 0.7378
# Epoch [392/4000] Fold 1, Train Loss: 0.7064, Val Loss: 0.7378
# Epoch [393/4000] Fold 1, Train Loss: 0.7062, Val Loss: 0.7379
# Epoch [394/4000] Fold 1, Train Loss: 0.7045, Val Loss: 0.7377
# Epoch [395/4000] Fold 1, Train Loss: 0.7063, Val Loss: 0.7376
# Epoch [396/4000] Fold 1, Train Loss: 0.7050, Val Loss: 0.7375
# Epoch [397/4000] Fold 1, Train Loss: 0.7054, Val Loss: 0.7376
# Epoch [398/4000] Fold 1, Train Loss: 0.7050, Val Loss: 0.7374
# Epoch [399/4000] Fold 1, Train Loss: 0.7027, Val Loss: 0.7374
# Epoch [400/4000] Fold 1, Train Loss: 0.7044, Val Loss: 0.7372
# Epoch [401/4000] Fold 1, Train Loss: 0.7056, Val Loss: 0.7374
# Epoch [402/4000] Fold 1, Train Loss: 0.7042, Val Loss: 0.7372
# Epoch [403/4000] Fold 1, Train Loss: 0.7038, Val Loss: 0.7370
# Epoch [404/4000] Fold 1, Train Loss: 0.7042, Val Loss: 0.7369
# Epoch [405/4000] Fold 1, Train Loss: 0.7032, Val Loss: 0.7369
# Epoch [406/4000] Fold 1, Train Loss: 0.7052, Val Loss: 0.7367
# Epoch [407/4000] Fold 1, Train Loss: 0.7032, Val Loss: 0.7367
# Epoch [408/4000] Fold 1, Train Loss: 0.7042, Val Loss: 0.7367
# Epoch [409/4000] Fold 1, Train Loss: 0.7031, Val Loss: 0.7366
# Epoch [410/4000] Fold 1, Train Loss: 0.7059, Val Loss: 0.7364
# Epoch [411/4000] Fold 1, Train Loss: 0.7018, Val Loss: 0.7363
# Epoch [412/4000] Fold 1, Train Loss: 0.7033, Val Loss: 0.7363
# Epoch [413/4000] Fold 1, Train Loss: 0.7046, Val Loss: 0.7362
# Epoch [414/4000] Fold 1, Train Loss: 0.7053, Val Loss: 0.7361
# Epoch [415/4000] Fold 1, Train Loss: 0.7043, Val Loss: 0.7361
# Epoch [416/4000] Fold 1, Train Loss: 0.7040, Val Loss: 0.7360
# Epoch [417/4000] Fold 1, Train Loss: 0.7018, Val Loss: 0.7358
# Epoch [418/4000] Fold 1, Train Loss: 0.7036, Val Loss: 0.7360
# Epoch [419/4000] Fold 1, Train Loss: 0.7049, Val Loss: 0.7360
# Epoch [420/4000] Fold 1, Train Loss: 0.7013, Val Loss: 0.7355
# Epoch [421/4000] Fold 1, Train Loss: 0.7021, Val Loss: 0.7357
# Epoch [422/4000] Fold 1, Train Loss: 0.7058, Val Loss: 0.7356
# Epoch [423/4000] Fold 1, Train Loss: 0.7047, Val Loss: 0.7355
# Epoch [424/4000] Fold 1, Train Loss: 0.7027, Val Loss: 0.7356
# Epoch [425/4000] Fold 1, Train Loss: 0.7005, Val Loss: 0.7353
# Epoch [426/4000] Fold 1, Train Loss: 0.7027, Val Loss: 0.7354
# Epoch [427/4000] Fold 1, Train Loss: 0.7025, Val Loss: 0.7353
# Epoch [428/4000] Fold 1, Train Loss: 0.7031, Val Loss: 0.7353
# Epoch [429/4000] Fold 1, Train Loss: 0.7020, Val Loss: 0.7351
# Epoch [430/4000] Fold 1, Train Loss: 0.7031, Val Loss: 0.7353
# Epoch [431/4000] Fold 1, Train Loss: 0.7017, Val Loss: 0.7351
# Epoch [432/4000] Fold 1, Train Loss: 0.7030, Val Loss: 0.7348
# Epoch [433/4000] Fold 1, Train Loss: 0.7018, Val Loss: 0.7350
# Epoch [434/4000] Fold 1, Train Loss: 0.7005, Val Loss: 0.7350
# Epoch [435/4000] Fold 1, Train Loss: 0.6997, Val Loss: 0.7347
# Epoch [436/4000] Fold 1, Train Loss: 0.6989, Val Loss: 0.7350
# Epoch [437/4000] Fold 1, Train Loss: 0.7017, Val Loss: 0.7343
# Epoch [438/4000] Fold 1, Train Loss: 0.7029, Val Loss: 0.7346
# Epoch [439/4000] Fold 1, Train Loss: 0.7023, Val Loss: 0.7341
# Epoch [440/4000] Fold 1, Train Loss: 0.7016, Val Loss: 0.7345
# Epoch [441/4000] Fold 1, Train Loss: 0.7011, Val Loss: 0.7346
# Epoch [442/4000] Fold 1, Train Loss: 0.6987, Val Loss: 0.7343
# Epoch [443/4000] Fold 1, Train Loss: 0.6996, Val Loss: 0.7340
# Epoch [444/4000] Fold 1, Train Loss: 0.7007, Val Loss: 0.7342
# Epoch [445/4000] Fold 1, Train Loss: 0.7011, Val Loss: 0.7343
# Epoch [446/4000] Fold 1, Train Loss: 0.7001, Val Loss: 0.7344
# Epoch [447/4000] Fold 1, Train Loss: 0.7026, Val Loss: 0.7339
# Epoch [448/4000] Fold 1, Train Loss: 0.6994, Val Loss: 0.7335
# Epoch [449/4000] Fold 1, Train Loss: 0.6995, Val Loss: 0.7338
# Epoch [450/4000] Fold 1, Train Loss: 0.6994, Val Loss: 0.7339
# Epoch [451/4000] Fold 1, Train Loss: 0.7003, Val Loss: 0.7336
# Epoch [452/4000] Fold 1, Train Loss: 0.7001, Val Loss: 0.7335
# Epoch [453/4000] Fold 1, Train Loss: 0.7001, Val Loss: 0.7336
# Epoch [454/4000] Fold 1, Train Loss: 0.6999, Val Loss: 0.7337
# Epoch [455/4000] Fold 1, Train Loss: 0.7006, Val Loss: 0.7332
# Epoch [456/4000] Fold 1, Train Loss: 0.6993, Val Loss: 0.7332
# Epoch [457/4000] Fold 1, Train Loss: 0.6999, Val Loss: 0.7336
# Epoch [458/4000] Fold 1, Train Loss: 0.6974, Val Loss: 0.7331
# Epoch [459/4000] Fold 1, Train Loss: 0.6992, Val Loss: 0.7333
# Epoch [460/4000] Fold 1, Train Loss: 0.7000, Val Loss: 0.7332
# Epoch [461/4000] Fold 1, Train Loss: 0.6989, Val Loss: 0.7333
# Epoch [462/4000] Fold 1, Train Loss: 0.6988, Val Loss: 0.7332
# Epoch [463/4000] Fold 1, Train Loss: 0.6988, Val Loss: 0.7331
# Epoch [464/4000] Fold 1, Train Loss: 0.6984, Val Loss: 0.7329
# Epoch [465/4000] Fold 1, Train Loss: 0.6973, Val Loss: 0.7332
# Epoch [466/4000] Fold 1, Train Loss: 0.6988, Val Loss: 0.7329
# Epoch [467/4000] Fold 1, Train Loss: 0.7009, Val Loss: 0.7327
# Epoch [468/4000] Fold 1, Train Loss: 0.6989, Val Loss: 0.7326
# Epoch [469/4000] Fold 1, Train Loss: 0.6976, Val Loss: 0.7327
# Epoch [470/4000] Fold 1, Train Loss: 0.6990, Val Loss: 0.7327
# Epoch [471/4000] Fold 1, Train Loss: 0.6986, Val Loss: 0.7328
# Epoch [472/4000] Fold 1, Train Loss: 0.6957, Val Loss: 0.7323
# Epoch [473/4000] Fold 1, Train Loss: 0.6981, Val Loss: 0.7326
# Epoch [474/4000] Fold 1, Train Loss: 0.6980, Val Loss: 0.7325
# Epoch [475/4000] Fold 1, Train Loss: 0.6994, Val Loss: 0.7323
# Epoch [476/4000] Fold 1, Train Loss: 0.6975, Val Loss: 0.7322
# Epoch [477/4000] Fold 1, Train Loss: 0.6970, Val Loss: 0.7323
# Epoch [478/4000] Fold 1, Train Loss: 0.6945, Val Loss: 0.7322
# Epoch [479/4000] Fold 1, Train Loss: 0.6959, Val Loss: 0.7324
# Epoch [480/4000] Fold 1, Train Loss: 0.6979, Val Loss: 0.7320
# Epoch [481/4000] Fold 1, Train Loss: 0.6960, Val Loss: 0.7321
# Epoch [482/4000] Fold 1, Train Loss: 0.6981, Val Loss: 0.7321
# Epoch [483/4000] Fold 1, Train Loss: 0.6961, Val Loss: 0.7319
# Epoch [484/4000] Fold 1, Train Loss: 0.6972, Val Loss: 0.7320
# Epoch [485/4000] Fold 1, Train Loss: 0.6964, Val Loss: 0.7319
# Epoch [486/4000] Fold 1, Train Loss: 0.6987, Val Loss: 0.7320
# Epoch [487/4000] Fold 1, Train Loss: 0.6964, Val Loss: 0.7320
# Epoch [488/4000] Fold 1, Train Loss: 0.6955, Val Loss: 0.7315
# Epoch [489/4000] Fold 1, Train Loss: 0.6945, Val Loss: 0.7318
# Epoch [490/4000] Fold 1, Train Loss: 0.6939, Val Loss: 0.7317
# Epoch [491/4000] Fold 1, Train Loss: 0.6951, Val Loss: 0.7316
# Epoch [492/4000] Fold 1, Train Loss: 0.6981, Val Loss: 0.7317
# Epoch [493/4000] Fold 1, Train Loss: 0.6961, Val Loss: 0.7316
# Epoch [494/4000] Fold 1, Train Loss: 0.6947, Val Loss: 0.7317
# Epoch [495/4000] Fold 1, Train Loss: 0.6981, Val Loss: 0.7316
# Epoch [496/4000] Fold 1, Train Loss: 0.6962, Val Loss: 0.7315
# Epoch [497/4000] Fold 1, Train Loss: 0.6937, Val Loss: 0.7314
# Epoch [498/4000] Fold 1, Train Loss: 0.6950, Val Loss: 0.7315
# Epoch [499/4000] Fold 1, Train Loss: 0.6959, Val Loss: 0.7315
# Epoch [500/4000] Fold 1, Train Loss: 0.6949, Val Loss: 0.7311
# Epoch [501/4000] Fold 1, Train Loss: 0.6968, Val Loss: 0.7311
# Epoch [502/4000] Fold 1, Train Loss: 0.6952, Val Loss: 0.7309
# Epoch [503/4000] Fold 1, Train Loss: 0.6949, Val Loss: 0.7310
# Epoch [504/4000] Fold 1, Train Loss: 0.6957, Val Loss: 0.7306
# Epoch [505/4000] Fold 1, Train Loss: 0.6956, Val Loss: 0.7313
# Epoch [506/4000] Fold 1, Train Loss: 0.6954, Val Loss: 0.7309
# Epoch [507/4000] Fold 1, Train Loss: 0.6938, Val Loss: 0.7314
# Epoch [508/4000] Fold 1, Train Loss: 0.6966, Val Loss: 0.7309
# Epoch [509/4000] Fold 1, Train Loss: 0.6931, Val Loss: 0.7310
# Epoch [510/4000] Fold 1, Train Loss: 0.6941, Val Loss: 0.7308
# Epoch [511/4000] Fold 1, Train Loss: 0.6959, Val Loss: 0.7309
# Epoch [512/4000] Fold 1, Train Loss: 0.6945, Val Loss: 0.7303
# Epoch [513/4000] Fold 1, Train Loss: 0.6954, Val Loss: 0.7305
# Epoch [514/4000] Fold 1, Train Loss: 0.6942, Val Loss: 0.7306
# Epoch [515/4000] Fold 1, Train Loss: 0.6947, Val Loss: 0.7307
# Epoch [516/4000] Fold 1, Train Loss: 0.6941, Val Loss: 0.7304
# Epoch [517/4000] Fold 1, Train Loss: 0.6929, Val Loss: 0.7304
# Epoch [518/4000] Fold 1, Train Loss: 0.6947, Val Loss: 0.7302
# Epoch [519/4000] Fold 1, Train Loss: 0.6943, Val Loss: 0.7302
# Epoch [520/4000] Fold 1, Train Loss: 0.6941, Val Loss: 0.7306
# Epoch [521/4000] Fold 1, Train Loss: 0.6939, Val Loss: 0.7298
# Epoch [522/4000] Fold 1, Train Loss: 0.6949, Val Loss: 0.7305
# Epoch [523/4000] Fold 1, Train Loss: 0.6940, Val Loss: 0.7304
# Epoch [524/4000] Fold 1, Train Loss: 0.6946, Val Loss: 0.7301
# Epoch [525/4000] Fold 1, Train Loss: 0.6946, Val Loss: 0.7301
# Epoch [526/4000] Fold 1, Train Loss: 0.6929, Val Loss: 0.7301
# Epoch [527/4000] Fold 1, Train Loss: 0.6932, Val Loss: 0.7300
# Epoch [528/4000] Fold 1, Train Loss: 0.6940, Val Loss: 0.7299
# Epoch [529/4000] Fold 1, Train Loss: 0.6947, Val Loss: 0.7302
# Epoch [530/4000] Fold 1, Train Loss: 0.6917, Val Loss: 0.7298
# Epoch [531/4000] Fold 1, Train Loss: 0.6943, Val Loss: 0.7301
# Epoch [532/4000] Fold 1, Train Loss: 0.6929, Val Loss: 0.7297
# Epoch [533/4000] Fold 1, Train Loss: 0.6932, Val Loss: 0.7298
# Epoch [534/4000] Fold 1, Train Loss: 0.6934, Val Loss: 0.7296
# Epoch [535/4000] Fold 1, Train Loss: 0.6934, Val Loss: 0.7295
# Epoch [536/4000] Fold 1, Train Loss: 0.6929, Val Loss: 0.7297
# Epoch [537/4000] Fold 1, Train Loss: 0.6922, Val Loss: 0.7295
# Epoch [538/4000] Fold 1, Train Loss: 0.6920, Val Loss: 0.7294
# Epoch [539/4000] Fold 1, Train Loss: 0.6928, Val Loss: 0.7294
# Epoch [540/4000] Fold 1, Train Loss: 0.6935, Val Loss: 0.7293
# Epoch [541/4000] Fold 1, Train Loss: 0.6933, Val Loss: 0.7295
# Epoch [542/4000] Fold 1, Train Loss: 0.6932, Val Loss: 0.7295
# Epoch [543/4000] Fold 1, Train Loss: 0.6917, Val Loss: 0.7294
# Epoch [544/4000] Fold 1, Train Loss: 0.6920, Val Loss: 0.7291
# Epoch [545/4000] Fold 1, Train Loss: 0.6925, Val Loss: 0.7295
# Epoch [546/4000] Fold 1, Train Loss: 0.6933, Val Loss: 0.7291
# Epoch [547/4000] Fold 1, Train Loss: 0.6928, Val Loss: 0.7294
# Epoch [548/4000] Fold 1, Train Loss: 0.6933, Val Loss: 0.7292
# Epoch [549/4000] Fold 1, Train Loss: 0.6934, Val Loss: 0.7292
# Epoch [550/4000] Fold 1, Train Loss: 0.6902, Val Loss: 0.7287
# Epoch [551/4000] Fold 1, Train Loss: 0.6913, Val Loss: 0.7289
# Epoch [552/4000] Fold 1, Train Loss: 0.6927, Val Loss: 0.7292
# Epoch [553/4000] Fold 1, Train Loss: 0.6911, Val Loss: 0.7290
# Epoch [554/4000] Fold 1, Train Loss: 0.6925, Val Loss: 0.7288
# Epoch [555/4000] Fold 1, Train Loss: 0.6904, Val Loss: 0.7287
# Epoch [556/4000] Fold 1, Train Loss: 0.6910, Val Loss: 0.7290
# Epoch [557/4000] Fold 1, Train Loss: 0.6925, Val Loss: 0.7286
# Epoch [558/4000] Fold 1, Train Loss: 0.6901, Val Loss: 0.7287
# Epoch [559/4000] Fold 1, Train Loss: 0.6931, Val Loss: 0.7285
# Epoch [560/4000] Fold 1, Train Loss: 0.6890, Val Loss: 0.7285
# Epoch [561/4000] Fold 1, Train Loss: 0.6909, Val Loss: 0.7288
# Epoch [562/4000] Fold 1, Train Loss: 0.6911, Val Loss: 0.7286
# Epoch [563/4000] Fold 1, Train Loss: 0.6900, Val Loss: 0.7284
# Epoch [564/4000] Fold 1, Train Loss: 0.6918, Val Loss: 0.7286
# Epoch [565/4000] Fold 1, Train Loss: 0.6899, Val Loss: 0.7287
# Epoch [566/4000] Fold 1, Train Loss: 0.6909, Val Loss: 0.7282
# Epoch [567/4000] Fold 1, Train Loss: 0.6907, Val Loss: 0.7284
# Epoch [568/4000] Fold 1, Train Loss: 0.6905, Val Loss: 0.7281
# Epoch [569/4000] Fold 1, Train Loss: 0.6930, Val Loss: 0.7284
# Epoch [570/4000] Fold 1, Train Loss: 0.6894, Val Loss: 0.7282
# Epoch [571/4000] Fold 1, Train Loss: 0.6895, Val Loss: 0.7281
# Epoch [572/4000] Fold 1, Train Loss: 0.6878, Val Loss: 0.7283
# Epoch [573/4000] Fold 1, Train Loss: 0.6899, Val Loss: 0.7279
# Epoch [574/4000] Fold 1, Train Loss: 0.6895, Val Loss: 0.7280
# Epoch [575/4000] Fold 1, Train Loss: 0.6896, Val Loss: 0.7281
# Epoch [576/4000] Fold 1, Train Loss: 0.6901, Val Loss: 0.7280
# Epoch [577/4000] Fold 1, Train Loss: 0.6900, Val Loss: 0.7279
# Epoch [578/4000] Fold 1, Train Loss: 0.6918, Val Loss: 0.7277
# Epoch [579/4000] Fold 1, Train Loss: 0.6903, Val Loss: 0.7277
# Epoch [580/4000] Fold 1, Train Loss: 0.6915, Val Loss: 0.7278
# Epoch [581/4000] Fold 1, Train Loss: 0.6906, Val Loss: 0.7275
# Epoch [582/4000] Fold 1, Train Loss: 0.6915, Val Loss: 0.7280
# Epoch [583/4000] Fold 1, Train Loss: 0.6889, Val Loss: 0.7276
# Epoch [584/4000] Fold 1, Train Loss: 0.6898, Val Loss: 0.7279
# Epoch [585/4000] Fold 1, Train Loss: 0.6901, Val Loss: 0.7278
# Epoch [586/4000] Fold 1, Train Loss: 0.6893, Val Loss: 0.7275
# Epoch [587/4000] Fold 1, Train Loss: 0.6895, Val Loss: 0.7272
# Epoch [588/4000] Fold 1, Train Loss: 0.6910, Val Loss: 0.7274
# Epoch [589/4000] Fold 1, Train Loss: 0.6884, Val Loss: 0.7273
# Epoch [590/4000] Fold 1, Train Loss: 0.6888, Val Loss: 0.7273
# Epoch [591/4000] Fold 1, Train Loss: 0.6889, Val Loss: 0.7273
# Epoch [592/4000] Fold 1, Train Loss: 0.6896, Val Loss: 0.7274
# Epoch [593/4000] Fold 1, Train Loss: 0.6890, Val Loss: 0.7268
# Epoch [594/4000] Fold 1, Train Loss: 0.6891, Val Loss: 0.7271
# Epoch [595/4000] Fold 1, Train Loss: 0.6875, Val Loss: 0.7271
# Epoch [596/4000] Fold 1, Train Loss: 0.6870, Val Loss: 0.7266
# Epoch [597/4000] Fold 1, Train Loss: 0.6882, Val Loss: 0.7267
# Epoch [598/4000] Fold 1, Train Loss: 0.6884, Val Loss: 0.7267
# Epoch [599/4000] Fold 1, Train Loss: 0.6877, Val Loss: 0.7269
# Epoch [600/4000] Fold 1, Train Loss: 0.6865, Val Loss: 0.7263
# Epoch [601/4000] Fold 1, Train Loss: 0.6854, Val Loss: 0.7264
# Epoch [602/4000] Fold 1, Train Loss: 0.6863, Val Loss: 0.7264
# Epoch [603/4000] Fold 1, Train Loss: 0.6878, Val Loss: 0.7262
# Epoch [604/4000] Fold 1, Train Loss: 0.6861, Val Loss: 0.7263
# Epoch [605/4000] Fold 1, Train Loss: 0.6861, Val Loss: 0.7260
# Epoch [606/4000] Fold 1, Train Loss: 0.6858, Val Loss: 0.7259
# Epoch [607/4000] Fold 1, Train Loss: 0.6851, Val Loss: 0.7257
# Epoch [608/4000] Fold 1, Train Loss: 0.6855, Val Loss: 0.7254
# Epoch [609/4000] Fold 1, Train Loss: 0.6858, Val Loss: 0.7255
# Epoch [610/4000] Fold 1, Train Loss: 0.6845, Val Loss: 0.7252
# Epoch [611/4000] Fold 1, Train Loss: 0.6859, Val Loss: 0.7254
# Epoch [612/4000] Fold 1, Train Loss: 0.6847, Val Loss: 0.7254
# Epoch [613/4000] Fold 1, Train Loss: 0.6848, Val Loss: 0.7250
# Epoch [614/4000] Fold 1, Train Loss: 0.6864, Val Loss: 0.7250
# Epoch [615/4000] Fold 1, Train Loss: 0.6844, Val Loss: 0.7251
# Epoch [616/4000] Fold 1, Train Loss: 0.6841, Val Loss: 0.7249
# Epoch [617/4000] Fold 1, Train Loss: 0.6844, Val Loss: 0.7245
# Epoch [618/4000] Fold 1, Train Loss: 0.6837, Val Loss: 0.7247
# Epoch [619/4000] Fold 1, Train Loss: 0.6833, Val Loss: 0.7245
# Epoch [620/4000] Fold 1, Train Loss: 0.6841, Val Loss: 0.7243
# Epoch [621/4000] Fold 1, Train Loss: 0.6843, Val Loss: 0.7242
# Epoch [622/4000] Fold 1, Train Loss: 0.6846, Val Loss: 0.7239
# Epoch [623/4000] Fold 1, Train Loss: 0.6845, Val Loss: 0.7247
# Epoch [624/4000] Fold 1, Train Loss: 0.6850, Val Loss: 0.7238
# Epoch [625/4000] Fold 1, Train Loss: 0.6845, Val Loss: 0.7240
# Epoch [626/4000] Fold 1, Train Loss: 0.6840, Val Loss: 0.7236
# Epoch [627/4000] Fold 1, Train Loss: 0.6851, Val Loss: 0.7237
# Epoch [628/4000] Fold 1, Train Loss: 0.6822, Val Loss: 0.7233
# Epoch [629/4000] Fold 1, Train Loss: 0.6817, Val Loss: 0.7235
# Epoch [630/4000] Fold 1, Train Loss: 0.6850, Val Loss: 0.7233
# Epoch [631/4000] Fold 1, Train Loss: 0.6840, Val Loss: 0.7230
# Epoch [632/4000] Fold 1, Train Loss: 0.6838, Val Loss: 0.7227
# Epoch [633/4000] Fold 1, Train Loss: 0.6827, Val Loss: 0.7227
# Epoch [634/4000] Fold 1, Train Loss: 0.6803, Val Loss: 0.7228
# Epoch [635/4000] Fold 1, Train Loss: 0.6813, Val Loss: 0.7222
# Epoch [636/4000] Fold 1, Train Loss: 0.6806, Val Loss: 0.7223
# Epoch [637/4000] Fold 1, Train Loss: 0.6822, Val Loss: 0.7221
# Epoch [638/4000] Fold 1, Train Loss: 0.6813, Val Loss: 0.7220
# Epoch [639/4000] Fold 1, Train Loss: 0.6811, Val Loss: 0.7221
# Epoch [640/4000] Fold 1, Train Loss: 0.6807, Val Loss: 0.7221
# Epoch [641/4000] Fold 1, Train Loss: 0.6815, Val Loss: 0.7218
# Epoch [642/4000] Fold 1, Train Loss: 0.6808, Val Loss: 0.7217
# Epoch [643/4000] Fold 1, Train Loss: 0.6801, Val Loss: 0.7212
# Epoch [644/4000] Fold 1, Train Loss: 0.6813, Val Loss: 0.7212
# Epoch [645/4000] Fold 1, Train Loss: 0.6799, Val Loss: 0.7208
# Epoch [646/4000] Fold 1, Train Loss: 0.6810, Val Loss: 0.7211
# Epoch [647/4000] Fold 1, Train Loss: 0.6786, Val Loss: 0.7207
# Epoch [648/4000] Fold 1, Train Loss: 0.6805, Val Loss: 0.7205
# Epoch [649/4000] Fold 1, Train Loss: 0.6776, Val Loss: 0.7203
# Epoch [650/4000] Fold 1, Train Loss: 0.6785, Val Loss: 0.7201
# Epoch [651/4000] Fold 1, Train Loss: 0.6786, Val Loss: 0.7203
# Epoch [652/4000] Fold 1, Train Loss: 0.6779, Val Loss: 0.7200
# Epoch [653/4000] Fold 1, Train Loss: 0.6794, Val Loss: 0.7197
# Epoch [654/4000] Fold 1, Train Loss: 0.6787, Val Loss: 0.7197
# Epoch [655/4000] Fold 1, Train Loss: 0.6785, Val Loss: 0.7194
# Epoch [656/4000] Fold 1, Train Loss: 0.6777, Val Loss: 0.7191
# Epoch [657/4000] Fold 1, Train Loss: 0.6788, Val Loss: 0.7193
# Epoch [658/4000] Fold 1, Train Loss: 0.6766, Val Loss: 0.7192
# Epoch [659/4000] Fold 1, Train Loss: 0.6772, Val Loss: 0.7186
# Epoch [660/4000] Fold 1, Train Loss: 0.6757, Val Loss: 0.7187
# Epoch [661/4000] Fold 1, Train Loss: 0.6769, Val Loss: 0.7188
# Epoch [662/4000] Fold 1, Train Loss: 0.6779, Val Loss: 0.7183
# Epoch [663/4000] Fold 1, Train Loss: 0.6756, Val Loss: 0.7182
# Epoch [664/4000] Fold 1, Train Loss: 0.6766, Val Loss: 0.7177
# Epoch [665/4000] Fold 1, Train Loss: 0.6753, Val Loss: 0.7178
# Epoch [666/4000] Fold 1, Train Loss: 0.6751, Val Loss: 0.7174
# Epoch [667/4000] Fold 1, Train Loss: 0.6734, Val Loss: 0.7178
# Epoch [668/4000] Fold 1, Train Loss: 0.6740, Val Loss: 0.7175
# Epoch [669/4000] Fold 1, Train Loss: 0.6742, Val Loss: 0.7175
# Epoch [670/4000] Fold 1, Train Loss: 0.6761, Val Loss: 0.7170
# Epoch [671/4000] Fold 1, Train Loss: 0.6725, Val Loss: 0.7170
# Epoch [672/4000] Fold 1, Train Loss: 0.6737, Val Loss: 0.7167
# Epoch [673/4000] Fold 1, Train Loss: 0.6731, Val Loss: 0.7165
# Epoch [674/4000] Fold 1, Train Loss: 0.6725, Val Loss: 0.7165
# Epoch [675/4000] Fold 1, Train Loss: 0.6733, Val Loss: 0.7163
# Epoch [676/4000] Fold 1, Train Loss: 0.6733, Val Loss: 0.7157
# Epoch [677/4000] Fold 1, Train Loss: 0.6719, Val Loss: 0.7158
# Epoch [678/4000] Fold 1, Train Loss: 0.6705, Val Loss: 0.7156
# Epoch [679/4000] Fold 1, Train Loss: 0.6714, Val Loss: 0.7156
# Epoch [680/4000] Fold 1, Train Loss: 0.6731, Val Loss: 0.7152
# Epoch [681/4000] Fold 1, Train Loss: 0.6715, Val Loss: 0.7148
# Epoch [682/4000] Fold 1, Train Loss: 0.6692, Val Loss: 0.7147
# Epoch [683/4000] Fold 1, Train Loss: 0.6695, Val Loss: 0.7145
# Epoch [684/4000] Fold 1, Train Loss: 0.6725, Val Loss: 0.7143
# Epoch [685/4000] Fold 1, Train Loss: 0.6707, Val Loss: 0.7139
# Epoch [686/4000] Fold 1, Train Loss: 0.6684, Val Loss: 0.7135
# Epoch [687/4000] Fold 1, Train Loss: 0.6681, Val Loss: 0.7133
# Epoch [688/4000] Fold 1, Train Loss: 0.6678, Val Loss: 0.7128
# Epoch [689/4000] Fold 1, Train Loss: 0.6676, Val Loss: 0.7127
# Epoch [690/4000] Fold 1, Train Loss: 0.6690, Val Loss: 0.7125
# Epoch [691/4000] Fold 1, Train Loss: 0.6670, Val Loss: 0.7123
# Epoch [692/4000] Fold 1, Train Loss: 0.6663, Val Loss: 0.7119
# Epoch [693/4000] Fold 1, Train Loss: 0.6676, Val Loss: 0.7120
# Epoch [694/4000] Fold 1, Train Loss: 0.6665, Val Loss: 0.7113
# Epoch [695/4000] Fold 1, Train Loss: 0.6677, Val Loss: 0.7108
# Epoch [696/4000] Fold 1, Train Loss: 0.6658, Val Loss: 0.7104
# Epoch [697/4000] Fold 1, Train Loss: 0.6648, Val Loss: 0.7103
# Epoch [698/4000] Fold 1, Train Loss: 0.6640, Val Loss: 0.7099
# Epoch [699/4000] Fold 1, Train Loss: 0.6620, Val Loss: 0.7098
# Epoch [700/4000] Fold 1, Train Loss: 0.6632, Val Loss: 0.7091
# Epoch [701/4000] Fold 1, Train Loss: 0.6652, Val Loss: 0.7091
# Epoch [702/4000] Fold 1, Train Loss: 0.6635, Val Loss: 0.7083
# Epoch [703/4000] Fold 1, Train Loss: 0.6615, Val Loss: 0.7080
# Epoch [704/4000] Fold 1, Train Loss: 0.6629, Val Loss: 0.7075
# Epoch [705/4000] Fold 1, Train Loss: 0.6626, Val Loss: 0.7073
# Epoch [706/4000] Fold 1, Train Loss: 0.6618, Val Loss: 0.7067
# Epoch [707/4000] Fold 1, Train Loss: 0.6619, Val Loss: 0.7063
# Epoch [708/4000] Fold 1, Train Loss: 0.6606, Val Loss: 0.7057
# Epoch [709/4000] Fold 1, Train Loss: 0.6628, Val Loss: 0.7053
# Epoch [710/4000] Fold 1, Train Loss: 0.6587, Val Loss: 0.7051
# Epoch [711/4000] Fold 1, Train Loss: 0.6586, Val Loss: 0.7050
# Epoch [712/4000] Fold 1, Train Loss: 0.6594, Val Loss: 0.7043
# Epoch [713/4000] Fold 1, Train Loss: 0.6589, Val Loss: 0.7039
# Epoch [714/4000] Fold 1, Train Loss: 0.6583, Val Loss: 0.7033
# Epoch [715/4000] Fold 1, Train Loss: 0.6580, Val Loss: 0.7028
# Epoch [716/4000] Fold 1, Train Loss: 0.6564, Val Loss: 0.7028
# Epoch [717/4000] Fold 1, Train Loss: 0.6572, Val Loss: 0.7024
# Epoch [718/4000] Fold 1, Train Loss: 0.6557, Val Loss: 0.7019
# Epoch [719/4000] Fold 1, Train Loss: 0.6561, Val Loss: 0.7016
# Epoch [720/4000] Fold 1, Train Loss: 0.6574, Val Loss: 0.7013
# Epoch [721/4000] Fold 1, Train Loss: 0.6559, Val Loss: 0.7007
# Epoch [722/4000] Fold 1, Train Loss: 0.6553, Val Loss: 0.7005
# Epoch [723/4000] Fold 1, Train Loss: 0.6550, Val Loss: 0.6998
# Epoch [724/4000] Fold 1, Train Loss: 0.6535, Val Loss: 0.6998
# Epoch [725/4000] Fold 1, Train Loss: 0.6543, Val Loss: 0.6993
# Epoch [726/4000] Fold 1, Train Loss: 0.6553, Val Loss: 0.6989
# Epoch [727/4000] Fold 1, Train Loss: 0.6521, Val Loss: 0.6985
# Epoch [728/4000] Fold 1, Train Loss: 0.6517, Val Loss: 0.6982
# Epoch [729/4000] Fold 1, Train Loss: 0.6510, Val Loss: 0.6979
# Epoch [730/4000] Fold 1, Train Loss: 0.6513, Val Loss: 0.6975
# Epoch [731/4000] Fold 1, Train Loss: 0.6522, Val Loss: 0.6974
# Epoch [732/4000] Fold 1, Train Loss: 0.6507, Val Loss: 0.6967
# Epoch [733/4000] Fold 1, Train Loss: 0.6496, Val Loss: 0.6960
# Epoch [734/4000] Fold 1, Train Loss: 0.6476, Val Loss: 0.6961
# Epoch [735/4000] Fold 1, Train Loss: 0.6495, Val Loss: 0.6955
# Epoch [736/4000] Fold 1, Train Loss: 0.6479, Val Loss: 0.6950
# Epoch [737/4000] Fold 1, Train Loss: 0.6499, Val Loss: 0.6949
# Epoch [738/4000] Fold 1, Train Loss: 0.6478, Val Loss: 0.6943
# Epoch [739/4000] Fold 1, Train Loss: 0.6473, Val Loss: 0.6941
# Epoch [740/4000] Fold 1, Train Loss: 0.6479, Val Loss: 0.6937
# Epoch [741/4000] Fold 1, Train Loss: 0.6478, Val Loss: 0.6935
# Epoch [742/4000] Fold 1, Train Loss: 0.6470, Val Loss: 0.6928
# Epoch [743/4000] Fold 1, Train Loss: 0.6451, Val Loss: 0.6926
# Epoch [744/4000] Fold 1, Train Loss: 0.6460, Val Loss: 0.6924
# Epoch [745/4000] Fold 1, Train Loss: 0.6487, Val Loss: 0.6917
# Epoch [746/4000] Fold 1, Train Loss: 0.6457, Val Loss: 0.6916
# Epoch [747/4000] Fold 1, Train Loss: 0.6436, Val Loss: 0.6911
# Epoch [748/4000] Fold 1, Train Loss: 0.6447, Val Loss: 0.6912
# Epoch [749/4000] Fold 1, Train Loss: 0.6437, Val Loss: 0.6904
# Epoch [750/4000] Fold 1, Train Loss: 0.6425, Val Loss: 0.6903
# Epoch [751/4000] Fold 1, Train Loss: 0.6439, Val Loss: 0.6897
# Epoch [752/4000] Fold 1, Train Loss: 0.6416, Val Loss: 0.6897
# Epoch [753/4000] Fold 1, Train Loss: 0.6429, Val Loss: 0.6893
# Epoch [754/4000] Fold 1, Train Loss: 0.6417, Val Loss: 0.6893
# Epoch [755/4000] Fold 1, Train Loss: 0.6420, Val Loss: 0.6885
# Epoch [756/4000] Fold 1, Train Loss: 0.6420, Val Loss: 0.6882
# Epoch [757/4000] Fold 1, Train Loss: 0.6401, Val Loss: 0.6880
# Epoch [758/4000] Fold 1, Train Loss: 0.6404, Val Loss: 0.6879
# Epoch [759/4000] Fold 1, Train Loss: 0.6410, Val Loss: 0.6874
# Epoch [760/4000] Fold 1, Train Loss: 0.6400, Val Loss: 0.6866
# Epoch [761/4000] Fold 1, Train Loss: 0.6398, Val Loss: 0.6862
# Epoch [762/4000] Fold 1, Train Loss: 0.6390, Val Loss: 0.6866
# Epoch [763/4000] Fold 1, Train Loss: 0.6373, Val Loss: 0.6859
# Epoch [764/4000] Fold 1, Train Loss: 0.6368, Val Loss: 0.6858
# Epoch [765/4000] Fold 1, Train Loss: 0.6366, Val Loss: 0.6851
# Epoch [766/4000] Fold 1, Train Loss: 0.6369, Val Loss: 0.6849
# Epoch [767/4000] Fold 1, Train Loss: 0.6380, Val Loss: 0.6846
# Epoch [768/4000] Fold 1, Train Loss: 0.6364, Val Loss: 0.6841
# Epoch [769/4000] Fold 1, Train Loss: 0.6369, Val Loss: 0.6835
# Epoch [770/4000] Fold 1, Train Loss: 0.6377, Val Loss: 0.6835
# Epoch [771/4000] Fold 1, Train Loss: 0.6352, Val Loss: 0.6830
# Epoch [772/4000] Fold 1, Train Loss: 0.6366, Val Loss: 0.6831
# Epoch [773/4000] Fold 1, Train Loss: 0.6348, Val Loss: 0.6826
# Epoch [774/4000] Fold 1, Train Loss: 0.6342, Val Loss: 0.6820
# Epoch [775/4000] Fold 1, Train Loss: 0.6348, Val Loss: 0.6820
# ...
# Epoch [3748/4000] Fold 5, Train Loss: 0.5185, Val Loss: 0.5862
# Epoch [3749/4000] Fold 5, Train Loss: 0.5183, Val Loss: 0.5860
# Epoch [3750/4000] Fold 5, Train Loss: 0.5187, Val Loss: 0.5863
# Epoch [3751/4000] Fold 5, Train Loss: 0.5186, Val Loss: 0.5861
# Epoch [3752/4000] Fold 5, Train Loss: 0.5190, Val Loss: 0.5869
# Epoch [3753/4000] Fold 5, Train Loss: 0.5175, Val Loss: 0.5863
# Epoch [3754/4000] Fold 5, Train Loss: 0.5174, Val Loss: 0.5860
# Epoch [3755/4000] Fold 5, Train Loss: 0.5178, Val Loss: 0.5861
# Epoch [3756/4000] Fold 5, Train Loss: 0.5173, Val Loss: 0.5864
# Epoch [3757/4000] Fold 5, Train Loss: 0.5179, Val Loss: 0.5862
# Epoch [3758/4000] Fold 5, Train Loss: 0.5174, Val Loss: 0.5860
# Epoch [3759/4000] Fold 5, Train Loss: 0.5180, Val Loss: 0.5860
# Epoch [3760/4000] Fold 5, Train Loss: 0.5169, Val Loss: 0.5863
# Epoch [3761/4000] Fold 5, Train Loss: 0.5178, Val Loss: 0.5860
# Epoch [3762/4000] Fold 5, Train Loss: 0.5191, Val Loss: 0.5863
# Epoch [3763/4000] Fold 5, Train Loss: 0.5181, Val Loss: 0.5862
# Epoch [3764/4000] Fold 5, Train Loss: 0.5179, Val Loss: 0.5859
# Epoch [3765/4000] Fold 5, Train Loss: 0.5177, Val Loss: 0.5862
# Epoch [3766/4000] Fold 5, Train Loss: 0.5188, Val Loss: 0.5863
# Epoch [3767/4000] Fold 5, Train Loss: 0.5178, Val Loss: 0.5862
# Epoch [3768/4000] Fold 5, Train Loss: 0.5190, Val Loss: 0.5860
# Epoch [3769/4000] Fold 5, Train Loss: 0.5167, Val Loss: 0.5860
# Epoch [3770/4000] Fold 5, Train Loss: 0.5199, Val Loss: 0.5862
# Epoch [3771/4000] Fold 5, Train Loss: 0.5180, Val Loss: 0.5861
# Epoch [3772/4000] Fold 5, Train Loss: 0.5165, Val Loss: 0.5863
# Epoch [3773/4000] Fold 5, Train Loss: 0.5182, Val Loss: 0.5858
# Epoch [3774/4000] Fold 5, Train Loss: 0.5186, Val Loss: 0.5861
# Epoch [3775/4000] Fold 5, Train Loss: 0.5192, Val Loss: 0.5859
# Epoch [3776/4000] Fold 5, Train Loss: 0.5176, Val Loss: 0.5863
# Epoch [3777/4000] Fold 5, Train Loss: 0.5181, Val Loss: 0.5862
# Epoch [3778/4000] Fold 5, Train Loss: 0.5178, Val Loss: 0.5859
# Epoch [3779/4000] Fold 5, Train Loss: 0.5169, Val Loss: 0.5860
# Epoch [3780/4000] Fold 5, Train Loss: 0.5167, Val Loss: 0.5858
# Epoch [3781/4000] Fold 5, Train Loss: 0.5166, Val Loss: 0.5858
# Epoch [3782/4000] Fold 5, Train Loss: 0.5171, Val Loss: 0.5861
# Epoch [3783/4000] Fold 5, Train Loss: 0.5171, Val Loss: 0.5858
# Epoch [3784/4000] Fold 5, Train Loss: 0.5170, Val Loss: 0.5859
# Epoch [3785/4000] Fold 5, Train Loss: 0.5180, Val Loss: 0.5861
# Epoch [3786/4000] Fold 5, Train Loss: 0.5179, Val Loss: 0.5861
# Epoch [3787/4000] Fold 5, Train Loss: 0.5189, Val Loss: 0.5860
# Epoch [3788/4000] Fold 5, Train Loss: 0.5180, Val Loss: 0.5859
# Epoch [3789/4000] Fold 5, Train Loss: 0.5181, Val Loss: 0.5856
# Epoch [3790/4000] Fold 5, Train Loss: 0.5168, Val Loss: 0.5860
# Epoch [3791/4000] Fold 5, Train Loss: 0.5179, Val Loss: 0.5861
# Epoch [3792/4000] Fold 5, Train Loss: 0.5169, Val Loss: 0.5856
# Epoch [3793/4000] Fold 5, Train Loss: 0.5167, Val Loss: 0.5864
# Epoch [3794/4000] Fold 5, Train Loss: 0.5167, Val Loss: 0.5857
# Epoch [3795/4000] Fold 5, Train Loss: 0.5181, Val Loss: 0.5865
# Epoch [3796/4000] Fold 5, Train Loss: 0.5188, Val Loss: 0.5856
# Epoch [3797/4000] Fold 5, Train Loss: 0.5174, Val Loss: 0.5861
# Epoch [3798/4000] Fold 5, Train Loss: 0.5170, Val Loss: 0.5858
# Epoch [3799/4000] Fold 5, Train Loss: 0.5176, Val Loss: 0.5858
# Epoch [3800/4000] Fold 5, Train Loss: 0.5179, Val Loss: 0.5859
# Epoch [3801/4000] Fold 5, Train Loss: 0.5183, Val Loss: 0.5860
# Epoch [3802/4000] Fold 5, Train Loss: 0.5180, Val Loss: 0.5861
# Epoch [3803/4000] Fold 5, Train Loss: 0.5165, Val Loss: 0.5861
# Epoch [3804/4000] Fold 5, Train Loss: 0.5174, Val Loss: 0.5858
# Epoch [3805/4000] Fold 5, Train Loss: 0.5186, Val Loss: 0.5862
# Epoch [3806/4000] Fold 5, Train Loss: 0.5178, Val Loss: 0.5860
# Epoch [3807/4000] Fold 5, Train Loss: 0.5170, Val Loss: 0.5861
# Epoch [3808/4000] Fold 5, Train Loss: 0.5175, Val Loss: 0.5856
# Epoch [3809/4000] Fold 5, Train Loss: 0.5185, Val Loss: 0.5859
# Epoch [3810/4000] Fold 5, Train Loss: 0.5168, Val Loss: 0.5865
# Epoch [3811/4000] Fold 5, Train Loss: 0.5185, Val Loss: 0.5860
# Epoch [3812/4000] Fold 5, Train Loss: 0.5188, Val Loss: 0.5858
# Epoch [3813/4000] Fold 5, Train Loss: 0.5177, Val Loss: 0.5858
# Epoch [3814/4000] Fold 5, Train Loss: 0.5176, Val Loss: 0.5858
# Epoch [3815/4000] Fold 5, Train Loss: 0.5174, Val Loss: 0.5859
# Epoch [3816/4000] Fold 5, Train Loss: 0.5172, Val Loss: 0.5856
# Epoch [3817/4000] Fold 5, Train Loss: 0.5180, Val Loss: 0.5860
# Epoch [3818/4000] Fold 5, Train Loss: 0.5168, Val Loss: 0.5861
# Epoch [3819/4000] Fold 5, Train Loss: 0.5174, Val Loss: 0.5859
# Epoch [3820/4000] Fold 5, Train Loss: 0.5192, Val Loss: 0.5856
# Epoch [3821/4000] Fold 5, Train Loss: 0.5178, Val Loss: 0.5860
# Epoch [3822/4000] Fold 5, Train Loss: 0.5157, Val Loss: 0.5861
# Epoch [3823/4000] Fold 5, Train Loss: 0.5180, Val Loss: 0.5857
# Epoch [3824/4000] Fold 5, Train Loss: 0.5164, Val Loss: 0.5863
# Epoch [3825/4000] Fold 5, Train Loss: 0.5169, Val Loss: 0.5856
# Epoch [3826/4000] Fold 5, Train Loss: 0.5174, Val Loss: 0.5858
# Epoch [3827/4000] Fold 5, Train Loss: 0.5179, Val Loss: 0.5859
# Epoch [3828/4000] Fold 5, Train Loss: 0.5178, Val Loss: 0.5856
# Epoch [3829/4000] Fold 5, Train Loss: 0.5181, Val Loss: 0.5861
# Epoch [3830/4000] Fold 5, Train Loss: 0.5172, Val Loss: 0.5859
# Epoch [3831/4000] Fold 5, Train Loss: 0.5171, Val Loss: 0.5860
# Epoch [3832/4000] Fold 5, Train Loss: 0.5176, Val Loss: 0.5859
# Epoch [3833/4000] Fold 5, Train Loss: 0.5183, Val Loss: 0.5856
# Epoch [3834/4000] Fold 5, Train Loss: 0.5183, Val Loss: 0.5855
# Epoch [3835/4000] Fold 5, Train Loss: 0.5190, Val Loss: 0.5862
# Epoch [3836/4000] Fold 5, Train Loss: 0.5164, Val Loss: 0.5855
# Epoch [3837/4000] Fold 5, Train Loss: 0.5182, Val Loss: 0.5864
# Epoch [3838/4000] Fold 5, Train Loss: 0.5191, Val Loss: 0.5854
# Epoch [3839/4000] Fold 5, Train Loss: 0.5177, Val Loss: 0.5861
# Epoch [3840/4000] Fold 5, Train Loss: 0.5175, Val Loss: 0.5861
# Epoch [3841/4000] Fold 5, Train Loss: 0.5165, Val Loss: 0.5856
# Epoch [3842/4000] Fold 5, Train Loss: 0.5169, Val Loss: 0.5856
# Epoch [3843/4000] Fold 5, Train Loss: 0.5186, Val Loss: 0.5860
# Epoch [3844/4000] Fold 5, Train Loss: 0.5185, Val Loss: 0.5860
# Epoch [3845/4000] Fold 5, Train Loss: 0.5170, Val Loss: 0.5853
# Epoch [3846/4000] Fold 5, Train Loss: 0.5172, Val Loss: 0.5854
# Epoch [3847/4000] Fold 5, Train Loss: 0.5167, Val Loss: 0.5859
# Epoch [3848/4000] Fold 5, Train Loss: 0.5161, Val Loss: 0.5856
# Epoch [3849/4000] Fold 5, Train Loss: 0.5176, Val Loss: 0.5856
# Epoch [3850/4000] Fold 5, Train Loss: 0.5169, Val Loss: 0.5856
# Epoch [3851/4000] Fold 5, Train Loss: 0.5165, Val Loss: 0.5861
# Epoch [3852/4000] Fold 5, Train Loss: 0.5176, Val Loss: 0.5856
# Epoch [3853/4000] Fold 5, Train Loss: 0.5175, Val Loss: 0.5856
# Epoch [3854/4000] Fold 5, Train Loss: 0.5166, Val Loss: 0.5856
# Epoch [3855/4000] Fold 5, Train Loss: 0.5162, Val Loss: 0.5855
# Epoch [3856/4000] Fold 5, Train Loss: 0.5176, Val Loss: 0.5855
# Epoch [3857/4000] Fold 5, Train Loss: 0.5168, Val Loss: 0.5852
# Epoch [3858/4000] Fold 5, Train Loss: 0.5176, Val Loss: 0.5861
# Epoch [3859/4000] Fold 5, Train Loss: 0.5176, Val Loss: 0.5851
# Epoch [3860/4000] Fold 5, Train Loss: 0.5173, Val Loss: 0.5851
# Epoch [3861/4000] Fold 5, Train Loss: 0.5167, Val Loss: 0.5856
# Epoch [3862/4000] Fold 5, Train Loss: 0.5174, Val Loss: 0.5856
# Epoch [3863/4000] Fold 5, Train Loss: 0.5168, Val Loss: 0.5852
# Epoch [3864/4000] Fold 5, Train Loss: 0.5167, Val Loss: 0.5856
# Epoch [3865/4000] Fold 5, Train Loss: 0.5156, Val Loss: 0.5853
# Epoch [3866/4000] Fold 5, Train Loss: 0.5178, Val Loss: 0.5854
# Epoch [3867/4000] Fold 5, Train Loss: 0.5164, Val Loss: 0.5856
# Epoch [3868/4000] Fold 5, Train Loss: 0.5165, Val Loss: 0.5856
# Epoch [3869/4000] Fold 5, Train Loss: 0.5175, Val Loss: 0.5852
# Epoch [3870/4000] Fold 5, Train Loss: 0.5163, Val Loss: 0.5854
# Epoch [3871/4000] Fold 5, Train Loss: 0.5169, Val Loss: 0.5854
# Epoch [3872/4000] Fold 5, Train Loss: 0.5165, Val Loss: 0.5854
# Epoch [3873/4000] Fold 5, Train Loss: 0.5180, Val Loss: 0.5856
# Epoch [3874/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5850
# Epoch [3875/4000] Fold 5, Train Loss: 0.5163, Val Loss: 0.5856
# Epoch [3876/4000] Fold 5, Train Loss: 0.5171, Val Loss: 0.5852
# Epoch [3877/4000] Fold 5, Train Loss: 0.5172, Val Loss: 0.5854
# Epoch [3878/4000] Fold 5, Train Loss: 0.5167, Val Loss: 0.5855
# Epoch [3879/4000] Fold 5, Train Loss: 0.5169, Val Loss: 0.5854
# Epoch [3880/4000] Fold 5, Train Loss: 0.5181, Val Loss: 0.5851
# Epoch [3881/4000] Fold 5, Train Loss: 0.5180, Val Loss: 0.5854
# Epoch [3882/4000] Fold 5, Train Loss: 0.5166, Val Loss: 0.5855
# Epoch [3883/4000] Fold 5, Train Loss: 0.5162, Val Loss: 0.5855
# Epoch [3884/4000] Fold 5, Train Loss: 0.5170, Val Loss: 0.5854
# Epoch [3885/4000] Fold 5, Train Loss: 0.5151, Val Loss: 0.5851
# Epoch [3886/4000] Fold 5, Train Loss: 0.5175, Val Loss: 0.5854
# Epoch [3887/4000] Fold 5, Train Loss: 0.5154, Val Loss: 0.5855
# Epoch [3888/4000] Fold 5, Train Loss: 0.5175, Val Loss: 0.5854
# Epoch [3889/4000] Fold 5, Train Loss: 0.5168, Val Loss: 0.5853
# Epoch [3890/4000] Fold 5, Train Loss: 0.5168, Val Loss: 0.5859
# Epoch [3891/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5850
# Epoch [3892/4000] Fold 5, Train Loss: 0.5159, Val Loss: 0.5852
# Epoch [3893/4000] Fold 5, Train Loss: 0.5163, Val Loss: 0.5852
# Epoch [3894/4000] Fold 5, Train Loss: 0.5155, Val Loss: 0.5852
# Epoch [3895/4000] Fold 5, Train Loss: 0.5169, Val Loss: 0.5854
# Epoch [3896/4000] Fold 5, Train Loss: 0.5153, Val Loss: 0.5850
# Epoch [3897/4000] Fold 5, Train Loss: 0.5153, Val Loss: 0.5850
# Epoch [3898/4000] Fold 5, Train Loss: 0.5154, Val Loss: 0.5854
# Epoch [3899/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5849
# Epoch [3900/4000] Fold 5, Train Loss: 0.5170, Val Loss: 0.5853
# Epoch [3901/4000] Fold 5, Train Loss: 0.5155, Val Loss: 0.5852
# Epoch [3902/4000] Fold 5, Train Loss: 0.5156, Val Loss: 0.5850
# Epoch [3903/4000] Fold 5, Train Loss: 0.5153, Val Loss: 0.5852
# Epoch [3904/4000] Fold 5, Train Loss: 0.5156, Val Loss: 0.5853
# Epoch [3905/4000] Fold 5, Train Loss: 0.5154, Val Loss: 0.5849
# Epoch [3906/4000] Fold 5, Train Loss: 0.5159, Val Loss: 0.5850
# Epoch [3907/4000] Fold 5, Train Loss: 0.5158, Val Loss: 0.5851
# Epoch [3908/4000] Fold 5, Train Loss: 0.5156, Val Loss: 0.5853
# Epoch [3909/4000] Fold 5, Train Loss: 0.5158, Val Loss: 0.5851
# Epoch [3910/4000] Fold 5, Train Loss: 0.5162, Val Loss: 0.5854
# Epoch [3911/4000] Fold 5, Train Loss: 0.5157, Val Loss: 0.5853
# Epoch [3912/4000] Fold 5, Train Loss: 0.5151, Val Loss: 0.5851
# Epoch [3913/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5850
# Epoch [3914/4000] Fold 5, Train Loss: 0.5158, Val Loss: 0.5851
# Epoch [3915/4000] Fold 5, Train Loss: 0.5167, Val Loss: 0.5849
# Epoch [3916/4000] Fold 5, Train Loss: 0.5157, Val Loss: 0.5851
# Epoch [3917/4000] Fold 5, Train Loss: 0.5151, Val Loss: 0.5852
# Epoch [3918/4000] Fold 5, Train Loss: 0.5167, Val Loss: 0.5851
# Epoch [3919/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5851
# Epoch [3920/4000] Fold 5, Train Loss: 0.5166, Val Loss: 0.5848
# Epoch [3921/4000] Fold 5, Train Loss: 0.5168, Val Loss: 0.5851
# Epoch [3922/4000] Fold 5, Train Loss: 0.5161, Val Loss: 0.5851
# Epoch [3923/4000] Fold 5, Train Loss: 0.5172, Val Loss: 0.5850
# Epoch [3924/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5853
# Epoch [3925/4000] Fold 5, Train Loss: 0.5151, Val Loss: 0.5851
# Epoch [3926/4000] Fold 5, Train Loss: 0.5170, Val Loss: 0.5847
# Epoch [3927/4000] Fold 5, Train Loss: 0.5178, Val Loss: 0.5853
# Epoch [3928/4000] Fold 5, Train Loss: 0.5165, Val Loss: 0.5847
# Epoch [3929/4000] Fold 5, Train Loss: 0.5147, Val Loss: 0.5850
# Epoch [3930/4000] Fold 5, Train Loss: 0.5151, Val Loss: 0.5849
# Epoch [3931/4000] Fold 5, Train Loss: 0.5145, Val Loss: 0.5850
# Epoch [3932/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5847
# Epoch [3933/4000] Fold 5, Train Loss: 0.5157, Val Loss: 0.5849
# Epoch [3934/4000] Fold 5, Train Loss: 0.5155, Val Loss: 0.5850
# Epoch [3935/4000] Fold 5, Train Loss: 0.5157, Val Loss: 0.5849
# Epoch [3936/4000] Fold 5, Train Loss: 0.5148, Val Loss: 0.5849
# Epoch [3937/4000] Fold 5, Train Loss: 0.5159, Val Loss: 0.5851
# Epoch [3938/4000] Fold 5, Train Loss: 0.5164, Val Loss: 0.5852
# Epoch [3939/4000] Fold 5, Train Loss: 0.5158, Val Loss: 0.5852
# Epoch [3940/4000] Fold 5, Train Loss: 0.5153, Val Loss: 0.5852
# Epoch [3941/4000] Fold 5, Train Loss: 0.5155, Val Loss: 0.5849
# Epoch [3942/4000] Fold 5, Train Loss: 0.5152, Val Loss: 0.5850
# Epoch [3943/4000] Fold 5, Train Loss: 0.5155, Val Loss: 0.5851
# Epoch [3944/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5850
# Epoch [3945/4000] Fold 5, Train Loss: 0.5158, Val Loss: 0.5850
# Epoch [3946/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5854
# Epoch [3947/4000] Fold 5, Train Loss: 0.5171, Val Loss: 0.5851
# Epoch [3948/4000] Fold 5, Train Loss: 0.5176, Val Loss: 0.5846
# Epoch [3949/4000] Fold 5, Train Loss: 0.5152, Val Loss: 0.5846
# Epoch [3950/4000] Fold 5, Train Loss: 0.5177, Val Loss: 0.5848
# Epoch [3951/4000] Fold 5, Train Loss: 0.5178, Val Loss: 0.5850
# Epoch [3952/4000] Fold 5, Train Loss: 0.5172, Val Loss: 0.5850
# Epoch [3953/4000] Fold 5, Train Loss: 0.5161, Val Loss: 0.5846
# Epoch [3954/4000] Fold 5, Train Loss: 0.5167, Val Loss: 0.5852
# Epoch [3955/4000] Fold 5, Train Loss: 0.5172, Val Loss: 0.5850
# Epoch [3956/4000] Fold 5, Train Loss: 0.5164, Val Loss: 0.5848
# Epoch [3957/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5853
# Epoch [3958/4000] Fold 5, Train Loss: 0.5156, Val Loss: 0.5848
# Epoch [3959/4000] Fold 5, Train Loss: 0.5150, Val Loss: 0.5849
# Epoch [3960/4000] Fold 5, Train Loss: 0.5150, Val Loss: 0.5849
# Epoch [3961/4000] Fold 5, Train Loss: 0.5151, Val Loss: 0.5850
# Epoch [3962/4000] Fold 5, Train Loss: 0.5151, Val Loss: 0.5848
# Epoch [3963/4000] Fold 5, Train Loss: 0.5159, Val Loss: 0.5850
# Epoch [3964/4000] Fold 5, Train Loss: 0.5162, Val Loss: 0.5855
# Epoch [3965/4000] Fold 5, Train Loss: 0.5141, Val Loss: 0.5848
# Epoch [3966/4000] Fold 5, Train Loss: 0.5154, Val Loss: 0.5848
# Epoch [3967/4000] Fold 5, Train Loss: 0.5149, Val Loss: 0.5848
# Epoch [3968/4000] Fold 5, Train Loss: 0.5162, Val Loss: 0.5847
# Epoch [3969/4000] Fold 5, Train Loss: 0.5161, Val Loss: 0.5853
# Epoch [3970/4000] Fold 5, Train Loss: 0.5155, Val Loss: 0.5848
# Epoch [3971/4000] Fold 5, Train Loss: 0.5153, Val Loss: 0.5849
# Epoch [3972/4000] Fold 5, Train Loss: 0.5161, Val Loss: 0.5848
# Epoch [3973/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5851
# Epoch [3974/4000] Fold 5, Train Loss: 0.5157, Val Loss: 0.5850
# Epoch [3975/4000] Fold 5, Train Loss: 0.5151, Val Loss: 0.5848
# Epoch [3976/4000] Fold 5, Train Loss: 0.5156, Val Loss: 0.5849
# Epoch [3977/4000] Fold 5, Train Loss: 0.5145, Val Loss: 0.5847
# Epoch [3978/4000] Fold 5, Train Loss: 0.5157, Val Loss: 0.5844
# Epoch [3979/4000] Fold 5, Train Loss: 0.5163, Val Loss: 0.5852
# Epoch [3980/4000] Fold 5, Train Loss: 0.5168, Val Loss: 0.5848
# Epoch [3981/4000] Fold 5, Train Loss: 0.5161, Val Loss: 0.5844
# Epoch [3982/4000] Fold 5, Train Loss: 0.5164, Val Loss: 0.5850
# Epoch [3983/4000] Fold 5, Train Loss: 0.5145, Val Loss: 0.5850
# Epoch [3984/4000] Fold 5, Train Loss: 0.5168, Val Loss: 0.5850
# Epoch [3985/4000] Fold 5, Train Loss: 0.5148, Val Loss: 0.5851
# Epoch [3986/4000] Fold 5, Train Loss: 0.5176, Val Loss: 0.5849
# Epoch [3987/4000] Fold 5, Train Loss: 0.5161, Val Loss: 0.5848
# Epoch [3988/4000] Fold 5, Train Loss: 0.5147, Val Loss: 0.5846
# Epoch [3989/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5847
# Epoch [3990/4000] Fold 5, Train Loss: 0.5160, Val Loss: 0.5847
# Epoch [3991/4000] Fold 5, Train Loss: 0.5146, Val Loss: 0.5846
# Epoch [3992/4000] Fold 5, Train Loss: 0.5145, Val Loss: 0.5846
# Epoch [3993/4000] Fold 5, Train Loss: 0.5165, Val Loss: 0.5847
# Epoch [3994/4000] Fold 5, Train Loss: 0.5158, Val Loss: 0.5847
# Epoch [3995/4000] Fold 5, Train Loss: 0.5152, Val Loss: 0.5846
# Epoch [3996/4000] Fold 5, Train Loss: 0.5147, Val Loss: 0.5848
# Epoch [3997/4000] Fold 5, Train Loss: 0.5153, Val Loss: 0.5846
# Epoch [3998/4000] Fold 5, Train Loss: 0.5156, Val Loss: 0.5847
# Epoch [3999/4000] Fold 5, Train Loss: 0.5147, Val Loss: 0.5845
# Epoch [4000/4000] Fold 5, Train Loss: 0.5165, Val Loss: 0.5850

# %%
# delta = 0, epochs 4000

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.5229

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.5637
#   Corresponding Training Loss = 0.4921
#   Best Epoch = 3998
# Fold 2:
#   Best Validation Loss = 0.4889
#   Corresponding Training Loss = 0.4686
#   Best Epoch = 3956
# Fold 3:
#   Best Validation Loss = 0.4630
#   Corresponding Training Loss = 0.4508
#   Best Epoch = 3995
# Fold 4:
#   Best Validation Loss = 0.5124
#   Corresponding Training Loss = 0.4485
#   Best Epoch = 3986
# Fold 5:
#   Best Validation Loss = 0.5844
#   Corresponding Training Loss = 0.5157
#   Best Epoch = 3978

# %%
def plot_loss_curves_separately(cv_histories):
    """
    Plot training and validation loss curves for each fold in separate figures.
    
    Args:
        cv_histories (list): List of loss histories for each fold.
    """
    # Plot Training Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['train_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
    plt.title('Training Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['val_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
    plt.title('Validation Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_loss_curves_separately(cv_histories)

# %%
import os

# Define the directory where models will be saved (current folder)
save_dir = "."  # Current directory
os.makedirs(save_dir, exist_ok=True)  # Create the directory if it doesn't exist (optional for ".")

# Save each fold's best model to the directory
for i, model_state in enumerate(best_models):
    save_path = os.path.join(save_dir, f'best_model_fold_{i+1}.pth')
    torch.save(model_state, save_path)

print(f"Models saved to the current directory: {save_dir}")
# Out:
# Models saved to the current directory: .

# %% [markdown]
# # delta = 0, epochs 2000

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.5565

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.5210
#   Corresponding Training Loss = 0.4545
#   Best Epoch = 1997
# Fold 2:
#   Best Validation Loss = 0.5725
#   Corresponding Training Loss = 0.5465
#   Best Epoch = 2000
# Fold 3:
#   Best Validation Loss = 0.6553
#   Corresponding Training Loss = 0.6237
#   Best Epoch = 1983
# Fold 4:
#   Best Validation Loss = 0.5227
#   Corresponding Training Loss = 0.4804
#   Best Epoch = 1994
# Fold 5:
#   Best Validation Loss = 0.5095
#   Corresponding Training Loss = 0.4754
#   Best Epoch = 2000

# %%
def plot_loss_curves_separately(cv_histories):
    """
    Plot training and validation loss curves for each fold in separate figures.
    
    Args:
        cv_histories (list): List of loss histories for each fold.
    """
    # Plot Training Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['train_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
    plt.title('Training Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['val_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
    plt.title('Validation Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_loss_curves_separately(cv_histories)

# %%
import os

# Define the directory where models will be saved (current folder)
save_dir = "."  # Current directory
os.makedirs(save_dir, exist_ok=True)  # Create the directory if it doesn't exist (optional for ".")

# Save each fold's best model to the directory
for i, model_state in enumerate(best_models):
    save_path = os.path.join(save_dir, f'best_model_fold_{i+1}.pth')
    torch.save(model_state, save_path)

print(f"Models saved to the current directory: {save_dir}")
# Out:
# Models saved to the current directory: .

# %% [markdown]
# # inference

# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import pandas as pd

# %%
import torch.nn as nn

class FeaturePredictor(nn.Module):
    def __init__(self, input_size=20, output_size=20):
        super(FeaturePredictor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 16),
            nn.ReLU(),
            nn.Linear(16, 8),
            nn.ReLU(),
            nn.Linear(8, 4),
            nn.ReLU(),
            nn.Linear(4, 8),
            nn.ReLU(),
            nn.Linear(8, 16),
            nn.ReLU(),
            nn.Linear(16,output_size)
        )
    
    def forward(self, x):
        return self.model(x)

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch

# Define the path to the specific model file
model_path = './best_model_fold_3.pth'

# Load the saved model state dictionary
model_state = torch.load(model_path)

# Initialize the model and load the state dictionary
model = FeaturePredictor()  # Replace with your model class
model.load_state_dict(model_state)
model.to(device)
model.eval()

print("Model loaded successfully.")
# Out:
# Model loaded successfully.
# C:\Users\k54739\AppData\Local\Temp\ipykernel_23160\65833548.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_state = torch.load(model_path)

# %%
# Load the CSV file
df = pd.read_csv("sd_feats.csv")

# Extract paths, labels, and features
loaded_paths = df["path"].tolist()
loaded_features = torch.tensor(df["features"].apply(eval).to_list(), dtype=torch.float32)
print(df.head())
print(f"Loaded features shape: {loaded_features.shape}")
print(f"Loaded paths: {len(loaded_paths)}")
# Out:
#                                                 path  \
# 0  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
# 1  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
# 2  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
# 3  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
# 4  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
#
#                                             features
# 0  [0.6580395698547363, 2.2357561588287354, -0.31...
# 1  [0.7452167868614197, 1.4099552631378174, 0.769...
# 2  [0.7592116594314575, 1.2189165353775024, 0.401...
# 3  [-0.09472537785768509, 0.878221333026886, 0.55...
# 4  [1.2078502178192139, -0.5769761800765991, -1.4...
# Loaded features shape: torch.Size([103, 20])
# Loaded paths: 103

# %% [markdown]
# # Load the CSV file
# df = pd.read_csv("cond7_combined_features.csv")
#
# # Extract paths, labels, and features
# loaded_paths = df["path"].tolist()
# loaded_labels = df["label"].tolist()
# loaded_features = torch.tensor(df["features"].apply(eval).to_list(), dtype=torch.float32)
# feats = loaded_features
# print(df.head())
# print(f"Loaded features shape: {loaded_features.shape}")
# print(f"Loaded paths: {len(loaded_paths)}")
# print(f"Loaded labels: {len(loaded_labels)}")

# %% [markdown]
# features_mean = loaded_features.mean(dim=0, keepdim=True)
# features_std = loaded_features.std(dim=0, keepdim=True)
#
# normalized_feats = (loaded_features - features_mean) / features_std

# %% [markdown]
# # Save features_min and features_max
# torch.save(features_mean, "train_mean.pth")
# torch.save(features_std, "train_std.pth")
#
# print("Features mean and std saved successfully.")

# %%
# Load features_min and features_max
loaded_features_mean = torch.load("train_mean.pth")
loaded_features_std = torch.load("train_std.pth")
print(loaded_features_mean.shape)
print(loaded_features_std.shape)
normalized_feats = (loaded_features - loaded_features_mean) / loaded_features_std
# Out:
# torch.Size([1, 20])
# torch.Size([1, 20])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_23160\106586103.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_features_mean = torch.load("train_mean.pth")
# C:\Users\k54739\AppData\Local\Temp\ipykernel_23160\106586103.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_features_std = torch.load("train_std.pth")

# %%
# Assuming normalized_feats is a tensor of shape [num_samples, num_features]
from torch.utils.data import TensorDataset, DataLoader
inference_dataset = TensorDataset(normalized_feats)
inference_loader = DataLoader(inference_dataset, batch_size=32, shuffle=False)

# %%
# Define a prefix for the group of images (e.g., "original" or "augmented")
prefix = "sd_feats"  # Change this for different groups, e.g., "augmented", "group1"

# Perform inference
mse_errors = []
euclidean_distances = []
cosine_distances = []

# Use the same criterion as during training
criterion = nn.MSELoss(reduction='none')  # Use 'none' to calculate loss per sample

with torch.no_grad():
    for batch_feats in inference_loader:
        # Extract features
        batch_feats = batch_feats[0].to(device)
        outputs = model(batch_feats)

        # Calculate MSE loss for each feature vector
        batch_mse = criterion(outputs, batch_feats).mean(dim=1)  # MSE per sample
        mse_errors.extend(batch_mse.cpu().numpy())

        # Calculate Euclidean distance for each feature vector
        batch_euclidean = torch.norm(outputs - batch_feats, p=2, dim=1)  # L2 norm
        euclidean_distances.extend(batch_euclidean.cpu().numpy())

        # Calculate Cosine distance for each feature vector
        batch_cosine_similarity = torch.nn.functional.cosine_similarity(outputs, batch_feats, dim=1)
        batch_cosine_distance = 1 - batch_cosine_similarity  # Cosine distance = 1 - Cosine similarity
        cosine_distances.extend(batch_cosine_distance.cpu().numpy())

# Convert results to numpy arrays for further analysis
mse_errors = np.array(mse_errors)
euclidean_distances = np.array(euclidean_distances)
cosine_distances = np.array(cosine_distances)

# Save the results with the prefix
np.save(f"{prefix}_mse_errors.npy", mse_errors)
np.save(f"{prefix}_euclidean_distances.npy", euclidean_distances)
np.save(f"{prefix}_cosine_distances.npy", cosine_distances)

print(f"Errors and distances for group '{prefix}' saved successfully.")
# Out:
# Errors and distances for group 'sd_feats' saved successfully.

# %% [markdown]
# prefix = "cond7"  # Replace with your specific prefix
#
# # Load the saved metrics
# cond7_mse_errors = np.load(f"{prefix}_mse_errors.npy")
# cond7_euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
# cond7_cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_distributions_with_boxplot(sd_metrics, control_metrics, exd_metrics, ds_metrics, cond_metrics, metric_names, bins=20):
    """
    Plots the histogram and box-and-whisker plots for multiple metrics across multiple groups.

    Args:
        sd_metrics (dict): Dictionary of metrics for the SD group. Keys are metric names, values are arrays.
        control_metrics (dict): Dictionary of metrics for the Control group. Keys are metric names, values are arrays.
        exd_metrics (dict): Dictionary of metrics for the EXD group. Keys are metric names, values are arrays.
        ds_metrics (dict): Dictionary of metrics for the Ds Close to SD group. Keys are metric names, values are arrays.
        cond_metrics (dict): Dictionary of metrics for the Cond10 group. Keys are metric names, values are arrays.
        metric_names (list): Names of the metrics to plot (e.g., ["Reconstruction Error", "Cosine Distance"]).
        bins (int): Number of bins for the histogram.
    """
    for metric_name in metric_names:
        # Extract metrics for all groups
        sd_values = sd_metrics[metric_name]
        control_values = control_metrics[metric_name]
        exd_values = exd_metrics[metric_name]
        ds_values = ds_metrics[metric_name]
        cond_values = cond_metrics[metric_name]

        # Create figure with two subplots: Histogram (top) and Boxplot (bottom)
        fig, axes = plt.subplots(2, 1, figsize=(14, 12), gridspec_kw={'height_ratios': [3, 1]})

        # Histogram
        axes[0].hist(sd_values, bins=bins, alpha=0.6, label="SD Group", color="orange", edgecolor="black")
        axes[0].hist(control_values, bins=bins, alpha=0.6, label="Control Group", color="blue", edgecolor="black")
        axes[0].hist(exd_values, bins=bins, alpha=0.6, label="EXD Group", color="green", edgecolor="black")
        axes[0].hist(ds_values, bins=bins, alpha=0.6, label="Ds Close to SD Group", color="red", edgecolor="black")
        axes[0].hist(cond_values, bins=bins, alpha=0.6, label="Cond10 Group", color="purple", edgecolor="black")

        # Add mean lines to the histogram
        axes[0].axvline(np.mean(sd_values), color='orange', linestyle='-', label=f"SD Mean: {np.mean(sd_values):.4f}")
        axes[0].axvline(np.mean(control_values), color='blue', linestyle='-', label=f"Control Mean: {np.mean(control_values):.4f}")
        axes[0].axvline(np.mean(exd_values), color='green', linestyle='-', label=f"EXD Mean: {np.mean(exd_values):.4f}")
        axes[0].axvline(np.mean(ds_values), color='red', linestyle='-', label=f"Ds Mean: {np.mean(ds_values):.4f}")
        axes[0].axvline(np.mean(cond_values), color='purple', linestyle='-', label=f"Cond10 Mean: {np.mean(cond_values):.4f}")

        # Add title and legend to the histogram
        axes[0].set_title(f"{metric_name} Distribution", fontsize=16)
        axes[0].set_xlabel(metric_name, fontsize=14)
        axes[0].set_ylabel("Frequency", fontsize=14)
        axes[0].legend(fontsize=10)
        axes[0].grid(alpha=0.3)

        # Box-and-whisker plot
        data = [sd_values, control_values, exd_values, ds_values, cond_values]
        labels = ["SD Group", "Control Group", "EXD Group", "Ds Close to SD Group", "Cond10 Group"]
        axes[1].boxplot(data, labels=labels, patch_artist=True, 
                        boxprops=dict(facecolor="lightgrey", color="black"),
                        medianprops=dict(color="black"), whiskerprops=dict(color="black"))

        # Add title and labels to the boxplot
        axes[1].set_title(f"{metric_name} Box-and-Whisker Plot", fontsize=16)
        axes[1].set_ylabel(metric_name, fontsize=14)

        # Adjust layout and show the plot
        plt.tight_layout()
        plt.show()

# Example Usage
if __name__ == "__main__":
    # Load the metrics for SD and Control groups
    sd_metrics = {
        "Reconstruction Error": np.load("sd_feats_mse_errors.npy"),
        "Cosine Distance": np.load("sd_feats_cosine_distances.npy"),
        "Euclidean Distance": np.load("sd_feats_euclidean_distances.npy")
    }

    control_metrics = {
        "Reconstruction Error": np.load("cond7_mse_errors.npy"),
        "Cosine Distance": np.load("cond7_cosine_distances.npy"),
        "Euclidean Distance": np.load("cond7_euclidean_distances.npy")
    }

    # Load the metrics for EXD and Ds Close to SD groups
    exd_metrics = {
        "Reconstruction Error": np.load("ex_feats_mse_errors.npy"),
        "Cosine Distance": np.load("ex_feats_cosine_distances.npy"),
        "Euclidean Distance": np.load("ex_feats_euclidean_distances.npy")
    }

    ds_metrics = {
        "Reconstruction Error": np.load("ds_closeto_sd_mse_errors.npy"),
        "Cosine Distance": np.load("ds_closeto_sd_cosine_distances.npy"),
        "Euclidean Distance": np.load("ds_closeto_sd_euclidean_distances.npy")
    }

    # Load the metrics for Cond10 group
    cond_metrics = {
        "Reconstruction Error": np.load("cond10_feats_mse_errors.npy"),
        "Cosine Distance": np.load("cond10_feats_cosine_distances.npy"),
        "Euclidean Distance": np.load("cond10_feats_euclidean_distances.npy")
    }

    # Define the metric names
    metric_names = ["Reconstruction Error", "Cosine Distance", "Euclidean Distance"]

    # Plot distributions with boxplots
    plot_distributions_with_boxplot(sd_metrics, control_metrics, exd_metrics, ds_metrics, cond_metrics, metric_names)
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_23160\2226352954.py:52: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=labels, patch_artist=True,
# C:\Users\k54739\AppData\Local\Temp\ipykernel_23160\2226352954.py:52: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=labels, patch_artist=True,
# C:\Users\k54739\AppData\Local\Temp\ipykernel_23160\2226352954.py:52: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=labels, patch_artist=True,

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the saved metrics
prefix = "ds_closeto_sd"  # Adjust to the prefix you used
mse_errors = np.load(f"{prefix}_mse_errors.npy")
euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# Plot MSE Errors
plt.figure(figsize=(10, 6))
plt.hist(mse_errors, bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.title(f"{prefix} - MSE Errors", fontsize=16)
plt.xlabel("MSE Error", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Euclidean Distances
plt.figure(figsize=(10, 6))
plt.hist(euclidean_distances, bins=30, alpha=0.7, color='green', edgecolor='black')
plt.title(f"{prefix} - Euclidean Distances", fontsize=16)
plt.xlabel("Euclidean Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Cosine Distances
plt.figure(figsize=(10, 6))
plt.hist(cosine_distances, bins=30, alpha=0.7, color='red', edgecolor='black')
plt.title(f"{prefix} - Cosine Distances", fontsize=16)
plt.xlabel("Cosine Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the saved metrics
prefix = "ex"  # Adjust to the prefix you used
mse_errors = np.load(f"{prefix}_mse_errors.npy")
euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# Plot MSE Errors
plt.figure(figsize=(10, 6))
plt.hist(mse_errors, bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.title(f"{prefix} - MSE Errors", fontsize=16)
plt.xlabel("MSE Error", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Euclidean Distances
plt.figure(figsize=(10, 6))
plt.hist(euclidean_distances, bins=30, alpha=0.7, color='green', edgecolor='black')
plt.title(f"{prefix} - Euclidean Distances", fontsize=16)
plt.xlabel("Euclidean Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Cosine Distances
plt.figure(figsize=(10, 6))
plt.hist(cosine_distances, bins=30, alpha=0.7, color='red', edgecolor='black')
plt.title(f"{prefix} - Cosine Distances", fontsize=16)
plt.xlabel("Cosine Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the saved metrics
prefix = "sd"  # Adjust to the prefix you used
mse_errors = np.load(f"{prefix}_mse_errors.npy")
euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# Plot MSE Errors
plt.figure(figsize=(10, 6))
plt.hist(mse_errors, bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.title(f"{prefix} - MSE Errors", fontsize=16)
plt.xlabel("MSE Error", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Euclidean Distances
plt.figure(figsize=(10, 6))
plt.hist(euclidean_distances, bins=30, alpha=0.7, color='green', edgecolor='black')
plt.title(f"{prefix} - Euclidean Distances", fontsize=16)
plt.xlabel("Euclidean Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Cosine Distances
plt.figure(figsize=(10, 6))
plt.hist(cosine_distances, bins=30, alpha=0.7, color='red', edgecolor='black')
plt.title(f"{prefix} - Cosine Distances", fontsize=16)
plt.xlabel("Cosine Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the saved metrics
prefix = "cond10"  # Adjust to the prefix you used
mse_errors = np.load(f"{prefix}_mse_errors.npy")
euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# Plot MSE Errors
plt.figure(figsize=(10, 6))
plt.hist(mse_errors, bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.title(f"{prefix} - MSE Errors", fontsize=16)
plt.xlabel("MSE Error", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Euclidean Distances
plt.figure(figsize=(10, 6))
plt.hist(euclidean_distances, bins=30, alpha=0.7, color='green', edgecolor='black')
plt.title(f"{prefix} - Euclidean Distances", fontsize=16)
plt.xlabel("Euclidean Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Cosine Distances
plt.figure(figsize=(10, 6))
plt.hist(cosine_distances, bins=30, alpha=0.7, color='red', edgecolor='black')
plt.title(f"{prefix} - Cosine Distances", fontsize=16)
plt.xlabel("Cosine Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the saved metrics
prefix = "cond7"  # Adjust to the prefix you used
mse_errors = np.load(f"{prefix}_mse_errors.npy")
euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# Plot MSE Errors
plt.figure(figsize=(10, 6))
plt.hist(mse_errors, bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.title(f"{prefix} - MSE Errors", fontsize=16)
plt.xlabel("MSE Error", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Euclidean Distances
plt.figure(figsize=(10, 6))
plt.hist(euclidean_distances, bins=30, alpha=0.7, color='green', edgecolor='black')
plt.title(f"{prefix} - Euclidean Distances", fontsize=16)
plt.xlabel("Euclidean Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Cosine Distances
plt.figure(figsize=(10, 6))
plt.hist(cosine_distances, bins=30, alpha=0.7, color='red', edgecolor='black')
plt.title(f"{prefix} - Cosine Distances", fontsize=16)
plt.xlabel("Cosine Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()
