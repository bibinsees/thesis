# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import pandas as pd

# %%
# Load the CSV file
df = pd.read_csv("combined_features.csv")

# Extract paths, labels, and features
loaded_paths = df["path"].tolist()
loaded_labels = df["label"].tolist()
loaded_features = torch.tensor(df["features"].apply(eval).to_list(), dtype=torch.float32)
feats = loaded_features
print(df.head())
print(f"Loaded features shape: {loaded_features.shape}")
print(f"Loaded paths: {len(loaded_paths)}")
print(f"Loaded labels: {len(loaded_labels)}")
# Out:
#                                                 path label  \
# 0  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
# 1  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
# 2  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
# 3  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
# 4  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
#
#                                             features
# 0  [0.0, 1.7346123456954956, 0.44908469915390015,...
# 1  [0.0, 0.0, 0.0, 3.3737080097198486, 0.04312886...
# 2  [0.0, 0.018066002056002617, 0.0, 0.0, 0.081132...
# 3  [0.0, 1.2526673078536987, 0.0, 0.0, 0.0, 0.071...
# 4  [0.0, 3.4545886516571045, 0.2538684606552124, ...
# Loaded features shape: torch.Size([944, 512])
# Loaded paths: 944
# Loaded labels: 944

# %%
import matplotlib.pyplot as plt

# Flatten the features for plotting (if needed)
flattened_features = feats.flatten().numpy()

# Plot the histogram of feature values
plt.figure(figsize=(10, 6))
plt.hist(flattened_features, bins=50, alpha=0.7, color='blue', edgecolor='black')
plt.title("Feature Value Distribution")
plt.xlabel("Feature Value")
plt.ylabel("Frequency")
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# # plot z score normalised

# %% [markdown]
# features_mean = feats.mean(dim=0, keepdim=True)
# features_std = feats.std(dim=0, keepdim=True)
#
# normalized_features = (feats - features_mean) / features_std
#
# # Check the new distribution
# flattened_normalized_features = normalized_features.flatten().numpy()
#
# # Plot the normalized distribution
# plt.figure(figsize=(10, 6))
# plt.hist(flattened_normalized_features, bins=50, alpha=0.7, color='green', edgecolor='black')
# plt.title("Normalized Feature Value Distribution (Standardized)")
# plt.xlabel("Feature Value")
# plt.ylabel("Frequency")
# plt.grid(alpha=0.3)
# plt.show()

# %%
# Min-Max scaling
features_min = feats.min(dim=0, keepdim=True).values  # Minimum value per feature
features_max = feats.max(dim=0, keepdim=True).values  # Maximum value per feature

normalized_feats = (feats - features_min) / (features_max - features_min)
print(normalized_feats.shape)

# Check the new distribution
flattened_normalized_features = normalized_feats.flatten().numpy()

# Plot the normalized distribution
plt.figure(figsize=(10, 6))
plt.hist(flattened_normalized_features, bins=50, alpha=0.7, color='green', edgecolor='black')
plt.title("Normalized Feature Value Distribution (Standardized)")
plt.xlabel("Feature Value")
plt.ylabel("Frequency")
plt.grid(alpha=0.3)
plt.show()
# Out:
# torch.Size([944, 512])

# %%
from torch.utils.data import TensorDataset
dataset = TensorDataset(normalized_feats)
len(dataset)
# Out:
# 944

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

class FeaturePredictor(nn.Module):
    def __init__(self, input_size=512, output_size=512):
        super(FeaturePredictor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16,8),
            nn.ReLU(),
            nn.Linear(8, 16),
            nn.ReLU(),
            nn.Linear(16,32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128,256),
            nn.ReLU(),
            nn.Linear(256, output_size)
        )
    
    def forward(self, x):
        return self.model(x)

# %%
model = FeaturePredictor()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
optimizer_class = torch.optim.Adam

from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset
import numpy as np
import torch

# %%
class EarlyStopping:
    def __init__(self, patience=10, delta=0.0):
        """
        Args:
            patience (int): How many epochs to wait after the last validation loss improvement.
            delta (float): Minimum change in the validation loss to qualify as an improvement.
        """
        self.patience = patience
        self.delta = delta
        self.best_loss = None
        self.no_improvement_epochs = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.no_improvement_epochs = 0
        else:
            self.no_improvement_epochs += 1
            if self.no_improvement_epochs >= self.patience:
                self.early_stop = True


def cross_validate_with_early_stopping(
    model_class, dataset, criterion, optimizer_class, num_epochs=50, n_splits=5, patience=10, delta=0.0, device='cuda'
):
    """
    Cross-validation with early stopping.

    Args:
        model_class: The model class to initialize.
        dataset: The dataset to perform cross-validation on.
        criterion: Loss function.
        optimizer_class: Optimizer class to use.
        num_epochs: Maximum number of epochs for training.
        n_splits: Number of cross-validation splits.
        patience: Number of epochs to wait for validation loss improvement.
        delta: Minimum change in validation loss to consider as improvement.
        device: Device to run the model on ('cuda' or 'cpu').

    Returns:
        histories: A list of training/validation loss histories for each fold.
        best_models: A list of best model states for each fold.
    """
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    histories = []
    best_models = []

    for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset)):
        print(f"Fold {fold + 1}/{n_splits}")

        # Create subsets for this fold
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        # Create DataLoaders
        train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

        # Initialize the model, optimizer, and early stopping for this fold
        model = model_class().to(device)
        optimizer = optimizer_class(model.parameters(), lr=1e-4)
        early_stopping = EarlyStopping(patience=patience, delta=delta)  # Pass delta here

        # Training and validation loop
        history = {'train_loss': [], 'val_loss': []}
        for epoch in range(num_epochs):
            # Training phase
            model.train()
            train_loss = 0.0
            for batch_feats in train_loader:
                batch_feats = batch_feats[0].to(device)

                # Forward pass
                outputs = model(batch_feats)
                loss = criterion(outputs, batch_feats)
                train_loss += loss.item()

                # Backward pass and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            train_loss /= len(train_loader)
            history['train_loss'].append(train_loss)

            # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for batch_feats in val_loader:
                    batch_feats = batch_feats[0].to(device)
                    outputs = model(batch_feats)
                    loss = criterion(outputs, batch_feats)
                    val_loss += loss.item()

            val_loss /= len(val_loader)
            history['val_loss'].append(val_loss)

            print(f"Epoch [{epoch + 1}/{num_epochs}] Fold {fold + 1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

            # Check early stopping
            early_stopping(val_loss)
            if early_stopping.early_stop:
                print(f"Early stopping at epoch {epoch + 1} for fold {fold + 1}")
                break

        # Save the best model for this fold
        best_models.append(model.state_dict())
        histories.append(history)

    return histories, best_models

# %%
cv_histories, best_models = cross_validate_with_early_stopping(
    model_class=FeaturePredictor,
    dataset=dataset,
    criterion=nn.MSELoss(),
    optimizer_class=torch.optim.Adam,
    num_epochs=2000,
    patience=500,
    delta=0.0000  # Example delta value
)
# Out:
# Fold 1/5
# Epoch [1/2000] Fold 1, Train Loss: 0.0744, Val Loss: 0.0716
# Epoch [2/2000] Fold 1, Train Loss: 0.0663, Val Loss: 0.0624
# Epoch [3/2000] Fold 1, Train Loss: 0.0561, Val Loss: 0.0514
# Epoch [4/2000] Fold 1, Train Loss: 0.0466, Val Loss: 0.0445
# Epoch [5/2000] Fold 1, Train Loss: 0.0424, Val Loss: 0.0426
# Epoch [6/2000] Fold 1, Train Loss: 0.0415, Val Loss: 0.0421
# Epoch [7/2000] Fold 1, Train Loss: 0.0412, Val Loss: 0.0420
# Epoch [8/2000] Fold 1, Train Loss: 0.0411, Val Loss: 0.0419
# Epoch [9/2000] Fold 1, Train Loss: 0.0410, Val Loss: 0.0418
# Epoch [10/2000] Fold 1, Train Loss: 0.0408, Val Loss: 0.0416
# Epoch [11/2000] Fold 1, Train Loss: 0.0405, Val Loss: 0.0409
# Epoch [12/2000] Fold 1, Train Loss: 0.0397, Val Loss: 0.0401
# Epoch [13/2000] Fold 1, Train Loss: 0.0392, Val Loss: 0.0393
# Epoch [14/2000] Fold 1, Train Loss: 0.0381, Val Loss: 0.0382
# Epoch [15/2000] Fold 1, Train Loss: 0.0370, Val Loss: 0.0373
# Epoch [16/2000] Fold 1, Train Loss: 0.0359, Val Loss: 0.0367
# Epoch [17/2000] Fold 1, Train Loss: 0.0353, Val Loss: 0.0362
# Epoch [18/2000] Fold 1, Train Loss: 0.0348, Val Loss: 0.0359
# Epoch [19/2000] Fold 1, Train Loss: 0.0344, Val Loss: 0.0356
# Epoch [20/2000] Fold 1, Train Loss: 0.0342, Val Loss: 0.0353
# Epoch [21/2000] Fold 1, Train Loss: 0.0338, Val Loss: 0.0350
# Epoch [22/2000] Fold 1, Train Loss: 0.0334, Val Loss: 0.0346
# Epoch [23/2000] Fold 1, Train Loss: 0.0327, Val Loss: 0.0338
# Epoch [24/2000] Fold 1, Train Loss: 0.0320, Val Loss: 0.0330
# Epoch [25/2000] Fold 1, Train Loss: 0.0312, Val Loss: 0.0321
# Epoch [26/2000] Fold 1, Train Loss: 0.0303, Val Loss: 0.0310
# Epoch [27/2000] Fold 1, Train Loss: 0.0295, Val Loss: 0.0301
# Epoch [28/2000] Fold 1, Train Loss: 0.0290, Val Loss: 0.0296
# Epoch [29/2000] Fold 1, Train Loss: 0.0285, Val Loss: 0.0294
# Epoch [30/2000] Fold 1, Train Loss: 0.0282, Val Loss: 0.0290
# Epoch [31/2000] Fold 1, Train Loss: 0.0280, Val Loss: 0.0288
# Epoch [32/2000] Fold 1, Train Loss: 0.0277, Val Loss: 0.0285
# Epoch [33/2000] Fold 1, Train Loss: 0.0274, Val Loss: 0.0283
# Epoch [34/2000] Fold 1, Train Loss: 0.0271, Val Loss: 0.0281
# Epoch [35/2000] Fold 1, Train Loss: 0.0269, Val Loss: 0.0278
# Epoch [36/2000] Fold 1, Train Loss: 0.0266, Val Loss: 0.0276
# Epoch [37/2000] Fold 1, Train Loss: 0.0264, Val Loss: 0.0275
# Epoch [38/2000] Fold 1, Train Loss: 0.0262, Val Loss: 0.0272
# Epoch [39/2000] Fold 1, Train Loss: 0.0257, Val Loss: 0.0269
# Epoch [40/2000] Fold 1, Train Loss: 0.0253, Val Loss: 0.0264
# Epoch [41/2000] Fold 1, Train Loss: 0.0248, Val Loss: 0.0258
# Epoch [42/2000] Fold 1, Train Loss: 0.0241, Val Loss: 0.0248
# Epoch [43/2000] Fold 1, Train Loss: 0.0232, Val Loss: 0.0244
# Epoch [44/2000] Fold 1, Train Loss: 0.0224, Val Loss: 0.0236
# Epoch [45/2000] Fold 1, Train Loss: 0.0220, Val Loss: 0.0236
# Epoch [46/2000] Fold 1, Train Loss: 0.0216, Val Loss: 0.0230
# Epoch [47/2000] Fold 1, Train Loss: 0.0215, Val Loss: 0.0230
# Epoch [48/2000] Fold 1, Train Loss: 0.0213, Val Loss: 0.0225
# Epoch [49/2000] Fold 1, Train Loss: 0.0210, Val Loss: 0.0226
# Epoch [50/2000] Fold 1, Train Loss: 0.0208, Val Loss: 0.0223
# Epoch [51/2000] Fold 1, Train Loss: 0.0207, Val Loss: 0.0223
# Epoch [52/2000] Fold 1, Train Loss: 0.0205, Val Loss: 0.0220
# Epoch [53/2000] Fold 1, Train Loss: 0.0204, Val Loss: 0.0220
# Epoch [54/2000] Fold 1, Train Loss: 0.0203, Val Loss: 0.0219
# Epoch [55/2000] Fold 1, Train Loss: 0.0201, Val Loss: 0.0217
# Epoch [56/2000] Fold 1, Train Loss: 0.0201, Val Loss: 0.0215
# Epoch [57/2000] Fold 1, Train Loss: 0.0199, Val Loss: 0.0216
# Epoch [58/2000] Fold 1, Train Loss: 0.0198, Val Loss: 0.0214
# Epoch [59/2000] Fold 1, Train Loss: 0.0196, Val Loss: 0.0213
# Epoch [60/2000] Fold 1, Train Loss: 0.0197, Val Loss: 0.0212
# Epoch [61/2000] Fold 1, Train Loss: 0.0195, Val Loss: 0.0212
# Epoch [62/2000] Fold 1, Train Loss: 0.0196, Val Loss: 0.0211
# Epoch [63/2000] Fold 1, Train Loss: 0.0194, Val Loss: 0.0210
# Epoch [64/2000] Fold 1, Train Loss: 0.0193, Val Loss: 0.0209
# Epoch [65/2000] Fold 1, Train Loss: 0.0193, Val Loss: 0.0208
# Epoch [66/2000] Fold 1, Train Loss: 0.0193, Val Loss: 0.0208
# Epoch [67/2000] Fold 1, Train Loss: 0.0191, Val Loss: 0.0207
# Epoch [68/2000] Fold 1, Train Loss: 0.0191, Val Loss: 0.0208
# Epoch [69/2000] Fold 1, Train Loss: 0.0190, Val Loss: 0.0208
# Epoch [70/2000] Fold 1, Train Loss: 0.0190, Val Loss: 0.0204
# Epoch [71/2000] Fold 1, Train Loss: 0.0189, Val Loss: 0.0206
# Epoch [72/2000] Fold 1, Train Loss: 0.0188, Val Loss: 0.0204
# Epoch [73/2000] Fold 1, Train Loss: 0.0187, Val Loss: 0.0203
# Epoch [74/2000] Fold 1, Train Loss: 0.0187, Val Loss: 0.0203
# Epoch [75/2000] Fold 1, Train Loss: 0.0186, Val Loss: 0.0203
# Epoch [76/2000] Fold 1, Train Loss: 0.0185, Val Loss: 0.0202
# Epoch [77/2000] Fold 1, Train Loss: 0.0185, Val Loss: 0.0201
# Epoch [78/2000] Fold 1, Train Loss: 0.0185, Val Loss: 0.0203
# Epoch [79/2000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0200
# Epoch [80/2000] Fold 1, Train Loss: 0.0184, Val Loss: 0.0200
# Epoch [81/2000] Fold 1, Train Loss: 0.0183, Val Loss: 0.0200
# Epoch [82/2000] Fold 1, Train Loss: 0.0183, Val Loss: 0.0199
# Epoch [83/2000] Fold 1, Train Loss: 0.0182, Val Loss: 0.0199
# Epoch [84/2000] Fold 1, Train Loss: 0.0181, Val Loss: 0.0197
# Epoch [85/2000] Fold 1, Train Loss: 0.0181, Val Loss: 0.0198
# Epoch [86/2000] Fold 1, Train Loss: 0.0181, Val Loss: 0.0197
# Epoch [87/2000] Fold 1, Train Loss: 0.0181, Val Loss: 0.0196
# Epoch [88/2000] Fold 1, Train Loss: 0.0179, Val Loss: 0.0196
# Epoch [89/2000] Fold 1, Train Loss: 0.0179, Val Loss: 0.0196
# Epoch [90/2000] Fold 1, Train Loss: 0.0179, Val Loss: 0.0195
# Epoch [91/2000] Fold 1, Train Loss: 0.0179, Val Loss: 0.0194
# Epoch [92/2000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0194
# Epoch [93/2000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0194
# Epoch [94/2000] Fold 1, Train Loss: 0.0178, Val Loss: 0.0193
# Epoch [95/2000] Fold 1, Train Loss: 0.0177, Val Loss: 0.0193
# Epoch [96/2000] Fold 1, Train Loss: 0.0176, Val Loss: 0.0193
# Epoch [97/2000] Fold 1, Train Loss: 0.0176, Val Loss: 0.0192
# Epoch [98/2000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0192
# Epoch [99/2000] Fold 1, Train Loss: 0.0176, Val Loss: 0.0192
# Epoch [100/2000] Fold 1, Train Loss: 0.0175, Val Loss: 0.0191
# Epoch [101/2000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0190
# Epoch [102/2000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0191
# Epoch [103/2000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0191
# Epoch [104/2000] Fold 1, Train Loss: 0.0173, Val Loss: 0.0189
# Epoch [105/2000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0190
# Epoch [106/2000] Fold 1, Train Loss: 0.0174, Val Loss: 0.0189
# Epoch [107/2000] Fold 1, Train Loss: 0.0172, Val Loss: 0.0189
# Epoch [108/2000] Fold 1, Train Loss: 0.0172, Val Loss: 0.0188
# Epoch [109/2000] Fold 1, Train Loss: 0.0172, Val Loss: 0.0189
# Epoch [110/2000] Fold 1, Train Loss: 0.0171, Val Loss: 0.0189
# Epoch [111/2000] Fold 1, Train Loss: 0.0171, Val Loss: 0.0187
# Epoch [112/2000] Fold 1, Train Loss: 0.0171, Val Loss: 0.0187
# Epoch [113/2000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0187
# Epoch [114/2000] Fold 1, Train Loss: 0.0171, Val Loss: 0.0186
# Epoch [115/2000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0186
# Epoch [116/2000] Fold 1, Train Loss: 0.0170, Val Loss: 0.0186
# Epoch [117/2000] Fold 1, Train Loss: 0.0169, Val Loss: 0.0187
# Epoch [118/2000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0185
# Epoch [119/2000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0186
# Epoch [120/2000] Fold 1, Train Loss: 0.0168, Val Loss: 0.0185
# Epoch [121/2000] Fold 1, Train Loss: 0.0167, Val Loss: 0.0185
# Epoch [122/2000] Fold 1, Train Loss: 0.0167, Val Loss: 0.0185
# Epoch [123/2000] Fold 1, Train Loss: 0.0167, Val Loss: 0.0184
# Epoch [124/2000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0183
# Epoch [125/2000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0183
# Epoch [126/2000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0183
# Epoch [127/2000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0183
# Epoch [128/2000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0184
# Epoch [129/2000] Fold 1, Train Loss: 0.0166, Val Loss: 0.0183
# Epoch [130/2000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0183
# Epoch [131/2000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0182
# Epoch [132/2000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0182
# Epoch [133/2000] Fold 1, Train Loss: 0.0165, Val Loss: 0.0182
# Epoch [134/2000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0182
# Epoch [135/2000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0182
# Epoch [136/2000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0181
# Epoch [137/2000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0181
# Epoch [138/2000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0181
# Epoch [139/2000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0182
# Epoch [140/2000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0183
# Epoch [141/2000] Fold 1, Train Loss: 0.0163, Val Loss: 0.0180
# Epoch [142/2000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0180
# Epoch [143/2000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0179
# Epoch [144/2000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0180
# Epoch [145/2000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0180
# Epoch [146/2000] Fold 1, Train Loss: 0.0162, Val Loss: 0.0180
# Epoch [147/2000] Fold 1, Train Loss: 0.0161, Val Loss: 0.0179
# Epoch [148/2000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0180
# Epoch [149/2000] Fold 1, Train Loss: 0.0160, Val Loss: 0.0178
# Epoch [150/2000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0179
# Epoch [151/2000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0178
# Epoch [152/2000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0178
# Epoch [153/2000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0178
# Epoch [154/2000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0178
# Epoch [155/2000] Fold 1, Train Loss: 0.0159, Val Loss: 0.0177
# Epoch [156/2000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0178
# Epoch [157/2000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0177
# Epoch [158/2000] Fold 1, Train Loss: 0.0158, Val Loss: 0.0178
# Epoch [159/2000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0177
# Epoch [160/2000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0176
# Epoch [161/2000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0176
# Epoch [162/2000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0177
# Epoch [163/2000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0178
# Epoch [164/2000] Fold 1, Train Loss: 0.0157, Val Loss: 0.0176
# Epoch [165/2000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0177
# Epoch [166/2000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0175
# Epoch [167/2000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0175
# Epoch [168/2000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0175
# Epoch [169/2000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0175
# Epoch [170/2000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0175
# Epoch [171/2000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0176
# Epoch [172/2000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0176
# Epoch [173/2000] Fold 1, Train Loss: 0.0156, Val Loss: 0.0175
# Epoch [174/2000] Fold 1, Train Loss: 0.0155, Val Loss: 0.0174
# Epoch [175/2000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0174
# Epoch [176/2000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0175
# Epoch [177/2000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0174
# Epoch [178/2000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0176
# Epoch [179/2000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0174
# Epoch [180/2000] Fold 1, Train Loss: 0.0154, Val Loss: 0.0173
# Epoch [181/2000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0174
# Epoch [182/2000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0173
# Epoch [183/2000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0173
# Epoch [184/2000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0173
# Epoch [185/2000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0172
# Epoch [186/2000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0173
# Epoch [187/2000] Fold 1, Train Loss: 0.0153, Val Loss: 0.0172
# Epoch [188/2000] Fold 1, Train Loss: 0.0152, Val Loss: 0.0173
# Epoch [189/2000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0173
# Epoch [190/2000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0172
# Epoch [191/2000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0172
# Epoch [192/2000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0172
# Epoch [193/2000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0172
# Epoch [194/2000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0172
# Epoch [195/2000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0172
# Epoch [196/2000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0172
# Epoch [197/2000] Fold 1, Train Loss: 0.0151, Val Loss: 0.0171
# Epoch [198/2000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0172
# Epoch [199/2000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0172
# Epoch [200/2000] Fold 1, Train Loss: 0.0150, Val Loss: 0.0171
# Epoch [201/2000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0171
# Epoch [202/2000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0170
# Epoch [203/2000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0170
# Epoch [204/2000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0171
# Epoch [205/2000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0170
# Epoch [206/2000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0171
# Epoch [207/2000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0170
# Epoch [208/2000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0170
# Epoch [209/2000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0171
# Epoch [210/2000] Fold 1, Train Loss: 0.0149, Val Loss: 0.0170
# Epoch [211/2000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0169
# Epoch [212/2000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0172
# Epoch [213/2000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0169
# Epoch [214/2000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0169
# Epoch [215/2000] Fold 1, Train Loss: 0.0148, Val Loss: 0.0170
# Epoch [216/2000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0170
# Epoch [217/2000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0170
# Epoch [218/2000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0169
# Epoch [219/2000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0169
# Epoch [220/2000] Fold 1, Train Loss: 0.0147, Val Loss: 0.0168
# Epoch [221/2000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0169
# Epoch [222/2000] Fold 1, Train Loss: 0.0146, Val Loss: 0.0170
# Epoch [223/2000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0168
# Epoch [224/2000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0169
# Epoch [225/2000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0168
# Epoch [226/2000] Fold 1, Train Loss: 0.0144, Val Loss: 0.0168
# Epoch [227/2000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0169
# Epoch [228/2000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0168
# Epoch [229/2000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0170
# Epoch [230/2000] Fold 1, Train Loss: 0.0145, Val Loss: 0.0168
# Epoch [231/2000] Fold 1, Train Loss: 0.0143, Val Loss: 0.0167
# Epoch [232/2000] Fold 1, Train Loss: 0.0144, Val Loss: 0.0168
# Epoch [233/2000] Fold 1, Train Loss: 0.0144, Val Loss: 0.0167
# Epoch [234/2000] Fold 1, Train Loss: 0.0144, Val Loss: 0.0167
# Epoch [235/2000] Fold 1, Train Loss: 0.0143, Val Loss: 0.0167
# Epoch [236/2000] Fold 1, Train Loss: 0.0143, Val Loss: 0.0168
# Epoch [237/2000] Fold 1, Train Loss: 0.0143, Val Loss: 0.0167
# Epoch [238/2000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0167
# Epoch [239/2000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0168
# Epoch [240/2000] Fold 1, Train Loss: 0.0143, Val Loss: 0.0168
# Epoch [241/2000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0166
# Epoch [242/2000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0166
# Epoch [243/2000] Fold 1, Train Loss: 0.0141, Val Loss: 0.0166
# Epoch [244/2000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0167
# Epoch [245/2000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0167
# Epoch [246/2000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0166
# Epoch [247/2000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0166
# Epoch [248/2000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0165
# Epoch [249/2000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0165
# Epoch [250/2000] Fold 1, Train Loss: 0.0141, Val Loss: 0.0166
# Epoch [251/2000] Fold 1, Train Loss: 0.0141, Val Loss: 0.0165
# Epoch [252/2000] Fold 1, Train Loss: 0.0142, Val Loss: 0.0166
# Epoch [253/2000] Fold 1, Train Loss: 0.0141, Val Loss: 0.0166
# Epoch [254/2000] Fold 1, Train Loss: 0.0140, Val Loss: 0.0165
# Epoch [255/2000] Fold 1, Train Loss: 0.0140, Val Loss: 0.0165
# Epoch [256/2000] Fold 1, Train Loss: 0.0140, Val Loss: 0.0165
# Epoch [257/2000] Fold 1, Train Loss: 0.0140, Val Loss: 0.0164
# Epoch [258/2000] Fold 1, Train Loss: 0.0140, Val Loss: 0.0164
# Epoch [259/2000] Fold 1, Train Loss: 0.0139, Val Loss: 0.0164
# Epoch [260/2000] Fold 1, Train Loss: 0.0140, Val Loss: 0.0165
# Epoch [261/2000] Fold 1, Train Loss: 0.0139, Val Loss: 0.0164
# Epoch [262/2000] Fold 1, Train Loss: 0.0139, Val Loss: 0.0164
# Epoch [263/2000] Fold 1, Train Loss: 0.0138, Val Loss: 0.0164
# Epoch [264/2000] Fold 1, Train Loss: 0.0139, Val Loss: 0.0163
# Epoch [265/2000] Fold 1, Train Loss: 0.0138, Val Loss: 0.0163
# Epoch [266/2000] Fold 1, Train Loss: 0.0138, Val Loss: 0.0163
# Epoch [267/2000] Fold 1, Train Loss: 0.0139, Val Loss: 0.0163
# Epoch [268/2000] Fold 1, Train Loss: 0.0138, Val Loss: 0.0163
# Epoch [269/2000] Fold 1, Train Loss: 0.0137, Val Loss: 0.0164
# Epoch [270/2000] Fold 1, Train Loss: 0.0138, Val Loss: 0.0163
# Epoch [271/2000] Fold 1, Train Loss: 0.0138, Val Loss: 0.0163
# Epoch [272/2000] Fold 1, Train Loss: 0.0137, Val Loss: 0.0163
# Epoch [273/2000] Fold 1, Train Loss: 0.0138, Val Loss: 0.0162
# Epoch [274/2000] Fold 1, Train Loss: 0.0137, Val Loss: 0.0162
# Epoch [275/2000] Fold 1, Train Loss: 0.0137, Val Loss: 0.0162
# Epoch [276/2000] Fold 1, Train Loss: 0.0137, Val Loss: 0.0162
# Epoch [277/2000] Fold 1, Train Loss: 0.0136, Val Loss: 0.0161
# Epoch [278/2000] Fold 1, Train Loss: 0.0135, Val Loss: 0.0161
# Epoch [279/2000] Fold 1, Train Loss: 0.0136, Val Loss: 0.0161
# Epoch [280/2000] Fold 1, Train Loss: 0.0135, Val Loss: 0.0162
# Epoch [281/2000] Fold 1, Train Loss: 0.0135, Val Loss: 0.0162
# Epoch [282/2000] Fold 1, Train Loss: 0.0136, Val Loss: 0.0162
# Epoch [283/2000] Fold 1, Train Loss: 0.0135, Val Loss: 0.0160
# Epoch [284/2000] Fold 1, Train Loss: 0.0134, Val Loss: 0.0161
# Epoch [285/2000] Fold 1, Train Loss: 0.0134, Val Loss: 0.0160
# Epoch [286/2000] Fold 1, Train Loss: 0.0134, Val Loss: 0.0163
# Epoch [287/2000] Fold 1, Train Loss: 0.0135, Val Loss: 0.0160
# Epoch [288/2000] Fold 1, Train Loss: 0.0133, Val Loss: 0.0160
# Epoch [289/2000] Fold 1, Train Loss: 0.0134, Val Loss: 0.0160
# Epoch [290/2000] Fold 1, Train Loss: 0.0133, Val Loss: 0.0159
# Epoch [291/2000] Fold 1, Train Loss: 0.0133, Val Loss: 0.0158
# Epoch [292/2000] Fold 1, Train Loss: 0.0133, Val Loss: 0.0159
# Epoch [293/2000] Fold 1, Train Loss: 0.0133, Val Loss: 0.0158
# Epoch [294/2000] Fold 1, Train Loss: 0.0132, Val Loss: 0.0159
# Epoch [295/2000] Fold 1, Train Loss: 0.0132, Val Loss: 0.0159
# Epoch [296/2000] Fold 1, Train Loss: 0.0131, Val Loss: 0.0157
# Epoch [297/2000] Fold 1, Train Loss: 0.0131, Val Loss: 0.0157
# Epoch [298/2000] Fold 1, Train Loss: 0.0131, Val Loss: 0.0158
# Epoch [299/2000] Fold 1, Train Loss: 0.0131, Val Loss: 0.0157
# Epoch [300/2000] Fold 1, Train Loss: 0.0130, Val Loss: 0.0157
# Epoch [301/2000] Fold 1, Train Loss: 0.0130, Val Loss: 0.0156
# Epoch [302/2000] Fold 1, Train Loss: 0.0130, Val Loss: 0.0157
# Epoch [303/2000] Fold 1, Train Loss: 0.0129, Val Loss: 0.0156
# Epoch [304/2000] Fold 1, Train Loss: 0.0129, Val Loss: 0.0155
# Epoch [305/2000] Fold 1, Train Loss: 0.0128, Val Loss: 0.0155
# Epoch [306/2000] Fold 1, Train Loss: 0.0129, Val Loss: 0.0154
# Epoch [307/2000] Fold 1, Train Loss: 0.0128, Val Loss: 0.0158
# Epoch [308/2000] Fold 1, Train Loss: 0.0129, Val Loss: 0.0154
# Epoch [309/2000] Fold 1, Train Loss: 0.0127, Val Loss: 0.0153
# Epoch [310/2000] Fold 1, Train Loss: 0.0127, Val Loss: 0.0152
# Epoch [311/2000] Fold 1, Train Loss: 0.0126, Val Loss: 0.0152
# Epoch [312/2000] Fold 1, Train Loss: 0.0126, Val Loss: 0.0152
# Epoch [313/2000] Fold 1, Train Loss: 0.0126, Val Loss: 0.0152
# Epoch [314/2000] Fold 1, Train Loss: 0.0125, Val Loss: 0.0151
# Epoch [315/2000] Fold 1, Train Loss: 0.0125, Val Loss: 0.0151
# Epoch [316/2000] Fold 1, Train Loss: 0.0125, Val Loss: 0.0152
# Epoch [317/2000] Fold 1, Train Loss: 0.0124, Val Loss: 0.0149
# Epoch [318/2000] Fold 1, Train Loss: 0.0123, Val Loss: 0.0148
# Epoch [319/2000] Fold 1, Train Loss: 0.0123, Val Loss: 0.0147
# Epoch [320/2000] Fold 1, Train Loss: 0.0121, Val Loss: 0.0147
# Epoch [321/2000] Fold 1, Train Loss: 0.0122, Val Loss: 0.0146
# Epoch [322/2000] Fold 1, Train Loss: 0.0121, Val Loss: 0.0146
# Epoch [323/2000] Fold 1, Train Loss: 0.0121, Val Loss: 0.0147
# Epoch [324/2000] Fold 1, Train Loss: 0.0120, Val Loss: 0.0145
# Epoch [325/2000] Fold 1, Train Loss: 0.0119, Val Loss: 0.0144
# Epoch [326/2000] Fold 1, Train Loss: 0.0119, Val Loss: 0.0145
# Epoch [327/2000] Fold 1, Train Loss: 0.0118, Val Loss: 0.0143
# Epoch [328/2000] Fold 1, Train Loss: 0.0118, Val Loss: 0.0143
# Epoch [329/2000] Fold 1, Train Loss: 0.0118, Val Loss: 0.0143
# Epoch [330/2000] Fold 1, Train Loss: 0.0117, Val Loss: 0.0142
# Epoch [331/2000] Fold 1, Train Loss: 0.0117, Val Loss: 0.0142
# Epoch [332/2000] Fold 1, Train Loss: 0.0116, Val Loss: 0.0141
# Epoch [333/2000] Fold 1, Train Loss: 0.0116, Val Loss: 0.0140
# Epoch [334/2000] Fold 1, Train Loss: 0.0116, Val Loss: 0.0140
# Epoch [335/2000] Fold 1, Train Loss: 0.0115, Val Loss: 0.0139
# Epoch [336/2000] Fold 1, Train Loss: 0.0116, Val Loss: 0.0142
# Epoch [337/2000] Fold 1, Train Loss: 0.0116, Val Loss: 0.0139
# Epoch [338/2000] Fold 1, Train Loss: 0.0114, Val Loss: 0.0139
# Epoch [339/2000] Fold 1, Train Loss: 0.0114, Val Loss: 0.0139
# Epoch [340/2000] Fold 1, Train Loss: 0.0114, Val Loss: 0.0137
# Epoch [341/2000] Fold 1, Train Loss: 0.0113, Val Loss: 0.0139
# Epoch [342/2000] Fold 1, Train Loss: 0.0113, Val Loss: 0.0138
# Epoch [343/2000] Fold 1, Train Loss: 0.0112, Val Loss: 0.0137
# Epoch [344/2000] Fold 1, Train Loss: 0.0112, Val Loss: 0.0138
# Epoch [345/2000] Fold 1, Train Loss: 0.0112, Val Loss: 0.0137
# Epoch [346/2000] Fold 1, Train Loss: 0.0112, Val Loss: 0.0137
# Epoch [347/2000] Fold 1, Train Loss: 0.0112, Val Loss: 0.0136
# Epoch [348/2000] Fold 1, Train Loss: 0.0112, Val Loss: 0.0137
# Epoch [349/2000] Fold 1, Train Loss: 0.0112, Val Loss: 0.0138
# Epoch [350/2000] Fold 1, Train Loss: 0.0111, Val Loss: 0.0136
# Epoch [351/2000] Fold 1, Train Loss: 0.0111, Val Loss: 0.0136
# Epoch [352/2000] Fold 1, Train Loss: 0.0111, Val Loss: 0.0136
# Epoch [353/2000] Fold 1, Train Loss: 0.0111, Val Loss: 0.0135
# Epoch [354/2000] Fold 1, Train Loss: 0.0110, Val Loss: 0.0134
# Epoch [355/2000] Fold 1, Train Loss: 0.0110, Val Loss: 0.0134
# Epoch [356/2000] Fold 1, Train Loss: 0.0109, Val Loss: 0.0135
# Epoch [357/2000] Fold 1, Train Loss: 0.0110, Val Loss: 0.0136
# Epoch [358/2000] Fold 1, Train Loss: 0.0109, Val Loss: 0.0133
# Epoch [359/2000] Fold 1, Train Loss: 0.0109, Val Loss: 0.0133
# Epoch [360/2000] Fold 1, Train Loss: 0.0108, Val Loss: 0.0134
# Epoch [361/2000] Fold 1, Train Loss: 0.0108, Val Loss: 0.0134
# Epoch [362/2000] Fold 1, Train Loss: 0.0108, Val Loss: 0.0133
# Epoch [363/2000] Fold 1, Train Loss: 0.0108, Val Loss: 0.0134
# Epoch [364/2000] Fold 1, Train Loss: 0.0107, Val Loss: 0.0133
# Epoch [365/2000] Fold 1, Train Loss: 0.0108, Val Loss: 0.0133
# Epoch [366/2000] Fold 1, Train Loss: 0.0108, Val Loss: 0.0133
# Epoch [367/2000] Fold 1, Train Loss: 0.0108, Val Loss: 0.0132
# Epoch [368/2000] Fold 1, Train Loss: 0.0107, Val Loss: 0.0132
# Epoch [369/2000] Fold 1, Train Loss: 0.0107, Val Loss: 0.0132
# Epoch [370/2000] Fold 1, Train Loss: 0.0106, Val Loss: 0.0132
# Epoch [371/2000] Fold 1, Train Loss: 0.0106, Val Loss: 0.0133
# Epoch [372/2000] Fold 1, Train Loss: 0.0106, Val Loss: 0.0132
# Epoch [373/2000] Fold 1, Train Loss: 0.0106, Val Loss: 0.0131
# Epoch [374/2000] Fold 1, Train Loss: 0.0106, Val Loss: 0.0131
# Epoch [375/2000] Fold 1, Train Loss: 0.0106, Val Loss: 0.0131
# Epoch [376/2000] Fold 1, Train Loss: 0.0105, Val Loss: 0.0132
# Epoch [377/2000] Fold 1, Train Loss: 0.0106, Val Loss: 0.0132
# Epoch [378/2000] Fold 1, Train Loss: 0.0105, Val Loss: 0.0131
# Epoch [379/2000] Fold 1, Train Loss: 0.0105, Val Loss: 0.0131
# Epoch [380/2000] Fold 1, Train Loss: 0.0105, Val Loss: 0.0131
# Epoch [381/2000] Fold 1, Train Loss: 0.0105, Val Loss: 0.0131
# Epoch [382/2000] Fold 1, Train Loss: 0.0104, Val Loss: 0.0130
# Epoch [383/2000] Fold 1, Train Loss: 0.0104, Val Loss: 0.0130
# Epoch [384/2000] Fold 1, Train Loss: 0.0104, Val Loss: 0.0130
# Epoch [385/2000] Fold 1, Train Loss: 0.0105, Val Loss: 0.0130
# Epoch [386/2000] Fold 1, Train Loss: 0.0104, Val Loss: 0.0130
# Epoch [387/2000] Fold 1, Train Loss: 0.0104, Val Loss: 0.0130
# Epoch [388/2000] Fold 1, Train Loss: 0.0104, Val Loss: 0.0129
# Epoch [389/2000] Fold 1, Train Loss: 0.0104, Val Loss: 0.0130
# Epoch [390/2000] Fold 1, Train Loss: 0.0103, Val Loss: 0.0129
# Epoch [391/2000] Fold 1, Train Loss: 0.0103, Val Loss: 0.0130
# Epoch [392/2000] Fold 1, Train Loss: 0.0103, Val Loss: 0.0130
# Epoch [393/2000] Fold 1, Train Loss: 0.0103, Val Loss: 0.0129
# Epoch [394/2000] Fold 1, Train Loss: 0.0103, Val Loss: 0.0130
# Epoch [395/2000] Fold 1, Train Loss: 0.0103, Val Loss: 0.0129
# Epoch [396/2000] Fold 1, Train Loss: 0.0102, Val Loss: 0.0128
# Epoch [397/2000] Fold 1, Train Loss: 0.0102, Val Loss: 0.0129
# Epoch [398/2000] Fold 1, Train Loss: 0.0101, Val Loss: 0.0129
# Epoch [399/2000] Fold 1, Train Loss: 0.0102, Val Loss: 0.0129
# Epoch [400/2000] Fold 1, Train Loss: 0.0102, Val Loss: 0.0129
# Epoch [401/2000] Fold 1, Train Loss: 0.0101, Val Loss: 0.0129
# Epoch [402/2000] Fold 1, Train Loss: 0.0101, Val Loss: 0.0129
# Epoch [403/2000] Fold 1, Train Loss: 0.0101, Val Loss: 0.0128
# Epoch [404/2000] Fold 1, Train Loss: 0.0101, Val Loss: 0.0128
# Epoch [405/2000] Fold 1, Train Loss: 0.0101, Val Loss: 0.0129
# Epoch [406/2000] Fold 1, Train Loss: 0.0101, Val Loss: 0.0128
# Epoch [407/2000] Fold 1, Train Loss: 0.0101, Val Loss: 0.0128
# Epoch [408/2000] Fold 1, Train Loss: 0.0101, Val Loss: 0.0128
# Epoch [409/2000] Fold 1, Train Loss: 0.0100, Val Loss: 0.0127
# Epoch [410/2000] Fold 1, Train Loss: 0.0100, Val Loss: 0.0127
# Epoch [411/2000] Fold 1, Train Loss: 0.0100, Val Loss: 0.0128
# Epoch [412/2000] Fold 1, Train Loss: 0.0100, Val Loss: 0.0128
# Epoch [413/2000] Fold 1, Train Loss: 0.0099, Val Loss: 0.0127
# Epoch [414/2000] Fold 1, Train Loss: 0.0099, Val Loss: 0.0128
# Epoch [415/2000] Fold 1, Train Loss: 0.0101, Val Loss: 0.0127
# Epoch [416/2000] Fold 1, Train Loss: 0.0100, Val Loss: 0.0127
# Epoch [417/2000] Fold 1, Train Loss: 0.0099, Val Loss: 0.0128
# Epoch [418/2000] Fold 1, Train Loss: 0.0100, Val Loss: 0.0127
# Epoch [419/2000] Fold 1, Train Loss: 0.0099, Val Loss: 0.0127
# Epoch [420/2000] Fold 1, Train Loss: 0.0099, Val Loss: 0.0128
# Epoch [421/2000] Fold 1, Train Loss: 0.0099, Val Loss: 0.0127
# Epoch [422/2000] Fold 1, Train Loss: 0.0098, Val Loss: 0.0127
# Epoch [423/2000] Fold 1, Train Loss: 0.0098, Val Loss: 0.0126
# Epoch [424/2000] Fold 1, Train Loss: 0.0098, Val Loss: 0.0126
# Epoch [425/2000] Fold 1, Train Loss: 0.0098, Val Loss: 0.0125
# Epoch [426/2000] Fold 1, Train Loss: 0.0098, Val Loss: 0.0126
# Epoch [427/2000] Fold 1, Train Loss: 0.0098, Val Loss: 0.0125
# Epoch [428/2000] Fold 1, Train Loss: 0.0098, Val Loss: 0.0125
# Epoch [429/2000] Fold 1, Train Loss: 0.0098, Val Loss: 0.0126
# Epoch [430/2000] Fold 1, Train Loss: 0.0098, Val Loss: 0.0127
# Epoch [431/2000] Fold 1, Train Loss: 0.0098, Val Loss: 0.0126
# Epoch [432/2000] Fold 1, Train Loss: 0.0097, Val Loss: 0.0125
# Epoch [433/2000] Fold 1, Train Loss: 0.0097, Val Loss: 0.0125
# Epoch [434/2000] Fold 1, Train Loss: 0.0098, Val Loss: 0.0127
# Epoch [435/2000] Fold 1, Train Loss: 0.0097, Val Loss: 0.0125
# Epoch [436/2000] Fold 1, Train Loss: 0.0097, Val Loss: 0.0126
# Epoch [437/2000] Fold 1, Train Loss: 0.0097, Val Loss: 0.0124
# Epoch [438/2000] Fold 1, Train Loss: 0.0096, Val Loss: 0.0125
# Epoch [439/2000] Fold 1, Train Loss: 0.0096, Val Loss: 0.0124
# Epoch [440/2000] Fold 1, Train Loss: 0.0096, Val Loss: 0.0126
# Epoch [441/2000] Fold 1, Train Loss: 0.0096, Val Loss: 0.0125
# Epoch [442/2000] Fold 1, Train Loss: 0.0096, Val Loss: 0.0125
# Epoch [443/2000] Fold 1, Train Loss: 0.0096, Val Loss: 0.0124
# Epoch [444/2000] Fold 1, Train Loss: 0.0096, Val Loss: 0.0126
# Epoch [445/2000] Fold 1, Train Loss: 0.0095, Val Loss: 0.0124
# Epoch [446/2000] Fold 1, Train Loss: 0.0096, Val Loss: 0.0124
# Epoch [447/2000] Fold 1, Train Loss: 0.0095, Val Loss: 0.0125
# Epoch [448/2000] Fold 1, Train Loss: 0.0096, Val Loss: 0.0124
# Epoch [449/2000] Fold 1, Train Loss: 0.0096, Val Loss: 0.0124
# Epoch [450/2000] Fold 1, Train Loss: 0.0096, Val Loss: 0.0124
# Epoch [451/2000] Fold 1, Train Loss: 0.0095, Val Loss: 0.0125
# Epoch [452/2000] Fold 1, Train Loss: 0.0095, Val Loss: 0.0124
# Epoch [453/2000] Fold 1, Train Loss: 0.0095, Val Loss: 0.0124
# Epoch [454/2000] Fold 1, Train Loss: 0.0095, Val Loss: 0.0124
# Epoch [455/2000] Fold 1, Train Loss: 0.0094, Val Loss: 0.0123
# Epoch [456/2000] Fold 1, Train Loss: 0.0094, Val Loss: 0.0124
# Epoch [457/2000] Fold 1, Train Loss: 0.0094, Val Loss: 0.0124
# Epoch [458/2000] Fold 1, Train Loss: 0.0094, Val Loss: 0.0124
# Epoch [459/2000] Fold 1, Train Loss: 0.0094, Val Loss: 0.0123
# Epoch [460/2000] Fold 1, Train Loss: 0.0094, Val Loss: 0.0124
# Epoch [461/2000] Fold 1, Train Loss: 0.0093, Val Loss: 0.0124
# Epoch [462/2000] Fold 1, Train Loss: 0.0094, Val Loss: 0.0124
# Epoch [463/2000] Fold 1, Train Loss: 0.0094, Val Loss: 0.0123
# Epoch [464/2000] Fold 1, Train Loss: 0.0094, Val Loss: 0.0123
# Epoch [465/2000] Fold 1, Train Loss: 0.0093, Val Loss: 0.0123
# Epoch [466/2000] Fold 1, Train Loss: 0.0093, Val Loss: 0.0123
# Epoch [467/2000] Fold 1, Train Loss: 0.0093, Val Loss: 0.0124
# Epoch [468/2000] Fold 1, Train Loss: 0.0093, Val Loss: 0.0123
# Epoch [469/2000] Fold 1, Train Loss: 0.0093, Val Loss: 0.0123
# Epoch [470/2000] Fold 1, Train Loss: 0.0093, Val Loss: 0.0122
# Epoch [471/2000] Fold 1, Train Loss: 0.0093, Val Loss: 0.0123
# Epoch [472/2000] Fold 1, Train Loss: 0.0092, Val Loss: 0.0122
# Epoch [473/2000] Fold 1, Train Loss: 0.0092, Val Loss: 0.0122
# Epoch [474/2000] Fold 1, Train Loss: 0.0092, Val Loss: 0.0123
# Epoch [475/2000] Fold 1, Train Loss: 0.0092, Val Loss: 0.0122
# Epoch [476/2000] Fold 1, Train Loss: 0.0092, Val Loss: 0.0122
# Epoch [477/2000] Fold 1, Train Loss: 0.0092, Val Loss: 0.0123
# Epoch [478/2000] Fold 1, Train Loss: 0.0093, Val Loss: 0.0124
# Epoch [479/2000] Fold 1, Train Loss: 0.0092, Val Loss: 0.0123
# Epoch [480/2000] Fold 1, Train Loss: 0.0091, Val Loss: 0.0122
# Epoch [481/2000] Fold 1, Train Loss: 0.0091, Val Loss: 0.0123
# Epoch [482/2000] Fold 1, Train Loss: 0.0092, Val Loss: 0.0122
# Epoch [483/2000] Fold 1, Train Loss: 0.0091, Val Loss: 0.0123
# Epoch [484/2000] Fold 1, Train Loss: 0.0091, Val Loss: 0.0123
# Epoch [485/2000] Fold 1, Train Loss: 0.0091, Val Loss: 0.0122
# Epoch [486/2000] Fold 1, Train Loss: 0.0091, Val Loss: 0.0122
# Epoch [487/2000] Fold 1, Train Loss: 0.0091, Val Loss: 0.0121
# Epoch [488/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0124
# Epoch [489/2000] Fold 1, Train Loss: 0.0091, Val Loss: 0.0123
# Epoch [490/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0122
# Epoch [491/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0122
# Epoch [492/2000] Fold 1, Train Loss: 0.0091, Val Loss: 0.0122
# Epoch [493/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0122
# Epoch [494/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0121
# Epoch [495/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0122
# Epoch [496/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0122
# Epoch [497/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0123
# Epoch [498/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0122
# Epoch [499/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0121
# Epoch [500/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0123
# Epoch [501/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0123
# Epoch [502/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0121
# Epoch [503/2000] Fold 1, Train Loss: 0.0089, Val Loss: 0.0121
# Epoch [504/2000] Fold 1, Train Loss: 0.0090, Val Loss: 0.0121
# Epoch [505/2000] Fold 1, Train Loss: 0.0089, Val Loss: 0.0121
# Epoch [506/2000] Fold 1, Train Loss: 0.0089, Val Loss: 0.0121
# Epoch [507/2000] Fold 1, Train Loss: 0.0089, Val Loss: 0.0122
# Epoch [508/2000] Fold 1, Train Loss: 0.0089, Val Loss: 0.0121
# Epoch [509/2000] Fold 1, Train Loss: 0.0088, Val Loss: 0.0120
# Epoch [510/2000] Fold 1, Train Loss: 0.0088, Val Loss: 0.0120
# Epoch [511/2000] Fold 1, Train Loss: 0.0088, Val Loss: 0.0120
# Epoch [512/2000] Fold 1, Train Loss: 0.0088, Val Loss: 0.0122
# Epoch [513/2000] Fold 1, Train Loss: 0.0088, Val Loss: 0.0120
# Epoch [514/2000] Fold 1, Train Loss: 0.0088, Val Loss: 0.0120
# Epoch [515/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0120
# Epoch [516/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0120
# Epoch [517/2000] Fold 1, Train Loss: 0.0088, Val Loss: 0.0120
# Epoch [518/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0120
# Epoch [519/2000] Fold 1, Train Loss: 0.0088, Val Loss: 0.0121
# Epoch [520/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0120
# Epoch [521/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0120
# Epoch [522/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0120
# Epoch [523/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0120
# Epoch [524/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0120
# Epoch [525/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0120
# Epoch [526/2000] Fold 1, Train Loss: 0.0086, Val Loss: 0.0119
# Epoch [527/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0120
# Epoch [528/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0120
# Epoch [529/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0120
# Epoch [530/2000] Fold 1, Train Loss: 0.0087, Val Loss: 0.0121
# Epoch [531/2000] Fold 1, Train Loss: 0.0086, Val Loss: 0.0120
# Epoch [532/2000] Fold 1, Train Loss: 0.0086, Val Loss: 0.0119
# Epoch [533/2000] Fold 1, Train Loss: 0.0086, Val Loss: 0.0119
# Epoch [534/2000] Fold 1, Train Loss: 0.0086, Val Loss: 0.0120
# Epoch [535/2000] Fold 1, Train Loss: 0.0086, Val Loss: 0.0118
# Epoch [536/2000] Fold 1, Train Loss: 0.0085, Val Loss: 0.0120
# Epoch [537/2000] Fold 1, Train Loss: 0.0085, Val Loss: 0.0119
# Epoch [538/2000] Fold 1, Train Loss: 0.0085, Val Loss: 0.0119
# Epoch [539/2000] Fold 1, Train Loss: 0.0085, Val Loss: 0.0119
# Epoch [540/2000] Fold 1, Train Loss: 0.0085, Val Loss: 0.0119
# Epoch [541/2000] Fold 1, Train Loss: 0.0085, Val Loss: 0.0118
# Epoch [542/2000] Fold 1, Train Loss: 0.0085, Val Loss: 0.0118
# Epoch [543/2000] Fold 1, Train Loss: 0.0085, Val Loss: 0.0120
# Epoch [544/2000] Fold 1, Train Loss: 0.0085, Val Loss: 0.0119
# Epoch [545/2000] Fold 1, Train Loss: 0.0085, Val Loss: 0.0120
# Epoch [546/2000] Fold 1, Train Loss: 0.0085, Val Loss: 0.0121
# Epoch [547/2000] Fold 1, Train Loss: 0.0085, Val Loss: 0.0120
# Epoch [548/2000] Fold 1, Train Loss: 0.0086, Val Loss: 0.0122
# Epoch [549/2000] Fold 1, Train Loss: 0.0086, Val Loss: 0.0119
# Epoch [550/2000] Fold 1, Train Loss: 0.0084, Val Loss: 0.0119
# Epoch [551/2000] Fold 1, Train Loss: 0.0084, Val Loss: 0.0118
# Epoch [552/2000] Fold 1, Train Loss: 0.0084, Val Loss: 0.0119
# Epoch [553/2000] Fold 1, Train Loss: 0.0084, Val Loss: 0.0118
# Epoch [554/2000] Fold 1, Train Loss: 0.0084, Val Loss: 0.0118
# Epoch [555/2000] Fold 1, Train Loss: 0.0084, Val Loss: 0.0119
# Epoch [556/2000] Fold 1, Train Loss: 0.0084, Val Loss: 0.0119
# Epoch [557/2000] Fold 1, Train Loss: 0.0084, Val Loss: 0.0120
# Epoch [558/2000] Fold 1, Train Loss: 0.0084, Val Loss: 0.0118
# Epoch [559/2000] Fold 1, Train Loss: 0.0083, Val Loss: 0.0118
# Epoch [560/2000] Fold 1, Train Loss: 0.0083, Val Loss: 0.0119
# Epoch [561/2000] Fold 1, Train Loss: 0.0083, Val Loss: 0.0119
# Epoch [562/2000] Fold 1, Train Loss: 0.0083, Val Loss: 0.0117
# Epoch [563/2000] Fold 1, Train Loss: 0.0083, Val Loss: 0.0119
# Epoch [564/2000] Fold 1, Train Loss: 0.0083, Val Loss: 0.0118
# Epoch [565/2000] Fold 1, Train Loss: 0.0084, Val Loss: 0.0118
# Epoch [566/2000] Fold 1, Train Loss: 0.0083, Val Loss: 0.0119
# Epoch [567/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0118
# Epoch [568/2000] Fold 1, Train Loss: 0.0083, Val Loss: 0.0118
# Epoch [569/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0118
# Epoch [570/2000] Fold 1, Train Loss: 0.0083, Val Loss: 0.0118
# Epoch [571/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0118
# Epoch [572/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0118
# Epoch [573/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0119
# Epoch [574/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0117
# Epoch [575/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0118
# Epoch [576/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0117
# Epoch [577/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0118
# Epoch [578/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0117
# Epoch [579/2000] Fold 1, Train Loss: 0.0083, Val Loss: 0.0118
# Epoch [580/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0118
# Epoch [581/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0119
# Epoch [582/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0119
# Epoch [583/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0117
# Epoch [584/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0118
# Epoch [585/2000] Fold 1, Train Loss: 0.0082, Val Loss: 0.0117
# Epoch [586/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0117
# Epoch [587/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0118
# Epoch [588/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0118
# Epoch [589/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0117
# Epoch [590/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0118
# Epoch [591/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0119
# Epoch [592/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0117
# Epoch [593/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0117
# Epoch [594/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0117
# Epoch [595/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0118
# Epoch [596/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0117
# Epoch [597/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0118
# Epoch [598/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0117
# Epoch [599/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0117
# Epoch [600/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0121
# Epoch [601/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0117
# Epoch [602/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0117
# Epoch [603/2000] Fold 1, Train Loss: 0.0079, Val Loss: 0.0117
# Epoch [604/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0117
# Epoch [605/2000] Fold 1, Train Loss: 0.0079, Val Loss: 0.0116
# Epoch [606/2000] Fold 1, Train Loss: 0.0079, Val Loss: 0.0117
# Epoch [607/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0117
# Epoch [608/2000] Fold 1, Train Loss: 0.0081, Val Loss: 0.0118
# Epoch [609/2000] Fold 1, Train Loss: 0.0079, Val Loss: 0.0117
# Epoch [610/2000] Fold 1, Train Loss: 0.0079, Val Loss: 0.0116
# Epoch [611/2000] Fold 1, Train Loss: 0.0079, Val Loss: 0.0117
# Epoch [612/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0118
# Epoch [613/2000] Fold 1, Train Loss: 0.0080, Val Loss: 0.0116
# Epoch [614/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0116
# Epoch [615/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0117
# Epoch [616/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0116
# Epoch [617/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0116
# Epoch [618/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0116
# Epoch [619/2000] Fold 1, Train Loss: 0.0079, Val Loss: 0.0116
# Epoch [620/2000] Fold 1, Train Loss: 0.0079, Val Loss: 0.0116
# Epoch [621/2000] Fold 1, Train Loss: 0.0079, Val Loss: 0.0117
# Epoch [622/2000] Fold 1, Train Loss: 0.0079, Val Loss: 0.0116
# Epoch [623/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0116
# Epoch [624/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0118
# Epoch [625/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0117
# Epoch [626/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0117
# Epoch [627/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0120
# Epoch [628/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0116
# Epoch [629/2000] Fold 1, Train Loss: 0.0077, Val Loss: 0.0117
# Epoch [630/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0116
# Epoch [631/2000] Fold 1, Train Loss: 0.0077, Val Loss: 0.0116
# Epoch [632/2000] Fold 1, Train Loss: 0.0077, Val Loss: 0.0116
# Epoch [633/2000] Fold 1, Train Loss: 0.0077, Val Loss: 0.0116
# Epoch [634/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0117
# Epoch [635/2000] Fold 1, Train Loss: 0.0078, Val Loss: 0.0116
# Epoch [636/2000] Fold 1, Train Loss: 0.0077, Val Loss: 0.0116
# Epoch [637/2000] Fold 1, Train Loss: 0.0077, Val Loss: 0.0116
# Epoch [638/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0116
# Epoch [639/2000] Fold 1, Train Loss: 0.0077, Val Loss: 0.0116
# Epoch [640/2000] Fold 1, Train Loss: 0.0077, Val Loss: 0.0116
# Epoch [641/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0115
# Epoch [642/2000] Fold 1, Train Loss: 0.0077, Val Loss: 0.0116
# Epoch [643/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0116
# Epoch [644/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0116
# Epoch [645/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0117
# Epoch [646/2000] Fold 1, Train Loss: 0.0077, Val Loss: 0.0116
# Epoch [647/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0116
# Epoch [648/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0116
# Epoch [649/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0116
# Epoch [650/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0117
# Epoch [651/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0116
# Epoch [652/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0116
# Epoch [653/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0117
# Epoch [654/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0116
# Epoch [655/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0116
# Epoch [656/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0116
# Epoch [657/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0115
# Epoch [658/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0116
# Epoch [659/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0115
# Epoch [660/2000] Fold 1, Train Loss: 0.0076, Val Loss: 0.0117
# Epoch [661/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0116
# Epoch [662/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0115
# Epoch [663/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0115
# Epoch [664/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0115
# Epoch [665/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0116
# Epoch [666/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0115
# Epoch [667/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0115
# Epoch [668/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0114
# Epoch [669/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0116
# Epoch [670/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0115
# Epoch [671/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0115
# Epoch [672/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0115
# Epoch [673/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0115
# Epoch [674/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0116
# Epoch [675/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0115
# Epoch [676/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0114
# Epoch [677/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0115
# Epoch [678/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0115
# Epoch [679/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0116
# Epoch [680/2000] Fold 1, Train Loss: 0.0075, Val Loss: 0.0114
# Epoch [681/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0116
# Epoch [682/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0115
# Epoch [683/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0115
# Epoch [684/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0118
# Epoch [685/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0116
# Epoch [686/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0116
# Epoch [687/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0115
# Epoch [688/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0115
# Epoch [689/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0115
# Epoch [690/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0115
# Epoch [691/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0116
# Epoch [692/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0116
# Epoch [693/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0115
# Epoch [694/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0116
# Epoch [695/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0115
# Epoch [696/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0117
# Epoch [697/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0114
# Epoch [698/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0114
# Epoch [699/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0115
# Epoch [700/2000] Fold 1, Train Loss: 0.0074, Val Loss: 0.0118
# Epoch [701/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0115
# Epoch [702/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0115
# Epoch [703/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0116
# Epoch [704/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0115
# Epoch [705/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0116
# Epoch [706/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0114
# Epoch [707/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0116
# Epoch [708/2000] Fold 1, Train Loss: 0.0073, Val Loss: 0.0114
# Epoch [709/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0114
# Epoch [710/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0114
# Epoch [711/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0115
# Epoch [712/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0115
# Epoch [713/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0116
# Epoch [714/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0116
# Epoch [715/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0115
# Epoch [716/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0114
# Epoch [717/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0114
# Epoch [718/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0115
# Epoch [719/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0114
# Epoch [720/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0115
# Epoch [721/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0114
# Epoch [722/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0114
# Epoch [723/2000] Fold 1, Train Loss: 0.0070, Val Loss: 0.0114
# Epoch [724/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0114
# Epoch [725/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0115
# Epoch [726/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0116
# Epoch [727/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0116
# Epoch [728/2000] Fold 1, Train Loss: 0.0072, Val Loss: 0.0115
# Epoch [729/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0114
# Epoch [730/2000] Fold 1, Train Loss: 0.0070, Val Loss: 0.0115
# Epoch [731/2000] Fold 1, Train Loss: 0.0070, Val Loss: 0.0114
# Epoch [732/2000] Fold 1, Train Loss: 0.0070, Val Loss: 0.0114
# Epoch [733/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0114
# Epoch [734/2000] Fold 1, Train Loss: 0.0070, Val Loss: 0.0115
# Epoch [735/2000] Fold 1, Train Loss: 0.0071, Val Loss: 0.0114
# Epoch [736/2000] Fold 1, Train Loss: 0.0070, Val Loss: 0.0113
# Epoch [737/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0113
# Epoch [738/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0115
# Epoch [739/2000] Fold 1, Train Loss: 0.0070, Val Loss: 0.0113
# Epoch [740/2000] Fold 1, Train Loss: 0.0070, Val Loss: 0.0115
# Epoch [741/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [742/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [743/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [744/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [745/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [746/2000] Fold 1, Train Loss: 0.0070, Val Loss: 0.0116
# Epoch [747/2000] Fold 1, Train Loss: 0.0070, Val Loss: 0.0114
# Epoch [748/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0113
# Epoch [749/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [750/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0115
# Epoch [751/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0117
# Epoch [752/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [753/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [754/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [755/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0113
# Epoch [756/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [757/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0115
# Epoch [758/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0113
# Epoch [759/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [760/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0113
# Epoch [761/2000] Fold 1, Train Loss: 0.0068, Val Loss: 0.0114
# Epoch [762/2000] Fold 1, Train Loss: 0.0068, Val Loss: 0.0114
# Epoch [763/2000] Fold 1, Train Loss: 0.0068, Val Loss: 0.0114
# Epoch [764/2000] Fold 1, Train Loss: 0.0068, Val Loss: 0.0115
# Epoch [765/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [766/2000] Fold 1, Train Loss: 0.0069, Val Loss: 0.0114
# Epoch [767/2000] Fold 1, Train Loss: 0.0068, Val Loss: 0.0114
# Epoch [768/2000] Fold 1, Train Loss: 0.0068, Val Loss: 0.0114
# Epoch [769/2000] Fold 1, Train Loss: 0.0068, Val Loss: 0.0115
# Epoch [770/2000] Fold 1, Train Loss: 0.0068, Val Loss: 0.0115
# Epoch [771/2000] Fold 1, Train Loss: 0.0068, Val Loss: 0.0114
# Epoch [772/2000] Fold 1, Train Loss: 0.0067, Val Loss: 0.0115
# Epoch [773/2000] Fold 1, Train Loss: 0.0067, Val Loss: 0.0114
# Epoch [774/2000] Fold 1, Train Loss: 0.0067, Val Loss: 0.0114
# Epoch [775/2000] Fold 1, Train Loss: 0.0067, Val Loss: 0.0114
# ...
# Epoch [1748/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1749/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0106
# Epoch [1750/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1751/2000] Fold 5, Train Loss: 0.0033, Val Loss: 0.0105
# Epoch [1752/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1753/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1754/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1755/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1756/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1757/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1758/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1759/2000] Fold 5, Train Loss: 0.0033, Val Loss: 0.0105
# Epoch [1760/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1761/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1762/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0107
# Epoch [1763/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0104
# Epoch [1764/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1765/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1766/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0104
# Epoch [1767/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0104
# Epoch [1768/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1769/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1770/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1771/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1772/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1773/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1774/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1775/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0104
# Epoch [1776/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1777/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1778/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0104
# Epoch [1779/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0104
# Epoch [1780/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1781/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1782/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1783/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1784/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0104
# Epoch [1785/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1786/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1787/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1788/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1789/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1790/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1791/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0104
# Epoch [1792/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0104
# Epoch [1793/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1794/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1795/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1796/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1797/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1798/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0104
# Epoch [1799/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1800/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1801/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1802/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1803/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1804/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1805/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1806/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1807/2000] Fold 5, Train Loss: 0.0032, Val Loss: 0.0105
# Epoch [1808/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1809/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1810/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1811/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1812/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1813/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1814/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1815/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1816/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1817/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1818/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1819/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1820/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1821/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1822/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1823/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1824/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1825/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1826/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1827/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1828/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1829/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1830/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1831/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1832/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1833/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1834/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1835/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1836/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1837/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1838/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1839/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1840/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1841/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0105
# Epoch [1842/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1843/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1844/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1845/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1846/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1847/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1848/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1849/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1850/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1851/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1852/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1853/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1854/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1855/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1856/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1857/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1858/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1859/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1860/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1861/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0103
# Epoch [1862/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0105
# Epoch [1863/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1864/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0102
# Epoch [1865/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1866/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1867/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1868/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1869/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1870/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1871/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1872/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1873/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1874/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1875/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1876/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1877/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1878/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1879/2000] Fold 5, Train Loss: 0.0031, Val Loss: 0.0104
# Epoch [1880/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1881/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1882/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1883/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1884/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1885/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0102
# Epoch [1886/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1887/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1888/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1889/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1890/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1891/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1892/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1893/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0102
# Epoch [1894/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1895/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1896/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1897/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1898/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0104
# Epoch [1899/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1900/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1901/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0102
# Epoch [1902/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0104
# Epoch [1903/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0102
# Epoch [1904/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1905/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1906/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1907/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1908/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1909/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1910/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1911/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0102
# Epoch [1912/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1913/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0102
# Epoch [1914/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1915/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1916/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1917/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1918/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1919/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1920/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1921/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1922/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1923/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1924/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0102
# Epoch [1925/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0102
# Epoch [1926/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1927/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1928/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0101
# Epoch [1929/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1930/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1931/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1932/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1933/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1934/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1935/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0102
# Epoch [1936/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1937/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1938/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1939/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0102
# Epoch [1940/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1941/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1942/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0104
# Epoch [1943/2000] Fold 5, Train Loss: 0.0030, Val Loss: 0.0103
# Epoch [1944/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1945/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1946/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1947/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1948/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1949/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1950/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0101
# Epoch [1951/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1952/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1953/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1954/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1955/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1956/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1957/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1958/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1959/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1960/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1961/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1962/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0101
# Epoch [1963/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0101
# Epoch [1964/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1965/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1966/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0102
# Epoch [1967/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0101
# Epoch [1968/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0103
# Epoch [1969/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0101
# Epoch [1970/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1971/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1972/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1973/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1974/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0102
# Epoch [1975/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0102
# Epoch [1976/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0102
# Epoch [1977/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1978/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1979/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1980/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1981/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1982/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0102
# Epoch [1983/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0102
# Epoch [1984/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1985/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1986/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1987/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1988/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1989/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0103
# Epoch [1990/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0101
# Epoch [1991/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0101
# Epoch [1992/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1993/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0102
# Epoch [1994/2000] Fold 5, Train Loss: 0.0029, Val Loss: 0.0101
# Epoch [1995/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0102
# Epoch [1996/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0101
# Epoch [1997/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0102
# Epoch [1998/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0101
# Epoch [1999/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0102
# Epoch [2000/2000] Fold 5, Train Loss: 0.0028, Val Loss: 0.0102

# %% [markdown]
# # delta = 0

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.0104

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.0108
#   Corresponding Training Loss = 0.0033
#   Best Epoch = 1981
# Fold 2:
#   Best Validation Loss = 0.0086
#   Corresponding Training Loss = 0.0037
#   Best Epoch = 1946
# Fold 3:
#   Best Validation Loss = 0.0109
#   Corresponding Training Loss = 0.0048
#   Best Epoch = 1364
# Fold 4:
#   Best Validation Loss = 0.0108
#   Corresponding Training Loss = 0.0061
#   Best Epoch = 1047
# Fold 5:
#   Best Validation Loss = 0.0101
#   Corresponding Training Loss = 0.0028
#   Best Epoch = 1998

# %%
import matplotlib.pyplot as plt
plot_loss_curves_separately(cv_histories)

# %%
import os

# Define the directory where models will be saved (current folder)
save_dir = "."  # Current directory
os.makedirs(save_dir, exist_ok=True)  # Create the directory if it doesn't exist (optional for ".")

# Save each fold's best model to the directory
for i, model_state in enumerate(best_models):
    save_path = os.path.join(save_dir, f'best_model_fold_{i+1}.pth')
    torch.save(model_state, save_path)

print(f"Models saved to the current directory: {save_dir}")
# Out:
# Models saved to the current directory: .

# %% [markdown]
# # inference

# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import pandas as pd

# %%
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

class FeaturePredictor(nn.Module):
    def __init__(self, input_size=512, output_size=512):
        super(FeaturePredictor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16,8),
            nn.ReLU(),
            nn.Linear(8, 16),
            nn.ReLU(),
            nn.Linear(16,32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128,256),
            nn.ReLU(),
            nn.Linear(256, output_size)
        )
    
    def forward(self, x):
        return self.model(x)

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch

# Define the path to the specific model file
model_path = './best_model_fold_2.pth'

# Load the saved model state dictionary
model_state = torch.load(model_path)

# Initialize the model and load the state dictionary
model = FeaturePredictor()  # Replace with your model class
model.load_state_dict(model_state)
model.to(device)
model.eval()

print("Model loaded successfully.")
# Out:
# Model loaded successfully.
# C:\Users\k54739\AppData\Local\Temp\ipykernel_23688\2288314956.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_state = torch.load(model_path)

# %%
# Load the CSV file
df = pd.read_csv("ds_closeto_sd_feats.csv")

# Extract paths, labels, and features
loaded_paths = df["path"].tolist()
loaded_features = torch.tensor(df["features"].apply(eval).to_list(), dtype=torch.float32)
print(df.head())
print(f"Loaded features shape: {loaded_features.shape}")
print(f"Loaded paths: {len(loaded_paths)}")
# Out:
#                                                 path  \
# 0  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
# 1  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
# 2  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
# 3  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
# 4  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
#
#                                             features
# 0  [0.8232919573783875, 0.7611361742019653, 0.0, ...
# 1  [2.0017168521881104, 0.0, 1.587598443031311, 2...
# 2  [2.4450366497039795, 0.31418296694755554, 1.47...
# 3  [2.543513059616089, 0.0, 2.05625581741333, 3.0...
# 4  [0.015524574555456638, 0.0, 0.6714532971382141...
# Loaded features shape: torch.Size([22, 512])
# Loaded paths: 22

# %% [markdown]
# # Load the CSV file
# df = pd.read_csv("combined_features.csv")
#
# # Extract paths, labels, and features
# loaded_paths = df["path"].tolist()
# loaded_labels = df["label"].tolist()
# loaded_features = torch.tensor(df["features"].apply(eval).to_list(), dtype=torch.float32)
# feats = loaded_features
# print(df.head())
# print(f"Loaded features shape: {loaded_features.shape}")
# print(f"Loaded paths: {len(loaded_paths)}")
# print(f"Loaded labels: {len(loaded_labels)}")

# %% [markdown]
# # Min-Max scaling
# features_min = feats.min(dim=0, keepdim=True).values  # Minimum value per feature
# features_max = feats.max(dim=0, keepdim=True).values  # Maximum value per feature
#
# normalized_feats = (feats - features_min) / (features_max - features_min)
# print(normalized_feats.shape)

# %% [markdown]
# # Save features_min and features_max
# torch.save(features_min, "train_min.pth")
# torch.save(features_max, "train_max.pth")
#
# print("Features min and max saved successfully.")

# %%
# Load features_min and features_max
loaded_features_min = torch.load("train_min.pth")
loaded_features_max = torch.load("train_max.pth")
print(loaded_features_min.shape)
print(loaded_features_max.shape)


print("Features min and max loaded successfully.")
# Out:
# torch.Size([1, 512])
# torch.Size([1, 512])
# Features min and max loaded successfully.
# C:\Users\k54739\AppData\Local\Temp\ipykernel_23688\3524933051.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_features_min = torch.load("train_min.pth")
# C:\Users\k54739\AppData\Local\Temp\ipykernel_23688\3524933051.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_features_max = torch.load("train_max.pth")

# %%
normalized_feats = (loaded_features - loaded_features_min) / (loaded_features_max - loaded_features_min)
print(normalized_feats.shape)
# Out:
# torch.Size([22, 512])

# %%
# Assuming normalized_feats is a tensor of shape [num_samples, num_features]
inference_dataset = TensorDataset(normalized_feats)
inference_loader = DataLoader(inference_dataset, batch_size=32, shuffle=False)

# %%
# Define a prefix for the group of images (e.g., "original" or "augmented")
prefix = "ds_closeto_sd"  # Change this for different groups, e.g., "augmented", "group1"

# Perform inference
mse_errors = []
euclidean_distances = []
cosine_distances = []

# Use the same criterion as during training
criterion = nn.MSELoss(reduction='none')  # Use 'none' to calculate loss per sample

with torch.no_grad():
    for batch_feats in inference_loader:
        # Extract features
        batch_feats = batch_feats[0].to(device)
        outputs = model(batch_feats)

        # Calculate MSE loss for each feature vector
        batch_mse = criterion(outputs, batch_feats).mean(dim=1)  # MSE per sample
        mse_errors.extend(batch_mse.cpu().numpy())

        # Calculate Euclidean distance for each feature vector
        batch_euclidean = torch.norm(outputs - batch_feats, p=2, dim=1)  # L2 norm
        euclidean_distances.extend(batch_euclidean.cpu().numpy())

        # Calculate Cosine distance for each feature vector
        batch_cosine_similarity = torch.nn.functional.cosine_similarity(outputs, batch_feats, dim=1)
        batch_cosine_distance = 1 - batch_cosine_similarity  # Cosine distance = 1 - Cosine similarity
        cosine_distances.extend(batch_cosine_distance.cpu().numpy())

# Convert results to numpy arrays for further analysis
mse_errors = np.array(mse_errors)
euclidean_distances = np.array(euclidean_distances)
cosine_distances = np.array(cosine_distances)

# Save the results with the prefix
np.save(f"{prefix}_mse_errors.npy", mse_errors)
np.save(f"{prefix}_euclidean_distances.npy", euclidean_distances)
np.save(f"{prefix}_cosine_distances.npy", cosine_distances)

print(f"Errors and distances for group '{prefix}' saved successfully.")
# Out:
# Errors and distances for group 'ds_closeto_sd' saved successfully.

# %%
prefix = "cond7"  # Replace with your specific prefix

# Load the saved metrics
cond7_mse_errors = np.load(f"{prefix}_mse_errors.npy")
cond7_euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cond7_cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_distributions_with_boxplot(sd_metrics, control_metrics, exd_metrics, ds_metrics, cond_metrics, metric_names, bins=20):
    """
    Plots the histogram and box-and-whisker plots for multiple metrics across multiple groups.

    Args:
        sd_metrics (dict): Dictionary of metrics for the SD group. Keys are metric names, values are arrays.
        control_metrics (dict): Dictionary of metrics for the Control group. Keys are metric names, values are arrays.
        exd_metrics (dict): Dictionary of metrics for the EXD group. Keys are metric names, values are arrays.
        ds_metrics (dict): Dictionary of metrics for the Ds Close to SD group. Keys are metric names, values are arrays.
        cond_metrics (dict): Dictionary of metrics for the Cond10 group. Keys are metric names, values are arrays.
        metric_names (list): Names of the metrics to plot (e.g., ["Reconstruction Error", "Cosine Distance"]).
        bins (int): Number of bins for the histogram.
    """
    for metric_name in metric_names:
        # Extract metrics for all groups
        sd_values = sd_metrics[metric_name]
        control_values = control_metrics[metric_name]
        exd_values = exd_metrics[metric_name]
        ds_values = ds_metrics[metric_name]
        cond_values = cond_metrics[metric_name]

        # Create figure with two subplots: Histogram (top) and Boxplot (bottom)
        fig, axes = plt.subplots(2, 1, figsize=(14, 12), gridspec_kw={'height_ratios': [3, 1]})

        # Histogram
        axes[0].hist(sd_values, bins=bins, alpha=0.6, label="SD Group", color="orange", edgecolor="black")
        axes[0].hist(control_values, bins=bins, alpha=0.6, label="Control Group", color="blue", edgecolor="black")
        axes[0].hist(exd_values, bins=bins, alpha=0.6, label="EXD Group", color="green", edgecolor="black")
        axes[0].hist(ds_values, bins=bins, alpha=0.6, label="Ds Close to SD Group", color="red", edgecolor="black")
        axes[0].hist(cond_values, bins=bins, alpha=0.6, label="Cond10 Group", color="purple", edgecolor="black")

        # Add mean lines to the histogram
        axes[0].axvline(np.mean(sd_values), color='orange', linestyle='-', label=f"SD Mean: {np.mean(sd_values):.4f}")
        axes[0].axvline(np.mean(control_values), color='blue', linestyle='-', label=f"Control Mean: {np.mean(control_values):.4f}")
        axes[0].axvline(np.mean(exd_values), color='green', linestyle='-', label=f"EXD Mean: {np.mean(exd_values):.4f}")
        axes[0].axvline(np.mean(ds_values), color='red', linestyle='-', label=f"Ds Mean: {np.mean(ds_values):.4f}")
        axes[0].axvline(np.mean(cond_values), color='purple', linestyle='-', label=f"Cond10 Mean: {np.mean(cond_values):.4f}")

        # Add title and legend to the histogram
        axes[0].set_title(f"{metric_name} Distribution", fontsize=16)
        axes[0].set_xlabel(metric_name, fontsize=14)
        axes[0].set_ylabel("Frequency", fontsize=14)
        axes[0].legend(fontsize=10)
        axes[0].grid(alpha=0.3)

        # Box-and-whisker plot
        data = [sd_values, control_values, exd_values, ds_values, cond_values]
        labels = ["SD Group", "Control Group", "EXD Group", "Ds Close to SD Group", "Cond10 Group"]
        axes[1].boxplot(data, labels=labels, patch_artist=True, 
                        boxprops=dict(facecolor="lightgrey", color="black"),
                        medianprops=dict(color="black"), whiskerprops=dict(color="black"))

        # Add title and labels to the boxplot
        axes[1].set_title(f"{metric_name} Box-and-Whisker Plot", fontsize=16)
        axes[1].set_ylabel(metric_name, fontsize=14)

        # Adjust layout and show the plot
        plt.tight_layout()
        plt.show()

# Example Usage
if __name__ == "__main__":
    # Load the metrics for SD and Control groups
    sd_metrics = {
        "Reconstruction Error": np.load("sd_mse_errors.npy"),
        "Cosine Distance": np.load("sd_cosine_distances.npy"),
        "Euclidean Distance": np.load("sd_euclidean_distances.npy")
    }

    control_metrics = {
        "Reconstruction Error": np.load("cond7_mse_errors.npy"),
        "Cosine Distance": np.load("cond7_cosine_distances.npy"),
        "Euclidean Distance": np.load("cond7_euclidean_distances.npy")
    }

    # Load the metrics for EXD and Ds Close to SD groups
    exd_metrics = {
        "Reconstruction Error": np.load("ex_mse_errors.npy"),
        "Cosine Distance": np.load("ex_cosine_distances.npy"),
        "Euclidean Distance": np.load("ex_euclidean_distances.npy")
    }

    ds_metrics = {
        "Reconstruction Error": np.load("ds_closeto_sd_mse_errors.npy"),
        "Cosine Distance": np.load("ds_closeto_sd_cosine_distances.npy"),
        "Euclidean Distance": np.load("ds_closeto_sd_euclidean_distances.npy")
    }

    # Load the metrics for Cond10 group
    cond_metrics = {
        "Reconstruction Error": np.load("cond10_mse_errors.npy"),
        "Cosine Distance": np.load("cond10_cosine_distances.npy"),
        "Euclidean Distance": np.load("cond10_euclidean_distances.npy")
    }

    # Define the metric names
    metric_names = ["Reconstruction Error", "Cosine Distance", "Euclidean Distance"]

    # Plot distributions with boxplots
    plot_distributions_with_boxplot(sd_metrics, control_metrics, exd_metrics, ds_metrics, cond_metrics, metric_names)
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_22764\3134692173.py:52: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=labels, patch_artist=True,
# C:\Users\k54739\AppData\Local\Temp\ipykernel_22764\3134692173.py:52: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=labels, patch_artist=True,
# C:\Users\k54739\AppData\Local\Temp\ipykernel_22764\3134692173.py:52: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=labels, patch_artist=True,

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the saved metrics
prefix = "ds_closeto_sd"  # Adjust to the prefix you used
mse_errors = np.load(f"{prefix}_mse_errors.npy")
euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# Plot MSE Errors
plt.figure(figsize=(10, 6))
plt.hist(mse_errors, bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.title(f"{prefix} - MSE Errors", fontsize=16)
plt.xlabel("MSE Error", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Euclidean Distances
plt.figure(figsize=(10, 6))
plt.hist(euclidean_distances, bins=30, alpha=0.7, color='green', edgecolor='black')
plt.title(f"{prefix} - Euclidean Distances", fontsize=16)
plt.xlabel("Euclidean Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Cosine Distances
plt.figure(figsize=(10, 6))
plt.hist(cosine_distances, bins=30, alpha=0.7, color='red', edgecolor='black')
plt.title(f"{prefix} - Cosine Distances", fontsize=16)
plt.xlabel("Cosine Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the saved metrics
prefix = "ex"  # Adjust to the prefix you used
mse_errors = np.load(f"{prefix}_mse_errors.npy")
euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# Plot MSE Errors
plt.figure(figsize=(10, 6))
plt.hist(mse_errors, bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.title(f"{prefix} - MSE Errors", fontsize=16)
plt.xlabel("MSE Error", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Euclidean Distances
plt.figure(figsize=(10, 6))
plt.hist(euclidean_distances, bins=30, alpha=0.7, color='green', edgecolor='black')
plt.title(f"{prefix} - Euclidean Distances", fontsize=16)
plt.xlabel("Euclidean Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Cosine Distances
plt.figure(figsize=(10, 6))
plt.hist(cosine_distances, bins=30, alpha=0.7, color='red', edgecolor='black')
plt.title(f"{prefix} - Cosine Distances", fontsize=16)
plt.xlabel("Cosine Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the saved metrics
prefix = "sd"  # Adjust to the prefix you used
mse_errors = np.load(f"{prefix}_mse_errors.npy")
euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# Plot MSE Errors
plt.figure(figsize=(10, 6))
plt.hist(mse_errors, bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.title(f"{prefix} - MSE Errors", fontsize=16)
plt.xlabel("MSE Error", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Euclidean Distances
plt.figure(figsize=(10, 6))
plt.hist(euclidean_distances, bins=30, alpha=0.7, color='green', edgecolor='black')
plt.title(f"{prefix} - Euclidean Distances", fontsize=16)
plt.xlabel("Euclidean Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Cosine Distances
plt.figure(figsize=(10, 6))
plt.hist(cosine_distances, bins=30, alpha=0.7, color='red', edgecolor='black')
plt.title(f"{prefix} - Cosine Distances", fontsize=16)
plt.xlabel("Cosine Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the saved metrics
prefix = "cond10"  # Adjust to the prefix you used
mse_errors = np.load(f"{prefix}_mse_errors.npy")
euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# Plot MSE Errors
plt.figure(figsize=(10, 6))
plt.hist(mse_errors, bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.title(f"{prefix} - MSE Errors", fontsize=16)
plt.xlabel("MSE Error", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Euclidean Distances
plt.figure(figsize=(10, 6))
plt.hist(euclidean_distances, bins=30, alpha=0.7, color='green', edgecolor='black')
plt.title(f"{prefix} - Euclidean Distances", fontsize=16)
plt.xlabel("Euclidean Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Cosine Distances
plt.figure(figsize=(10, 6))
plt.hist(cosine_distances, bins=30, alpha=0.7, color='red', edgecolor='black')
plt.title(f"{prefix} - Cosine Distances", fontsize=16)
plt.xlabel("Cosine Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the saved metrics
prefix = "cond7"  # Adjust to the prefix you used
mse_errors = np.load(f"{prefix}_mse_errors.npy")
euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# Plot MSE Errors
plt.figure(figsize=(10, 6))
plt.hist(mse_errors, bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.title(f"{prefix} - MSE Errors", fontsize=16)
plt.xlabel("MSE Error", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Euclidean Distances
plt.figure(figsize=(10, 6))
plt.hist(euclidean_distances, bins=30, alpha=0.7, color='green', edgecolor='black')
plt.title(f"{prefix} - Euclidean Distances", fontsize=16)
plt.xlabel("Euclidean Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Cosine Distances
plt.figure(figsize=(10, 6))
plt.hist(cosine_distances, bins=30, alpha=0.7, color='red', edgecolor='black')
plt.title(f"{prefix} - Cosine Distances", fontsize=16)
plt.xlabel("Cosine Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()
