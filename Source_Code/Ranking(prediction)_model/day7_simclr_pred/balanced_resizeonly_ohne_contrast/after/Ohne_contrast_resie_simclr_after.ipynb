# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import pandas as pd

# %%
# Load the CSV file
df = pd.read_csv("cond7_combined_features.csv")

# Extract paths, labels, and features
loaded_paths = df["path"].tolist()
loaded_labels = df["label"].tolist()
loaded_features = torch.tensor(df["features"].apply(eval).to_list(), dtype=torch.float32)
feats = loaded_features
print(df.head())
print(f"Loaded features shape: {loaded_features.shape}")
print(f"Loaded paths: {len(loaded_paths)}")
print(f"Loaded labels: {len(loaded_labels)}")
# Out:
#                                                 path label  \
# 0  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
# 1  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
# 2  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
# 3  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
# 4  C:\Users\k54739\Bibi_new_thesis\thesis\day7tod...  orig
#
#                                             features
# 0  [-0.6405425667762756, -0.8287757635116577, -0....
# 1  [0.7662427425384521, -1.0618577003479004, -0.1...
# 2  [0.6320910453796387, -0.1435827612876892, 0.58...
# 3  [-0.2813078463077545, 0.8500182628631592, 1.28...
# 4  [0.9887382984161377, 0.08325622230768204, 0.99...
# Loaded features shape: torch.Size([944, 20])
# Loaded paths: 944
# Loaded labels: 944

# %%
import matplotlib.pyplot as plt

# Flatten the features for plotting (if needed)
flattened_features = feats.flatten().numpy()

# Plot the histogram of feature values
plt.figure(figsize=(10, 6))
plt.hist(flattened_features, bins=50, alpha=0.7, color='blue', edgecolor='black')
plt.title("Feature Value Distribution")
plt.xlabel("Feature Value")
plt.ylabel("Frequency")
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# # plot z score normalised

# %%
features_mean = feats.mean(dim=0, keepdim=True)
features_std = feats.std(dim=0, keepdim=True)

normalized_feats = (feats - features_mean) / features_std

# Check the new distribution
flattened_normalized_features = normalized_feats.flatten().numpy()

# Plot the normalized distribution
plt.figure(figsize=(10, 6))
plt.hist(flattened_normalized_features, bins=50, alpha=0.7, color='green', edgecolor='black')
plt.title("Normalized Feature Value Distribution (Standardized)")
plt.xlabel("Feature Value")
plt.ylabel("Frequency")
plt.grid(alpha=0.3)
plt.show()

# %%
from torch.utils.data import TensorDataset
dataset = TensorDataset(normalized_feats)
len(dataset)
# Out:
# 944

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch.nn as nn

class FeaturePredictor(nn.Module):
    def __init__(self, input_size=20, output_size=20):
        super(FeaturePredictor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 16),
            nn.ReLU(),
            nn.Linear(16, 8),
            nn.ReLU(),
            nn.Linear(8, 4),
            nn.ReLU(),
            nn.Linear(4, 8),
            nn.ReLU(),
            nn.Linear(8, 16),
            nn.ReLU(),
            nn.Linear(16,output_size)
        )
    
    def forward(self, x):
        return self.model(x)

# %%
model = FeaturePredictor()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
optimizer_class = torch.optim.Adam

from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, Subset
import numpy as np
import torch

# %%
class EarlyStopping:
    def __init__(self, patience=10, delta=0.0):
        """
        Args:
            patience (int): How many epochs to wait after the last validation loss improvement.
            delta (float): Minimum change in the validation loss to qualify as an improvement.
        """
        self.patience = patience
        self.delta = delta
        self.best_loss = None
        self.no_improvement_epochs = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.no_improvement_epochs = 0
        else:
            self.no_improvement_epochs += 1
            if self.no_improvement_epochs >= self.patience:
                self.early_stop = True


def cross_validate_with_early_stopping(
    model_class, dataset, criterion, optimizer_class, num_epochs=50, n_splits=5, patience=10, delta=0.0, device='cuda'
):
    """
    Cross-validation with early stopping.

    Args:
        model_class: The model class to initialize.
        dataset: The dataset to perform cross-validation on.
        criterion: Loss function.
        optimizer_class: Optimizer class to use.
        num_epochs: Maximum number of epochs for training.
        n_splits: Number of cross-validation splits.
        patience: Number of epochs to wait for validation loss improvement.
        delta: Minimum change in validation loss to consider as improvement.
        device: Device to run the model on ('cuda' or 'cpu').

    Returns:
        histories: A list of training/validation loss histories for each fold.
        best_models: A list of best model states for each fold.
    """
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    histories = []
    best_models = []

    for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset)):
        print(f"Fold {fold + 1}/{n_splits}")

        # Create subsets for this fold
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        # Create DataLoaders
        train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

        # Initialize the model, optimizer, and early stopping for this fold
        model = model_class().to(device)
        optimizer = optimizer_class(model.parameters(), lr=1e-4)
        early_stopping = EarlyStopping(patience=patience, delta=delta)  # Pass delta here

        # Training and validation loop
        history = {'train_loss': [], 'val_loss': []}
        for epoch in range(num_epochs):
            # Training phase
            model.train()
            train_loss = 0.0
            for batch_feats in train_loader:
                batch_feats = batch_feats[0].to(device)

                # Forward pass
                outputs = model(batch_feats)
                loss = criterion(outputs, batch_feats)
                train_loss += loss.item()

                # Backward pass and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            train_loss /= len(train_loader)
            history['train_loss'].append(train_loss)

            # Validation phase
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for batch_feats in val_loader:
                    batch_feats = batch_feats[0].to(device)
                    outputs = model(batch_feats)
                    loss = criterion(outputs, batch_feats)
                    val_loss += loss.item()

            val_loss /= len(val_loader)
            history['val_loss'].append(val_loss)

            print(f"Epoch [{epoch + 1}/{num_epochs}] Fold {fold + 1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

            # Check early stopping
            early_stopping(val_loss)
            if early_stopping.early_stop:
                print(f"Early stopping at epoch {epoch + 1} for fold {fold + 1}")
                break

        # Save the best model for this fold
        best_models.append(model.state_dict())
        histories.append(history)

    return histories, best_models

# %%
cv_histories, best_models = cross_validate_with_early_stopping(
    model_class=FeaturePredictor,
    dataset=dataset,
    criterion=nn.MSELoss(),
    optimizer_class=torch.optim.Adam,
    num_epochs=4000,
    patience=500,
    delta=0.0000  # Example delta value
)
# Out:
# Fold 1/5
# Epoch [1/4000] Fold 1, Train Loss: 1.0383, Val Loss: 1.0132
# Epoch [2/4000] Fold 1, Train Loss: 1.0385, Val Loss: 1.0115
# Epoch [3/4000] Fold 1, Train Loss: 1.0344, Val Loss: 1.0099
# Epoch [4/4000] Fold 1, Train Loss: 1.0340, Val Loss: 1.0084
# Epoch [5/4000] Fold 1, Train Loss: 1.0309, Val Loss: 1.0071
# Epoch [6/4000] Fold 1, Train Loss: 1.0293, Val Loss: 1.0059
# Epoch [7/4000] Fold 1, Train Loss: 1.0254, Val Loss: 1.0048
# Epoch [8/4000] Fold 1, Train Loss: 1.0244, Val Loss: 1.0038
# Epoch [9/4000] Fold 1, Train Loss: 1.0269, Val Loss: 1.0028
# Epoch [10/4000] Fold 1, Train Loss: 1.0215, Val Loss: 1.0019
# Epoch [11/4000] Fold 1, Train Loss: 1.0224, Val Loss: 1.0011
# Epoch [12/4000] Fold 1, Train Loss: 1.0199, Val Loss: 1.0002
# Epoch [13/4000] Fold 1, Train Loss: 1.0185, Val Loss: 0.9995
# Epoch [14/4000] Fold 1, Train Loss: 1.0185, Val Loss: 0.9987
# Epoch [15/4000] Fold 1, Train Loss: 1.0160, Val Loss: 0.9980
# Epoch [16/4000] Fold 1, Train Loss: 1.0138, Val Loss: 0.9974
# Epoch [17/4000] Fold 1, Train Loss: 1.0154, Val Loss: 0.9968
# Epoch [18/4000] Fold 1, Train Loss: 1.0104, Val Loss: 0.9961
# Epoch [19/4000] Fold 1, Train Loss: 1.0140, Val Loss: 0.9954
# Epoch [20/4000] Fold 1, Train Loss: 1.0107, Val Loss: 0.9948
# Epoch [21/4000] Fold 1, Train Loss: 1.0107, Val Loss: 0.9941
# Epoch [22/4000] Fold 1, Train Loss: 1.0122, Val Loss: 0.9934
# Epoch [23/4000] Fold 1, Train Loss: 1.0096, Val Loss: 0.9927
# Epoch [24/4000] Fold 1, Train Loss: 1.0079, Val Loss: 0.9920
# Epoch [25/4000] Fold 1, Train Loss: 1.0064, Val Loss: 0.9912
# Epoch [26/4000] Fold 1, Train Loss: 1.0075, Val Loss: 0.9903
# Epoch [27/4000] Fold 1, Train Loss: 1.0075, Val Loss: 0.9895
# Epoch [28/4000] Fold 1, Train Loss: 1.0058, Val Loss: 0.9885
# Epoch [29/4000] Fold 1, Train Loss: 1.0058, Val Loss: 0.9875
# Epoch [30/4000] Fold 1, Train Loss: 1.0048, Val Loss: 0.9865
# Epoch [31/4000] Fold 1, Train Loss: 1.0010, Val Loss: 0.9854
# Epoch [32/4000] Fold 1, Train Loss: 0.9984, Val Loss: 0.9842
# Epoch [33/4000] Fold 1, Train Loss: 0.9980, Val Loss: 0.9825
# Epoch [34/4000] Fold 1, Train Loss: 0.9959, Val Loss: 0.9805
# Epoch [35/4000] Fold 1, Train Loss: 0.9953, Val Loss: 0.9783
# Epoch [36/4000] Fold 1, Train Loss: 0.9950, Val Loss: 0.9759
# Epoch [37/4000] Fold 1, Train Loss: 0.9902, Val Loss: 0.9732
# Epoch [38/4000] Fold 1, Train Loss: 0.9850, Val Loss: 0.9703
# Epoch [39/4000] Fold 1, Train Loss: 0.9851, Val Loss: 0.9673
# Epoch [40/4000] Fold 1, Train Loss: 0.9806, Val Loss: 0.9642
# Epoch [41/4000] Fold 1, Train Loss: 0.9796, Val Loss: 0.9609
# Epoch [42/4000] Fold 1, Train Loss: 0.9768, Val Loss: 0.9577
# Epoch [43/4000] Fold 1, Train Loss: 0.9741, Val Loss: 0.9544
# Epoch [44/4000] Fold 1, Train Loss: 0.9677, Val Loss: 0.9508
# Epoch [45/4000] Fold 1, Train Loss: 0.9660, Val Loss: 0.9475
# Epoch [46/4000] Fold 1, Train Loss: 0.9612, Val Loss: 0.9439
# Epoch [47/4000] Fold 1, Train Loss: 0.9593, Val Loss: 0.9404
# Epoch [48/4000] Fold 1, Train Loss: 0.9552, Val Loss: 0.9368
# Epoch [49/4000] Fold 1, Train Loss: 0.9530, Val Loss: 0.9332
# Epoch [50/4000] Fold 1, Train Loss: 0.9478, Val Loss: 0.9296
# Epoch [51/4000] Fold 1, Train Loss: 0.9449, Val Loss: 0.9261
# Epoch [52/4000] Fold 1, Train Loss: 0.9415, Val Loss: 0.9228
# Epoch [53/4000] Fold 1, Train Loss: 0.9382, Val Loss: 0.9196
# Epoch [54/4000] Fold 1, Train Loss: 0.9347, Val Loss: 0.9164
# Epoch [55/4000] Fold 1, Train Loss: 0.9317, Val Loss: 0.9135
# Epoch [56/4000] Fold 1, Train Loss: 0.9295, Val Loss: 0.9105
# Epoch [57/4000] Fold 1, Train Loss: 0.9258, Val Loss: 0.9078
# Epoch [58/4000] Fold 1, Train Loss: 0.9245, Val Loss: 0.9052
# Epoch [59/4000] Fold 1, Train Loss: 0.9183, Val Loss: 0.9027
# Epoch [60/4000] Fold 1, Train Loss: 0.9185, Val Loss: 0.9003
# Epoch [61/4000] Fold 1, Train Loss: 0.9150, Val Loss: 0.8980
# Epoch [62/4000] Fold 1, Train Loss: 0.9113, Val Loss: 0.8959
# Epoch [63/4000] Fold 1, Train Loss: 0.9105, Val Loss: 0.8939
# Epoch [64/4000] Fold 1, Train Loss: 0.9079, Val Loss: 0.8919
# Epoch [65/4000] Fold 1, Train Loss: 0.9062, Val Loss: 0.8901
# Epoch [66/4000] Fold 1, Train Loss: 0.9045, Val Loss: 0.8884
# Epoch [67/4000] Fold 1, Train Loss: 0.9014, Val Loss: 0.8867
# Epoch [68/4000] Fold 1, Train Loss: 0.8984, Val Loss: 0.8851
# Epoch [69/4000] Fold 1, Train Loss: 0.8983, Val Loss: 0.8836
# Epoch [70/4000] Fold 1, Train Loss: 0.8968, Val Loss: 0.8823
# Epoch [71/4000] Fold 1, Train Loss: 0.8964, Val Loss: 0.8808
# Epoch [72/4000] Fold 1, Train Loss: 0.8930, Val Loss: 0.8795
# Epoch [73/4000] Fold 1, Train Loss: 0.8898, Val Loss: 0.8782
# Epoch [74/4000] Fold 1, Train Loss: 0.8914, Val Loss: 0.8771
# Epoch [75/4000] Fold 1, Train Loss: 0.8855, Val Loss: 0.8758
# Epoch [76/4000] Fold 1, Train Loss: 0.8857, Val Loss: 0.8748
# Epoch [77/4000] Fold 1, Train Loss: 0.8865, Val Loss: 0.8738
# Epoch [78/4000] Fold 1, Train Loss: 0.8855, Val Loss: 0.8728
# Epoch [79/4000] Fold 1, Train Loss: 0.8807, Val Loss: 0.8718
# Epoch [80/4000] Fold 1, Train Loss: 0.8809, Val Loss: 0.8710
# Epoch [81/4000] Fold 1, Train Loss: 0.8795, Val Loss: 0.8701
# Epoch [82/4000] Fold 1, Train Loss: 0.8787, Val Loss: 0.8692
# Epoch [83/4000] Fold 1, Train Loss: 0.8777, Val Loss: 0.8684
# Epoch [84/4000] Fold 1, Train Loss: 0.8781, Val Loss: 0.8676
# Epoch [85/4000] Fold 1, Train Loss: 0.8727, Val Loss: 0.8669
# Epoch [86/4000] Fold 1, Train Loss: 0.8760, Val Loss: 0.8662
# Epoch [87/4000] Fold 1, Train Loss: 0.8717, Val Loss: 0.8655
# Epoch [88/4000] Fold 1, Train Loss: 0.8726, Val Loss: 0.8649
# Epoch [89/4000] Fold 1, Train Loss: 0.8718, Val Loss: 0.8643
# Epoch [90/4000] Fold 1, Train Loss: 0.8702, Val Loss: 0.8637
# Epoch [91/4000] Fold 1, Train Loss: 0.8688, Val Loss: 0.8631
# Epoch [92/4000] Fold 1, Train Loss: 0.8732, Val Loss: 0.8625
# Epoch [93/4000] Fold 1, Train Loss: 0.8674, Val Loss: 0.8621
# Epoch [94/4000] Fold 1, Train Loss: 0.8695, Val Loss: 0.8616
# Epoch [95/4000] Fold 1, Train Loss: 0.8660, Val Loss: 0.8611
# Epoch [96/4000] Fold 1, Train Loss: 0.8648, Val Loss: 0.8606
# Epoch [97/4000] Fold 1, Train Loss: 0.8655, Val Loss: 0.8601
# Epoch [98/4000] Fold 1, Train Loss: 0.8638, Val Loss: 0.8597
# Epoch [99/4000] Fold 1, Train Loss: 0.8647, Val Loss: 0.8592
# Epoch [100/4000] Fold 1, Train Loss: 0.8641, Val Loss: 0.8589
# Epoch [101/4000] Fold 1, Train Loss: 0.8602, Val Loss: 0.8585
# Epoch [102/4000] Fold 1, Train Loss: 0.8607, Val Loss: 0.8582
# Epoch [103/4000] Fold 1, Train Loss: 0.8600, Val Loss: 0.8577
# Epoch [104/4000] Fold 1, Train Loss: 0.8598, Val Loss: 0.8574
# Epoch [105/4000] Fold 1, Train Loss: 0.8560, Val Loss: 0.8569
# Epoch [106/4000] Fold 1, Train Loss: 0.8604, Val Loss: 0.8565
# Epoch [107/4000] Fold 1, Train Loss: 0.8580, Val Loss: 0.8561
# Epoch [108/4000] Fold 1, Train Loss: 0.8599, Val Loss: 0.8558
# Epoch [109/4000] Fold 1, Train Loss: 0.8568, Val Loss: 0.8554
# Epoch [110/4000] Fold 1, Train Loss: 0.8579, Val Loss: 0.8551
# Epoch [111/4000] Fold 1, Train Loss: 0.8544, Val Loss: 0.8548
# Epoch [112/4000] Fold 1, Train Loss: 0.8556, Val Loss: 0.8544
# Epoch [113/4000] Fold 1, Train Loss: 0.8548, Val Loss: 0.8539
# Epoch [114/4000] Fold 1, Train Loss: 0.8544, Val Loss: 0.8536
# Epoch [115/4000] Fold 1, Train Loss: 0.8530, Val Loss: 0.8531
# Epoch [116/4000] Fold 1, Train Loss: 0.8525, Val Loss: 0.8528
# Epoch [117/4000] Fold 1, Train Loss: 0.8506, Val Loss: 0.8525
# Epoch [118/4000] Fold 1, Train Loss: 0.8514, Val Loss: 0.8522
# Epoch [119/4000] Fold 1, Train Loss: 0.8488, Val Loss: 0.8516
# Epoch [120/4000] Fold 1, Train Loss: 0.8520, Val Loss: 0.8512
# Epoch [121/4000] Fold 1, Train Loss: 0.8526, Val Loss: 0.8509
# Epoch [122/4000] Fold 1, Train Loss: 0.8493, Val Loss: 0.8504
# Epoch [123/4000] Fold 1, Train Loss: 0.8500, Val Loss: 0.8501
# Epoch [124/4000] Fold 1, Train Loss: 0.8486, Val Loss: 0.8495
# Epoch [125/4000] Fold 1, Train Loss: 0.8482, Val Loss: 0.8492
# Epoch [126/4000] Fold 1, Train Loss: 0.8470, Val Loss: 0.8486
# Epoch [127/4000] Fold 1, Train Loss: 0.8479, Val Loss: 0.8482
# Epoch [128/4000] Fold 1, Train Loss: 0.8456, Val Loss: 0.8478
# Epoch [129/4000] Fold 1, Train Loss: 0.8472, Val Loss: 0.8471
# Epoch [130/4000] Fold 1, Train Loss: 0.8457, Val Loss: 0.8467
# Epoch [131/4000] Fold 1, Train Loss: 0.8451, Val Loss: 0.8459
# Epoch [132/4000] Fold 1, Train Loss: 0.8450, Val Loss: 0.8454
# Epoch [133/4000] Fold 1, Train Loss: 0.8430, Val Loss: 0.8448
# Epoch [134/4000] Fold 1, Train Loss: 0.8435, Val Loss: 0.8443
# Epoch [135/4000] Fold 1, Train Loss: 0.8413, Val Loss: 0.8436
# Epoch [136/4000] Fold 1, Train Loss: 0.8426, Val Loss: 0.8430
# Epoch [137/4000] Fold 1, Train Loss: 0.8426, Val Loss: 0.8424
# Epoch [138/4000] Fold 1, Train Loss: 0.8415, Val Loss: 0.8419
# Epoch [139/4000] Fold 1, Train Loss: 0.8404, Val Loss: 0.8413
# Epoch [140/4000] Fold 1, Train Loss: 0.8387, Val Loss: 0.8407
# Epoch [141/4000] Fold 1, Train Loss: 0.8378, Val Loss: 0.8401
# Epoch [142/4000] Fold 1, Train Loss: 0.8373, Val Loss: 0.8397
# Epoch [143/4000] Fold 1, Train Loss: 0.8391, Val Loss: 0.8390
# Epoch [144/4000] Fold 1, Train Loss: 0.8393, Val Loss: 0.8385
# Epoch [145/4000] Fold 1, Train Loss: 0.8369, Val Loss: 0.8378
# Epoch [146/4000] Fold 1, Train Loss: 0.8374, Val Loss: 0.8373
# Epoch [147/4000] Fold 1, Train Loss: 0.8374, Val Loss: 0.8367
# Epoch [148/4000] Fold 1, Train Loss: 0.8330, Val Loss: 0.8361
# Epoch [149/4000] Fold 1, Train Loss: 0.8335, Val Loss: 0.8356
# Epoch [150/4000] Fold 1, Train Loss: 0.8350, Val Loss: 0.8350
# Epoch [151/4000] Fold 1, Train Loss: 0.8337, Val Loss: 0.8344
# Epoch [152/4000] Fold 1, Train Loss: 0.8335, Val Loss: 0.8336
# Epoch [153/4000] Fold 1, Train Loss: 0.8324, Val Loss: 0.8330
# Epoch [154/4000] Fold 1, Train Loss: 0.8317, Val Loss: 0.8321
# Epoch [155/4000] Fold 1, Train Loss: 0.8306, Val Loss: 0.8312
# Epoch [156/4000] Fold 1, Train Loss: 0.8306, Val Loss: 0.8306
# Epoch [157/4000] Fold 1, Train Loss: 0.8273, Val Loss: 0.8296
# Epoch [158/4000] Fold 1, Train Loss: 0.8280, Val Loss: 0.8287
# Epoch [159/4000] Fold 1, Train Loss: 0.8274, Val Loss: 0.8279
# Epoch [160/4000] Fold 1, Train Loss: 0.8266, Val Loss: 0.8269
# Epoch [161/4000] Fold 1, Train Loss: 0.8257, Val Loss: 0.8259
# Epoch [162/4000] Fold 1, Train Loss: 0.8261, Val Loss: 0.8249
# Epoch [163/4000] Fold 1, Train Loss: 0.8254, Val Loss: 0.8238
# Epoch [164/4000] Fold 1, Train Loss: 0.8203, Val Loss: 0.8228
# Epoch [165/4000] Fold 1, Train Loss: 0.8221, Val Loss: 0.8219
# Epoch [166/4000] Fold 1, Train Loss: 0.8191, Val Loss: 0.8208
# Epoch [167/4000] Fold 1, Train Loss: 0.8198, Val Loss: 0.8198
# Epoch [168/4000] Fold 1, Train Loss: 0.8187, Val Loss: 0.8188
# Epoch [169/4000] Fold 1, Train Loss: 0.8154, Val Loss: 0.8177
# Epoch [170/4000] Fold 1, Train Loss: 0.8154, Val Loss: 0.8168
# Epoch [171/4000] Fold 1, Train Loss: 0.8161, Val Loss: 0.8160
# Epoch [172/4000] Fold 1, Train Loss: 0.8160, Val Loss: 0.8152
# Epoch [173/4000] Fold 1, Train Loss: 0.8128, Val Loss: 0.8144
# Epoch [174/4000] Fold 1, Train Loss: 0.8131, Val Loss: 0.8137
# Epoch [175/4000] Fold 1, Train Loss: 0.8118, Val Loss: 0.8127
# Epoch [176/4000] Fold 1, Train Loss: 0.8115, Val Loss: 0.8123
# Epoch [177/4000] Fold 1, Train Loss: 0.8104, Val Loss: 0.8116
# Epoch [178/4000] Fold 1, Train Loss: 0.8094, Val Loss: 0.8109
# Epoch [179/4000] Fold 1, Train Loss: 0.8101, Val Loss: 0.8105
# Epoch [180/4000] Fold 1, Train Loss: 0.8082, Val Loss: 0.8098
# Epoch [181/4000] Fold 1, Train Loss: 0.8072, Val Loss: 0.8094
# Epoch [182/4000] Fold 1, Train Loss: 0.8056, Val Loss: 0.8088
# Epoch [183/4000] Fold 1, Train Loss: 0.8084, Val Loss: 0.8085
# Epoch [184/4000] Fold 1, Train Loss: 0.8069, Val Loss: 0.8080
# Epoch [185/4000] Fold 1, Train Loss: 0.8080, Val Loss: 0.8075
# Epoch [186/4000] Fold 1, Train Loss: 0.8043, Val Loss: 0.8071
# Epoch [187/4000] Fold 1, Train Loss: 0.8059, Val Loss: 0.8066
# Epoch [188/4000] Fold 1, Train Loss: 0.8041, Val Loss: 0.8062
# Epoch [189/4000] Fold 1, Train Loss: 0.8033, Val Loss: 0.8057
# Epoch [190/4000] Fold 1, Train Loss: 0.8033, Val Loss: 0.8054
# Epoch [191/4000] Fold 1, Train Loss: 0.8017, Val Loss: 0.8050
# Epoch [192/4000] Fold 1, Train Loss: 0.8033, Val Loss: 0.8046
# Epoch [193/4000] Fold 1, Train Loss: 0.8021, Val Loss: 0.8042
# Epoch [194/4000] Fold 1, Train Loss: 0.8003, Val Loss: 0.8041
# Epoch [195/4000] Fold 1, Train Loss: 0.7998, Val Loss: 0.8038
# Epoch [196/4000] Fold 1, Train Loss: 0.7985, Val Loss: 0.8036
# Epoch [197/4000] Fold 1, Train Loss: 0.7989, Val Loss: 0.8032
# Epoch [198/4000] Fold 1, Train Loss: 0.8011, Val Loss: 0.8031
# Epoch [199/4000] Fold 1, Train Loss: 0.7974, Val Loss: 0.8027
# Epoch [200/4000] Fold 1, Train Loss: 0.7975, Val Loss: 0.8026
# Epoch [201/4000] Fold 1, Train Loss: 0.7950, Val Loss: 0.8023
# Epoch [202/4000] Fold 1, Train Loss: 0.7960, Val Loss: 0.8020
# Epoch [203/4000] Fold 1, Train Loss: 0.7973, Val Loss: 0.8019
# Epoch [204/4000] Fold 1, Train Loss: 0.7956, Val Loss: 0.8014
# Epoch [205/4000] Fold 1, Train Loss: 0.7967, Val Loss: 0.8013
# Epoch [206/4000] Fold 1, Train Loss: 0.7965, Val Loss: 0.8010
# Epoch [207/4000] Fold 1, Train Loss: 0.7948, Val Loss: 0.8009
# Epoch [208/4000] Fold 1, Train Loss: 0.7944, Val Loss: 0.8008
# Epoch [209/4000] Fold 1, Train Loss: 0.7924, Val Loss: 0.8004
# Epoch [210/4000] Fold 1, Train Loss: 0.7947, Val Loss: 0.8003
# Epoch [211/4000] Fold 1, Train Loss: 0.7911, Val Loss: 0.8000
# Epoch [212/4000] Fold 1, Train Loss: 0.7935, Val Loss: 0.7999
# Epoch [213/4000] Fold 1, Train Loss: 0.7918, Val Loss: 0.7998
# Epoch [214/4000] Fold 1, Train Loss: 0.7914, Val Loss: 0.7997
# Epoch [215/4000] Fold 1, Train Loss: 0.7903, Val Loss: 0.7993
# Epoch [216/4000] Fold 1, Train Loss: 0.7899, Val Loss: 0.7991
# Epoch [217/4000] Fold 1, Train Loss: 0.7901, Val Loss: 0.7989
# Epoch [218/4000] Fold 1, Train Loss: 0.7886, Val Loss: 0.7987
# Epoch [219/4000] Fold 1, Train Loss: 0.7913, Val Loss: 0.7985
# Epoch [220/4000] Fold 1, Train Loss: 0.7903, Val Loss: 0.7982
# Epoch [221/4000] Fold 1, Train Loss: 0.7879, Val Loss: 0.7980
# Epoch [222/4000] Fold 1, Train Loss: 0.7914, Val Loss: 0.7979
# Epoch [223/4000] Fold 1, Train Loss: 0.7887, Val Loss: 0.7975
# Epoch [224/4000] Fold 1, Train Loss: 0.7902, Val Loss: 0.7973
# Epoch [225/4000] Fold 1, Train Loss: 0.7877, Val Loss: 0.7973
# Epoch [226/4000] Fold 1, Train Loss: 0.7872, Val Loss: 0.7972
# Epoch [227/4000] Fold 1, Train Loss: 0.7875, Val Loss: 0.7968
# Epoch [228/4000] Fold 1, Train Loss: 0.7853, Val Loss: 0.7967
# Epoch [229/4000] Fold 1, Train Loss: 0.7859, Val Loss: 0.7966
# Epoch [230/4000] Fold 1, Train Loss: 0.7875, Val Loss: 0.7964
# Epoch [231/4000] Fold 1, Train Loss: 0.7852, Val Loss: 0.7963
# Epoch [232/4000] Fold 1, Train Loss: 0.7837, Val Loss: 0.7962
# Epoch [233/4000] Fold 1, Train Loss: 0.7858, Val Loss: 0.7959
# Epoch [234/4000] Fold 1, Train Loss: 0.7826, Val Loss: 0.7956
# Epoch [235/4000] Fold 1, Train Loss: 0.7841, Val Loss: 0.7953
# Epoch [236/4000] Fold 1, Train Loss: 0.7822, Val Loss: 0.7950
# Epoch [237/4000] Fold 1, Train Loss: 0.7827, Val Loss: 0.7950
# Epoch [238/4000] Fold 1, Train Loss: 0.7817, Val Loss: 0.7950
# Epoch [239/4000] Fold 1, Train Loss: 0.7812, Val Loss: 0.7948
# Epoch [240/4000] Fold 1, Train Loss: 0.7835, Val Loss: 0.7943
# Epoch [241/4000] Fold 1, Train Loss: 0.7857, Val Loss: 0.7944
# Epoch [242/4000] Fold 1, Train Loss: 0.7832, Val Loss: 0.7940
# Epoch [243/4000] Fold 1, Train Loss: 0.7805, Val Loss: 0.7938
# Epoch [244/4000] Fold 1, Train Loss: 0.7789, Val Loss: 0.7939
# Epoch [245/4000] Fold 1, Train Loss: 0.7800, Val Loss: 0.7936
# Epoch [246/4000] Fold 1, Train Loss: 0.7804, Val Loss: 0.7935
# Epoch [247/4000] Fold 1, Train Loss: 0.7810, Val Loss: 0.7932
# Epoch [248/4000] Fold 1, Train Loss: 0.7796, Val Loss: 0.7930
# Epoch [249/4000] Fold 1, Train Loss: 0.7798, Val Loss: 0.7928
# Epoch [250/4000] Fold 1, Train Loss: 0.7797, Val Loss: 0.7924
# Epoch [251/4000] Fold 1, Train Loss: 0.7807, Val Loss: 0.7923
# Epoch [252/4000] Fold 1, Train Loss: 0.7794, Val Loss: 0.7920
# Epoch [253/4000] Fold 1, Train Loss: 0.7789, Val Loss: 0.7919
# Epoch [254/4000] Fold 1, Train Loss: 0.7778, Val Loss: 0.7919
# Epoch [255/4000] Fold 1, Train Loss: 0.7795, Val Loss: 0.7917
# Epoch [256/4000] Fold 1, Train Loss: 0.7764, Val Loss: 0.7917
# Epoch [257/4000] Fold 1, Train Loss: 0.7778, Val Loss: 0.7912
# Epoch [258/4000] Fold 1, Train Loss: 0.7782, Val Loss: 0.7911
# Epoch [259/4000] Fold 1, Train Loss: 0.7800, Val Loss: 0.7908
# Epoch [260/4000] Fold 1, Train Loss: 0.7756, Val Loss: 0.7908
# Epoch [261/4000] Fold 1, Train Loss: 0.7775, Val Loss: 0.7907
# Epoch [262/4000] Fold 1, Train Loss: 0.7778, Val Loss: 0.7902
# Epoch [263/4000] Fold 1, Train Loss: 0.7769, Val Loss: 0.7903
# Epoch [264/4000] Fold 1, Train Loss: 0.7746, Val Loss: 0.7898
# Epoch [265/4000] Fold 1, Train Loss: 0.7769, Val Loss: 0.7896
# Epoch [266/4000] Fold 1, Train Loss: 0.7758, Val Loss: 0.7894
# Epoch [267/4000] Fold 1, Train Loss: 0.7762, Val Loss: 0.7890
# Epoch [268/4000] Fold 1, Train Loss: 0.7753, Val Loss: 0.7890
# Epoch [269/4000] Fold 1, Train Loss: 0.7758, Val Loss: 0.7889
# Epoch [270/4000] Fold 1, Train Loss: 0.7741, Val Loss: 0.7885
# Epoch [271/4000] Fold 1, Train Loss: 0.7747, Val Loss: 0.7882
# Epoch [272/4000] Fold 1, Train Loss: 0.7730, Val Loss: 0.7880
# Epoch [273/4000] Fold 1, Train Loss: 0.7722, Val Loss: 0.7877
# Epoch [274/4000] Fold 1, Train Loss: 0.7737, Val Loss: 0.7875
# Epoch [275/4000] Fold 1, Train Loss: 0.7727, Val Loss: 0.7872
# Epoch [276/4000] Fold 1, Train Loss: 0.7728, Val Loss: 0.7872
# Epoch [277/4000] Fold 1, Train Loss: 0.7725, Val Loss: 0.7868
# Epoch [278/4000] Fold 1, Train Loss: 0.7740, Val Loss: 0.7863
# Epoch [279/4000] Fold 1, Train Loss: 0.7719, Val Loss: 0.7862
# Epoch [280/4000] Fold 1, Train Loss: 0.7693, Val Loss: 0.7859
# Epoch [281/4000] Fold 1, Train Loss: 0.7703, Val Loss: 0.7854
# Epoch [282/4000] Fold 1, Train Loss: 0.7696, Val Loss: 0.7853
# Epoch [283/4000] Fold 1, Train Loss: 0.7719, Val Loss: 0.7851
# Epoch [284/4000] Fold 1, Train Loss: 0.7687, Val Loss: 0.7848
# Epoch [285/4000] Fold 1, Train Loss: 0.7673, Val Loss: 0.7843
# Epoch [286/4000] Fold 1, Train Loss: 0.7694, Val Loss: 0.7840
# Epoch [287/4000] Fold 1, Train Loss: 0.7700, Val Loss: 0.7839
# Epoch [288/4000] Fold 1, Train Loss: 0.7686, Val Loss: 0.7834
# Epoch [289/4000] Fold 1, Train Loss: 0.7657, Val Loss: 0.7831
# Epoch [290/4000] Fold 1, Train Loss: 0.7686, Val Loss: 0.7826
# Epoch [291/4000] Fold 1, Train Loss: 0.7671, Val Loss: 0.7823
# Epoch [292/4000] Fold 1, Train Loss: 0.7664, Val Loss: 0.7820
# Epoch [293/4000] Fold 1, Train Loss: 0.7652, Val Loss: 0.7816
# Epoch [294/4000] Fold 1, Train Loss: 0.7646, Val Loss: 0.7813
# Epoch [295/4000] Fold 1, Train Loss: 0.7636, Val Loss: 0.7808
# Epoch [296/4000] Fold 1, Train Loss: 0.7621, Val Loss: 0.7807
# Epoch [297/4000] Fold 1, Train Loss: 0.7635, Val Loss: 0.7802
# Epoch [298/4000] Fold 1, Train Loss: 0.7645, Val Loss: 0.7796
# Epoch [299/4000] Fold 1, Train Loss: 0.7615, Val Loss: 0.7793
# Epoch [300/4000] Fold 1, Train Loss: 0.7629, Val Loss: 0.7787
# Epoch [301/4000] Fold 1, Train Loss: 0.7619, Val Loss: 0.7785
# Epoch [302/4000] Fold 1, Train Loss: 0.7608, Val Loss: 0.7781
# Epoch [303/4000] Fold 1, Train Loss: 0.7617, Val Loss: 0.7776
# Epoch [304/4000] Fold 1, Train Loss: 0.7604, Val Loss: 0.7771
# Epoch [305/4000] Fold 1, Train Loss: 0.7595, Val Loss: 0.7768
# Epoch [306/4000] Fold 1, Train Loss: 0.7598, Val Loss: 0.7762
# Epoch [307/4000] Fold 1, Train Loss: 0.7583, Val Loss: 0.7756
# Epoch [308/4000] Fold 1, Train Loss: 0.7592, Val Loss: 0.7754
# Epoch [309/4000] Fold 1, Train Loss: 0.7600, Val Loss: 0.7748
# Epoch [310/4000] Fold 1, Train Loss: 0.7598, Val Loss: 0.7744
# Epoch [311/4000] Fold 1, Train Loss: 0.7549, Val Loss: 0.7739
# Epoch [312/4000] Fold 1, Train Loss: 0.7566, Val Loss: 0.7733
# Epoch [313/4000] Fold 1, Train Loss: 0.7555, Val Loss: 0.7727
# Epoch [314/4000] Fold 1, Train Loss: 0.7550, Val Loss: 0.7724
# Epoch [315/4000] Fold 1, Train Loss: 0.7541, Val Loss: 0.7719
# Epoch [316/4000] Fold 1, Train Loss: 0.7540, Val Loss: 0.7712
# Epoch [317/4000] Fold 1, Train Loss: 0.7527, Val Loss: 0.7707
# Epoch [318/4000] Fold 1, Train Loss: 0.7532, Val Loss: 0.7700
# Epoch [319/4000] Fold 1, Train Loss: 0.7531, Val Loss: 0.7695
# Epoch [320/4000] Fold 1, Train Loss: 0.7540, Val Loss: 0.7689
# Epoch [321/4000] Fold 1, Train Loss: 0.7510, Val Loss: 0.7685
# Epoch [322/4000] Fold 1, Train Loss: 0.7508, Val Loss: 0.7679
# Epoch [323/4000] Fold 1, Train Loss: 0.7526, Val Loss: 0.7671
# Epoch [324/4000] Fold 1, Train Loss: 0.7500, Val Loss: 0.7667
# Epoch [325/4000] Fold 1, Train Loss: 0.7502, Val Loss: 0.7660
# Epoch [326/4000] Fold 1, Train Loss: 0.7495, Val Loss: 0.7654
# Epoch [327/4000] Fold 1, Train Loss: 0.7476, Val Loss: 0.7645
# Epoch [328/4000] Fold 1, Train Loss: 0.7453, Val Loss: 0.7638
# Epoch [329/4000] Fold 1, Train Loss: 0.7480, Val Loss: 0.7633
# Epoch [330/4000] Fold 1, Train Loss: 0.7469, Val Loss: 0.7629
# Epoch [331/4000] Fold 1, Train Loss: 0.7461, Val Loss: 0.7620
# Epoch [332/4000] Fold 1, Train Loss: 0.7443, Val Loss: 0.7611
# Epoch [333/4000] Fold 1, Train Loss: 0.7444, Val Loss: 0.7604
# Epoch [334/4000] Fold 1, Train Loss: 0.7451, Val Loss: 0.7600
# Epoch [335/4000] Fold 1, Train Loss: 0.7426, Val Loss: 0.7593
# Epoch [336/4000] Fold 1, Train Loss: 0.7429, Val Loss: 0.7585
# Epoch [337/4000] Fold 1, Train Loss: 0.7435, Val Loss: 0.7575
# Epoch [338/4000] Fold 1, Train Loss: 0.7409, Val Loss: 0.7570
# Epoch [339/4000] Fold 1, Train Loss: 0.7394, Val Loss: 0.7562
# Epoch [340/4000] Fold 1, Train Loss: 0.7396, Val Loss: 0.7558
# Epoch [341/4000] Fold 1, Train Loss: 0.7386, Val Loss: 0.7550
# Epoch [342/4000] Fold 1, Train Loss: 0.7373, Val Loss: 0.7542
# Epoch [343/4000] Fold 1, Train Loss: 0.7383, Val Loss: 0.7534
# Epoch [344/4000] Fold 1, Train Loss: 0.7353, Val Loss: 0.7529
# Epoch [345/4000] Fold 1, Train Loss: 0.7359, Val Loss: 0.7522
# Epoch [346/4000] Fold 1, Train Loss: 0.7345, Val Loss: 0.7516
# Epoch [347/4000] Fold 1, Train Loss: 0.7338, Val Loss: 0.7506
# Epoch [348/4000] Fold 1, Train Loss: 0.7345, Val Loss: 0.7502
# Epoch [349/4000] Fold 1, Train Loss: 0.7348, Val Loss: 0.7493
# Epoch [350/4000] Fold 1, Train Loss: 0.7323, Val Loss: 0.7489
# Epoch [351/4000] Fold 1, Train Loss: 0.7315, Val Loss: 0.7480
# Epoch [352/4000] Fold 1, Train Loss: 0.7301, Val Loss: 0.7472
# Epoch [353/4000] Fold 1, Train Loss: 0.7323, Val Loss: 0.7468
# Epoch [354/4000] Fold 1, Train Loss: 0.7299, Val Loss: 0.7462
# Epoch [355/4000] Fold 1, Train Loss: 0.7315, Val Loss: 0.7457
# Epoch [356/4000] Fold 1, Train Loss: 0.7290, Val Loss: 0.7449
# Epoch [357/4000] Fold 1, Train Loss: 0.7308, Val Loss: 0.7446
# Epoch [358/4000] Fold 1, Train Loss: 0.7259, Val Loss: 0.7437
# Epoch [359/4000] Fold 1, Train Loss: 0.7287, Val Loss: 0.7431
# Epoch [360/4000] Fold 1, Train Loss: 0.7252, Val Loss: 0.7427
# Epoch [361/4000] Fold 1, Train Loss: 0.7254, Val Loss: 0.7420
# Epoch [362/4000] Fold 1, Train Loss: 0.7263, Val Loss: 0.7415
# Epoch [363/4000] Fold 1, Train Loss: 0.7261, Val Loss: 0.7409
# Epoch [364/4000] Fold 1, Train Loss: 0.7266, Val Loss: 0.7405
# Epoch [365/4000] Fold 1, Train Loss: 0.7259, Val Loss: 0.7401
# Epoch [366/4000] Fold 1, Train Loss: 0.7262, Val Loss: 0.7394
# Epoch [367/4000] Fold 1, Train Loss: 0.7253, Val Loss: 0.7389
# Epoch [368/4000] Fold 1, Train Loss: 0.7201, Val Loss: 0.7384
# Epoch [369/4000] Fold 1, Train Loss: 0.7228, Val Loss: 0.7381
# Epoch [370/4000] Fold 1, Train Loss: 0.7220, Val Loss: 0.7373
# Epoch [371/4000] Fold 1, Train Loss: 0.7205, Val Loss: 0.7370
# Epoch [372/4000] Fold 1, Train Loss: 0.7215, Val Loss: 0.7362
# Epoch [373/4000] Fold 1, Train Loss: 0.7217, Val Loss: 0.7356
# Epoch [374/4000] Fold 1, Train Loss: 0.7198, Val Loss: 0.7354
# Epoch [375/4000] Fold 1, Train Loss: 0.7217, Val Loss: 0.7346
# Epoch [376/4000] Fold 1, Train Loss: 0.7172, Val Loss: 0.7341
# Epoch [377/4000] Fold 1, Train Loss: 0.7195, Val Loss: 0.7338
# Epoch [378/4000] Fold 1, Train Loss: 0.7183, Val Loss: 0.7333
# Epoch [379/4000] Fold 1, Train Loss: 0.7175, Val Loss: 0.7328
# Epoch [380/4000] Fold 1, Train Loss: 0.7175, Val Loss: 0.7320
# Epoch [381/4000] Fold 1, Train Loss: 0.7162, Val Loss: 0.7317
# Epoch [382/4000] Fold 1, Train Loss: 0.7181, Val Loss: 0.7313
# Epoch [383/4000] Fold 1, Train Loss: 0.7181, Val Loss: 0.7307
# Epoch [384/4000] Fold 1, Train Loss: 0.7165, Val Loss: 0.7301
# Epoch [385/4000] Fold 1, Train Loss: 0.7148, Val Loss: 0.7297
# Epoch [386/4000] Fold 1, Train Loss: 0.7149, Val Loss: 0.7294
# Epoch [387/4000] Fold 1, Train Loss: 0.7131, Val Loss: 0.7290
# Epoch [388/4000] Fold 1, Train Loss: 0.7141, Val Loss: 0.7286
# Epoch [389/4000] Fold 1, Train Loss: 0.7133, Val Loss: 0.7281
# Epoch [390/4000] Fold 1, Train Loss: 0.7121, Val Loss: 0.7278
# Epoch [391/4000] Fold 1, Train Loss: 0.7119, Val Loss: 0.7274
# Epoch [392/4000] Fold 1, Train Loss: 0.7098, Val Loss: 0.7273
# Epoch [393/4000] Fold 1, Train Loss: 0.7124, Val Loss: 0.7266
# Epoch [394/4000] Fold 1, Train Loss: 0.7128, Val Loss: 0.7263
# Epoch [395/4000] Fold 1, Train Loss: 0.7112, Val Loss: 0.7260
# Epoch [396/4000] Fold 1, Train Loss: 0.7113, Val Loss: 0.7252
# Epoch [397/4000] Fold 1, Train Loss: 0.7096, Val Loss: 0.7253
# Epoch [398/4000] Fold 1, Train Loss: 0.7098, Val Loss: 0.7248
# Epoch [399/4000] Fold 1, Train Loss: 0.7092, Val Loss: 0.7244
# Epoch [400/4000] Fold 1, Train Loss: 0.7110, Val Loss: 0.7238
# Epoch [401/4000] Fold 1, Train Loss: 0.7077, Val Loss: 0.7235
# Epoch [402/4000] Fold 1, Train Loss: 0.7080, Val Loss: 0.7234
# Epoch [403/4000] Fold 1, Train Loss: 0.7081, Val Loss: 0.7231
# Epoch [404/4000] Fold 1, Train Loss: 0.7071, Val Loss: 0.7225
# Epoch [405/4000] Fold 1, Train Loss: 0.7084, Val Loss: 0.7222
# Epoch [406/4000] Fold 1, Train Loss: 0.7063, Val Loss: 0.7221
# Epoch [407/4000] Fold 1, Train Loss: 0.7062, Val Loss: 0.7215
# Epoch [408/4000] Fold 1, Train Loss: 0.7071, Val Loss: 0.7215
# Epoch [409/4000] Fold 1, Train Loss: 0.7059, Val Loss: 0.7212
# Epoch [410/4000] Fold 1, Train Loss: 0.7072, Val Loss: 0.7207
# Epoch [411/4000] Fold 1, Train Loss: 0.7075, Val Loss: 0.7205
# Epoch [412/4000] Fold 1, Train Loss: 0.7041, Val Loss: 0.7200
# Epoch [413/4000] Fold 1, Train Loss: 0.7051, Val Loss: 0.7196
# Epoch [414/4000] Fold 1, Train Loss: 0.7042, Val Loss: 0.7197
# Epoch [415/4000] Fold 1, Train Loss: 0.7047, Val Loss: 0.7191
# Epoch [416/4000] Fold 1, Train Loss: 0.7033, Val Loss: 0.7189
# Epoch [417/4000] Fold 1, Train Loss: 0.7042, Val Loss: 0.7187
# Epoch [418/4000] Fold 1, Train Loss: 0.7040, Val Loss: 0.7185
# Epoch [419/4000] Fold 1, Train Loss: 0.7048, Val Loss: 0.7181
# Epoch [420/4000] Fold 1, Train Loss: 0.7042, Val Loss: 0.7178
# Epoch [421/4000] Fold 1, Train Loss: 0.7052, Val Loss: 0.7172
# Epoch [422/4000] Fold 1, Train Loss: 0.7026, Val Loss: 0.7170
# Epoch [423/4000] Fold 1, Train Loss: 0.7017, Val Loss: 0.7168
# Epoch [424/4000] Fold 1, Train Loss: 0.7029, Val Loss: 0.7166
# Epoch [425/4000] Fold 1, Train Loss: 0.7038, Val Loss: 0.7165
# Epoch [426/4000] Fold 1, Train Loss: 0.7013, Val Loss: 0.7162
# Epoch [427/4000] Fold 1, Train Loss: 0.6998, Val Loss: 0.7156
# Epoch [428/4000] Fold 1, Train Loss: 0.7021, Val Loss: 0.7158
# Epoch [429/4000] Fold 1, Train Loss: 0.7024, Val Loss: 0.7152
# Epoch [430/4000] Fold 1, Train Loss: 0.7012, Val Loss: 0.7150
# Epoch [431/4000] Fold 1, Train Loss: 0.7006, Val Loss: 0.7150
# Epoch [432/4000] Fold 1, Train Loss: 0.6993, Val Loss: 0.7146
# Epoch [433/4000] Fold 1, Train Loss: 0.7011, Val Loss: 0.7144
# Epoch [434/4000] Fold 1, Train Loss: 0.6993, Val Loss: 0.7141
# Epoch [435/4000] Fold 1, Train Loss: 0.6978, Val Loss: 0.7140
# Epoch [436/4000] Fold 1, Train Loss: 0.6980, Val Loss: 0.7137
# Epoch [437/4000] Fold 1, Train Loss: 0.6988, Val Loss: 0.7134
# Epoch [438/4000] Fold 1, Train Loss: 0.6981, Val Loss: 0.7131
# Epoch [439/4000] Fold 1, Train Loss: 0.6987, Val Loss: 0.7126
# Epoch [440/4000] Fold 1, Train Loss: 0.6982, Val Loss: 0.7129
# Epoch [441/4000] Fold 1, Train Loss: 0.6982, Val Loss: 0.7126
# Epoch [442/4000] Fold 1, Train Loss: 0.6974, Val Loss: 0.7123
# Epoch [443/4000] Fold 1, Train Loss: 0.6967, Val Loss: 0.7120
# Epoch [444/4000] Fold 1, Train Loss: 0.6958, Val Loss: 0.7119
# Epoch [445/4000] Fold 1, Train Loss: 0.6968, Val Loss: 0.7116
# Epoch [446/4000] Fold 1, Train Loss: 0.6977, Val Loss: 0.7112
# Epoch [447/4000] Fold 1, Train Loss: 0.6944, Val Loss: 0.7113
# Epoch [448/4000] Fold 1, Train Loss: 0.6969, Val Loss: 0.7107
# Epoch [449/4000] Fold 1, Train Loss: 0.6953, Val Loss: 0.7108
# Epoch [450/4000] Fold 1, Train Loss: 0.6953, Val Loss: 0.7104
# Epoch [451/4000] Fold 1, Train Loss: 0.6959, Val Loss: 0.7104
# Epoch [452/4000] Fold 1, Train Loss: 0.6950, Val Loss: 0.7098
# Epoch [453/4000] Fold 1, Train Loss: 0.6957, Val Loss: 0.7097
# Epoch [454/4000] Fold 1, Train Loss: 0.6954, Val Loss: 0.7096
# Epoch [455/4000] Fold 1, Train Loss: 0.6939, Val Loss: 0.7095
# Epoch [456/4000] Fold 1, Train Loss: 0.6942, Val Loss: 0.7093
# Epoch [457/4000] Fold 1, Train Loss: 0.6935, Val Loss: 0.7089
# Epoch [458/4000] Fold 1, Train Loss: 0.6935, Val Loss: 0.7086
# Epoch [459/4000] Fold 1, Train Loss: 0.6948, Val Loss: 0.7085
# Epoch [460/4000] Fold 1, Train Loss: 0.6921, Val Loss: 0.7083
# Epoch [461/4000] Fold 1, Train Loss: 0.6935, Val Loss: 0.7082
# Epoch [462/4000] Fold 1, Train Loss: 0.6929, Val Loss: 0.7078
# Epoch [463/4000] Fold 1, Train Loss: 0.6920, Val Loss: 0.7080
# Epoch [464/4000] Fold 1, Train Loss: 0.6918, Val Loss: 0.7076
# Epoch [465/4000] Fold 1, Train Loss: 0.6925, Val Loss: 0.7074
# Epoch [466/4000] Fold 1, Train Loss: 0.6931, Val Loss: 0.7071
# Epoch [467/4000] Fold 1, Train Loss: 0.6920, Val Loss: 0.7070
# Epoch [468/4000] Fold 1, Train Loss: 0.6902, Val Loss: 0.7067
# Epoch [469/4000] Fold 1, Train Loss: 0.6905, Val Loss: 0.7067
# Epoch [470/4000] Fold 1, Train Loss: 0.6939, Val Loss: 0.7063
# Epoch [471/4000] Fold 1, Train Loss: 0.6911, Val Loss: 0.7063
# Epoch [472/4000] Fold 1, Train Loss: 0.6915, Val Loss: 0.7061
# Epoch [473/4000] Fold 1, Train Loss: 0.6902, Val Loss: 0.7061
# Epoch [474/4000] Fold 1, Train Loss: 0.6908, Val Loss: 0.7055
# Epoch [475/4000] Fold 1, Train Loss: 0.6898, Val Loss: 0.7055
# Epoch [476/4000] Fold 1, Train Loss: 0.6890, Val Loss: 0.7057
# Epoch [477/4000] Fold 1, Train Loss: 0.6890, Val Loss: 0.7053
# Epoch [478/4000] Fold 1, Train Loss: 0.6888, Val Loss: 0.7051
# Epoch [479/4000] Fold 1, Train Loss: 0.6900, Val Loss: 0.7051
# Epoch [480/4000] Fold 1, Train Loss: 0.6894, Val Loss: 0.7048
# Epoch [481/4000] Fold 1, Train Loss: 0.6889, Val Loss: 0.7045
# Epoch [482/4000] Fold 1, Train Loss: 0.6884, Val Loss: 0.7045
# Epoch [483/4000] Fold 1, Train Loss: 0.6890, Val Loss: 0.7042
# Epoch [484/4000] Fold 1, Train Loss: 0.6888, Val Loss: 0.7041
# Epoch [485/4000] Fold 1, Train Loss: 0.6876, Val Loss: 0.7037
# Epoch [486/4000] Fold 1, Train Loss: 0.6886, Val Loss: 0.7040
# Epoch [487/4000] Fold 1, Train Loss: 0.6881, Val Loss: 0.7036
# Epoch [488/4000] Fold 1, Train Loss: 0.6887, Val Loss: 0.7035
# Epoch [489/4000] Fold 1, Train Loss: 0.6873, Val Loss: 0.7033
# Epoch [490/4000] Fold 1, Train Loss: 0.6872, Val Loss: 0.7033
# Epoch [491/4000] Fold 1, Train Loss: 0.6864, Val Loss: 0.7027
# Epoch [492/4000] Fold 1, Train Loss: 0.6869, Val Loss: 0.7028
# Epoch [493/4000] Fold 1, Train Loss: 0.6865, Val Loss: 0.7026
# Epoch [494/4000] Fold 1, Train Loss: 0.6854, Val Loss: 0.7026
# Epoch [495/4000] Fold 1, Train Loss: 0.6885, Val Loss: 0.7024
# Epoch [496/4000] Fold 1, Train Loss: 0.6851, Val Loss: 0.7024
# Epoch [497/4000] Fold 1, Train Loss: 0.6863, Val Loss: 0.7017
# Epoch [498/4000] Fold 1, Train Loss: 0.6875, Val Loss: 0.7020
# Epoch [499/4000] Fold 1, Train Loss: 0.6854, Val Loss: 0.7016
# Epoch [500/4000] Fold 1, Train Loss: 0.6851, Val Loss: 0.7016
# Epoch [501/4000] Fold 1, Train Loss: 0.6856, Val Loss: 0.7011
# Epoch [502/4000] Fold 1, Train Loss: 0.6845, Val Loss: 0.7013
# Epoch [503/4000] Fold 1, Train Loss: 0.6857, Val Loss: 0.7013
# Epoch [504/4000] Fold 1, Train Loss: 0.6857, Val Loss: 0.7011
# Epoch [505/4000] Fold 1, Train Loss: 0.6860, Val Loss: 0.7010
# Epoch [506/4000] Fold 1, Train Loss: 0.6844, Val Loss: 0.7005
# Epoch [507/4000] Fold 1, Train Loss: 0.6852, Val Loss: 0.7006
# Epoch [508/4000] Fold 1, Train Loss: 0.6850, Val Loss: 0.7002
# Epoch [509/4000] Fold 1, Train Loss: 0.6840, Val Loss: 0.7002
# Epoch [510/4000] Fold 1, Train Loss: 0.6852, Val Loss: 0.7001
# Epoch [511/4000] Fold 1, Train Loss: 0.6830, Val Loss: 0.7000
# Epoch [512/4000] Fold 1, Train Loss: 0.6856, Val Loss: 0.7000
# Epoch [513/4000] Fold 1, Train Loss: 0.6824, Val Loss: 0.6997
# Epoch [514/4000] Fold 1, Train Loss: 0.6823, Val Loss: 0.6994
# Epoch [515/4000] Fold 1, Train Loss: 0.6842, Val Loss: 0.6997
# Epoch [516/4000] Fold 1, Train Loss: 0.6829, Val Loss: 0.6992
# Epoch [517/4000] Fold 1, Train Loss: 0.6820, Val Loss: 0.6991
# Epoch [518/4000] Fold 1, Train Loss: 0.6838, Val Loss: 0.6990
# Epoch [519/4000] Fold 1, Train Loss: 0.6829, Val Loss: 0.6988
# Epoch [520/4000] Fold 1, Train Loss: 0.6808, Val Loss: 0.6986
# Epoch [521/4000] Fold 1, Train Loss: 0.6819, Val Loss: 0.6986
# Epoch [522/4000] Fold 1, Train Loss: 0.6833, Val Loss: 0.6984
# Epoch [523/4000] Fold 1, Train Loss: 0.6836, Val Loss: 0.6983
# Epoch [524/4000] Fold 1, Train Loss: 0.6817, Val Loss: 0.6977
# Epoch [525/4000] Fold 1, Train Loss: 0.6801, Val Loss: 0.6979
# Epoch [526/4000] Fold 1, Train Loss: 0.6820, Val Loss: 0.6981
# Epoch [527/4000] Fold 1, Train Loss: 0.6815, Val Loss: 0.6977
# Epoch [528/4000] Fold 1, Train Loss: 0.6819, Val Loss: 0.6977
# Epoch [529/4000] Fold 1, Train Loss: 0.6808, Val Loss: 0.6975
# Epoch [530/4000] Fold 1, Train Loss: 0.6807, Val Loss: 0.6973
# Epoch [531/4000] Fold 1, Train Loss: 0.6793, Val Loss: 0.6973
# Epoch [532/4000] Fold 1, Train Loss: 0.6822, Val Loss: 0.6970
# Epoch [533/4000] Fold 1, Train Loss: 0.6800, Val Loss: 0.6974
# Epoch [534/4000] Fold 1, Train Loss: 0.6817, Val Loss: 0.6969
# Epoch [535/4000] Fold 1, Train Loss: 0.6807, Val Loss: 0.6972
# Epoch [536/4000] Fold 1, Train Loss: 0.6804, Val Loss: 0.6966
# Epoch [537/4000] Fold 1, Train Loss: 0.6789, Val Loss: 0.6965
# Epoch [538/4000] Fold 1, Train Loss: 0.6803, Val Loss: 0.6968
# Epoch [539/4000] Fold 1, Train Loss: 0.6791, Val Loss: 0.6960
# Epoch [540/4000] Fold 1, Train Loss: 0.6796, Val Loss: 0.6964
# Epoch [541/4000] Fold 1, Train Loss: 0.6786, Val Loss: 0.6962
# Epoch [542/4000] Fold 1, Train Loss: 0.6789, Val Loss: 0.6962
# Epoch [543/4000] Fold 1, Train Loss: 0.6788, Val Loss: 0.6961
# Epoch [544/4000] Fold 1, Train Loss: 0.6790, Val Loss: 0.6959
# Epoch [545/4000] Fold 1, Train Loss: 0.6791, Val Loss: 0.6956
# Epoch [546/4000] Fold 1, Train Loss: 0.6802, Val Loss: 0.6955
# Epoch [547/4000] Fold 1, Train Loss: 0.6791, Val Loss: 0.6956
# Epoch [548/4000] Fold 1, Train Loss: 0.6787, Val Loss: 0.6955
# Epoch [549/4000] Fold 1, Train Loss: 0.6783, Val Loss: 0.6954
# Epoch [550/4000] Fold 1, Train Loss: 0.6783, Val Loss: 0.6953
# Epoch [551/4000] Fold 1, Train Loss: 0.6789, Val Loss: 0.6948
# Epoch [552/4000] Fold 1, Train Loss: 0.6793, Val Loss: 0.6950
# Epoch [553/4000] Fold 1, Train Loss: 0.6784, Val Loss: 0.6948
# Epoch [554/4000] Fold 1, Train Loss: 0.6783, Val Loss: 0.6947
# Epoch [555/4000] Fold 1, Train Loss: 0.6789, Val Loss: 0.6949
# Epoch [556/4000] Fold 1, Train Loss: 0.6786, Val Loss: 0.6951
# Epoch [557/4000] Fold 1, Train Loss: 0.6805, Val Loss: 0.6946
# Epoch [558/4000] Fold 1, Train Loss: 0.6764, Val Loss: 0.6944
# Epoch [559/4000] Fold 1, Train Loss: 0.6777, Val Loss: 0.6948
# Epoch [560/4000] Fold 1, Train Loss: 0.6767, Val Loss: 0.6941
# Epoch [561/4000] Fold 1, Train Loss: 0.6748, Val Loss: 0.6942
# Epoch [562/4000] Fold 1, Train Loss: 0.6755, Val Loss: 0.6943
# Epoch [563/4000] Fold 1, Train Loss: 0.6762, Val Loss: 0.6936
# Epoch [564/4000] Fold 1, Train Loss: 0.6792, Val Loss: 0.6939
# Epoch [565/4000] Fold 1, Train Loss: 0.6759, Val Loss: 0.6937
# Epoch [566/4000] Fold 1, Train Loss: 0.6765, Val Loss: 0.6937
# Epoch [567/4000] Fold 1, Train Loss: 0.6750, Val Loss: 0.6937
# Epoch [568/4000] Fold 1, Train Loss: 0.6771, Val Loss: 0.6937
# Epoch [569/4000] Fold 1, Train Loss: 0.6769, Val Loss: 0.6934
# Epoch [570/4000] Fold 1, Train Loss: 0.6773, Val Loss: 0.6932
# Epoch [571/4000] Fold 1, Train Loss: 0.6784, Val Loss: 0.6933
# Epoch [572/4000] Fold 1, Train Loss: 0.6755, Val Loss: 0.6935
# Epoch [573/4000] Fold 1, Train Loss: 0.6766, Val Loss: 0.6928
# Epoch [574/4000] Fold 1, Train Loss: 0.6749, Val Loss: 0.6930
# Epoch [575/4000] Fold 1, Train Loss: 0.6764, Val Loss: 0.6927
# Epoch [576/4000] Fold 1, Train Loss: 0.6751, Val Loss: 0.6928
# Epoch [577/4000] Fold 1, Train Loss: 0.6756, Val Loss: 0.6926
# Epoch [578/4000] Fold 1, Train Loss: 0.6746, Val Loss: 0.6925
# Epoch [579/4000] Fold 1, Train Loss: 0.6759, Val Loss: 0.6930
# Epoch [580/4000] Fold 1, Train Loss: 0.6769, Val Loss: 0.6922
# Epoch [581/4000] Fold 1, Train Loss: 0.6743, Val Loss: 0.6924
# Epoch [582/4000] Fold 1, Train Loss: 0.6740, Val Loss: 0.6928
# Epoch [583/4000] Fold 1, Train Loss: 0.6754, Val Loss: 0.6920
# Epoch [584/4000] Fold 1, Train Loss: 0.6752, Val Loss: 0.6920
# Epoch [585/4000] Fold 1, Train Loss: 0.6749, Val Loss: 0.6922
# Epoch [586/4000] Fold 1, Train Loss: 0.6741, Val Loss: 0.6918
# Epoch [587/4000] Fold 1, Train Loss: 0.6766, Val Loss: 0.6918
# Epoch [588/4000] Fold 1, Train Loss: 0.6753, Val Loss: 0.6918
# Epoch [589/4000] Fold 1, Train Loss: 0.6767, Val Loss: 0.6917
# Epoch [590/4000] Fold 1, Train Loss: 0.6764, Val Loss: 0.6918
# Epoch [591/4000] Fold 1, Train Loss: 0.6752, Val Loss: 0.6915
# Epoch [592/4000] Fold 1, Train Loss: 0.6735, Val Loss: 0.6913
# Epoch [593/4000] Fold 1, Train Loss: 0.6748, Val Loss: 0.6915
# Epoch [594/4000] Fold 1, Train Loss: 0.6719, Val Loss: 0.6912
# Epoch [595/4000] Fold 1, Train Loss: 0.6730, Val Loss: 0.6914
# Epoch [596/4000] Fold 1, Train Loss: 0.6740, Val Loss: 0.6910
# Epoch [597/4000] Fold 1, Train Loss: 0.6727, Val Loss: 0.6910
# Epoch [598/4000] Fold 1, Train Loss: 0.6712, Val Loss: 0.6911
# Epoch [599/4000] Fold 1, Train Loss: 0.6734, Val Loss: 0.6908
# Epoch [600/4000] Fold 1, Train Loss: 0.6740, Val Loss: 0.6908
# Epoch [601/4000] Fold 1, Train Loss: 0.6739, Val Loss: 0.6909
# Epoch [602/4000] Fold 1, Train Loss: 0.6734, Val Loss: 0.6906
# Epoch [603/4000] Fold 1, Train Loss: 0.6720, Val Loss: 0.6908
# Epoch [604/4000] Fold 1, Train Loss: 0.6736, Val Loss: 0.6904
# Epoch [605/4000] Fold 1, Train Loss: 0.6738, Val Loss: 0.6906
# Epoch [606/4000] Fold 1, Train Loss: 0.6732, Val Loss: 0.6906
# Epoch [607/4000] Fold 1, Train Loss: 0.6729, Val Loss: 0.6903
# Epoch [608/4000] Fold 1, Train Loss: 0.6723, Val Loss: 0.6904
# Epoch [609/4000] Fold 1, Train Loss: 0.6723, Val Loss: 0.6900
# Epoch [610/4000] Fold 1, Train Loss: 0.6711, Val Loss: 0.6903
# Epoch [611/4000] Fold 1, Train Loss: 0.6713, Val Loss: 0.6902
# Epoch [612/4000] Fold 1, Train Loss: 0.6729, Val Loss: 0.6900
# Epoch [613/4000] Fold 1, Train Loss: 0.6706, Val Loss: 0.6900
# Epoch [614/4000] Fold 1, Train Loss: 0.6717, Val Loss: 0.6900
# Epoch [615/4000] Fold 1, Train Loss: 0.6721, Val Loss: 0.6900
# Epoch [616/4000] Fold 1, Train Loss: 0.6712, Val Loss: 0.6893
# Epoch [617/4000] Fold 1, Train Loss: 0.6709, Val Loss: 0.6897
# Epoch [618/4000] Fold 1, Train Loss: 0.6723, Val Loss: 0.6894
# Epoch [619/4000] Fold 1, Train Loss: 0.6724, Val Loss: 0.6897
# Epoch [620/4000] Fold 1, Train Loss: 0.6737, Val Loss: 0.6895
# Epoch [621/4000] Fold 1, Train Loss: 0.6708, Val Loss: 0.6894
# Epoch [622/4000] Fold 1, Train Loss: 0.6715, Val Loss: 0.6890
# Epoch [623/4000] Fold 1, Train Loss: 0.6719, Val Loss: 0.6892
# Epoch [624/4000] Fold 1, Train Loss: 0.6695, Val Loss: 0.6890
# Epoch [625/4000] Fold 1, Train Loss: 0.6704, Val Loss: 0.6892
# Epoch [626/4000] Fold 1, Train Loss: 0.6720, Val Loss: 0.6889
# Epoch [627/4000] Fold 1, Train Loss: 0.6702, Val Loss: 0.6891
# Epoch [628/4000] Fold 1, Train Loss: 0.6695, Val Loss: 0.6895
# Epoch [629/4000] Fold 1, Train Loss: 0.6707, Val Loss: 0.6887
# Epoch [630/4000] Fold 1, Train Loss: 0.6708, Val Loss: 0.6888
# Epoch [631/4000] Fold 1, Train Loss: 0.6692, Val Loss: 0.6891
# Epoch [632/4000] Fold 1, Train Loss: 0.6711, Val Loss: 0.6886
# Epoch [633/4000] Fold 1, Train Loss: 0.6706, Val Loss: 0.6884
# Epoch [634/4000] Fold 1, Train Loss: 0.6690, Val Loss: 0.6885
# Epoch [635/4000] Fold 1, Train Loss: 0.6699, Val Loss: 0.6885
# Epoch [636/4000] Fold 1, Train Loss: 0.6699, Val Loss: 0.6887
# Epoch [637/4000] Fold 1, Train Loss: 0.6700, Val Loss: 0.6885
# Epoch [638/4000] Fold 1, Train Loss: 0.6699, Val Loss: 0.6883
# Epoch [639/4000] Fold 1, Train Loss: 0.6704, Val Loss: 0.6881
# Epoch [640/4000] Fold 1, Train Loss: 0.6688, Val Loss: 0.6883
# Epoch [641/4000] Fold 1, Train Loss: 0.6685, Val Loss: 0.6881
# Epoch [642/4000] Fold 1, Train Loss: 0.6685, Val Loss: 0.6878
# Epoch [643/4000] Fold 1, Train Loss: 0.6712, Val Loss: 0.6882
# Epoch [644/4000] Fold 1, Train Loss: 0.6680, Val Loss: 0.6882
# Epoch [645/4000] Fold 1, Train Loss: 0.6687, Val Loss: 0.6879
# Epoch [646/4000] Fold 1, Train Loss: 0.6687, Val Loss: 0.6878
# Epoch [647/4000] Fold 1, Train Loss: 0.6694, Val Loss: 0.6879
# Epoch [648/4000] Fold 1, Train Loss: 0.6699, Val Loss: 0.6879
# Epoch [649/4000] Fold 1, Train Loss: 0.6689, Val Loss: 0.6875
# Epoch [650/4000] Fold 1, Train Loss: 0.6683, Val Loss: 0.6875
# Epoch [651/4000] Fold 1, Train Loss: 0.6686, Val Loss: 0.6874
# Epoch [652/4000] Fold 1, Train Loss: 0.6688, Val Loss: 0.6874
# Epoch [653/4000] Fold 1, Train Loss: 0.6704, Val Loss: 0.6876
# Epoch [654/4000] Fold 1, Train Loss: 0.6698, Val Loss: 0.6871
# Epoch [655/4000] Fold 1, Train Loss: 0.6690, Val Loss: 0.6872
# Epoch [656/4000] Fold 1, Train Loss: 0.6682, Val Loss: 0.6874
# Epoch [657/4000] Fold 1, Train Loss: 0.6685, Val Loss: 0.6871
# Epoch [658/4000] Fold 1, Train Loss: 0.6665, Val Loss: 0.6872
# Epoch [659/4000] Fold 1, Train Loss: 0.6683, Val Loss: 0.6873
# Epoch [660/4000] Fold 1, Train Loss: 0.6698, Val Loss: 0.6869
# Epoch [661/4000] Fold 1, Train Loss: 0.6685, Val Loss: 0.6869
# Epoch [662/4000] Fold 1, Train Loss: 0.6691, Val Loss: 0.6870
# Epoch [663/4000] Fold 1, Train Loss: 0.6705, Val Loss: 0.6870
# Epoch [664/4000] Fold 1, Train Loss: 0.6678, Val Loss: 0.6869
# Epoch [665/4000] Fold 1, Train Loss: 0.6677, Val Loss: 0.6866
# Epoch [666/4000] Fold 1, Train Loss: 0.6677, Val Loss: 0.6869
# Epoch [667/4000] Fold 1, Train Loss: 0.6668, Val Loss: 0.6865
# Epoch [668/4000] Fold 1, Train Loss: 0.6680, Val Loss: 0.6865
# Epoch [669/4000] Fold 1, Train Loss: 0.6677, Val Loss: 0.6869
# Epoch [670/4000] Fold 1, Train Loss: 0.6678, Val Loss: 0.6864
# Epoch [671/4000] Fold 1, Train Loss: 0.6692, Val Loss: 0.6863
# Epoch [672/4000] Fold 1, Train Loss: 0.6649, Val Loss: 0.6863
# Epoch [673/4000] Fold 1, Train Loss: 0.6685, Val Loss: 0.6862
# Epoch [674/4000] Fold 1, Train Loss: 0.6674, Val Loss: 0.6863
# Epoch [675/4000] Fold 1, Train Loss: 0.6668, Val Loss: 0.6860
# Epoch [676/4000] Fold 1, Train Loss: 0.6662, Val Loss: 0.6860
# Epoch [677/4000] Fold 1, Train Loss: 0.6651, Val Loss: 0.6861
# Epoch [678/4000] Fold 1, Train Loss: 0.6662, Val Loss: 0.6857
# Epoch [679/4000] Fold 1, Train Loss: 0.6657, Val Loss: 0.6859
# Epoch [680/4000] Fold 1, Train Loss: 0.6664, Val Loss: 0.6859
# Epoch [681/4000] Fold 1, Train Loss: 0.6665, Val Loss: 0.6855
# Epoch [682/4000] Fold 1, Train Loss: 0.6673, Val Loss: 0.6859
# Epoch [683/4000] Fold 1, Train Loss: 0.6670, Val Loss: 0.6855
# Epoch [684/4000] Fold 1, Train Loss: 0.6654, Val Loss: 0.6859
# Epoch [685/4000] Fold 1, Train Loss: 0.6676, Val Loss: 0.6855
# Epoch [686/4000] Fold 1, Train Loss: 0.6638, Val Loss: 0.6855
# Epoch [687/4000] Fold 1, Train Loss: 0.6664, Val Loss: 0.6855
# Epoch [688/4000] Fold 1, Train Loss: 0.6660, Val Loss: 0.6855
# Epoch [689/4000] Fold 1, Train Loss: 0.6652, Val Loss: 0.6855
# Epoch [690/4000] Fold 1, Train Loss: 0.6672, Val Loss: 0.6852
# Epoch [691/4000] Fold 1, Train Loss: 0.6661, Val Loss: 0.6847
# Epoch [692/4000] Fold 1, Train Loss: 0.6645, Val Loss: 0.6853
# Epoch [693/4000] Fold 1, Train Loss: 0.6641, Val Loss: 0.6851
# Epoch [694/4000] Fold 1, Train Loss: 0.6650, Val Loss: 0.6850
# Epoch [695/4000] Fold 1, Train Loss: 0.6654, Val Loss: 0.6846
# Epoch [696/4000] Fold 1, Train Loss: 0.6658, Val Loss: 0.6851
# Epoch [697/4000] Fold 1, Train Loss: 0.6648, Val Loss: 0.6846
# Epoch [698/4000] Fold 1, Train Loss: 0.6654, Val Loss: 0.6849
# Epoch [699/4000] Fold 1, Train Loss: 0.6632, Val Loss: 0.6846
# Epoch [700/4000] Fold 1, Train Loss: 0.6650, Val Loss: 0.6845
# Epoch [701/4000] Fold 1, Train Loss: 0.6654, Val Loss: 0.6845
# Epoch [702/4000] Fold 1, Train Loss: 0.6636, Val Loss: 0.6845
# Epoch [703/4000] Fold 1, Train Loss: 0.6641, Val Loss: 0.6845
# Epoch [704/4000] Fold 1, Train Loss: 0.6662, Val Loss: 0.6841
# Epoch [705/4000] Fold 1, Train Loss: 0.6653, Val Loss: 0.6844
# Epoch [706/4000] Fold 1, Train Loss: 0.6651, Val Loss: 0.6845
# Epoch [707/4000] Fold 1, Train Loss: 0.6641, Val Loss: 0.6846
# Epoch [708/4000] Fold 1, Train Loss: 0.6662, Val Loss: 0.6841
# Epoch [709/4000] Fold 1, Train Loss: 0.6645, Val Loss: 0.6840
# Epoch [710/4000] Fold 1, Train Loss: 0.6654, Val Loss: 0.6842
# Epoch [711/4000] Fold 1, Train Loss: 0.6641, Val Loss: 0.6842
# Epoch [712/4000] Fold 1, Train Loss: 0.6635, Val Loss: 0.6843
# Epoch [713/4000] Fold 1, Train Loss: 0.6644, Val Loss: 0.6839
# Epoch [714/4000] Fold 1, Train Loss: 0.6630, Val Loss: 0.6837
# Epoch [715/4000] Fold 1, Train Loss: 0.6645, Val Loss: 0.6840
# Epoch [716/4000] Fold 1, Train Loss: 0.6633, Val Loss: 0.6840
# Epoch [717/4000] Fold 1, Train Loss: 0.6640, Val Loss: 0.6837
# Epoch [718/4000] Fold 1, Train Loss: 0.6644, Val Loss: 0.6835
# Epoch [719/4000] Fold 1, Train Loss: 0.6643, Val Loss: 0.6838
# Epoch [720/4000] Fold 1, Train Loss: 0.6635, Val Loss: 0.6833
# Epoch [721/4000] Fold 1, Train Loss: 0.6619, Val Loss: 0.6838
# Epoch [722/4000] Fold 1, Train Loss: 0.6635, Val Loss: 0.6833
# Epoch [723/4000] Fold 1, Train Loss: 0.6649, Val Loss: 0.6833
# Epoch [724/4000] Fold 1, Train Loss: 0.6634, Val Loss: 0.6831
# Epoch [725/4000] Fold 1, Train Loss: 0.6642, Val Loss: 0.6834
# Epoch [726/4000] Fold 1, Train Loss: 0.6636, Val Loss: 0.6833
# Epoch [727/4000] Fold 1, Train Loss: 0.6634, Val Loss: 0.6832
# Epoch [728/4000] Fold 1, Train Loss: 0.6643, Val Loss: 0.6830
# Epoch [729/4000] Fold 1, Train Loss: 0.6620, Val Loss: 0.6830
# Epoch [730/4000] Fold 1, Train Loss: 0.6637, Val Loss: 0.6831
# Epoch [731/4000] Fold 1, Train Loss: 0.6623, Val Loss: 0.6828
# Epoch [732/4000] Fold 1, Train Loss: 0.6630, Val Loss: 0.6829
# Epoch [733/4000] Fold 1, Train Loss: 0.6616, Val Loss: 0.6830
# Epoch [734/4000] Fold 1, Train Loss: 0.6609, Val Loss: 0.6829
# Epoch [735/4000] Fold 1, Train Loss: 0.6639, Val Loss: 0.6828
# Epoch [736/4000] Fold 1, Train Loss: 0.6629, Val Loss: 0.6826
# Epoch [737/4000] Fold 1, Train Loss: 0.6644, Val Loss: 0.6826
# Epoch [738/4000] Fold 1, Train Loss: 0.6617, Val Loss: 0.6822
# Epoch [739/4000] Fold 1, Train Loss: 0.6615, Val Loss: 0.6823
# Epoch [740/4000] Fold 1, Train Loss: 0.6618, Val Loss: 0.6825
# Epoch [741/4000] Fold 1, Train Loss: 0.6629, Val Loss: 0.6822
# Epoch [742/4000] Fold 1, Train Loss: 0.6621, Val Loss: 0.6825
# Epoch [743/4000] Fold 1, Train Loss: 0.6620, Val Loss: 0.6821
# Epoch [744/4000] Fold 1, Train Loss: 0.6633, Val Loss: 0.6819
# Epoch [745/4000] Fold 1, Train Loss: 0.6605, Val Loss: 0.6819
# Epoch [746/4000] Fold 1, Train Loss: 0.6614, Val Loss: 0.6819
# Epoch [747/4000] Fold 1, Train Loss: 0.6611, Val Loss: 0.6819
# Epoch [748/4000] Fold 1, Train Loss: 0.6609, Val Loss: 0.6821
# Epoch [749/4000] Fold 1, Train Loss: 0.6620, Val Loss: 0.6816
# Epoch [750/4000] Fold 1, Train Loss: 0.6608, Val Loss: 0.6816
# Epoch [751/4000] Fold 1, Train Loss: 0.6624, Val Loss: 0.6822
# Epoch [752/4000] Fold 1, Train Loss: 0.6614, Val Loss: 0.6816
# Epoch [753/4000] Fold 1, Train Loss: 0.6609, Val Loss: 0.6818
# Epoch [754/4000] Fold 1, Train Loss: 0.6606, Val Loss: 0.6817
# Epoch [755/4000] Fold 1, Train Loss: 0.6629, Val Loss: 0.6817
# Epoch [756/4000] Fold 1, Train Loss: 0.6618, Val Loss: 0.6814
# Epoch [757/4000] Fold 1, Train Loss: 0.6599, Val Loss: 0.6814
# Epoch [758/4000] Fold 1, Train Loss: 0.6603, Val Loss: 0.6818
# Epoch [759/4000] Fold 1, Train Loss: 0.6611, Val Loss: 0.6812
# Epoch [760/4000] Fold 1, Train Loss: 0.6602, Val Loss: 0.6813
# Epoch [761/4000] Fold 1, Train Loss: 0.6612, Val Loss: 0.6820
# Epoch [762/4000] Fold 1, Train Loss: 0.6611, Val Loss: 0.6811
# Epoch [763/4000] Fold 1, Train Loss: 0.6616, Val Loss: 0.6811
# Epoch [764/4000] Fold 1, Train Loss: 0.6606, Val Loss: 0.6810
# Epoch [765/4000] Fold 1, Train Loss: 0.6620, Val Loss: 0.6812
# Epoch [766/4000] Fold 1, Train Loss: 0.6595, Val Loss: 0.6809
# Epoch [767/4000] Fold 1, Train Loss: 0.6608, Val Loss: 0.6813
# Epoch [768/4000] Fold 1, Train Loss: 0.6602, Val Loss: 0.6809
# Epoch [769/4000] Fold 1, Train Loss: 0.6613, Val Loss: 0.6809
# Epoch [770/4000] Fold 1, Train Loss: 0.6599, Val Loss: 0.6809
# Epoch [771/4000] Fold 1, Train Loss: 0.6605, Val Loss: 0.6805
# Epoch [772/4000] Fold 1, Train Loss: 0.6611, Val Loss: 0.6810
# Epoch [773/4000] Fold 1, Train Loss: 0.6624, Val Loss: 0.6809
# Epoch [774/4000] Fold 1, Train Loss: 0.6607, Val Loss: 0.6810
# Epoch [775/4000] Fold 1, Train Loss: 0.6610, Val Loss: 0.6805
# ...
# Epoch [2551/4000] Fold 5, Train Loss: 0.6128, Val Loss: 0.6868
# Epoch [2552/4000] Fold 5, Train Loss: 0.6124, Val Loss: 0.6857
# Epoch [2553/4000] Fold 5, Train Loss: 0.6122, Val Loss: 0.6873
# Epoch [2554/4000] Fold 5, Train Loss: 0.6114, Val Loss: 0.6861
# Epoch [2555/4000] Fold 5, Train Loss: 0.6106, Val Loss: 0.6860
# Epoch [2556/4000] Fold 5, Train Loss: 0.6129, Val Loss: 0.6866
# Epoch [2557/4000] Fold 5, Train Loss: 0.6120, Val Loss: 0.6858
# Epoch [2558/4000] Fold 5, Train Loss: 0.6121, Val Loss: 0.6860
# Epoch [2559/4000] Fold 5, Train Loss: 0.6124, Val Loss: 0.6870
# Epoch [2560/4000] Fold 5, Train Loss: 0.6120, Val Loss: 0.6865
# Epoch [2561/4000] Fold 5, Train Loss: 0.6117, Val Loss: 0.6857
# Epoch [2562/4000] Fold 5, Train Loss: 0.6121, Val Loss: 0.6862
# Epoch [2563/4000] Fold 5, Train Loss: 0.6114, Val Loss: 0.6864
# Epoch [2564/4000] Fold 5, Train Loss: 0.6124, Val Loss: 0.6872
# Epoch [2565/4000] Fold 5, Train Loss: 0.6126, Val Loss: 0.6862
# Epoch [2566/4000] Fold 5, Train Loss: 0.6120, Val Loss: 0.6869
# Epoch [2567/4000] Fold 5, Train Loss: 0.6118, Val Loss: 0.6862
# Epoch [2568/4000] Fold 5, Train Loss: 0.6127, Val Loss: 0.6863
# Epoch [2569/4000] Fold 5, Train Loss: 0.6118, Val Loss: 0.6865
# Epoch [2570/4000] Fold 5, Train Loss: 0.6125, Val Loss: 0.6873
# Epoch [2571/4000] Fold 5, Train Loss: 0.6120, Val Loss: 0.6857
# Epoch [2572/4000] Fold 5, Train Loss: 0.6117, Val Loss: 0.6868
# Epoch [2573/4000] Fold 5, Train Loss: 0.6120, Val Loss: 0.6859
# Epoch [2574/4000] Fold 5, Train Loss: 0.6131, Val Loss: 0.6865
# Epoch [2575/4000] Fold 5, Train Loss: 0.6116, Val Loss: 0.6870
# Epoch [2576/4000] Fold 5, Train Loss: 0.6120, Val Loss: 0.6871
# Epoch [2577/4000] Fold 5, Train Loss: 0.6124, Val Loss: 0.6857
# Epoch [2578/4000] Fold 5, Train Loss: 0.6116, Val Loss: 0.6867
# Epoch [2579/4000] Fold 5, Train Loss: 0.6119, Val Loss: 0.6863
# Epoch [2580/4000] Fold 5, Train Loss: 0.6121, Val Loss: 0.6859
# Epoch [2581/4000] Fold 5, Train Loss: 0.6120, Val Loss: 0.6866
# Epoch [2582/4000] Fold 5, Train Loss: 0.6110, Val Loss: 0.6862
# Epoch [2583/4000] Fold 5, Train Loss: 0.6120, Val Loss: 0.6860
# Epoch [2584/4000] Fold 5, Train Loss: 0.6112, Val Loss: 0.6861
# Epoch [2585/4000] Fold 5, Train Loss: 0.6120, Val Loss: 0.6862
# Epoch [2586/4000] Fold 5, Train Loss: 0.6129, Val Loss: 0.6864
# Epoch [2587/4000] Fold 5, Train Loss: 0.6122, Val Loss: 0.6863
# Epoch [2588/4000] Fold 5, Train Loss: 0.6119, Val Loss: 0.6859
# Epoch [2589/4000] Fold 5, Train Loss: 0.6127, Val Loss: 0.6868
# Epoch [2590/4000] Fold 5, Train Loss: 0.6103, Val Loss: 0.6861
# Epoch [2591/4000] Fold 5, Train Loss: 0.6115, Val Loss: 0.6863
# Epoch [2592/4000] Fold 5, Train Loss: 0.6100, Val Loss: 0.6863
# Epoch [2593/4000] Fold 5, Train Loss: 0.6108, Val Loss: 0.6863
# Epoch [2594/4000] Fold 5, Train Loss: 0.6128, Val Loss: 0.6867
# Epoch [2595/4000] Fold 5, Train Loss: 0.6128, Val Loss: 0.6863
# Epoch [2596/4000] Fold 5, Train Loss: 0.6116, Val Loss: 0.6861
# Epoch [2597/4000] Fold 5, Train Loss: 0.6106, Val Loss: 0.6861
# Epoch [2598/4000] Fold 5, Train Loss: 0.6124, Val Loss: 0.6871
# Epoch [2599/4000] Fold 5, Train Loss: 0.6115, Val Loss: 0.6858
# Epoch [2600/4000] Fold 5, Train Loss: 0.6112, Val Loss: 0.6864
# Epoch [2601/4000] Fold 5, Train Loss: 0.6109, Val Loss: 0.6861
# Epoch [2602/4000] Fold 5, Train Loss: 0.6116, Val Loss: 0.6859
# Epoch [2603/4000] Fold 5, Train Loss: 0.6116, Val Loss: 0.6869
# Epoch [2604/4000] Fold 5, Train Loss: 0.6110, Val Loss: 0.6860
# Epoch [2605/4000] Fold 5, Train Loss: 0.6118, Val Loss: 0.6861
# Epoch [2606/4000] Fold 5, Train Loss: 0.6112, Val Loss: 0.6863
# Epoch [2607/4000] Fold 5, Train Loss: 0.6111, Val Loss: 0.6866
# Epoch [2608/4000] Fold 5, Train Loss: 0.6116, Val Loss: 0.6861
# Epoch [2609/4000] Fold 5, Train Loss: 0.6116, Val Loss: 0.6861
# Epoch [2610/4000] Fold 5, Train Loss: 0.6112, Val Loss: 0.6870
# Epoch [2611/4000] Fold 5, Train Loss: 0.6107, Val Loss: 0.6861
# Epoch [2612/4000] Fold 5, Train Loss: 0.6119, Val Loss: 0.6869
# Epoch [2613/4000] Fold 5, Train Loss: 0.6112, Val Loss: 0.6861
# Epoch [2614/4000] Fold 5, Train Loss: 0.6103, Val Loss: 0.6856
# Epoch [2615/4000] Fold 5, Train Loss: 0.6110, Val Loss: 0.6865
# Epoch [2616/4000] Fold 5, Train Loss: 0.6126, Val Loss: 0.6867
# Epoch [2617/4000] Fold 5, Train Loss: 0.6119, Val Loss: 0.6868
# Epoch [2618/4000] Fold 5, Train Loss: 0.6092, Val Loss: 0.6860
# Epoch [2619/4000] Fold 5, Train Loss: 0.6106, Val Loss: 0.6859
# Epoch [2620/4000] Fold 5, Train Loss: 0.6112, Val Loss: 0.6869
# Epoch [2621/4000] Fold 5, Train Loss: 0.6114, Val Loss: 0.6871
# Epoch [2622/4000] Fold 5, Train Loss: 0.6113, Val Loss: 0.6869
# Epoch [2623/4000] Fold 5, Train Loss: 0.6119, Val Loss: 0.6868
# Epoch [2624/4000] Fold 5, Train Loss: 0.6099, Val Loss: 0.6863
# Epoch [2625/4000] Fold 5, Train Loss: 0.6099, Val Loss: 0.6862
# Epoch [2626/4000] Fold 5, Train Loss: 0.6122, Val Loss: 0.6869
# Epoch [2627/4000] Fold 5, Train Loss: 0.6102, Val Loss: 0.6860
# Epoch [2628/4000] Fold 5, Train Loss: 0.6118, Val Loss: 0.6867
# Epoch [2629/4000] Fold 5, Train Loss: 0.6113, Val Loss: 0.6861
# Epoch [2630/4000] Fold 5, Train Loss: 0.6098, Val Loss: 0.6859
# Epoch [2631/4000] Fold 5, Train Loss: 0.6112, Val Loss: 0.6870
# Epoch [2632/4000] Fold 5, Train Loss: 0.6127, Val Loss: 0.6867
# Epoch [2633/4000] Fold 5, Train Loss: 0.6117, Val Loss: 0.6864
# Epoch [2634/4000] Fold 5, Train Loss: 0.6106, Val Loss: 0.6862
# Epoch [2635/4000] Fold 5, Train Loss: 0.6100, Val Loss: 0.6869
# Epoch [2636/4000] Fold 5, Train Loss: 0.6104, Val Loss: 0.6857
# Epoch [2637/4000] Fold 5, Train Loss: 0.6103, Val Loss: 0.6871
# Epoch [2638/4000] Fold 5, Train Loss: 0.6110, Val Loss: 0.6864
# Epoch [2639/4000] Fold 5, Train Loss: 0.6095, Val Loss: 0.6867
# Epoch [2640/4000] Fold 5, Train Loss: 0.6115, Val Loss: 0.6863
# Epoch [2641/4000] Fold 5, Train Loss: 0.6093, Val Loss: 0.6863
# Epoch [2642/4000] Fold 5, Train Loss: 0.6105, Val Loss: 0.6867
# Epoch [2643/4000] Fold 5, Train Loss: 0.6102, Val Loss: 0.6864
# Epoch [2644/4000] Fold 5, Train Loss: 0.6104, Val Loss: 0.6864
# Epoch [2645/4000] Fold 5, Train Loss: 0.6118, Val Loss: 0.6862
# Epoch [2646/4000] Fold 5, Train Loss: 0.6112, Val Loss: 0.6865
# Epoch [2647/4000] Fold 5, Train Loss: 0.6094, Val Loss: 0.6863
# Epoch [2648/4000] Fold 5, Train Loss: 0.6110, Val Loss: 0.6863
# Epoch [2649/4000] Fold 5, Train Loss: 0.6104, Val Loss: 0.6859
# Epoch [2650/4000] Fold 5, Train Loss: 0.6117, Val Loss: 0.6865
# Epoch [2651/4000] Fold 5, Train Loss: 0.6101, Val Loss: 0.6866
# Epoch [2652/4000] Fold 5, Train Loss: 0.6104, Val Loss: 0.6871
# Epoch [2653/4000] Fold 5, Train Loss: 0.6107, Val Loss: 0.6863
# Epoch [2654/4000] Fold 5, Train Loss: 0.6114, Val Loss: 0.6859
# Epoch [2655/4000] Fold 5, Train Loss: 0.6098, Val Loss: 0.6867
# Epoch [2656/4000] Fold 5, Train Loss: 0.6108, Val Loss: 0.6858
# Epoch [2657/4000] Fold 5, Train Loss: 0.6093, Val Loss: 0.6862
# Epoch [2658/4000] Fold 5, Train Loss: 0.6108, Val Loss: 0.6865
# Epoch [2659/4000] Fold 5, Train Loss: 0.6096, Val Loss: 0.6861
# Epoch [2660/4000] Fold 5, Train Loss: 0.6105, Val Loss: 0.6862
# Epoch [2661/4000] Fold 5, Train Loss: 0.6101, Val Loss: 0.6867
# Epoch [2662/4000] Fold 5, Train Loss: 0.6102, Val Loss: 0.6862
# Epoch [2663/4000] Fold 5, Train Loss: 0.6103, Val Loss: 0.6852
# Epoch [2664/4000] Fold 5, Train Loss: 0.6097, Val Loss: 0.6866
# Epoch [2665/4000] Fold 5, Train Loss: 0.6095, Val Loss: 0.6867
# Epoch [2666/4000] Fold 5, Train Loss: 0.6095, Val Loss: 0.6860
# Epoch [2667/4000] Fold 5, Train Loss: 0.6100, Val Loss: 0.6868
# Epoch [2668/4000] Fold 5, Train Loss: 0.6105, Val Loss: 0.6863
# Epoch [2669/4000] Fold 5, Train Loss: 0.6085, Val Loss: 0.6868
# Epoch [2670/4000] Fold 5, Train Loss: 0.6120, Val Loss: 0.6870
# Epoch [2671/4000] Fold 5, Train Loss: 0.6105, Val Loss: 0.6863
# Epoch [2672/4000] Fold 5, Train Loss: 0.6090, Val Loss: 0.6859
# Epoch [2673/4000] Fold 5, Train Loss: 0.6092, Val Loss: 0.6862
# Epoch [2674/4000] Fold 5, Train Loss: 0.6112, Val Loss: 0.6877
# Epoch [2675/4000] Fold 5, Train Loss: 0.6102, Val Loss: 0.6860
# Epoch [2676/4000] Fold 5, Train Loss: 0.6084, Val Loss: 0.6859
# Epoch [2677/4000] Fold 5, Train Loss: 0.6113, Val Loss: 0.6874
# Epoch [2678/4000] Fold 5, Train Loss: 0.6110, Val Loss: 0.6862
# Epoch [2679/4000] Fold 5, Train Loss: 0.6096, Val Loss: 0.6861
# Epoch [2680/4000] Fold 5, Train Loss: 0.6107, Val Loss: 0.6862
# Epoch [2681/4000] Fold 5, Train Loss: 0.6091, Val Loss: 0.6860
# Epoch [2682/4000] Fold 5, Train Loss: 0.6092, Val Loss: 0.6865
# Epoch [2683/4000] Fold 5, Train Loss: 0.6096, Val Loss: 0.6866
# Epoch [2684/4000] Fold 5, Train Loss: 0.6108, Val Loss: 0.6863
# Epoch [2685/4000] Fold 5, Train Loss: 0.6096, Val Loss: 0.6867
# Epoch [2686/4000] Fold 5, Train Loss: 0.6100, Val Loss: 0.6862
# Epoch [2687/4000] Fold 5, Train Loss: 0.6114, Val Loss: 0.6877
# Epoch [2688/4000] Fold 5, Train Loss: 0.6085, Val Loss: 0.6854
# Epoch [2689/4000] Fold 5, Train Loss: 0.6092, Val Loss: 0.6863
# Epoch [2690/4000] Fold 5, Train Loss: 0.6102, Val Loss: 0.6869
# Epoch [2691/4000] Fold 5, Train Loss: 0.6086, Val Loss: 0.6868
# Epoch [2692/4000] Fold 5, Train Loss: 0.6090, Val Loss: 0.6859
# Epoch [2693/4000] Fold 5, Train Loss: 0.6093, Val Loss: 0.6870
# Epoch [2694/4000] Fold 5, Train Loss: 0.6100, Val Loss: 0.6861
# Epoch [2695/4000] Fold 5, Train Loss: 0.6100, Val Loss: 0.6863
# Epoch [2696/4000] Fold 5, Train Loss: 0.6081, Val Loss: 0.6865
# Epoch [2697/4000] Fold 5, Train Loss: 0.6091, Val Loss: 0.6863
# Epoch [2698/4000] Fold 5, Train Loss: 0.6103, Val Loss: 0.6864
# Epoch [2699/4000] Fold 5, Train Loss: 0.6088, Val Loss: 0.6861
# Epoch [2700/4000] Fold 5, Train Loss: 0.6089, Val Loss: 0.6870
# Epoch [2701/4000] Fold 5, Train Loss: 0.6097, Val Loss: 0.6861
# Epoch [2702/4000] Fold 5, Train Loss: 0.6107, Val Loss: 0.6862
# Epoch [2703/4000] Fold 5, Train Loss: 0.6090, Val Loss: 0.6869
# Epoch [2704/4000] Fold 5, Train Loss: 0.6088, Val Loss: 0.6860
# Epoch [2705/4000] Fold 5, Train Loss: 0.6098, Val Loss: 0.6862
# Epoch [2706/4000] Fold 5, Train Loss: 0.6094, Val Loss: 0.6865
# Epoch [2707/4000] Fold 5, Train Loss: 0.6086, Val Loss: 0.6858
# Epoch [2708/4000] Fold 5, Train Loss: 0.6102, Val Loss: 0.6862
# Epoch [2709/4000] Fold 5, Train Loss: 0.6095, Val Loss: 0.6865
# Epoch [2710/4000] Fold 5, Train Loss: 0.6085, Val Loss: 0.6858
# Epoch [2711/4000] Fold 5, Train Loss: 0.6090, Val Loss: 0.6871
# Epoch [2712/4000] Fold 5, Train Loss: 0.6105, Val Loss: 0.6870
# Epoch [2713/4000] Fold 5, Train Loss: 0.6117, Val Loss: 0.6862
# Epoch [2714/4000] Fold 5, Train Loss: 0.6105, Val Loss: 0.6869
# Epoch [2715/4000] Fold 5, Train Loss: 0.6092, Val Loss: 0.6857
# Epoch [2716/4000] Fold 5, Train Loss: 0.6096, Val Loss: 0.6860
# Epoch [2717/4000] Fold 5, Train Loss: 0.6106, Val Loss: 0.6867
# Epoch [2718/4000] Fold 5, Train Loss: 0.6089, Val Loss: 0.6860
# Epoch [2719/4000] Fold 5, Train Loss: 0.6098, Val Loss: 0.6867
# Epoch [2720/4000] Fold 5, Train Loss: 0.6092, Val Loss: 0.6859
# Epoch [2721/4000] Fold 5, Train Loss: 0.6093, Val Loss: 0.6868
# Epoch [2722/4000] Fold 5, Train Loss: 0.6087, Val Loss: 0.6859
# Epoch [2723/4000] Fold 5, Train Loss: 0.6095, Val Loss: 0.6863
# Epoch [2724/4000] Fold 5, Train Loss: 0.6089, Val Loss: 0.6861
# Epoch [2725/4000] Fold 5, Train Loss: 0.6082, Val Loss: 0.6866
# Epoch [2726/4000] Fold 5, Train Loss: 0.6083, Val Loss: 0.6862
# Epoch [2727/4000] Fold 5, Train Loss: 0.6094, Val Loss: 0.6863
# Epoch [2728/4000] Fold 5, Train Loss: 0.6093, Val Loss: 0.6867
# Epoch [2729/4000] Fold 5, Train Loss: 0.6086, Val Loss: 0.6858
# Epoch [2730/4000] Fold 5, Train Loss: 0.6106, Val Loss: 0.6861
# Epoch [2731/4000] Fold 5, Train Loss: 0.6078, Val Loss: 0.6864
# Epoch [2732/4000] Fold 5, Train Loss: 0.6099, Val Loss: 0.6861
# Epoch [2733/4000] Fold 5, Train Loss: 0.6087, Val Loss: 0.6865
# Epoch [2734/4000] Fold 5, Train Loss: 0.6091, Val Loss: 0.6866
# Epoch [2735/4000] Fold 5, Train Loss: 0.6084, Val Loss: 0.6864
# Epoch [2736/4000] Fold 5, Train Loss: 0.6094, Val Loss: 0.6858
# Epoch [2737/4000] Fold 5, Train Loss: 0.6087, Val Loss: 0.6859
# Epoch [2738/4000] Fold 5, Train Loss: 0.6079, Val Loss: 0.6862
# Epoch [2739/4000] Fold 5, Train Loss: 0.6100, Val Loss: 0.6866
# Epoch [2740/4000] Fold 5, Train Loss: 0.6077, Val Loss: 0.6860
# Epoch [2741/4000] Fold 5, Train Loss: 0.6073, Val Loss: 0.6865
# Epoch [2742/4000] Fold 5, Train Loss: 0.6101, Val Loss: 0.6862
# Epoch [2743/4000] Fold 5, Train Loss: 0.6085, Val Loss: 0.6869
# Epoch [2744/4000] Fold 5, Train Loss: 0.6084, Val Loss: 0.6862
# Epoch [2745/4000] Fold 5, Train Loss: 0.6087, Val Loss: 0.6861
# Epoch [2746/4000] Fold 5, Train Loss: 0.6079, Val Loss: 0.6866
# Epoch [2747/4000] Fold 5, Train Loss: 0.6097, Val Loss: 0.6856
# Epoch [2748/4000] Fold 5, Train Loss: 0.6096, Val Loss: 0.6859
# Epoch [2749/4000] Fold 5, Train Loss: 0.6095, Val Loss: 0.6863
# Epoch [2750/4000] Fold 5, Train Loss: 0.6067, Val Loss: 0.6861
# Epoch [2751/4000] Fold 5, Train Loss: 0.6092, Val Loss: 0.6855
# Epoch [2752/4000] Fold 5, Train Loss: 0.6088, Val Loss: 0.6863
# Epoch [2753/4000] Fold 5, Train Loss: 0.6095, Val Loss: 0.6866
# Epoch [2754/4000] Fold 5, Train Loss: 0.6084, Val Loss: 0.6862
# Epoch [2755/4000] Fold 5, Train Loss: 0.6089, Val Loss: 0.6857
# Epoch [2756/4000] Fold 5, Train Loss: 0.6069, Val Loss: 0.6871
# Epoch [2757/4000] Fold 5, Train Loss: 0.6088, Val Loss: 0.6857
# Epoch [2758/4000] Fold 5, Train Loss: 0.6087, Val Loss: 0.6864
# Epoch [2759/4000] Fold 5, Train Loss: 0.6097, Val Loss: 0.6870
# Epoch [2760/4000] Fold 5, Train Loss: 0.6079, Val Loss: 0.6858
# Epoch [2761/4000] Fold 5, Train Loss: 0.6088, Val Loss: 0.6868
# Epoch [2762/4000] Fold 5, Train Loss: 0.6083, Val Loss: 0.6866
# Epoch [2763/4000] Fold 5, Train Loss: 0.6074, Val Loss: 0.6858
# Epoch [2764/4000] Fold 5, Train Loss: 0.6068, Val Loss: 0.6869
# Epoch [2765/4000] Fold 5, Train Loss: 0.6099, Val Loss: 0.6859
# Epoch [2766/4000] Fold 5, Train Loss: 0.6093, Val Loss: 0.6872
# Epoch [2767/4000] Fold 5, Train Loss: 0.6081, Val Loss: 0.6857
# Epoch [2768/4000] Fold 5, Train Loss: 0.6082, Val Loss: 0.6866
# Epoch [2769/4000] Fold 5, Train Loss: 0.6086, Val Loss: 0.6866
# Epoch [2770/4000] Fold 5, Train Loss: 0.6085, Val Loss: 0.6862
# Epoch [2771/4000] Fold 5, Train Loss: 0.6081, Val Loss: 0.6863
# Epoch [2772/4000] Fold 5, Train Loss: 0.6074, Val Loss: 0.6868
# Epoch [2773/4000] Fold 5, Train Loss: 0.6083, Val Loss: 0.6869
# Epoch [2774/4000] Fold 5, Train Loss: 0.6079, Val Loss: 0.6864
# Epoch [2775/4000] Fold 5, Train Loss: 0.6076, Val Loss: 0.6870
# Epoch [2776/4000] Fold 5, Train Loss: 0.6084, Val Loss: 0.6856
# Epoch [2777/4000] Fold 5, Train Loss: 0.6073, Val Loss: 0.6853
# Epoch [2778/4000] Fold 5, Train Loss: 0.6078, Val Loss: 0.6863
# Epoch [2779/4000] Fold 5, Train Loss: 0.6077, Val Loss: 0.6861
# Epoch [2780/4000] Fold 5, Train Loss: 0.6093, Val Loss: 0.6871
# Epoch [2781/4000] Fold 5, Train Loss: 0.6081, Val Loss: 0.6862
# Epoch [2782/4000] Fold 5, Train Loss: 0.6082, Val Loss: 0.6862
# Epoch [2783/4000] Fold 5, Train Loss: 0.6095, Val Loss: 0.6861
# Epoch [2784/4000] Fold 5, Train Loss: 0.6073, Val Loss: 0.6862
# Epoch [2785/4000] Fold 5, Train Loss: 0.6075, Val Loss: 0.6859
# Epoch [2786/4000] Fold 5, Train Loss: 0.6078, Val Loss: 0.6877
# Epoch [2787/4000] Fold 5, Train Loss: 0.6094, Val Loss: 0.6861
# Epoch [2788/4000] Fold 5, Train Loss: 0.6077, Val Loss: 0.6864
# Epoch [2789/4000] Fold 5, Train Loss: 0.6087, Val Loss: 0.6864
# Epoch [2790/4000] Fold 5, Train Loss: 0.6085, Val Loss: 0.6857
# Epoch [2791/4000] Fold 5, Train Loss: 0.6071, Val Loss: 0.6861
# Epoch [2792/4000] Fold 5, Train Loss: 0.6084, Val Loss: 0.6867
# Epoch [2793/4000] Fold 5, Train Loss: 0.6081, Val Loss: 0.6866
# Epoch [2794/4000] Fold 5, Train Loss: 0.6081, Val Loss: 0.6857
# Epoch [2795/4000] Fold 5, Train Loss: 0.6071, Val Loss: 0.6858
# Epoch [2796/4000] Fold 5, Train Loss: 0.6064, Val Loss: 0.6855
# Epoch [2797/4000] Fold 5, Train Loss: 0.6072, Val Loss: 0.6869
# Epoch [2798/4000] Fold 5, Train Loss: 0.6078, Val Loss: 0.6868
# Epoch [2799/4000] Fold 5, Train Loss: 0.6068, Val Loss: 0.6857
# Epoch [2800/4000] Fold 5, Train Loss: 0.6085, Val Loss: 0.6852
# Epoch [2801/4000] Fold 5, Train Loss: 0.6081, Val Loss: 0.6867
# Epoch [2802/4000] Fold 5, Train Loss: 0.6080, Val Loss: 0.6864
# Epoch [2803/4000] Fold 5, Train Loss: 0.6069, Val Loss: 0.6858
# Early stopping at epoch 2803 for fold 5

# %%
# delta = 0, epochs 4000

# %%
# Example: Average validation loss across folds
avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
print(f"Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Average Validation Loss: 0.6966

# %%
# Analyze the best results for each fold outside the training function
for fold_idx, history in enumerate(cv_histories):
    # Find the epoch with the lowest validation loss
    best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
    best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
    best_train_loss = history['train_loss'][best_epoch - 1]

    print(f"Fold {fold_idx + 1}:")
    print(f"  Best Validation Loss = {best_val_loss:.4f}")
    print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
    print(f"  Best Epoch = {best_epoch}")
# Out:
# Fold 1:
#   Best Validation Loss = 0.6641
#   Corresponding Training Loss = 0.6064
#   Best Epoch = 3965
# Fold 2:
#   Best Validation Loss = 0.7073
#   Corresponding Training Loss = 0.6529
#   Best Epoch = 3999
# Fold 3:
#   Best Validation Loss = 0.7427
#   Corresponding Training Loss = 0.6637
#   Best Epoch = 3998
# Fold 4:
#   Best Validation Loss = 0.6809
#   Corresponding Training Loss = 0.5911
#   Best Epoch = 3564
# Fold 5:
#   Best Validation Loss = 0.6851
#   Corresponding Training Loss = 0.6183
#   Best Epoch = 2303

# %%
def plot_loss_curves_separately(cv_histories):
    """
    Plot training and validation loss curves for each fold in separate figures.
    
    Args:
        cv_histories (list): List of loss histories for each fold.
    """
    # Plot Training Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['train_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
    plt.title('Training Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Validation Loss
    plt.figure(figsize=(10, 6))
    for fold, history in enumerate(cv_histories):
        epochs = range(1, len(history['val_loss']) + 1)  # Dynamically set range
        plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
    plt.title('Validation Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_loss_curves_separately(cv_histories)

# %%
import os

# Define the directory where models will be saved (current folder)
save_dir = "."  # Current directory
os.makedirs(save_dir, exist_ok=True)  # Create the directory if it doesn't exist (optional for ".")

# Save each fold's best model to the directory
for i, model_state in enumerate(best_models):
    save_path = os.path.join(save_dir, f'best_model_fold_{i+1}.pth')
    torch.save(model_state, save_path)

print(f"Models saved to the current directory: {save_dir}")
# Out:
# Models saved to the current directory: .

# %% [markdown]
# # delta = 0, epochs 2000

# %% [markdown]
# # Example: Average validation loss across folds
# avg_val_loss = np.mean([history['val_loss'][-1] for history in cv_histories])
# print(f"Average Validation Loss: {avg_val_loss:.4f}")

# %% [markdown]
# # Analyze the best results for each fold outside the training function
# for fold_idx, history in enumerate(cv_histories):
#     # Find the epoch with the lowest validation loss
#     best_epoch = int(np.argmin(history['val_loss'])) + 1  # Adding 1 because epochs are 1-indexed
#     best_val_loss = history['val_loss'][best_epoch - 1]  # Accessing the loss using 0-based index
#     best_train_loss = history['train_loss'][best_epoch - 1]
#
#     print(f"Fold {fold_idx + 1}:")
#     print(f"  Best Validation Loss = {best_val_loss:.4f}")
#     print(f"  Corresponding Training Loss = {best_train_loss:.4f}")
#     print(f"  Best Epoch = {best_epoch}")

# %% [markdown]
# def plot_loss_curves_separately(cv_histories):
#     """
#     Plot training and validation loss curves for each fold in separate figures.
#
#     Args:
#         cv_histories (list): List of loss histories for each fold.
#     """
#     # Plot Training Loss
#     plt.figure(figsize=(10, 6))
#     for fold, history in enumerate(cv_histories):
#         epochs = range(1, len(history['train_loss']) + 1)  # Dynamically set range
#         plt.plot(epochs, history['train_loss'], label=f'Fold {fold + 1} Train Loss')
#     plt.title('Training Loss per Fold')
#     plt.xlabel('Epochs')
#     plt.ylabel('Loss')
#     plt.legend()
#     plt.grid(True)
#     plt.show()
#
#     # Plot Validation Loss
#     plt.figure(figsize=(10, 6))
#     for fold, history in enumerate(cv_histories):
#         epochs = range(1, len(history['val_loss']) + 1)  # Dynamically set range
#         plt.plot(epochs, history['val_loss'], label=f'Fold {fold + 1} Val Loss', linestyle='--')
#     plt.title('Validation Loss per Fold')
#     plt.xlabel('Epochs')
#     plt.ylabel('Loss')
#     plt.legend()
#     plt.grid(True)
#     plt.show()

# %% [markdown]
# import matplotlib.pyplot as plt
# plot_loss_curves_separately(cv_histories)

# %% [markdown]
# import os
#
# # Define the directory where models will be saved (current folder)
# save_dir = "."  # Current directory
# os.makedirs(save_dir, exist_ok=True)  # Create the directory if it doesn't exist (optional for ".")
#
# # Save each fold's best model to the directory
# for i, model_state in enumerate(best_models):
#     save_path = os.path.join(save_dir, f'best_model_fold_{i+1}.pth')
#     torch.save(model_state, save_path)
#
# print(f"Models saved to the current directory: {save_dir}")

# %% [markdown]
# # inference

# %%
import os
import numpy as np
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
import torchvision
import pandas as pd

# %%
import torch.nn as nn

class FeaturePredictor(nn.Module):
    def __init__(self, input_size=20, output_size=20):
        super(FeaturePredictor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 16),
            nn.ReLU(),
            nn.Linear(16, 8),
            nn.ReLU(),
            nn.Linear(8, 4),
            nn.ReLU(),
            nn.Linear(4, 8),
            nn.ReLU(),
            nn.Linear(8, 16),
            nn.ReLU(),
            nn.Linear(16,output_size)
        )
    
    def forward(self, x):
        return self.model(x)

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch

# Define the path to the specific model file
model_path = './best_model_fold_1.pth'

# Load the saved model state dictionary
model_state = torch.load(model_path)

# Initialize the model and load the state dictionary
model = FeaturePredictor()  # Replace with your model class
model.load_state_dict(model_state)
model.to(device)
model.eval()

print("Model loaded successfully.")
# Out:
# Model loaded successfully.
# C:\Users\k54739\AppData\Local\Temp\ipykernel_15744\3622140116.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_state = torch.load(model_path)

# %%
# Load the CSV file
df = pd.read_csv("ds_closeto_sd_feats.csv")

# Extract paths, labels, and features
loaded_paths = df["path"].tolist()
loaded_features = torch.tensor(df["features"].apply(eval).to_list(), dtype=torch.float32)
print(df.head())
print(f"Loaded features shape: {loaded_features.shape}")
print(f"Loaded paths: {len(loaded_paths)}")
# Out:
#                                                 path  \
# 0  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
# 1  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
# 2  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
# 3  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
# 4  C:\Users\k54739\Bibi_new_thesis\thesis\day10to...
#
#                                             features
# 0  [-0.04119446501135826, -0.4279928207397461, 0....
# 1  [-0.1709444522857666, 0.1268514096736908, -0.7...
# 2  [-0.9513655304908752, -0.17941886186599731, -0...
# 3  [0.6149718761444092, -0.18044540286064148, -2....
# 4  [-0.7171481847763062, 0.6128349304199219, 0.53...
# Loaded features shape: torch.Size([22, 20])
# Loaded paths: 22

# %% [markdown]
# # Load the CSV file
# df = pd.read_csv("cond7_combined_features.csv")
#
# # Extract paths, labels, and features
# loaded_paths = df["path"].tolist()
# loaded_labels = df["label"].tolist()
# loaded_features = torch.tensor(df["features"].apply(eval).to_list(), dtype=torch.float32)
# feats = loaded_features
# print(df.head())
# print(f"Loaded features shape: {loaded_features.shape}")
# print(f"Loaded paths: {len(loaded_paths)}")
# print(f"Loaded labels: {len(loaded_labels)}")

# %% [markdown]
# features_mean = feats.mean(dim=0, keepdim=True)
# features_std = feats.std(dim=0, keepdim=True)
#
# normalized_feats = (feats - features_mean) / features_std

# %% [markdown]
# # Save features_min and features_max
# torch.save(features_mean, "train_mean.pth")
# torch.save(features_std, "train_std.pth")
#
# print("Features mean and std saved successfully.")

# %%
# Load features_min and features_max
loaded_features_mean = torch.load("train_mean.pth")
loaded_features_std = torch.load("train_std.pth")
print(loaded_features_mean.shape)
print(loaded_features_std.shape)
normalized_feats = (loaded_features - loaded_features_mean) / loaded_features_std
# Out:
# torch.Size([1, 20])
# torch.Size([1, 20])
# C:\Users\k54739\AppData\Local\Temp\ipykernel_15744\106586103.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_features_mean = torch.load("train_mean.pth")
# C:\Users\k54739\AppData\Local\Temp\ipykernel_15744\106586103.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_features_std = torch.load("train_std.pth")

# %%
# Assuming normalized_feats is a tensor of shape [num_samples, num_features]
from torch.utils.data import TensorDataset, DataLoader
inference_dataset = TensorDataset(normalized_feats)
inference_loader = DataLoader(inference_dataset, batch_size=32, shuffle=False)

# %%
# Define a prefix for the group of images (e.g., "original" or "augmented")
prefix = "ds_closeto_sd"  # Change this for different groups, e.g., "augmented", "group1"

# Perform inference
mse_errors = []
euclidean_distances = []
cosine_distances = []

# Use the same criterion as during training
criterion = nn.MSELoss(reduction='none')  # Use 'none' to calculate loss per sample

with torch.no_grad():
    for batch_feats in inference_loader:
        # Extract features
        batch_feats = batch_feats[0].to(device)
        outputs = model(batch_feats)

        # Calculate MSE loss for each feature vector
        batch_mse = criterion(outputs, batch_feats).mean(dim=1)  # MSE per sample
        mse_errors.extend(batch_mse.cpu().numpy())

        # Calculate Euclidean distance for each feature vector
        batch_euclidean = torch.norm(outputs - batch_feats, p=2, dim=1)  # L2 norm
        euclidean_distances.extend(batch_euclidean.cpu().numpy())

        # Calculate Cosine distance for each feature vector
        batch_cosine_similarity = torch.nn.functional.cosine_similarity(outputs, batch_feats, dim=1)
        batch_cosine_distance = 1 - batch_cosine_similarity  # Cosine distance = 1 - Cosine similarity
        cosine_distances.extend(batch_cosine_distance.cpu().numpy())

# Convert results to numpy arrays for further analysis
mse_errors = np.array(mse_errors)
euclidean_distances = np.array(euclidean_distances)
cosine_distances = np.array(cosine_distances)

# Save the results with the prefix
np.save(f"{prefix}_mse_errors.npy", mse_errors)
np.save(f"{prefix}_euclidean_distances.npy", euclidean_distances)
np.save(f"{prefix}_cosine_distances.npy", cosine_distances)

print(f"Errors and distances for group '{prefix}' saved successfully.")
# Out:
# Errors and distances for group 'ds_closeto_sd' saved successfully.

# %%
prefix = "ds_closeto_sd"  # Replace with your specific prefix

# Load the saved metrics
cond7_mse_errors = np.load(f"{prefix}_mse_errors.npy")
cond7_euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cond7_cosine_distances = np.load(f"{prefix}_cosine_distances.npy")
cond7_cosine_distances.shape
# Out:
# (22,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_distributions_with_boxplot(sd_metrics, control_metrics, exd_metrics, ds_metrics, metric_names, bins=20):
    """
    Plots the histogram and box-and-whisker plots for multiple metrics across multiple groups.

    Args:
        sd_metrics (dict): Dictionary of metrics for the SD group. Keys are metric names, values are arrays.
        control_metrics (dict): Dictionary of metrics for the Control group. Keys are metric names, values are arrays.
        exd_metrics (dict): Dictionary of metrics for the EXD group. Keys are metric names, values are arrays.
        ds_metrics (dict): Dictionary of metrics for the Ds Close to SD group. Keys are metric names, values are arrays.
        metric_names (list): Names of the metrics to plot (e.g., ["Reconstruction Error", "Cosine Distance"]).
        bins (int): Number of bins for the histogram.
    """
    for metric_name in metric_names:
        # Extract metrics for all groups
        sd_values = sd_metrics[metric_name]
        control_values = control_metrics[metric_name]
        exd_values = exd_metrics[metric_name]
        ds_values = ds_metrics[metric_name]

        # Create figure with two subplots: Histogram (top) and Boxplot (bottom)
        fig, axes = plt.subplots(2, 1, figsize=(14, 12), gridspec_kw={'height_ratios': [3, 1]})

        # Histogram
        axes[0].hist(sd_values, bins=bins, alpha=0.6, label="SD Group", color="orange", edgecolor="black")
        axes[0].hist(control_values, bins=bins, alpha=0.6, label="Cond7 Group", color="blue", edgecolor="black")
        axes[0].hist(exd_values, bins=bins, alpha=0.6, label="EXD Group", color="green", edgecolor="black")
        axes[0].hist(ds_values, bins=bins, alpha=0.6, label="Ds Close to SD Group", color="red", edgecolor="black")

        # Add mean lines to the histogram
        axes[0].axvline(np.mean(sd_values), color='orange', linestyle='-', label=f"SD Mean: {np.mean(sd_values):.4f}")
        axes[0].axvline(np.mean(control_values), color='blue', linestyle='-', label=f"Cond7 Mean: {np.mean(control_values):.4f}")
        axes[0].axvline(np.mean(exd_values), color='green', linestyle='-', label=f"EXD Mean: {np.mean(exd_values):.4f}")
        axes[0].axvline(np.mean(ds_values), color='red', linestyle='-', label=f"Ds Mean: {np.mean(ds_values):.4f}")

        # Add title and legend to the histogram
        axes[0].set_title(f"{metric_name} Distribution", fontsize=16)
        axes[0].set_xlabel(metric_name, fontsize=14)
        axes[0].set_ylabel("Frequency", fontsize=14)
        axes[0].legend(fontsize=10)
        axes[0].grid(alpha=0.3)

        # Box-and-whisker plot
        data = [sd_values, control_values, exd_values, ds_values]
        labels = ["SD Group", "Cond7 Group", "EXD Group", "Ds Close to SD Group"]
        axes[1].boxplot(data, labels=labels, patch_artist=True, 
                        boxprops=dict(facecolor="lightgrey", color="black"),
                        medianprops=dict(color="black"), whiskerprops=dict(color="black"))

        # Add title and labels to the boxplot
        axes[1].set_title(f"{metric_name} Box-and-Whisker Plot", fontsize=16)
        axes[1].set_ylabel(metric_name, fontsize=14)

        # Adjust layout and show the plot
        plt.tight_layout()
        plt.show()

# Example Usage
if __name__ == "__main__":
    # Load the metrics for SD and Control groups
    sd_metrics = {
        "Reconstruction Error": np.load("sd_mse_errors.npy"),
        "Cosine Distance": np.load("sd_cosine_distances.npy"),
        "Euclidean Distance": np.load("sd_euclidean_distances.npy")
    }

    control_metrics = {
        "Reconstruction Error": np.load("cond7_mse_errors.npy"),
        "Cosine Distance": np.load("cond7_cosine_distances.npy"),
        "Euclidean Distance": np.load("cond7_euclidean_distances.npy")
    }

    # Load the metrics for EXD and Ds Close to SD groups
    exd_metrics = {
        "Reconstruction Error": np.load("ex_mse_errors.npy"),
        "Cosine Distance": np.load("ex_cosine_distances.npy"),
        "Euclidean Distance": np.load("ex_euclidean_distances.npy")
    }

    ds_metrics = {
        "Reconstruction Error": np.load("ds_closeto_sd_mse_errors.npy"),
        "Cosine Distance": np.load("ds_closeto_sd_cosine_distances.npy"),
        "Euclidean Distance": np.load("ds_closeto_sd_euclidean_distances.npy")
    }

    # Define the metric names
    metric_names = ["Reconstruction Error", "Cosine Distance", "Euclidean Distance"]

    # Plot distributions with boxplots
    plot_distributions_with_boxplot(sd_metrics, control_metrics, exd_metrics, ds_metrics, metric_names)
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_15744\3256272314.py:48: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=labels, patch_artist=True,
# C:\Users\k54739\AppData\Local\Temp\ipykernel_15744\3256272314.py:48: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=labels, patch_artist=True,
# C:\Users\k54739\AppData\Local\Temp\ipykernel_15744\3256272314.py:48: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=labels, patch_artist=True,

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_distributions_with_boxplot(sd_metrics, control_metrics, exd_metrics, ds_metrics, cond_metrics, metric_names, bins=20):
    """
    Plots the histogram and box-and-whisker plots for multiple metrics across multiple groups.

    Args:
        sd_metrics (dict): Dictionary of metrics for the SD group. Keys are metric names, values are arrays.
        control_metrics (dict): Dictionary of metrics for the Control group. Keys are metric names, values are arrays.
        exd_metrics (dict): Dictionary of metrics for the EXD group. Keys are metric names, values are arrays.
        ds_metrics (dict): Dictionary of metrics for the Ds Close to SD group. Keys are metric names, values are arrays.
        cond_metrics (dict): Dictionary of metrics for the Cond10 group. Keys are metric names, values are arrays.
        metric_names (list): Names of the metrics to plot (e.g., ["Reconstruction Error", "Cosine Distance"]).
        bins (int): Number of bins for the histogram.
    """
    for metric_name in metric_names:
        # Extract metrics for all groups
        sd_values = sd_metrics[metric_name]
        control_values = control_metrics[metric_name]
        exd_values = exd_metrics[metric_name]
        ds_values = ds_metrics[metric_name]
        cond_values = cond_metrics[metric_name]

        # Create figure with two subplots: Histogram (top) and Boxplot (bottom)
        fig, axes = plt.subplots(2, 1, figsize=(14, 12), gridspec_kw={'height_ratios': [3, 1]})

        # Histogram
        axes[0].hist(sd_values, bins=bins, alpha=0.6, label="SD Group", color="orange", edgecolor="black")
        axes[0].hist(control_values, bins=bins, alpha=0.6, label="Control Group", color="blue", edgecolor="black")
        axes[0].hist(exd_values, bins=bins, alpha=0.6, label="EXD Group", color="green", edgecolor="black")
        axes[0].hist(ds_values, bins=bins, alpha=0.6, label="Ds Close to SD Group", color="red", edgecolor="black")
        axes[0].hist(cond_values, bins=bins, alpha=0.6, label="Cond10 Group", color="purple", edgecolor="black")

        # Add mean lines to the histogram
        axes[0].axvline(np.mean(sd_values), color='orange', linestyle='-', label=f"SD Mean: {np.mean(sd_values):.4f}")
        axes[0].axvline(np.mean(control_values), color='blue', linestyle='-', label=f"Control Mean: {np.mean(control_values):.4f}")
        axes[0].axvline(np.mean(exd_values), color='green', linestyle='-', label=f"EXD Mean: {np.mean(exd_values):.4f}")
        axes[0].axvline(np.mean(ds_values), color='red', linestyle='-', label=f"Ds Mean: {np.mean(ds_values):.4f}")
        axes[0].axvline(np.mean(cond_values), color='purple', linestyle='-', label=f"Cond10 Mean: {np.mean(cond_values):.4f}")

        # Add title and legend to the histogram
        axes[0].set_title(f"{metric_name} Distribution", fontsize=16)
        axes[0].set_xlabel(metric_name, fontsize=14)
        axes[0].set_ylabel("Frequency", fontsize=14)
        axes[0].legend(fontsize=10)
        axes[0].grid(alpha=0.3)

        # Box-and-whisker plot
        data = [sd_values, control_values, exd_values, ds_values, cond_values]
        labels = ["SD Group", "Control Group", "EXD Group", "Ds Close to SD Group", "Cond10 Group"]
        axes[1].boxplot(data, labels=labels, patch_artist=True, 
                        boxprops=dict(facecolor="lightgrey", color="black"),
                        medianprops=dict(color="black"), whiskerprops=dict(color="black"))

        # Add title and labels to the boxplot
        axes[1].set_title(f"{metric_name} Box-and-Whisker Plot", fontsize=16)
        axes[1].set_ylabel(metric_name, fontsize=14)

        # Adjust layout and show the plot
        plt.tight_layout()
        plt.show()

# Example Usage
if __name__ == "__main__":
    # Load the metrics for SD and Control groups
    sd_metrics = {
        "Reconstruction Error": np.load("sd_mse_errors.npy"),
        "Cosine Distance": np.load("sd_cosine_distances.npy"),
        "Euclidean Distance": np.load("sd_euclidean_distances.npy")
    }

    control_metrics = {
        "Reconstruction Error": np.load("cond7_mse_errors.npy"),
        "Cosine Distance": np.load("cond7_cosine_distances.npy"),
        "Euclidean Distance": np.load("cond7_euclidean_distances.npy")
    }

    # Load the metrics for EXD and Ds Close to SD groups
    exd_metrics = {
        "Reconstruction Error": np.load("ex_mse_errors.npy"),
        "Cosine Distance": np.load("ex_cosine_distances.npy"),
        "Euclidean Distance": np.load("ex_euclidean_distances.npy")
    }

    ds_metrics = {
        "Reconstruction Error": np.load("ds_closeto_sd_mse_errors.npy"),
        "Cosine Distance": np.load("ds_closeto_sd_cosine_distances.npy"),
        "Euclidean Distance": np.load("ds_closeto_sd_euclidean_distances.npy")
    }

    # Load the metrics for Cond10 group
    cond_metrics = {
        "Reconstruction Error": np.load("cond10_mse_errors.npy"),
        "Cosine Distance": np.load("cond10_cosine_distances.npy"),
        "Euclidean Distance": np.load("cond10_euclidean_distances.npy")
    }

    # Define the metric names
    metric_names = ["Reconstruction Error", "Cosine Distance", "Euclidean Distance"]

    # Plot distributions with boxplots
    plot_distributions_with_boxplot(sd_metrics, control_metrics, exd_metrics, ds_metrics, cond_metrics, metric_names)
# Out:
# C:\Users\k54739\AppData\Local\Temp\ipykernel_15744\3134692173.py:52: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=labels, patch_artist=True,
# C:\Users\k54739\AppData\Local\Temp\ipykernel_15744\3134692173.py:52: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=labels, patch_artist=True,
# C:\Users\k54739\AppData\Local\Temp\ipykernel_15744\3134692173.py:52: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=labels, patch_artist=True,

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the saved metrics
prefix = "ds_closeto_sd"  # Adjust to the prefix you used
mse_errors = np.load(f"{prefix}_mse_errors.npy")
euclidean_distances = np.load(f"{prefix}_euclidean_distances.npy")
cosine_distances = np.load(f"{prefix}_cosine_distances.npy")

# Plot MSE Errors
plt.figure(figsize=(10, 6))
plt.hist(mse_errors, bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.title(f"{prefix} - MSE Errors", fontsize=16)
plt.xlabel("MSE Error", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Euclidean Distances
plt.figure(figsize=(10, 6))
plt.hist(euclidean_distances, bins=30, alpha=0.7, color='green', edgecolor='black')
plt.title(f"{prefix} - Euclidean Distances", fontsize=16)
plt.xlabel("Euclidean Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()

# Plot Cosine Distances
plt.figure(figsize=(10, 6))
plt.hist(cosine_distances, bins=30, alpha=0.7, color='red', edgecolor='black')
plt.title(f"{prefix} - Cosine Distances", fontsize=16)
plt.xlabel("Cosine Distance", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(alpha=0.3)
plt.show()
